# %% [markdown]
# [Pandas Data Validation](https://www.w3resource.com/python-exercises/pandas/pandas-data-validation.php)

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# <div class="alert alert-warning">
#
# **1. Checking Missing Values in a DataFrame**
#
# **Write a Pandas program to check for missing values in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1138         179         9  81.26      0.01  724.0266
# 1  2023-01-02         1241         196         1  42.00      0.17   34.8600
# 2  2023-01-03         1808         141         6  92.96      0.06  524.2944
# 3  2023-01-04         1217         137         9  53.24      0.29  340.2036
# 4  2023-01-05         1158         139         4  38.55      0.29  109.4820
# 5  2023-01-06         1255         157         7  49.89      0.26  258.4302
# 6  2023-01-07         1440         133         9  36.71      0.27  241.1847
# 7  2023-01-08         1485         147         1  52.73      0.02   51.6754
# 8  2023-01-09         1157         158         3  21.80      0.16   54.9360
# 9  2023-01-10         1411         132         1  41.71      0.12   36.7048
# 10 2023-01-11         1960         154         1  35.51      0.06   33.3794
# 11 2023-01-12         1629         112         2  49.50      0.13   86.1300
# 12 2023-01-13         1684         127         2  41.37      0.06   77.7756
# 13 2023-01-14         1750         144         6  60.48      0.10  326.5920
# 14 2023-01-15         1785         170         2  58.08      0.20   92.9280
# 15 2023-01-16         1401         198         3  12.91      0.18   31.7586
# 16 2023-01-17         1666         125         3  81.47      0.19  197.9721
# 17 2023-01-18         1845         165         1  45.04      0.20   36.0320
# 18 2023-01-19         1851         119         1  27.74      0.19   22.4694
# 19 2023-01-20         1862         182         8  25.48      0.01  201.8016
# 20 2023-01-21         1175         175         3  20.37      0.04   58.6656
# 21 2023-01-22         1341         169         4  45.27      0.21  143.0532
# 22 2023-01-23         1001         157         1  77.46      0.19   62.7426
# 23 2023-01-24         1098         113         3  67.47      0.22  157.8798
# 24 2023-01-25         1230         138         4  92.72      0.11  330.0832
# 25 2023-01-26         1229         104         1  19.10      0.13   16.6170
# 26 2023-01-27         1133         114         4  67.45      0.24  205.0480
# 27 2023-01-28         1763         182         3  41.91      0.05  119.4435
# 28 2023-01-29         1891         198         6  77.32      0.05  440.7240
# 29 2023-01-30         1228         158         8  93.83      0.20  600.5120
# 30 2023-01-31         1583         182         8  26.57      0.07  197.6808
# 31 2023-02-01         1262         167         9  64.72      0.27  425.2104
# 32 2023-02-02         1127         155         2  31.36      0.15   53.3120
# 33 2023-02-03         1279         120         9  20.16      0.07  168.7392
# 34 2023-02-04         1621         152         4  36.46      0.13  126.8808
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          8   West         Online      False              5            26
# 1          6  South    Credit Card       True              2            50
# 2          8   West    Credit Card       True              5            23
# 3          1  South         Online       True              2            27
# 4          7   West           Cash      False              3            63
# 5          8   West         Online       True              4            69
# 6          9   East    Credit Card       True              3            42
# 7          5   East    Credit Card       True              4            22
# 8          3  North         Online       True              4            23
# 9          1   East         Online       True              1            21
# 10         1   East         Online      False              3            45
# 11         9  North    Credit Card       True              4            61
# 12         8   East    Credit Card      False              1            45
# 13         9  North    Credit Card      False              3            24
# 14         1   West    Credit Card       True              2            58
# 15         2   West           Cash       True              3            51
# 16         5   East    Credit Card       True              3            63
# 17         3  North    Credit Card      False              5            26
# 18         4   East    Credit Card       True              2            58
# 19         1  North         Online      False              1            38
# 20         1  North         Online       True              1            67
# 21         3   West         Online       True              5            21
# 22         2   West         Online       True              4            49
# 23         6   West           Cash      False              4            48
# 24         6   West         Online       True              2            19
# 25         4   East    Credit Card      False              4            54
# 26         4  North           Cash       True              6            63
# 27         6  South           Cash       True              4            60
# 28         9  North    Credit Card       True              2            35
# 29         5   West         Online       True              2            40
# 30         1   West    Credit Card      False              1            20
# 31         1   East           Cash      False              1            50
# 32         6   East    Credit Card      False              6            18
# 33         1  South    Credit Card      False              1            25
# 34         3  North           Cash       True              2            21
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male         Clothing     2.3  Not Returned   Neutral          10.32
# 1    Other      Electronics     1.6  Not Returned  Positive          12.61
# 2   Female         Clothing     3.9      Returned  Negative           5.75
# 3    Other             Food     4.8      Returned   Neutral           6.15
# 4    Other             Food     1.0  Not Returned  Positive          10.47
# 5   Female      Electronics     4.7  Not Returned  Positive            NaN
# 6   Female            Books     4.3  Not Returned  Positive           6.61
# 7   Female      Electronics     3.9      Returned   Neutral          15.10
# 8    Other         Clothing     4.1  Not Returned   Neutral          10.40
# 9     Male      Electronics     2.5  Not Returned  Negative           5.35
# 10   Other             Food     1.4  Not Returned  Positive            NaN
# 11   Other      Electronics     1.2  Not Returned   Neutral           5.82
# 12  Female            Books     2.7      Returned  Positive          19.89
# 13    Male      Electronics     4.9  Not Returned   Neutral          16.13
# 14    Male            Books     3.5      Returned  Positive          16.22
# 15   Other             Food     4.5  Not Returned   Neutral            NaN
# 16  Female      Electronics     4.6  Not Returned  Positive          12.73
# 17    Male         Clothing     2.2  Not Returned  Negative            NaN
# 18    Male      Electronics     2.9  Not Returned  Positive            NaN
# 19  Female      Electronics     4.2      Returned   Neutral            NaN
# 20  Female      Electronics     2.6      Returned  Positive          15.58
# 21    Male      Electronics     3.4      Returned   Neutral          13.35
# 22    Male            Books     1.9  Not Returned  Negative            NaN
# 23  Female      Electronics     2.8      Returned  Negative          17.89
# 24    Male             Food     4.1  Not Returned  Negative           9.50
# 25   Other      Electronics     3.5  Not Returned  Negative           5.14
# 26    Male      Electronics     3.4  Not Returned  Negative            NaN
# 27    Male         Clothing     2.3  Not Returned  Positive          10.00
# 28  Female            Books     2.8  Not Returned  Negative          18.97
# 29  Female             Food     2.0  Not Returned   Neutral          13.44
# 30   Other             Food     1.1  Not Returned  Positive            NaN
# 31   Other      Electronics     2.1  Not Returned  Negative           9.26
# 32   Other            Books     1.8      Returned   Neutral          14.53
# 33  Female             Food     4.6      Returned   Neutral          12.29
# 34  Female            Books     2.9  Not Returned  Positive          19.24
#
#    coupon_code  delivery_rating
# 0     WELCOME5              4.2
# 1       SAVE10              2.9
# 2          nan              2.8
# 3       SAVE10              3.7
# 4          nan              NaN
# 5     WELCOME5              2.9
# 6          nan              1.8
# 7     FREESHIP              NaN
# 8     WELCOME5              3.2
# 9       SAVE10              NaN
# 10    WELCOME5              4.3
# 11         nan              NaN
# 12      SAVE10              2.2
# 13    FREESHIP              NaN
# 14      SAVE10              2.0
# 15      SAVE10              1.6
# 16         nan              1.5
# 17    FREESHIP              2.6
# 18      SAVE10              4.9
# 19         nan              2.0
# 20    FREESHIP              2.0
# 21         nan              1.1
# 22      SAVE10              NaN
# 23         nan              3.4
# 24    FREESHIP              1.8
# 25      SAVE10              NaN
# 26         nan              3.3
# 27      SAVE10              3.8
# 28      SAVE10              1.3
# 29         nan              1.9
# 30    FREESHIP              1.4
# 31      SAVE10              4.6
# 32         nan              3.9
# 33         nan              4.6
# 34      SAVE10              2.1

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
# 1. Checking Missing Values in a DataFrame
# Write a Pandas program to check for missing values in a DataFrame.

# Check for missing values
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# shipping_cost      9
# delivery_rating    7
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **2. Ensuring Consistent Data Types of All Columns**
#
# **Write a Pandas program to check and ensure that the data types of all columns are consistent.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1154         156         6  84.33      0.23  389.6046
# 1  2023-01-02         1523         130         3  20.79      0.02   61.1226
# 2  2023-01-03         1860         141         3  21.79      0.17   54.2571
# 3  2023-01-04         1145         134         9  79.76      0.06  674.7696
# 4  2023-01-05         1100         181         8  14.09      0.25   84.5400
# 5  2023-01-06         1115         172         9  25.93      0.02  228.7026
# 6  2023-01-07         1770         111         4  69.48      0.16  233.4528
# 7  2023-01-08         1154         168         1  18.41      0.07   17.1213
# 8  2023-01-09         1440         151         5  21.48      0.04  103.1040
# 9  2023-01-10         1897         155         6  68.68      0.25  309.0600
# 10 2023-01-11         1354         162         5  11.05      0.03   53.5925
# 11 2023-01-12         1469         126         4  94.45      0.02  370.2440
# 12 2023-01-13         1357         136         4  45.98      0.12  161.8496
# 13 2023-01-14         1229         116         2  47.45      0.28   68.3280
# 14 2023-01-15         1613         132         5  30.64      0.11  136.3480
# 15 2023-01-16         1978         129         8  35.11      0.22  219.0864
# 16 2023-01-17         1137         163         4  52.56      0.20  168.1920
# 17 2023-01-18         1948         117         8  68.44      0.20  438.0160
# 18 2023-01-19         1183         172         7  69.52      0.23  374.7128
# 19 2023-01-20         1827         128         8  44.70      0.16  300.3840
# 20 2023-01-21         1710         141         1  80.04      0.13   69.6348
# 21 2023-01-22         1779         111         3  30.69      0.29   65.3697
# 22 2023-01-23         1686         126         2  83.46      0.27  121.8516
# 23 2023-01-24         1224         177         4  41.48      0.28  119.4624
# 24 2023-01-25         1037         192         5  61.77      0.26  228.5490
# 25 2023-01-26         1475         131         9  53.86      0.08  445.9608
# 26 2023-01-27         1893         144         2  33.71      0.02   66.0716
# 27 2023-01-28         1219         123         1  70.80      0.11   63.0120
# 28 2023-01-29         1786         118         5  33.05      0.24  125.5900
# 29 2023-01-30         1536         166         4  71.53      0.09  260.3692
# 30 2023-01-31         1854         127         7  20.07      0.22  109.5822
# 31 2023-02-01         1712         126         9  67.82      0.25  457.7850
# 32 2023-02-02         1584         122         8  44.95      0.03  348.8120
# 33 2023-02-03         1881         141         6  56.98      0.25  256.4100
# 34 2023-02-04         1504         175         4  80.57      0.06  302.9432
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5  North           Cash       True              1            50
# 1          7  South         Online       True              1            52
# 2          7   East    Credit Card      False              6            59
# 3          2  North    Credit Card       True              1            47
# 4          6  South         Online      False              3            34
# 5          2   West    Credit Card       True              3            19
# 6          4  North    Credit Card      False              6            34
# 7          5  North    Credit Card       True              5            23
# 8          1   East    Credit Card       True              3            57
# 9          4   West         Online       True              6            59
# 10         4   West    Credit Card      False              4            26
# 11         5   West         Online       True              5            20
# 12         9  South           Cash       True              2            56
# 13         7  North           Cash       True              3            37
# 14         3  South           Cash       True              5            23
# 15         4   East           Cash       True              4            46
# 16         7   East    Credit Card       True              1            27
# 17         2  South         Online      False              2            58
# 18         9  South           Cash      False              1            45
# 19         3   West    Credit Card       True              1            61
# 20         3  South           Cash       True              6            66
# 21         9   East         Online       True              5            61
# 22         4  North           Cash      False              2            29
# 23         5   East         Online       True              6            51
# 24         4   East    Credit Card       True              4            28
# 25         7  South           Cash      False              4            57
# 26         4   East         Online      False              1            36
# 27         7  South    Credit Card      False              1            44
# 28         3   West    Credit Card      False              1            28
# 29         6   West         Online      False              5            19
# 30         2   West         Online      False              6            48
# 31         3  North           Cash      False              4            57
# 32         4   West         Online      False              2            38
# 33         3  North         Online       True              3            54
# 34         2   East    Credit Card       True              6            66
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male      Electronics     3.5  Not Returned  Negative          12.44
# 1    Other             Food     3.8  Not Returned  Positive          19.18
# 2   Female            Books     3.0      Returned  Negative          16.56
# 3    Other      Electronics     4.6      Returned  Positive          11.08
# 4   Female             Food     4.4      Returned   Neutral          13.06
# 5    Other      Electronics     3.4  Not Returned   Neutral           7.87
# 6     Male             Food     1.9  Not Returned  Positive           7.00
# 7     Male             Food     3.8      Returned  Positive          19.38
# 8    Other         Clothing     3.2  Not Returned  Positive            NaN
# 9    Other             Food     3.3  Not Returned  Positive            NaN
# 10  Female         Clothing     1.0  Not Returned  Positive          18.07
# 11   Other            Books     4.6      Returned   Neutral          17.58
# 12    Male            Books     1.6      Returned  Positive          11.90
# 13    Male         Clothing     4.8      Returned  Negative            NaN
# 14   Other            Books     1.5      Returned  Negative            NaN
# 15    Male         Clothing     2.0  Not Returned   Neutral           5.46
# 16    Male         Clothing     3.9      Returned  Negative           6.24
# 17  Female         Clothing     1.7  Not Returned  Negative            NaN
# 18   Other      Electronics     4.6      Returned  Positive          11.55
# 19   Other         Clothing     3.8  Not Returned   Neutral           8.45
# 20    Male         Clothing     2.5      Returned  Negative          19.88
# 21    Male      Electronics     3.2  Not Returned   Neutral          15.72
# 22    Male            Books     3.9  Not Returned  Negative          15.00
# 23   Other      Electronics     1.9      Returned   Neutral          12.41
# 24   Other             Food     4.1      Returned  Negative            NaN
# 25  Female            Books     4.5      Returned   Neutral            NaN
# 26   Other            Books     4.8      Returned  Positive          19.24
# 27    Male      Electronics     1.1  Not Returned  Negative          12.19
# 28   Other         Clothing     3.2  Not Returned  Negative          15.44
# 29   Other      Electronics     3.2      Returned  Negative          16.80
# 30    Male            Books     3.4  Not Returned   Neutral          16.93
# 31   Other         Clothing     1.5      Returned  Negative          13.59
# 32  Female             Food     3.9  Not Returned   Neutral           7.39
# 33  Female      Electronics     4.6  Not Returned  Negative          12.00
# 34   Other            Books     3.3      Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0       SAVE10              4.6
# 1     FREESHIP              2.3
# 2       SAVE10              3.5
# 3     WELCOME5              3.1
# 4       SAVE10              NaN
# 5     WELCOME5              2.6
# 6       SAVE10              2.1
# 7       SAVE10              3.2
# 8     WELCOME5              4.5
# 9          nan              1.0
# 10      SAVE10              2.0
# 11    WELCOME5              3.6
# 12    FREESHIP              4.7
# 13         nan              4.5
# 14         nan              NaN
# 15      SAVE10              NaN
# 16         nan              2.7
# 17      SAVE10              1.1
# 18         nan              3.5
# 19         nan              1.1
# 20    WELCOME5              3.5
# 21         nan              NaN
# 22    FREESHIP              3.2
# 23         nan              NaN
# 24         nan              NaN
# 25    FREESHIP              2.8
# 26         nan              NaN
# 27    WELCOME5              2.7
# 28         nan              1.7
# 29         nan              4.4
# 30         nan              NaN
# 31         nan              4.6
# 32    WELCOME5              3.8
# 33    WELCOME5              2.2
# 34    WELCOME5              4.8

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 02:**
# </div>

# %%
# 2. Ensuring Consistent Data Types of All Columns
# Write a Pandas program to check and ensure that the data types of all columns are consistent.

# Check data types
data_types = df.dtypes
data_types
# Out:
# date                datetime64[ns]
# customer_id                  int64
# product_id                   int64
# quantity                     int64
# price                      float64
# discount                   float64
# revenue                    float64
# store_id                     int64
# region                      object
# payment_method              object
# is_member                     bool
# delivery_days                int64
# customer_age                 int64
# gender                      object
# product_category            object
# rating                     float64
# return_status               object
# feedback                    object
# shipping_cost              float64
# coupon_code                 object
# delivery_rating            float64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning">
#
# **3. Validating the Data Type of a Specific Column**
#
# **Write a Pandas program to validate the data type of a specific column in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1196         174         2  49.31      0.01   97.6338
# 1  2023-01-02         1768         192         6  26.57      0.16  133.9128
# 2  2023-01-03         1254         129         2  37.96      0.23   58.4584
# 3  2023-01-04         1670         111         6  10.27      0.15   52.3770
# 4  2023-01-05         1514         193         5  65.88      0.06  309.6360
# 5  2023-01-06         1717         173         2  84.71      0.12  149.0896
# 6  2023-01-07         1903         151         6  50.94      0.28  220.0608
# 7  2023-01-08         1167         189         4  89.96      0.05  341.8480
# 8  2023-01-09         1080         138         4  48.46      0.27  141.5032
# 9  2023-01-10         1543         152         8  32.46      0.17  215.5344
# 10 2023-01-11         1736         136         9  99.24      0.28  643.0752
# 11 2023-01-12         1040         120         2  25.08      0.11   44.6424
# 12 2023-01-13         1816         169         4  18.46      0.23   56.8568
# 13 2023-01-14         1119         126         6  97.53      0.22  456.4404
# 14 2023-01-15         1239         123         9  56.18      0.09  460.1142
# 15 2023-01-16         1781         196         9  22.11      0.05  189.0405
# 16 2023-01-17         1421         148         9  53.92      0.08  446.4576
# 17 2023-01-18         1426         123         4  38.42      0.15  130.6280
# 18 2023-01-19         1478         193         2  92.95      0.10  167.3100
# 19 2023-01-20         1268         158         6  66.83      0.03  388.9506
# 20 2023-01-21         1413         132         9  33.29      0.27  218.7153
# 21 2023-01-22         1110         198         7  53.48      0.09  340.6676
# 22 2023-01-23         1231         102         2  85.63      0.03  166.1222
# 23 2023-01-24         1794         194         6  40.49      0.16  204.0696
# 24 2023-01-25         1428         195         7  12.41      0.09   79.0517
# 25 2023-01-26         1734         122         3  62.15      0.10  167.8050
# 26 2023-01-27         1005         169         8  70.51      0.23  434.3416
# 27 2023-01-28         1012         143         9  37.69      0.25  254.4075
# 28 2023-01-29         1633         158         5  71.79      0.04  344.5920
# 29 2023-01-30         1863         185         3  24.86      0.07   69.3594
# 30 2023-01-31         1606         194         1  58.54      0.10   52.6860
# 31 2023-02-01         1457         171         8  40.01      0.23  246.4616
# 32 2023-02-02         1348         141         5  28.96      0.20  115.8400
# 33 2023-02-03         1347         131         8  32.32      0.10  232.7040
# 34 2023-02-04         1218         186         5  79.54      0.24  302.2520
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          7   West         Online       True              6            45
# 1          5  North           Cash       True              5            69
# 2          2   West         Online       True              5            39
# 3          6  North         Online      False              4            30
# 4          4   East    Credit Card       True              1            54
# 5          1   East    Credit Card      False              6            46
# 6          1   East           Cash       True              5            59
# 7          3   West           Cash      False              2            24
# 8          1  North    Credit Card      False              5            66
# 9          8  North    Credit Card       True              3            18
# 10         5  South         Online       True              4            26
# 11         9   East           Cash      False              5            53
# 12         4  North         Online       True              5            34
# 13         1   East         Online       True              6            57
# 14         6  South         Online       True              1            18
# 15         7   West         Online       True              2            46
# 16         7   East         Online      False              3            28
# 17         1  North           Cash      False              4            25
# 18         1  North         Online      False              3            62
# 19         2   West    Credit Card      False              3            21
# 20         3   West         Online      False              3            18
# 21         5  North         Online      False              4            22
# 22         3  North    Credit Card      False              3            21
# 23         6  North           Cash       True              6            20
# 24         7  South    Credit Card      False              6            48
# 25         3   East    Credit Card       True              6            35
# 26         8  South           Cash       True              5            41
# 27         6  South           Cash       True              4            45
# 28         7  South         Online       True              6            36
# 29         3  South    Credit Card       True              3            28
# 30         8  South           Cash      False              3            58
# 31         9   East           Cash       True              3            22
# 32         4   East           Cash      False              1            31
# 33         9   East    Credit Card       True              3            18
# 34         2   West         Online       True              1            48
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male      Electronics     1.6  Not Returned   Neutral          10.01
# 1    Other         Clothing     4.5  Not Returned  Negative           8.91
# 2     Male             Food     3.2  Not Returned  Negative          11.88
# 3    Other      Electronics     4.5  Not Returned  Positive          13.87
# 4     Male             Food     2.8      Returned  Negative          15.67
# 5   Female         Clothing     1.6  Not Returned   Neutral           6.76
# 6     Male            Books     2.1      Returned  Positive          18.12
# 7   Female         Clothing     1.3      Returned   Neutral           5.08
# 8    Other         Clothing     2.1      Returned   Neutral           5.29
# 9     Male      Electronics     4.3      Returned   Neutral          19.42
# 10   Other      Electronics     3.4      Returned  Negative            NaN
# 11   Other         Clothing     4.1      Returned  Negative          15.41
# 12   Other            Books     1.1  Not Returned   Neutral          11.75
# 13    Male            Books     2.7  Not Returned   Neutral          17.40
# 14   Other             Food     4.2      Returned  Positive          12.86
# 15   Other             Food     2.0      Returned  Positive          14.03
# 16  Female            Books     1.9      Returned   Neutral          19.53
# 17  Female      Electronics     5.0  Not Returned   Neutral          15.52
# 18   Other            Books     3.7  Not Returned  Positive          16.60
# 19  Female         Clothing     1.6      Returned   Neutral           9.71
# 20   Other         Clothing     1.2      Returned   Neutral          10.58
# 21  Female            Books     4.1      Returned  Negative          11.87
# 22    Male      Electronics     4.1  Not Returned  Negative          12.59
# 23   Other            Books     2.5      Returned   Neutral           5.08
# 24  Female      Electronics     1.1  Not Returned   Neutral          19.72
# 25    Male             Food     3.3      Returned  Negative          12.57
# 26   Other            Books     2.4  Not Returned  Positive          11.82
# 27   Other         Clothing     2.5      Returned  Negative           9.30
# 28   Other         Clothing     3.0  Not Returned  Negative            NaN
# 29  Female            Books     2.9  Not Returned  Negative          13.89
# 30   Other            Books     4.8  Not Returned  Negative          19.37
# 31  Female             Food     3.4      Returned   Neutral          13.43
# 32  Female         Clothing     3.4      Returned  Positive           9.34
# 33    Male         Clothing     4.1      Returned   Neutral           7.09
# 34    Male         Clothing     1.5  Not Returned   Neutral          12.27
#
#    coupon_code  delivery_rating
# 0     FREESHIP              3.4
# 1       SAVE10              1.5
# 2     FREESHIP              2.3
# 3          nan              2.5
# 4     WELCOME5              NaN
# 5     FREESHIP              1.4
# 6       SAVE10              NaN
# 7          nan              4.2
# 8     WELCOME5              2.6
# 9       SAVE10              NaN
# 10      SAVE10              1.6
# 11      SAVE10              3.4
# 12    FREESHIP              4.7
# 13    WELCOME5              3.9
# 14         nan              4.9
# 15         nan              3.5
# 16    WELCOME5              3.0
# 17    WELCOME5              2.7
# 18    WELCOME5              2.1
# 19    FREESHIP              NaN
# 20      SAVE10              2.6
# 21         nan              NaN
# 22      SAVE10              NaN
# 23         nan              NaN
# 24    WELCOME5              3.6
# 25    FREESHIP              4.5
# 26    WELCOME5              3.0
# 27    WELCOME5              2.8
# 28      SAVE10              NaN
# 29         nan              2.4
# 30    FREESHIP              2.4
# 31    FREESHIP              4.2
# 32         nan              3.2
# 33      SAVE10              4.8
# 34         nan              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 03:**
# </div>

# %%
# 3. Validating the Data Type of a Specific Column
# Write a Pandas program to validate the data type of a specific column in a DataFrame.

# Check if 'price' column is of type float
is_of_type = 'float64'
is_price_float = df['price'].dtype == is_of_type
is_price_float

# Validate the data type of 'price' column
if is_price_float:
    print("The 'price' column is of type {}.".format(df['price'].dtype))
else:
    print("The 'price' column is not of type {}, it is {}.".format(is_of_type, df['price'].dtype))
# Out:
# The 'price' column is of type float64.

# %% [markdown]
# <div class="alert alert-warning">
#
# **4. Checking Duplicate Rows in a DataFrame**
#
# **Write a Pandas program to check duplicate rows in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1368         158         7  10.21      0.08   65.7524
# 1  2023-01-02         1046         117         4  21.94      0.29   62.3096
# 2  2023-01-03         1905         161         8  49.98      0.24  303.8784
# 3  2023-01-04         1084         163         4  17.18      0.07   63.9096
# 4  2023-01-05         1565         192         3  26.79      0.03   77.9589
# 5  2023-01-06         1374         148         6  51.94      0.10  280.4760
# 6  2023-01-07         1542         185         8  98.03      0.01  776.3976
# 7  2023-01-08         1515         140         5  69.97      0.26  258.8890
# 8  2023-01-09         1786         181         5  20.36      0.09   92.6380
# 9  2023-01-10         1941         134         1  18.26      0.29   12.9646
# 10 2023-01-11         1932         141         7  25.71      0.29  127.7787
# 11 2023-01-12         1569         141         2  25.23      0.02   49.4508
# 12 2023-01-13         1598         181         7  72.79      0.01  504.4347
# 13 2023-01-14         1717         136         4  84.48      0.29  239.9232
# 14 2023-01-15         1312         151         3  60.12      0.24  137.0736
# 15 2023-01-16         1288         161         6  14.56      0.14   75.1296
# 16 2023-01-17         1619         112         2  79.53      0.14  136.7916
# 17 2023-01-18         1372         106         8  89.59      0.17  594.8776
# 18 2023-01-19         1369         153         3  19.80      0.17   49.3020
# 19 2023-01-20         1036         141         2  57.66      0.06  108.4008
# 20 2023-01-21         1634         115         3  13.89      0.01   41.2533
# 21 2023-01-22         1239         177         9  58.41      0.24  399.5244
# 22 2023-01-23         1601         172         6  52.02      0.01  308.9988
# 23 2023-01-24         1085         113         8  12.12      0.06   91.1424
# 24 2023-01-25         1285         123         9  70.95      0.17  529.9965
# 25 2023-01-26         1466         124         5  66.03      0.14  283.9290
# 26 2023-01-27         1408         154         5  72.32      0.28  260.3520
# 27 2023-01-28         1412         139         2  30.19      0.09   54.9458
# 28 2023-01-29         1795         123         9  10.73      0.24   73.3932
# 29 2023-01-30         1499         127         5  88.00      0.27  321.2000
# 30 2023-01-31         1144         144         2  60.78      0.28   87.5232
# 31 2023-02-01         1945         169         8  87.64      0.09  638.0192
# 32 2023-02-02         1749         134         2  77.74      0.29  110.3908
# 33 2023-02-03         1574         128         7  98.70      0.24  525.0840
# 34 2023-02-04         1128         159         5  42.77      0.01  211.7115
# 35 2023-01-27         1408         154         5  72.32      0.28  260.3520
# 36 2023-01-14         1717         136         4  84.48      0.29  239.9232
# 37 2023-01-25         1285         123         9  70.95      0.17  529.9965
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          4   West         Online      False              4            34
# 1          8  North    Credit Card       True              3            33
# 2          8  North           Cash       True              1            30
# 3          1   West         Online      False              4            21
# 4          6   West           Cash       True              5            49
# 5          5  North         Online       True              6            27
# 6          2   West           Cash       True              6            44
# 7          6  South           Cash      False              3            48
# 8          7  North           Cash      False              6            28
# 9          2   East           Cash      False              6            32
# 10         2   West    Credit Card      False              2            27
# 11         6  South           Cash      False              6            67
# 12         5  South    Credit Card      False              5            57
# 13         5   East    Credit Card       True              6            57
# 14         5   West           Cash      False              5            68
# 15         9  North           Cash       True              4            62
# 16         5   East         Online       True              4            35
# 17         7   West         Online       True              3            45
# 18         5   East    Credit Card      False              4            49
# 19         4   West           Cash      False              2            52
# 20         7   East           Cash      False              3            42
# 21         7  South           Cash      False              5            46
# 22         3  North           Cash       True              2            33
# 23         8  South    Credit Card      False              3            61
# 24         1  North           Cash      False              5            68
# 25         2   West           Cash      False              5            21
# 26         2   West    Credit Card      False              5            33
# 27         7  North    Credit Card       True              1            62
# 28         7  South    Credit Card       True              5            26
# 29         7   West    Credit Card      False              4            30
# 30         5  North         Online       True              2            66
# 31         6   East           Cash       True              3            49
# 32         2  North           Cash       True              5            31
# 33         5  South           Cash      False              2            18
# 34         2  North         Online       True              4            52
# 35         2   West    Credit Card      False              5            33
# 36         5   East    Credit Card       True              6            57
# 37         1  North           Cash      False              5            68
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female             Food     3.6      Returned  Positive          12.74
# 1     Male      Electronics     1.7  Not Returned  Positive            NaN
# 2   Female      Electronics     1.2      Returned  Negative           8.19
# 3     Male            Books     4.9      Returned  Negative          17.50
# 4     Male         Clothing     3.1      Returned  Negative          11.81
# 5     Male      Electronics     2.2      Returned   Neutral           8.84
# 6     Male             Food     1.7      Returned  Negative           6.12
# 7     Male             Food     4.1      Returned  Positive          18.52
# 8     Male         Clothing     3.3      Returned  Negative            NaN
# 9   Female      Electronics     3.6      Returned  Positive          16.17
# 10    Male      Electronics     3.2      Returned  Positive          13.64
# 11   Other         Clothing     3.9      Returned  Positive           7.65
# 12   Other            Books     3.3      Returned   Neutral            NaN
# 13  Female      Electronics     3.4  Not Returned  Positive           7.48
# 14    Male      Electronics     3.0  Not Returned   Neutral          16.18
# 15    Male         Clothing     4.8  Not Returned   Neutral          10.53
# 16  Female            Books     1.3  Not Returned  Negative          18.48
# 17    Male            Books     3.5      Returned   Neutral            NaN
# 18    Male            Books     1.2  Not Returned   Neutral          15.23
# 19    Male            Books     4.5      Returned   Neutral           5.67
# 20    Male         Clothing     3.7  Not Returned   Neutral          16.78
# 21  Female            Books     3.6      Returned  Positive          13.58
# 22  Female      Electronics     1.5  Not Returned  Positive          10.30
# 23    Male            Books     3.8      Returned   Neutral          13.29
# 24  Female         Clothing     4.7  Not Returned  Positive           7.30
# 25   Other            Books     2.3  Not Returned  Positive           5.83
# 26   Other         Clothing     4.2  Not Returned  Negative          16.28
# 27    Male             Food     3.2  Not Returned  Negative           6.88
# 28    Male      Electronics     4.2  Not Returned  Positive          14.19
# 29   Other             Food     4.9      Returned  Negative           7.20
# 30   Other      Electronics     3.3  Not Returned   Neutral            NaN
# 31    Male            Books     3.7  Not Returned   Neutral          17.65
# 32   Other      Electronics     1.0      Returned  Negative          16.82
# 33    Male         Clothing     4.0      Returned  Negative            NaN
# 34   Other             Food     2.2  Not Returned   Neutral            NaN
# 35   Other         Clothing     4.2  Not Returned  Negative          16.28
# 36  Female      Electronics     3.4  Not Returned  Positive           7.48
# 37  Female         Clothing     4.7  Not Returned  Positive           7.30
#
#    coupon_code  delivery_rating
# 0     WELCOME5              4.0
# 1          nan              3.3
# 2          nan              1.3
# 3     FREESHIP              NaN
# 4          nan              4.8
# 5     WELCOME5              3.1
# 6          nan              1.0
# 7       SAVE10              2.9
# 8     FREESHIP              3.6
# 9       SAVE10              3.6
# 10    WELCOME5              1.9
# 11         nan              3.2
# 12         nan              NaN
# 13    WELCOME5              4.5
# 14         nan              1.5
# 15    WELCOME5              3.6
# 16    WELCOME5              NaN
# 17      SAVE10              NaN
# 18         nan              NaN
# 19         nan              1.1
# 20         nan              5.0
# 21    FREESHIP              2.3
# 22         nan              3.0
# 23      SAVE10              1.9
# 24         nan              NaN
# 25    WELCOME5              2.4
# 26         nan              4.3
# 27    WELCOME5              3.9
# 28         nan              2.9
# 29    FREESHIP              4.7
# 30      SAVE10              NaN
# 31         nan              1.5
# 32    WELCOME5              2.1
# 33    FREESHIP              NaN
# 34         nan              2.8
# 35         nan              4.3
# 36    WELCOME5              4.5
# 37         nan              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
# 4. Checking Duplicate Rows in a DataFrame
# Write a Pandas program to check duplicate rows in a DataFrame.

# Check for duplicate rows
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 35 2023-01-27         1408         154         5  72.32      0.28  260.3520
# 36 2023-01-14         1717         136         4  84.48      0.29  239.9232
# 37 2023-01-25         1285         123         9  70.95      0.17  529.9965
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 35         2   West    Credit Card      False              5            33
# 36         5   East    Credit Card       True              6            57
# 37         1  North           Cash      False              5            68
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 35   Other         Clothing     4.2  Not Returned  Negative          16.28
# 36  Female      Electronics     3.4  Not Returned  Positive           7.48
# 37  Female         Clothing     4.7  Not Returned  Positive           7.30
#
#    coupon_code  delivery_rating
# 35         nan              4.3
# 36    WELCOME5              4.5
# 37         nan              NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **5. Removing Duplicate Rows from a DataFrame**
#
# **Write a Pandas program to remove duplicate rows from a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1066         154         2  69.13      0.09  125.8166
# 1  2023-01-02         1222         108         1  30.21      0.22   23.5638
# 2  2023-01-03         1048         163         2  57.29      0.04  109.9968
# 3  2023-01-04         1640         139         1  15.46      0.09   14.0686
# 4  2023-01-05         1780         188         1  20.34      0.21   16.0686
# 5  2023-01-06         1320         119         6  86.51      0.25  389.2950
# 6  2023-01-07         1098         195         1  40.64      0.23   31.2928
# 7  2023-01-08         1711         147         7  61.48      0.09  391.6276
# 8  2023-01-09         1014         161         2  91.21      0.18  149.5844
# 9  2023-01-10         1963         171         2  66.18      0.08  121.7712
# 10 2023-01-11         1394         169         1  69.41      0.16   58.3044
# 11 2023-01-12         1984         100         4  54.72      0.11  194.8032
# 12 2023-01-13         1623         155         6  14.73      0.22   68.9364
# 13 2023-01-14         1254         155         7  74.24      0.22  405.3504
# 14 2023-01-15         1806         125         3  95.72      0.10  258.4440
# 15 2023-01-16         1049         175         4  94.62      0.22  295.2144
# 16 2023-01-17         1774         111         8  44.53      0.29  252.9304
# 17 2023-01-18         1467         133         7  32.05      0.24  170.5060
# 18 2023-01-19         1535         137         3  52.01      0.07  145.1079
# 19 2023-01-20         1486         139         3  92.66      0.25  208.4850
# 20 2023-01-21         1417         112         7  21.75      0.28  109.6200
# 21 2023-01-22         1692         129         1  86.60      0.05   82.2700
# 22 2023-01-23         1223         162         1  87.92      0.03   85.2824
# 23 2023-01-24         1502         139         8  89.28      0.07  664.2432
# 24 2023-01-25         1407         194         1  50.09      0.10   45.0810
# 25 2023-01-26         1627         145         1  46.47      0.28   33.4584
# 26 2023-01-27         1273         187         7  44.78      0.08  288.3832
# 27 2023-01-28         1209         104         8  82.93      0.06  623.6336
# 28 2023-01-29         1094         182         2  22.21      0.28   31.9824
# 29 2023-01-30         1773         150         9  14.00      0.22   98.2800
# 30 2023-01-31         1694         197         3  77.25      0.29  164.5425
# 31 2023-02-01         1419         186         9  67.99      0.16  514.0044
# 32 2023-02-02         1453         184         1  75.71      0.12   66.6248
# 33 2023-02-03         1757         133         7  55.59      0.14  334.6518
# 34 2023-02-04         1799         141         4  22.06      0.25   66.1800
# 35 2023-01-27         1273         187         7  44.78      0.08  288.3832
# 36 2023-01-14         1254         155         7  74.24      0.22  405.3504
# 37 2023-01-25         1407         194         1  50.09      0.10   45.0810
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          8   East           Cash      False              4            42
# 1          5  South         Online      False              2            40
# 2          5  South    Credit Card      False              1            51
# 3          3  North           Cash      False              5            40
# 4          2   West         Online       True              3            24
# 5          3   East    Credit Card       True              3            45
# 6          1  North    Credit Card       True              6            69
# 7          9   West    Credit Card      False              1            59
# 8          6   West           Cash      False              1            35
# 9          1  North         Online       True              3            29
# 10         7  South         Online       True              6            53
# 11         3  South           Cash      False              6            65
# 12         4  South         Online      False              6            60
# 13         8   East    Credit Card       True              5            53
# 14         3  South    Credit Card      False              2            27
# 15         7  North           Cash      False              2            50
# 16         3  South    Credit Card       True              5            19
# 17         5   West           Cash       True              4            23
# 18         6  South    Credit Card       True              3            61
# 19         2   West         Online       True              1            30
# 20         6  South           Cash      False              2            18
# 21         2  South           Cash       True              2            59
# 22         3  South         Online       True              2            59
# 23         8   West           Cash      False              2            51
# 24         6   West    Credit Card       True              3            54
# 25         6  South    Credit Card      False              2            54
# 26         7   West         Online      False              2            57
# 27         6   East           Cash       True              1            66
# 28         1   West           Cash      False              3            20
# 29         1   East         Online       True              5            41
# 30         7   West         Online       True              4            18
# 31         3  North           Cash      False              5            42
# 32         6   West    Credit Card       True              6            65
# 33         6  South    Credit Card       True              1            30
# 34         6  South    Credit Card      False              5            19
# 35         7   West         Online      False              2            57
# 36         8   East    Credit Card       True              5            53
# 37         6   West    Credit Card       True              3            54
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     2.0      Returned  Negative          10.94
# 1   Female         Clothing     4.9      Returned   Neutral          14.41
# 2     Male             Food     1.9  Not Returned  Negative            NaN
# 3     Male             Food     4.5  Not Returned  Positive          15.68
# 4   Female         Clothing     4.7  Not Returned  Positive            NaN
# 5   Female            Books     2.8      Returned  Positive            NaN
# 6    Other         Clothing     1.1  Not Returned  Negative           5.56
# 7     Male            Books     4.6  Not Returned  Negative           6.46
# 8   Female      Electronics     3.1      Returned   Neutral          13.17
# 9    Other      Electronics     2.7  Not Returned  Negative           5.36
# 10  Female             Food     4.2      Returned   Neutral          15.86
# 11  Female      Electronics     1.2  Not Returned  Negative          15.69
# 12  Female      Electronics     1.3      Returned  Positive          14.37
# 13   Other         Clothing     3.8  Not Returned  Negative          19.55
# 14   Other         Clothing     4.3      Returned   Neutral          14.85
# 15    Male            Books     4.8      Returned  Negative           9.00
# 16   Other            Books     3.1      Returned   Neutral          13.94
# 17  Female         Clothing     1.7  Not Returned  Positive          14.77
# 18  Female            Books     3.8      Returned   Neutral          14.60
# 19  Female             Food     3.4      Returned  Positive            NaN
# 20    Male            Books     4.4      Returned   Neutral          16.55
# 21    Male             Food     4.8  Not Returned  Negative          11.91
# 22  Female            Books     2.0      Returned   Neutral          12.17
# 23    Male            Books     4.3  Not Returned   Neutral           7.20
# 24    Male         Clothing     1.8      Returned  Negative            NaN
# 25    Male            Books     4.4  Not Returned  Negative            NaN
# 26    Male             Food     5.0      Returned  Negative            NaN
# 27    Male            Books     1.8  Not Returned  Positive            NaN
# 28   Other             Food     4.6      Returned   Neutral            NaN
# 29  Female             Food     2.3      Returned  Negative          14.72
# 30  Female             Food     4.8      Returned  Negative          17.72
# 31    Male            Books     4.2      Returned  Negative          19.67
# 32    Male         Clothing     3.2  Not Returned  Positive           9.55
# 33   Other            Books     3.3  Not Returned  Negative          10.50
# 34   Other            Books     3.4      Returned  Negative            NaN
# 35    Male             Food     5.0      Returned  Negative            NaN
# 36   Other         Clothing     3.8  Not Returned  Negative          19.55
# 37    Male         Clothing     1.8      Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0     WELCOME5              NaN
# 1          nan              2.4
# 2       SAVE10              4.4
# 3          nan              1.5
# 4     FREESHIP              3.2
# 5          nan              3.4
# 6     WELCOME5              2.8
# 7          nan              NaN
# 8          nan              5.0
# 9     FREESHIP              4.7
# 10         nan              NaN
# 11    WELCOME5              2.9
# 12      SAVE10              2.6
# 13    WELCOME5              2.4
# 14    WELCOME5              4.9
# 15    FREESHIP              4.9
# 16         nan              2.9
# 17         nan              NaN
# 18         nan              4.6
# 19      SAVE10              2.1
# 20    WELCOME5              2.5
# 21    WELCOME5              4.0
# 22         nan              2.5
# 23         nan              1.4
# 24    FREESHIP              4.3
# 25    FREESHIP              1.9
# 26      SAVE10              1.5
# 27         nan              NaN
# 28    FREESHIP              NaN
# 29         nan              1.5
# 30         nan              2.6
# 31      SAVE10              4.3
# 32      SAVE10              2.8
# 33      SAVE10              NaN
# 34    WELCOME5              3.5
# 35      SAVE10              1.5
# 36    WELCOME5              2.4
# 37    FREESHIP              4.3

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
# 5. Removing Duplicate Rows from a DataFrame
# Write a Pandas program to remove duplicate rows from a DataFrame.

print("Shape of DataFrame before removing duplicates:\n", df.shape)
# Remove duplicate rows
df = df.drop_duplicates()
print("Shape of DataFrame after removing duplicates:\n", df.shape)
# Out:
# Shape of DataFrame before removing duplicates:
#  (38, 21)
# Shape of DataFrame after removing duplicates:
#  (35, 21)

# %% [markdown]
# <div class="alert alert-warning">
#
# **6. Validating Data Based on Custom Conditions**
#
# **Write a Pandas program to validate data based on custom conditions.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1849         122         9  16.95      0.12  134.2440
# 1  2023-01-02         1155         157         2  31.21      0.01   61.7958
# 2  2023-01-03         1328         196         6  25.20      0.29  107.3520
# 3  2023-01-04         1977         116         7  87.00      0.12  535.9200
# 4  2023-01-05         1644         172         2  40.35      0.03   78.2790
# 5  2023-01-06         1275         184         1  57.29      0.01   56.7171
# 6  2023-01-07         1691         119         5  75.76      0.01  375.0120
# 7  2023-01-08         1748         190         3  32.11      0.09   87.6603
# 8  2023-01-09         1039         163         4  82.94      0.26  245.5024
# 9  2023-01-10         1990         163         1  12.51      0.23    9.6327
# 10 2023-01-11         1965         187         6  86.83      0.26  385.5252
# 11 2023-01-12         1781         143         5  83.31      0.18  341.5710
# 12 2023-01-13         1607         134         3  79.70      0.01  236.7090
# 13 2023-01-14         1490         159         8  85.92      0.17  570.5088
# 14 2023-01-15         1428         138         4  17.85      0.25   53.5500
# 15 2023-01-16         1812         130         9  76.39      0.23  529.3827
# 16 2023-01-17         1864         162         2  45.74      0.26   67.6952
# 17 2023-01-18         1911         188         2  27.33      0.09   49.7406
# 18 2023-01-19         1952         182         1  38.96      0.18   31.9472
# 19 2023-01-20         1147         174         9  20.66      0.24  141.3144
# 20 2023-01-21         1289         104         6  81.39      0.28  351.6048
# 21 2023-01-22         1630         193         9  62.75      0.09  513.9225
# 22 2023-01-23         1500         199         2  93.74      0.17  155.6084
# 23 2023-01-24         1335         155         8  14.70      0.05  111.7200
# 24 2023-01-25         1706         112         9  85.27      0.20  613.9440
# 25 2023-01-26         1788         192         7  65.87      0.22  359.6502
# 26 2023-01-27         1051         160         9  40.21      0.26  267.7986
# 27 2023-01-28         1334         148         6  93.37      0.07  521.0046
# 28 2023-01-29         1615         183         6  24.40      0.02  143.4720
# 29 2023-01-30         1890         185         6  44.42      0.05  253.1940
# 30 2023-01-31         1734         137         7  59.86      0.06  393.8788
# 31 2023-02-01         1478         147         5  34.67      0.09  157.7485
# 32 2023-02-02         1129         144         3  49.11      0.14  126.7038
# 33 2023-02-03         1528         112         2  17.45      0.07   32.4570
# 34 2023-02-04         1278         165         7  30.68      0.15  182.5460
# 35 2023-01-27         1051         160         9  40.21      0.26  267.7986
# 36 2023-01-14         1490         159         8  85.92      0.17  570.5088
# 37 2023-01-25         1706         112         9  85.27      0.20  613.9440
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          2  North    Credit Card      False              6            47
# 1          2   West         Online      False              4            21
# 2          6   West           Cash       True              1            61
# 3          8  South    Credit Card       True              1            25
# 4          2  South    Credit Card      False              6            58
# 5          7  South    Credit Card       True              5            31
# 6          9  South         Online       True              5            44
# 7          3  South           Cash       True              5            26
# 8          1   East    Credit Card      False              1            31
# 9          1   East           Cash      False              3            66
# 10         2  North    Credit Card      False              3            60
# 11         1  North           Cash      False              1            44
# 12         9  North         Online       True              4            64
# 13         2   West         Online       True              2            59
# 14         2  South    Credit Card       True              5            46
# 15         3   West         Online       True              5            69
# 16         4  South         Online      False              1            36
# 17         8   West    Credit Card      False              5            34
# 18         4   East    Credit Card      False              5            50
# 19         9  North         Online      False              3            42
# 20         6   West           Cash      False              1            38
# 21         1   East           Cash       True              6            65
# 22         5   West    Credit Card      False              4            38
# 23         4   East         Online      False              3            59
# 24         5   West         Online       True              6            49
# 25         1  North           Cash       True              3            28
# 26         5   West           Cash       True              1            52
# 27         2   West    Credit Card      False              5            21
# 28         8  North           Cash       True              6            51
# 29         4  North         Online      False              4            18
# 30         9  South           Cash       True              1            56
# 31         8  North    Credit Card      False              2            68
# 32         9  North         Online       True              1            59
# 33         4  South    Credit Card       True              1            44
# 34         9  North    Credit Card      False              6            18
# 35         5   West           Cash       True              1            52
# 36         2   West         Online       True              2            59
# 37         5   West         Online       True              6            49
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female             Food     1.0      Returned   Neutral           7.04
# 1   Female         Clothing     3.0  Not Returned  Negative          10.37
# 2     Male      Electronics     3.3  Not Returned   Neutral          11.40
# 3   Female            Books     3.3      Returned  Positive          12.40
# 4   Female             Food     3.3  Not Returned  Positive            NaN
# 5    Other            Books     1.9  Not Returned  Negative          16.52
# 6     Male             Food     4.7      Returned   Neutral          17.48
# 7     Male         Clothing     1.1  Not Returned  Positive          16.45
# 8   Female         Clothing     3.5      Returned  Negative           5.49
# 9   Female      Electronics     4.2  Not Returned  Positive          12.97
# 10    Male         Clothing     4.7  Not Returned   Neutral          11.96
# 11   Other            Books     3.7      Returned  Negative          14.85
# 12    Male         Clothing     3.4      Returned   Neutral           6.14
# 13   Other             Food     4.5  Not Returned  Positive            NaN
# 14    Male             Food     4.7      Returned   Neutral          17.13
# 15   Other            Books     1.5      Returned  Positive          11.67
# 16   Other             Food     3.5      Returned  Negative          14.92
# 17   Other            Books     3.3  Not Returned  Negative          11.99
# 18   Other            Books     3.5      Returned  Negative          13.96
# 19   Other         Clothing     1.4  Not Returned  Negative          10.04
# 20    Male         Clothing     1.5      Returned  Positive           9.54
# 21   Other             Food     3.5  Not Returned  Negative          12.87
# 22    Male            Books     3.6  Not Returned   Neutral          12.61
# 23   Other            Books     4.0      Returned  Positive            NaN
# 24    Male             Food     1.1      Returned   Neutral           6.23
# 25  Female            Books     3.3      Returned   Neutral          17.37
# 26   Other         Clothing     4.1  Not Returned  Negative            NaN
# 27    Male      Electronics     3.0  Not Returned  Positive          12.78
# 28  Female         Clothing     1.4      Returned  Positive          18.98
# 29   Other      Electronics     2.4      Returned  Positive          17.26
# 30  Female      Electronics     2.6  Not Returned  Positive          13.91
# 31   Other            Books     2.2  Not Returned  Negative           5.92
# 32   Other         Clothing     4.1  Not Returned   Neutral          13.64
# 33   Other            Books     2.5  Not Returned  Positive          15.51
# 34   Other      Electronics     2.8  Not Returned  Negative            NaN
# 35   Other         Clothing     4.1  Not Returned  Negative            NaN
# 36   Other             Food     4.5  Not Returned  Positive            NaN
# 37    Male             Food     1.1      Returned   Neutral           6.23
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0     FREESHIP              1.9
# 1          nan              4.7
# 2          nan              NaN
# 3     FREESHIP              1.5
# 4     WELCOME5              2.9
# 5          nan              2.1
# 6       SAVE10              1.9
# 7          nan              2.4
# 8     WELCOME5              NaN
# 9          nan              4.9
# 10    FREESHIP              4.5
# 11         nan              2.3
# 12    WELCOME5              NaN
# 13         nan              1.8
# 14    FREESHIP              NaN
# 15         nan              1.1
# 16         nan              1.3
# 17    FREESHIP              3.2
# 18    FREESHIP              3.4
# 19         nan              3.1
# 20         nan              NaN
# 21    WELCOME5              2.5
# 22         nan              4.7
# 23      SAVE10              NaN
# 24         nan              1.6
# 25    FREESHIP              NaN
# 26    FREESHIP              3.6
# 27         nan              NaN
# 28      SAVE10              NaN
# 29    FREESHIP              4.7
# 30    WELCOME5              NaN
# 31         nan              2.7
# 32      SAVE10              4.2
# 33    FREESHIP              NaN
# 34    WELCOME5              1.0
# 35    FREESHIP              3.6
# 36         nan              1.8
# 37         nan              1.6
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 06:**
# </div>

# %%
# 6. Validating Data Based on Custom Conditions
# Write a Pandas program to validate data based on custom conditions.

# Check if 'price' is greater than 0
valid_price = df['price'] > 0
if valid_price.all():
    print("All prices are valid.")
else:
    print("Some prices are invalid:")
    display(df[~valid_price])
# Out:
# Some prices are invalid:
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **7. Checking That a Specific Column Contains Only Unique Values**
#
# **Write a Pandas program to check that a specific column contains only unique values.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1348         154         9  24.57      0.20  176.9040
# 1  2023-01-02         1779         100         6  91.91      0.05  523.8870
# 2  2023-01-03         1378         190         3  54.85      0.11  146.4495
# 3  2023-01-04         1327         175         8  16.26      0.11  115.7712
# 4  2023-01-05         1121         164         9  30.36      0.21  215.8596
# 5  2023-01-06         1449         100         8  40.27      0.07  299.6088
# 6  2023-01-07         1115         149         1  93.32      0.19   75.5892
# 7  2023-01-08         1492         136         8  93.73      0.27  547.3832
# 8  2023-01-09         1470         185         3  97.45      0.20  233.8800
# 9  2023-01-10         1854         168         6  84.10      0.08  464.2320
# 10 2023-01-11         1298         107         5  88.67      0.11  394.5815
# 11 2023-01-12         1511         185         7  97.80      0.21  540.8340
# 12 2023-01-13         1746         168         2  58.07      0.29   82.4594
# 13 2023-01-14         1523         148         8  90.79      0.05  690.0040
# 14 2023-01-15         1165         183         2  44.28      0.06   83.2464
# 15 2023-01-16         1320         171         2  15.56      0.05   29.5640
# 16 2023-01-17         1313         185         2  96.55      0.09  175.7210
# 17 2023-01-18         1179         179         2  61.00      0.26   90.2800
# 18 2023-01-19         1843         153         6  28.53      0.09  155.7738
# 19 2023-01-20         1038         134         7  19.68      0.03  133.6272
# 20 2023-01-21         1106         126         2  90.90      0.27  132.7140
# 21 2023-01-22         1446         135         5  44.92      0.14  193.1560
# 22 2023-01-23         1313         100         6  69.35      0.06  391.1340
# 23 2023-01-24         1867         173         7  38.84      0.16  228.3792
# 24 2023-01-25         1408         144         7  61.78      0.11  384.8894
# 25 2023-01-26         1618         131         1  54.03      0.30   37.8210
# 26 2023-01-27         1201         179         9  60.62      0.03  529.2126
# 27 2023-01-28         1659         199         1  20.55      0.13   17.8785
# 28 2023-01-29         1579         189         9  31.80      0.27  208.9260
# 29 2023-01-30         1516         195         8  46.49      0.19  301.2552
# 30 2023-01-31         1569         139         9  43.22      0.02  381.2004
# 31 2023-02-01         1695         128         2  10.03      0.12   17.6528
# 32 2023-02-02         1036         145         8  73.39      0.02  575.3776
# 33 2023-02-03         1319         135         1  17.07      0.19   13.8267
# 34 2023-02-04         1565         156         6  11.53      0.27   50.5014
# 35 2023-01-27         1201         179         9  60.62      0.03  529.2126
# 36 2023-01-14         1523         148         8  90.79      0.05  690.0040
# 37 2023-01-25         1408         144         7  61.78      0.11  384.8894
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          4  South    Credit Card      False              6            64
# 1          5  North           Cash       True              4            26
# 2          4   East    Credit Card       True              3            51
# 3          9  North         Online      False              3            33
# 4          1   West    Credit Card      False              6            20
# 5          5   West         Online      False              4            43
# 6          1  North    Credit Card       True              6            33
# 7          6  South         Online      False              6            51
# 8          9   East    Credit Card      False              2            55
# 9          4   West         Online       True              1            21
# 10         6   East    Credit Card       True              6            18
# 11         7   East    Credit Card      False              3            46
# 12         6   East           Cash       True              5            58
# 13         2  North         Online      False              2            37
# 14         7  North    Credit Card       True              4            19
# 15         7  South    Credit Card      False              6            18
# 16         8   West           Cash       True              1            53
# 17         1  South           Cash      False              6            49
# 18         8  North    Credit Card       True              1            50
# 19         1  South           Cash       True              2            19
# 20         5  South         Online      False              5            53
# 21         3   West         Online      False              6            59
# 22         9   West           Cash      False              5            33
# 23         7  South    Credit Card      False              1            36
# 24         4  North           Cash      False              5            41
# 25         2  South         Online      False              1            52
# 26         5   West    Credit Card       True              2            59
# 27         5   West    Credit Card      False              1            66
# 28         2   West    Credit Card      False              5            31
# 29         3  South         Online       True              1            61
# 30         8   West    Credit Card      False              6            61
# 31         7  South    Credit Card      False              2            25
# 32         5   East         Online       True              1            19
# 33         2  South         Online       True              4            57
# 34         1  South           Cash       True              2            48
# 35         5   West    Credit Card       True              2            59
# 36         2  North         Online      False              2            37
# 37         4  North           Cash      False              5            41
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male         Clothing     2.1  Not Returned  Positive           6.71
# 1    Other         Clothing     2.4      Returned   Neutral          10.52
# 2    Other         Clothing     2.0      Returned   Neutral          11.09
# 3    Other         Clothing     3.5      Returned  Negative            NaN
# 4    Other      Electronics     2.4      Returned   Neutral          16.27
# 5     Male      Electronics     4.2  Not Returned   Neutral          10.07
# 6    Other             Food     1.3      Returned  Positive           9.30
# 7   Female            Books     3.8      Returned  Negative          13.95
# 8    Other             Food     1.8      Returned  Negative          13.79
# 9    Other      Electronics     4.2      Returned   Neutral          13.05
# 10  Female      Electronics     2.2  Not Returned   Neutral          18.40
# 11   Other      Electronics     4.1  Not Returned   Neutral          18.55
# 12    Male             Food     2.2  Not Returned   Neutral            NaN
# 13  Female      Electronics     4.0  Not Returned  Positive          10.78
# 14   Other             Food     4.5  Not Returned   Neutral          11.27
# 15   Other            Books     4.9      Returned  Positive            NaN
# 16   Other             Food     1.3  Not Returned  Positive           9.84
# 17    Male            Books     3.8  Not Returned  Positive            NaN
# 18  Female             Food     4.2  Not Returned  Negative          17.27
# 19    Male      Electronics     4.1  Not Returned  Positive          12.14
# 20  Female             Food     4.9  Not Returned  Positive          10.33
# 21  Female             Food     1.0  Not Returned   Neutral           7.92
# 22    Male             Food     4.4      Returned  Positive          13.91
# 23  Female         Clothing     1.8  Not Returned  Negative           6.36
# 24    Male      Electronics     2.7  Not Returned  Negative            NaN
# 25  Female      Electronics     1.3      Returned  Negative          10.73
# 26   Other      Electronics     1.4      Returned  Negative           8.30
# 27  Female             Food     4.9      Returned  Positive          19.51
# 28  Female             Food     4.0      Returned   Neutral           5.07
# 29   Other         Clothing     4.1      Returned  Positive           9.82
# 30  Female         Clothing     1.3  Not Returned   Neutral          18.88
# 31    Male         Clothing     2.0      Returned  Positive          10.31
# 32    Male      Electronics     2.6      Returned  Positive          16.54
# 33   Other             Food     2.7      Returned  Negative          16.32
# 34   Other      Electronics     2.9  Not Returned   Neutral            NaN
# 35   Other      Electronics     1.4      Returned  Negative           8.30
# 36  Female      Electronics     4.0  Not Returned  Positive          10.78
# 37    Male      Electronics     2.7  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              4.6          1
# 1     FREESHIP              NaN          2
# 2     WELCOME5              NaN          3
# 3     WELCOME5              1.5          4
# 4     WELCOME5              3.8          5
# 5     FREESHIP              4.2          6
# 6          nan              5.0          7
# 7     FREESHIP              4.9          8
# 8          nan              2.8          9
# 9       SAVE10              3.1         10
# 10      SAVE10              4.5         11
# 11         nan              3.3         12
# 12      SAVE10              4.6         13
# 13         nan              4.7         14
# 14         nan              NaN         15
# 15    FREESHIP              NaN         16
# 16    FREESHIP              NaN         17
# 17    WELCOME5              4.3         18
# 18      SAVE10              3.5         19
# 19      SAVE10              NaN         20
# 20         nan              3.0         21
# 21         nan              4.8         22
# 22    FREESHIP              2.7         23
# 23         nan              1.5         24
# 24    FREESHIP              NaN         25
# 25    FREESHIP              4.9         26
# 26         nan              4.7         27
# 27         nan              3.8         28
# 28    WELCOME5              4.6         29
# 29    WELCOME5              2.0         30
# 30         nan              1.1         31
# 31         nan              3.3         32
# 32         nan              2.2         33
# 33         nan              NaN         34
# 34         nan              4.7         35
# 35         nan              4.7         36
# 36         nan              4.7         37
# 37    FREESHIP              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 07:**
# </div>

# %%
pd.Series.is_unique?
# Out:
# Type:        property
# String form: <property object at 0x10605c130>
# Docstring:
# Return boolean if values in the object are unique.
#
# Returns
# -------
# bool
#
# Examples
# --------
# >>> s = pd.Series([1, 2, 3])
# >>> s.is_unique
# True
#
# >>> s = pd.Series([1, 2, 3, 1])
# >>> s.is_unique
# False

# %%
# 7. Checking That a Specific Column Contains Only Unique Values
# Write a Pandas program to check that a specific column contains only unique values.


def is_unique(column_name, dataframe):
    if dataframe[column_name].is_unique:
        print("The column {:<20} contains only unique values.".format(column_name))
    else:
        print("The column {:<20} has more than one unique value - has duplicates.".format(column_name))

for col in df.columns:
    is_unique(col, df)
# Out:
# The column date                 has more than one unique value - has duplicates.
# The column customer_id          has more than one unique value - has duplicates.
# The column product_id           has more than one unique value - has duplicates.
# The column quantity             has more than one unique value - has duplicates.
# The column price                has more than one unique value - has duplicates.
# The column discount             has more than one unique value - has duplicates.
# The column revenue              has more than one unique value - has duplicates.
# The column store_id             has more than one unique value - has duplicates.
# The column region               has more than one unique value - has duplicates.
# The column payment_method       has more than one unique value - has duplicates.
# The column is_member            has more than one unique value - has duplicates.
# The column delivery_days        has more than one unique value - has duplicates.
# The column customer_age         has more than one unique value - has duplicates.
# The column gender               has more than one unique value - has duplicates.
# The column product_category     has more than one unique value - has duplicates.
# The column rating               has more than one unique value - has duplicates.
# The column return_status        has more than one unique value - has duplicates.
# The column feedback             has more than one unique value - has duplicates.
# The column shipping_cost        has more than one unique value - has duplicates.
# The column coupon_code          has more than one unique value - has duplicates.
# The column delivery_rating      has more than one unique value - has duplicates.
# The column unique_id            contains only unique values.

# %% [markdown]
# <div class="alert alert-warning">
#
# **8. Detecting Outliers in a DataFrame**
#
# **Write a Pandas program to detect outliers in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1391         108         2  9999.99      0.10   39.4920
# 1  2023-01-02         1492         131         5    11.16      0.19   45.1980
# 2  2023-01-03         1489         147         2    92.63      0.19  150.0606
# 3  2023-01-04         1948         154         3  8888.88      0.14  149.0724
# 4  2023-01-05         1899         116         5    72.31      0.11  321.7795
# 5  2023-01-06         1160         168         6  7777.77      0.19  416.7450
# 6  2023-01-07         1592         105         6    73.28      0.28  316.5696
# 7  2023-01-08         1957         132         1    37.17      0.01   36.7983
# 8  2023-01-09         1232         158         5    43.24      0.09  196.7420
# 9  2023-01-10         1153         142         6    26.60      0.19  129.2760
# 10 2023-01-11         1282         111         8    20.03      0.16  134.6016
# 11 2023-01-12         1136         104         5    47.06      0.02  230.5940
# 12 2023-01-13         1874         131         8    70.93      0.26  419.9056
# 13 2023-01-14         1376         162         8    43.56      0.28  250.9056
# 14 2023-01-15         1722         162         9    78.11      0.02  688.9302
# 15 2023-01-16         1059         141         7    13.17      0.16   77.4396
# 16 2023-01-17         1962         192         6    22.75      0.18  111.9300
# 17 2023-01-18         1701         144         4    55.48      0.22  173.0976
# 18 2023-01-19         1593         139         4    45.03      0.13  156.7044
# 19 2023-01-20         1915         106         7    96.73      0.27  494.2903
# 20 2023-01-21         1360         133         2    71.82      0.19  116.3484
# 21 2023-01-22         1344         113         8    64.87      0.26  384.0304
# 22 2023-01-23         1721         170         4    81.00      0.19  262.4400
# 23 2023-01-24         1025         174         9    91.84      0.06  776.9664
# 24 2023-01-25         1958         198         3    17.45      0.22   40.8330
# 25 2023-01-26         1714         100         3    69.12      0.24  157.5936
# 26 2023-01-27         1163         187         3    45.27      0.06  127.6614
# 27 2023-01-28         1635         146         2    39.05      0.24   59.3560
# 28 2023-01-29         1739         109         4    17.49      0.29   49.6716
# 29 2023-01-30         1845         181         7    84.76      0.27  433.1236
# 30 2023-01-31         1834         127         8    73.29      0.22  457.3296
# 31 2023-02-01         1445         155         8    90.05      0.06  677.1760
# 32 2023-02-02         1493         123         5    64.73      0.18  265.3930
# 33 2023-02-03         1439         155         5    88.16      0.17  365.8640
# 34 2023-02-04         1763         117         5    39.42      0.08  181.3320
# 35 2023-01-27         1163         187         3    45.27      0.06  127.6614
# 36 2023-01-14         1376         162         8    43.56      0.28  250.9056
# 37 2023-01-25         1958         198         3    17.45      0.22   40.8330
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          1   East         Online      False              1            64
# 1          3  South         Online      False              2            50
# 2          7  North    Credit Card       True              2            52
# 3          4   West    Credit Card       True              5            41
# 4          3  North           Cash      False              2            68
# 5          8   East         Online       True              4            58
# 6          1   West         Online       True              6            56
# 7          7   East    Credit Card      False              1            66
# 8          8  North    Credit Card      False              2            60
# 9          2  North           Cash      False              2            23
# 10         6   East         Online      False              5            66
# 11         9   East           Cash      False              3            53
# 12         5  North    Credit Card       True              2            41
# 13         4  South           Cash       True              2            41
# 14         4   East         Online      False              4            55
# 15         9   East           Cash       True              2            34
# 16         2  South         Online       True              5            22
# 17         9  South           Cash       True              4            67
# 18         5  North    Credit Card       True              5            63
# 19         8  South    Credit Card      False              4            46
# 20         4   East    Credit Card       True              3            54
# 21         7  North    Credit Card       True              4            48
# 22         5   East    Credit Card       True              4            63
# 23         8   East         Online      False              3            63
# 24         3   East         Online       True              4            24
# 25         3  North    Credit Card      False              5            49
# 26         5  North           Cash      False              6            35
# 27         2  North    Credit Card      False              3            53
# 28         9  North         Online      False              5            29
# 29         6   West           Cash      False              3            69
# 30         6   West    Credit Card       True              4            21
# 31         3   East           Cash      False              6            63
# 32         9  North    Credit Card      False              3            48
# 33         6   East           Cash       True              5            41
# 34         6  North         Online       True              1            35
# 35         5  North           Cash      False              6            35
# 36         4  South           Cash       True              2            41
# 37         3   East         Online       True              4            24
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other             Food     1.9  Not Returned  Positive            NaN
# 1     Male            Books     1.9      Returned  Negative           9.65
# 2    Other            Books     3.9  Not Returned  Negative           6.37
# 3    Other         Clothing     1.2  Not Returned  Positive          19.37
# 4   Female             Food     1.9      Returned  Negative          15.85
# 5   Female            Books     3.5  Not Returned   Neutral           6.55
# 6    Other            Books     3.1      Returned   Neutral          16.32
# 7     Male             Food     2.8      Returned  Negative          14.73
# 8    Other      Electronics     3.4  Not Returned  Positive           9.80
# 9   Female         Clothing     2.6      Returned   Neutral          19.69
# 10    Male         Clothing     3.4      Returned  Positive          10.81
# 11    Male         Clothing     3.4  Not Returned  Negative            NaN
# 12    Male             Food     3.8      Returned  Positive          19.60
# 13   Other      Electronics     3.4      Returned   Neutral           6.10
# 14   Other      Electronics     4.9  Not Returned  Positive           5.33
# 15    Male            Books     2.1  Not Returned   Neutral          16.28
# 16  Female      Electronics     3.3  Not Returned   Neutral           6.31
# 17   Other         Clothing     4.1      Returned  Negative          17.00
# 18  Female      Electronics     1.8  Not Returned  Negative            NaN
# 19   Other            Books     3.8      Returned   Neutral          12.68
# 20    Male             Food     1.7      Returned  Positive          12.21
# 21  Female         Clothing     4.3  Not Returned  Positive          16.99
# 22   Other      Electronics     1.9      Returned  Positive          12.37
# 23    Male             Food     1.2  Not Returned  Negative          19.38
# 24   Other            Books     3.1      Returned   Neutral          13.51
# 25    Male      Electronics     1.1      Returned  Positive          13.47
# 26    Male            Books     1.2  Not Returned   Neutral          10.85
# 27  Female      Electronics     2.0      Returned  Positive          17.22
# 28    Male            Books     1.5  Not Returned  Negative          13.63
# 29  Female      Electronics     4.2  Not Returned  Negative            NaN
# 30    Male      Electronics     2.9      Returned   Neutral          10.26
# 31    Male         Clothing     4.1      Returned  Positive          15.32
# 32   Other             Food     3.5  Not Returned  Positive          16.16
# 33    Male         Clothing     3.5  Not Returned   Neutral          17.35
# 34  Female             Food     1.9  Not Returned   Neutral           7.43
# 35    Male            Books     1.2  Not Returned   Neutral          10.85
# 36   Other      Electronics     3.4      Returned   Neutral           6.10
# 37   Other            Books     3.1      Returned   Neutral          13.51
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              2.8          1
# 1     WELCOME5              2.6          2
# 2          nan              5.0          3
# 3          nan              3.6          4
# 4          nan              2.3          5
# 5       SAVE10              NaN          6
# 6          nan              2.8          7
# 7     WELCOME5              3.2          8
# 8          nan              4.5          9
# 9     WELCOME5              3.8         10
# 10         nan              3.0         11
# 11         nan              4.2         12
# 12      SAVE10              1.2         13
# 13         nan              3.3         14
# 14    FREESHIP              2.4         15
# 15    FREESHIP              NaN         16
# 16      SAVE10              3.4         17
# 17         nan              NaN         18
# 18         nan              2.3         19
# 19      SAVE10              2.9         20
# 20         nan              5.0         21
# 21         nan              4.0         22
# 22    WELCOME5              4.8         23
# 23      SAVE10              2.5         24
# 24    WELCOME5              3.7         25
# 25         nan              NaN         26
# 26      SAVE10              5.0         27
# 27         nan              NaN         28
# 28      SAVE10              3.8         29
# 29      SAVE10              3.3         30
# 30    FREESHIP              3.5         31
# 31      SAVE10              1.4         32
# 32         nan              3.4         33
# 33      SAVE10              1.7         34
# 34      SAVE10              2.1         35
# 35      SAVE10              5.0         36
# 36         nan              3.3         37
# 37    WELCOME5              3.7         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 08:**
# </div>

# %%
# 8. Detecting Outliers in a DataFrame
# Write a Pandas program to detect outliers in a DataFrame.

def detect_outliers(column_name, dataframe):
    if dataframe[column_name].dtype not in [np.float64, np.int64]:
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        Q1 = dataframe[column_name].quantile(0.25)
        Q3 = dataframe[column_name].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = dataframe[(dataframe[column_name] < lower_bound) | (dataframe[column_name] > upper_bound)]
    if not outliers.empty:
        print("Column {:>30} OUTLIERS DETECTED.\n####### OUTLIERS #######".format(column_name))
        display(outliers)
    else:
        print("Column {:>30} has no outliers detected.".format(column_name))

for col in df.columns:
    detect_outliers(col, df)
# Out:
# Column                           date is not numeric and will be skipped.
# Column                    customer_id has no outliers detected.
# Column                     product_id has no outliers detected.
# Column                       quantity has no outliers detected.
# Column                          price OUTLIERS DETECTED.
# ####### OUTLIERS #######
#         date  customer_id  product_id  quantity    price  discount   revenue  \
# 0 2023-01-01         1391         108         2  9999.99      0.10   39.4920
# 3 2023-01-04         1948         154         3  8888.88      0.14  149.0724
# 5 2023-01-06         1160         168         6  7777.77      0.19  416.7450
#
#    store_id region payment_method  is_member  delivery_days  customer_age  \
# 0         1   East         Online      False              1            64
# 3         4   West    Credit Card       True              5            41
# 5         8   East         Online       True              4            58
#
#    gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Other             Food     1.9  Not Returned  Positive            NaN
# 3   Other         Clothing     1.2  Not Returned  Positive          19.37
# 5  Female            Books     3.5  Not Returned   Neutral           6.55
#
#   coupon_code  delivery_rating  unique_id
# 0         nan              2.8          1
# 3         nan              3.6          4
# 5      SAVE10              NaN          6
# Column                       discount has no outliers detected.
# Column                        revenue OUTLIERS DETECTED.
# ####### OUTLIERS #######
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 14 2023-01-15         1722         162         9  78.11      0.02  688.9302
# 23 2023-01-24         1025         174         9  91.84      0.06  776.9664
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 14         4   East         Online      False              4            55
# 23         8   East         Online      False              3            63
#
#    gender product_category  rating return_status  feedback  shipping_cost  \
# 14  Other      Electronics     4.9  Not Returned  Positive           5.33
# 23   Male             Food     1.2  Not Returned  Negative          19.38
#
#    coupon_code  delivery_rating  unique_id
# 14    FREESHIP              2.4         15
# 23      SAVE10              2.5         24
# Column                       store_id has no outliers detected.
# Column                         region is not numeric and will be skipped.
# Column                 payment_method is not numeric and will be skipped.
# Column                      is_member is not numeric and will be skipped.
# Column                  delivery_days has no outliers detected.
# Column                   customer_age has no outliers detected.
# Column                         gender is not numeric and will be skipped.
# Column               product_category is not numeric and will be skipped.
# Column                         rating has no outliers detected.
# Column                  return_status is not numeric and will be skipped.
# Column                       feedback is not numeric and will be skipped.
# Column                  shipping_cost has no outliers detected.
# Column                    coupon_code is not numeric and will be skipped.
# Column                delivery_rating has no outliers detected.
# Column                      unique_id has no outliers detected.

# %%
# finding outliers using the 3-σ rule

def detect_outliers_3sigma(column_name, dataframe):
    if dataframe[column_name].dtype not in [np.float64, np.int64]:
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        mean = dataframe[column_name].mean()
        std = dataframe[column_name].std()
        lower_bound = mean - 3 * std
        upper_bound = mean + 3 * std
        outliers = dataframe[(dataframe[column_name] < lower_bound) | (dataframe[column_name] > upper_bound)]
    
    if not outliers.empty:
        print("Column {:>30} OUTLIERS DETECTED (3σ rule).\n####### OUTLIERS #######".format(column_name))
        display(outliers)
    else:
        print("Column {:>30} has no outliers detected.".format(column_name))

# Apply to all columns
for col in df.columns:
    detect_outliers_3sigma(col, df)
# Out:
# Column                           date is not numeric and will be skipped.
# Column                    customer_id has no outliers detected.
# Column                     product_id has no outliers detected.
# Column                       quantity has no outliers detected.
# Column                          price OUTLIERS DETECTED (3σ rule).
# ####### OUTLIERS #######
#         date  customer_id  product_id  quantity    price  discount   revenue  \
# 0 2023-01-01         1391         108         2  9999.99      0.10   39.4920
# 3 2023-01-04         1948         154         3  8888.88      0.14  149.0724
# 5 2023-01-06         1160         168         6  7777.77      0.19  416.7450
#
#    store_id region payment_method  is_member  delivery_days  customer_age  \
# 0         1   East         Online      False              1            64
# 3         4   West    Credit Card       True              5            41
# 5         8   East         Online       True              4            58
#
#    gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Other             Food     1.9  Not Returned  Positive            NaN
# 3   Other         Clothing     1.2  Not Returned  Positive          19.37
# 5  Female            Books     3.5  Not Returned   Neutral           6.55
#
#   coupon_code  delivery_rating  unique_id
# 0         nan              2.8          1
# 3         nan              3.6          4
# 5      SAVE10              NaN          6
# Column                       discount has no outliers detected.
# Column                        revenue has no outliers detected.
# Column                       store_id has no outliers detected.
# Column                         region is not numeric and will be skipped.
# Column                 payment_method is not numeric and will be skipped.
# Column                      is_member is not numeric and will be skipped.
# Column                  delivery_days has no outliers detected.
# Column                   customer_age has no outliers detected.
# Column                         gender is not numeric and will be skipped.
# Column               product_category is not numeric and will be skipped.
# Column                         rating has no outliers detected.
# Column                  return_status is not numeric and will be skipped.
# Column                       feedback is not numeric and will be skipped.
# Column                  shipping_cost has no outliers detected.
# Column                    coupon_code is not numeric and will be skipped.
# Column                delivery_rating has no outliers detected.
# Column                      unique_id has no outliers detected.

# %% [markdown]
# <div class="alert alert-warning">
#
# **9. Validating Date Formats in a DataFrame**
#
# **Write a Pandas program to validate date formats in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1700         188         6  9999.99      0.13  485.3556
# 1  2023-01-02         1467         121         2    28.43      0.14   48.8996
# 2  2023-01-03         1313         104         2    43.28      0.27   63.1888
# 3  2023-01-04         1667         191         1  8888.88      0.12   54.3840
# 4  2023-01-05         1261         127         9    87.11      0.02  768.3102
# 5  2023-01-06         1352         198         1  7777.77      0.24   10.7920
# 6  2023-01-07         1170         159         6    86.39      0.26  383.5716
# 7  2023-01-08         1230         164         2    81.21      0.10  146.1780
# 8  2023-01-09         1059         106         4    64.25      0.16  215.8800
# 9  2023-01-10         1927         116         3    65.38      0.15  166.7190
# 10 2023-01-11         1427         129         5    13.21      0.26   48.8770
# 11 2023-01-12         1788         112         9    33.33      0.04  287.9712
# 12 2023-01-13         1291         179         4    77.39      0.21  244.5524
# 13 2023-01-14         1526         174         7    83.51      0.26  432.5818
# 14 2023-01-15         1673         143         8    21.11      0.20  135.1040
# 15 2023-01-16         1593         161         2    64.02      0.10  115.2360
# 16 2023-01-17         1543         165         5    93.42      0.16  392.3640
# 17 2023-01-18         1785         131         7    41.45      0.14  249.5290
# 18 2023-01-19         1314         198         2    73.25      0.05  139.1750
# 19 2023-01-20         1521         155         2    22.85      0.15   38.8450
# 20 2023-01-21         1904         113         3    90.60      0.04  260.9280
# 21 2023-01-22         1312         107         8    85.16      0.19  551.8368
# 22 2023-01-23         1553         172         3    26.69      0.25   60.0525
# 23 2023-01-24         1455         131         4    44.63      0.06  167.8088
# 24 2023-01-25         1841         144         1    26.97      0.08   24.8124
# 25 2023-01-26         1890         159         4    38.28      0.10  137.8080
# 26 2023-01-27         1367         127         3    75.78      0.19  184.1454
# 27 2023-01-28         1676         155         8    24.05      0.29  136.6040
# 28 2023-01-29         1774         192         6    15.01      0.16   75.6504
# 29 2023-01-30         1966         158         2    34.39      0.07   63.9654
# 30 2023-01-31         1056         162         8    95.92      0.20  613.8880
# 31 2023-02-01         1441         117         9    50.01      0.25  337.5675
# 32 2023-02-02         1519         125         6    94.80      0.03  551.7360
# 33 2023-02-03         1287         160         8    66.54      0.08  489.7344
# 34 2023-02-04         1709         194         9    13.74      0.25   92.7450
# 35 2023-01-27         1367         127         3    75.78      0.19  184.1454
# 36 2023-01-14         1526         174         7    83.51      0.26  432.5818
# 37 2023-01-25         1841         144         1    26.97      0.08   24.8124
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   East           Cash      False              2            35
# 1          3  North    Credit Card      False              3            62
# 2          9  North           Cash       True              5            34
# 3          1  North         Online      False              3            38
# 4          8  South           Cash       True              4            65
# 5          2   East    Credit Card       True              5            58
# 6          4   East    Credit Card      False              1            50
# 7          1  North    Credit Card      False              5            24
# 8          5  North           Cash      False              5            26
# 9          3   West         Online      False              3            30
# 10         3  South           Cash       True              5            63
# 11         3   West    Credit Card      False              6            67
# 12         9   West         Online      False              1            43
# 13         4   West    Credit Card      False              2            32
# 14         3  North         Online       True              4            48
# 15         1  South         Online      False              2            21
# 16         5   West           Cash      False              5            63
# 17         9  South           Cash       True              1            52
# 18         1   West           Cash      False              5            33
# 19         9  South         Online       True              3            23
# 20         1  South         Online       True              1            47
# 21         4   West    Credit Card       True              3            45
# 22         3  South           Cash      False              3            64
# 23         6  North           Cash      False              3            24
# 24         1   West         Online       True              6            45
# 25         6   East           Cash      False              3            35
# 26         1   West         Online       True              5            67
# 27         1  South           Cash      False              1            47
# 28         5  South    Credit Card       True              1            35
# 29         4   West    Credit Card      False              6            22
# 30         5  South           Cash      False              3            54
# 31         2  North           Cash      False              5            52
# 32         5  South         Online       True              5            52
# 33         1  South           Cash       True              5            25
# 34         7  North           Cash      False              1            47
# 35         1   West         Online       True              5            67
# 36         4   West    Credit Card      False              2            32
# 37         1   West         Online       True              6            45
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     1.0  Not Returned   Neutral          13.89
# 1    Other            Books     5.0      Returned  Negative            NaN
# 2   Female            Books     1.7  Not Returned  Negative          13.36
# 3   Female         Clothing     4.3      Returned  Positive          15.58
# 4     Male      Electronics     4.6  Not Returned  Positive          17.61
# 5    Other             Food     2.1  Not Returned  Negative            NaN
# 6     Male      Electronics     1.0      Returned   Neutral            NaN
# 7   Female         Clothing     2.1      Returned  Negative           9.74
# 8   Female      Electronics     4.5  Not Returned  Negative          16.15
# 9     Male            Books     3.1      Returned  Positive          10.24
# 10    Male             Food     2.9  Not Returned  Negative          14.71
# 11   Other         Clothing     2.1      Returned   Neutral          14.31
# 12   Other             Food     2.0      Returned  Positive          17.31
# 13  Female             Food     3.6      Returned  Negative           7.89
# 14  Female             Food     3.7  Not Returned   Neutral          13.85
# 15   Other            Books     4.4  Not Returned  Positive            NaN
# 16    Male            Books     4.8  Not Returned   Neutral          13.61
# 17   Other            Books     4.8      Returned  Positive          10.63
# 18   Other             Food     1.4  Not Returned   Neutral           8.12
# 19    Male      Electronics     2.9      Returned   Neutral            NaN
# 20  Female            Books     3.5      Returned  Positive          11.18
# 21  Female         Clothing     3.4      Returned   Neutral           7.64
# 22  Female      Electronics     4.0  Not Returned   Neutral          11.75
# 23  Female         Clothing     2.3      Returned   Neutral          19.19
# 24    Male      Electronics     4.6  Not Returned  Negative            NaN
# 25  Female      Electronics     3.4      Returned   Neutral            NaN
# 26  Female             Food     2.1      Returned  Positive           8.37
# 27   Other      Electronics     4.7  Not Returned  Negative            NaN
# 28    Male         Clothing     2.8  Not Returned  Negative          15.82
# 29   Other      Electronics     4.0      Returned  Negative           6.43
# 30    Male         Clothing     4.5  Not Returned  Positive          19.48
# 31   Other         Clothing     3.2  Not Returned  Negative            NaN
# 32   Other            Books     3.1      Returned  Negative          15.09
# 33  Female      Electronics     3.3  Not Returned  Negative          11.22
# 34    Male             Food     1.6  Not Returned  Negative          17.88
# 35  Female             Food     2.1      Returned  Positive           8.37
# 36  Female             Food     3.6      Returned  Negative           7.89
# 37    Male      Electronics     4.6  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              2.3          1
# 1     FREESHIP              NaN          2
# 2       SAVE10              NaN          3
# 3       SAVE10              NaN          4
# 4          nan              2.3          5
# 5          nan              3.2          6
# 6          nan              NaN          7
# 7          nan              2.3          8
# 8     FREESHIP              3.0          9
# 9     FREESHIP              4.4         10
# 10         nan              3.7         11
# 11         nan              NaN         12
# 12         nan              3.7         13
# 13         nan              NaN         14
# 14         nan              3.9         15
# 15    WELCOME5              4.4         16
# 16         nan              3.0         17
# 17      SAVE10              2.0         18
# 18         nan              3.6         19
# 19         nan              2.4         20
# 20      SAVE10              NaN         21
# 21    FREESHIP              NaN         22
# 22         nan              4.9         23
# 23      SAVE10              2.1         24
# 24         nan              NaN         25
# 25         nan              3.4         26
# 26    FREESHIP              NaN         27
# 27      SAVE10              NaN         28
# 28    WELCOME5              1.3         29
# 29         nan              1.6         30
# 30    FREESHIP              1.2         31
# 31      SAVE10              3.6         32
# 32         nan              1.3         33
# 33    WELCOME5              4.9         34
# 34      SAVE10              3.2         35
# 35    FREESHIP              NaN         36
# 36         nan              NaN         37
# 37         nan              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 09:**
# </div>

# %%
# 9. Validating Date Formats in a DataFrame
# Write a Pandas program to validate date formats in a DataFrame.

def validate_date_formats(date_column, dataframe):
    if not pd.api.types.is_datetime64_any_dtype(dataframe[date_column]):
        print("Column {:>30} is not a datetime type and will be skipped.".format(date_column))
        return
    else:
        invalid_dates = dataframe[~dataframe[date_column].dt.strftime('%Y-%m-%d').str.match(r'^\d{4}-\d{2}-\d{2}$')]
    if not invalid_dates.empty:
        print("Column {:>30} INVALID DATES DETECTED.\n####### INVALID DATES #######".format(date_column))
        display(invalid_dates)
    else:
        print("Column {:>30} has no invalid dates detected.".format(date_column))

# Apply to all columns
for col in df.columns:
    validate_date_formats(col, df)
# Out:
# Column                           date has no invalid dates detected.
# Column                    customer_id is not a datetime type and will be skipped.
# Column                     product_id is not a datetime type and will be skipped.
# Column                       quantity is not a datetime type and will be skipped.
# Column                          price is not a datetime type and will be skipped.
# Column                       discount is not a datetime type and will be skipped.
# Column                        revenue is not a datetime type and will be skipped.
# Column                       store_id is not a datetime type and will be skipped.
# Column                         region is not a datetime type and will be skipped.
# Column                 payment_method is not a datetime type and will be skipped.
# Column                      is_member is not a datetime type and will be skipped.
# Column                  delivery_days is not a datetime type and will be skipped.
# Column                   customer_age is not a datetime type and will be skipped.
# Column                         gender is not a datetime type and will be skipped.
# Column               product_category is not a datetime type and will be skipped.
# Column                         rating is not a datetime type and will be skipped.
# Column                  return_status is not a datetime type and will be skipped.
# Column                       feedback is not a datetime type and will be skipped.
# Column                  shipping_cost is not a datetime type and will be skipped.
# Column                    coupon_code is not a datetime type and will be skipped.
# Column                delivery_rating is not a datetime type and will be skipped.
# Column                      unique_id is not a datetime type and will be skipped.

# %% [markdown]
# <div class="alert alert-warning">
#
# **10. Ensuring No Missing Values in a Critical Column**
#
# **Write a Pandas program that ensures no missing values in a critical column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1160         142         4  9999.99      0.11  158.7760
# 1  2023-01-02         1291         162         7    11.05      0.24   58.7860
# 2  2023-01-03         1378         116         9    59.24      0.01  527.8284
# 3  2023-01-04         1144         109         2  8888.88      0.29   31.2542
# 4  2023-01-05         1787         198         5    36.24      0.24  137.7120
# 5  2023-01-06         1701         118         2  7777.77      0.01  178.3584
# 6  2023-01-07         1490         197         2    25.31      0.02   49.6076
# 7  2023-01-08         1328         172         1    52.50      0.05   49.8750
# 8  2023-01-09         1000         105         8    82.49      0.09  600.5272
# 9  2023-01-10         1568         140         2    86.63      0.21  136.8754
# 10 2023-01-11         1891         108         8    62.72      0.03  486.7072
# 11 2023-01-12         1685         109         3    65.62      0.04  188.9856
# 12 2023-01-13         1833         178         4    61.36      0.08  225.8048
# 13 2023-01-14         1643         112         8    33.30      0.20  213.1200
# 14 2023-01-15         1866         157         6    19.05      0.14   98.2980
# 15 2023-01-16         1078         134         3    76.56      0.22  179.1504
# 16 2023-01-17         1921         127         2    57.17      0.11  101.7626
# 17 2023-01-18         1270         195         5    38.43      0.07  178.6995
# 18 2023-01-19         1148         118         3    28.71      0.19   69.7653
# 19 2023-01-20         1063         193         9    27.89      0.11  223.3989
# 20 2023-01-21         1761         113         9    46.77      0.12  370.4184
# 21 2023-01-22         1862         122         8    10.51      0.02   82.3984
# 22 2023-01-23         1379         170         6    56.99      0.09  311.1654
# 23 2023-01-24         1942         147         9    86.34      0.01  769.2894
# 24 2023-01-25         1031         157         9    38.43      0.04  332.0352
# 25 2023-01-26         1172         186         5    22.67      0.04  108.8160
# 26 2023-01-27         1080         139         4    95.77      0.22  298.8024
# 27 2023-01-28         1377         148         1    36.38      0.05   34.5610
# 28 2023-01-29         1782         176         1    22.43      0.03   21.7571
# 29 2023-01-30         1514         190         5    18.44      0.05   87.5900
# 30 2023-01-31         1621         114         6    91.20      0.14  470.5920
# 31 2023-02-01         1816         182         1    49.47      0.19   40.0707
# 32 2023-02-02         1746         126         4    58.26      0.23  179.4408
# 33 2023-02-03         1833         151         5    66.85      0.23  257.3725
# 34 2023-02-04         1588         145         7    33.99      0.24  180.8268
# 35 2023-01-27         1080         139         4    95.77      0.22  298.8024
# 36 2023-01-14         1643         112         8    33.30      0.20  213.1200
# 37 2023-01-25         1031         157         9    38.43      0.04  332.0352
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5  North         Online       True              3            33
# 1          7  South    Credit Card       True              4            27
# 2          2   East         Online      False              4            56
# 3          3  South         Online      False              1            66
# 4          1   East    Credit Card      False              1            61
# 5          7   East         Online      False              3            34
# 6          2  South    Credit Card       True              4            24
# 7          7  South         Online       True              4            29
# 8          5   East         Online      False              3            34
# 9          3   East    Credit Card       True              5            22
# 10         3   West         Online      False              2            35
# 11         6   West         Online      False              3            51
# 12         7   East           Cash       True              4            31
# 13         5   East    Credit Card       True              4            60
# 14         3   West           Cash      False              3            26
# 15         8  South    Credit Card       True              3            60
# 16         7  North           Cash       True              1            57
# 17         3   West    Credit Card      False              4            35
# 18         1   West    Credit Card       True              4            20
# 19         4  South    Credit Card      False              4            28
# 20         9  South         Online       True              3            67
# 21         3  North         Online      False              6            47
# 22         6   West         Online       True              2            29
# 23         3  North           Cash      False              6            38
# 24         4  South         Online       True              5            25
# 25         4   West         Online       True              1            59
# 26         5  South    Credit Card      False              6            57
# 27         5   West           Cash      False              5            51
# 28         9  North    Credit Card      False              4            51
# 29         9  South         Online      False              4            37
# 30         3   West         Online       True              3            39
# 31         2  South         Online      False              2            27
# 32         6  North    Credit Card       True              4            53
# 33         8   West         Online       True              6            44
# 34         8  South           Cash       True              1            63
# 35         5  South    Credit Card      False              6            57
# 36         5   East    Credit Card       True              4            60
# 37         4  South         Online       True              5            25
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     3.1      Returned   Neutral          10.28
# 1     Male      Electronics     4.6  Not Returned  Negative          14.84
# 2    Other             Food     2.6      Returned  Negative            NaN
# 3     Male      Electronics     4.0      Returned   Neutral          15.24
# 4     Male             Food     3.4  Not Returned   Neutral          19.61
# 5     Male            Books     1.9  Not Returned   Neutral           7.13
# 6    Other         Clothing     4.0  Not Returned  Positive          12.39
# 7   Female      Electronics     4.8      Returned  Negative            NaN
# 8   Female      Electronics     2.9      Returned   Neutral           9.04
# 9    Other            Books     2.9  Not Returned  Negative            NaN
# 10    Male         Clothing     2.6      Returned   Neutral           7.68
# 11   Other            Books     3.7      Returned   Neutral           9.85
# 12  Female      Electronics     2.8  Not Returned  Negative          16.53
# 13    Male            Books     4.2      Returned   Neutral          19.42
# 14  Female      Electronics     3.4  Not Returned   Neutral           5.71
# 15   Other            Books     2.3      Returned  Positive           8.73
# 16  Female      Electronics     2.6      Returned  Negative          18.14
# 17    Male      Electronics     4.9      Returned  Positive          19.12
# 18    Male             Food     2.5      Returned  Negative            NaN
# 19   Other      Electronics     4.6  Not Returned   Neutral          17.68
# 20  Female            Books     2.0      Returned   Neutral          18.80
# 21   Other            Books     4.0      Returned  Positive          15.25
# 22   Other         Clothing     2.6  Not Returned   Neutral           7.84
# 23  Female         Clothing     4.5  Not Returned  Positive            NaN
# 24    Male         Clothing     1.8  Not Returned   Neutral           7.51
# 25   Other         Clothing     4.7      Returned   Neutral           6.31
# 26  Female             Food     1.3      Returned  Positive            NaN
# 27    Male      Electronics     1.8      Returned   Neutral            NaN
# 28    Male            Books     1.7  Not Returned   Neutral          18.62
# 29   Other      Electronics     2.9      Returned  Negative           9.12
# 30  Female      Electronics     3.3      Returned  Negative          15.17
# 31    Male         Clothing     3.3  Not Returned   Neutral          11.11
# 32    Male      Electronics     2.2  Not Returned   Neutral            NaN
# 33  Female         Clothing     1.6      Returned   Neutral           9.15
# 34   Other         Clothing     2.5  Not Returned   Neutral          14.26
# 35  Female             Food     1.3      Returned  Positive            NaN
# 36    Male            Books     4.2      Returned   Neutral          19.42
# 37    Male         Clothing     1.8  Not Returned   Neutral           7.51
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              1.5          1
# 1          nan              4.7          2
# 2          nan              3.6          3
# 3     WELCOME5              NaN          4
# 4       SAVE10              4.0          5
# 5     WELCOME5              4.6          6
# 6     WELCOME5              NaN          7
# 7          nan              2.2          8
# 8     WELCOME5              2.6          9
# 9          nan              1.8         10
# 10    FREESHIP              NaN         11
# 11      SAVE10              2.1         12
# 12         nan              4.7         13
# 13         nan              3.7         14
# 14    FREESHIP              2.7         15
# 15         nan              3.7         16
# 16    WELCOME5              NaN         17
# 17      SAVE10              4.0         18
# 18    FREESHIP              NaN         19
# 19         nan              4.6         20
# 20    FREESHIP              2.0         21
# 21         nan              NaN         22
# 22    WELCOME5              2.9         23
# 23         nan              2.1         24
# 24         nan              4.1         25
# 25    WELCOME5              4.2         26
# 26         nan              NaN         27
# 27    WELCOME5              4.8         28
# 28         nan              4.8         29
# 29         nan              4.0         30
# 30         nan              3.6         31
# 31         nan              NaN         32
# 32    FREESHIP              1.8         33
# 33         nan              4.0         34
# 34      SAVE10              3.4         35
# 35         nan              NaN         36
# 36         nan              3.7         37
# 37         nan              4.1         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 10:**
# </div>

# %%
# 10. Ensuring No Missing Values in a Critical Column
# Write a Pandas program that ensures no missing values in a critical column.

def check_missing_values(column_name, dataframe):
    missing_values = dataframe[column_name].isnull().sum()
    if missing_values > 0:
        print("Column {:>30} has {} missing values.".format(column_name, missing_values))
        display(dataframe[dataframe[column_name].isnull()])
    else:
        print("Column {:>30} has no missing values.".format(column_name))

# Apply to all columns
for col in df.columns:
    check_missing_values(col, df)
# Out:
# Column                           date has no missing values.
# Column                    customer_id has no missing values.
# Column                     product_id has no missing values.
# Column                       quantity has no missing values.
# Column                          price has no missing values.
# Column                       discount has no missing values.
# Column                        revenue has no missing values.
# Column                       store_id has no missing values.
# Column                         region has no missing values.
# Column                 payment_method has no missing values.
# Column                      is_member has no missing values.
# Column                  delivery_days has no missing values.
# Column                   customer_age has no missing values.
# Column                         gender has no missing values.
# Column               product_category has no missing values.
# Column                         rating has no missing values.
# Column                  return_status has no missing values.
# Column                       feedback has no missing values.
# Column                  shipping_cost has 12 missing values.
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 2  2023-01-03         1378         116         9  59.24      0.01  527.8284
# 7  2023-01-08         1328         172         1  52.50      0.05   49.8750
# 9  2023-01-10         1568         140         2  86.63      0.21  136.8754
# 18 2023-01-19         1148         118         3  28.71      0.19   69.7653
# 23 2023-01-24         1942         147         9  86.34      0.01  769.2894
# 26 2023-01-27         1080         139         4  95.77      0.22  298.8024
# 27 2023-01-28         1377         148         1  36.38      0.05   34.5610
# 32 2023-02-02         1746         126         4  58.26      0.23  179.4408
# 35 2023-01-27         1080         139         4  95.77      0.22  298.8024
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 2          2   East         Online      False              4            56
# 7          7  South         Online       True              4            29
# 9          3   East    Credit Card       True              5            22
# 18         1   West    Credit Card       True              4            20
# 23         3  North           Cash      False              6            38
# 26         5  South    Credit Card      False              6            57
# 27         5   West           Cash      False              5            51
# 32         6  North    Credit Card       True              4            53
# 35         5  South    Credit Card      False              6            57
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 2    Other             Food     2.6      Returned  Negative            NaN
# 7   Female      Electronics     4.8      Returned  Negative            NaN
# 9    Other            Books     2.9  Not Returned  Negative            NaN
# 18    Male             Food     2.5      Returned  Negative            NaN
# 23  Female         Clothing     4.5  Not Returned  Positive            NaN
# 26  Female             Food     1.3      Returned  Positive            NaN
# 27    Male      Electronics     1.8      Returned   Neutral            NaN
# 32    Male      Electronics     2.2  Not Returned   Neutral            NaN
# 35  Female             Food     1.3      Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 2          nan              3.6          3
# 7          nan              2.2          8
# 9          nan              1.8         10
# 18    FREESHIP              NaN         19
# 23         nan              2.1         24
# 26         nan              NaN         27
# 27    WELCOME5              4.8         28
# 32    FREESHIP              1.8         33
# 35         nan              NaN         36
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                    coupon_code has 3 missing values.
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                delivery_rating has 12 missing values.
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 3  2023-01-04         1144         109         2  8888.88      0.29   31.2542
# 6  2023-01-07         1490         197         2    25.31      0.02   49.6076
# 10 2023-01-11         1891         108         8    62.72      0.03  486.7072
# 16 2023-01-17         1921         127         2    57.17      0.11  101.7626
# 18 2023-01-19         1148         118         3    28.71      0.19   69.7653
# 21 2023-01-22         1862         122         8    10.51      0.02   82.3984
# 26 2023-01-27         1080         139         4    95.77      0.22  298.8024
# 31 2023-02-01         1816         182         1    49.47      0.19   40.0707
# 35 2023-01-27         1080         139         4    95.77      0.22  298.8024
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 3          3  South         Online      False              1            66
# 6          2  South    Credit Card       True              4            24
# 10         3   West         Online      False              2            35
# 16         7  North           Cash       True              1            57
# 18         1   West    Credit Card       True              4            20
# 21         3  North         Online      False              6            47
# 26         5  South    Credit Card      False              6            57
# 31         2  South         Online      False              2            27
# 35         5  South    Credit Card      False              6            57
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 3     Male      Electronics     4.0      Returned   Neutral          15.24
# 6    Other         Clothing     4.0  Not Returned  Positive          12.39
# 10    Male         Clothing     2.6      Returned   Neutral           7.68
# 16  Female      Electronics     2.6      Returned  Negative          18.14
# 18    Male             Food     2.5      Returned  Negative            NaN
# 21   Other            Books     4.0      Returned  Positive          15.25
# 26  Female             Food     1.3      Returned  Positive            NaN
# 31    Male         Clothing     3.3  Not Returned   Neutral          11.11
# 35  Female             Food     1.3      Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 3     WELCOME5              NaN          4
# 6     WELCOME5              NaN          7
# 10    FREESHIP              NaN         11
# 16    WELCOME5              NaN         17
# 18    FREESHIP              NaN         19
# 21         nan              NaN         22
# 26         nan              NaN         27
# 31         nan              NaN         32
# 35         nan              NaN         36
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                      unique_id has no missing values.

# %% [markdown]
# <div class="alert alert-warning">
#
# **11. Validating String Length in a DataFrame Column**
#
# **Write a Pandas program that validates string length in a DataFrame column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1279         184         3  9999.99      0.14  193.5258
# 1  2023-01-02         1885         182         8    36.32      0.01  287.6544
# 2  2023-01-03         1072         134         5    75.21      0.15  319.6425
# 3  2023-01-04         1399         163         1  8888.88      0.01   36.8379
# 4  2023-01-05         1939         139         6    10.64      0.28   45.9648
# 5  2023-01-06         1421         135         3  7777.77      0.17   92.4537
# 6  2023-01-07         1700         153         5    80.38      0.24  305.4440
# 7  2023-01-08         1160         136         8    25.97      0.11  184.9064
# 8  2023-01-09         1752         178         4    67.92      0.19  220.0608
# 9  2023-01-10         1878         158         3    92.33      0.28  199.4328
# 10 2023-01-11         1789         153         3    45.59      0.16  114.8868
# 11 2023-01-12         1773         199         7    83.30      0.19  472.3110
# 12 2023-01-13         1865         124         4    88.30      0.17  293.1560
# 13 2023-01-14         1850         197         2    10.88      0.14   18.7136
# 14 2023-01-15         1560         146         7    52.87      0.30  259.0630
# 15 2023-01-16         1932         158         3    99.16      0.08  273.6816
# 16 2023-01-17         1936         197         9    94.47      0.11  756.7047
# 17 2023-01-18         1381         193         8    73.75      0.29  418.9000
# 18 2023-01-19         1275         132         3    27.41      0.02   80.5854
# 19 2023-01-20         1558         185         5    65.86      0.28  237.0960
# 20 2023-01-21         1412         103         1    36.08      0.11   32.1112
# 21 2023-01-22         1746         145         4    34.34      0.19  111.2616
# 22 2023-01-23         1282         173         9    94.29      0.22  661.9158
# 23 2023-01-24         1027         116         7    76.31      0.21  421.9943
# 24 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 25 2023-01-26         1086         120         2    38.55      0.12   67.8480
# 26 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 27 2023-01-28         1402         186         5    44.42      0.03  215.4370
# 28 2023-01-29         1329         110         6    91.48      0.25  411.6600
# 29 2023-01-30         1658         117         4    18.16      0.26   53.7536
# 30 2023-01-31         1080         141         8    46.31      0.21  292.6792
# 31 2023-02-01         1068         104         8    28.46      0.23  175.3136
# 32 2023-02-02         1652         117         2    21.34      0.16   35.8512
# 33 2023-02-03         1895         101         1    49.90      0.01   49.4010
# 34 2023-02-04         1984         175         2    29.41      0.10   52.9380
# 35 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 36 2023-01-14         1850         197         2    10.88      0.14   18.7136
# 37 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   East    Credit Card       True              1            60
# 1          9  North    Credit Card       True              2            34
# 2          5   West    Credit Card      False              5            21
# 3          5  South    Credit Card      False              1            59
# 4          5   West    Credit Card      False              4            28
# 5          9  North    Credit Card      False              4            56
# 6          4  North    Credit Card       True              1            53
# 7          3   East    Credit Card       True              6            32
# 8          8  North           Cash      False              2            31
# 9          2  South    Credit Card      False              2            67
# 10         7   West         Online      False              4            32
# 11         1  North    Credit Card      False              2            18
# 12         3   East         Online      False              1            42
# 13         6   East           Cash       True              6            53
# 14         6  North    Credit Card       True              1            43
# 15         3   West           Cash      False              6            45
# 16         2   West         Online       True              4            30
# 17         5   West           Cash      False              4            36
# 18         4  North           Cash       True              3            18
# 19         2  North           Cash      False              3            40
# 20         1   East           Cash      False              3            55
# 21         1   West         Online       True              4            55
# 22         8  South           Cash      False              5            44
# 23         9   West    Credit Card      False              5            33
# 24         1   West           Cash      False              3            67
# 25         4   West           Cash      False              6            30
# 26         4  South         Online       True              4            39
# 27         3   East           Cash      False              1            18
# 28         5  South    Credit Card       True              2            51
# 29         2   East         Online      False              3            61
# 30         8   East    Credit Card      False              2            47
# 31         9  North    Credit Card      False              4            37
# 32         5  North         Online       True              4            39
# 33         9   East    Credit Card      False              4            34
# 34         7  South           Cash       True              6            49
# 35         4  South         Online       True              4            39
# 36         6   East           Cash       True              6            53
# 37         1   West           Cash      False              3            67
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     2.4  Not Returned  Negative          17.52
# 1     Male      Electronics     4.7  Not Returned  Negative          14.13
# 2   Female            Books     2.9  Not Returned  Negative          11.43
# 3     Male         Clothing     4.3      Returned   Neutral            NaN
# 4    Other         Clothing     2.7      Returned   Neutral          12.17
# 5     Male      Electronics     3.7      Returned   Neutral          13.77
# 6    Other             Food     2.6  Not Returned  Negative          11.85
# 7     Male             Food     4.3      Returned   Neutral          14.33
# 8   Female             Food     2.4  Not Returned  Positive           8.34
# 9   Female             Food     3.6  Not Returned   Neutral           9.22
# 10   Other      Electronics     1.1  Not Returned  Negative            NaN
# 11   Other             Food     4.4  Not Returned   Neutral            NaN
# 12   Other         Clothing     3.7      Returned  Positive            NaN
# 13    Male      Electronics     3.1      Returned  Negative            NaN
# 14    Male      Electronics     4.4      Returned   Neutral            NaN
# 15   Other             Food     3.9      Returned  Positive            NaN
# 16    Male             Food     4.9      Returned   Neutral           9.64
# 17  Female         Clothing     3.8  Not Returned   Neutral           8.81
# 18   Other      Electronics     4.5  Not Returned  Negative          10.02
# 19  Female      Electronics     4.7  Not Returned  Negative           5.58
# 20   Other      Electronics     3.2  Not Returned   Neutral           7.33
# 21  Female            Books     1.9  Not Returned   Neutral          16.59
# 22  Female            Books     1.4  Not Returned  Negative           7.05
# 23  Female             Food     1.8      Returned  Negative            NaN
# 24  Female         Clothing     2.4      Returned   Neutral           5.99
# 25  Female             Food     1.1      Returned  Negative            NaN
# 26   Other         Clothing     4.6  Not Returned  Positive           5.66
# 27  Female            Books     3.4  Not Returned   Neutral          17.38
# 28   Other      Electronics     4.1      Returned  Positive           7.03
# 29    Male            Books     4.0      Returned  Negative          15.04
# 30   Other         Clothing     2.5      Returned   Neutral          12.81
# 31    Male             Food     4.8  Not Returned   Neutral            NaN
# 32    Male      Electronics     2.3      Returned  Positive           6.20
# 33   Other         Clothing     2.6  Not Returned   Neutral          14.93
# 34  Female             Food     1.6      Returned  Positive          13.91
# 35   Other         Clothing     4.6  Not Returned  Positive           5.66
# 36    Male      Electronics     3.1      Returned  Negative            NaN
# 37  Female         Clothing     2.4      Returned   Neutral           5.99
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              4.5          1
# 1     FREESHIP              2.9          2
# 2     FREESHIP              NaN          3
# 3     WELCOME5              NaN          4
# 4     WELCOME5              4.5          5
# 5          nan              3.9          6
# 6     WELCOME5              2.3          7
# 7       SAVE10              1.4          8
# 8     FREESHIP              4.1          9
# 9     FREESHIP              1.2         10
# 10         nan              2.9         11
# 11    WELCOME5              NaN         12
# 12         nan              NaN         13
# 13    FREESHIP              1.7         14
# 14         nan              3.9         15
# 15         nan              2.2         16
# 16         nan              4.3         17
# 17    WELCOME5              4.4         18
# 18    WELCOME5              4.0         19
# 19      SAVE10              1.8         20
# 20         nan              NaN         21
# 21         nan              NaN         22
# 22    WELCOME5              3.8         23
# 23         nan              NaN         24
# 24    FREESHIP              NaN         25
# 25    FREESHIP              2.3         26
# 26         nan              NaN         27
# 27    FREESHIP              1.5         28
# 28         nan              3.1         29
# 29    WELCOME5              2.3         30
# 30    FREESHIP              NaN         31
# 31         nan              4.9         32
# 32         nan              NaN         33
# 33         nan              NaN         34
# 34    WELCOME5              4.3         35
# 35         nan              NaN         36
# 36    FREESHIP              1.7         37
# 37    FREESHIP              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 11:**
# </div>

# %%
# 11. Validating String Length in a DataFrame Column
# Write a Pandas program that validates string length in a DataFrame column.

def validate_string_length(dataframe, column_name, min_length: int=0, max_length: int=100):
    if not pd.api.types.is_string_dtype(dataframe[column_name]):
        print("Column {:>30} is not a string type and will be skipped.".format(column_name))
        return
    else:
        invalid_length = dataframe[(dataframe[column_name].str.len() < min_length) | (dataframe[column_name].str.len() > max_length)]
    if not invalid_length.empty:
        print("Column {:>30} INVALID LENGTH DETECTED.\n####### INVALID LENGTH #######".format(column_name))
        display(invalid_length)
    else:
        print("Column {:>30} has no invalid length detected.".format(column_name))

# Apply to all columns
for col in df.columns:
    validate_string_length(df, col, min_length=0, max_length=4)
# Out:
# Column                           date is not a string type and will be skipped.
# Column                    customer_id is not a string type and will be skipped.
# Column                     product_id is not a string type and will be skipped.
# Column                       quantity is not a string type and will be skipped.
# Column                          price is not a string type and will be skipped.
# Column                       discount is not a string type and will be skipped.
# Column                        revenue is not a string type and will be skipped.
# Column                       store_id is not a string type and will be skipped.
# Column                         region INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 1  2023-01-02         1885         182         8    36.32      0.01  287.6544
# 3  2023-01-04         1399         163         1  8888.88      0.01   36.8379
# 5  2023-01-06         1421         135         3  7777.77      0.17   92.4537
# 6  2023-01-07         1700         153         5    80.38      0.24  305.4440
# 8  2023-01-09         1752         178         4    67.92      0.19  220.0608
# 9  2023-01-10         1878         158         3    92.33      0.28  199.4328
# 11 2023-01-12         1773         199         7    83.30      0.19  472.3110
# 14 2023-01-15         1560         146         7    52.87      0.30  259.0630
# 18 2023-01-19         1275         132         3    27.41      0.02   80.5854
# 19 2023-01-20         1558         185         5    65.86      0.28  237.0960
# 22 2023-01-23         1282         173         9    94.29      0.22  661.9158
# 26 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 28 2023-01-29         1329         110         6    91.48      0.25  411.6600
# 31 2023-02-01         1068         104         8    28.46      0.23  175.3136
# 32 2023-02-02         1652         117         2    21.34      0.16   35.8512
# 34 2023-02-04         1984         175         2    29.41      0.10   52.9380
# 35 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 1          9  North    Credit Card       True              2            34
# 3          5  South    Credit Card      False              1            59
# 5          9  North    Credit Card      False              4            56
# 6          4  North    Credit Card       True              1            53
# 8          8  North           Cash      False              2            31
# 9          2  South    Credit Card      False              2            67
# 11         1  North    Credit Card      False              2            18
# 14         6  North    Credit Card       True              1            43
# 18         4  North           Cash       True              3            18
# 19         2  North           Cash      False              3            40
# 22         8  South           Cash      False              5            44
# 26         4  South         Online       True              4            39
# 28         5  South    Credit Card       True              2            51
# 31         9  North    Credit Card      False              4            37
# 32         5  North         Online       True              4            39
# 34         7  South           Cash       True              6            49
# 35         4  South         Online       True              4            39
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 1     Male      Electronics     4.7  Not Returned  Negative          14.13
# 3     Male         Clothing     4.3      Returned   Neutral            NaN
# 5     Male      Electronics     3.7      Returned   Neutral          13.77
# 6    Other             Food     2.6  Not Returned  Negative          11.85
# 8   Female             Food     2.4  Not Returned  Positive           8.34
# 9   Female             Food     3.6  Not Returned   Neutral           9.22
# 11   Other             Food     4.4  Not Returned   Neutral            NaN
# 14    Male      Electronics     4.4      Returned   Neutral            NaN
# 18   Other      Electronics     4.5  Not Returned  Negative          10.02
# 19  Female      Electronics     4.7  Not Returned  Negative           5.58
# 22  Female            Books     1.4  Not Returned  Negative           7.05
# 26   Other         Clothing     4.6  Not Returned  Positive           5.66
# 28   Other      Electronics     4.1      Returned  Positive           7.03
# 31    Male             Food     4.8  Not Returned   Neutral            NaN
# 32    Male      Electronics     2.3      Returned  Positive           6.20
# 34  Female             Food     1.6      Returned  Positive          13.91
# 35   Other         Clothing     4.6  Not Returned  Positive           5.66
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
#
#    coupon_code  delivery_rating  unique_id
# 1     FREESHIP              2.9          2
# 3     WELCOME5              NaN          4
# 5          nan              3.9          6
# 6     WELCOME5              2.3          7
# 8     FREESHIP              4.1          9
# 9     FREESHIP              1.2         10
# 11    WELCOME5              NaN         12
# 14         nan              3.9         15
# 18    WELCOME5              4.0         19
# 19      SAVE10              1.8         20
# 22    WELCOME5              3.8         23
# 26         nan              NaN         27
# 28         nan              3.1         29
# 31         nan              4.9         32
# 32         nan              NaN         33
# 34    WELCOME5              4.3         35
# 35         nan              NaN         36
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# Column                 payment_method INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1279         184         3  9999.99      0.14  193.5258
# 1  2023-01-02         1885         182         8    36.32      0.01  287.6544
# 2  2023-01-03         1072         134         5    75.21      0.15  319.6425
# 3  2023-01-04         1399         163         1  8888.88      0.01   36.8379
# 4  2023-01-05         1939         139         6    10.64      0.28   45.9648
# 5  2023-01-06         1421         135         3  7777.77      0.17   92.4537
# 6  2023-01-07         1700         153         5    80.38      0.24  305.4440
# 7  2023-01-08         1160         136         8    25.97      0.11  184.9064
# 9  2023-01-10         1878         158         3    92.33      0.28  199.4328
# 10 2023-01-11         1789         153         3    45.59      0.16  114.8868
# 11 2023-01-12         1773         199         7    83.30      0.19  472.3110
# 12 2023-01-13         1865         124         4    88.30      0.17  293.1560
# 14 2023-01-15         1560         146         7    52.87      0.30  259.0630
# 16 2023-01-17         1936         197         9    94.47      0.11  756.7047
# 21 2023-01-22         1746         145         4    34.34      0.19  111.2616
# 23 2023-01-24         1027         116         7    76.31      0.21  421.9943
# 26 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 28 2023-01-29         1329         110         6    91.48      0.25  411.6600
# 29 2023-01-30         1658         117         4    18.16      0.26   53.7536
# 30 2023-01-31         1080         141         8    46.31      0.21  292.6792
# 31 2023-02-01         1068         104         8    28.46      0.23  175.3136
# 32 2023-02-02         1652         117         2    21.34      0.16   35.8512
# 33 2023-02-03         1895         101         1    49.90      0.01   49.4010
# 35 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   East    Credit Card       True              1            60
# 1          9  North    Credit Card       True              2            34
# 2          5   West    Credit Card      False              5            21
# 3          5  South    Credit Card      False              1            59
# 4          5   West    Credit Card      False              4            28
# 5          9  North    Credit Card      False              4            56
# 6          4  North    Credit Card       True              1            53
# 7          3   East    Credit Card       True              6            32
# 9          2  South    Credit Card      False              2            67
# 10         7   West         Online      False              4            32
# 11         1  North    Credit Card      False              2            18
# 12         3   East         Online      False              1            42
# 14         6  North    Credit Card       True              1            43
# 16         2   West         Online       True              4            30
# 21         1   West         Online       True              4            55
# 23         9   West    Credit Card      False              5            33
# 26         4  South         Online       True              4            39
# 28         5  South    Credit Card       True              2            51
# 29         2   East         Online      False              3            61
# 30         8   East    Credit Card      False              2            47
# 31         9  North    Credit Card      False              4            37
# 32         5  North         Online       True              4            39
# 33         9   East    Credit Card      False              4            34
# 35         4  South         Online       True              4            39
# 38         5  North    Credit Card       True              3            25
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     2.4  Not Returned  Negative          17.52
# 1     Male      Electronics     4.7  Not Returned  Negative          14.13
# 2   Female            Books     2.9  Not Returned  Negative          11.43
# 3     Male         Clothing     4.3      Returned   Neutral            NaN
# 4    Other         Clothing     2.7      Returned   Neutral          12.17
# 5     Male      Electronics     3.7      Returned   Neutral          13.77
# 6    Other             Food     2.6  Not Returned  Negative          11.85
# 7     Male             Food     4.3      Returned   Neutral          14.33
# 9   Female             Food     3.6  Not Returned   Neutral           9.22
# 10   Other      Electronics     1.1  Not Returned  Negative            NaN
# 11   Other             Food     4.4  Not Returned   Neutral            NaN
# 12   Other         Clothing     3.7      Returned  Positive            NaN
# 14    Male      Electronics     4.4      Returned   Neutral            NaN
# 16    Male             Food     4.9      Returned   Neutral           9.64
# 21  Female            Books     1.9  Not Returned   Neutral          16.59
# 23  Female             Food     1.8      Returned  Negative            NaN
# 26   Other         Clothing     4.6  Not Returned  Positive           5.66
# 28   Other      Electronics     4.1      Returned  Positive           7.03
# 29    Male            Books     4.0      Returned  Negative          15.04
# 30   Other         Clothing     2.5      Returned   Neutral          12.81
# 31    Male             Food     4.8  Not Returned   Neutral            NaN
# 32    Male      Electronics     2.3      Returned  Positive           6.20
# 33   Other         Clothing     2.6  Not Returned   Neutral          14.93
# 35   Other         Clothing     4.6  Not Returned  Positive           5.66
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              4.5          1
# 1     FREESHIP              2.9          2
# 2     FREESHIP              NaN          3
# 3     WELCOME5              NaN          4
# 4     WELCOME5              4.5          5
# 5          nan              3.9          6
# 6     WELCOME5              2.3          7
# 7       SAVE10              1.4          8
# 9     FREESHIP              1.2         10
# 10         nan              2.9         11
# 11    WELCOME5              NaN         12
# 12         nan              NaN         13
# 14         nan              3.9         15
# 16         nan              4.3         17
# 21         nan              NaN         22
# 23         nan              NaN         24
# 26         nan              NaN         27
# 28         nan              3.1         29
# 29    WELCOME5              2.3         30
# 30    FREESHIP              NaN         31
# 31         nan              4.9         32
# 32         nan              NaN         33
# 33         nan              NaN         34
# 35         nan              NaN         36
# 38         NaN              NaN         39
# 40         NaN              NaN         41
# Column                      is_member is not a string type and will be skipped.
# Column                  delivery_days is not a string type and will be skipped.
# Column                   customer_age is not a string type and will be skipped.
# Column                         gender INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1279         184         3  9999.99      0.14  193.5258
# 2  2023-01-03         1072         134         5    75.21      0.15  319.6425
# 4  2023-01-05         1939         139         6    10.64      0.28   45.9648
# 6  2023-01-07         1700         153         5    80.38      0.24  305.4440
# 8  2023-01-09         1752         178         4    67.92      0.19  220.0608
# 9  2023-01-10         1878         158         3    92.33      0.28  199.4328
# 10 2023-01-11         1789         153         3    45.59      0.16  114.8868
# 11 2023-01-12         1773         199         7    83.30      0.19  472.3110
# 12 2023-01-13         1865         124         4    88.30      0.17  293.1560
# 15 2023-01-16         1932         158         3    99.16      0.08  273.6816
# 17 2023-01-18         1381         193         8    73.75      0.29  418.9000
# 18 2023-01-19         1275         132         3    27.41      0.02   80.5854
# 19 2023-01-20         1558         185         5    65.86      0.28  237.0960
# 20 2023-01-21         1412         103         1    36.08      0.11   32.1112
# 21 2023-01-22         1746         145         4    34.34      0.19  111.2616
# 22 2023-01-23         1282         173         9    94.29      0.22  661.9158
# 23 2023-01-24         1027         116         7    76.31      0.21  421.9943
# 24 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 25 2023-01-26         1086         120         2    38.55      0.12   67.8480
# 26 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 27 2023-01-28         1402         186         5    44.42      0.03  215.4370
# 28 2023-01-29         1329         110         6    91.48      0.25  411.6600
# 30 2023-01-31         1080         141         8    46.31      0.21  292.6792
# 33 2023-02-03         1895         101         1    49.90      0.01   49.4010
# 34 2023-02-04         1984         175         2    29.41      0.10   52.9380
# 35 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 37 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   East    Credit Card       True              1            60
# 2          5   West    Credit Card      False              5            21
# 4          5   West    Credit Card      False              4            28
# 6          4  North    Credit Card       True              1            53
# 8          8  North           Cash      False              2            31
# 9          2  South    Credit Card      False              2            67
# 10         7   West         Online      False              4            32
# 11         1  North    Credit Card      False              2            18
# 12         3   East         Online      False              1            42
# 15         3   West           Cash      False              6            45
# 17         5   West           Cash      False              4            36
# 18         4  North           Cash       True              3            18
# 19         2  North           Cash      False              3            40
# 20         1   East           Cash      False              3            55
# 21         1   West         Online       True              4            55
# 22         8  South           Cash      False              5            44
# 23         9   West    Credit Card      False              5            33
# 24         1   West           Cash      False              3            67
# 25         4   West           Cash      False              6            30
# 26         4  South         Online       True              4            39
# 27         3   East           Cash      False              1            18
# 28         5  South    Credit Card       True              2            51
# 30         8   East    Credit Card      False              2            47
# 33         9   East    Credit Card      False              4            34
# 34         7  South           Cash       True              6            49
# 35         4  South         Online       True              4            39
# 37         1   West           Cash      False              3            67
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     2.4  Not Returned  Negative          17.52
# 2   Female            Books     2.9  Not Returned  Negative          11.43
# 4    Other         Clothing     2.7      Returned   Neutral          12.17
# 6    Other             Food     2.6  Not Returned  Negative          11.85
# 8   Female             Food     2.4  Not Returned  Positive           8.34
# 9   Female             Food     3.6  Not Returned   Neutral           9.22
# 10   Other      Electronics     1.1  Not Returned  Negative            NaN
# 11   Other             Food     4.4  Not Returned   Neutral            NaN
# 12   Other         Clothing     3.7      Returned  Positive            NaN
# 15   Other             Food     3.9      Returned  Positive            NaN
# 17  Female         Clothing     3.8  Not Returned   Neutral           8.81
# 18   Other      Electronics     4.5  Not Returned  Negative          10.02
# 19  Female      Electronics     4.7  Not Returned  Negative           5.58
# 20   Other      Electronics     3.2  Not Returned   Neutral           7.33
# 21  Female            Books     1.9  Not Returned   Neutral          16.59
# 22  Female            Books     1.4  Not Returned  Negative           7.05
# 23  Female             Food     1.8      Returned  Negative            NaN
# 24  Female         Clothing     2.4      Returned   Neutral           5.99
# 25  Female             Food     1.1      Returned  Negative            NaN
# 26   Other         Clothing     4.6  Not Returned  Positive           5.66
# 27  Female            Books     3.4  Not Returned   Neutral          17.38
# 28   Other      Electronics     4.1      Returned  Positive           7.03
# 30   Other         Clothing     2.5      Returned   Neutral          12.81
# 33   Other         Clothing     2.6  Not Returned   Neutral          14.93
# 34  Female             Food     1.6      Returned  Positive          13.91
# 35   Other         Clothing     4.6  Not Returned  Positive           5.66
# 37  Female         Clothing     2.4      Returned   Neutral           5.99
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              4.5          1
# 2     FREESHIP              NaN          3
# 4     WELCOME5              4.5          5
# 6     WELCOME5              2.3          7
# 8     FREESHIP              4.1          9
# 9     FREESHIP              1.2         10
# 10         nan              2.9         11
# 11    WELCOME5              NaN         12
# 12         nan              NaN         13
# 15         nan              2.2         16
# 17    WELCOME5              4.4         18
# 18    WELCOME5              4.0         19
# 19      SAVE10              1.8         20
# 20         nan              NaN         21
# 21         nan              NaN         22
# 22    WELCOME5              3.8         23
# 23         nan              NaN         24
# 24    FREESHIP              NaN         25
# 25    FREESHIP              2.3         26
# 26         nan              NaN         27
# 27    FREESHIP              1.5         28
# 28         nan              3.1         29
# 30    FREESHIP              NaN         31
# 33         nan              NaN         34
# 34    WELCOME5              4.3         35
# 35         nan              NaN         36
# 37    FREESHIP              NaN         38
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column               product_category INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1279         184         3  9999.99      0.14  193.5258
# 1  2023-01-02         1885         182         8    36.32      0.01  287.6544
# 2  2023-01-03         1072         134         5    75.21      0.15  319.6425
# 3  2023-01-04         1399         163         1  8888.88      0.01   36.8379
# 4  2023-01-05         1939         139         6    10.64      0.28   45.9648
# 5  2023-01-06         1421         135         3  7777.77      0.17   92.4537
# 10 2023-01-11         1789         153         3    45.59      0.16  114.8868
# 12 2023-01-13         1865         124         4    88.30      0.17  293.1560
# 13 2023-01-14         1850         197         2    10.88      0.14   18.7136
# 14 2023-01-15         1560         146         7    52.87      0.30  259.0630
# 17 2023-01-18         1381         193         8    73.75      0.29  418.9000
# 18 2023-01-19         1275         132         3    27.41      0.02   80.5854
# 19 2023-01-20         1558         185         5    65.86      0.28  237.0960
# 20 2023-01-21         1412         103         1    36.08      0.11   32.1112
# 21 2023-01-22         1746         145         4    34.34      0.19  111.2616
# 22 2023-01-23         1282         173         9    94.29      0.22  661.9158
# 24 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 26 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 27 2023-01-28         1402         186         5    44.42      0.03  215.4370
# 28 2023-01-29         1329         110         6    91.48      0.25  411.6600
# 29 2023-01-30         1658         117         4    18.16      0.26   53.7536
# 30 2023-01-31         1080         141         8    46.31      0.21  292.6792
# 32 2023-02-02         1652         117         2    21.34      0.16   35.8512
# 33 2023-02-03         1895         101         1    49.90      0.01   49.4010
# 35 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 36 2023-01-14         1850         197         2    10.88      0.14   18.7136
# 37 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   East    Credit Card       True              1            60
# 1          9  North    Credit Card       True              2            34
# 2          5   West    Credit Card      False              5            21
# 3          5  South    Credit Card      False              1            59
# 4          5   West    Credit Card      False              4            28
# 5          9  North    Credit Card      False              4            56
# 10         7   West         Online      False              4            32
# 12         3   East         Online      False              1            42
# 13         6   East           Cash       True              6            53
# 14         6  North    Credit Card       True              1            43
# 17         5   West           Cash      False              4            36
# 18         4  North           Cash       True              3            18
# 19         2  North           Cash      False              3            40
# 20         1   East           Cash      False              3            55
# 21         1   West         Online       True              4            55
# 22         8  South           Cash      False              5            44
# 24         1   West           Cash      False              3            67
# 26         4  South         Online       True              4            39
# 27         3   East           Cash      False              1            18
# 28         5  South    Credit Card       True              2            51
# 29         2   East         Online      False              3            61
# 30         8   East    Credit Card      False              2            47
# 32         5  North         Online       True              4            39
# 33         9   East    Credit Card      False              4            34
# 35         4  South         Online       True              4            39
# 36         6   East           Cash       True              6            53
# 37         1   West           Cash      False              3            67
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     2.4  Not Returned  Negative          17.52
# 1     Male      Electronics     4.7  Not Returned  Negative          14.13
# 2   Female            Books     2.9  Not Returned  Negative          11.43
# 3     Male         Clothing     4.3      Returned   Neutral            NaN
# 4    Other         Clothing     2.7      Returned   Neutral          12.17
# 5     Male      Electronics     3.7      Returned   Neutral          13.77
# 10   Other      Electronics     1.1  Not Returned  Negative            NaN
# 12   Other         Clothing     3.7      Returned  Positive            NaN
# 13    Male      Electronics     3.1      Returned  Negative            NaN
# 14    Male      Electronics     4.4      Returned   Neutral            NaN
# 17  Female         Clothing     3.8  Not Returned   Neutral           8.81
# 18   Other      Electronics     4.5  Not Returned  Negative          10.02
# 19  Female      Electronics     4.7  Not Returned  Negative           5.58
# 20   Other      Electronics     3.2  Not Returned   Neutral           7.33
# 21  Female            Books     1.9  Not Returned   Neutral          16.59
# 22  Female            Books     1.4  Not Returned  Negative           7.05
# 24  Female         Clothing     2.4      Returned   Neutral           5.99
# 26   Other         Clothing     4.6  Not Returned  Positive           5.66
# 27  Female            Books     3.4  Not Returned   Neutral          17.38
# 28   Other      Electronics     4.1      Returned  Positive           7.03
# 29    Male            Books     4.0      Returned  Negative          15.04
# 30   Other         Clothing     2.5      Returned   Neutral          12.81
# 32    Male      Electronics     2.3      Returned  Positive           6.20
# 33   Other         Clothing     2.6  Not Returned   Neutral          14.93
# 35   Other         Clothing     4.6  Not Returned  Positive           5.66
# 36    Male      Electronics     3.1      Returned  Negative            NaN
# 37  Female         Clothing     2.4      Returned   Neutral           5.99
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              4.5          1
# 1     FREESHIP              2.9          2
# 2     FREESHIP              NaN          3
# 3     WELCOME5              NaN          4
# 4     WELCOME5              4.5          5
# 5          nan              3.9          6
# 10         nan              2.9         11
# 12         nan              NaN         13
# 13    FREESHIP              1.7         14
# 14         nan              3.9         15
# 17    WELCOME5              4.4         18
# 18    WELCOME5              4.0         19
# 19      SAVE10              1.8         20
# 20         nan              NaN         21
# 21         nan              NaN         22
# 22    WELCOME5              3.8         23
# 24    FREESHIP              NaN         25
# 26         nan              NaN         27
# 27    FREESHIP              1.5         28
# 28         nan              3.1         29
# 29    WELCOME5              2.3         30
# 30    FREESHIP              NaN         31
# 32         nan              NaN         33
# 33         nan              NaN         34
# 35         nan              NaN         36
# 36    FREESHIP              1.7         37
# 37    FREESHIP              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                         rating is not a string type and will be skipped.
# Column                  return_status INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1279         184         3  9999.99      0.14  193.5258
# 1  2023-01-02         1885         182         8    36.32      0.01  287.6544
# 2  2023-01-03         1072         134         5    75.21      0.15  319.6425
# 3  2023-01-04         1399         163         1  8888.88      0.01   36.8379
# 4  2023-01-05         1939         139         6    10.64      0.28   45.9648
# 5  2023-01-06         1421         135         3  7777.77      0.17   92.4537
# 6  2023-01-07         1700         153         5    80.38      0.24  305.4440
# 7  2023-01-08         1160         136         8    25.97      0.11  184.9064
# 8  2023-01-09         1752         178         4    67.92      0.19  220.0608
# 9  2023-01-10         1878         158         3    92.33      0.28  199.4328
# 10 2023-01-11         1789         153         3    45.59      0.16  114.8868
# 11 2023-01-12         1773         199         7    83.30      0.19  472.3110
# 12 2023-01-13         1865         124         4    88.30      0.17  293.1560
# 13 2023-01-14         1850         197         2    10.88      0.14   18.7136
# 14 2023-01-15         1560         146         7    52.87      0.30  259.0630
# 15 2023-01-16         1932         158         3    99.16      0.08  273.6816
# 16 2023-01-17         1936         197         9    94.47      0.11  756.7047
# 17 2023-01-18         1381         193         8    73.75      0.29  418.9000
# 18 2023-01-19         1275         132         3    27.41      0.02   80.5854
# 19 2023-01-20         1558         185         5    65.86      0.28  237.0960
# 20 2023-01-21         1412         103         1    36.08      0.11   32.1112
# 21 2023-01-22         1746         145         4    34.34      0.19  111.2616
# 22 2023-01-23         1282         173         9    94.29      0.22  661.9158
# 23 2023-01-24         1027         116         7    76.31      0.21  421.9943
# 24 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 25 2023-01-26         1086         120         2    38.55      0.12   67.8480
# 26 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 27 2023-01-28         1402         186         5    44.42      0.03  215.4370
# 28 2023-01-29         1329         110         6    91.48      0.25  411.6600
# 29 2023-01-30         1658         117         4    18.16      0.26   53.7536
# 30 2023-01-31         1080         141         8    46.31      0.21  292.6792
# 31 2023-02-01         1068         104         8    28.46      0.23  175.3136
# 32 2023-02-02         1652         117         2    21.34      0.16   35.8512
# 33 2023-02-03         1895         101         1    49.90      0.01   49.4010
# 34 2023-02-04         1984         175         2    29.41      0.10   52.9380
# 35 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 36 2023-01-14         1850         197         2    10.88      0.14   18.7136
# 37 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   East    Credit Card       True              1            60
# 1          9  North    Credit Card       True              2            34
# 2          5   West    Credit Card      False              5            21
# 3          5  South    Credit Card      False              1            59
# 4          5   West    Credit Card      False              4            28
# 5          9  North    Credit Card      False              4            56
# 6          4  North    Credit Card       True              1            53
# 7          3   East    Credit Card       True              6            32
# 8          8  North           Cash      False              2            31
# 9          2  South    Credit Card      False              2            67
# 10         7   West         Online      False              4            32
# 11         1  North    Credit Card      False              2            18
# 12         3   East         Online      False              1            42
# 13         6   East           Cash       True              6            53
# 14         6  North    Credit Card       True              1            43
# 15         3   West           Cash      False              6            45
# 16         2   West         Online       True              4            30
# 17         5   West           Cash      False              4            36
# 18         4  North           Cash       True              3            18
# 19         2  North           Cash      False              3            40
# 20         1   East           Cash      False              3            55
# 21         1   West         Online       True              4            55
# 22         8  South           Cash      False              5            44
# 23         9   West    Credit Card      False              5            33
# 24         1   West           Cash      False              3            67
# 25         4   West           Cash      False              6            30
# 26         4  South         Online       True              4            39
# 27         3   East           Cash      False              1            18
# 28         5  South    Credit Card       True              2            51
# 29         2   East         Online      False              3            61
# 30         8   East    Credit Card      False              2            47
# 31         9  North    Credit Card      False              4            37
# 32         5  North         Online       True              4            39
# 33         9   East    Credit Card      False              4            34
# 34         7  South           Cash       True              6            49
# 35         4  South         Online       True              4            39
# 36         6   East           Cash       True              6            53
# 37         1   West           Cash      False              3            67
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     2.4  Not Returned  Negative          17.52
# 1     Male      Electronics     4.7  Not Returned  Negative          14.13
# 2   Female            Books     2.9  Not Returned  Negative          11.43
# 3     Male         Clothing     4.3      Returned   Neutral            NaN
# 4    Other         Clothing     2.7      Returned   Neutral          12.17
# 5     Male      Electronics     3.7      Returned   Neutral          13.77
# 6    Other             Food     2.6  Not Returned  Negative          11.85
# 7     Male             Food     4.3      Returned   Neutral          14.33
# 8   Female             Food     2.4  Not Returned  Positive           8.34
# 9   Female             Food     3.6  Not Returned   Neutral           9.22
# 10   Other      Electronics     1.1  Not Returned  Negative            NaN
# 11   Other             Food     4.4  Not Returned   Neutral            NaN
# 12   Other         Clothing     3.7      Returned  Positive            NaN
# 13    Male      Electronics     3.1      Returned  Negative            NaN
# 14    Male      Electronics     4.4      Returned   Neutral            NaN
# 15   Other             Food     3.9      Returned  Positive            NaN
# 16    Male             Food     4.9      Returned   Neutral           9.64
# 17  Female         Clothing     3.8  Not Returned   Neutral           8.81
# 18   Other      Electronics     4.5  Not Returned  Negative          10.02
# 19  Female      Electronics     4.7  Not Returned  Negative           5.58
# 20   Other      Electronics     3.2  Not Returned   Neutral           7.33
# 21  Female            Books     1.9  Not Returned   Neutral          16.59
# 22  Female            Books     1.4  Not Returned  Negative           7.05
# 23  Female             Food     1.8      Returned  Negative            NaN
# 24  Female         Clothing     2.4      Returned   Neutral           5.99
# 25  Female             Food     1.1      Returned  Negative            NaN
# 26   Other         Clothing     4.6  Not Returned  Positive           5.66
# 27  Female            Books     3.4  Not Returned   Neutral          17.38
# 28   Other      Electronics     4.1      Returned  Positive           7.03
# 29    Male            Books     4.0      Returned  Negative          15.04
# 30   Other         Clothing     2.5      Returned   Neutral          12.81
# 31    Male             Food     4.8  Not Returned   Neutral            NaN
# 32    Male      Electronics     2.3      Returned  Positive           6.20
# 33   Other         Clothing     2.6  Not Returned   Neutral          14.93
# 34  Female             Food     1.6      Returned  Positive          13.91
# 35   Other         Clothing     4.6  Not Returned  Positive           5.66
# 36    Male      Electronics     3.1      Returned  Negative            NaN
# 37  Female         Clothing     2.4      Returned   Neutral           5.99
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              4.5          1
# 1     FREESHIP              2.9          2
# 2     FREESHIP              NaN          3
# 3     WELCOME5              NaN          4
# 4     WELCOME5              4.5          5
# 5          nan              3.9          6
# 6     WELCOME5              2.3          7
# 7       SAVE10              1.4          8
# 8     FREESHIP              4.1          9
# 9     FREESHIP              1.2         10
# 10         nan              2.9         11
# 11    WELCOME5              NaN         12
# 12         nan              NaN         13
# 13    FREESHIP              1.7         14
# 14         nan              3.9         15
# 15         nan              2.2         16
# 16         nan              4.3         17
# 17    WELCOME5              4.4         18
# 18    WELCOME5              4.0         19
# 19      SAVE10              1.8         20
# 20         nan              NaN         21
# 21         nan              NaN         22
# 22    WELCOME5              3.8         23
# 23         nan              NaN         24
# 24    FREESHIP              NaN         25
# 25    FREESHIP              2.3         26
# 26         nan              NaN         27
# 27    FREESHIP              1.5         28
# 28         nan              3.1         29
# 29    WELCOME5              2.3         30
# 30    FREESHIP              NaN         31
# 31         nan              4.9         32
# 32         nan              NaN         33
# 33         nan              NaN         34
# 34    WELCOME5              4.3         35
# 35         nan              NaN         36
# 36    FREESHIP              1.7         37
# 37    FREESHIP              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                       feedback INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1279         184         3  9999.99      0.14  193.5258
# 1  2023-01-02         1885         182         8    36.32      0.01  287.6544
# 2  2023-01-03         1072         134         5    75.21      0.15  319.6425
# 3  2023-01-04         1399         163         1  8888.88      0.01   36.8379
# 4  2023-01-05         1939         139         6    10.64      0.28   45.9648
# 5  2023-01-06         1421         135         3  7777.77      0.17   92.4537
# 6  2023-01-07         1700         153         5    80.38      0.24  305.4440
# 7  2023-01-08         1160         136         8    25.97      0.11  184.9064
# 8  2023-01-09         1752         178         4    67.92      0.19  220.0608
# 9  2023-01-10         1878         158         3    92.33      0.28  199.4328
# 10 2023-01-11         1789         153         3    45.59      0.16  114.8868
# 11 2023-01-12         1773         199         7    83.30      0.19  472.3110
# 12 2023-01-13         1865         124         4    88.30      0.17  293.1560
# 13 2023-01-14         1850         197         2    10.88      0.14   18.7136
# 14 2023-01-15         1560         146         7    52.87      0.30  259.0630
# 15 2023-01-16         1932         158         3    99.16      0.08  273.6816
# 16 2023-01-17         1936         197         9    94.47      0.11  756.7047
# 17 2023-01-18         1381         193         8    73.75      0.29  418.9000
# 18 2023-01-19         1275         132         3    27.41      0.02   80.5854
# 19 2023-01-20         1558         185         5    65.86      0.28  237.0960
# 20 2023-01-21         1412         103         1    36.08      0.11   32.1112
# 21 2023-01-22         1746         145         4    34.34      0.19  111.2616
# 22 2023-01-23         1282         173         9    94.29      0.22  661.9158
# 23 2023-01-24         1027         116         7    76.31      0.21  421.9943
# 24 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 25 2023-01-26         1086         120         2    38.55      0.12   67.8480
# 26 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 27 2023-01-28         1402         186         5    44.42      0.03  215.4370
# 28 2023-01-29         1329         110         6    91.48      0.25  411.6600
# 29 2023-01-30         1658         117         4    18.16      0.26   53.7536
# 30 2023-01-31         1080         141         8    46.31      0.21  292.6792
# 31 2023-02-01         1068         104         8    28.46      0.23  175.3136
# 32 2023-02-02         1652         117         2    21.34      0.16   35.8512
# 33 2023-02-03         1895         101         1    49.90      0.01   49.4010
# 34 2023-02-04         1984         175         2    29.41      0.10   52.9380
# 35 2023-01-27         1800         141         8    41.73      0.01  330.5016
# 36 2023-01-14         1850         197         2    10.88      0.14   18.7136
# 37 2023-01-25         1885         157         7    22.08      0.01  153.0144
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   East    Credit Card       True              1            60
# 1          9  North    Credit Card       True              2            34
# 2          5   West    Credit Card      False              5            21
# 3          5  South    Credit Card      False              1            59
# 4          5   West    Credit Card      False              4            28
# 5          9  North    Credit Card      False              4            56
# 6          4  North    Credit Card       True              1            53
# 7          3   East    Credit Card       True              6            32
# 8          8  North           Cash      False              2            31
# 9          2  South    Credit Card      False              2            67
# 10         7   West         Online      False              4            32
# 11         1  North    Credit Card      False              2            18
# 12         3   East         Online      False              1            42
# 13         6   East           Cash       True              6            53
# 14         6  North    Credit Card       True              1            43
# 15         3   West           Cash      False              6            45
# 16         2   West         Online       True              4            30
# 17         5   West           Cash      False              4            36
# 18         4  North           Cash       True              3            18
# 19         2  North           Cash      False              3            40
# 20         1   East           Cash      False              3            55
# 21         1   West         Online       True              4            55
# 22         8  South           Cash      False              5            44
# 23         9   West    Credit Card      False              5            33
# 24         1   West           Cash      False              3            67
# 25         4   West           Cash      False              6            30
# 26         4  South         Online       True              4            39
# 27         3   East           Cash      False              1            18
# 28         5  South    Credit Card       True              2            51
# 29         2   East         Online      False              3            61
# 30         8   East    Credit Card      False              2            47
# 31         9  North    Credit Card      False              4            37
# 32         5  North         Online       True              4            39
# 33         9   East    Credit Card      False              4            34
# 34         7  South           Cash       True              6            49
# 35         4  South         Online       True              4            39
# 36         6   East           Cash       True              6            53
# 37         1   West           Cash      False              3            67
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     2.4  Not Returned  Negative          17.52
# 1     Male      Electronics     4.7  Not Returned  Negative          14.13
# 2   Female            Books     2.9  Not Returned  Negative          11.43
# 3     Male         Clothing     4.3      Returned   Neutral            NaN
# 4    Other         Clothing     2.7      Returned   Neutral          12.17
# 5     Male      Electronics     3.7      Returned   Neutral          13.77
# 6    Other             Food     2.6  Not Returned  Negative          11.85
# 7     Male             Food     4.3      Returned   Neutral          14.33
# 8   Female             Food     2.4  Not Returned  Positive           8.34
# 9   Female             Food     3.6  Not Returned   Neutral           9.22
# 10   Other      Electronics     1.1  Not Returned  Negative            NaN
# 11   Other             Food     4.4  Not Returned   Neutral            NaN
# 12   Other         Clothing     3.7      Returned  Positive            NaN
# 13    Male      Electronics     3.1      Returned  Negative            NaN
# 14    Male      Electronics     4.4      Returned   Neutral            NaN
# 15   Other             Food     3.9      Returned  Positive            NaN
# 16    Male             Food     4.9      Returned   Neutral           9.64
# 17  Female         Clothing     3.8  Not Returned   Neutral           8.81
# 18   Other      Electronics     4.5  Not Returned  Negative          10.02
# 19  Female      Electronics     4.7  Not Returned  Negative           5.58
# 20   Other      Electronics     3.2  Not Returned   Neutral           7.33
# 21  Female            Books     1.9  Not Returned   Neutral          16.59
# 22  Female            Books     1.4  Not Returned  Negative           7.05
# 23  Female             Food     1.8      Returned  Negative            NaN
# 24  Female         Clothing     2.4      Returned   Neutral           5.99
# 25  Female             Food     1.1      Returned  Negative            NaN
# 26   Other         Clothing     4.6  Not Returned  Positive           5.66
# 27  Female            Books     3.4  Not Returned   Neutral          17.38
# 28   Other      Electronics     4.1      Returned  Positive           7.03
# 29    Male            Books     4.0      Returned  Negative          15.04
# 30   Other         Clothing     2.5      Returned   Neutral          12.81
# 31    Male             Food     4.8  Not Returned   Neutral            NaN
# 32    Male      Electronics     2.3      Returned  Positive           6.20
# 33   Other         Clothing     2.6  Not Returned   Neutral          14.93
# 34  Female             Food     1.6      Returned  Positive          13.91
# 35   Other         Clothing     4.6  Not Returned  Positive           5.66
# 36    Male      Electronics     3.1      Returned  Negative            NaN
# 37  Female         Clothing     2.4      Returned   Neutral           5.99
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              4.5          1
# 1     FREESHIP              2.9          2
# 2     FREESHIP              NaN          3
# 3     WELCOME5              NaN          4
# 4     WELCOME5              4.5          5
# 5          nan              3.9          6
# 6     WELCOME5              2.3          7
# 7       SAVE10              1.4          8
# 8     FREESHIP              4.1          9
# 9     FREESHIP              1.2         10
# 10         nan              2.9         11
# 11    WELCOME5              NaN         12
# 12         nan              NaN         13
# 13    FREESHIP              1.7         14
# 14         nan              3.9         15
# 15         nan              2.2         16
# 16         nan              4.3         17
# 17    WELCOME5              4.4         18
# 18    WELCOME5              4.0         19
# 19      SAVE10              1.8         20
# 20         nan              NaN         21
# 21         nan              NaN         22
# 22    WELCOME5              3.8         23
# 23         nan              NaN         24
# 24    FREESHIP              NaN         25
# 25    FREESHIP              2.3         26
# 26         nan              NaN         27
# 27    FREESHIP              1.5         28
# 28         nan              3.1         29
# 29    WELCOME5              2.3         30
# 30    FREESHIP              NaN         31
# 31         nan              4.9         32
# 32         nan              NaN         33
# 33         nan              NaN         34
# 34    WELCOME5              4.3         35
# 35         nan              NaN         36
# 36    FREESHIP              1.7         37
# 37    FREESHIP              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                  shipping_cost is not a string type and will be skipped.
# Column                    coupon_code is not a string type and will be skipped.
# Column                delivery_rating is not a string type and will be skipped.
# Column                      unique_id is not a string type and will be skipped.

# %% [markdown]
# <div class="alert alert-warning">
#
# **12. Verifying Numeric Range in a DataFrame Column**
#
# **Write a Pandas program to verify numeric range in a DataFrame column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1752         154         9  9999.99      0.20  222.4080
# 1  2023-01-02         1602         142         1    82.89      0.26   61.3386
# 2  2023-01-03         1368         106         8    81.41      0.28  468.9216
# 3  2023-01-04         1624         142         8  8888.88      0.25   77.2800
# 4  2023-01-05         1052         152         8    82.71      0.08  608.7456
# 5  2023-01-06         1585         197         9  7777.77      0.03  739.5183
# 6  2023-01-07         1396         141         2    40.45      0.21   63.9110
# 7  2023-01-08         1157         195         7    11.65      0.13   70.9485
# 8  2023-01-09         1461         154         1    82.74      0.20   66.1920
# 9  2023-01-10         1010         169         1    12.60      0.12   11.0880
# 10 2023-01-11         1558         191         2    69.25      0.00  138.5000
# 11 2023-01-12         1123         113         8    45.20      0.20  289.2800
# 12 2023-01-13         1292         177         9    45.11      0.07  377.5707
# 13 2023-01-14         1086         187         9    48.48      0.13  379.5984
# 14 2023-01-15         1449         119         7    28.30      0.27  144.6130
# 15 2023-01-16         1486         137         1    37.03      0.18   30.3646
# 16 2023-01-17         1104         119         6    15.01      0.11   80.1534
# 17 2023-01-18         1412         185         1    82.24      0.13   71.5488
# 18 2023-01-19         1997         159         2    17.50      0.19   28.3500
# 19 2023-01-20         1443         169         6    34.28      0.12  180.9984
# 20 2023-01-21         1051         121         6    77.02      0.29  328.1052
# 21 2023-01-22         1708         126         2    97.63      0.25  146.4450
# 22 2023-01-23         1865         134         9    13.29      0.15  101.6685
# 23 2023-01-24         1665         115         4    24.76      0.15   84.1840
# 24 2023-01-25         1751         191         2    48.86      0.14   84.0392
# 25 2023-01-26         1029         121         4    55.33      0.19  179.2692
# 26 2023-01-27         1607         174         7    73.99      0.01  512.7507
# 27 2023-01-28         1684         198         2    40.36      0.01   79.9128
# 28 2023-01-29         1088         140         5    86.36      0.29  306.5780
# 29 2023-01-30         1160         110         4    20.15      0.11   71.7340
# 30 2023-01-31         1388         123         1    49.54      0.17   41.1182
# 31 2023-02-01         1145         179         3    68.12      0.08  188.0112
# 32 2023-02-02         1161         140         2    88.05      0.17  146.1630
# 33 2023-02-03         1703         131         8    93.24      0.07  693.7056
# 34 2023-02-04         1198         161         2    69.82      0.06  131.2616
# 35 2023-01-27         1607         174         7    73.99      0.01  512.7507
# 36 2023-01-14         1086         187         9    48.48      0.13  379.5984
# 37 2023-01-25         1751         191         2    48.86      0.14   84.0392
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          9   West         Online      False              3            36
# 1          6   East    Credit Card       True              5            63
# 2          9  South         Online      False              5            22
# 3          7   West         Online       True              1            49
# 4          7   West         Online       True              4            62
# 5          2   East           Cash       True              2            27
# 6          5   East         Online       True              4            47
# 7          2   East    Credit Card      False              3            67
# 8          8  South           Cash      False              2            51
# 9          9   West    Credit Card       True              3            66
# 10         1   West    Credit Card       True              5            28
# 11         4   East           Cash       True              1            54
# 12         3   West    Credit Card      False              1            69
# 13         5   East           Cash      False              4            65
# 14         9   West    Credit Card      False              4            42
# 15         2  North    Credit Card       True              4            27
# 16         1  North           Cash       True              4            30
# 17         2  South           Cash      False              2            68
# 18         2  North    Credit Card       True              2            31
# 19         3   East           Cash       True              3            25
# 20         7  North    Credit Card      False              1            28
# 21         5  North    Credit Card       True              6            25
# 22         3  South         Online       True              5            25
# 23         4   West           Cash       True              3            55
# 24         6   West    Credit Card      False              5            29
# 25         3   West         Online      False              1            51
# 26         9  South         Online      False              5            69
# 27         4  South    Credit Card      False              5            29
# 28         2   West    Credit Card       True              3            38
# 29         3  North         Online      False              4            46
# 30         2  South    Credit Card       True              2            59
# 31         8   East         Online      False              2            54
# 32         1  South    Credit Card      False              5            36
# 33         8  South           Cash      False              1            53
# 34         5   East    Credit Card       True              3            30
# 35         9  South         Online      False              5            69
# 36         5   East           Cash      False              4            65
# 37         6   West    Credit Card      False              5            29
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male             Food     2.9      Returned  Negative           5.13
# 1   Female      Electronics     2.0  Not Returned  Negative          16.00
# 2    Other            Books     3.3  Not Returned  Negative          14.48
# 3   Female         Clothing     3.6  Not Returned  Positive          13.99
# 4    Other            Books     2.4  Not Returned  Negative            NaN
# 5    Other      Electronics     4.6  Not Returned  Negative          19.79
# 6     Male         Clothing     4.0      Returned  Positive          16.29
# 7    Other      Electronics     4.9      Returned  Negative          19.02
# 8   Female      Electronics     1.4  Not Returned  Positive          11.06
# 9     Male      Electronics     3.5  Not Returned  Positive            NaN
# 10    Male         Clothing     1.4      Returned   Neutral          19.83
# 11    Male             Food     2.2      Returned   Neutral            NaN
# 12  Female             Food     3.5  Not Returned  Positive          10.76
# 13   Other             Food     3.7  Not Returned  Positive          17.33
# 14    Male             Food     4.8      Returned   Neutral           9.68
# 15  Female             Food     2.4  Not Returned  Negative          16.92
# 16   Other         Clothing     1.3      Returned  Positive           8.16
# 17  Female            Books     1.3      Returned  Negative          18.67
# 18   Other         Clothing     1.7  Not Returned  Negative           7.18
# 19   Other      Electronics     4.4  Not Returned   Neutral            NaN
# 20    Male      Electronics     3.0  Not Returned  Positive            NaN
# 21   Other            Books     1.4  Not Returned  Negative            NaN
# 22  Female         Clothing     1.0      Returned  Positive           9.06
# 23  Female      Electronics     1.2  Not Returned   Neutral          11.66
# 24    Male            Books     4.5      Returned   Neutral           5.70
# 25  Female         Clothing     4.6  Not Returned   Neutral          12.16
# 26  Female             Food     4.5  Not Returned   Neutral          11.69
# 27    Male            Books     3.2      Returned  Negative           5.09
# 28  Female             Food     2.9  Not Returned  Negative          18.32
# 29  Female      Electronics     2.4  Not Returned   Neutral            NaN
# 30    Male            Books     3.3  Not Returned  Negative           8.59
# 31   Other         Clothing     3.4      Returned   Neutral            NaN
# 32    Male             Food     4.7      Returned  Negative            NaN
# 33    Male             Food     2.1  Not Returned  Positive           6.32
# 34    Male         Clothing     2.7  Not Returned  Negative           5.46
# 35  Female             Food     4.5  Not Returned   Neutral          11.69
# 36   Other             Food     3.7  Not Returned  Positive          17.33
# 37    Male            Books     4.5      Returned   Neutral           5.70
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              4.2          1
# 1     WELCOME5              NaN          2
# 2     WELCOME5              3.3          3
# 3          nan              NaN          4
# 4     FREESHIP              3.4          5
# 5     WELCOME5              4.0          6
# 6     WELCOME5              2.7          7
# 7     FREESHIP              NaN          8
# 8          nan              NaN          9
# 9     FREESHIP              2.8         10
# 10    FREESHIP              4.9         11
# 11    WELCOME5              NaN         12
# 12      SAVE10              1.5         13
# 13         nan              2.8         14
# 14    FREESHIP              3.4         15
# 15    FREESHIP              NaN         16
# 16    FREESHIP              3.0         17
# 17    FREESHIP              NaN         18
# 18         nan              3.9         19
# 19    FREESHIP              NaN         20
# 20         nan              2.1         21
# 21    FREESHIP              4.6         22
# 22         nan              4.3         23
# 23    WELCOME5              4.2         24
# 24         nan              4.9         25
# 25    FREESHIP              NaN         26
# 26      SAVE10              4.6         27
# 27    FREESHIP              NaN         28
# 28         nan              NaN         29
# 29    WELCOME5              3.2         30
# 30      SAVE10              2.7         31
# 31    WELCOME5              1.8         32
# 32         nan              2.2         33
# 33         nan              NaN         34
# 34         nan              2.2         35
# 35      SAVE10              4.6         36
# 36         nan              2.8         37
# 37         nan              4.9         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 12:**
# </div>

# %%
# 12. Verifying Numeric Range in a DataFrame Column
# Write a Pandas program to verify numeric range in a DataFrame column.

def verify_numeric_range(dataframe, column_name, min_value, max_value):
    if not pd.api.types.is_numeric_dtype(dataframe[column_name]):
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        out_of_range = dataframe[(dataframe[column_name] < min_value) | (dataframe[column_name] > max_value)]
    if not out_of_range.empty:
        print("Column {:>30} OUT OF RANGE DETECTED.\n####### OUT OF RANGE #######".format(column_name))
        display(out_of_range)
    else:
        print("Column {:>30} has no out of range values detected.".format(column_name))

# Apply to price column only
verify_numeric_range(df, 'price', min_value=0, max_value=100)
# Out:
# Column                          price OUT OF RANGE DETECTED.
# ####### OUT OF RANGE #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1752         154         9  9999.99      0.20  222.4080
# 3  2023-01-04         1624         142         8  8888.88      0.25   77.2800
# 5  2023-01-06         1585         197         9  7777.77      0.03  739.5183
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          9   West         Online      False              3            36
# 3          7   West         Online       True              1            49
# 5          2   East           Cash       True              2            27
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male             Food     2.9      Returned  Negative           5.13
# 3   Female         Clothing     3.6  Not Returned  Positive          13.99
# 5    Other      Electronics     4.6  Not Returned  Negative          19.79
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              4.2          1
# 3          nan              NaN          4
# 5     WELCOME5              4.0          6
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-warning">
#
# **13. Validating the Format of Email Addresses**
#
# **Write a Pandas program that validates the format of email addresses.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# add emails
df['email'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, 'customer' + df['customer_id'].astype(str) + '@example.com')
df.loc[0, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[10, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[20, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df['email'] = df['email'].fillna('onemore-invalid_email')


# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1756         123         7  9999.99      0.04  587.9328
# 1  2023-01-02         1121         197         9    57.26      0.14  443.1924
# 2  2023-01-03         1670         161         7    40.67      0.09  259.0679
# 3  2023-01-04         1093         198         3  8888.88      0.16  161.0784
# 4  2023-01-05         1536         116         7    99.52      0.26  515.5136
# 5  2023-01-06         1883         174         5  7777.77      0.12  270.1160
# 6  2023-01-07         1623         123         7    70.25      0.17  408.1525
# 7  2023-01-08         1368         175         5    64.25      0.08  295.5500
# 8  2023-01-09         1678         150         4    39.19      0.17  130.1108
# 9  2023-01-10         1585         180         5    46.81      0.24  177.8780
# 10 2023-01-11         1375         118         9    69.63      0.07  582.8031
# 11 2023-01-12         1234         183         2    87.78      0.04  168.5376
# 12 2023-01-13         1914         115         1    22.15      0.18   18.1630
# 13 2023-01-14         1092         195         1    82.91      0.29   58.8661
# 14 2023-01-15         1945         198         4    70.34      0.23  216.6472
# 15 2023-01-16         1782         158         5    80.37      0.29  285.3135
# 16 2023-01-17         1735         139         5    28.41      0.04  136.3680
# 17 2023-01-18         1034         133         3    32.93      0.04   94.8384
# 18 2023-01-19         1277         106         4    62.56      0.02  245.2352
# 19 2023-01-20         1620         150         8    72.73      0.22  453.8352
# 20 2023-01-21         1145         192         8    53.16      0.07  395.5104
# 21 2023-01-22         1082         108         4    95.34      0.25  286.0200
# 22 2023-01-23         1247         147         7    57.65      0.07  375.3015
# 23 2023-01-24         1652         109         2    72.92      0.09  132.7144
# 24 2023-01-25         1711         106         2    96.06      0.13  167.1444
# 25 2023-01-26         1684         199         1    47.44      0.00   47.4400
# 26 2023-01-27         1359         145         7    89.18      0.20  499.4080
# 27 2023-01-28         1260         182         8    14.33      0.23   88.2728
# 28 2023-01-29         1647         104         2    26.31      0.11   46.8318
# 29 2023-01-30         1802         189         4    84.55      0.07  314.5260
# 30 2023-01-31         1120         138         9    38.86      0.24  265.8024
# 31 2023-02-01         1592         192         2    14.53      0.08   26.7352
# 32 2023-02-02         1544         135         6    70.02      0.09  382.3092
# 33 2023-02-03         1563         122         9    56.13      0.21  399.0843
# 34 2023-02-04         1654         185         5    52.37      0.25  196.3875
# 35 2023-01-27         1359         145         7    89.18      0.20  499.4080
# 36 2023-01-14         1092         195         1    82.91      0.29   58.8661
# 37 2023-01-25         1711         106         2    96.06      0.13  167.1444
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6  North           Cash       True              3            36
# 1          4   East    Credit Card       True              3            56
# 2          1  South         Online       True              1            60
# 3          6   East         Online      False              1            41
# 4          9   West         Online      False              1            38
# 5          2   West         Online       True              1            25
# 6          1  South         Online       True              5            26
# 7          3  South    Credit Card      False              1            57
# 8          5   East         Online       True              4            29
# 9          3   East    Credit Card      False              1            56
# 10         3  North    Credit Card       True              3            33
# 11         4  North           Cash      False              2            52
# 12         2   East           Cash      False              2            61
# 13         5  South    Credit Card      False              1            46
# 14         6   East    Credit Card       True              2            40
# 15         9  South           Cash      False              4            31
# 16         8   East         Online      False              2            48
# 17         9   East           Cash       True              5            37
# 18         2   East           Cash      False              5            65
# 19         1  South         Online       True              1            69
# 20         6  South    Credit Card      False              1            49
# 21         6   West    Credit Card       True              1            60
# 22         1  South           Cash       True              3            49
# 23         5  South           Cash      False              4            59
# 24         4   West           Cash      False              2            22
# 25         7   East    Credit Card       True              4            68
# 26         9  South         Online       True              4            69
# 27         8   East         Online       True              3            68
# 28         1   East         Online      False              6            37
# 29         8   East    Credit Card      False              1            41
# 30         8  North           Cash      False              4            25
# 31         7   West         Online       True              2            24
# 32         9   West           Cash      False              2            41
# 33         3  South    Credit Card       True              4            25
# 34         7  South         Online       True              6            66
# 35         9  South         Online       True              4            69
# 36         5  South    Credit Card      False              1            46
# 37         4   West           Cash      False              2            22
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male      Electronics     1.3  Not Returned   Neutral          17.91
# 1   Female      Electronics     2.8      Returned   Neutral          11.75
# 2     Male      Electronics     4.5      Returned  Negative           6.90
# 3   Female      Electronics     2.1      Returned   Neutral          19.97
# 4     Male            Books     4.9      Returned   Neutral          13.94
# 5   Female         Clothing     2.3      Returned  Positive          10.48
# 6     Male         Clothing     4.9  Not Returned   Neutral           7.86
# 7     Male         Clothing     1.1      Returned  Negative           9.47
# 8   Female      Electronics     4.3  Not Returned   Neutral          14.48
# 9   Female             Food     3.3  Not Returned  Positive            NaN
# 10  Female         Clothing     3.6  Not Returned  Negative          12.30
# 11  Female             Food     3.2      Returned   Neutral            NaN
# 12   Other         Clothing     4.0  Not Returned  Positive          19.10
# 13  Female             Food     4.7  Not Returned  Positive          14.85
# 14   Other            Books     2.0  Not Returned   Neutral          14.04
# 15  Female            Books     2.8      Returned   Neutral          19.44
# 16   Other      Electronics     1.7  Not Returned  Positive          14.08
# 17  Female            Books     4.1      Returned  Positive          13.43
# 18  Female             Food     4.1      Returned  Negative          14.79
# 19  Female      Electronics     1.4      Returned  Positive          14.20
# 20  Female      Electronics     1.2      Returned   Neutral          11.72
# 21    Male      Electronics     4.3  Not Returned  Negative           6.83
# 22   Other             Food     1.2      Returned   Neutral          16.44
# 23  Female            Books     4.5  Not Returned   Neutral           8.28
# 24  Female      Electronics     3.6  Not Returned  Negative          17.63
# 25    Male             Food     3.3      Returned  Negative          15.16
# 26  Female            Books     2.1  Not Returned  Negative          10.55
# 27    Male             Food     1.3  Not Returned   Neutral          18.71
# 28    Male         Clothing     1.5  Not Returned  Positive           7.11
# 29    Male      Electronics     3.8  Not Returned  Negative          18.82
# 30  Female      Electronics     3.3  Not Returned   Neutral            NaN
# 31   Other      Electronics     1.5      Returned  Positive          16.32
# 32  Female      Electronics     2.1  Not Returned   Neutral           5.53
# 33  Female            Books     2.3  Not Returned   Neutral           6.86
# 34  Female             Food     2.8  Not Returned  Positive           8.79
# 35  Female            Books     2.1  Not Returned  Negative          10.55
# 36  Female             Food     4.7  Not Returned  Positive          14.85
# 37  Female      Electronics     3.6  Not Returned  Negative          17.63
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id                     email
# 0     WELCOME5              2.8          1      invalid-email-format
# 1          nan              1.6          2  customer1121@example.com
# 2     FREESHIP              4.9          3  customer1670@example.com
# 3       SAVE10              3.2          4  customer1093@example.com
# 4     FREESHIP              NaN          5  customer1536@example.com
# 5       SAVE10              1.2          6     onemore-invalid_email
# 6     WELCOME5              2.1          7  customer1623@example.com
# 7          nan              2.3          8  customer1368@example.com
# 8       SAVE10              NaN          9  customer1678@example.com
# 9          nan              3.0         10  customer1585@example.com
# 10         nan              NaN         11      invalid-email-format
# 11    FREESHIP              NaN         12  customer1234@example.com
# 12      SAVE10              NaN         13     onemore-invalid_email
# 13    WELCOME5              1.1         14  customer1092@example.com
# 14         nan              3.6         15     onemore-invalid_email
# 15    FREESHIP              2.8         16  customer1782@example.com
# 16    FREESHIP              2.3         17     onemore-invalid_email
# 17    FREESHIP              3.6         18  customer1034@example.com
# 18    FREESHIP              3.1         19  customer1277@example.com
# 19    FREESHIP              4.6         20  customer1620@example.com
# 20         nan              1.6         21      invalid-email-format
# 21         nan              1.6         22  customer1082@example.com
# 22    WELCOME5              1.8         23  customer1247@example.com
# 23         nan              4.3         24  customer1652@example.com
# 24      SAVE10              3.2         25  customer1711@example.com
# 25    FREESHIP              3.3         26  customer1684@example.com
# 26      SAVE10              NaN         27  customer1359@example.com
# 27    FREESHIP              3.4         28  customer1260@example.com
# 28         nan              2.5         29  customer1647@example.com
# 29         nan              2.4         30  customer1802@example.com
# 30      SAVE10              2.2         31     onemore-invalid_email
# 31      SAVE10              1.7         32     onemore-invalid_email
# 32      SAVE10              2.4         33  customer1544@example.com
# 33         nan              1.7         34  customer1563@example.com
# 34         nan              4.2         35  customer1654@example.com
# 35      SAVE10              NaN         36  customer1359@example.com
# 36    WELCOME5              1.1         37  customer1092@example.com
# 37      SAVE10              3.2         38  customer1711@example.com
# 38         NaN              NaN         39  customer1500@example.com
# 39         NaN              NaN         40  customer1501@example.com
# 40         NaN              NaN         41  customer1502@example.com

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 13:**
# </div>

# %%
# 13. Validating the Format of Email Addresses
# Write a Pandas program that validates the format of email addresses.

# Validate email format using a regular expression
valid_emails = df['email'].str.contains(r'^[\w\.-]+@[\w\.-]+\.\w+$')

# Output the result
df[~valid_emails].loc[:, ['email']]
# Out:
#                     email
# 0    invalid-email-format
# 5   onemore-invalid_email
# 10   invalid-email-format
# 12  onemore-invalid_email
# 14  onemore-invalid_email
# 16  onemore-invalid_email
# 20   invalid-email-format
# 30  onemore-invalid_email
# 31  onemore-invalid_email

# %% [markdown]
# <div class="alert alert-warning">
#
# **14. Checking Consistent Date Order in a Column**
#
# **Write a Pandas program to check consistent date order in a column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# add emails
df['email'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, 'customer' + df['customer_id'].astype(str) + '@example.com')
df.loc[0, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[10, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[20, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df['email'] = df['email'].fillna('onemore-invalid_email')


# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1817         178         4  9999.99      0.06  269.5920
# 1  2023-01-02         1568         153         6    61.42      0.25  276.3900
# 2  2023-01-03         1779         198         9    46.02      0.22  323.0604
# 3  2023-01-04         1235         192         2  8888.88      0.19  137.8782
# 4  2023-01-05         1599         128         4    82.23      0.01  325.6308
# 5  2023-01-06         1942         161         9  7777.77      0.29  100.2591
# 6  2023-01-07         1251         106         8    38.02      0.26  225.0784
# 7  2023-01-08         1238         185         7    58.85      0.14  354.2770
# 8  2023-01-09         1142         144         9    36.51      0.18  269.4438
# 9  2023-01-10         1177         127         5    76.38      0.09  347.5290
# 10 2023-01-11         1914         155         4    87.63      0.07  325.9836
# 11 2023-01-12         1545         160         9    12.56      0.14   97.2144
# 12 2023-01-13         1695         112         9    75.10      0.29  479.8890
# 13 2023-01-14         1977         136         5    73.84      0.01  365.5080
# 14 2023-01-15         1854         149         6    12.67      0.12   66.8976
# 15 2023-01-16         1578         184         8    66.71      0.24  405.5968
# 16 2023-01-17         1848         125         7    94.57      0.20  529.5920
# 17 2023-01-18         1578         143         5    33.59      0.08  154.5140
# 18 2023-01-19         1680         128         5    90.18      0.22  351.7020
# 19 2023-01-20         1401         154         3    19.16      0.01   56.9052
# 20 2023-01-21         1748         110         4    62.09      0.21  196.2044
# 21 2023-01-22         1563         175         9    78.67      0.22  552.2634
# 22 2023-01-23         1582         139         6    99.28      0.20  476.5440
# 23 2023-01-24         1209         106         2    80.12      0.16  134.6016
# 24 2023-01-25         1051         143         1    87.21      0.29   61.9191
# 25 2023-01-26         1858         138         3    32.12      0.26   71.3064
# 26 2023-01-27         1632         174         5    33.32      0.02  163.2680
# 27 2023-01-28         1280         127         1    80.38      0.03   77.9686
# 28 2023-01-29         1714         187         4    30.22      0.25   90.6600
# 29 2023-01-30         1012         173         3    78.75      0.21  186.6375
# 30 2023-01-31         1073         145         8    99.11      0.01  784.9512
# 31 2023-02-01         1373         163         7    98.89      0.26  512.2502
# 32 2023-02-02         1161         177         3    58.80      0.03  171.1080
# 33 2023-02-03         1481         165         4    48.28      0.24  146.7712
# 34 2023-02-04         1512         109         3    65.36      0.25  147.0600
# 35 2023-01-27         1632         174         5    33.32      0.02  163.2680
# 36 2023-01-14         1977         136         5    73.84      0.01  365.5080
# 37 2023-01-25         1051         143         1    87.21      0.29   61.9191
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          2   East    Credit Card       True              5            33
# 1          1  South         Online      False              4            41
# 2          6   East    Credit Card       True              3            25
# 3          7  South    Credit Card      False              2            37
# 4          3  North    Credit Card      False              2            66
# 5          3   East    Credit Card       True              2            62
# 6          9  South    Credit Card      False              1            49
# 7          2   West         Online      False              2            53
# 8          5   East           Cash      False              1            51
# 9          9  South    Credit Card      False              1            26
# 10         8  North    Credit Card      False              5            69
# 11         4  South    Credit Card      False              6            44
# 12         9  North         Online       True              3            36
# 13         4  South           Cash       True              4            50
# 14         6  South           Cash      False              5            25
# 15         1  South         Online       True              5            25
# 16         8   West         Online       True              6            54
# 17         6   East           Cash       True              5            22
# 18         9   East           Cash       True              5            62
# 19         1   West           Cash      False              1            64
# 20         7  South         Online       True              2            25
# 21         3  South         Online      False              4            45
# 22         8  North         Online      False              5            29
# 23         7   East         Online      False              6            37
# 24         7   East         Online      False              4            24
# 25         3   West    Credit Card       True              5            58
# 26         9  South         Online       True              5            47
# 27         9   East    Credit Card      False              2            50
# 28         1   West    Credit Card      False              5            47
# 29         5  North         Online       True              6            42
# 30         9  North    Credit Card       True              1            35
# 31         3  North           Cash      False              3            52
# 32         7   East         Online       True              1            59
# 33         1  North           Cash      False              3            50
# 34         9   East    Credit Card       True              4            58
# 35         9  South         Online       True              5            47
# 36         4  South           Cash       True              4            50
# 37         7   East         Online      False              4            24
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male         Clothing     4.7      Returned  Positive          13.29
# 1     Male      Electronics     1.7  Not Returned   Neutral           8.15
# 2     Male      Electronics     2.7  Not Returned  Negative            NaN
# 3    Other         Clothing     4.7      Returned  Negative          14.51
# 4    Other         Clothing     4.1      Returned  Negative          11.11
# 5     Male      Electronics     2.0      Returned  Negative           8.38
# 6     Male         Clothing     4.4  Not Returned   Neutral          15.72
# 7   Female            Books     4.8  Not Returned  Positive          13.95
# 8    Other            Books     3.8      Returned  Negative           8.36
# 9    Other            Books     3.0  Not Returned   Neutral           7.41
# 10   Other         Clothing     3.0  Not Returned   Neutral           7.60
# 11  Female             Food     2.2      Returned  Positive          14.17
# 12  Female            Books     4.8  Not Returned  Negative            NaN
# 13    Male            Books     1.3      Returned  Negative            NaN
# 14   Other         Clothing     4.5      Returned  Negative          19.29
# 15    Male             Food     3.2  Not Returned  Negative          12.07
# 16   Other      Electronics     1.2      Returned  Positive           5.91
# 17   Other            Books     1.9      Returned  Positive            NaN
# 18  Female             Food     2.8  Not Returned  Negative          16.62
# 19  Female            Books     1.8      Returned   Neutral           9.56
# 20  Female         Clothing     4.4  Not Returned  Negative          18.45
# 21  Female      Electronics     3.0      Returned   Neutral          19.22
# 22    Male         Clothing     1.9  Not Returned  Negative           9.67
# 23   Other             Food     2.9  Not Returned  Negative            NaN
# 24    Male      Electronics     3.8      Returned  Negative          16.69
# 25    Male         Clothing     3.2  Not Returned   Neutral            NaN
# 26    Male         Clothing     1.5  Not Returned  Negative          19.93
# 27   Other            Books     3.1  Not Returned  Positive          16.88
# 28    Male         Clothing     4.9  Not Returned  Negative           8.06
# 29  Female            Books     3.0  Not Returned  Positive          13.13
# 30   Other            Books     2.2  Not Returned  Negative          15.85
# 31    Male      Electronics     2.1  Not Returned  Negative           9.34
# 32   Other             Food     2.4      Returned  Positive          15.55
# 33   Other            Books     4.9  Not Returned   Neutral            NaN
# 34   Other            Books     1.0      Returned  Positive          16.82
# 35    Male         Clothing     1.5  Not Returned  Negative          19.93
# 36    Male            Books     1.3      Returned  Negative            NaN
# 37    Male      Electronics     3.8      Returned  Negative          16.69
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id                     email
# 0       SAVE10              2.9          1      invalid-email-format
# 1     WELCOME5              4.4          2  customer1568@example.com
# 2          nan              2.6          3  customer1779@example.com
# 3     FREESHIP              4.1          4  customer1235@example.com
# 4          nan              2.7          5     onemore-invalid_email
# 5       SAVE10              NaN          6  customer1942@example.com
# 6     FREESHIP              1.7          7  customer1251@example.com
# 7          nan              3.5          8  customer1238@example.com
# 8          nan              4.2          9  customer1142@example.com
# 9     FREESHIP              2.3         10  customer1177@example.com
# 10         nan              1.2         11      invalid-email-format
# 11      SAVE10              2.7         12  customer1545@example.com
# 12         nan              1.0         13  customer1695@example.com
# 13         nan              3.5         14  customer1977@example.com
# 14         nan              1.6         15     onemore-invalid_email
# 15    WELCOME5              2.7         16     onemore-invalid_email
# 16    WELCOME5              1.4         17  customer1848@example.com
# 17         nan              1.7         18  customer1578@example.com
# 18         nan              3.2         19  customer1680@example.com
# 19         nan              2.4         20  customer1401@example.com
# 20         nan              2.4         21      invalid-email-format
# 21         nan              NaN         22  customer1563@example.com
# 22    FREESHIP              1.8         23  customer1582@example.com
# 23         nan              1.6         24     onemore-invalid_email
# 24      SAVE10              2.2         25  customer1051@example.com
# 25    WELCOME5              3.0         26  customer1858@example.com
# 26         nan              2.9         27  customer1632@example.com
# 27      SAVE10              NaN         28  customer1280@example.com
# 28         nan              4.9         29  customer1714@example.com
# 29         nan              NaN         30  customer1012@example.com
# 30    WELCOME5              NaN         31  customer1073@example.com
# 31      SAVE10              4.0         32  customer1373@example.com
# 32    FREESHIP              2.1         33  customer1161@example.com
# 33    WELCOME5              3.3         34  customer1481@example.com
# 34    FREESHIP              2.4         35  customer1512@example.com
# 35         nan              2.9         36  customer1632@example.com
# 36         nan              3.5         37  customer1977@example.com
# 37      SAVE10              2.2         38  customer1051@example.com
# 38         NaN              NaN         39  customer1500@example.com
# 39         NaN              NaN         40  customer1501@example.com
# 40         NaN              NaN         41  customer1502@example.com

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 14:**
# </div>

# %%
# 14. Checking Consistent Date Order in a Column
# Write a Pandas program to check consistent date order in a column.

# Check if dates are in consistent order
is_consistent = df['date'].is_monotonic_increasing

# Output the result
is_consistent

print(f"Dates in chronological order: {is_consistent}")
# Out:
# Dates in chronological order: False
