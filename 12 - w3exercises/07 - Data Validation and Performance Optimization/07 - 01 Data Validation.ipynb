# %% [markdown]
# [Pandas Data Validation](https://www.w3resource.com/python-exercises/pandas/pandas-data-validation.php)

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# <div class="alert alert-warning">
#
# **1. Checking Missing Values in a DataFrame**
#
# **Write a Pandas program to check for missing values in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1189         172         6  62.65      0.04  360.8640
# 1  2023-01-02         1290         163         8  49.22      0.11  350.4464
# 2  2023-01-03         1822         166         8  64.10      0.20  410.2400
# 3  2023-01-04         1498         183         1  23.58      0.12   20.7504
# 4  2023-01-05         1611         138         1  91.52      0.14   78.7072
# 5  2023-01-06         1536         192         4  25.42      0.01  100.6632
# 6  2023-01-07         1633         151         1  84.19      0.22   65.6682
# 7  2023-01-08         1046         139         1  21.42      0.25   16.0650
# 8  2023-01-09         1625         129         2  55.80      0.10  100.4400
# 9  2023-01-10         1153         135         3  41.29      0.12  109.0056
# 10 2023-01-11         1491         181         3  56.59      0.05  161.2815
# 11 2023-01-12         1137         144         4  27.29      0.12   96.0608
# 12 2023-01-13         1351         128         6  42.40      0.29  180.6240
# 13 2023-01-14         1629         124         4  35.76      0.07  133.0272
# 14 2023-01-15         1985         184         3  52.59      0.11  140.4153
# 15 2023-01-16         1467         110         9  47.41      0.30  298.6830
# 16 2023-01-17         1077         158         9  16.71      0.00  150.3900
# 17 2023-01-18         1606         138         9  96.89      0.01  863.2899
# 18 2023-01-19         1938         136         7  58.85      0.11  366.6355
# 19 2023-01-20         1052         102         6  34.95      0.04  201.3120
# 20 2023-01-21         1897         130         4  39.02      0.08  143.5936
# 21 2023-01-22         1393         164         6  43.49      0.16  219.1896
# 22 2023-01-23         1321         175         4  47.42      0.28  136.5696
# 23 2023-01-24         1595         162         9  27.65      0.01  246.3615
# 24 2023-01-25         1239         100         2  19.77      0.10   35.5860
# 25 2023-01-26         1950         146         3  58.61      0.11  156.4887
# 26 2023-01-27         1017         126         9  12.58      0.19   91.7082
# 27 2023-01-28         1665         115         3  82.76      0.28  178.7616
# 28 2023-01-29         1799         146         6  54.43      0.19  264.5298
# 29 2023-01-30         1183         102         8  95.17      0.27  555.7928
# 30 2023-01-31         1536         151         6  20.28      0.20   97.3440
# 31 2023-02-01         1482         112         7  61.37      0.14  369.4474
# 32 2023-02-02         1629         187         3  11.90      0.10   32.1300
# 33 2023-02-03         1470         103         9  75.74      0.08  627.1272
# 34 2023-02-04         1167         162         7  47.62      0.04  320.0064
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   West           Cash       True              4            69
# 1          3   East    Credit Card      False              1            34
# 2          2  North         Online      False              2            34
# 3          4   East         Online      False              3            24
# 4          1   East    Credit Card      False              3            34
# 5          5   East         Online      False              2            27
# 6          7   East           Cash       True              2            31
# 7          4   West           Cash      False              1            57
# 8          3   East    Credit Card      False              2            46
# 9          3   East         Online      False              2            50
# 10         8  North           Cash      False              2            21
# 11         7   East           Cash       True              3            43
# 12         1   East    Credit Card       True              2            19
# 13         9  North    Credit Card      False              2            35
# 14         1   East    Credit Card      False              1            60
# 15         1  North           Cash       True              5            37
# 16         9   West           Cash      False              4            49
# 17         3  South    Credit Card      False              5            35
# 18         2   West    Credit Card       True              5            52
# 19         6  North    Credit Card      False              6            52
# 20         8   East           Cash      False              5            22
# 21         3   West           Cash       True              6            43
# 22         4  South         Online      False              3            63
# 23         4  South           Cash      False              2            43
# 24         1   East           Cash      False              4            64
# 25         1   East           Cash       True              2            67
# 26         9  North         Online      False              2            30
# 27         3   East    Credit Card       True              2            63
# 28         6   East         Online      False              4            22
# 29         6   West    Credit Card       True              3            41
# 30         6   East           Cash      False              2            46
# 31         7  South         Online       True              1            43
# 32         2   East         Online      False              3            40
# 33         4   East         Online       True              6            21
# 34         3   East    Credit Card       True              5            50
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female         Clothing     1.3      Returned  Negative          19.44
# 1   Female            Books     4.9  Not Returned  Positive          11.07
# 2    Other      Electronics     3.2  Not Returned   Neutral          16.02
# 3    Other         Clothing     4.1      Returned  Positive            NaN
# 4   Female      Electronics     4.8  Not Returned  Positive          17.43
# 5   Female            Books     3.2      Returned   Neutral          16.43
# 6    Other         Clothing     3.6  Not Returned  Negative           7.79
# 7    Other         Clothing     3.3      Returned   Neutral          12.52
# 8     Male         Clothing     3.8  Not Returned  Positive          18.46
# 9    Other             Food     1.1  Not Returned  Positive            NaN
# 10  Female         Clothing     3.3      Returned  Positive           7.12
# 11    Male             Food     4.9  Not Returned  Positive          19.48
# 12    Male         Clothing     3.0  Not Returned   Neutral           7.84
# 13    Male         Clothing     3.9      Returned  Positive           7.16
# 14    Male      Electronics     1.4      Returned  Negative          10.82
# 15    Male      Electronics     3.6  Not Returned   Neutral           9.08
# 16   Other            Books     2.4      Returned  Negative            NaN
# 17   Other            Books     2.3  Not Returned  Negative          13.99
# 18    Male         Clothing     2.6  Not Returned  Negative          11.77
# 19  Female            Books     4.3  Not Returned   Neutral           6.89
# 20   Other             Food     4.4  Not Returned  Positive          14.48
# 21  Female            Books     3.0      Returned   Neutral           7.81
# 22    Male             Food     1.3      Returned  Negative            NaN
# 23  Female             Food     4.3      Returned  Positive            NaN
# 24   Other      Electronics     3.0  Not Returned  Positive          13.02
# 25    Male         Clothing     5.0  Not Returned   Neutral           6.70
# 26  Female         Clothing     3.7  Not Returned  Positive          19.93
# 27  Female      Electronics     2.9      Returned  Negative           6.03
# 28  Female      Electronics     2.8      Returned  Negative          17.05
# 29   Other      Electronics     4.0      Returned  Negative            NaN
# 30    Male      Electronics     3.9  Not Returned  Positive          14.47
# 31    Male             Food     2.9      Returned  Positive          16.45
# 32  Female      Electronics     2.2      Returned  Negative          18.78
# 33    Male         Clothing     4.3      Returned  Negative          13.25
# 34   Other         Clothing     2.6      Returned  Positive          18.82
#
#    coupon_code  delivery_rating
# 0          nan              4.4
# 1       SAVE10              3.9
# 2          nan              2.6
# 3          nan              2.2
# 4     FREESHIP              2.1
# 5          nan              1.6
# 6     FREESHIP              NaN
# 7          nan              3.4
# 8     FREESHIP              4.2
# 9          nan              NaN
# 10         nan              3.6
# 11         nan              3.0
# 12    FREESHIP              NaN
# 13         nan              3.9
# 14    FREESHIP              4.2
# 15    FREESHIP              NaN
# 16    FREESHIP              1.1
# 17      SAVE10              1.0
# 18    WELCOME5              3.1
# 19    FREESHIP              4.5
# 20         nan              NaN
# 21    FREESHIP              NaN
# 22    FREESHIP              4.0
# 23    FREESHIP              NaN
# 24    FREESHIP              1.5
# 25    WELCOME5              NaN
# 26         nan              NaN
# 27    FREESHIP              NaN
# 28      SAVE10              1.3
# 29         nan              1.3
# 30    WELCOME5              1.9
# 31         nan              2.2
# 32         nan              1.2
# 33         nan              3.7
# 34    WELCOME5              3.3

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
# 1. Checking Missing Values in a DataFrame
# Write a Pandas program to check for missing values in a DataFrame.

# Check for missing values
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# shipping_cost       6
# delivery_rating    10
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **2. Ensuring Consistent Data Types of All Columns**
#
# **Write a Pandas program to check and ensure that the data types of all columns are consistent.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1462         160         4  83.23      0.24  253.0192
# 1  2023-01-02         1986         155         4  24.48      0.07   91.0656
# 2  2023-01-03         1764         135         3  87.12      0.08  240.4512
# 3  2023-01-04         1251         106         7  92.08      0.15  547.8760
# 4  2023-01-05         1064         159         9  85.36      0.19  622.2744
# 5  2023-01-06         1110         122         4  87.57      0.00  350.2800
# 6  2023-01-07         1123         199         4  20.62      0.29   58.5608
# 7  2023-01-08         1746         147         7  40.25      0.10  253.5750
# 8  2023-01-09         1598         168         1  96.10      0.07   89.3730
# 9  2023-01-10         1497         102         6  88.64      0.14  457.3824
# 10 2023-01-11         1295         116         8  33.23      0.03  257.8648
# 11 2023-01-12         1470         102         1  73.77      0.24   56.0652
# 12 2023-01-13         1087         157         9  11.51      0.01  102.5541
# 13 2023-01-14         1709         142         7  26.21      0.29  130.2637
# 14 2023-01-15         1845         164         9  33.02      0.23  228.8286
# 15 2023-01-16         1779         131         7  35.75      0.13  217.7175
# 16 2023-01-17         1380         112         9  56.04      0.06  474.0984
# 17 2023-01-18         1227         180         8  32.28      0.27  188.5152
# 18 2023-01-19         1391         124         6  19.65      0.30   82.5300
# 19 2023-01-20         1291         191         2  57.19      0.25   85.7850
# 20 2023-01-21         1628         138         3  14.37      0.03   41.8167
# 21 2023-01-22         1120         125         9  38.19      0.13  299.0277
# 22 2023-01-23         1336         105         2  63.61      0.17  105.5926
# 23 2023-01-24         1229         160         4  82.66      0.24  251.2864
# 24 2023-01-25         1247         198         1  61.27      0.01   60.6573
# 25 2023-01-26         1536         182         1  96.66      0.29   68.6286
# 26 2023-01-27         1087         160         2  78.87      0.01  156.1626
# 27 2023-01-28         1750         155         9  96.06      0.03  838.6038
# 28 2023-01-29         1986         120         4  48.46      0.06  182.2096
# 29 2023-01-30         1549         191         4  24.18      0.14   83.1792
# 30 2023-01-31         1040         118         2  46.69      0.13   81.2406
# 31 2023-02-01         1335         143         3  26.83      0.17   66.8067
# 32 2023-02-02         1253         137         2  18.06      0.28   26.0064
# 33 2023-02-03         1906         101         4  23.51      0.09   85.5764
# 34 2023-02-04         1364         179         4  85.90      0.03  333.2920
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          1   West         Online       True              6            41
# 1          8  South           Cash      False              3            31
# 2          4  South         Online       True              3            47
# 3          1   West         Online       True              1            25
# 4          6  North    Credit Card      False              5            69
# 5          4  North           Cash       True              4            39
# 6          9  South    Credit Card      False              6            69
# 7          2  North    Credit Card       True              6            54
# 8          7  North         Online      False              2            54
# 9          2   East         Online       True              3            33
# 10         4  North           Cash       True              2            67
# 11         7  South           Cash      False              5            65
# 12         6  South           Cash      False              1            19
# 13         1  South           Cash       True              5            68
# 14         3  South    Credit Card       True              1            69
# 15         5   West    Credit Card      False              1            64
# 16         1   East    Credit Card      False              5            29
# 17         7  North           Cash       True              4            67
# 18         4   West         Online       True              2            44
# 19         6  South         Online      False              5            23
# 20         6   West         Online      False              5            28
# 21         8   East           Cash       True              5            33
# 22         4   West           Cash       True              2            35
# 23         4   East    Credit Card       True              6            45
# 24         8  North           Cash       True              1            45
# 25         7  North         Online      False              5            37
# 26         6  South    Credit Card      False              2            18
# 27         2  North         Online       True              4            54
# 28         5   East    Credit Card       True              2            28
# 29         5   East           Cash      False              6            43
# 30         9  North         Online       True              3            62
# 31         2   East    Credit Card       True              3            48
# 32         9   West    Credit Card      False              1            33
# 33         2   East           Cash       True              6            26
# 34         1  North    Credit Card      False              5            23
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     1.4      Returned   Neutral            NaN
# 1     Male      Electronics     3.4  Not Returned  Positive            NaN
# 2    Other         Clothing     2.3  Not Returned  Negative          17.56
# 3     Male      Electronics     4.4      Returned  Negative          11.61
# 4     Male      Electronics     3.7      Returned  Negative           5.29
# 5    Other             Food     3.9  Not Returned   Neutral          18.50
# 6     Male             Food     4.2      Returned  Negative          15.77
# 7   Female            Books     1.1      Returned  Positive          18.64
# 8     Male             Food     2.6  Not Returned  Negative          14.51
# 9     Male             Food     4.9  Not Returned   Neutral          17.97
# 10   Other            Books     1.5  Not Returned  Positive          19.04
# 11    Male             Food     2.6  Not Returned  Negative          16.99
# 12  Female            Books     4.1      Returned  Negative          11.52
# 13  Female             Food     1.9  Not Returned  Negative           7.39
# 14   Other             Food     1.1  Not Returned   Neutral           9.71
# 15   Other      Electronics     1.6      Returned  Negative            NaN
# 16    Male         Clothing     3.1  Not Returned  Positive           6.48
# 17    Male      Electronics     5.0  Not Returned  Negative          13.52
# 18    Male      Electronics     2.5      Returned  Negative          17.39
# 19    Male            Books     2.7  Not Returned   Neutral          10.29
# 20   Other             Food     3.3      Returned  Positive           8.81
# 21  Female            Books     4.9  Not Returned   Neutral           7.51
# 22  Female            Books     2.6      Returned  Negative          15.72
# 23    Male         Clothing     3.4      Returned  Negative          13.39
# 24   Other            Books     1.0      Returned  Positive          12.38
# 25    Male         Clothing     3.8  Not Returned   Neutral          15.60
# 26  Female            Books     3.0      Returned  Positive          17.16
# 27   Other      Electronics     1.5      Returned   Neutral          10.97
# 28    Male      Electronics     3.8  Not Returned   Neutral           6.69
# 29  Female      Electronics     1.2      Returned  Negative           9.62
# 30  Female      Electronics     1.7      Returned   Neutral          18.02
# 31   Other            Books     4.3      Returned   Neutral           9.90
# 32   Other            Books     3.6      Returned  Positive          12.25
# 33    Male            Books     2.4  Not Returned  Negative          10.57
# 34    Male             Food     2.1  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0       SAVE10              2.1
# 1       SAVE10              3.6
# 2     FREESHIP              3.1
# 3     FREESHIP              NaN
# 4       SAVE10              4.8
# 5          nan              3.7
# 6       SAVE10              NaN
# 7     WELCOME5              3.0
# 8     WELCOME5              NaN
# 9     FREESHIP              3.1
# 10    WELCOME5              NaN
# 11         nan              4.2
# 12    WELCOME5              NaN
# 13      SAVE10              NaN
# 14      SAVE10              3.1
# 15    WELCOME5              3.1
# 16      SAVE10              1.5
# 17         nan              1.5
# 18    WELCOME5              4.5
# 19      SAVE10              1.1
# 20         nan              3.3
# 21    WELCOME5              4.0
# 22    WELCOME5              4.3
# 23      SAVE10              NaN
# 24    FREESHIP              1.9
# 25      SAVE10              1.9
# 26    FREESHIP              3.4
# 27    FREESHIP              2.4
# 28    WELCOME5              NaN
# 29    FREESHIP              1.6
# 30      SAVE10              1.6
# 31      SAVE10              2.0
# 32    FREESHIP              1.5
# 33         nan              3.7
# 34    WELCOME5              4.8

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 02:**
# </div>

# %%
# 2. Ensuring Consistent Data Types of All Columns
# Write a Pandas program to check and ensure that the data types of all columns are consistent.

# Check data types
data_types = df.dtypes
data_types
# Out:
# date                datetime64[ns]
# customer_id                  int64
# product_id                   int64
# quantity                     int64
# price                      float64
# discount                   float64
# revenue                    float64
# store_id                     int64
# region                      object
# payment_method              object
# is_member                     bool
# delivery_days                int64
# customer_age                 int64
# gender                      object
# product_category            object
# rating                     float64
# return_status               object
# feedback                    object
# shipping_cost              float64
# coupon_code                 object
# delivery_rating            float64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning">
#
# **3. Validating the Data Type of a Specific Column**
#
# **Write a Pandas program to validate the data type of a specific column in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1212         136         9  74.47      0.12  589.8024
# 1  2023-01-02         1799         155         5  99.14      0.06  465.9580
# 2  2023-01-03         1353         193         8  81.62      0.09  594.1936
# 3  2023-01-04         1060         192         2  72.77      0.15  123.7090
# 4  2023-01-05         1363         147         4  16.42      0.17   54.5144
# 5  2023-01-06         1552         183         4  93.28      0.13  324.6144
# 6  2023-01-07         1448         119         8  68.75      0.04  528.0000
# 7  2023-01-08         1530         132         1  95.38      0.15   81.0730
# 8  2023-01-09         1560         168         5  84.83      0.19  343.5615
# 9  2023-01-10         1727         159         7  33.34      0.19  189.0378
# 10 2023-01-11         1753         132         8  28.71      0.09  209.0088
# 11 2023-01-12         1369         173         5  79.52      0.06  373.7440
# 12 2023-01-13         1486         161         3  95.83      0.30  201.2430
# 13 2023-01-14         1556         172         7  18.56      0.02  127.3216
# 14 2023-01-15         1334         159         7  68.01      0.03  461.7879
# 15 2023-01-16         1091         138         3  44.83      0.23  103.5573
# 16 2023-01-17         1109         102         2  20.54      0.03   39.8476
# 17 2023-01-18         1760         193         1  94.48      0.26   69.9152
# 18 2023-01-19         1479         179         3  98.79      0.10  266.7330
# 19 2023-01-20         1236         122         8  62.73      0.28  361.3248
# 20 2023-01-21         1549         178         5  61.55      0.25  230.8125
# 21 2023-01-22         1470         121         1  14.27      0.26   10.5598
# 22 2023-01-23         1953         124         2  42.97      0.05   81.6430
# 23 2023-01-24         1101         184         7  99.40      0.15  591.4300
# 24 2023-01-25         1980         127         7  12.48      0.13   76.0032
# 25 2023-01-26         1426         104         7  50.93      0.11  317.2939
# 26 2023-01-27         1389         147         6  59.38      0.28  256.5216
# 27 2023-01-28         1392         102         3  84.06      0.13  219.3966
# 28 2023-01-29         1252         122         8  72.56      0.08  534.0416
# 29 2023-01-30         1732         142         9  45.00      0.23  311.8500
# 30 2023-01-31         1322         148         9  53.61      0.05  458.3655
# 31 2023-02-01         1302         111         2  41.82      0.13   72.7668
# 32 2023-02-02         1733         149         6  46.56      0.14  240.2496
# 33 2023-02-03         1627         196         4  78.35      0.11  278.9260
# 34 2023-02-04         1739         134         2  13.46      0.16   22.6128
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          1   West           Cash       True              3            57
# 1          1   East    Credit Card       True              6            38
# 2          4   West         Online      False              5            60
# 3          5   West         Online      False              5            41
# 4          5   West           Cash       True              2            36
# 5          9   East    Credit Card       True              6            49
# 6          4   West           Cash      False              3            20
# 7          7   East    Credit Card      False              1            24
# 8          6  South         Online      False              5            34
# 9          9   East    Credit Card       True              4            36
# 10         2   West         Online      False              5            44
# 11         5   East    Credit Card      False              2            66
# 12         2   West    Credit Card       True              4            41
# 13         1   East           Cash       True              2            57
# 14         8  North           Cash      False              2            37
# 15         4  North    Credit Card       True              5            61
# 16         6   West    Credit Card      False              3            43
# 17         7   West           Cash       True              3            61
# 18         3   West    Credit Card      False              6            69
# 19         4   East         Online      False              6            23
# 20         1  South    Credit Card      False              5            39
# 21         5  North           Cash       True              4            18
# 22         1   West           Cash      False              5            59
# 23         1  North    Credit Card       True              3            41
# 24         4   West           Cash       True              4            44
# 25         5   West         Online       True              6            52
# 26         3  South         Online       True              1            28
# 27         2   West           Cash      False              6            22
# 28         2   West         Online       True              6            21
# 29         3   East    Credit Card       True              3            31
# 30         4  North           Cash      False              5            46
# 31         4  North         Online       True              5            44
# 32         9   West           Cash       True              1            56
# 33         5   East    Credit Card      False              4            54
# 34         9  South         Online       True              4            33
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other            Books     2.0      Returned  Negative          10.22
# 1     Male             Food     4.2  Not Returned  Negative           6.09
# 2     Male            Books     1.9  Not Returned  Negative            NaN
# 3     Male         Clothing     3.4  Not Returned   Neutral            NaN
# 4     Male            Books     2.9  Not Returned   Neutral          19.68
# 5     Male            Books     3.3      Returned  Negative          11.56
# 6   Female         Clothing     4.5  Not Returned  Negative          11.86
# 7   Female      Electronics     2.6      Returned   Neutral          18.66
# 8     Male      Electronics     1.6      Returned  Positive            NaN
# 9   Female            Books     2.3      Returned  Positive          13.54
# 10    Male         Clothing     4.5  Not Returned  Negative          15.69
# 11   Other            Books     1.6      Returned   Neutral            NaN
# 12  Female            Books     4.0  Not Returned  Positive          18.53
# 13    Male      Electronics     2.4  Not Returned  Negative          10.60
# 14    Male             Food     4.1      Returned   Neutral          15.31
# 15  Female             Food     2.3  Not Returned  Positive          16.54
# 16  Female             Food     4.3      Returned  Negative            NaN
# 17   Other         Clothing     4.3      Returned  Negative          18.90
# 18  Female         Clothing     3.5      Returned   Neutral           6.96
# 19    Male      Electronics     2.6      Returned  Negative          14.07
# 20   Other            Books     4.2      Returned  Negative            NaN
# 21  Female            Books     1.1      Returned   Neutral           7.42
# 22   Other      Electronics     3.7      Returned  Positive            NaN
# 23  Female            Books     3.5      Returned  Negative          11.37
# 24    Male         Clothing     1.1      Returned   Neutral           8.45
# 25  Female      Electronics     1.7      Returned  Positive          12.20
# 26  Female             Food     4.1      Returned  Negative          13.33
# 27   Other             Food     3.0  Not Returned  Negative          17.60
# 28  Female            Books     2.6  Not Returned  Positive          15.01
# 29   Other         Clothing     1.0  Not Returned  Positive          12.69
# 30   Other             Food     4.1      Returned  Positive          11.44
# 31   Other      Electronics     1.2      Returned   Neutral          12.94
# 32  Female            Books     4.9      Returned  Positive          10.28
# 33  Female            Books     1.9      Returned  Positive          13.03
# 34    Male      Electronics     2.8  Not Returned   Neutral          13.66
#
#    coupon_code  delivery_rating
# 0       SAVE10              NaN
# 1          nan              3.1
# 2       SAVE10              3.4
# 3     WELCOME5              3.4
# 4     FREESHIP              1.7
# 5     WELCOME5              NaN
# 6       SAVE10              2.9
# 7     WELCOME5              4.3
# 8     WELCOME5              1.9
# 9          nan              2.5
# 10    WELCOME5              3.7
# 11    WELCOME5              NaN
# 12         nan              NaN
# 13    WELCOME5              4.2
# 14      SAVE10              NaN
# 15         nan              4.9
# 16    FREESHIP              NaN
# 17      SAVE10              NaN
# 18         nan              NaN
# 19      SAVE10              3.0
# 20      SAVE10              1.5
# 21    FREESHIP              4.7
# 22    WELCOME5              NaN
# 23         nan              1.5
# 24         nan              2.2
# 25         nan              NaN
# 26      SAVE10              1.4
# 27    WELCOME5              1.1
# 28    WELCOME5              NaN
# 29    FREESHIP              4.3
# 30    FREESHIP              NaN
# 31    FREESHIP              4.7
# 32      SAVE10              5.0
# 33    WELCOME5              4.3
# 34         nan              5.0

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 03:**
# </div>

# %%
# 3. Validating the Data Type of a Specific Column
# Write a Pandas program to validate the data type of a specific column in a DataFrame.

# Check if 'price' column is of type float
is_of_type = 'float64'
is_price_float = df['price'].dtype == is_of_type
is_price_float

# Validate the data type of 'price' column
if is_price_float:
    print("The 'price' column is of type {}.".format(df['price'].dtype))
else:
    print("The 'price' column is not of type {}, it is {}.".format(is_of_type, df['price'].dtype))
# Out:
# The 'price' column is of type float64.

# %% [markdown]
# <div class="alert alert-warning">
#
# **4. Checking Duplicate Rows in a DataFrame**
#
# **Write a Pandas program to check duplicate rows in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1575         101         3  40.41      0.15  103.0455
# 1  2023-01-02         1241         109         7  50.88      0.26  263.5584
# 2  2023-01-03         1518         101         8  56.90      0.30  318.6400
# 3  2023-01-04         1663         164         7  27.01      0.02  185.2886
# 4  2023-01-05         1013         103         4  61.57      0.05  233.9660
# 5  2023-01-06         1964         174         9  91.34      0.28  591.8832
# 6  2023-01-07         1448         102         4  90.51      0.14  311.3544
# 7  2023-01-08         1277         141         2  30.56      0.12   53.7856
# 8  2023-01-09         1998         190         9  59.14      0.24  404.5176
# 9  2023-01-10         1047         157         2  47.73      0.13   83.0502
# 10 2023-01-11         1477         127         8  23.36      0.28  134.5536
# 11 2023-01-12         1985         132         1  77.65      0.08   71.4380
# 12 2023-01-13         1195         136         9  28.80      0.24  196.9920
# 13 2023-01-14         1913         187         9  40.49      0.20  291.5280
# 14 2023-01-15         1929         172         5  33.55      0.00  167.7500
# 15 2023-01-16         1708         178         8  21.02      0.17  139.5728
# 16 2023-01-17         1612         111         3  11.48      0.18   28.2408
# 17 2023-01-18         1110         111         2  71.10      0.07  132.2460
# 18 2023-01-19         1244         133         2  44.74      0.14   76.9528
# 19 2023-01-20         1142         197         9  86.08      0.28  557.7984
# 20 2023-01-21         1246         136         5  90.91      0.08  418.1860
# 21 2023-01-22         1619         194         9  63.76      0.26  424.6416
# 22 2023-01-23         1570         175         8  58.12      0.14  399.8656
# 23 2023-01-24         1458         149         6  81.14      0.22  379.7352
# 24 2023-01-25         1657         154         2  34.90      0.03   67.7060
# 25 2023-01-26         1741         192         8  41.14      0.24  250.1312
# 26 2023-01-27         1643         172         3  13.14      0.22   30.7476
# 27 2023-01-28         1667         109         6  48.40      0.09  264.2640
# 28 2023-01-29         1101         128         4  31.14      0.15  105.8760
# 29 2023-01-30         1598         196         9  13.69      0.08  113.3532
# 30 2023-01-31         1109         169         9  83.52      0.04  721.6128
# 31 2023-02-01         1139         111         3  96.56      0.03  280.9896
# 32 2023-02-02         1056         160         3  60.82      0.04  175.1616
# 33 2023-02-03         1734         121         9  88.13      0.18  650.3994
# 34 2023-02-04         1813         126         1  99.95      0.01   98.9505
# 35 2023-01-27         1643         172         3  13.14      0.22   30.7476
# 36 2023-01-14         1913         187         9  40.49      0.20  291.5280
# 37 2023-01-25         1657         154         2  34.90      0.03   67.7060
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          4   West           Cash       True              1            40
# 1          6  North           Cash      False              1            49
# 2          4  North           Cash      False              3            65
# 3          9  North           Cash      False              1            58
# 4          6   East           Cash      False              1            63
# 5          8  South           Cash       True              2            69
# 6          4   West    Credit Card      False              2            37
# 7          2   East           Cash       True              2            30
# 8          1   East         Online       True              1            25
# 9          2  South         Online      False              2            41
# 10         8  North    Credit Card       True              5            57
# 11         1   East         Online      False              3            25
# 12         9   West         Online       True              2            21
# 13         1   East         Online      False              1            69
# 14         8  North           Cash       True              5            43
# 15         4  South           Cash      False              5            43
# 16         5   West         Online       True              1            45
# 17         7  South           Cash       True              4            30
# 18         2  North    Credit Card       True              6            51
# 19         8  North           Cash      False              6            26
# 20         6   West           Cash       True              1            61
# 21         7   West         Online       True              1            34
# 22         8  North    Credit Card       True              3            59
# 23         1  South    Credit Card      False              1            31
# 24         4  South         Online      False              1            30
# 25         6  South           Cash      False              2            27
# 26         6  South    Credit Card      False              2            33
# 27         2   East    Credit Card      False              1            39
# 28         8   East         Online       True              4            66
# 29         8   East           Cash       True              4            37
# 30         1  North           Cash       True              2            37
# 31         9   West    Credit Card      False              6            27
# 32         2  South           Cash       True              3            43
# 33         2   West           Cash      False              6            51
# 34         4   West         Online      False              3            32
# 35         6  South    Credit Card      False              2            33
# 36         1   East         Online      False              1            69
# 37         4  South         Online      False              1            30
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other      Electronics     3.7      Returned  Negative          11.93
# 1   Female            Books     1.7      Returned   Neutral            NaN
# 2     Male         Clothing     2.9  Not Returned  Negative          10.56
# 3    Other             Food     4.2  Not Returned  Positive          17.84
# 4    Other            Books     4.3      Returned   Neutral          14.86
# 5   Female            Books     4.5  Not Returned  Positive          16.24
# 6     Male      Electronics     3.9      Returned  Negative           5.32
# 7    Other            Books     1.4      Returned   Neutral           6.90
# 8   Female            Books     3.6  Not Returned   Neutral          13.09
# 9   Female      Electronics     3.2  Not Returned  Negative           6.93
# 10   Other      Electronics     4.0  Not Returned  Negative           9.29
# 11    Male             Food     4.0  Not Returned  Negative          10.29
# 12   Other         Clothing     1.1  Not Returned  Negative          14.79
# 13    Male      Electronics     2.9      Returned   Neutral           5.98
# 14  Female         Clothing     1.0      Returned  Negative          17.35
# 15  Female         Clothing     3.8      Returned   Neutral            NaN
# 16    Male             Food     3.3      Returned  Positive           8.44
# 17  Female         Clothing     2.7      Returned  Negative          13.89
# 18    Male      Electronics     3.0      Returned  Negative            NaN
# 19   Other            Books     2.8  Not Returned  Negative          14.31
# 20    Male             Food     4.9      Returned  Positive            NaN
# 21  Female            Books     4.1  Not Returned   Neutral           8.10
# 22   Other             Food     1.5  Not Returned  Negative          18.24
# 23   Other      Electronics     1.3  Not Returned   Neutral           7.09
# 24   Other      Electronics     1.5  Not Returned  Negative            NaN
# 25  Female            Books     4.4      Returned  Negative          11.28
# 26  Female      Electronics     4.2  Not Returned  Positive          17.60
# 27   Other            Books     4.5  Not Returned  Positive           8.72
# 28    Male      Electronics     4.0      Returned  Negative           7.31
# 29   Other      Electronics     3.4  Not Returned   Neutral           7.67
# 30   Other            Books     3.7      Returned  Positive          10.66
# 31  Female      Electronics     1.4  Not Returned  Positive          18.25
# 32   Other             Food     2.0  Not Returned  Negative           7.79
# 33   Other         Clothing     3.4  Not Returned  Negative           5.82
# 34  Female      Electronics     4.8      Returned   Neutral          18.20
# 35  Female      Electronics     4.2  Not Returned  Positive          17.60
# 36    Male      Electronics     2.9      Returned   Neutral           5.98
# 37   Other      Electronics     1.5  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0     WELCOME5              3.4
# 1     FREESHIP              4.1
# 2       SAVE10              3.4
# 3     WELCOME5              1.3
# 4          nan              1.8
# 5     WELCOME5              NaN
# 6     WELCOME5              1.9
# 7       SAVE10              NaN
# 8       SAVE10              3.9
# 9          nan              1.9
# 10    FREESHIP              1.7
# 11         nan              NaN
# 12    WELCOME5              4.9
# 13         nan              4.6
# 14    FREESHIP              NaN
# 15    FREESHIP              1.3
# 16    WELCOME5              3.1
# 17         nan              3.0
# 18    WELCOME5              NaN
# 19         nan              3.0
# 20         nan              2.9
# 21         nan              2.3
# 22         nan              3.2
# 23      SAVE10              5.0
# 24    WELCOME5              1.7
# 25         nan              4.5
# 26         nan              NaN
# 27         nan              4.6
# 28    FREESHIP              3.8
# 29      SAVE10              3.7
# 30         nan              3.9
# 31      SAVE10              3.3
# 32         nan              2.2
# 33    WELCOME5              NaN
# 34         nan              2.6
# 35         nan              NaN
# 36         nan              4.6
# 37    WELCOME5              1.7

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
# 4. Checking Duplicate Rows in a DataFrame
# Write a Pandas program to check duplicate rows in a DataFrame.

# Check for duplicate rows
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 35 2023-01-27         1643         172         3  13.14      0.22   30.7476
# 36 2023-01-14         1913         187         9  40.49      0.20  291.5280
# 37 2023-01-25         1657         154         2  34.90      0.03   67.7060
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 35         6  South    Credit Card      False              2            33
# 36         1   East         Online      False              1            69
# 37         4  South         Online      False              1            30
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 35  Female      Electronics     4.2  Not Returned  Positive          17.60
# 36    Male      Electronics     2.9      Returned   Neutral           5.98
# 37   Other      Electronics     1.5  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 35         nan              NaN
# 36         nan              4.6
# 37    WELCOME5              1.7

# %% [markdown]
# <div class="alert alert-warning">
#
# **5. Removing Duplicate Rows from a DataFrame**
#
# **Write a Pandas program to remove duplicate rows from a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1981         141         2  32.81      0.03   63.6514
# 1  2023-01-02         1620         177         5  22.06      0.18   90.4460
# 2  2023-01-03         1113         183         2  25.73      0.25   38.5950
# 3  2023-01-04         1930         149         1  41.74      0.28   30.0528
# 4  2023-01-05         1093         148         6  93.50      0.00  561.0000
# 5  2023-01-06         1321         159         7  30.87      0.04  207.4464
# 6  2023-01-07         1804         118         6  99.07      0.17  493.3686
# 7  2023-01-08         1698         172         2  19.72      0.22   30.7632
# 8  2023-01-09         1168         119         1  54.20      0.08   49.8640
# 9  2023-01-10         1007         155         3  50.09      0.29  106.6917
# 10 2023-01-11         1709         107         5  28.34      0.16  119.0280
# 11 2023-01-12         1663         160         1  56.55      0.01   55.9845
# 12 2023-01-13         1731         186         4  24.26      0.11   86.3656
# 13 2023-01-14         1658         190         2  31.45      0.09   57.2390
# 14 2023-01-15         1367         194         8  41.38      0.11  294.6256
# 15 2023-01-16         1038         179         7  21.59      0.16  126.9492
# 16 2023-01-17         1633         135         1  13.52      0.21   10.6808
# 17 2023-01-18         1587         140         9  69.88      0.02  616.3416
# 18 2023-01-19         1742         125         6  95.86      0.21  454.3764
# 19 2023-01-20         1042         182         9  75.92      0.22  532.9584
# 20 2023-01-21         1009         162         5  85.99      0.13  374.0565
# 21 2023-01-22         1546         138         8  17.39      0.25  104.3400
# 22 2023-01-23         1976         158         7  23.25      0.09  148.1025
# 23 2023-01-24         1053         151         5  42.45      0.17  176.1675
# 24 2023-01-25         1810         150         9  92.68      0.17  692.3196
# 25 2023-01-26         1671         178         1  71.30      0.26   52.7620
# 26 2023-01-27         1608         157         7  45.93      0.07  299.0043
# 27 2023-01-28         1699         122         8  74.82      0.04  574.6176
# 28 2023-01-29         1804         153         8  80.82      0.19  523.7136
# 29 2023-01-30         1893         109         9  64.66      0.19  471.3714
# 30 2023-01-31         1289         132         6  66.61      0.13  347.7042
# 31 2023-02-01         1455         104         7  40.88      0.18  234.6512
# 32 2023-02-02         1593         131         1  98.53      0.02   96.5594
# 33 2023-02-03         1300         151         6  68.38      0.11  365.1492
# 34 2023-02-04         1152         155         5  65.53      0.27  239.1845
# 35 2023-01-27         1608         157         7  45.93      0.07  299.0043
# 36 2023-01-14         1658         190         2  31.45      0.09   57.2390
# 37 2023-01-25         1810         150         9  92.68      0.17  692.3196
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6   East           Cash      False              3            39
# 1          6   East    Credit Card      False              5            41
# 2          7   East    Credit Card       True              6            35
# 3          5   East           Cash      False              5            62
# 4          1  North           Cash       True              1            55
# 5          8   East           Cash      False              6            21
# 6          2  North    Credit Card      False              6            41
# 7          9  South         Online       True              1            55
# 8          1  South         Online       True              2            24
# 9          1  North         Online      False              3            18
# 10         1  North           Cash       True              6            48
# 11         5  South         Online      False              3            44
# 12         4  North         Online       True              3            38
# 13         1   West           Cash      False              4            58
# 14         2  South    Credit Card      False              3            57
# 15         5  North           Cash       True              6            44
# 16         3   East    Credit Card       True              3            43
# 17         1  South         Online      False              3            20
# 18         3  South         Online      False              4            18
# 19         7   East    Credit Card       True              4            26
# 20         4  North    Credit Card      False              3            27
# 21         2  South         Online       True              1            56
# 22         5  North           Cash       True              1            39
# 23         7  North    Credit Card      False              5            60
# 24         4  South         Online      False              5            27
# 25         5  South    Credit Card      False              2            63
# 26         3   West    Credit Card       True              2            50
# 27         9  North           Cash      False              4            23
# 28         9   East    Credit Card       True              5            63
# 29         8  North    Credit Card       True              6            39
# 30         1   East           Cash       True              1            27
# 31         7   West    Credit Card      False              1            65
# 32         7  South           Cash       True              4            32
# 33         9   West         Online       True              4            52
# 34         9  North    Credit Card      False              3            52
# 35         3   West    Credit Card       True              2            50
# 36         1   West           Cash      False              4            58
# 37         4  South         Online      False              5            27
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other             Food     3.7  Not Returned  Negative            NaN
# 1   Female         Clothing     2.4  Not Returned  Positive          13.34
# 2    Other      Electronics     4.3  Not Returned   Neutral           8.99
# 3    Other            Books     2.5      Returned   Neutral          15.14
# 4   Female             Food     2.4      Returned  Positive           6.50
# 5     Male      Electronics     3.6  Not Returned   Neutral          12.50
# 6    Other             Food     3.9      Returned  Positive          13.76
# 7     Male            Books     1.8  Not Returned   Neutral          17.37
# 8   Female         Clothing     2.2  Not Returned   Neutral            NaN
# 9     Male             Food     2.7      Returned  Positive           8.99
# 10  Female            Books     3.8      Returned  Negative          14.78
# 11  Female      Electronics     4.0  Not Returned   Neutral          11.18
# 12  Female      Electronics     3.2  Not Returned  Negative           5.99
# 13  Female            Books     3.3  Not Returned  Negative          15.84
# 14   Other            Books     2.3      Returned  Positive          12.81
# 15    Male            Books     4.4      Returned  Positive            NaN
# 16  Female            Books     2.2  Not Returned  Negative           9.56
# 17  Female             Food     3.7  Not Returned  Negative          18.83
# 18   Other            Books     1.5      Returned  Negative          18.39
# 19  Female             Food     1.4  Not Returned   Neutral           7.24
# 20    Male         Clothing     1.1      Returned  Positive           8.21
# 21    Male            Books     5.0      Returned  Negative           9.00
# 22    Male      Electronics     4.2  Not Returned  Positive          18.59
# 23   Other         Clothing     4.2  Not Returned  Negative          14.52
# 24   Other      Electronics     2.4      Returned  Negative          10.79
# 25   Other            Books     1.4  Not Returned  Negative          12.85
# 26   Other             Food     2.4      Returned   Neutral          13.09
# 27    Male             Food     1.0  Not Returned   Neutral            NaN
# 28  Female      Electronics     1.9      Returned  Positive          13.46
# 29  Female      Electronics     4.7  Not Returned   Neutral           6.15
# 30    Male      Electronics     1.2  Not Returned  Positive          18.34
# 31    Male      Electronics     3.1      Returned   Neutral            NaN
# 32   Other            Books     4.6  Not Returned   Neutral            NaN
# 33    Male            Books     1.7      Returned  Negative           7.89
# 34    Male         Clothing     3.6      Returned   Neutral           5.39
# 35   Other             Food     2.4      Returned   Neutral          13.09
# 36  Female            Books     3.3  Not Returned  Negative          15.84
# 37   Other      Electronics     2.4      Returned  Negative          10.79
#
#    coupon_code  delivery_rating
# 0          nan              4.5
# 1     FREESHIP              4.7
# 2     WELCOME5              NaN
# 3          nan              2.1
# 4     FREESHIP              2.5
# 5          nan              4.2
# 6          nan              NaN
# 7     WELCOME5              NaN
# 8          nan              1.8
# 9       SAVE10              NaN
# 10    WELCOME5              4.9
# 11         nan              NaN
# 12         nan              NaN
# 13    FREESHIP              2.2
# 14         nan              2.2
# 15         nan              NaN
# 16         nan              4.8
# 17    FREESHIP              NaN
# 18    FREESHIP              1.5
# 19    WELCOME5              NaN
# 20         nan              2.2
# 21      SAVE10              NaN
# 22      SAVE10              NaN
# 23    FREESHIP              NaN
# 24    WELCOME5              2.4
# 25         nan              NaN
# 26    WELCOME5              NaN
# 27         nan              NaN
# 28         nan              4.4
# 29    WELCOME5              2.1
# 30    WELCOME5              2.2
# 31         nan              4.8
# 32      SAVE10              3.0
# 33    WELCOME5              3.8
# 34         nan              4.7
# 35    WELCOME5              NaN
# 36    FREESHIP              2.2
# 37    WELCOME5              2.4

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
# 5. Removing Duplicate Rows from a DataFrame
# Write a Pandas program to remove duplicate rows from a DataFrame.

print("Shape of DataFrame before removing duplicates:\n", df.shape)
# Remove duplicate rows
df = df.drop_duplicates()
print("Shape of DataFrame after removing duplicates:\n", df.shape)
# Out:
# Shape of DataFrame before removing duplicates:
#  (38, 21)
# Shape of DataFrame after removing duplicates:
#  (35, 21)

# %% [markdown]
# <div class="alert alert-warning">
#
# **6. Validating Data Based on Custom Conditions**
#
# **Write a Pandas program to validate data based on custom conditions.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1597         190         8  80.38      0.18  527.2928
# 1  2023-01-02         1565         170         4  56.01      0.26  165.7896
# 2  2023-01-03         1818         143         5  23.21      0.11  103.2845
# 3  2023-01-04         1442         106         5  71.88      0.06  337.8360
# 4  2023-01-05         1882         196         2  34.48      0.25   51.7200
# 5  2023-01-06         1570         134         6  38.97      0.13  203.4234
# 6  2023-01-07         1023         161         5  54.52      0.09  248.0660
# 7  2023-01-08         1475         144         2  14.13      0.16   23.7384
# 8  2023-01-09         1659         189         1  93.08      0.29   66.0868
# 9  2023-01-10         1560         196         3  30.52      0.07   85.1508
# 10 2023-01-11         1981         137         8  90.77      0.19  588.1896
# 11 2023-01-12         1492         106         3  40.85      0.10  110.2950
# 12 2023-01-13         1971         161         2  36.62      0.28   52.7328
# 13 2023-01-14         1441         166         1  73.97      0.28   53.2584
# 14 2023-01-15         1689         124         6  46.76      0.14  241.2816
# 15 2023-01-16         1134         153         9  32.64      0.12  258.5088
# 16 2023-01-17         1693         190         3  73.24      0.01  217.5228
# 17 2023-01-18         1994         184         1  16.65      0.22   12.9870
# 18 2023-01-19         1242         190         6  33.11      0.12  174.8208
# 19 2023-01-20         1237         196         1  29.39      0.02   28.8022
# 20 2023-01-21         1120         129         1  23.52      0.00   23.5200
# 21 2023-01-22         1128         172         5  40.07      0.30  140.2450
# 22 2023-01-23         1275         114         3  74.52      0.26  165.4344
# 23 2023-01-24         1683         177         9  72.90      0.08  603.6120
# 24 2023-01-25         1413         113         6  82.99      0.23  383.4138
# 25 2023-01-26         1831         142         3  82.17      0.28  177.4872
# 26 2023-01-27         1027         178         8  17.65      0.20  112.9600
# 27 2023-01-28         1370         157         9  85.92      0.10  695.9520
# 28 2023-01-29         1392         168         6  21.63      0.01  128.4822
# 29 2023-01-30         1766         127         2  31.17      0.00   62.3400
# 30 2023-01-31         1564         168         4  79.26      0.23  244.1208
# 31 2023-02-01         1734         126         7  35.74      0.17  207.6494
# 32 2023-02-02         1783         115         1  24.26      0.29   17.2246
# 33 2023-02-03         1473         155         8  96.44      0.13  671.2224
# 34 2023-02-04         1781         195         1  43.71      0.22   34.0938
# 35 2023-01-27         1027         178         8  17.65      0.20  112.9600
# 36 2023-01-14         1441         166         1  73.97      0.28   53.2584
# 37 2023-01-25         1413         113         6  82.99      0.23  383.4138
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          9  South           Cash      False              2            45
# 1          8  South         Online       True              4            43
# 2          9   West           Cash       True              3            29
# 3          9  South    Credit Card       True              6            55
# 4          4  North           Cash       True              5            50
# 5          8  North    Credit Card      False              5            32
# 6          5  South           Cash      False              5            33
# 7          9   West           Cash       True              3            22
# 8          6  North    Credit Card       True              4            42
# 9          3  South           Cash      False              1            44
# 10         2  South    Credit Card       True              4            57
# 11         4  South         Online       True              6            22
# 12         5   East    Credit Card      False              1            27
# 13         1  South           Cash       True              6            37
# 14         8  North         Online      False              6            30
# 15         7  North           Cash      False              6            26
# 16         8   East           Cash      False              5            51
# 17         9   West         Online      False              3            27
# 18         9  South    Credit Card      False              2            40
# 19         9   East         Online       True              4            57
# 20         6  North         Online       True              2            67
# 21         3   East         Online       True              6            68
# 22         7  South         Online       True              1            48
# 23         6   East         Online       True              1            19
# 24         2  North    Credit Card       True              1            50
# 25         3  North         Online      False              2            67
# 26         5  North    Credit Card       True              2            52
# 27         1  North           Cash       True              6            38
# 28         4  North           Cash      False              1            31
# 29         4   East         Online       True              1            44
# 30         7   East           Cash       True              5            29
# 31         6   East    Credit Card      False              4            42
# 32         6  North    Credit Card       True              2            57
# 33         8   West    Credit Card      False              4            31
# 34         5  South         Online      False              6            33
# 35         5  North    Credit Card       True              2            52
# 36         1  South           Cash       True              6            37
# 37         2  North    Credit Card       True              1            50
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male         Clothing     1.1  Not Returned   Neutral           8.94
# 1   Female      Electronics     4.3  Not Returned  Positive           6.17
# 2   Female         Clothing     4.9  Not Returned   Neutral           5.59
# 3     Male      Electronics     3.7      Returned   Neutral           5.00
# 4   Female             Food     4.2  Not Returned   Neutral           5.72
# 5   Female         Clothing     2.0  Not Returned  Negative          19.27
# 6     Male         Clothing     1.2      Returned   Neutral          10.68
# 7   Female         Clothing     2.0      Returned  Negative          16.37
# 8    Other             Food     3.2  Not Returned   Neutral          17.74
# 9    Other      Electronics     1.8  Not Returned  Negative          13.48
# 10  Female            Books     2.0      Returned  Positive           9.59
# 11    Male            Books     1.9      Returned  Positive          13.69
# 12   Other         Clothing     3.7  Not Returned  Negative            NaN
# 13   Other         Clothing     1.4  Not Returned   Neutral          10.89
# 14  Female         Clothing     3.3  Not Returned   Neutral          16.63
# 15   Other         Clothing     3.1      Returned  Positive            NaN
# 16   Other             Food     4.3      Returned  Positive          17.22
# 17    Male            Books     3.7      Returned   Neutral          15.76
# 18  Female         Clothing     4.2  Not Returned  Negative          17.32
# 19   Other            Books     1.8  Not Returned   Neutral          12.68
# 20    Male             Food     2.8      Returned   Neutral          19.84
# 21  Female            Books     3.1  Not Returned  Positive          16.24
# 22  Female         Clothing     4.9  Not Returned  Positive           7.86
# 23   Other            Books     1.2      Returned  Negative          15.35
# 24  Female      Electronics     3.4      Returned  Negative           8.69
# 25  Female             Food     1.3  Not Returned  Negative          12.83
# 26   Other      Electronics     3.4      Returned   Neutral           8.24
# 27   Other      Electronics     3.9      Returned   Neutral           7.81
# 28  Female      Electronics     1.9      Returned  Positive          11.54
# 29  Female             Food     1.9  Not Returned  Negative          10.29
# 30    Male      Electronics     1.0  Not Returned   Neutral          17.22
# 31   Other             Food     2.3  Not Returned   Neutral          19.32
# 32   Other             Food     4.1  Not Returned  Positive          12.16
# 33    Male         Clothing     4.4  Not Returned   Neutral          13.79
# 34    Male             Food     4.2  Not Returned  Negative          16.45
# 35   Other      Electronics     3.4      Returned   Neutral           8.24
# 36   Other         Clothing     1.4  Not Returned   Neutral          10.89
# 37  Female      Electronics     3.4      Returned  Negative           8.69
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0     WELCOME5              3.3
# 1          nan              NaN
# 2          nan              NaN
# 3     FREESHIP              3.4
# 4          nan              4.1
# 5          nan              3.1
# 6          nan              1.7
# 7     WELCOME5              4.4
# 8          nan              NaN
# 9          nan              NaN
# 10      SAVE10              4.3
# 11    FREESHIP              1.0
# 12      SAVE10              2.8
# 13         nan              4.5
# 14    FREESHIP              NaN
# 15      SAVE10              NaN
# 16      SAVE10              1.4
# 17      SAVE10              3.6
# 18         nan              NaN
# 19      SAVE10              4.8
# 20    FREESHIP              NaN
# 21         nan              4.4
# 22         nan              3.0
# 23    FREESHIP              3.7
# 24         nan              NaN
# 25         nan              3.4
# 26    WELCOME5              2.1
# 27    WELCOME5              NaN
# 28    WELCOME5              3.5
# 29    FREESHIP              4.8
# 30      SAVE10              4.4
# 31         nan              2.5
# 32      SAVE10              2.8
# 33    FREESHIP              3.0
# 34      SAVE10              4.7
# 35    WELCOME5              2.1
# 36         nan              4.5
# 37         nan              NaN
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 06:**
# </div>

# %%
# 6. Validating Data Based on Custom Conditions
# Write a Pandas program to validate data based on custom conditions.

# Check if 'price' is greater than 0
valid_price = df['price'] > 0
if valid_price.all():
    print("All prices are valid.")
else:
    print("Some prices are invalid:")
    display(df[~valid_price])
# Out:
# Some prices are invalid:
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **7. Checking That a Specific Column Contains Only Unique Values**
#
# **Write a Pandas program to check that a specific column contains only unique values.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1864         187         1  94.29      0.29   66.9459
# 1  2023-01-02         1637         142         2  26.24      0.13   45.6576
# 2  2023-01-03         1722         110         8  14.96      0.20   95.7440
# 3  2023-01-04         1847         114         7  92.68      0.21  512.5204
# 4  2023-01-05         1690         175         6  22.31      0.05  127.1670
# 5  2023-01-06         1344         189         6  60.39      0.23  279.0018
# 6  2023-01-07         1964         147         7  46.09      0.28  232.2936
# 7  2023-01-08         1154         164         6  81.13      0.21  384.5562
# 8  2023-01-09         1746         135         2  19.64      0.03   38.1016
# 9  2023-01-10         1302         165         9  13.23      0.11  105.9723
# 10 2023-01-11         1003         154         7  52.63      0.00  368.4100
# 11 2023-01-12         1916         132         2  98.22      0.04  188.5824
# 12 2023-01-13         1333         132         5  75.87      0.20  303.4800
# 13 2023-01-14         1057         159         5  63.90      0.21  252.4050
# 14 2023-01-15         1518         152         5  84.77      0.25  317.8875
# 15 2023-01-16         1418         143         9  36.24      0.24  247.8816
# 16 2023-01-17         1569         120         3  14.56      0.13   38.0016
# 17 2023-01-18         1660         152         4  33.11      0.11  117.8716
# 18 2023-01-19         1434         174         2  46.43      0.11   82.6454
# 19 2023-01-20         1244         168         2  90.80      0.23  139.8320
# 20 2023-01-21         1828         185         9  55.28      0.15  422.8920
# 21 2023-01-22         1916         142         6  41.38      0.14  213.5208
# 22 2023-01-23         1755         124         5  11.11      0.27   40.5515
# 23 2023-01-24         1749         109         5  70.58      0.12  310.5520
# 24 2023-01-25         1534         194         2  46.42      0.02   90.9832
# 25 2023-01-26         1826         149         1  77.41      0.24   58.8316
# 26 2023-01-27         1839         152         7  62.04      0.04  416.9088
# 27 2023-01-28         1938         101         4  89.48      0.23  275.5984
# 28 2023-01-29         1241         195         2  15.01      0.20   24.0160
# 29 2023-01-30         1293         152         6  76.84      0.29  327.3384
# 30 2023-01-31         1350         188         7  70.22      0.05  466.9630
# 31 2023-02-01         1304         159         6  46.66      0.08  257.5632
# 32 2023-02-02         1260         195         6  54.52      0.29  232.2552
# 33 2023-02-03         1382         191         1  48.04      0.09   43.7164
# 34 2023-02-04         1988         100         1  27.15      0.20   21.7200
# 35 2023-01-27         1839         152         7  62.04      0.04  416.9088
# 36 2023-01-14         1057         159         5  63.90      0.21  252.4050
# 37 2023-01-25         1534         194         2  46.42      0.02   90.9832
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   West    Credit Card      False              6            59
# 1          7   East         Online       True              5            44
# 2          1   East         Online       True              4            21
# 3          7   East         Online      False              5            48
# 4          8   East           Cash      False              5            44
# 5          8  North    Credit Card       True              3            48
# 6          6   East    Credit Card       True              1            39
# 7          5  South    Credit Card      False              6            58
# 8          2  South    Credit Card       True              2            66
# 9          7   East           Cash       True              3            51
# 10         4  North         Online      False              5            49
# 11         3   East         Online       True              5            52
# 12         7   West           Cash      False              1            31
# 13         8   West         Online      False              5            50
# 14         5  South    Credit Card       True              3            31
# 15         3  South           Cash      False              6            48
# 16         8   East    Credit Card       True              6            23
# 17         6   West         Online      False              6            65
# 18         3  North    Credit Card       True              4            69
# 19         2  South           Cash       True              5            47
# 20         9  South    Credit Card      False              4            52
# 21         4   East    Credit Card       True              6            52
# 22         5  South         Online       True              2            69
# 23         2  North         Online       True              4            37
# 24         4  North    Credit Card      False              5            41
# 25         5   West           Cash      False              5            47
# 26         4   West         Online       True              4            52
# 27         9   West    Credit Card       True              6            36
# 28         5   West         Online       True              4            68
# 29         7   West    Credit Card      False              6            54
# 30         3  South    Credit Card      False              5            35
# 31         5   East    Credit Card       True              2            24
# 32         6  South           Cash      False              2            32
# 33         7   West           Cash       True              4            27
# 34         8   East         Online      False              1            22
# 35         4   West         Online       True              4            52
# 36         8   West         Online      False              5            50
# 37         4  North    Credit Card      False              5            41
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other      Electronics     4.9  Not Returned  Positive           6.63
# 1    Other            Books     2.0      Returned  Positive           7.28
# 2     Male      Electronics     2.1  Not Returned   Neutral          16.18
# 3   Female         Clothing     5.0      Returned  Positive          15.68
# 4    Other      Electronics     2.7      Returned   Neutral          15.66
# 5     Male             Food     2.9  Not Returned  Negative          14.09
# 6   Female         Clothing     1.4  Not Returned  Positive          18.26
# 7    Other             Food     2.6      Returned  Positive          12.38
# 8   Female             Food     1.6      Returned  Positive           5.10
# 9   Female             Food     3.2      Returned  Negative          10.78
# 10  Female         Clothing     4.2  Not Returned  Positive           5.08
# 11    Male      Electronics     1.9      Returned   Neutral           9.07
# 12   Other            Books     3.1      Returned  Negative            NaN
# 13   Other         Clothing     3.1      Returned  Negative          15.54
# 14  Female            Books     2.6      Returned  Positive          15.23
# 15    Male             Food     3.9      Returned  Negative          19.40
# 16    Male      Electronics     2.0      Returned  Negative          18.35
# 17  Female            Books     1.3      Returned  Positive           8.45
# 18   Other      Electronics     4.6  Not Returned  Positive           6.04
# 19   Other            Books     1.5      Returned  Positive           7.70
# 20    Male      Electronics     3.4  Not Returned  Positive          18.11
# 21    Male            Books     1.8      Returned  Positive          16.60
# 22  Female         Clothing     4.6  Not Returned   Neutral          18.95
# 23   Other            Books     2.9  Not Returned   Neutral            NaN
# 24   Other            Books     4.1      Returned  Negative            NaN
# 25    Male      Electronics     1.2      Returned   Neutral          15.82
# 26    Male            Books     1.5      Returned  Positive           6.63
# 27  Female         Clothing     1.9  Not Returned  Positive            NaN
# 28  Female            Books     3.8  Not Returned  Negative           8.94
# 29   Other            Books     4.0  Not Returned   Neutral           8.03
# 30   Other             Food     1.4  Not Returned  Positive           7.97
# 31  Female            Books     2.3      Returned  Negative            NaN
# 32    Male            Books     1.0      Returned  Negative          12.78
# 33   Other            Books     3.8  Not Returned  Negative          11.80
# 34    Male             Food     4.4  Not Returned  Positive           7.27
# 35    Male            Books     1.5      Returned  Positive           6.63
# 36   Other         Clothing     3.1      Returned  Negative          15.54
# 37   Other            Books     4.1      Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              NaN          1
# 1          nan              2.1          2
# 2          nan              NaN          3
# 3     WELCOME5              2.2          4
# 4          nan              NaN          5
# 5     WELCOME5              2.3          6
# 6     WELCOME5              1.9          7
# 7     FREESHIP              2.5          8
# 8       SAVE10              3.9          9
# 9     WELCOME5              NaN         10
# 10      SAVE10              4.4         11
# 11      SAVE10              3.7         12
# 12         nan              1.9         13
# 13         nan              NaN         14
# 14    WELCOME5              2.1         15
# 15         nan              3.7         16
# 16    FREESHIP              1.0         17
# 17      SAVE10              2.1         18
# 18         nan              3.9         19
# 19      SAVE10              NaN         20
# 20    FREESHIP              2.6         21
# 21    WELCOME5              NaN         22
# 22      SAVE10              1.9         23
# 23    FREESHIP              2.2         24
# 24         nan              3.3         25
# 25         nan              1.9         26
# 26      SAVE10              NaN         27
# 27         nan              3.9         28
# 28      SAVE10              2.6         29
# 29    WELCOME5              3.5         30
# 30      SAVE10              NaN         31
# 31    FREESHIP              1.6         32
# 32    WELCOME5              3.9         33
# 33         nan              1.8         34
# 34      SAVE10              4.9         35
# 35      SAVE10              NaN         36
# 36         nan              NaN         37
# 37         nan              3.3         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 07:**
# </div>

# %%
pd.Series.is_unique?
# Out:
# Type:        property
# String form: <property object at 0x10bc5c220>
# Docstring:
# Return boolean if values in the object are unique.
#
# Returns
# -------
# bool
#
# Examples
# --------
# >>> s = pd.Series([1, 2, 3])
# >>> s.is_unique
# True
#
# >>> s = pd.Series([1, 2, 3, 1])
# >>> s.is_unique
# False

# %%
# 7. Checking That a Specific Column Contains Only Unique Values
# Write a Pandas program to check that a specific column contains only unique values.


def is_unique(column_name, dataframe):
    if dataframe[column_name].is_unique:
        print("The column {:<20} contains only unique values.".format(column_name))
    else:
        print("The column {:<20} has more than one unique value - has duplicates.".format(column_name))

for col in df.columns:
    is_unique(col, df)
# Out:
# The column date                 has more than one unique value - has duplicates.
# The column customer_id          has more than one unique value - has duplicates.
# The column product_id           has more than one unique value - has duplicates.
# The column quantity             has more than one unique value - has duplicates.
# The column price                has more than one unique value - has duplicates.
# The column discount             has more than one unique value - has duplicates.
# The column revenue              has more than one unique value - has duplicates.
# The column store_id             has more than one unique value - has duplicates.
# The column region               has more than one unique value - has duplicates.
# The column payment_method       has more than one unique value - has duplicates.
# The column is_member            has more than one unique value - has duplicates.
# The column delivery_days        has more than one unique value - has duplicates.
# The column customer_age         has more than one unique value - has duplicates.
# The column gender               has more than one unique value - has duplicates.
# The column product_category     has more than one unique value - has duplicates.
# The column rating               has more than one unique value - has duplicates.
# The column return_status        has more than one unique value - has duplicates.
# The column feedback             has more than one unique value - has duplicates.
# The column shipping_cost        has more than one unique value - has duplicates.
# The column coupon_code          has more than one unique value - has duplicates.
# The column delivery_rating      has more than one unique value - has duplicates.
# The column unique_id            contains only unique values.

# %% [markdown]
# <div class="alert alert-warning">
#
# **8. Detecting Outliers in a DataFrame**
#
# **Write a Pandas program to detect outliers in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1959         197         7  9999.99      0.10  480.3120
# 1  2023-01-02         1195         140         5    39.88      0.19  161.5140
# 2  2023-01-03         1502         119         6    11.56      0.28   49.9392
# 3  2023-01-04         1140         142         4  8888.88      0.11  294.2340
# 4  2023-01-05         1272         186         3    81.04      0.24  184.7712
# 5  2023-01-06         1616         182         2  7777.77      0.26  130.8616
# 6  2023-01-07         1851         124         7    41.94      0.21  231.9282
# 7  2023-01-08         1105         135         6    91.60      0.04  527.6160
# 8  2023-01-09         1162         182         5    22.56      0.12   99.2640
# 9  2023-01-10         1953         104         2    64.89      0.03  125.8866
# 10 2023-01-11         1285         169         5    58.07      0.25  217.7625
# 11 2023-01-12         1177         101         9    87.12      0.23  603.7416
# 12 2023-01-13         1149         150         6    72.45      0.20  347.7600
# 13 2023-01-14         1256         166         6    15.62      0.26   69.3528
# 14 2023-01-15         1478         191         1    91.08      0.13   79.2396
# 15 2023-01-16         1291         183         8    51.62      0.18  338.6272
# 16 2023-01-17         1766         181         9    20.29      0.17  151.5663
# 17 2023-01-18         1839         115         1    89.19      0.01   88.2981
# 18 2023-01-19         1489         146         6    24.26      0.11  129.5484
# 19 2023-01-20         1640         109         2    35.23      0.24   53.5496
# 20 2023-01-21         1562         171         1    98.50      0.15   83.7250
# 21 2023-01-22         1638         173         8    82.43      0.14  567.1184
# 22 2023-01-23         1374         105         6    59.60      0.21  282.5040
# 23 2023-01-24         1602         106         3    41.88      0.04  120.6144
# 24 2023-01-25         1764         179         3    31.95      0.12   84.3480
# 25 2023-01-26         1722         139         4    32.98      0.28   94.9824
# 26 2023-01-27         1350         197         8    94.34      0.10  679.2480
# 27 2023-01-28         1543         116         8    25.55      0.21  161.4760
# 28 2023-01-29         1073         173         4    60.60      0.23  186.6480
# 29 2023-01-30         1096         120         8    47.39      0.05  360.1640
# 30 2023-01-31         1177         103         7    89.97      0.18  516.4278
# 31 2023-02-01         1777         105         6    14.37      0.05   81.9090
# 32 2023-02-02         1387         109         5    65.68      0.01  325.1160
# 33 2023-02-03         1504         174         5    55.81      0.04  267.8880
# 34 2023-02-04         1355         107         9    10.55      0.02   93.0510
# 35 2023-01-27         1350         197         8    94.34      0.10  679.2480
# 36 2023-01-14         1256         166         6    15.62      0.26   69.3528
# 37 2023-01-25         1764         179         3    31.95      0.12   84.3480
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          7  North           Cash      False              4            58
# 1          4  South    Credit Card       True              6            45
# 2          7  North           Cash      False              1            44
# 3          5   East           Cash       True              4            57
# 4          5  North         Online       True              4            42
# 5          4  South           Cash      False              1            43
# 6          3  North           Cash      False              1            32
# 7          1  South         Online      False              5            34
# 8          5  North           Cash      False              1            47
# 9          8  South    Credit Card       True              2            36
# 10         8  North    Credit Card       True              2            22
# 11         9  South         Online      False              1            49
# 12         3   West         Online       True              3            52
# 13         8   West    Credit Card      False              6            28
# 14         8   West           Cash      False              2            24
# 15         9   East    Credit Card      False              2            48
# 16         7   West    Credit Card      False              6            49
# 17         6   West           Cash      False              4            23
# 18         5   West    Credit Card       True              5            39
# 19         3  North    Credit Card       True              3            38
# 20         4   East           Cash      False              1            22
# 21         5   West           Cash       True              3            48
# 22         5   East         Online       True              2            47
# 23         3   West    Credit Card       True              6            28
# 24         3  North    Credit Card       True              1            35
# 25         4  North    Credit Card      False              3            25
# 26         8   East           Cash       True              5            67
# 27         8   West         Online      False              5            27
# 28         1   East         Online       True              5            21
# 29         7   West         Online       True              1            18
# 30         8   East    Credit Card      False              3            30
# 31         6   West         Online       True              5            43
# 32         1  North    Credit Card       True              2            36
# 33         2  North    Credit Card      False              6            64
# 34         2  South    Credit Card       True              4            27
# 35         8   East           Cash       True              5            67
# 36         8   West    Credit Card      False              6            28
# 37         3  North    Credit Card       True              1            35
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female             Food     3.1      Returned  Negative          12.14
# 1    Other            Books     2.1  Not Returned   Neutral            NaN
# 2    Other            Books     3.2      Returned  Positive          15.49
# 3   Female            Books     4.5      Returned  Positive            NaN
# 4   Female      Electronics     2.7      Returned   Neutral          13.20
# 5   Female            Books     1.2  Not Returned  Positive          17.94
# 6     Male            Books     4.3  Not Returned  Negative            NaN
# 7   Female         Clothing     4.1  Not Returned  Positive            NaN
# 8     Male             Food     4.7      Returned  Negative           5.23
# 9     Male            Books     1.7  Not Returned  Positive           9.74
# 10   Other      Electronics     1.6      Returned  Positive           8.00
# 11    Male      Electronics     1.5  Not Returned  Negative          18.69
# 12    Male            Books     1.1  Not Returned  Negative           9.57
# 13    Male         Clothing     3.1  Not Returned  Negative          14.42
# 14  Female             Food     2.2  Not Returned   Neutral          17.40
# 15    Male             Food     4.1  Not Returned  Negative           9.14
# 16   Other             Food     4.8      Returned   Neutral            NaN
# 17    Male      Electronics     4.9  Not Returned  Negative          18.11
# 18  Female         Clothing     4.0  Not Returned  Negative           5.47
# 19   Other      Electronics     4.8  Not Returned  Negative          19.07
# 20   Other      Electronics     1.0      Returned  Negative            NaN
# 21  Female             Food     3.0      Returned   Neutral          12.06
# 22   Other            Books     4.0  Not Returned  Positive          18.69
# 23    Male         Clothing     4.7      Returned  Negative          15.79
# 24  Female         Clothing     1.7      Returned   Neutral           9.14
# 25    Male      Electronics     2.0  Not Returned  Negative          14.32
# 26  Female            Books     2.2      Returned   Neutral          17.23
# 27  Female            Books     2.1      Returned  Negative            NaN
# 28  Female             Food     3.8  Not Returned   Neutral          15.04
# 29   Other      Electronics     1.2      Returned  Negative           7.08
# 30    Male             Food     2.8  Not Returned   Neutral           9.93
# 31  Female             Food     2.5      Returned  Positive           9.33
# 32  Female         Clothing     4.1      Returned  Negative           6.84
# 33  Female      Electronics     3.5      Returned   Neutral            NaN
# 34   Other             Food     1.7      Returned   Neutral            NaN
# 35  Female            Books     2.2      Returned   Neutral          17.23
# 36    Male         Clothing     3.1  Not Returned  Negative          14.42
# 37  Female         Clothing     1.7      Returned   Neutral           9.14
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              3.8          1
# 1          nan              2.3          2
# 2          nan              2.1          3
# 3       SAVE10              3.4          4
# 4          nan              NaN          5
# 5     WELCOME5              2.2          6
# 6       SAVE10              4.5          7
# 7     WELCOME5              NaN          8
# 8          nan              3.9          9
# 9          nan              4.8         10
# 10    FREESHIP              2.7         11
# 11         nan              2.5         12
# 12         nan              NaN         13
# 13    WELCOME5              3.5         14
# 14    WELCOME5              2.4         15
# 15    WELCOME5              NaN         16
# 16      SAVE10              2.0         17
# 17         nan              1.4         18
# 18         nan              3.8         19
# 19    WELCOME5              NaN         20
# 20      SAVE10              4.5         21
# 21         nan              3.9         22
# 22    WELCOME5              NaN         23
# 23         nan              3.2         24
# 24    WELCOME5              4.5         25
# 25         nan              3.1         26
# 26         nan              1.3         27
# 27    FREESHIP              4.8         28
# 28         nan              NaN         29
# 29    WELCOME5              NaN         30
# 30    FREESHIP              NaN         31
# 31         nan              NaN         32
# 32      SAVE10              3.3         33
# 33    FREESHIP              5.0         34
# 34         nan              NaN         35
# 35         nan              1.3         36
# 36    WELCOME5              3.5         37
# 37    WELCOME5              4.5         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 08:**
# </div>

# %%
# 8. Detecting Outliers in a DataFrame
# Write a Pandas program to detect outliers in a DataFrame.

def detect_outliers(column_name, dataframe):
    if dataframe[column_name].dtype not in [np.float64, np.int64]:
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        Q1 = dataframe[column_name].quantile(0.25)
        Q3 = dataframe[column_name].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = dataframe[(dataframe[column_name] < lower_bound) | (dataframe[column_name] > upper_bound)]
    if not outliers.empty:
        print("Column {:>30} OUTLIERS DETECTED.\n####### OUTLIERS #######".format(column_name))
        display(outliers)
    else:
        print("Column {:>30} has no outliers detected.".format(column_name))

for col in df.columns:
    detect_outliers(col, df)
# Out:
# Column                           date is not numeric and will be skipped.
# Column                    customer_id has no outliers detected.
# Column                     product_id has no outliers detected.
# Column                       quantity has no outliers detected.
# Column                          price OUTLIERS DETECTED.
# ####### OUTLIERS #######
#         date  customer_id  product_id  quantity    price  discount   revenue  \
# 0 2023-01-01         1959         197         7  9999.99      0.10  480.3120
# 3 2023-01-04         1140         142         4  8888.88      0.11  294.2340
# 5 2023-01-06         1616         182         2  7777.77      0.26  130.8616
#
#    store_id region payment_method  is_member  delivery_days  customer_age  \
# 0         7  North           Cash      False              4            58
# 3         5   East           Cash       True              4            57
# 5         4  South           Cash      False              1            43
#
#    gender product_category  rating return_status  feedback  shipping_cost  \
# 0  Female             Food     3.1      Returned  Negative          12.14
# 3  Female            Books     4.5      Returned  Positive            NaN
# 5  Female            Books     1.2  Not Returned  Positive          17.94
#
#   coupon_code  delivery_rating  unique_id
# 0         nan              3.8          1
# 3      SAVE10              3.4          4
# 5    WELCOME5              2.2          6
# Column                       discount has no outliers detected.
# Column                        revenue has no outliers detected.
# Column                       store_id has no outliers detected.
# Column                         region is not numeric and will be skipped.
# Column                 payment_method is not numeric and will be skipped.
# Column                      is_member is not numeric and will be skipped.
# Column                  delivery_days has no outliers detected.
# Column                   customer_age has no outliers detected.
# Column                         gender is not numeric and will be skipped.
# Column               product_category is not numeric and will be skipped.
# Column                         rating has no outliers detected.
# Column                  return_status is not numeric and will be skipped.
# Column                       feedback is not numeric and will be skipped.
# Column                  shipping_cost has no outliers detected.
# Column                    coupon_code is not numeric and will be skipped.
# Column                delivery_rating has no outliers detected.
# Column                      unique_id has no outliers detected.

# %%
# finding outliers using the 3-σ rule

def detect_outliers_3sigma(column_name, dataframe):
    if dataframe[column_name].dtype not in [np.float64, np.int64]:
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        mean = dataframe[column_name].mean()
        std = dataframe[column_name].std()
        lower_bound = mean - 3 * std
        upper_bound = mean + 3 * std
        outliers = dataframe[(dataframe[column_name] < lower_bound) | (dataframe[column_name] > upper_bound)]
    
    if not outliers.empty:
        print("Column {:>30} OUTLIERS DETECTED (3σ rule).\n####### OUTLIERS #######".format(column_name))
        display(outliers)
    else:
        print("Column {:>30} has no outliers detected.".format(column_name))

# Apply to all columns
for col in df.columns:
    detect_outliers_3sigma(col, df)
# Out:
# Column                           date is not numeric and will be skipped.
# Column                    customer_id has no outliers detected.
# Column                     product_id has no outliers detected.
# Column                       quantity has no outliers detected.
# Column                          price OUTLIERS DETECTED (3σ rule).
# ####### OUTLIERS #######
#         date  customer_id  product_id  quantity    price  discount   revenue  \
# 0 2023-01-01         1959         197         7  9999.99      0.10  480.3120
# 3 2023-01-04         1140         142         4  8888.88      0.11  294.2340
# 5 2023-01-06         1616         182         2  7777.77      0.26  130.8616
#
#    store_id region payment_method  is_member  delivery_days  customer_age  \
# 0         7  North           Cash      False              4            58
# 3         5   East           Cash       True              4            57
# 5         4  South           Cash      False              1            43
#
#    gender product_category  rating return_status  feedback  shipping_cost  \
# 0  Female             Food     3.1      Returned  Negative          12.14
# 3  Female            Books     4.5      Returned  Positive            NaN
# 5  Female            Books     1.2  Not Returned  Positive          17.94
#
#   coupon_code  delivery_rating  unique_id
# 0         nan              3.8          1
# 3      SAVE10              3.4          4
# 5    WELCOME5              2.2          6
# Column                       discount has no outliers detected.
# Column                        revenue has no outliers detected.
# Column                       store_id has no outliers detected.
# Column                         region is not numeric and will be skipped.
# Column                 payment_method is not numeric and will be skipped.
# Column                      is_member is not numeric and will be skipped.
# Column                  delivery_days has no outliers detected.
# Column                   customer_age has no outliers detected.
# Column                         gender is not numeric and will be skipped.
# Column               product_category is not numeric and will be skipped.
# Column                         rating has no outliers detected.
# Column                  return_status is not numeric and will be skipped.
# Column                       feedback is not numeric and will be skipped.
# Column                  shipping_cost has no outliers detected.
# Column                    coupon_code is not numeric and will be skipped.
# Column                delivery_rating has no outliers detected.
# Column                      unique_id has no outliers detected.

# %% [markdown]
# <div class="alert alert-warning">
#
# **9. Validating Date Formats in a DataFrame**
#
# **Write a Pandas program to validate date formats in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1523         173         6  9999.99      0.03   87.3000
# 1  2023-01-02         1644         192         3    11.17      0.01   33.1749
# 2  2023-01-03         1642         186         9    66.33      0.28  429.8184
# 3  2023-01-04         1343         146         1  8888.88      0.02   48.3826
# 4  2023-01-05         1074         115         5    85.57      0.27  312.3305
# 5  2023-01-06         1823         127         1  7777.77      0.11   67.5421
# 6  2023-01-07         1480         193         2    73.18      0.21  115.6244
# 7  2023-01-08         1747         149         1    74.13      0.26   54.8562
# 8  2023-01-09         1939         129         8    75.49      0.09  549.5672
# 9  2023-01-10         1393         147         2    49.76      0.12   87.5776
# 10 2023-01-11         1149         190         3    26.71      0.25   60.0975
# 11 2023-01-12         1042         177         9    33.34      0.29  213.0426
# 12 2023-01-13         1576         175         6    92.94      0.22  434.9592
# 13 2023-01-14         1117         185         2    14.22      0.12   25.0272
# 14 2023-01-15         1733         135         6    78.06      0.04  449.6256
# 15 2023-01-16         1178         157         9    41.30      0.09  338.2470
# 16 2023-01-17         1712         125         6    75.14      0.07  419.2812
# 17 2023-01-18         1201         199         6    87.50      0.13  456.7500
# 18 2023-01-19         1986         123         9    91.50      0.14  708.2100
# 19 2023-01-20         1566         173         3    86.58      0.20  207.7920
# 20 2023-01-21         1999         136         3    78.26      0.14  201.9108
# 21 2023-01-22         1139         111         5    66.03      0.08  303.7380
# 22 2023-01-23         1829         112         2    16.26      0.12   28.6176
# 23 2023-01-24         1653         147         5    74.43      0.06  349.8210
# 24 2023-01-25         1338         168         3    29.68      0.09   81.0264
# 25 2023-01-26         1248         154         7    63.55      0.02  435.9530
# 26 2023-01-27         1621         195         1    52.52      0.18   43.0664
# 27 2023-01-28         1075         185         4    65.82      0.11  234.3192
# 28 2023-01-29         1941         162         2    14.08      0.08   25.9072
# 29 2023-01-30         1877         183         9    68.99      0.23  478.1007
# 30 2023-01-31         1930         191         4    72.22      0.08  265.7696
# 31 2023-02-01         1811         130         7    22.75      0.17  132.1775
# 32 2023-02-02         1463         118         5    15.89      0.18   65.1490
# 33 2023-02-03         1110         129         1    25.91      0.14   22.2826
# 34 2023-02-04         1969         139         3    39.35      0.29   83.8155
# 35 2023-01-27         1621         195         1    52.52      0.18   43.0664
# 36 2023-01-14         1117         185         2    14.22      0.12   25.0272
# 37 2023-01-25         1338         168         3    29.68      0.09   81.0264
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          2  North         Online       True              1            46
# 1          1  South    Credit Card      False              5            57
# 2          4   East    Credit Card       True              3            67
# 3          6   West    Credit Card       True              1            67
# 4          6  South           Cash      False              6            40
# 5          4  South         Online      False              1            34
# 6          9   West    Credit Card       True              1            21
# 7          3   East         Online       True              5            62
# 8          5  South           Cash      False              1            37
# 9          1   East         Online       True              6            69
# 10         7   West           Cash       True              4            49
# 11         7   East           Cash       True              3            55
# 12         6   West         Online      False              6            53
# 13         7   East           Cash      False              3            23
# 14         6  South         Online       True              4            18
# 15         3  South           Cash      False              2            37
# 16         8  North    Credit Card      False              2            60
# 17         3  South         Online       True              1            36
# 18         8  North           Cash       True              6            63
# 19         4   West         Online       True              1            23
# 20         7   West         Online      False              3            44
# 21         4  North         Online       True              4            27
# 22         5  North         Online      False              1            36
# 23         2  South         Online       True              2            47
# 24         7   East           Cash       True              3            46
# 25         8   West         Online      False              3            44
# 26         6  South           Cash       True              4            45
# 27         3   East         Online       True              4            60
# 28         1   East    Credit Card      False              1            62
# 29         8   East           Cash      False              1            30
# 30         3  South           Cash       True              4            53
# 31         5   East           Cash      False              6            62
# 32         9   East           Cash      False              5            40
# 33         3  North    Credit Card      False              1            43
# 34         8   East         Online       True              5            21
# 35         6  South           Cash       True              4            45
# 36         7   East           Cash      False              3            23
# 37         7   East           Cash       True              3            46
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female         Clothing     2.7  Not Returned  Positive           9.41
# 1    Other         Clothing     3.4      Returned  Positive            NaN
# 2     Male         Clothing     4.9      Returned  Positive          18.80
# 3    Other         Clothing     2.0      Returned  Positive           9.85
# 4   Female         Clothing     5.0  Not Returned   Neutral           9.45
# 5   Female             Food     2.1      Returned  Negative          15.00
# 6     Male            Books     3.4  Not Returned   Neutral           6.85
# 7     Male            Books     2.2  Not Returned  Positive          12.32
# 8   Female      Electronics     1.4  Not Returned   Neutral          11.06
# 9    Other      Electronics     2.7      Returned  Negative          15.42
# 10    Male      Electronics     4.1  Not Returned   Neutral          11.87
# 11   Other            Books     2.6      Returned   Neutral          15.27
# 12   Other      Electronics     2.5      Returned  Negative          16.48
# 13  Female             Food     4.3      Returned  Negative           7.34
# 14  Female         Clothing     1.6  Not Returned  Positive          10.54
# 15  Female            Books     2.5      Returned  Negative          16.17
# 16   Other      Electronics     1.5  Not Returned  Positive            NaN
# 17  Female            Books     1.6  Not Returned  Negative          17.75
# 18    Male         Clothing     1.9  Not Returned   Neutral          19.34
# 19    Male            Books     4.3  Not Returned   Neutral          10.20
# 20    Male             Food     1.2      Returned  Positive          18.52
# 21    Male            Books     1.4      Returned  Positive          15.27
# 22  Female      Electronics     3.4      Returned   Neutral          10.01
# 23    Male      Electronics     1.3  Not Returned  Positive          10.60
# 24   Other      Electronics     1.4      Returned   Neutral          19.17
# 25  Female         Clothing     2.8      Returned   Neutral          17.90
# 26  Female      Electronics     1.2  Not Returned  Negative           6.18
# 27  Female         Clothing     3.3  Not Returned  Positive          10.48
# 28    Male         Clothing     1.3  Not Returned  Positive           6.95
# 29    Male      Electronics     4.8      Returned  Positive          12.70
# 30  Female             Food     1.5      Returned   Neutral            NaN
# 31  Female      Electronics     2.8      Returned  Positive          14.11
# 32   Other             Food     2.4  Not Returned  Negative          17.51
# 33  Female      Electronics     4.5      Returned   Neutral          19.19
# 34    Male         Clothing     3.0      Returned  Negative           9.16
# 35  Female      Electronics     1.2  Not Returned  Negative           6.18
# 36  Female             Food     4.3      Returned  Negative           7.34
# 37   Other      Electronics     1.4      Returned   Neutral          19.17
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              NaN          1
# 1       SAVE10              4.6          2
# 2     FREESHIP              NaN          3
# 3     FREESHIP              3.4          4
# 4          nan              1.2          5
# 5     WELCOME5              2.3          6
# 6          nan              3.6          7
# 7          nan              1.1          8
# 8          nan              2.0          9
# 9       SAVE10              NaN         10
# 10    WELCOME5              1.2         11
# 11    FREESHIP              3.4         12
# 12    WELCOME5              NaN         13
# 13    FREESHIP              4.0         14
# 14    WELCOME5              3.7         15
# 15      SAVE10              NaN         16
# 16    FREESHIP              2.6         17
# 17         nan              1.5         18
# 18    FREESHIP              1.3         19
# 19         nan              NaN         20
# 20    FREESHIP              NaN         21
# 21    WELCOME5              NaN         22
# 22         nan              1.0         23
# 23         nan              2.6         24
# 24    WELCOME5              3.4         25
# 25         nan              1.1         26
# 26    FREESHIP              1.2         27
# 27    FREESHIP              NaN         28
# 28         nan              NaN         29
# 29    WELCOME5              NaN         30
# 30         nan              3.3         31
# 31         nan              4.2         32
# 32         nan              1.4         33
# 33      SAVE10              2.6         34
# 34    FREESHIP              2.0         35
# 35    FREESHIP              1.2         36
# 36    FREESHIP              4.0         37
# 37    WELCOME5              3.4         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 09:**
# </div>

# %%
# 9. Validating Date Formats in a DataFrame
# Write a Pandas program to validate date formats in a DataFrame.

def validate_date_formats(date_column, dataframe):
    if not pd.api.types.is_datetime64_any_dtype(dataframe[date_column]):
        print("Column {:>30} is not a datetime type and will be skipped.".format(date_column))
        return
    else:
        invalid_dates = dataframe[~dataframe[date_column].dt.strftime('%Y-%m-%d').str.match(r'^\d{4}-\d{2}-\d{2}$')]
    if not invalid_dates.empty:
        print("Column {:>30} INVALID DATES DETECTED.\n####### INVALID DATES #######".format(date_column))
        display(invalid_dates)
    else:
        print("Column {:>30} has no invalid dates detected.".format(date_column))

# Apply to all columns
for col in df.columns:
    validate_date_formats(col, df)
# Out:
# Column                           date has no invalid dates detected.
# Column                    customer_id is not a datetime type and will be skipped.
# Column                     product_id is not a datetime type and will be skipped.
# Column                       quantity is not a datetime type and will be skipped.
# Column                          price is not a datetime type and will be skipped.
# Column                       discount is not a datetime type and will be skipped.
# Column                        revenue is not a datetime type and will be skipped.
# Column                       store_id is not a datetime type and will be skipped.
# Column                         region is not a datetime type and will be skipped.
# Column                 payment_method is not a datetime type and will be skipped.
# Column                      is_member is not a datetime type and will be skipped.
# Column                  delivery_days is not a datetime type and will be skipped.
# Column                   customer_age is not a datetime type and will be skipped.
# Column                         gender is not a datetime type and will be skipped.
# Column               product_category is not a datetime type and will be skipped.
# Column                         rating is not a datetime type and will be skipped.
# Column                  return_status is not a datetime type and will be skipped.
# Column                       feedback is not a datetime type and will be skipped.
# Column                  shipping_cost is not a datetime type and will be skipped.
# Column                    coupon_code is not a datetime type and will be skipped.
# Column                delivery_rating is not a datetime type and will be skipped.
# Column                      unique_id is not a datetime type and will be skipped.

# %% [markdown]
# <div class="alert alert-warning">
#
# **10. Ensuring No Missing Values in a Critical Column**
#
# **Write a Pandas program that ensures no missing values in a critical column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1409         187         6  9999.99      0.28  393.1200
# 1  2023-01-02         1245         122         6    56.23      0.04  323.8848
# 2  2023-01-03         1529         149         8    98.66      0.28  568.2816
# 3  2023-01-04         1361         140         5  8888.88      0.04  460.8480
# 4  2023-01-05         1739         191         3    46.62      0.15  118.8810
# 5  2023-01-06         1106         138         3  7777.77      0.27  181.5948
# 6  2023-01-07         1477         165         4    86.90      0.03  337.1720
# 7  2023-01-08         1566         157         7    26.69      0.22  145.7274
# 8  2023-01-09         1453         115         9    54.12      0.07  452.9844
# 9  2023-01-10         1985         112         3    29.66      0.13   77.4126
# 10 2023-01-11         1991         182         6    45.34      0.12  239.3952
# 11 2023-01-12         1369         174         2    59.11      0.02  115.8556
# 12 2023-01-13         1448         152         4    34.58      0.14  118.9552
# 13 2023-01-14         1841         185         4    65.77      0.09  239.4028
# 14 2023-01-15         1531         198         9    77.61      0.11  621.6561
# 15 2023-01-16         1698         129         7    88.71      0.03  602.3409
# 16 2023-01-17         1314         192         3    69.57      0.27  152.3583
# 17 2023-01-18         1165         115         7    45.23      0.08  291.2812
# 18 2023-01-19         1942         107         3    66.28      0.29  141.1764
# 19 2023-01-20         1019         182         8    80.73      0.08  594.1728
# 20 2023-01-21         1497         142         1    22.77      0.21   17.9883
# 21 2023-01-22         1820         170         5    44.63      0.17  185.2145
# 22 2023-01-23         1191         177         8    65.18      0.25  391.0800
# 23 2023-01-24         1092         127         7    38.42      0.24  204.3944
# 24 2023-01-25         1638         191         6    86.14      0.27  377.2932
# 25 2023-01-26         1235         173         4    29.63      0.26   87.7048
# 26 2023-01-27         1062         136         1    54.49      0.07   50.6757
# 27 2023-01-28         1142         148         4    15.68      0.17   52.0576
# 28 2023-01-29         1922         105         2    97.85      0.24  148.7320
# 29 2023-01-30         1470         165         9    74.29      0.04  641.8656
# 30 2023-01-31         1603         143         8    43.77      0.02  343.1568
# 31 2023-02-01         1669         180         7    34.36      0.30  168.3640
# 32 2023-02-02         1429         115         3    48.48      0.23  111.9888
# 33 2023-02-03         1778         161         5    14.54      0.05   69.0650
# 34 2023-02-04         1344         100         6    33.14      0.19  161.0604
# 35 2023-01-27         1062         136         1    54.49      0.07   50.6757
# 36 2023-01-14         1841         185         4    65.77      0.09  239.4028
# 37 2023-01-25         1638         191         6    86.14      0.27  377.2932
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6  South           Cash      False              6            54
# 1          1  North         Online       True              1            27
# 2          4  North         Online      False              3            27
# 3          1   West    Credit Card      False              1            68
# 4          6   East           Cash       True              1            61
# 5          9  South           Cash       True              2            24
# 6          9   East    Credit Card      False              1            66
# 7          9  North    Credit Card      False              2            68
# 8          6  South    Credit Card      False              3            67
# 9          3  South    Credit Card       True              6            31
# 10         9   West    Credit Card      False              6            34
# 11         6  North           Cash       True              4            32
# 12         3  North    Credit Card      False              2            33
# 13         6   East    Credit Card       True              1            57
# 14         1  North         Online      False              6            32
# 15         7   West           Cash      False              6            19
# 16         8  South           Cash       True              1            57
# 17         3   West         Online       True              4            41
# 18         1  North         Online      False              5            20
# 19         4   East         Online      False              1            42
# 20         6  South    Credit Card       True              2            21
# 21         8  North         Online       True              3            37
# 22         8   East         Online      False              3            62
# 23         7  South           Cash       True              6            33
# 24         6   West    Credit Card       True              5            57
# 25         1   West           Cash       True              3            60
# 26         1  South    Credit Card       True              4            39
# 27         9  South         Online      False              3            43
# 28         1  South           Cash       True              1            39
# 29         2  North           Cash      False              3            52
# 30         2  South           Cash      False              5            57
# 31         5  South         Online      False              3            61
# 32         3   West           Cash      False              5            20
# 33         8   West           Cash      False              5            41
# 34         4   East         Online      False              4            26
# 35         1  South    Credit Card       True              4            39
# 36         6   East    Credit Card       True              1            57
# 37         6   West    Credit Card       True              5            57
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male             Food     5.0  Not Returned   Neutral          13.61
# 1     Male            Books     3.5      Returned   Neutral           5.42
# 2   Female            Books     1.1  Not Returned  Positive           7.35
# 3    Other      Electronics     2.9      Returned   Neutral          15.20
# 4     Male         Clothing     4.4      Returned  Positive          11.61
# 5   Female      Electronics     4.1  Not Returned   Neutral            NaN
# 6    Other         Clothing     4.8  Not Returned  Negative          19.40
# 7   Female         Clothing     2.9  Not Returned  Positive            NaN
# 8     Male         Clothing     2.7  Not Returned  Negative          16.62
# 9     Male             Food     4.8  Not Returned  Negative          12.03
# 10    Male            Books     3.9  Not Returned   Neutral           6.62
# 11   Other             Food     4.8      Returned  Positive          13.27
# 12   Other         Clothing     4.0  Not Returned   Neutral          18.42
# 13  Female            Books     4.1  Not Returned   Neutral            NaN
# 14   Other            Books     1.8  Not Returned  Positive          17.69
# 15   Other            Books     4.6      Returned  Negative          10.87
# 16    Male             Food     3.4      Returned  Positive          13.89
# 17  Female         Clothing     3.5  Not Returned   Neutral          12.16
# 18   Other             Food     3.1  Not Returned  Positive          13.40
# 19  Female      Electronics     1.2  Not Returned   Neutral          11.36
# 20    Male         Clothing     3.0  Not Returned   Neutral            NaN
# 21    Male             Food     2.9  Not Returned  Negative          11.65
# 22  Female            Books     1.3  Not Returned   Neutral           5.34
# 23   Other             Food     2.5  Not Returned  Positive          16.86
# 24  Female         Clothing     3.2      Returned   Neutral           5.75
# 25    Male            Books     3.4      Returned  Negative           5.92
# 26    Male         Clothing     3.0      Returned  Negative          15.21
# 27  Female         Clothing     3.3  Not Returned  Negative          18.82
# 28    Male      Electronics     3.4      Returned   Neutral          17.48
# 29  Female             Food     4.3  Not Returned  Positive            NaN
# 30  Female             Food     4.3  Not Returned  Negative          15.10
# 31  Female             Food     1.7  Not Returned   Neutral          18.62
# 32  Female            Books     2.1  Not Returned  Negative          17.34
# 33  Female             Food     4.4  Not Returned  Positive          10.53
# 34   Other         Clothing     3.3  Not Returned  Negative          14.06
# 35    Male         Clothing     3.0      Returned  Negative          15.21
# 36  Female            Books     4.1  Not Returned   Neutral            NaN
# 37  Female         Clothing     3.2      Returned   Neutral           5.75
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              4.4          1
# 1     FREESHIP              NaN          2
# 2       SAVE10              NaN          3
# 3       SAVE10              1.8          4
# 4          nan              NaN          5
# 5          nan              NaN          6
# 6       SAVE10              4.7          7
# 7       SAVE10              4.2          8
# 8       SAVE10              NaN          9
# 9     WELCOME5              3.6         10
# 10         nan              4.9         11
# 11    WELCOME5              NaN         12
# 12    FREESHIP              1.6         13
# 13      SAVE10              2.8         14
# 14         nan              2.5         15
# 15      SAVE10              1.1         16
# 16    WELCOME5              4.8         17
# 17    WELCOME5              NaN         18
# 18    WELCOME5              2.4         19
# 19         nan              2.0         20
# 20         nan              3.0         21
# 21    FREESHIP              NaN         22
# 22         nan              4.9         23
# 23      SAVE10              NaN         24
# 24    FREESHIP              NaN         25
# 25    FREESHIP              NaN         26
# 26         nan              NaN         27
# 27    FREESHIP              4.4         28
# 28         nan              2.5         29
# 29      SAVE10              3.2         30
# 30      SAVE10              2.0         31
# 31         nan              3.4         32
# 32    FREESHIP              1.5         33
# 33    FREESHIP              2.2         34
# 34         nan              1.8         35
# 35         nan              NaN         36
# 36      SAVE10              2.8         37
# 37    FREESHIP              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 10:**
# </div>

# %%
# 10. Ensuring No Missing Values in a Critical Column
# Write a Pandas program that ensures no missing values in a critical column.

def check_missing_values(column_name, dataframe):
    missing_values = dataframe[column_name].isnull().sum()
    if missing_values > 0:
        print("Column {:>30} has {} missing values.".format(column_name, missing_values))
        display(dataframe[dataframe[column_name].isnull()])
    else:
        print("Column {:>30} has no missing values.".format(column_name))

# Apply to all columns
for col in df.columns:
    check_missing_values(col, df)
# Out:
# Column                           date has no missing values.
# Column                    customer_id has no missing values.
# Column                     product_id has no missing values.
# Column                       quantity has no missing values.
# Column                          price has no missing values.
# Column                       discount has no missing values.
# Column                        revenue has no missing values.
# Column                       store_id has no missing values.
# Column                         region has no missing values.
# Column                 payment_method has no missing values.
# Column                      is_member has no missing values.
# Column                  delivery_days has no missing values.
# Column                   customer_age has no missing values.
# Column                         gender has no missing values.
# Column               product_category has no missing values.
# Column                         rating has no missing values.
# Column                  return_status has no missing values.
# Column                       feedback has no missing values.
# Column                  shipping_cost has 9 missing values.
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 5  2023-01-06         1106         138         3  7777.77      0.27  181.5948
# 7  2023-01-08         1566         157         7    26.69      0.22  145.7274
# 13 2023-01-14         1841         185         4    65.77      0.09  239.4028
# 20 2023-01-21         1497         142         1    22.77      0.21   17.9883
# 29 2023-01-30         1470         165         9    74.29      0.04  641.8656
# 36 2023-01-14         1841         185         4    65.77      0.09  239.4028
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 5          9  South           Cash       True              2            24
# 7          9  North    Credit Card      False              2            68
# 13         6   East    Credit Card       True              1            57
# 20         6  South    Credit Card       True              2            21
# 29         2  North           Cash      False              3            52
# 36         6   East    Credit Card       True              1            57
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 5   Female      Electronics     4.1  Not Returned   Neutral            NaN
# 7   Female         Clothing     2.9  Not Returned  Positive            NaN
# 13  Female            Books     4.1  Not Returned   Neutral            NaN
# 20    Male         Clothing     3.0  Not Returned   Neutral            NaN
# 29  Female             Food     4.3  Not Returned  Positive            NaN
# 36  Female            Books     4.1  Not Returned   Neutral            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 5          nan              NaN          6
# 7       SAVE10              4.2          8
# 13      SAVE10              2.8         14
# 20         nan              3.0         21
# 29      SAVE10              3.2         30
# 36      SAVE10              2.8         37
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                    coupon_code has 3 missing values.
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                delivery_rating has 17 missing values.
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 1  2023-01-02         1245         122         6    56.23      0.04  323.8848
# 2  2023-01-03         1529         149         8    98.66      0.28  568.2816
# 4  2023-01-05         1739         191         3    46.62      0.15  118.8810
# 5  2023-01-06         1106         138         3  7777.77      0.27  181.5948
# 8  2023-01-09         1453         115         9    54.12      0.07  452.9844
# 11 2023-01-12         1369         174         2    59.11      0.02  115.8556
# 17 2023-01-18         1165         115         7    45.23      0.08  291.2812
# 21 2023-01-22         1820         170         5    44.63      0.17  185.2145
# 23 2023-01-24         1092         127         7    38.42      0.24  204.3944
# 24 2023-01-25         1638         191         6    86.14      0.27  377.2932
# 25 2023-01-26         1235         173         4    29.63      0.26   87.7048
# 26 2023-01-27         1062         136         1    54.49      0.07   50.6757
# 35 2023-01-27         1062         136         1    54.49      0.07   50.6757
# 37 2023-01-25         1638         191         6    86.14      0.27  377.2932
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 1          1  North         Online       True              1            27
# 2          4  North         Online      False              3            27
# 4          6   East           Cash       True              1            61
# 5          9  South           Cash       True              2            24
# 8          6  South    Credit Card      False              3            67
# 11         6  North           Cash       True              4            32
# 17         3   West         Online       True              4            41
# 21         8  North         Online       True              3            37
# 23         7  South           Cash       True              6            33
# 24         6   West    Credit Card       True              5            57
# 25         1   West           Cash       True              3            60
# 26         1  South    Credit Card       True              4            39
# 35         1  South    Credit Card       True              4            39
# 37         6   West    Credit Card       True              5            57
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 1     Male            Books     3.5      Returned   Neutral           5.42
# 2   Female            Books     1.1  Not Returned  Positive           7.35
# 4     Male         Clothing     4.4      Returned  Positive          11.61
# 5   Female      Electronics     4.1  Not Returned   Neutral            NaN
# 8     Male         Clothing     2.7  Not Returned  Negative          16.62
# 11   Other             Food     4.8      Returned  Positive          13.27
# 17  Female         Clothing     3.5  Not Returned   Neutral          12.16
# 21    Male             Food     2.9  Not Returned  Negative          11.65
# 23   Other             Food     2.5  Not Returned  Positive          16.86
# 24  Female         Clothing     3.2      Returned   Neutral           5.75
# 25    Male            Books     3.4      Returned  Negative           5.92
# 26    Male         Clothing     3.0      Returned  Negative          15.21
# 35    Male         Clothing     3.0      Returned  Negative          15.21
# 37  Female         Clothing     3.2      Returned   Neutral           5.75
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 1     FREESHIP              NaN          2
# 2       SAVE10              NaN          3
# 4          nan              NaN          5
# 5          nan              NaN          6
# 8       SAVE10              NaN          9
# 11    WELCOME5              NaN         12
# 17    WELCOME5              NaN         18
# 21    FREESHIP              NaN         22
# 23      SAVE10              NaN         24
# 24    FREESHIP              NaN         25
# 25    FREESHIP              NaN         26
# 26         nan              NaN         27
# 35         nan              NaN         36
# 37    FREESHIP              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                      unique_id has no missing values.

# %% [markdown]
# <div class="alert alert-warning">
#
# **11. Validating String Length in a DataFrame Column**
#
# **Write a Pandas program that validates string length in a DataFrame column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1792         161         6  9999.99      0.21  449.2098
# 1  2023-01-02         1478         175         4    11.96      0.18   39.2288
# 2  2023-01-03         1164         153         4    99.41      0.07  369.8052
# 3  2023-01-04         1377         142         4  8888.88      0.21  241.8032
# 4  2023-01-05         1247         153         3    85.99      0.26  190.8978
# 5  2023-01-06         1129         169         8  7777.77      0.03  692.5800
# 6  2023-01-07         1923         180         4    68.77      0.14  236.5688
# 7  2023-01-08         1443         128         5    95.84      0.22  373.7760
# 8  2023-01-09         1188         141         6    26.66      0.26  118.3704
# 9  2023-01-10         1224         132         1    50.80      0.06   47.7520
# 10 2023-01-11         1818         197         9    55.84      0.11  447.2784
# 11 2023-01-12         1201         103         5    94.40      0.27  344.5600
# 12 2023-01-13         1337         196         7    38.04      0.23  205.0356
# 13 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 14 2023-01-15         1434         199         5    81.03      0.24  307.9140
# 15 2023-01-16         1687         149         5    85.78      0.07  398.8770
# 16 2023-01-17         1384         189         5    29.98      0.16  125.9160
# 17 2023-01-18         1180         185         4    71.48      0.04  274.4832
# 18 2023-01-19         1905         181         9    24.53      0.21  174.4083
# 19 2023-01-20         1289         190         6    38.36      0.15  195.6360
# 20 2023-01-21         1758         149         7    38.64      0.14  232.6128
# 21 2023-01-22         1262         139         3    34.57      0.17   86.0793
# 22 2023-01-23         1258         104         6    41.20      0.16  207.6480
# 23 2023-01-24         1384         174         9    13.55      0.04  117.0720
# 24 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 25 2023-01-26         1248         172         9    38.61      0.23  267.5673
# 26 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 27 2023-01-28         1858         134         9    91.73      0.05  784.2915
# 28 2023-01-29         1496         171         9    64.48      0.26  429.4368
# 29 2023-01-30         1732         174         4    51.33      0.21  162.2028
# 30 2023-01-31         1122         118         4    46.07      0.28  132.6816
# 31 2023-02-01         1858         168         1    41.71      0.04   40.0416
# 32 2023-02-02         1191         182         6    45.41      0.02  267.0108
# 33 2023-02-03         1622         140         5    42.39      0.02  207.7110
# 34 2023-02-04         1708         173         2    87.90      0.11  156.4620
# 35 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 36 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 37 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East         Online      False              6            45
# 1          9   East           Cash       True              3            25
# 2          9  North           Cash       True              6            25
# 3          6  North           Cash      False              4            37
# 4          3  South         Online      False              3            27
# 5          2   West         Online       True              5            55
# 6          5   East    Credit Card      False              1            41
# 7          9   East           Cash      False              5            18
# 8          3   East    Credit Card       True              4            41
# 9          8   East           Cash       True              4            21
# 10         9  South    Credit Card      False              5            30
# 11         5   West           Cash      False              2            29
# 12         9   West    Credit Card       True              3            35
# 13         4   West    Credit Card      False              5            38
# 14         9   East           Cash       True              3            25
# 15         2   East           Cash      False              2            58
# 16         4   East         Online       True              4            34
# 17         4  North           Cash       True              3            54
# 18         8   West           Cash      False              4            21
# 19         5   West    Credit Card      False              3            64
# 20         4  North    Credit Card       True              6            60
# 21         6   East           Cash       True              2            49
# 22         3  North           Cash       True              1            52
# 23         2   East           Cash      False              2            63
# 24         8   West           Cash      False              6            20
# 25         8  North           Cash       True              6            52
# 26         7  South           Cash      False              3            32
# 27         4  South    Credit Card      False              6            69
# 28         7  North    Credit Card       True              1            52
# 29         5  North           Cash       True              3            40
# 30         1  North    Credit Card       True              6            59
# 31         7  North    Credit Card      False              6            42
# 32         9   West    Credit Card      False              2            45
# 33         4   East         Online       True              2            66
# 34         6   East           Cash      False              1            60
# 35         7  South           Cash      False              3            32
# 36         4   West    Credit Card      False              5            38
# 37         8   West           Cash      False              6            20
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     3.2  Not Returned   Neutral           8.21
# 1     Male            Books     1.3      Returned  Positive           8.44
# 2   Female         Clothing     4.9      Returned  Negative            NaN
# 3   Female      Electronics     2.8  Not Returned  Negative          10.22
# 4     Male      Electronics     4.7  Not Returned   Neutral            NaN
# 5     Male             Food     3.8  Not Returned  Positive            NaN
# 6     Male             Food     4.8      Returned   Neutral            NaN
# 7     Male         Clothing     2.7  Not Returned   Neutral          19.67
# 8   Female            Books     3.3  Not Returned   Neutral            NaN
# 9    Other             Food     1.9  Not Returned  Positive           7.46
# 10  Female             Food     1.9      Returned   Neutral           7.25
# 11  Female         Clothing     5.0  Not Returned  Positive          10.90
# 12    Male         Clothing     1.9  Not Returned  Negative          16.34
# 13  Female            Books     3.2      Returned   Neutral            NaN
# 14   Other      Electronics     3.2  Not Returned  Positive           7.25
# 15    Male      Electronics     2.9      Returned  Positive           6.86
# 16  Female             Food     2.1      Returned  Positive          19.25
# 17  Female            Books     3.3  Not Returned  Negative          13.84
# 18   Other      Electronics     1.1      Returned  Positive           8.02
# 19  Female         Clothing     2.6  Not Returned  Positive          17.19
# 20  Female            Books     4.2      Returned   Neutral          18.90
# 21   Other      Electronics     1.7  Not Returned  Positive          14.21
# 22  Female            Books     1.0  Not Returned   Neutral          19.35
# 23  Female             Food     3.8      Returned  Negative          10.86
# 24   Other         Clothing     2.1      Returned  Positive            NaN
# 25   Other            Books     2.4  Not Returned  Positive          14.31
# 26   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 27    Male             Food     3.4  Not Returned   Neutral          17.41
# 28    Male      Electronics     3.8  Not Returned   Neutral          14.75
# 29   Other             Food     2.5  Not Returned  Positive            NaN
# 30  Female      Electronics     3.8  Not Returned  Positive           7.69
# 31    Male            Books     2.9  Not Returned   Neutral          18.21
# 32   Other             Food     4.4  Not Returned   Neutral            NaN
# 33   Other      Electronics     1.5      Returned   Neutral          15.26
# 34    Male            Books     1.7      Returned   Neutral           8.04
# 35   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 36  Female            Books     3.2      Returned   Neutral            NaN
# 37   Other         Clothing     2.1      Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              4.9          1
# 1       SAVE10              1.9          2
# 2          nan              4.6          3
# 3          nan              3.9          4
# 4     FREESHIP              4.4          5
# 5       SAVE10              NaN          6
# 6       SAVE10              NaN          7
# 7          nan              4.6          8
# 8          nan              2.4          9
# 9          nan              NaN         10
# 10    FREESHIP              NaN         11
# 11         nan              4.0         12
# 12    WELCOME5              NaN         13
# 13    WELCOME5              3.5         14
# 14      SAVE10              NaN         15
# 15    WELCOME5              1.8         16
# 16         nan              NaN         17
# 17         nan              4.4         18
# 18    WELCOME5              NaN         19
# 19    FREESHIP              1.4         20
# 20         nan              NaN         21
# 21    FREESHIP              2.9         22
# 22         nan              NaN         23
# 23    WELCOME5              4.2         24
# 24         nan              4.3         25
# 25    FREESHIP              1.7         26
# 26         nan              1.5         27
# 27      SAVE10              3.3         28
# 28         nan              3.5         29
# 29      SAVE10              4.8         30
# 30    FREESHIP              NaN         31
# 31    WELCOME5              3.6         32
# 32    FREESHIP              NaN         33
# 33    FREESHIP              NaN         34
# 34         nan              4.6         35
# 35         nan              1.5         36
# 36    WELCOME5              3.5         37
# 37         nan              4.3         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 11:**
# </div>

# %%
# 11. Validating String Length in a DataFrame Column
# Write a Pandas program that validates string length in a DataFrame column.

def validate_string_length(dataframe, column_name, min_length: int=0, max_length: int=100):
    if not pd.api.types.is_string_dtype(dataframe[column_name]):
        print("Column {:>30} is not a string type and will be skipped.".format(column_name))
        return
    else:
        invalid_length = dataframe[(dataframe[column_name].str.len() < min_length) | (dataframe[column_name].str.len() > max_length)]
    if not invalid_length.empty:
        print("Column {:>30} INVALID LENGTH DETECTED.\n####### INVALID LENGTH #######".format(column_name))
        display(invalid_length)
    else:
        print("Column {:>30} has no invalid length detected.".format(column_name))

# Apply to all columns
for col in df.columns:
    validate_string_length(df, col, min_length=0, max_length=4)
# Out:
# Column                           date is not a string type and will be skipped.
# Column                    customer_id is not a string type and will be skipped.
# Column                     product_id is not a string type and will be skipped.
# Column                       quantity is not a string type and will be skipped.
# Column                          price is not a string type and will be skipped.
# Column                       discount is not a string type and will be skipped.
# Column                        revenue is not a string type and will be skipped.
# Column                       store_id is not a string type and will be skipped.
# Column                         region INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 2  2023-01-03         1164         153         4    99.41      0.07  369.8052
# 3  2023-01-04         1377         142         4  8888.88      0.21  241.8032
# 4  2023-01-05         1247         153         3    85.99      0.26  190.8978
# 10 2023-01-11         1818         197         9    55.84      0.11  447.2784
# 17 2023-01-18         1180         185         4    71.48      0.04  274.4832
# 20 2023-01-21         1758         149         7    38.64      0.14  232.6128
# 22 2023-01-23         1258         104         6    41.20      0.16  207.6480
# 25 2023-01-26         1248         172         9    38.61      0.23  267.5673
# 26 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 27 2023-01-28         1858         134         9    91.73      0.05  784.2915
# 28 2023-01-29         1496         171         9    64.48      0.26  429.4368
# 29 2023-01-30         1732         174         4    51.33      0.21  162.2028
# 30 2023-01-31         1122         118         4    46.07      0.28  132.6816
# 31 2023-02-01         1858         168         1    41.71      0.04   40.0416
# 35 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 2          9  North           Cash       True              6            25
# 3          6  North           Cash      False              4            37
# 4          3  South         Online      False              3            27
# 10         9  South    Credit Card      False              5            30
# 17         4  North           Cash       True              3            54
# 20         4  North    Credit Card       True              6            60
# 22         3  North           Cash       True              1            52
# 25         8  North           Cash       True              6            52
# 26         7  South           Cash      False              3            32
# 27         4  South    Credit Card      False              6            69
# 28         7  North    Credit Card       True              1            52
# 29         5  North           Cash       True              3            40
# 30         1  North    Credit Card       True              6            59
# 31         7  North    Credit Card      False              6            42
# 35         7  South           Cash      False              3            32
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 2   Female         Clothing     4.9      Returned  Negative            NaN
# 3   Female      Electronics     2.8  Not Returned  Negative          10.22
# 4     Male      Electronics     4.7  Not Returned   Neutral            NaN
# 10  Female             Food     1.9      Returned   Neutral           7.25
# 17  Female            Books     3.3  Not Returned  Negative          13.84
# 20  Female            Books     4.2      Returned   Neutral          18.90
# 22  Female            Books     1.0  Not Returned   Neutral          19.35
# 25   Other            Books     2.4  Not Returned  Positive          14.31
# 26   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 27    Male             Food     3.4  Not Returned   Neutral          17.41
# 28    Male      Electronics     3.8  Not Returned   Neutral          14.75
# 29   Other             Food     2.5  Not Returned  Positive            NaN
# 30  Female      Electronics     3.8  Not Returned  Positive           7.69
# 31    Male            Books     2.9  Not Returned   Neutral          18.21
# 35   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
#
#    coupon_code  delivery_rating  unique_id
# 2          nan              4.6          3
# 3          nan              3.9          4
# 4     FREESHIP              4.4          5
# 10    FREESHIP              NaN         11
# 17         nan              4.4         18
# 20         nan              NaN         21
# 22         nan              NaN         23
# 25    FREESHIP              1.7         26
# 26         nan              1.5         27
# 27      SAVE10              3.3         28
# 28         nan              3.5         29
# 29      SAVE10              4.8         30
# 30    FREESHIP              NaN         31
# 31    WELCOME5              3.6         32
# 35         nan              1.5         36
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# Column                 payment_method INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1792         161         6  9999.99      0.21  449.2098
# 4  2023-01-05         1247         153         3    85.99      0.26  190.8978
# 5  2023-01-06         1129         169         8  7777.77      0.03  692.5800
# 6  2023-01-07         1923         180         4    68.77      0.14  236.5688
# 8  2023-01-09         1188         141         6    26.66      0.26  118.3704
# 10 2023-01-11         1818         197         9    55.84      0.11  447.2784
# 12 2023-01-13         1337         196         7    38.04      0.23  205.0356
# 13 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 16 2023-01-17         1384         189         5    29.98      0.16  125.9160
# 19 2023-01-20         1289         190         6    38.36      0.15  195.6360
# 20 2023-01-21         1758         149         7    38.64      0.14  232.6128
# 27 2023-01-28         1858         134         9    91.73      0.05  784.2915
# 28 2023-01-29         1496         171         9    64.48      0.26  429.4368
# 30 2023-01-31         1122         118         4    46.07      0.28  132.6816
# 31 2023-02-01         1858         168         1    41.71      0.04   40.0416
# 32 2023-02-02         1191         182         6    45.41      0.02  267.0108
# 33 2023-02-03         1622         140         5    42.39      0.02  207.7110
# 36 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East         Online      False              6            45
# 4          3  South         Online      False              3            27
# 5          2   West         Online       True              5            55
# 6          5   East    Credit Card      False              1            41
# 8          3   East    Credit Card       True              4            41
# 10         9  South    Credit Card      False              5            30
# 12         9   West    Credit Card       True              3            35
# 13         4   West    Credit Card      False              5            38
# 16         4   East         Online       True              4            34
# 19         5   West    Credit Card      False              3            64
# 20         4  North    Credit Card       True              6            60
# 27         4  South    Credit Card      False              6            69
# 28         7  North    Credit Card       True              1            52
# 30         1  North    Credit Card       True              6            59
# 31         7  North    Credit Card      False              6            42
# 32         9   West    Credit Card      False              2            45
# 33         4   East         Online       True              2            66
# 36         4   West    Credit Card      False              5            38
# 38         5  North    Credit Card       True              3            25
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     3.2  Not Returned   Neutral           8.21
# 4     Male      Electronics     4.7  Not Returned   Neutral            NaN
# 5     Male             Food     3.8  Not Returned  Positive            NaN
# 6     Male             Food     4.8      Returned   Neutral            NaN
# 8   Female            Books     3.3  Not Returned   Neutral            NaN
# 10  Female             Food     1.9      Returned   Neutral           7.25
# 12    Male         Clothing     1.9  Not Returned  Negative          16.34
# 13  Female            Books     3.2      Returned   Neutral            NaN
# 16  Female             Food     2.1      Returned  Positive          19.25
# 19  Female         Clothing     2.6  Not Returned  Positive          17.19
# 20  Female            Books     4.2      Returned   Neutral          18.90
# 27    Male             Food     3.4  Not Returned   Neutral          17.41
# 28    Male      Electronics     3.8  Not Returned   Neutral          14.75
# 30  Female      Electronics     3.8  Not Returned  Positive           7.69
# 31    Male            Books     2.9  Not Returned   Neutral          18.21
# 32   Other             Food     4.4  Not Returned   Neutral            NaN
# 33   Other      Electronics     1.5      Returned   Neutral          15.26
# 36  Female            Books     3.2      Returned   Neutral            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              4.9          1
# 4     FREESHIP              4.4          5
# 5       SAVE10              NaN          6
# 6       SAVE10              NaN          7
# 8          nan              2.4          9
# 10    FREESHIP              NaN         11
# 12    WELCOME5              NaN         13
# 13    WELCOME5              3.5         14
# 16         nan              NaN         17
# 19    FREESHIP              1.4         20
# 20         nan              NaN         21
# 27      SAVE10              3.3         28
# 28         nan              3.5         29
# 30    FREESHIP              NaN         31
# 31    WELCOME5              3.6         32
# 32    FREESHIP              NaN         33
# 33    FREESHIP              NaN         34
# 36    WELCOME5              3.5         37
# 38         NaN              NaN         39
# 40         NaN              NaN         41
# Column                      is_member is not a string type and will be skipped.
# Column                  delivery_days is not a string type and will be skipped.
# Column                   customer_age is not a string type and will be skipped.
# Column                         gender INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1792         161         6  9999.99      0.21  449.2098
# 2  2023-01-03         1164         153         4    99.41      0.07  369.8052
# 3  2023-01-04         1377         142         4  8888.88      0.21  241.8032
# 8  2023-01-09         1188         141         6    26.66      0.26  118.3704
# 9  2023-01-10         1224         132         1    50.80      0.06   47.7520
# 10 2023-01-11         1818         197         9    55.84      0.11  447.2784
# 11 2023-01-12         1201         103         5    94.40      0.27  344.5600
# 13 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 14 2023-01-15         1434         199         5    81.03      0.24  307.9140
# 16 2023-01-17         1384         189         5    29.98      0.16  125.9160
# 17 2023-01-18         1180         185         4    71.48      0.04  274.4832
# 18 2023-01-19         1905         181         9    24.53      0.21  174.4083
# 19 2023-01-20         1289         190         6    38.36      0.15  195.6360
# 20 2023-01-21         1758         149         7    38.64      0.14  232.6128
# 21 2023-01-22         1262         139         3    34.57      0.17   86.0793
# 22 2023-01-23         1258         104         6    41.20      0.16  207.6480
# 23 2023-01-24         1384         174         9    13.55      0.04  117.0720
# 24 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 25 2023-01-26         1248         172         9    38.61      0.23  267.5673
# 26 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 29 2023-01-30         1732         174         4    51.33      0.21  162.2028
# 30 2023-01-31         1122         118         4    46.07      0.28  132.6816
# 32 2023-02-02         1191         182         6    45.41      0.02  267.0108
# 33 2023-02-03         1622         140         5    42.39      0.02  207.7110
# 35 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 36 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 37 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East         Online      False              6            45
# 2          9  North           Cash       True              6            25
# 3          6  North           Cash      False              4            37
# 8          3   East    Credit Card       True              4            41
# 9          8   East           Cash       True              4            21
# 10         9  South    Credit Card      False              5            30
# 11         5   West           Cash      False              2            29
# 13         4   West    Credit Card      False              5            38
# 14         9   East           Cash       True              3            25
# 16         4   East         Online       True              4            34
# 17         4  North           Cash       True              3            54
# 18         8   West           Cash      False              4            21
# 19         5   West    Credit Card      False              3            64
# 20         4  North    Credit Card       True              6            60
# 21         6   East           Cash       True              2            49
# 22         3  North           Cash       True              1            52
# 23         2   East           Cash      False              2            63
# 24         8   West           Cash      False              6            20
# 25         8  North           Cash       True              6            52
# 26         7  South           Cash      False              3            32
# 29         5  North           Cash       True              3            40
# 30         1  North    Credit Card       True              6            59
# 32         9   West    Credit Card      False              2            45
# 33         4   East         Online       True              2            66
# 35         7  South           Cash      False              3            32
# 36         4   West    Credit Card      False              5            38
# 37         8   West           Cash      False              6            20
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     3.2  Not Returned   Neutral           8.21
# 2   Female         Clothing     4.9      Returned  Negative            NaN
# 3   Female      Electronics     2.8  Not Returned  Negative          10.22
# 8   Female            Books     3.3  Not Returned   Neutral            NaN
# 9    Other             Food     1.9  Not Returned  Positive           7.46
# 10  Female             Food     1.9      Returned   Neutral           7.25
# 11  Female         Clothing     5.0  Not Returned  Positive          10.90
# 13  Female            Books     3.2      Returned   Neutral            NaN
# 14   Other      Electronics     3.2  Not Returned  Positive           7.25
# 16  Female             Food     2.1      Returned  Positive          19.25
# 17  Female            Books     3.3  Not Returned  Negative          13.84
# 18   Other      Electronics     1.1      Returned  Positive           8.02
# 19  Female         Clothing     2.6  Not Returned  Positive          17.19
# 20  Female            Books     4.2      Returned   Neutral          18.90
# 21   Other      Electronics     1.7  Not Returned  Positive          14.21
# 22  Female            Books     1.0  Not Returned   Neutral          19.35
# 23  Female             Food     3.8      Returned  Negative          10.86
# 24   Other         Clothing     2.1      Returned  Positive            NaN
# 25   Other            Books     2.4  Not Returned  Positive          14.31
# 26   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 29   Other             Food     2.5  Not Returned  Positive            NaN
# 30  Female      Electronics     3.8  Not Returned  Positive           7.69
# 32   Other             Food     4.4  Not Returned   Neutral            NaN
# 33   Other      Electronics     1.5      Returned   Neutral          15.26
# 35   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 36  Female            Books     3.2      Returned   Neutral            NaN
# 37   Other         Clothing     2.1      Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              4.9          1
# 2          nan              4.6          3
# 3          nan              3.9          4
# 8          nan              2.4          9
# 9          nan              NaN         10
# 10    FREESHIP              NaN         11
# 11         nan              4.0         12
# 13    WELCOME5              3.5         14
# 14      SAVE10              NaN         15
# 16         nan              NaN         17
# 17         nan              4.4         18
# 18    WELCOME5              NaN         19
# 19    FREESHIP              1.4         20
# 20         nan              NaN         21
# 21    FREESHIP              2.9         22
# 22         nan              NaN         23
# 23    WELCOME5              4.2         24
# 24         nan              4.3         25
# 25    FREESHIP              1.7         26
# 26         nan              1.5         27
# 29      SAVE10              4.8         30
# 30    FREESHIP              NaN         31
# 32    FREESHIP              NaN         33
# 33    FREESHIP              NaN         34
# 35         nan              1.5         36
# 36    WELCOME5              3.5         37
# 37         nan              4.3         38
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column               product_category INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1792         161         6  9999.99      0.21  449.2098
# 1  2023-01-02         1478         175         4    11.96      0.18   39.2288
# 2  2023-01-03         1164         153         4    99.41      0.07  369.8052
# 3  2023-01-04         1377         142         4  8888.88      0.21  241.8032
# 4  2023-01-05         1247         153         3    85.99      0.26  190.8978
# 7  2023-01-08         1443         128         5    95.84      0.22  373.7760
# 8  2023-01-09         1188         141         6    26.66      0.26  118.3704
# 11 2023-01-12         1201         103         5    94.40      0.27  344.5600
# 12 2023-01-13         1337         196         7    38.04      0.23  205.0356
# 13 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 14 2023-01-15         1434         199         5    81.03      0.24  307.9140
# 15 2023-01-16         1687         149         5    85.78      0.07  398.8770
# 17 2023-01-18         1180         185         4    71.48      0.04  274.4832
# 18 2023-01-19         1905         181         9    24.53      0.21  174.4083
# 19 2023-01-20         1289         190         6    38.36      0.15  195.6360
# 20 2023-01-21         1758         149         7    38.64      0.14  232.6128
# 21 2023-01-22         1262         139         3    34.57      0.17   86.0793
# 22 2023-01-23         1258         104         6    41.20      0.16  207.6480
# 24 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 25 2023-01-26         1248         172         9    38.61      0.23  267.5673
# 26 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 28 2023-01-29         1496         171         9    64.48      0.26  429.4368
# 30 2023-01-31         1122         118         4    46.07      0.28  132.6816
# 31 2023-02-01         1858         168         1    41.71      0.04   40.0416
# 33 2023-02-03         1622         140         5    42.39      0.02  207.7110
# 34 2023-02-04         1708         173         2    87.90      0.11  156.4620
# 35 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 36 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 37 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East         Online      False              6            45
# 1          9   East           Cash       True              3            25
# 2          9  North           Cash       True              6            25
# 3          6  North           Cash      False              4            37
# 4          3  South         Online      False              3            27
# 7          9   East           Cash      False              5            18
# 8          3   East    Credit Card       True              4            41
# 11         5   West           Cash      False              2            29
# 12         9   West    Credit Card       True              3            35
# 13         4   West    Credit Card      False              5            38
# 14         9   East           Cash       True              3            25
# 15         2   East           Cash      False              2            58
# 17         4  North           Cash       True              3            54
# 18         8   West           Cash      False              4            21
# 19         5   West    Credit Card      False              3            64
# 20         4  North    Credit Card       True              6            60
# 21         6   East           Cash       True              2            49
# 22         3  North           Cash       True              1            52
# 24         8   West           Cash      False              6            20
# 25         8  North           Cash       True              6            52
# 26         7  South           Cash      False              3            32
# 28         7  North    Credit Card       True              1            52
# 30         1  North    Credit Card       True              6            59
# 31         7  North    Credit Card      False              6            42
# 33         4   East         Online       True              2            66
# 34         6   East           Cash      False              1            60
# 35         7  South           Cash      False              3            32
# 36         4   West    Credit Card      False              5            38
# 37         8   West           Cash      False              6            20
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     3.2  Not Returned   Neutral           8.21
# 1     Male            Books     1.3      Returned  Positive           8.44
# 2   Female         Clothing     4.9      Returned  Negative            NaN
# 3   Female      Electronics     2.8  Not Returned  Negative          10.22
# 4     Male      Electronics     4.7  Not Returned   Neutral            NaN
# 7     Male         Clothing     2.7  Not Returned   Neutral          19.67
# 8   Female            Books     3.3  Not Returned   Neutral            NaN
# 11  Female         Clothing     5.0  Not Returned  Positive          10.90
# 12    Male         Clothing     1.9  Not Returned  Negative          16.34
# 13  Female            Books     3.2      Returned   Neutral            NaN
# 14   Other      Electronics     3.2  Not Returned  Positive           7.25
# 15    Male      Electronics     2.9      Returned  Positive           6.86
# 17  Female            Books     3.3  Not Returned  Negative          13.84
# 18   Other      Electronics     1.1      Returned  Positive           8.02
# 19  Female         Clothing     2.6  Not Returned  Positive          17.19
# 20  Female            Books     4.2      Returned   Neutral          18.90
# 21   Other      Electronics     1.7  Not Returned  Positive          14.21
# 22  Female            Books     1.0  Not Returned   Neutral          19.35
# 24   Other         Clothing     2.1      Returned  Positive            NaN
# 25   Other            Books     2.4  Not Returned  Positive          14.31
# 26   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 28    Male      Electronics     3.8  Not Returned   Neutral          14.75
# 30  Female      Electronics     3.8  Not Returned  Positive           7.69
# 31    Male            Books     2.9  Not Returned   Neutral          18.21
# 33   Other      Electronics     1.5      Returned   Neutral          15.26
# 34    Male            Books     1.7      Returned   Neutral           8.04
# 35   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 36  Female            Books     3.2      Returned   Neutral            NaN
# 37   Other         Clothing     2.1      Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              4.9          1
# 1       SAVE10              1.9          2
# 2          nan              4.6          3
# 3          nan              3.9          4
# 4     FREESHIP              4.4          5
# 7          nan              4.6          8
# 8          nan              2.4          9
# 11         nan              4.0         12
# 12    WELCOME5              NaN         13
# 13    WELCOME5              3.5         14
# 14      SAVE10              NaN         15
# 15    WELCOME5              1.8         16
# 17         nan              4.4         18
# 18    WELCOME5              NaN         19
# 19    FREESHIP              1.4         20
# 20         nan              NaN         21
# 21    FREESHIP              2.9         22
# 22         nan              NaN         23
# 24         nan              4.3         25
# 25    FREESHIP              1.7         26
# 26         nan              1.5         27
# 28         nan              3.5         29
# 30    FREESHIP              NaN         31
# 31    WELCOME5              3.6         32
# 33    FREESHIP              NaN         34
# 34         nan              4.6         35
# 35         nan              1.5         36
# 36    WELCOME5              3.5         37
# 37         nan              4.3         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                         rating is not a string type and will be skipped.
# Column                  return_status INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1792         161         6  9999.99      0.21  449.2098
# 1  2023-01-02         1478         175         4    11.96      0.18   39.2288
# 2  2023-01-03         1164         153         4    99.41      0.07  369.8052
# 3  2023-01-04         1377         142         4  8888.88      0.21  241.8032
# 4  2023-01-05         1247         153         3    85.99      0.26  190.8978
# 5  2023-01-06         1129         169         8  7777.77      0.03  692.5800
# 6  2023-01-07         1923         180         4    68.77      0.14  236.5688
# 7  2023-01-08         1443         128         5    95.84      0.22  373.7760
# 8  2023-01-09         1188         141         6    26.66      0.26  118.3704
# 9  2023-01-10         1224         132         1    50.80      0.06   47.7520
# 10 2023-01-11         1818         197         9    55.84      0.11  447.2784
# 11 2023-01-12         1201         103         5    94.40      0.27  344.5600
# 12 2023-01-13         1337         196         7    38.04      0.23  205.0356
# 13 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 14 2023-01-15         1434         199         5    81.03      0.24  307.9140
# 15 2023-01-16         1687         149         5    85.78      0.07  398.8770
# 16 2023-01-17         1384         189         5    29.98      0.16  125.9160
# 17 2023-01-18         1180         185         4    71.48      0.04  274.4832
# 18 2023-01-19         1905         181         9    24.53      0.21  174.4083
# 19 2023-01-20         1289         190         6    38.36      0.15  195.6360
# 20 2023-01-21         1758         149         7    38.64      0.14  232.6128
# 21 2023-01-22         1262         139         3    34.57      0.17   86.0793
# 22 2023-01-23         1258         104         6    41.20      0.16  207.6480
# 23 2023-01-24         1384         174         9    13.55      0.04  117.0720
# 24 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 25 2023-01-26         1248         172         9    38.61      0.23  267.5673
# 26 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 27 2023-01-28         1858         134         9    91.73      0.05  784.2915
# 28 2023-01-29         1496         171         9    64.48      0.26  429.4368
# 29 2023-01-30         1732         174         4    51.33      0.21  162.2028
# 30 2023-01-31         1122         118         4    46.07      0.28  132.6816
# 31 2023-02-01         1858         168         1    41.71      0.04   40.0416
# 32 2023-02-02         1191         182         6    45.41      0.02  267.0108
# 33 2023-02-03         1622         140         5    42.39      0.02  207.7110
# 34 2023-02-04         1708         173         2    87.90      0.11  156.4620
# 35 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 36 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 37 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East         Online      False              6            45
# 1          9   East           Cash       True              3            25
# 2          9  North           Cash       True              6            25
# 3          6  North           Cash      False              4            37
# 4          3  South         Online      False              3            27
# 5          2   West         Online       True              5            55
# 6          5   East    Credit Card      False              1            41
# 7          9   East           Cash      False              5            18
# 8          3   East    Credit Card       True              4            41
# 9          8   East           Cash       True              4            21
# 10         9  South    Credit Card      False              5            30
# 11         5   West           Cash      False              2            29
# 12         9   West    Credit Card       True              3            35
# 13         4   West    Credit Card      False              5            38
# 14         9   East           Cash       True              3            25
# 15         2   East           Cash      False              2            58
# 16         4   East         Online       True              4            34
# 17         4  North           Cash       True              3            54
# 18         8   West           Cash      False              4            21
# 19         5   West    Credit Card      False              3            64
# 20         4  North    Credit Card       True              6            60
# 21         6   East           Cash       True              2            49
# 22         3  North           Cash       True              1            52
# 23         2   East           Cash      False              2            63
# 24         8   West           Cash      False              6            20
# 25         8  North           Cash       True              6            52
# 26         7  South           Cash      False              3            32
# 27         4  South    Credit Card      False              6            69
# 28         7  North    Credit Card       True              1            52
# 29         5  North           Cash       True              3            40
# 30         1  North    Credit Card       True              6            59
# 31         7  North    Credit Card      False              6            42
# 32         9   West    Credit Card      False              2            45
# 33         4   East         Online       True              2            66
# 34         6   East           Cash      False              1            60
# 35         7  South           Cash      False              3            32
# 36         4   West    Credit Card      False              5            38
# 37         8   West           Cash      False              6            20
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     3.2  Not Returned   Neutral           8.21
# 1     Male            Books     1.3      Returned  Positive           8.44
# 2   Female         Clothing     4.9      Returned  Negative            NaN
# 3   Female      Electronics     2.8  Not Returned  Negative          10.22
# 4     Male      Electronics     4.7  Not Returned   Neutral            NaN
# 5     Male             Food     3.8  Not Returned  Positive            NaN
# 6     Male             Food     4.8      Returned   Neutral            NaN
# 7     Male         Clothing     2.7  Not Returned   Neutral          19.67
# 8   Female            Books     3.3  Not Returned   Neutral            NaN
# 9    Other             Food     1.9  Not Returned  Positive           7.46
# 10  Female             Food     1.9      Returned   Neutral           7.25
# 11  Female         Clothing     5.0  Not Returned  Positive          10.90
# 12    Male         Clothing     1.9  Not Returned  Negative          16.34
# 13  Female            Books     3.2      Returned   Neutral            NaN
# 14   Other      Electronics     3.2  Not Returned  Positive           7.25
# 15    Male      Electronics     2.9      Returned  Positive           6.86
# 16  Female             Food     2.1      Returned  Positive          19.25
# 17  Female            Books     3.3  Not Returned  Negative          13.84
# 18   Other      Electronics     1.1      Returned  Positive           8.02
# 19  Female         Clothing     2.6  Not Returned  Positive          17.19
# 20  Female            Books     4.2      Returned   Neutral          18.90
# 21   Other      Electronics     1.7  Not Returned  Positive          14.21
# 22  Female            Books     1.0  Not Returned   Neutral          19.35
# 23  Female             Food     3.8      Returned  Negative          10.86
# 24   Other         Clothing     2.1      Returned  Positive            NaN
# 25   Other            Books     2.4  Not Returned  Positive          14.31
# 26   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 27    Male             Food     3.4  Not Returned   Neutral          17.41
# 28    Male      Electronics     3.8  Not Returned   Neutral          14.75
# 29   Other             Food     2.5  Not Returned  Positive            NaN
# 30  Female      Electronics     3.8  Not Returned  Positive           7.69
# 31    Male            Books     2.9  Not Returned   Neutral          18.21
# 32   Other             Food     4.4  Not Returned   Neutral            NaN
# 33   Other      Electronics     1.5      Returned   Neutral          15.26
# 34    Male            Books     1.7      Returned   Neutral           8.04
# 35   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 36  Female            Books     3.2      Returned   Neutral            NaN
# 37   Other         Clothing     2.1      Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              4.9          1
# 1       SAVE10              1.9          2
# 2          nan              4.6          3
# 3          nan              3.9          4
# 4     FREESHIP              4.4          5
# 5       SAVE10              NaN          6
# 6       SAVE10              NaN          7
# 7          nan              4.6          8
# 8          nan              2.4          9
# 9          nan              NaN         10
# 10    FREESHIP              NaN         11
# 11         nan              4.0         12
# 12    WELCOME5              NaN         13
# 13    WELCOME5              3.5         14
# 14      SAVE10              NaN         15
# 15    WELCOME5              1.8         16
# 16         nan              NaN         17
# 17         nan              4.4         18
# 18    WELCOME5              NaN         19
# 19    FREESHIP              1.4         20
# 20         nan              NaN         21
# 21    FREESHIP              2.9         22
# 22         nan              NaN         23
# 23    WELCOME5              4.2         24
# 24         nan              4.3         25
# 25    FREESHIP              1.7         26
# 26         nan              1.5         27
# 27      SAVE10              3.3         28
# 28         nan              3.5         29
# 29      SAVE10              4.8         30
# 30    FREESHIP              NaN         31
# 31    WELCOME5              3.6         32
# 32    FREESHIP              NaN         33
# 33    FREESHIP              NaN         34
# 34         nan              4.6         35
# 35         nan              1.5         36
# 36    WELCOME5              3.5         37
# 37         nan              4.3         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                       feedback INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1792         161         6  9999.99      0.21  449.2098
# 1  2023-01-02         1478         175         4    11.96      0.18   39.2288
# 2  2023-01-03         1164         153         4    99.41      0.07  369.8052
# 3  2023-01-04         1377         142         4  8888.88      0.21  241.8032
# 4  2023-01-05         1247         153         3    85.99      0.26  190.8978
# 5  2023-01-06         1129         169         8  7777.77      0.03  692.5800
# 6  2023-01-07         1923         180         4    68.77      0.14  236.5688
# 7  2023-01-08         1443         128         5    95.84      0.22  373.7760
# 8  2023-01-09         1188         141         6    26.66      0.26  118.3704
# 9  2023-01-10         1224         132         1    50.80      0.06   47.7520
# 10 2023-01-11         1818         197         9    55.84      0.11  447.2784
# 11 2023-01-12         1201         103         5    94.40      0.27  344.5600
# 12 2023-01-13         1337         196         7    38.04      0.23  205.0356
# 13 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 14 2023-01-15         1434         199         5    81.03      0.24  307.9140
# 15 2023-01-16         1687         149         5    85.78      0.07  398.8770
# 16 2023-01-17         1384         189         5    29.98      0.16  125.9160
# 17 2023-01-18         1180         185         4    71.48      0.04  274.4832
# 18 2023-01-19         1905         181         9    24.53      0.21  174.4083
# 19 2023-01-20         1289         190         6    38.36      0.15  195.6360
# 20 2023-01-21         1758         149         7    38.64      0.14  232.6128
# 21 2023-01-22         1262         139         3    34.57      0.17   86.0793
# 22 2023-01-23         1258         104         6    41.20      0.16  207.6480
# 23 2023-01-24         1384         174         9    13.55      0.04  117.0720
# 24 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 25 2023-01-26         1248         172         9    38.61      0.23  267.5673
# 26 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 27 2023-01-28         1858         134         9    91.73      0.05  784.2915
# 28 2023-01-29         1496         171         9    64.48      0.26  429.4368
# 29 2023-01-30         1732         174         4    51.33      0.21  162.2028
# 30 2023-01-31         1122         118         4    46.07      0.28  132.6816
# 31 2023-02-01         1858         168         1    41.71      0.04   40.0416
# 32 2023-02-02         1191         182         6    45.41      0.02  267.0108
# 33 2023-02-03         1622         140         5    42.39      0.02  207.7110
# 34 2023-02-04         1708         173         2    87.90      0.11  156.4620
# 35 2023-01-27         1927         183         5    93.92      0.24  356.8960
# 36 2023-01-14         1659         172         1    67.33      0.00   67.3300
# 37 2023-01-25         1400         115         2    67.76      0.01  134.1648
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East         Online      False              6            45
# 1          9   East           Cash       True              3            25
# 2          9  North           Cash       True              6            25
# 3          6  North           Cash      False              4            37
# 4          3  South         Online      False              3            27
# 5          2   West         Online       True              5            55
# 6          5   East    Credit Card      False              1            41
# 7          9   East           Cash      False              5            18
# 8          3   East    Credit Card       True              4            41
# 9          8   East           Cash       True              4            21
# 10         9  South    Credit Card      False              5            30
# 11         5   West           Cash      False              2            29
# 12         9   West    Credit Card       True              3            35
# 13         4   West    Credit Card      False              5            38
# 14         9   East           Cash       True              3            25
# 15         2   East           Cash      False              2            58
# 16         4   East         Online       True              4            34
# 17         4  North           Cash       True              3            54
# 18         8   West           Cash      False              4            21
# 19         5   West    Credit Card      False              3            64
# 20         4  North    Credit Card       True              6            60
# 21         6   East           Cash       True              2            49
# 22         3  North           Cash       True              1            52
# 23         2   East           Cash      False              2            63
# 24         8   West           Cash      False              6            20
# 25         8  North           Cash       True              6            52
# 26         7  South           Cash      False              3            32
# 27         4  South    Credit Card      False              6            69
# 28         7  North    Credit Card       True              1            52
# 29         5  North           Cash       True              3            40
# 30         1  North    Credit Card       True              6            59
# 31         7  North    Credit Card      False              6            42
# 32         9   West    Credit Card      False              2            45
# 33         4   East         Online       True              2            66
# 34         6   East           Cash      False              1            60
# 35         7  South           Cash      False              3            32
# 36         4   West    Credit Card      False              5            38
# 37         8   West           Cash      False              6            20
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     3.2  Not Returned   Neutral           8.21
# 1     Male            Books     1.3      Returned  Positive           8.44
# 2   Female         Clothing     4.9      Returned  Negative            NaN
# 3   Female      Electronics     2.8  Not Returned  Negative          10.22
# 4     Male      Electronics     4.7  Not Returned   Neutral            NaN
# 5     Male             Food     3.8  Not Returned  Positive            NaN
# 6     Male             Food     4.8      Returned   Neutral            NaN
# 7     Male         Clothing     2.7  Not Returned   Neutral          19.67
# 8   Female            Books     3.3  Not Returned   Neutral            NaN
# 9    Other             Food     1.9  Not Returned  Positive           7.46
# 10  Female             Food     1.9      Returned   Neutral           7.25
# 11  Female         Clothing     5.0  Not Returned  Positive          10.90
# 12    Male         Clothing     1.9  Not Returned  Negative          16.34
# 13  Female            Books     3.2      Returned   Neutral            NaN
# 14   Other      Electronics     3.2  Not Returned  Positive           7.25
# 15    Male      Electronics     2.9      Returned  Positive           6.86
# 16  Female             Food     2.1      Returned  Positive          19.25
# 17  Female            Books     3.3  Not Returned  Negative          13.84
# 18   Other      Electronics     1.1      Returned  Positive           8.02
# 19  Female         Clothing     2.6  Not Returned  Positive          17.19
# 20  Female            Books     4.2      Returned   Neutral          18.90
# 21   Other      Electronics     1.7  Not Returned  Positive          14.21
# 22  Female            Books     1.0  Not Returned   Neutral          19.35
# 23  Female             Food     3.8      Returned  Negative          10.86
# 24   Other         Clothing     2.1      Returned  Positive            NaN
# 25   Other            Books     2.4  Not Returned  Positive          14.31
# 26   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 27    Male             Food     3.4  Not Returned   Neutral          17.41
# 28    Male      Electronics     3.8  Not Returned   Neutral          14.75
# 29   Other             Food     2.5  Not Returned  Positive            NaN
# 30  Female      Electronics     3.8  Not Returned  Positive           7.69
# 31    Male            Books     2.9  Not Returned   Neutral          18.21
# 32   Other             Food     4.4  Not Returned   Neutral            NaN
# 33   Other      Electronics     1.5      Returned   Neutral          15.26
# 34    Male            Books     1.7      Returned   Neutral           8.04
# 35   Other         Clothing     2.6  Not Returned   Neutral          10.46
# 36  Female            Books     3.2      Returned   Neutral            NaN
# 37   Other         Clothing     2.1      Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              4.9          1
# 1       SAVE10              1.9          2
# 2          nan              4.6          3
# 3          nan              3.9          4
# 4     FREESHIP              4.4          5
# 5       SAVE10              NaN          6
# 6       SAVE10              NaN          7
# 7          nan              4.6          8
# 8          nan              2.4          9
# 9          nan              NaN         10
# 10    FREESHIP              NaN         11
# 11         nan              4.0         12
# 12    WELCOME5              NaN         13
# 13    WELCOME5              3.5         14
# 14      SAVE10              NaN         15
# 15    WELCOME5              1.8         16
# 16         nan              NaN         17
# 17         nan              4.4         18
# 18    WELCOME5              NaN         19
# 19    FREESHIP              1.4         20
# 20         nan              NaN         21
# 21    FREESHIP              2.9         22
# 22         nan              NaN         23
# 23    WELCOME5              4.2         24
# 24         nan              4.3         25
# 25    FREESHIP              1.7         26
# 26         nan              1.5         27
# 27      SAVE10              3.3         28
# 28         nan              3.5         29
# 29      SAVE10              4.8         30
# 30    FREESHIP              NaN         31
# 31    WELCOME5              3.6         32
# 32    FREESHIP              NaN         33
# 33    FREESHIP              NaN         34
# 34         nan              4.6         35
# 35         nan              1.5         36
# 36    WELCOME5              3.5         37
# 37         nan              4.3         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                  shipping_cost is not a string type and will be skipped.
# Column                    coupon_code is not a string type and will be skipped.
# Column                delivery_rating is not a string type and will be skipped.
# Column                      unique_id is not a string type and will be skipped.

# %% [markdown]
# <div class="alert alert-warning">
#
# **12. Verifying Numeric Range in a DataFrame Column**
#
# **Write a Pandas program to verify numeric range in a DataFrame column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1989         183         2  9999.99      0.23   18.4646
# 1  2023-01-02         1415         113         6    25.35      0.03  147.5370
# 2  2023-01-03         1540         111         9    11.65      0.06   98.5590
# 3  2023-01-04         1758         128         4  8888.88      0.27  236.9288
# 4  2023-01-05         1480         190         7    73.92      0.17  429.4752
# 5  2023-01-06         1780         118         6  7777.77      0.06  543.9780
# 6  2023-01-07         1787         161         5    41.99      0.10  188.9550
# 7  2023-01-08         1156         188         8    69.90      0.01  553.6080
# 8  2023-01-09         1886         162         1    81.96      0.07   76.2228
# 9  2023-01-10         1150         190         3    77.36      0.11  206.5512
# 10 2023-01-11         1561         138         7    95.67      0.19  542.4489
# 11 2023-01-12         1309         159         2    78.15      0.06  146.9220
# 12 2023-01-13         1459         192         8    56.18      0.10  404.4960
# 13 2023-01-14         1157         128         3    69.99      0.30  146.9790
# 14 2023-01-15         1695         122         9    75.47      0.10  611.3070
# 15 2023-01-16         1940         171         5    92.21      0.09  419.5555
# 16 2023-01-17         1222         129         2    78.09      0.11  139.0002
# 17 2023-01-18         1145         136         6    33.88      0.25  152.4600
# 18 2023-01-19         1025         156         9    16.98      0.24  116.1432
# 19 2023-01-20         1174         187         3    75.60      0.15  192.7800
# 20 2023-01-21         1791         131         4    38.55      0.17  127.9860
# 21 2023-01-22         1572         179         1    52.62      0.07   48.9366
# 22 2023-01-23         1869         195         9    36.83      0.12  291.6936
# 23 2023-01-24         1889         103         5    87.90      0.23  338.4150
# 24 2023-01-25         1026         169         8    58.54      0.13  407.4384
# 25 2023-01-26         1659         182         2    38.49      0.28   55.4256
# 26 2023-01-27         1605         187         1    81.13      0.22   63.2814
# 27 2023-01-28         1260         120         2    61.14      0.08  112.4976
# 28 2023-01-29         1108         122         2    78.81      0.16  132.4008
# 29 2023-01-30         1613         180         3    62.77      0.05  178.8945
# 30 2023-01-31         1519         183         1    76.91      0.22   59.9898
# 31 2023-02-01         1652         155         6    93.67      0.17  466.4766
# 32 2023-02-02         1628         143         2    72.06      0.18  118.1784
# 33 2023-02-03         1526         167         9    58.51      0.22  410.7402
# 34 2023-02-04         1946         173         9    77.54      0.17  579.2238
# 35 2023-01-27         1605         187         1    81.13      0.22   63.2814
# 36 2023-01-14         1157         128         3    69.99      0.30  146.9790
# 37 2023-01-25         1026         169         8    58.54      0.13  407.4384
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   West         Online       True              4            20
# 1          3   West         Online      False              1            34
# 2          6   West    Credit Card      False              4            46
# 3          3  South           Cash       True              3            50
# 4          9  South         Online      False              6            35
# 5          9   West    Credit Card       True              6            61
# 6          1   East         Online       True              2            69
# 7          8   West           Cash      False              4            40
# 8          5   East         Online      False              3            22
# 9          9  South         Online      False              1            22
# 10         9  South         Online       True              1            36
# 11         5  North    Credit Card      False              4            37
# 12         9   East         Online      False              6            45
# 13         7   East    Credit Card       True              6            45
# 14         6  North         Online       True              5            30
# 15         5  North         Online      False              4            43
# 16         1  South    Credit Card      False              3            60
# 17         8  North           Cash      False              5            44
# 18         5   East         Online       True              1            40
# 19         1  South           Cash       True              3            69
# 20         1   West           Cash       True              3            55
# 21         2  South    Credit Card      False              6            35
# 22         4   East    Credit Card       True              5            41
# 23         9   West    Credit Card       True              1            64
# 24         9   East         Online      False              2            54
# 25         7   East           Cash      False              3            38
# 26         4   East         Online       True              3            63
# 27         1   East         Online       True              1            26
# 28         1   West         Online      False              5            43
# 29         2   East         Online       True              3            50
# 30         9  North         Online      False              4            67
# 31         3   East    Credit Card      False              4            63
# 32         4   East         Online      False              2            49
# 33         2  North    Credit Card       True              3            26
# 34         4   East         Online       True              2            57
# 35         4   East         Online       True              3            63
# 36         7   East    Credit Card       True              6            45
# 37         9   East         Online      False              2            54
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     1.7      Returned   Neutral          16.70
# 1   Female      Electronics     3.5      Returned  Positive          18.49
# 2     Male      Electronics     3.8      Returned  Positive          18.06
# 3   Female             Food     2.6  Not Returned   Neutral           5.33
# 4   Female             Food     1.6      Returned  Negative          17.44
# 5     Male            Books     4.6  Not Returned  Negative           6.87
# 6   Female         Clothing     2.1      Returned  Positive          11.52
# 7    Other             Food     1.4      Returned   Neutral            NaN
# 8     Male         Clothing     4.8      Returned  Negative          16.87
# 9    Other         Clothing     3.9  Not Returned  Negative          16.85
# 10  Female            Books     4.4  Not Returned  Positive          19.29
# 11   Other         Clothing     4.1  Not Returned  Negative           6.98
# 12    Male             Food     1.7  Not Returned   Neutral          14.86
# 13    Male         Clothing     2.5  Not Returned   Neutral          17.45
# 14   Other      Electronics     4.2  Not Returned   Neutral           7.85
# 15    Male         Clothing     4.6  Not Returned  Positive          17.64
# 16  Female             Food     2.1  Not Returned  Negative          19.29
# 17   Other             Food     4.2  Not Returned   Neutral          12.47
# 18   Other            Books     3.4  Not Returned   Neutral          17.36
# 19   Other      Electronics     1.5  Not Returned  Positive          10.49
# 20   Other      Electronics     3.9  Not Returned  Negative           5.19
# 21   Other             Food     2.2  Not Returned  Negative            NaN
# 22   Other            Books     4.2      Returned  Negative          11.72
# 23    Male             Food     3.1      Returned  Negative          19.48
# 24   Other             Food     3.7  Not Returned   Neutral            NaN
# 25  Female         Clothing     4.9      Returned  Positive           7.53
# 26  Female      Electronics     1.7      Returned  Positive          16.98
# 27   Other      Electronics     1.6  Not Returned   Neutral          15.94
# 28   Other      Electronics     4.7  Not Returned  Negative          11.25
# 29   Other      Electronics     1.4      Returned  Positive           6.95
# 30  Female      Electronics     3.1      Returned  Negative          17.98
# 31   Other         Clothing     4.0  Not Returned  Negative          13.70
# 32    Male      Electronics     2.6      Returned  Negative          13.85
# 33  Female            Books     1.7  Not Returned  Positive          17.16
# 34   Other         Clothing     4.9      Returned  Negative           7.04
# 35  Female      Electronics     1.7      Returned  Positive          16.98
# 36    Male         Clothing     2.5  Not Returned   Neutral          17.45
# 37   Other             Food     3.7  Not Returned   Neutral            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              NaN          1
# 1          nan              2.2          2
# 2       SAVE10              4.6          3
# 3     FREESHIP              4.4          4
# 4     FREESHIP              3.8          5
# 5       SAVE10              4.1          6
# 6          nan              2.8          7
# 7     WELCOME5              3.5          8
# 8     WELCOME5              2.1          9
# 9          nan              NaN         10
# 10    FREESHIP              1.2         11
# 11         nan              NaN         12
# 12    WELCOME5              NaN         13
# 13    FREESHIP              NaN         14
# 14    WELCOME5              3.7         15
# 15         nan              3.7         16
# 16    FREESHIP              NaN         17
# 17    FREESHIP              NaN         18
# 18         nan              2.6         19
# 19         nan              1.3         20
# 20         nan              3.3         21
# 21    WELCOME5              3.9         22
# 22    FREESHIP              NaN         23
# 23    FREESHIP              4.0         24
# 24    WELCOME5              4.3         25
# 25         nan              2.8         26
# 26    WELCOME5              4.5         27
# 27      SAVE10              1.6         28
# 28    FREESHIP              2.7         29
# 29    FREESHIP              NaN         30
# 30      SAVE10              2.1         31
# 31    WELCOME5              3.1         32
# 32      SAVE10              1.6         33
# 33      SAVE10              4.5         34
# 34         nan              NaN         35
# 35    WELCOME5              4.5         36
# 36    FREESHIP              NaN         37
# 37    WELCOME5              4.3         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 12:**
# </div>

# %%
# 12. Verifying Numeric Range in a DataFrame Column
# Write a Pandas program to verify numeric range in a DataFrame column.

def verify_numeric_range(dataframe, column_name, min_value, max_value):
    if not pd.api.types.is_numeric_dtype(dataframe[column_name]):
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        out_of_range = dataframe[(dataframe[column_name] < min_value) | (dataframe[column_name] > max_value)]
    if not out_of_range.empty:
        print("Column {:>30} OUT OF RANGE DETECTED.\n####### OUT OF RANGE #######".format(column_name))
        display(out_of_range)
    else:
        print("Column {:>30} has no out of range values detected.".format(column_name))

# Apply to price column only
verify_numeric_range(df, 'price', min_value=0, max_value=100)
# Out:
# Column                          price OUT OF RANGE DETECTED.
# ####### OUT OF RANGE #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1989         183         2  9999.99      0.23   18.4646
# 3  2023-01-04         1758         128         4  8888.88      0.27  236.9288
# 5  2023-01-06         1780         118         6  7777.77      0.06  543.9780
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3   West         Online       True              4            20
# 3          3  South           Cash       True              3            50
# 5          9   West    Credit Card       True              6            61
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     1.7      Returned   Neutral          16.70
# 3   Female             Food     2.6  Not Returned   Neutral           5.33
# 5     Male            Books     4.6  Not Returned  Negative           6.87
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              NaN          1
# 3     FREESHIP              4.4          4
# 5       SAVE10              4.1          6
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
