# 18         3   East           Cash       True              3            50
# 19         2   East    Credit Card      False              2            41
# 20         4  North         Online       True              4            31
# 21         8  South           Cash      False              1            51
# 22         4   West    Credit Card      False              2            67
# 23         5   East    Credit Card       True              6            42
# 24         3   West           Cash       True              5            24
# 25         7   West    Credit Card       True              4            41
# 26         1   West    Credit Card      False              2            20
# 27         9   East         Online       True              2            58
# 28         5   West           Cash      False              3            26
# 29         5   East           Cash      False              2            64
# 30         3  South         Online      False              6            53
# 31         4   West         Online       True              2            44
# 32         9  North           Cash      False              6            53
# 33         3   West           Cash      False              3            28
# 34         8  South    Credit Card       True              3            25
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male            Books     4.8      Returned  Positive            NaN
# 1    Other      Electronics     3.0      Returned   Neutral           8.60
# 2     Male         Clothing     1.5  Not Returned  Negative           6.63
# 3   Female             Food     2.8  Not Returned  Negative           5.15
# 4    Other      Electronics     3.9  Not Returned  Positive          16.68
# 5   Female             Food     3.9      Returned  Positive           6.69
# 6     Male      Electronics     2.2      Returned   Neutral          13.19
# 7     Male             Food     4.1      Returned  Positive          16.21
# 8    Other             Food     2.7      Returned  Negative            NaN
# 9   Female             Food     4.3      Returned   Neutral          16.16
# 10    Male         Clothing     1.8  Not Returned  Negative          17.88
# 11    Male            Books     2.3  Not Returned   Neutral            NaN
# 12  Female         Clothing     3.8      Returned  Positive          10.14
# 13   Other             Food     2.4      Returned  Positive            NaN
# 14  Female            Books     3.6      Returned   Neutral          14.19
# 15  Female         Clothing     3.9      Returned  Positive          14.60
# 16    Male             Food     3.2      Returned   Neutral           9.98
# 17    Male         Clothing     1.4      Returned   Neutral          17.11
# 18    Male             Food     3.9      Returned  Positive            NaN
# 19   Other      Electronics     1.2      Returned  Negative           8.13
# 20  Female             Food     3.4      Returned   Neutral          19.60
# 21    Male         Clothing     3.4  Not Returned  Negative          10.18
# 22  Female            Books     4.4  Not Returned  Positive            NaN
# 23    Male            Books     4.4  Not Returned   Neutral           8.97
# 24  Female             Food     4.9      Returned   Neutral          13.41
# 25    Male            Books     3.3  Not Returned  Positive           9.51
# 26  Female             Food     2.7  Not Returned   Neutral           5.25
# 27    Male      Electronics     4.5  Not Returned  Negative           7.96
# 28  Female         Clothing     1.9      Returned  Positive          17.90
# 29  Female      Electronics     3.5  Not Returned  Negative            NaN
# 30   Other      Electronics     2.7      Returned   Neutral            NaN
# 31  Female            Books     2.2  Not Returned  Negative            NaN
# 32  Female             Food     3.0  Not Returned  Negative          16.81
# 33   Other         Clothing     1.9  Not Returned  Negative           6.47
# 34  Female             Food     2.5      Returned  Negative           5.23
#
#    coupon_code  delivery_rating
# 0          nan              NaN
# 1       SAVE10              NaN
# 2       SAVE10              NaN
# 3     WELCOME5              4.2
# 4     FREESHIP              3.9
# 5     FREESHIP              NaN
# 6     FREESHIP              3.1
# 7     WELCOME5              NaN
# 8       SAVE10              3.5
# 9          nan              1.0
# 10         nan              1.4
# 11      SAVE10              NaN
# 12    FREESHIP              2.6
# 13    FREESHIP              2.2
# 14         nan              NaN
# 15    WELCOME5              2.9
# 16    FREESHIP              3.0
# 17         nan              1.1
# 18      SAVE10              2.0
# 19      SAVE10              2.7
# 20    FREESHIP              2.1
# 21      SAVE10              NaN
# 22    FREESHIP              3.8
# 23         nan              2.2
# 24    WELCOME5              1.1
# 25         nan              1.0
# 26         nan              2.5
# 27    WELCOME5              3.6
# 28    FREESHIP              4.7
# 29         nan              5.0
# 30    WELCOME5              2.5
# 31         nan              4.3
# 32      SAVE10              NaN
# 33         nan              2.6
# 34      SAVE10              1.5

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
# 1. Checking Missing Values in a DataFrame
# Write a Pandas program to check for missing values in a DataFrame.

# Check for missing values
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# shipping_cost      9
# delivery_rating    9
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **2. Ensuring Consistent Data Types of All Columns**
#
# **Write a Pandas program to check and ensure that the data types of all columns are consistent.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1637         142         5  44.60      0.04  214.0800
# 1  2023-01-02         1301         161         2  86.26      0.10  155.2680
# 2  2023-01-03         1907         171         5  97.91      0.13  425.9085
# 3  2023-01-04         1397         108         6  88.31      0.24  402.6936
# 4  2023-01-05         1725         161         8  93.43      0.15  635.3240
# 5  2023-01-06         1611         136         1  74.89      0.09   68.1499
# 6  2023-01-07         1219         158         6  76.47      0.23  353.2914
# 7  2023-01-08         1514         130         2  92.07      0.18  150.9948
# 8  2023-01-09         1189         104         5  52.24      0.06  245.5280
# 9  2023-01-10         1647         171         8  12.83      0.05   97.5080
# 10 2023-01-11         1010         173         3  64.24      0.05  183.0840
# 11 2023-01-12         1956         165         1  12.97      0.06   12.1918
# 12 2023-01-13         1635         180         6  37.92      0.19  184.2912
# 13 2023-01-14         1129         175         5  82.83      0.21  327.1785
# 14 2023-01-15         1117         126         2  95.46      0.27  139.3716
# 15 2023-01-16         1709         139         9  53.34      0.00  480.0600
# 16 2023-01-17         1048         183         5  81.20      0.23  312.6200
# 17 2023-01-18         1955         114         7  35.45      0.24  188.5940
# 18 2023-01-19         1669         105         9  67.55      0.14  522.8370
# 19 2023-01-20         1675         109         5  66.66      0.10  299.9700
# 20 2023-01-21         1180         199         4  43.40      0.16  145.8240
# 21 2023-01-22         1329         107         7  89.36      0.11  556.7128
# 22 2023-01-23         1946         191         8  65.87      0.21  416.2984
# 23 2023-01-24         1494         171         8  65.83      0.18  431.8448
# 24 2023-01-25         1027         161         9  29.42      0.24  201.2328
# 25 2023-01-26         1942         181         3  13.74      0.12   36.2736
# 26 2023-01-27         1430         117         2  51.53      0.18   84.5092
# 27 2023-01-28         1555         110         3  34.23      0.10   92.4210
# 28 2023-01-29         1112         149         6  92.01      0.04  529.9776
# 29 2023-01-30         1823         146         8  68.44      0.21  432.5408
# 30 2023-01-31         1811         111         9  64.10      0.30  403.8300
# 31 2023-02-01         1879         118         2  51.21      0.16   86.0328
# 32 2023-02-02         1495         124         3  85.23      0.11  227.5641
# 33 2023-02-03         1854         179         5  32.19      0.15  136.8075
# 34 2023-02-04         1161         187         6  49.19      0.28  212.5008
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          4  South         Online      False              3            45
# 1          1   East         Online      False              6            41
# 2          1   West           Cash      False              4            63
# 3          5  North         Online      False              6            31
# 4          8  South    Credit Card      False              5            38
# 5          9   East           Cash      False              5            58
# 6          1  South           Cash      False              6            52
# 7          6   West    Credit Card      False              6            31
# 8          8   East           Cash       True              4            21
# 9          6   East         Online      False              5            37
# 10         7  South    Credit Card      False              4            24
# 11         8   East           Cash       True              6            23
# 12         7   East    Credit Card       True              3            51
# 13         2  North    Credit Card      False              6            46
# 14         2   East           Cash      False              1            18
# 15         1  North    Credit Card       True              1            32
# 16         1   East         Online      False              3            66
# 17         1  North           Cash      False              2            39
# 18         3  North           Cash       True              4            23
# 19         2   East           Cash      False              3            44
# 20         8  South    Credit Card       True              5            28
# 21         4   East    Credit Card       True              1            24
# 22         8  South           Cash       True              6            43
# 23         8  North    Credit Card       True              4            34
# 24         3   West           Cash       True              3            29
# 25         9  South           Cash      False              1            40
# 26         6   West           Cash      False              6            25
# 27         6  South           Cash       True              1            37
# 28         4  South           Cash      False              5            69
# 29         4   West    Credit Card      False              4            26
# 30         8  South    Credit Card       True              4            47
# 31         1  South    Credit Card       True              6            62
# 32         3  South         Online      False              1            34
# 33         7   West           Cash      False              3            32
# 34         1  North    Credit Card       True              2            58
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male      Electronics     3.3      Returned  Negative          16.93
# 1   Female            Books     4.0      Returned  Positive           8.07
# 2     Male             Food     4.5      Returned   Neutral            NaN
# 3     Male      Electronics     2.6  Not Returned  Negative           9.68
# 4   Female      Electronics     1.3  Not Returned  Negative           5.94
# 5     Male             Food     2.3  Not Returned  Negative          15.73
# 6     Male         Clothing     4.2  Not Returned   Neutral          18.61
# 7    Other         Clothing     4.1  Not Returned  Positive           9.12
# 8     Male             Food     3.9  Not Returned  Negative            NaN
# 9    Other         Clothing     3.5  Not Returned  Positive           9.91
# 10    Male            Books     2.8      Returned  Negative            NaN
# 11    Male      Electronics     4.0      Returned  Positive          15.33
# 12   Other            Books     4.2  Not Returned  Negative           9.76
# 13  Female             Food     4.1      Returned   Neutral          18.13
# 14  Female      Electronics     2.5  Not Returned  Negative          17.57
# 15    Male      Electronics     4.2      Returned   Neutral          13.40
# 16    Male             Food     4.8      Returned   Neutral          19.18
# 17   Other         Clothing     4.6  Not Returned  Positive           7.46
# 18  Female      Electronics     1.9      Returned  Negative          12.03
# 19    Male             Food     3.5  Not Returned   Neutral           9.27
# 20  Female         Clothing     3.7  Not Returned   Neutral           6.04
# 21  Female             Food     4.7      Returned  Positive          17.64
# 22    Male      Electronics     2.8  Not Returned  Negative          15.75
# 23    Male            Books     3.4  Not Returned  Negative           5.37
# 24    Male             Food     4.7  Not Returned   Neutral            NaN
# 25  Female         Clothing     1.4      Returned   Neutral            NaN
# 26  Female            Books     2.5      Returned   Neutral          18.57
# 27    Male             Food     2.6      Returned  Positive          11.01
# 28   Other      Electronics     4.9      Returned   Neutral          12.32
# 29    Male         Clothing     1.6  Not Returned   Neutral            NaN
# 30    Male         Clothing     3.3  Not Returned  Negative            NaN
# 31   Other            Books     3.6      Returned   Neutral          13.07
# 32   Other         Clothing     3.6  Not Returned  Negative           9.60
# 33   Other             Food     4.0      Returned  Negative           9.06
# 34    Male      Electronics     3.4      Returned   Neutral            NaN
#
#    coupon_code  delivery_rating
# 0          nan              1.5
# 1     FREESHIP              1.4
# 2          nan              1.7
# 3          nan              3.0
# 4          nan              3.5
# 5     FREESHIP              4.3
# 6     WELCOME5              2.0
# 7       SAVE10              1.2
# 8       SAVE10              NaN
# 9     WELCOME5              NaN
# 10         nan              4.4
# 11      SAVE10              1.6
# 12    FREESHIP              2.2
# 13         nan              NaN
# 14         nan              3.8
# 15    FREESHIP              NaN
# 16    WELCOME5              3.3
# 17         nan              NaN
# 18    WELCOME5              NaN
# 19    FREESHIP              4.9
# 20         nan              NaN
# 21         nan              NaN
# 22         nan              3.0
# 23    WELCOME5              4.9
# 24      SAVE10              3.9
# 25    WELCOME5              NaN
# 26         nan              1.1
# 27      SAVE10              4.1
# 28         nan              NaN
# 29         nan              1.5
# 30         nan              NaN
# 31      SAVE10              4.0
# 32         nan              NaN
# 33         nan              4.3
# 34    FREESHIP              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 02:**
# </div>

# %%
# 2. Ensuring Consistent Data Types of All Columns
# Write a Pandas program to check and ensure that the data types of all columns are consistent.

# Check data types
data_types = df.dtypes
data_types
# Out:
# date                datetime64[ns]
# customer_id                  int64
# product_id                   int64
# quantity                     int64
# price                      float64
# discount                   float64
# revenue                    float64
# store_id                     int64
# region                      object
# payment_method              object
# is_member                     bool
# delivery_days                int64
# customer_age                 int64
# gender                      object
# product_category            object
# rating                     float64
# return_status               object
# feedback                    object
# shipping_cost              float64
# coupon_code                 object
# delivery_rating            float64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning">
#
# **3. Validating the Data Type of a Specific Column**
#
# **Write a Pandas program to validate the data type of a specific column in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1970         183         8  38.72      0.23  238.5152
# 1  2023-01-02         1305         113         4  47.89      0.30  134.0920
# 2  2023-01-03         1329         151         8  62.90      0.26  372.3680
# 3  2023-01-04         1065         141         5  92.84      0.02  454.9160
# 4  2023-01-05         1410         140         9  36.76      0.13  287.8308
# 5  2023-01-06         1662         118         6  50.93      0.28  220.0176
# 6  2023-01-07         1813         143         2  30.05      0.21   47.4790
# 7  2023-01-08         1586         195         2  56.90      0.23   87.6260
# 8  2023-01-09         1970         174         9  71.90      0.11  575.9190
# 9  2023-01-10         1271         181         3  48.29      0.14  124.5882
# 10 2023-01-11         1419         101         6  99.53      0.12  525.5184
# 11 2023-01-12         1982         153         1  68.96      0.06   64.8224
# 12 2023-01-13         1481         145         7  10.01      0.20   56.0560
# 13 2023-01-14         1353         184         1  43.40      0.09   39.4940
# 14 2023-01-15         1324         133         9  29.16      0.18  215.2008
# 15 2023-01-16         1629         102         6  27.99      0.16  141.0696
# 16 2023-01-17         1692         103         8  25.89      0.09  188.4792
# 17 2023-01-18         1004         177         2  71.99      0.17  119.5034
# 18 2023-01-19         1541         142         1  69.28      0.03   67.2016
# 19 2023-01-20         1961         100         9  74.91      0.26  498.9006
# 20 2023-01-21         1524         114         5  96.53      0.26  357.1610
# 21 2023-01-22         1314         164         9  11.93      0.04  103.0752
# 22 2023-01-23         1525         115         4  17.27      0.02   67.6984
# 23 2023-01-24         1932         199         9  93.03      0.27  611.2071
# 24 2023-01-25         1886         143         8  90.15      0.04  692.3520
# 25 2023-01-26         1026         191         5  89.15      0.14  383.3450
# 26 2023-01-27         1198         143         4  89.95      0.07  334.6140
# 27 2023-01-28         1587         167         7  68.13      0.29  338.6061
# 28 2023-01-29         1874         198         4  92.53      0.00  370.1200
# 29 2023-01-30         1202         191         2  80.06      0.05  152.1140
# 30 2023-01-31         1744         160         4  42.71      0.28  123.0048
# 31 2023-02-01         1400         197         7  23.55      0.10  148.3650
# 32 2023-02-02         1574         174         6  63.39      0.30  266.2380
# 33 2023-02-03         1553         199         6  48.30      0.05  275.3100
# 34 2023-02-04         1223         141         1  63.85      0.26   47.2490
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          2   West    Credit Card       True              6            63
# 1          2  South    Credit Card      False              6            48
# 2          9   East           Cash       True              1            56
# 3          9  South    Credit Card       True              4            48
# 4          5  North         Online      False              1            56
# 5          1  North         Online      False              6            67
# 6          7   East         Online       True              1            20
# 7          1  North           Cash       True              2            47
# 8          7   East    Credit Card       True              6            54
# 9          8  South         Online      False              3            18
# 10         3  South    Credit Card      False              3            43
# 11         3  South    Credit Card       True              1            38
# 12         5   West    Credit Card       True              5            42
# 13         4  South         Online       True              3            46
# 14         3  North    Credit Card       True              2            55
# 15         1  South         Online      False              6            62
# 16         6   West    Credit Card       True              1            50
# 17         1   West    Credit Card      False              4            51
# 18         5  South           Cash      False              1            37
# 19         5  North         Online       True              6            31
# 20         6  North         Online      False              2            62
# 21         2   West    Credit Card       True              3            22
# 22         6  North         Online      False              4            18
# 23         1   West           Cash      False              2            53
# 24         4  South         Online      False              1            18
# 25         6   East    Credit Card       True              6            44
# 26         5  South    Credit Card      False              3            23
# 27         5  South           Cash      False              5            40
# 28         8  South         Online       True              3            59
# 29         9   West    Credit Card       True              6            18
# 30         2   West           Cash      False              4            51
# 31         5  South         Online       True              1            50
# 32         7  South         Online       True              4            24
# 33         2   East    Credit Card      False              5            24
# 34         4   West    Credit Card       True              5            29
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other             Food     1.7      Returned  Negative            NaN
# 1     Male             Food     4.8      Returned  Negative          17.43
# 2   Female            Books     4.9  Not Returned  Positive          11.66
# 3    Other             Food     3.4      Returned  Positive            NaN
# 4   Female            Books     3.9      Returned  Negative          18.49
# 5     Male         Clothing     1.3  Not Returned  Positive          14.77
# 6     Male         Clothing     1.7      Returned  Positive           9.32
# 7     Male             Food     1.8  Not Returned  Negative          12.88
# 8    Other      Electronics     1.6      Returned  Positive          13.69
# 9     Male             Food     4.4      Returned   Neutral          13.82
# 10   Other             Food     2.2      Returned  Negative          11.49
# 11    Male         Clothing     3.0  Not Returned  Positive          18.57
# 12    Male            Books     4.3      Returned  Negative            NaN
# 13    Male      Electronics     2.5      Returned  Positive          16.46
# 14    Male      Electronics     4.6  Not Returned   Neutral          18.69
# 15  Female      Electronics     4.6      Returned  Negative            NaN
# 16    Male            Books     3.5  Not Returned  Negative            NaN
# 17   Other         Clothing     4.8      Returned  Negative            NaN
# 18    Male      Electronics     2.0      Returned  Positive          14.60
# 19    Male         Clothing     2.6  Not Returned  Negative            NaN
# 20   Other         Clothing     2.1  Not Returned  Negative          12.99
# 21  Female            Books     3.6  Not Returned  Positive          18.50
# 22    Male         Clothing     4.5  Not Returned  Positive          15.95
# 23  Female      Electronics     4.9      Returned   Neutral          12.63
# 24    Male      Electronics     3.1  Not Returned   Neutral          17.76
# 25    Male         Clothing     2.1  Not Returned   Neutral           9.20
# 26   Other            Books     1.9      Returned  Positive          10.82
# 27    Male             Food     2.9  Not Returned   Neutral          14.77
# 28  Female         Clothing     4.7  Not Returned  Negative            NaN
# 29   Other            Books     1.2  Not Returned   Neutral            NaN
# 30   Other            Books     2.0      Returned  Positive            NaN
# 31  Female      Electronics     2.3  Not Returned  Negative           8.22
# 32  Female             Food     3.7  Not Returned  Negative            NaN
# 33  Female            Books     4.4      Returned  Positive           9.71
# 34    Male         Clothing     4.6  Not Returned  Negative           6.49
#
#    coupon_code  delivery_rating
# 0     WELCOME5              4.1
# 1          nan              1.7
# 2     FREESHIP              NaN
# 3          nan              2.8
# 4          nan              4.9
# 5          nan              1.4
# 6     FREESHIP              1.2
# 7          nan              1.5
# 8          nan              3.6
# 9     FREESHIP              NaN
# 10         nan              2.4
# 11    WELCOME5              NaN
# 12      SAVE10              3.3
# 13      SAVE10              4.5
# 14    WELCOME5              3.6
# 15         nan              1.7
# 16    WELCOME5              4.4
# 17      SAVE10              3.4
# 18      SAVE10              1.5
# 19      SAVE10              NaN
# 20      SAVE10              NaN
# 21    FREESHIP              4.1
# 22         nan              3.0
# 23      SAVE10              NaN
# 24      SAVE10              2.9
# 25         nan              NaN
# 26         nan              2.8
# 27         nan              NaN
# 28      SAVE10              4.3
# 29      SAVE10              NaN
# 30    FREESHIP              3.4
# 31    WELCOME5              NaN
# 32         nan              4.7
# 33      SAVE10              1.8
# 34    WELCOME5              2.4

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 03:**
# </div>

# %%
# 3. Validating the Data Type of a Specific Column
# Write a Pandas program to validate the data type of a specific column in a DataFrame.

# Check if 'price' column is of type float
is_of_type = 'float64'
is_price_float = df['price'].dtype == is_of_type
is_price_float

# Validate the data type of 'price' column
if is_price_float:
    print("The 'price' column is of type {}.".format(df['price'].dtype))
else:
    print("The 'price' column is not of type {}, it is {}.".format(is_of_type, df['price'].dtype))
# Out:
# The 'price' column is of type float64.

# %% [markdown]
# <div class="alert alert-warning">
#
# **4. Checking Duplicate Rows in a DataFrame**
#
# **Write a Pandas program to check duplicate rows in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1177         171         5  18.98      0.04   91.1040
# 1  2023-01-02         1008         116         5  70.36      0.05  334.2100
# 2  2023-01-03         1350         190         4  70.24      0.17  233.1968
# 3  2023-01-04         1753         177         1  73.05      0.26   54.0570
# 4  2023-01-05         1265         106         7  93.51      0.25  490.9275
# 5  2023-01-06         1230         181         2  69.63      0.00  139.2600
# 6  2023-01-07         1637         148         6  11.03      0.24   50.2968
# 7  2023-01-08         1078         147         6  27.28      0.29  116.2128
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male             Food     3.0      Returned  Positive          14.24
# 1    Other         Clothing     4.7  Not Returned  Negative          11.09
# 2   Female             Food     3.3  Not Returned   Neutral          12.57
# 3    Other      Electronics     2.0  Not Returned  Negative          14.39
# 4    Other      Electronics     1.5  Not Returned  Negative           6.70
# 5   Female      Electronics     3.5      Returned  Negative          16.30
# 6    Other         Clothing     4.6      Returned   Neutral          17.03
# 7   Female            Books     2.6  Not Returned  Positive          10.92
# 8     Male             Food     1.5      Returned  Positive            NaN
# 9     Male             Food     1.3  Not Returned  Positive            NaN
# 10   Other            Books     1.5      Returned  Negative          11.36
# 11    Male      Electronics     4.5      Returned   Neutral          12.83
# 12  Female         Clothing     1.6  Not Returned   Neutral            NaN
# 13  Female            Books     2.8  Not Returned   Neutral           9.99
# 14  Female             Food     4.9      Returned  Negative          16.40
# 15  Female         Clothing     1.1      Returned   Neutral            NaN
# 16    Male      Electronics     4.6  Not Returned  Negative            NaN
# 17  Female         Clothing     1.3      Returned  Negative           7.49
# 18    Male         Clothing     2.6      Returned  Positive          17.12
# 19  Female      Electronics     1.0      Returned  Positive           9.93
# 20  Female             Food     3.2  Not Returned  Positive            NaN
# 21   Other            Books     1.1      Returned  Positive          11.98
# 22    Male             Food     2.4      Returned  Negative          20.00
# 23    Male      Electronics     4.8      Returned   Neutral          16.45
# 24    Male         Clothing     3.9      Returned   Neutral          13.58
# 25  Female             Food     1.1  Not Returned   Neutral           6.36
# 26  Female         Clothing     2.8  Not Returned   Neutral          19.11
# 27   Other      Electronics     4.3  Not Returned  Negative           9.69
# 28   Other         Clothing     3.8  Not Returned  Negative            NaN
# 29   Other      Electronics     2.2      Returned  Positive          17.11
# 30  Female         Clothing     4.4  Not Returned  Negative          11.42
# 31  Female             Food     2.7  Not Returned  Positive          17.26
# 32  Female      Electronics     1.3  Not Returned   Neutral          11.37
# 33   Other             Food     5.0      Returned  Negative          19.50
# 34  Female      Electronics     4.0      Returned  Negative            NaN
# 35  Female         Clothing     2.8  Not Returned   Neutral          19.11
# 36  Female            Books     2.8  Not Returned   Neutral           9.99
# 37    Male         Clothing     3.9      Returned   Neutral          13.58
#
#    coupon_code  delivery_rating
# 0          nan              NaN
# 1     FREESHIP              NaN
# 2     WELCOME5              NaN
# 3       SAVE10              NaN
# 4       SAVE10              NaN
# 5          nan              NaN
# 6     WELCOME5              3.8
# 7     WELCOME5              3.2
# 8          nan              3.1
# 9       SAVE10              1.1
# 10    FREESHIP              NaN
# 11         nan              4.9
# 12    WELCOME5              2.1
# 13    FREESHIP              NaN
# 14      SAVE10              1.6
# 15         nan              2.9
# 16      SAVE10              4.3
# 17         nan              1.8
# 18      SAVE10              2.0
# 19         nan              2.5
# 20         nan              2.6
# 21         nan              3.7
# 22         nan              NaN
# 23         nan              2.7
# 24      SAVE10              4.2
# 25         nan              NaN
# 26         nan              NaN
# 27    FREESHIP              NaN
# 28         nan              3.8
# 29    FREESHIP              1.8
# 30         nan              1.1
# 31      SAVE10              NaN
# 32    WELCOME5              3.1
# 33    WELCOME5              4.5
# 34    FREESHIP              1.1
# 35         nan              NaN
# 36    FREESHIP              NaN
# 37      SAVE10              4.2

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
# 4. Checking Duplicate Rows in a DataFrame
# Write a Pandas program to check duplicate rows in a DataFrame.

# Check for duplicate rows
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 35 2023-01-27         1371         108         5  49.19      0.28  177.0840
# 36 2023-01-14         1236         156         8  18.23      0.06  137.0896
# 37 2023-01-25         1786         173         2  91.61      0.10  164.8980
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 35         4   East           Cash       True              6            43
# 36         4   East         Online       True              2            42
# 37         8   East    Credit Card      False              4            63
#
#     gender product_category  rating return_status feedback  shipping_cost  \
# 35  Female         Clothing     2.8  Not Returned  Neutral          19.11
# 36  Female            Books     2.8  Not Returned  Neutral           9.99
# 37    Male         Clothing     3.9      Returned  Neutral          13.58
#
#    coupon_code  delivery_rating
# 35         nan              NaN
# 36    FREESHIP              NaN
# 37      SAVE10              4.2

# %% [markdown]
# <div class="alert alert-warning">
#
# **5. Removing Duplicate Rows from a DataFrame**
#
# **Write a Pandas program to remove duplicate rows from a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1670         119         6  85.65      0.02  503.6220
# 1  2023-01-02         1352         111         4  83.35      0.10  300.0600
# 2  2023-01-03         1761         183         3  92.77      0.16  233.7804
# 3  2023-01-04         1625         117         8  69.74      0.06  524.4448
# 4  2023-01-05         1436         118         3  25.31      0.13   66.0591
# 5  2023-01-06         1568         126         9  56.59      0.11  453.2859
# 6  2023-01-07         1600         143         9  13.40      0.12  106.1280
# 7  2023-01-08         1037         137         4  73.35      0.04  281.6640
# 8  2023-01-09         1191         138         5  20.95      0.04  100.5600
# 9  2023-01-10         1302         197         2  54.38      0.27   79.3948
# 10 2023-01-11         1081         148         5  70.04      0.19  283.6620
# 11 2023-01-12         1082         174         4  27.63      0.18   90.6264
# 12 2023-01-13         1703         106         9  79.10      0.26  526.8060
# 13 2023-01-14         1286         130         9  75.02      0.06  634.6692
# 14 2023-01-15         1783         188         8  45.81      0.08  337.1616
# 15 2023-01-16         1719         125         6  56.66      0.26  251.5704
# 16 2023-01-17         1899         127         6  60.39      0.28  260.8848
# 17 2023-01-18         1509         127         9  75.29      0.05  643.7295
# 18 2023-01-19         1007         135         1  51.83      0.22   40.4274
# 19 2023-01-20         1822         155         5  71.21      0.20  284.8400
# 20 2023-01-21         1589         150         4  93.64      0.01  370.8144
# 21 2023-01-22         1542         163         6  18.57      0.28   80.2224
# 22 2023-01-23         1169         171         5  27.38      0.25  102.6750
# 23 2023-01-24         1043         166         3  30.48      0.14   78.6384
# 24 2023-01-25         1280         110         7  64.54      0.22  352.3884
# 25 2023-01-26         1034         112         2  20.89      0.27   30.4994
# 26 2023-01-27         1389         186         3  63.04      0.26  139.9488
# 27 2023-01-28         1148         108         3  29.08      0.06   82.0056
# 28 2023-01-29         1898         111         2  31.48      0.22   49.1088
# 29 2023-01-30         1812         167         6  32.21      0.25  144.9450
# 30 2023-01-31         1625         175         9  50.35      0.20  362.5200
# 31 2023-02-01         1240         189         8  76.46      0.11  544.3952
# 32 2023-02-02         1890         138         8  29.94      0.24  182.0352
# 33 2023-02-03         1885         146         8  21.43      0.17  142.2952
# 34 2023-02-04         1504         103         7  70.74      0.05  470.4210
# 35 2023-01-27         1389         186         3  63.04      0.26  139.9488
# 36 2023-01-14         1286         130         9  75.02      0.06  634.6692
# 37 2023-01-25         1280         110         7  64.54      0.22  352.3884
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5  South         Online      False              3            52
# 1          1   West           Cash       True              1            33
# 2          3   West    Credit Card      False              5            49
# 3          6  North         Online      False              6            21
# 4          4  South    Credit Card      False              5            33
# 5          4  North           Cash      False              3            53
# 6          8  North    Credit Card      False              4            57
# 7          9  North    Credit Card      False              6            30
# 8          2  North    Credit Card       True              5            31
# 9          1  South           Cash       True              2            64
# 10         5  South           Cash       True              3            19
# 11         6   East    Credit Card      False              5            31
# 12         5   East           Cash       True              2            60
# 13         4   East    Credit Card       True              1            58
# 14         8   West    Credit Card       True              1            64
# 15         1   East         Online      False              6            47
# 16         8   East         Online       True              6            20
# 17         1   East         Online      False              1            27
# 18         9   East           Cash       True              4            47
# 19         5  North         Online       True              1            69
# 20         4  South    Credit Card       True              4            33
# 21         8   West           Cash      False              4            57
# 22         1   East         Online       True              3            33
# 23         1  North         Online       True              4            59
# 24         1  North         Online       True              4            64
# 25         1  South         Online       True              5            38
# 26         3  South           Cash       True              2            44
# 27         2   East         Online      False              4            28
# 28         4  South         Online       True              1            41
# 29         6  South           Cash      False              5            45
# 30         6   East           Cash       True              5            67
# 31         2   East           Cash      False              6            37
# 32         8   West         Online      False              6            42
# 33         7   East         Online      False              3            69
# 34         1   East    Credit Card       True              5            63
# 35         3  South           Cash       True              2            44
# 36         4   East    Credit Card       True              1            58
# 37         1  North         Online       True              4            64
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female             Food     2.2  Not Returned  Positive          12.53
# 1   Female             Food     1.3      Returned   Neutral          11.96
# 2    Other             Food     1.8  Not Returned  Negative            NaN
# 3     Male             Food     3.0      Returned  Negative          18.31
# 4   Female             Food     3.3  Not Returned   Neutral            NaN
# 5   Female      Electronics     3.0  Not Returned  Positive           6.60
# 6    Other             Food     1.7  Not Returned  Positive          19.64
# 7   Female            Books     1.3  Not Returned   Neutral          13.57
# 8    Other            Books     1.6      Returned  Negative            NaN
# 9    Other      Electronics     1.7      Returned  Positive           8.95
# 10    Male            Books     3.6      Returned  Positive           9.01
# 11  Female         Clothing     2.1      Returned  Positive          13.74
# 12    Male      Electronics     3.7      Returned  Negative            NaN
# 13  Female      Electronics     3.9  Not Returned   Neutral          15.93
# 14  Female            Books     1.7  Not Returned  Positive            NaN
# 15  Female            Books     1.0      Returned  Negative           6.58
# 16    Male      Electronics     2.8  Not Returned   Neutral          15.72
# 17  Female      Electronics     4.4      Returned   Neutral           9.17
# 18  Female             Food     4.2      Returned  Positive            NaN
# 19  Female         Clothing     2.0  Not Returned  Positive          10.31
# 20   Other         Clothing     1.1  Not Returned  Negative          14.92
# 21    Male      Electronics     3.9  Not Returned   Neutral          17.27
# 22  Female             Food     3.1  Not Returned  Positive            NaN
# 23    Male         Clothing     2.7  Not Returned  Negative            NaN
# 24    Male      Electronics     2.4  Not Returned  Negative           9.25
# 25    Male            Books     2.7  Not Returned  Negative          17.54
# 26   Other             Food     2.3      Returned  Negative          10.42
# 27   Other      Electronics     2.3      Returned  Negative           9.90
# 28  Female            Books     1.8  Not Returned  Negative          12.72
# 29    Male             Food     4.4  Not Returned  Positive          15.13
# 30   Other      Electronics     2.4  Not Returned  Positive          14.90
# 31  Female            Books     4.7      Returned  Negative          10.82
# 32  Female            Books     3.7      Returned  Negative           7.28
# 33   Other             Food     1.9      Returned  Positive          15.60
# 34  Female         Clothing     1.0      Returned  Negative          18.67
# 35   Other             Food     2.3      Returned  Negative          10.42
# 36  Female      Electronics     3.9  Not Returned   Neutral          15.93
# 37    Male      Electronics     2.4  Not Returned  Negative           9.25
#
#    coupon_code  delivery_rating
# 0       SAVE10              2.4
# 1          nan              2.1
# 2     WELCOME5              1.5
# 3     FREESHIP              1.7
# 4     FREESHIP              NaN
# 5     FREESHIP              2.9
# 6          nan              4.1
# 7       SAVE10              1.4
# 8     WELCOME5              3.2
# 9       SAVE10              NaN
# 10         nan              3.6
# 11      SAVE10              3.6
# 12    WELCOME5              NaN
# 13         nan              NaN
# 14      SAVE10              3.8
# 15         nan              NaN
# 16      SAVE10              1.4
# 17      SAVE10              NaN
# 18      SAVE10              4.8
# 19         nan              1.3
# 20    FREESHIP              NaN
# 21         nan              2.5
# 22      SAVE10              NaN
# 23    WELCOME5              1.7
# 24    FREESHIP              NaN
# 25      SAVE10              1.0
# 26         nan              4.9
# 27         nan              4.3
# 28         nan              2.5
# 29         nan              2.4
# 30    WELCOME5              NaN
# 31    WELCOME5              1.5
# 32      SAVE10              2.2
# 33      SAVE10              3.2
# 34         nan              NaN
# 35         nan              4.9
# 36         nan              NaN
# 37    FREESHIP              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
# 5. Removing Duplicate Rows from a DataFrame
# Write a Pandas program to remove duplicate rows from a DataFrame.

print("Shape of DataFrame before removing duplicates:\n", df.shape)
# Remove duplicate rows
df = df.drop_duplicates()
print("Shape of DataFrame after removing duplicates:\n", df.shape)
# Out:
# Shape of DataFrame before removing duplicates:
#  (38, 21)
# Shape of DataFrame after removing duplicates:
#  (35, 21)

# %% [markdown]
# <div class="alert alert-warning">
#
# **6. Validating Data Based on Custom Conditions**
#
# **Write a Pandas program to validate data based on custom conditions.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1235         139         3  11.93      0.08   32.9268
# 1  2023-01-02         1142         183         8  96.70      0.00  773.6000
# 2  2023-01-03         1499         135         1  78.47      0.15   66.6995
# 3  2023-01-04         1101         155         7  19.93      0.11  124.1639
# 4  2023-01-05         1988         171         1  14.73      0.26   10.9002
# 5  2023-01-06         1300         177         1  22.55      0.00   22.5500
# 6  2023-01-07         1020         198         8  80.53      0.10  579.8160
# 7  2023-01-08         1334         155         2  21.91      0.11   38.9998
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male         Clothing     4.0  Not Returned  Positive          18.83
# 1    Other      Electronics     4.4      Returned  Negative          16.87
# 2   Female      Electronics     2.1      Returned  Positive            NaN
# 3    Other         Clothing     3.3  Not Returned  Negative          17.96
# 4     Male      Electronics     3.6  Not Returned  Positive          19.60
# 5     Male         Clothing     4.7  Not Returned   Neutral          12.96
# 6    Other             Food     3.9  Not Returned  Positive          19.32
# 7    Other             Food     2.8  Not Returned  Negative          19.31
# 8    Other         Clothing     4.1      Returned  Negative          11.65
# 9   Female            Books     3.6  Not Returned  Positive            NaN
# 10  Female             Food     1.7      Returned  Positive           6.66
# 11    Male      Electronics     3.3      Returned   Neutral          13.85
# 12  Female      Electronics     2.0  Not Returned  Negative          15.68
# 13  Female             Food     1.1  Not Returned  Positive            NaN
# 14   Other         Clothing     4.7      Returned  Positive          13.83
# 15    Male             Food     4.4  Not Returned  Negative            NaN
# 16  Female         Clothing     4.5  Not Returned   Neutral           9.73
# 17    Male         Clothing     3.2  Not Returned  Positive            NaN
# 18   Other             Food     3.3      Returned  Negative          11.54
# 19    Male         Clothing     2.6  Not Returned  Positive          10.71
# 20  Female            Books     2.0      Returned  Positive          15.62
# 21  Female             Food     3.3  Not Returned   Neutral            NaN
# 22  Female         Clothing     3.9  Not Returned  Positive          14.33
# 23    Male             Food     4.4      Returned  Negative            NaN
# 24    Male             Food     1.5      Returned  Positive          14.59
# 25    Male             Food     3.8      Returned  Positive          14.25
# 26  Female            Books     4.8  Not Returned   Neutral          15.95
# 27  Female         Clothing     3.0  Not Returned  Positive            NaN
# 28    Male         Clothing     3.4      Returned   Neutral           6.35
# 29  Female             Food     3.9  Not Returned   Neutral          17.13
# 30   Other            Books     2.8      Returned   Neutral            NaN
# 31    Male             Food     3.2      Returned   Neutral           5.27
# 32   Other            Books     3.5      Returned  Positive            NaN
# 33   Other            Books     2.5      Returned   Neutral            NaN
# 34  Female         Clothing     3.2      Returned  Positive            NaN
# 35  Female            Books     4.8  Not Returned   Neutral          15.95
# 36  Female             Food     1.1  Not Returned  Positive            NaN
# 37    Male             Food     1.5      Returned  Positive          14.59
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0          nan              NaN
# 1       SAVE10              1.4
# 2       SAVE10              1.8
# 3     FREESHIP              2.2
# 4     WELCOME5              3.7
# 5       SAVE10              4.7
# 6       SAVE10              NaN
# 7     WELCOME5              4.7
# 8     FREESHIP              2.0
# 9          nan              4.6
# 10         nan              2.9
# 11      SAVE10              4.7
# 12    FREESHIP              NaN
# 13      SAVE10              1.1
# 14         nan              NaN
# 15    FREESHIP              NaN
# 16         nan              NaN
# 17    WELCOME5              2.0
# 18    FREESHIP              1.1
# 19         nan              2.8
# 20    WELCOME5              NaN
# 21         nan              NaN
# 22    WELCOME5              1.8
# 23      SAVE10              NaN
# 24    FREESHIP              NaN
# 25         nan              NaN
# 26      SAVE10              2.8
# 27         nan              NaN
# 28    FREESHIP              2.0
# 29         nan              1.0
# 30      SAVE10              1.8
# 31    WELCOME5              NaN
# 32         nan              4.2
# 33    FREESHIP              4.4
# 34         nan              NaN
# 35      SAVE10              2.8
# 36      SAVE10              1.1
# 37    FREESHIP              NaN
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 06:**
# </div>

# %%
# 6. Validating Data Based on Custom Conditions
# Write a Pandas program to validate data based on custom conditions.

# Check if 'price' is greater than 0
valid_price = df['price'] > 0
if valid_price.all():
    print("All prices are valid.")
else:
    print("Some prices are invalid:")
    display(df[~valid_price])
# Out:
# Some prices are invalid:
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **7. Checking That a Specific Column Contains Only Unique Values**
#
# **Write a Pandas program to check that a specific column contains only unique values.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1129         195         7  18.16      0.03  123.3064
# 1  2023-01-02         1769         157         5  19.00      0.03   92.1500
# 2  2023-01-03         1299         111         5  31.23      0.23  120.2355
# 3  2023-01-04         1766         117         3  72.77      0.12  192.1128
# 4  2023-01-05         1906         122         2  55.06      0.07  102.4116
# 5  2023-01-06         1943         191         5  79.52      0.26  294.2240
# 6  2023-01-07         1883         146         5  45.20      0.03  219.2200
# 7  2023-01-08         1799         145         7  29.93      0.02  205.3198
# 8  2023-01-09         1567         181         1  87.84      0.14   75.5424
# 9  2023-01-10         1126         132         6  81.41      0.01  483.5754
# 10 2023-01-11         1786         188         3  60.62      0.00  181.8600
# 11 2023-01-12         1901         192         7  99.39      0.06  653.9862
# 12 2023-01-13         1615         181         4  10.39      0.22   32.4168
# 13 2023-01-14         1189         103         4  28.07      0.03  108.9116
# 14 2023-01-15         1441         145         2  36.62      0.15   62.2540
# 15 2023-01-16         1218         148         1  41.18      0.13   35.8266
# 16 2023-01-17         1472         112         5  41.57      0.12  182.9080
# 17 2023-01-18         1673         183         6  98.79      0.08  545.3208
# 18 2023-01-19         1857         157         9  30.09      0.25  203.1075
# 19 2023-01-20         1185         134         3  24.50      0.10   66.1500
# 20 2023-01-21         1061         162         4  31.19      0.12  109.7888
# 21 2023-01-22         1717         177         5  51.75      0.05  245.8125
# 22 2023-01-23         1594         157         1  45.42      0.12   39.9696
# 23 2023-01-24         1304         171         3  91.69      0.18  225.5574
# 24 2023-01-25         1693         171         8  53.94      0.19  349.5312
# 25 2023-01-26         1269         124         4  52.58      0.10  189.2880
# 26 2023-01-27         1528         191         3  10.35      0.07   28.8765
# 27 2023-01-28         1681         112         1  59.87      0.05   56.8765
# 28 2023-01-29         1817         180         4  70.61      0.01  279.6156
# 29 2023-01-30         1921         181         3  81.67      0.17  203.3583
# 30 2023-01-31         1355         191         1  11.52      0.18    9.4464
# 31 2023-02-01         1122         135         9  60.91      0.13  476.9253
# 32 2023-02-02         1904         151         6  51.24      0.03  298.2168
# 33 2023-02-03         1584         180         1  38.65      0.06   36.3310
# 34 2023-02-04         1515         142         8  29.49      0.29  167.5032
# 35 2023-01-27         1528         191         3  10.35      0.07   28.8765
# 36 2023-01-14         1189         103         4  28.07      0.03  108.9116
# 37 2023-01-25         1693         171         8  53.94      0.19  349.5312
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          7   West         Online      False              1            45
# 1          1   West           Cash       True              5            27
# 2          6   East         Online       True              2            32
# 3          1   West         Online       True              4            42
# 4          4  South    Credit Card       True              5            69
# 5          4   East           Cash       True              3            41
# 6          2  North         Online      False              6            44
# 7          1  South         Online      False              5            36
# 8          6   East    Credit Card       True              2            26
# 9          8   West         Online      False              2            40
# 10         2   West           Cash       True              1            54
# 11         6  South    Credit Card      False              2            29
# 12         4  North         Online       True              3            58
# 13         5   West         Online       True              2            21
# 14         3   West    Credit Card      False              3            63
# 15         8  North           Cash      False              6            55
# 16         3  South         Online       True              4            22
# 17         1   East         Online      False              2            48
# 18         3   West           Cash       True              1            54
# 19         8   East    Credit Card       True              3            40
# 20         8   East           Cash      False              6            38
# 21         5   West    Credit Card       True              2            40
# 22         7  South           Cash      False              4            53
# 23         5   West           Cash       True              1            30
# 24         5  South           Cash       True              6            48
# 25         7   West    Credit Card       True              3            57
# 26         3  South    Credit Card       True              1            20
# 27         6  North           Cash      False              1            35
# 28         5   East           Cash      False              3            21
# 29         4   West           Cash       True              4            62
# 30         3   West    Credit Card      False              4            20
# 31         8  South         Online       True              1            38
# 32         1   East    Credit Card       True              3            33
# 33         1  North         Online      False              6            56
# 34         7  North         Online      False              5            22
# 35         3  South    Credit Card       True              1            20
# 36         5   West         Online       True              2            21
# 37         5  South           Cash       True              6            48
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other             Food     4.8      Returned  Positive          13.66
# 1    Other         Clothing     3.0  Not Returned   Neutral          11.82
# 2   Female            Books     3.0  Not Returned  Positive          10.10
# 3    Other             Food     2.0      Returned  Negative          18.27
# 4     Male         Clothing     2.8  Not Returned  Positive          13.90
# 5     Male         Clothing     4.6      Returned  Negative            NaN
# 6     Male         Clothing     1.5  Not Returned  Negative          12.35
# 7   Female         Clothing     1.5      Returned  Negative           6.91
# 8    Other            Books     3.9      Returned  Positive          13.54
# 9    Other      Electronics     1.5  Not Returned  Negative           9.37
# 10    Male            Books     3.3      Returned   Neutral            NaN
# 11   Other            Books     5.0      Returned  Negative           9.49
# 12   Other         Clothing     4.1      Returned   Neutral            NaN
# 13   Other             Food     3.4      Returned  Positive            NaN
# 14   Other      Electronics     4.1  Not Returned  Negative           8.08
# 15    Male         Clothing     2.9      Returned  Negative          11.99
# 16  Female         Clothing     2.2  Not Returned  Positive          17.45
# 17    Male            Books     3.2      Returned  Negative          11.98
# 18    Male             Food     3.1  Not Returned  Positive          19.68
# 19    Male            Books     2.9      Returned  Negative           6.36
# 20    Male      Electronics     4.5      Returned   Neutral          10.51
# 21  Female             Food     3.7      Returned  Positive          14.40
# 22  Female             Food     4.4      Returned   Neutral            NaN
# 23  Female            Books     2.4  Not Returned  Negative          12.47
# 24    Male            Books     4.1  Not Returned  Positive          12.08
# 25   Other      Electronics     4.5  Not Returned  Negative           9.08
# 26    Male             Food     2.8  Not Returned  Negative          17.28
# 27    Male             Food     4.5      Returned   Neutral            NaN
# 28    Male         Clothing     3.2  Not Returned  Negative          11.23
# 29  Female            Books     3.7      Returned   Neutral            NaN
# 30  Female            Books     4.6      Returned  Negative          17.88
# 31    Male         Clothing     2.5  Not Returned   Neutral           5.71
# 32  Female      Electronics     1.0      Returned  Positive          11.18
# 33  Female            Books     4.1  Not Returned  Positive           6.48
# 34   Other         Clothing     2.1      Returned   Neutral          14.18
# 35    Male             Food     2.8  Not Returned  Negative          17.28
# 36   Other             Food     3.4      Returned  Positive            NaN
# 37    Male            Books     4.1  Not Returned  Positive          12.08
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0       SAVE10              3.6          1
# 1          nan              NaN          2
# 2          nan              1.5          3
# 3     WELCOME5              4.1          4
# 4     FREESHIP              4.6          5
# 5       SAVE10              4.5          6
# 6       SAVE10              NaN          7
# 7     WELCOME5              NaN          8
# 8          nan              1.6          9
# 9     FREESHIP              1.5         10
# 10      SAVE10              3.9         11
# 11      SAVE10              3.4         12
# 12         nan              NaN         13
# 13         nan              4.1         14
# 14    FREESHIP              4.7         15
# 15    WELCOME5              4.4         16
# 16         nan              NaN         17
# 17      SAVE10              1.5         18
# 18    FREESHIP              NaN         19
# 19    WELCOME5              4.9         20
# 20      SAVE10              1.2         21
# 21         nan              NaN         22
# 22         nan              3.7         23
# 23         nan              4.8         24
# 24      SAVE10              2.1         25
# 25    WELCOME5              4.7         26
# 26      SAVE10              4.7         27
# 27         nan              NaN         28
# 28    WELCOME5              1.1         29
# 29      SAVE10              3.4         30
# 30         nan              2.2         31
# 31    WELCOME5              4.4         32
# 32    WELCOME5              4.7         33
# 33         nan              3.1         34
# 34         nan              NaN         35
# 35      SAVE10              4.7         36
# 36         nan              4.1         37
# 37      SAVE10              2.1         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 07:**
# </div>

# %%
pd.Series.is_unique?
# Out:
# Type:        property
# String form: <property object at 0x1087d43b0>
# Docstring:
# Return boolean if values in the object are unique.
#
# Returns
# -------
# bool
#
# Examples
# --------
# >>> s = pd.Series([1, 2, 3])
# >>> s.is_unique
# True
#
# >>> s = pd.Series([1, 2, 3, 1])
# >>> s.is_unique
# False

# %%
# 7. Checking That a Specific Column Contains Only Unique Values
# Write a Pandas program to check that a specific column contains only unique values.


def is_unique(column_name, dataframe):
    if dataframe[column_name].is_unique:
        print("The column {:<20} contains only unique values.".format(column_name))
    else:
        print("The column {:<20} has more than one unique value - has duplicates.".format(column_name))

for col in df.columns:
    is_unique(col, df)
# Out:
# The column date                 has more than one unique value - has duplicates.
# The column customer_id          has more than one unique value - has duplicates.
# The column product_id           has more than one unique value - has duplicates.
# The column quantity             has more than one unique value - has duplicates.
# The column price                has more than one unique value - has duplicates.
# The column discount             has more than one unique value - has duplicates.
# The column revenue              has more than one unique value - has duplicates.
# The column store_id             has more than one unique value - has duplicates.
# The column region               has more than one unique value - has duplicates.
# The column payment_method       has more than one unique value - has duplicates.
# The column is_member            has more than one unique value - has duplicates.
# The column delivery_days        has more than one unique value - has duplicates.
# The column customer_age         has more than one unique value - has duplicates.
# The column gender               has more than one unique value - has duplicates.
# The column product_category     has more than one unique value - has duplicates.
# The column rating               has more than one unique value - has duplicates.
# The column return_status        has more than one unique value - has duplicates.
# The column feedback             has more than one unique value - has duplicates.
# The column shipping_cost        has more than one unique value - has duplicates.
# The column coupon_code          has more than one unique value - has duplicates.
# The column delivery_rating      has more than one unique value - has duplicates.
# The column unique_id            contains only unique values.

# %% [markdown]
# <div class="alert alert-warning">
#
# **8. Detecting Outliers in a DataFrame**
#
# **Write a Pandas program to detect outliers in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1797         129         5  9999.99      0.08  267.2140
# 1  2023-01-02         1054         130         5    30.23      0.01  149.6385
# 2  2023-01-03         1460         184         9    80.60      0.16  609.3360
# 3  2023-01-04         1377         185         5  8888.88      0.06  446.3120
# 4  2023-01-05         1347         133         5    29.21      0.30  102.2350
# 5  2023-01-06         1428         194         1  7777.77      0.01   98.5743
# 6  2023-01-07         1043         189         2    65.12      0.02  127.6352
# 7  2023-01-08         1094         107         8    99.99      0.09  727.9272
# 8  2023-01-09         1036         193         8    93.45      0.15  635.4600
# 9  2023-01-10         1584         133         4    25.24      0.09   91.8736
# 10 2023-01-11         1046         168         5    24.89      0.25   93.3375
# 11 2023-01-12         1535         123         7    40.02      0.08  257.7288
# 12 2023-01-13         1606         103         2    22.27      0.23   34.2958
# 13 2023-01-14         1269         186         8    44.10      0.10  317.5200
# 14 2023-01-15         1556         162         3    84.35      0.19  204.9705
# 15 2023-01-16         1974         149         1    18.57      0.30   12.9990
# 16 2023-01-17         1022         136         1    82.58      0.14   71.0188
# 17 2023-01-18         1594         117         1    63.63      0.19   51.5403
# 18 2023-01-19         1234         111         1    48.60      0.27   35.4780
# 19 2023-01-20         1089         108         8    76.96      0.06  578.7392
# 20 2023-01-21         1513         128         2    71.55      0.09  130.2210
# 21 2023-01-22         1422         162         5    69.34      0.09  315.4970
# 22 2023-01-23         1553         138         7    79.99      0.22  436.7454
# 23 2023-01-24         1202         136         7    19.26      0.02  132.1236
# 24 2023-01-25         1546         154         6    66.46      0.07  370.8468
# 25 2023-01-26         1352         183         5    57.00      0.22  222.3000
# 26 2023-01-27         1291         120         7    85.45      0.18  490.4830
# 27 2023-01-28         1006         196         6    89.53      0.23  413.6286
# 28 2023-01-29         1097         176         9    65.40      0.13  512.0820
# 29 2023-01-30         1785         176         7    98.83      0.24  525.7756
# 30 2023-01-31         1107         146         9    25.29      0.02  223.0578
# 31 2023-02-01         1546         152         6    40.00      0.05  228.0000
# 32 2023-02-02         1261         110         9    67.30      0.01  599.6430
# 33 2023-02-03         1878         122         3    36.16      0.15   92.2080
# 34 2023-02-04         1904         133         5    62.33      0.02  305.4170
# 35 2023-01-27         1291         120         7    85.45      0.18  490.4830
# 36 2023-01-14         1269         186         8    44.10      0.10  317.5200
# 37 2023-01-25         1546         154         6    66.46      0.07  370.8468
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          8   West         Online       True              6            57
# 1          2   West         Online       True              6            53
# 2          3   East    Credit Card      False              3            69
# 3          5   East         Online      False              4            34
# 4          5  South    Credit Card       True              2            52
# 5          4   East           Cash      False              2            50
# 6          5  North           Cash      False              6            29
# 7          5  South    Credit Card      False              4            20
# 8          3  North           Cash       True              2            31
# 9          9   East         Online      False              1            49
# 10         9   East           Cash       True              6            28
# 11         4  South           Cash      False              2            41
# 12         4  North    Credit Card       True              5            59
# 13         6  North    Credit Card      False              4            22
# 14         3   West    Credit Card      False              4            25
# 15         3  North           Cash      False              6            57
# 16         5  South         Online       True              5            57
# 17         2  South           Cash      False              1            39
# 18         4   West           Cash      False              5            23
# 19         7   East         Online       True              3            56
# 20         3  North    Credit Card      False              5            68
# 21         8   East         Online       True              2            21
# 22         8   West         Online      False              3            29
# 23         7   East           Cash      False              5            54
# 24         5  South         Online       True              3            68
# 25         9   West    Credit Card      False              3            65
# 26         6  North         Online       True              2            28
# 27         5  North    Credit Card      False              4            38
# 28         2   West    Credit Card       True              5            49
# 29         1  North         Online      False              6            43
# 30         8  North         Online      False              4            40
# 31         2  South         Online       True              5            43
# 32         8   West    Credit Card       True              1            25
# 33         1   East         Online      False              5            47
# 34         9  North           Cash      False              6            59
# 35         6  North         Online       True              2            28
# 36         6  North    Credit Card      False              4            22
# 37         5  South         Online       True              3            68
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male            Books     3.9      Returned  Positive          19.31
# 1   Female         Clothing     3.4  Not Returned   Neutral          19.72
# 2     Male            Books     3.2      Returned  Positive           5.55
# 3     Male             Food     1.3  Not Returned  Positive          13.91
# 4   Female         Clothing     2.6      Returned  Negative          12.00
# 5     Male            Books     4.3      Returned   Neutral            NaN
# 6    Other            Books     1.8      Returned  Negative          19.29
# 7   Female            Books     4.4  Not Returned   Neutral            NaN
# 8    Other            Books     1.9  Not Returned  Positive          11.48
# 9   Female      Electronics     1.6  Not Returned  Negative           8.87
# 10  Female            Books     3.4  Not Returned  Negative          11.71
# 11   Other            Books     4.6  Not Returned  Positive          14.17
# 12  Female         Clothing     4.0      Returned   Neutral          14.21
# 13    Male         Clothing     2.9  Not Returned  Negative            NaN
# 14  Female         Clothing     4.9  Not Returned  Negative           7.56
# 15   Other         Clothing     4.4  Not Returned   Neutral           9.16
# 16   Other             Food     2.8  Not Returned  Negative           6.38
# 17  Female            Books     4.2      Returned   Neutral          14.60
# 18   Other            Books     3.7  Not Returned  Positive            NaN
# 19  Female            Books     2.0  Not Returned  Positive           6.36
# 20  Female             Food     5.0  Not Returned   Neutral          17.93
# 21   Other         Clothing     4.2      Returned   Neutral           5.12
# 22   Other             Food     5.0  Not Returned  Positive            NaN
# 23    Male      Electronics     3.1  Not Returned  Negative          18.55
# 24  Female      Electronics     1.9  Not Returned  Positive            NaN
# 25  Female            Books     2.9  Not Returned   Neutral          13.35
# 26  Female            Books     4.6      Returned  Negative          14.76
# 27   Other             Food     2.3  Not Returned  Negative           7.27
# 28  Female            Books     1.4      Returned  Negative          15.53
# 29  Female             Food     4.8      Returned   Neutral            NaN
# 30   Other      Electronics     2.2  Not Returned  Positive          17.78
# 31   Other      Electronics     3.4  Not Returned   Neutral          13.32
# 32    Male             Food     3.4      Returned  Positive            NaN
# 33    Male      Electronics     4.9  Not Returned  Negative          12.28
# 34   Other             Food     4.9      Returned  Negative           7.17
# 35  Female            Books     4.6      Returned  Negative          14.76
# 36    Male         Clothing     2.9  Not Returned  Negative            NaN
# 37  Female      Electronics     1.9  Not Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              NaN          1
# 1     WELCOME5              2.7          2
# 2       SAVE10              1.2          3
# 3          nan              4.1          4
# 4          nan              3.2          5
# 5     WELCOME5              1.6          6
# 6     FREESHIP              2.6          7
# 7     FREESHIP              2.0          8
# 8          nan              4.4          9
# 9       SAVE10              3.6         10
# 10      SAVE10              3.2         11
# 11         nan              4.7         12
# 12      SAVE10              2.2         13
# 13    WELCOME5              NaN         14
# 14    FREESHIP              NaN         15
# 15    FREESHIP              1.1         16
# 16    WELCOME5              NaN         17
# 17         nan              NaN         18
# 18         nan              4.4         19
# 19    WELCOME5              NaN         20
# 20         nan              3.4         21
# 21    WELCOME5              NaN         22
# 22         nan              3.0         23
# 23         nan              2.3         24
# 24    FREESHIP              NaN         25
# 25         nan              NaN         26
# 26    WELCOME5              1.6         27
# 27         nan              2.9         28
# 28      SAVE10              3.5         29
# 29         nan              2.8         30
# 30    FREESHIP              3.9         31
# 31      SAVE10              1.1         32
# 32         nan              NaN         33
# 33    FREESHIP              1.1         34
# 34    FREESHIP              NaN         35
# 35    WELCOME5              1.6         36
# 36    WELCOME5              NaN         37
# 37    FREESHIP              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 08:**
# </div>

# %%
# 8. Detecting Outliers in a DataFrame
# Write a Pandas program to detect outliers in a DataFrame.

def detect_outliers(column_name, dataframe):
    if dataframe[column_name].dtype not in [np.float64, np.int64]:
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        Q1 = dataframe[column_name].quantile(0.25)
        Q3 = dataframe[column_name].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = dataframe[(dataframe[column_name] < lower_bound) | (dataframe[column_name] > upper_bound)]
    if not outliers.empty:
        print("Column {:>30} OUTLIERS DETECTED.\n####### OUTLIERS #######".format(column_name))
        display(outliers)
    else:
        print("Column {:>30} has no outliers detected.".format(column_name))

for col in df.columns:
    detect_outliers(col, df)
# Out:
# Column                           date is not numeric and will be skipped.
# Column                    customer_id has no outliers detected.
# Column                     product_id has no outliers detected.
# Column                       quantity has no outliers detected.
# Column                          price OUTLIERS DETECTED.
# ####### OUTLIERS #######
#         date  customer_id  product_id  quantity    price  discount   revenue  \
# 0 2023-01-01         1797         129         5  9999.99      0.08  267.2140
# 3 2023-01-04         1377         185         5  8888.88      0.06  446.3120
# 5 2023-01-06         1428         194         1  7777.77      0.01   98.5743
#
#    store_id region payment_method  is_member  delivery_days  customer_age  \
# 0         8   West         Online       True              6            57
# 3         5   East         Online      False              4            34
# 5         4   East           Cash      False              2            50
#
#   gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Male            Books     3.9      Returned  Positive          19.31
# 3   Male             Food     1.3  Not Returned  Positive          13.91
# 5   Male            Books     4.3      Returned   Neutral            NaN
#
#   coupon_code  delivery_rating  unique_id
# 0    WELCOME5              NaN          1
# 3         nan              4.1          4
# 5    WELCOME5              1.6          6
# Column                       discount has no outliers detected.
# Column                        revenue has no outliers detected.
# Column                       store_id has no outliers detected.
# Column                         region is not numeric and will be skipped.
# Column                 payment_method is not numeric and will be skipped.
# Column                      is_member is not numeric and will be skipped.
# Column                  delivery_days has no outliers detected.
# Column                   customer_age has no outliers detected.
# Column                         gender is not numeric and will be skipped.
# Column               product_category is not numeric and will be skipped.
# Column                         rating has no outliers detected.
# Column                  return_status is not numeric and will be skipped.
# Column                       feedback is not numeric and will be skipped.
# Column                  shipping_cost has no outliers detected.
# Column                    coupon_code is not numeric and will be skipped.
# Column                delivery_rating has no outliers detected.
# Column                      unique_id has no outliers detected.

# %%
# finding outliers using the 3-σ rule

def detect_outliers_3sigma(column_name, dataframe):
    if dataframe[column_name].dtype not in [np.float64, np.int64]:
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        mean = dataframe[column_name].mean()
        std = dataframe[column_name].std()
        lower_bound = mean - 3 * std
        upper_bound = mean + 3 * std
        outliers = dataframe[(dataframe[column_name] < lower_bound) | (dataframe[column_name] > upper_bound)]
    
    if not outliers.empty:
        print("Column {:>30} OUTLIERS DETECTED (3σ rule).\n####### OUTLIERS #######".format(column_name))
        display(outliers)
    else:
        print("Column {:>30} has no outliers detected.".format(column_name))

# Apply to all columns
for col in df.columns:
    detect_outliers_3sigma(col, df)
# Out:
# Column                           date is not numeric and will be skipped.
# Column                    customer_id has no outliers detected.
# Column                     product_id has no outliers detected.
# Column                       quantity has no outliers detected.
# Column                          price OUTLIERS DETECTED (3σ rule).
# ####### OUTLIERS #######
#         date  customer_id  product_id  quantity    price  discount   revenue  \
# 0 2023-01-01         1797         129         5  9999.99      0.08  267.2140
# 3 2023-01-04         1377         185         5  8888.88      0.06  446.3120
# 5 2023-01-06         1428         194         1  7777.77      0.01   98.5743
#
#    store_id region payment_method  is_member  delivery_days  customer_age  \
# 0         8   West         Online       True              6            57
# 3         5   East         Online      False              4            34
# 5         4   East           Cash      False              2            50
#
#   gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Male            Books     3.9      Returned  Positive          19.31
# 3   Male             Food     1.3  Not Returned  Positive          13.91
# 5   Male            Books     4.3      Returned   Neutral            NaN
#
#   coupon_code  delivery_rating  unique_id
# 0    WELCOME5              NaN          1
# 3         nan              4.1          4
# 5    WELCOME5              1.6          6
# Column                       discount has no outliers detected.
# Column                        revenue has no outliers detected.
# Column                       store_id has no outliers detected.
# Column                         region is not numeric and will be skipped.
# Column                 payment_method is not numeric and will be skipped.
# Column                      is_member is not numeric and will be skipped.
# Column                  delivery_days has no outliers detected.
# Column                   customer_age has no outliers detected.
# Column                         gender is not numeric and will be skipped.
# Column               product_category is not numeric and will be skipped.
# Column                         rating has no outliers detected.
# Column                  return_status is not numeric and will be skipped.
# Column                       feedback is not numeric and will be skipped.
# Column                  shipping_cost has no outliers detected.
# Column                    coupon_code is not numeric and will be skipped.
# Column                delivery_rating has no outliers detected.
# Column                      unique_id has no outliers detected.

# %% [markdown]
# <div class="alert alert-warning">
#
# **9. Validating Date Formats in a DataFrame**
#
# **Write a Pandas program to validate date formats in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1193         134         2  9999.99      0.17   62.9472
# 1  2023-01-02         1002         172         8    17.87      0.25  107.2200
# 2  2023-01-03         1857         169         5    65.63      0.02  321.5870
# 3  2023-01-04         1181         179         8  8888.88      0.07  716.8440
# 4  2023-01-05         1352         165         4    44.25      0.17  146.9100
# 5  2023-01-06         1480         146         9  7777.77      0.26  427.5054
# 6  2023-01-07         1683         139         1    40.52      0.18   33.2264
# 7  2023-01-08         1970         137         8    18.76      0.04  144.0768
# 8  2023-01-09         1723         176         9    46.15      0.13  361.3545
# 9  2023-01-10         1270         102         3    35.05      0.12   92.5320
# 10 2023-01-11         1903         152         3    29.32      0.03   85.3212
# 11 2023-01-12         1449         196         5    14.17      0.12   62.3480
# 12 2023-01-13         1088         163         2    79.28      0.28  114.1632
# 13 2023-01-14         1582         164         3    82.20      0.09  224.4060
# 14 2023-01-15         1466         193         5    83.40      0.07  387.8100
# 15 2023-01-16         1116         144         8    62.43      0.23  384.5688
# 16 2023-01-17         1905         153         8    40.12      0.24  243.9296
# 17 2023-01-18         1499         161         4    96.79      0.07  360.0588
# 18 2023-01-19         1321         183         9    31.81      0.02  280.5642
# 19 2023-01-20         1336         156         2    51.45      0.25   77.1750
# 20 2023-01-21         1371         136         1    23.56      0.18   19.3192
# 21 2023-01-22         1759         118         3    51.14      0.28  110.4624
# 22 2023-01-23         1534         119         6    84.87      0.15  432.8370
# 23 2023-01-24         1438         126         7    54.48      0.10  343.2240
# 24 2023-01-25         1000         100         8    57.74      0.01  457.3008
# 25 2023-01-26         1784         162         3    22.36      0.07   62.3844
# 26 2023-01-27         1461         184         3    93.13      0.12  245.8632
# 27 2023-01-28         1318         147         3    94.95      0.26  210.7890
# 28 2023-01-29         1181         150         5    11.10      0.02   54.3900
# 29 2023-01-30         1525         113         9    11.69      0.16   88.3764
# 30 2023-01-31         1194         139         7    43.78      0.07  285.0078
# 31 2023-02-01         1901         193         9    56.29      0.03  491.4117
# 32 2023-02-02         1340         114         7    47.97      0.26  248.4846
# 33 2023-02-03         1804         187         6    22.15      0.09  120.9390
# 34 2023-02-04         1820         135         4    77.77      0.09  283.0828
# 35 2023-01-27         1461         184         3    93.13      0.12  245.8632
# 36 2023-01-14         1582         164         3    82.20      0.09  224.4060
# 37 2023-01-25         1000         100         8    57.74      0.01  457.3008
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          9   West           Cash       True              1            49
# 1          3  North           Cash       True              1            26
# 2          2   East           Cash      False              5            22
# 3          3  South    Credit Card      False              3            40
# 4          9  North    Credit Card      False              3            64
# 5          4  North         Online       True              6            51
# 6          3  South           Cash       True              1            58
# 7          6  North           Cash       True              5            32
# 8          3  South           Cash      False              4            62
# 9          8  North    Credit Card      False              2            37
# 10         9  South           Cash      False              3            38
# 11         7  North    Credit Card      False              1            32
# 12         8  North           Cash       True              3            67
# 13         9   East    Credit Card      False              6            21
# 14         4   East           Cash      False              2            56
# 15         7   East           Cash       True              4            23
# 16         3   West           Cash       True              2            40
# 17         2   West           Cash      False              4            47
# 18         2   East           Cash       True              1            22
# 19         1  North         Online       True              1            43
# 20         8   East           Cash       True              3            45
# 21         1   East         Online      False              1            42
# 22         6   East         Online       True              6            62
# 23         6  South    Credit Card       True              6            62
# 24         6  South           Cash      False              3            46
# 25         7   West         Online      False              3            38
# 26         7  South    Credit Card       True              5            44
# 27         6   East    Credit Card       True              6            60
# 28         5   West         Online       True              2            54
# 29         9   East         Online      False              4            55
# 30         9  South         Online      False              2            44
# 31         4   East    Credit Card       True              2            56
# 32         3  South         Online      False              4            41
# 33         6   East           Cash      False              5            44
# 34         2   East    Credit Card      False              6            32
# 35         7  South    Credit Card       True              5            44
# 36         9   East    Credit Card      False              6            21
# 37         6  South           Cash      False              3            46
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male      Electronics     1.3  Not Returned  Positive           5.67
# 1   Female             Food     3.6  Not Returned   Neutral          13.66
# 2    Other         Clothing     1.8      Returned   Neutral           8.90
# 3    Other             Food     2.7      Returned  Negative           5.24
# 4    Other      Electronics     1.1  Not Returned  Positive          12.84
# 5   Female      Electronics     4.5      Returned  Negative            NaN
# 6   Female             Food     3.4  Not Returned  Negative          18.65
# 7    Other            Books     4.0      Returned  Positive            NaN
# 8     Male             Food     3.2  Not Returned   Neutral          19.17
# 9     Male      Electronics     3.7  Not Returned  Negative            NaN
# 10  Female            Books     3.0      Returned  Positive           7.91
# 11   Other         Clothing     4.4  Not Returned  Positive            NaN
# 12   Other            Books     4.4      Returned  Positive          19.31
# 13  Female            Books     3.1  Not Returned  Negative            NaN
# 14  Female      Electronics     2.7      Returned  Positive          15.08
# 15    Male         Clothing     3.2      Returned   Neutral           9.39
# 16  Female            Books     1.8  Not Returned   Neutral            NaN
# 17  Female             Food     2.6  Not Returned  Positive           8.73
# 18  Female      Electronics     1.5  Not Returned   Neutral          16.35
# 19  Female      Electronics     2.4      Returned  Negative           5.43
# 20   Other         Clothing     3.3  Not Returned  Negative           8.26
# 21  Female            Books     3.1      Returned  Positive          18.46
# 22  Female      Electronics     2.0      Returned  Negative          12.13
# 23   Other      Electronics     4.3      Returned  Positive            NaN
# 24    Male      Electronics     2.3  Not Returned  Negative           9.75
# 25   Other         Clothing     4.8      Returned  Positive            NaN
# 26    Male             Food     1.7  Not Returned  Negative            NaN
# 27    Male            Books     4.6  Not Returned  Positive          11.41
# 28  Female             Food     2.3  Not Returned   Neutral           8.94
# 29    Male             Food     2.7  Not Returned  Positive           7.83
# 30    Male         Clothing     2.3  Not Returned  Negative          14.88
# 31    Male             Food     1.6  Not Returned  Positive           7.69
# 32  Female      Electronics     4.7  Not Returned   Neutral            NaN
# 33    Male            Books     4.7  Not Returned  Positive           7.79
# 34   Other      Electronics     3.1      Returned  Positive          17.87
# 35    Male             Food     1.7  Not Returned  Negative            NaN
# 36  Female            Books     3.1  Not Returned  Negative            NaN
# 37    Male      Electronics     2.3  Not Returned  Negative           9.75
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              4.3          1
# 1     WELCOME5              2.6          2
# 2          nan              3.8          3
# 3          nan              4.7          4
# 4     WELCOME5              NaN          5
# 5          nan              4.0          6
# 6     WELCOME5              2.9          7
# 7          nan              3.4          8
# 8     WELCOME5              3.7          9
# 9          nan              1.2         10
# 10    WELCOME5              NaN         11
# 11    FREESHIP              NaN         12
# 12      SAVE10              1.5         13
# 13         nan              NaN         14
# 14         nan              NaN         15
# 15         nan              4.9         16
# 16    FREESHIP              4.3         17
# 17         nan              4.7         18
# 18    WELCOME5              NaN         19
# 19         nan              4.4         20
# 20         nan              3.4         21
# 21    WELCOME5              1.4         22
# 22    WELCOME5              4.5         23
# 23         nan              2.3         24
# 24    WELCOME5              NaN         25
# 25    FREESHIP              1.4         26
# 26         nan              2.0         27
# 27         nan              4.3         28
# 28         nan              3.9         29
# 29         nan              4.4         30
# 30         nan              3.9         31
# 31         nan              1.8         32
# 32    FREESHIP              3.9         33
# 33      SAVE10              1.3         34
# 34      SAVE10              NaN         35
# 35         nan              2.0         36
# 36         nan              NaN         37
# 37    WELCOME5              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 09:**
# </div>

# %%
# 9. Validating Date Formats in a DataFrame
# Write a Pandas program to validate date formats in a DataFrame.

def validate_date_formats(date_column, dataframe):
    if not pd.api.types.is_datetime64_any_dtype(dataframe[date_column]):
        print("Column {:>30} is not a datetime type and will be skipped.".format(date_column))
        return
    else:
        invalid_dates = dataframe[~dataframe[date_column].dt.strftime('%Y-%m-%d').str.match(r'^\d{4}-\d{2}-\d{2}$')]
    if not invalid_dates.empty:
        print("Column {:>30} INVALID DATES DETECTED.\n####### INVALID DATES #######".format(date_column))
        display(invalid_dates)
    else:
        print("Column {:>30} has no invalid dates detected.".format(date_column))

# Apply to all columns
for col in df.columns:
    validate_date_formats(col, df)
# Out:
# Column                           date has no invalid dates detected.
# Column                    customer_id is not a datetime type and will be skipped.
# Column                     product_id is not a datetime type and will be skipped.
# Column                       quantity is not a datetime type and will be skipped.
# Column                          price is not a datetime type and will be skipped.
# Column                       discount is not a datetime type and will be skipped.
# Column                        revenue is not a datetime type and will be skipped.
# Column                       store_id is not a datetime type and will be skipped.
# Column                         region is not a datetime type and will be skipped.
# Column                 payment_method is not a datetime type and will be skipped.
# Column                      is_member is not a datetime type and will be skipped.
# Column                  delivery_days is not a datetime type and will be skipped.
# Column                   customer_age is not a datetime type and will be skipped.
# Column                         gender is not a datetime type and will be skipped.
# Column               product_category is not a datetime type and will be skipped.
# Column                         rating is not a datetime type and will be skipped.
# Column                  return_status is not a datetime type and will be skipped.
# Column                       feedback is not a datetime type and will be skipped.
# Column                  shipping_cost is not a datetime type and will be skipped.
# Column                    coupon_code is not a datetime type and will be skipped.
# Column                delivery_rating is not a datetime type and will be skipped.
# Column                      unique_id is not a datetime type and will be skipped.

# %% [markdown]
# <div class="alert alert-warning">
#
# **10. Ensuring No Missing Values in a Critical Column**
#
# **Write a Pandas program that ensures no missing values in a critical column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1904         153         8  9999.99      0.05  329.4600
# 1  2023-01-02         1747         159         3    51.24      0.19  124.5132
# 2  2023-01-03         1778         199         5    15.62      0.30   54.6700
# 3  2023-01-04         1822         119         1  8888.88      0.14   44.1180
# 4  2023-01-05         1662         129         8    46.18      0.28  265.9968
# 5  2023-01-06         1608         114         7  7777.77      0.06  527.7160
# 6  2023-01-07         1108         131         9    18.80      0.13  147.2040
# 7  2023-01-08         1045         142         7    51.31      0.20  287.3360
# 8  2023-01-09         1674         136         4    10.38      0.02   40.6896
# 9  2023-01-10         1824         135         8    82.97      0.22  517.7328
# 10 2023-01-11         1066         105         9    65.79      0.28  426.3192
# 11 2023-01-12         1854         196         9    94.21      0.07  788.5377
# 12 2023-01-13         1423         103         1    80.29      0.24   61.0204
# 13 2023-01-14         1762         194         9    67.21      0.26  447.6186
# 14 2023-01-15         1884         143         1    67.33      0.08   61.9436
# 15 2023-01-16         1789         124         4    77.74      0.05  295.4120
# 16 2023-01-17         1690         134         2    63.64      0.19  103.0968
# 17 2023-01-18         1985         150         1    64.17      0.08   59.0364
# 18 2023-01-19         1913         111         3    84.68      0.25  190.5300
# 19 2023-01-20         1597         131         3    65.04      0.09  177.5592
# 20 2023-01-21         1970         114         6    26.51      0.05  151.1070
# 21 2023-01-22         1000         116         7    23.26      0.28  117.2304
# 22 2023-01-23         1499         120         3    83.88      0.22  196.2792
# 23 2023-01-24         1314         144         3    30.00      0.03   87.3000
# 24 2023-01-25         1770         121         6    62.73      0.20  301.1040
# 25 2023-01-26         1948         159         3    58.95      0.16  148.5540
# 26 2023-01-27         1466         181         4    60.18      0.02  235.9056
# 27 2023-01-28         1583         118         2    21.35      0.03   41.4190
# 28 2023-01-29         1203         161         6    77.45      0.22  362.4660
# 29 2023-01-30         1025         156         4    88.01      0.22  274.5912
# 30 2023-01-31         1746         132         9    34.22      0.09  280.2618
# 31 2023-02-01         1327         159         2    67.57      0.27   98.6522
# 32 2023-02-02         1416         189         4    32.56      0.14  112.0064
# 33 2023-02-03         1062         150         8    91.62      0.16  615.6864
# 34 2023-02-04         1681         122         9    98.35      0.03  858.5955
# 35 2023-01-27         1466         181         4    60.18      0.02  235.9056
# 36 2023-01-14         1762         194         9    67.21      0.26  447.6186
# 37 2023-01-25         1770         121         6    62.73      0.20  301.1040
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6  North           Cash       True              3            66
# 1          2   East           Cash      False              3            55
# 2          4   East           Cash       True              2            66
# 3          9   West           Cash      False              3            43
# 4          9  North           Cash      False              3            52
# 5          2   West           Cash      False              1            22
# 6          3   West           Cash       True              2            19
# 7          9  North         Online       True              3            24
# 8          8   East           Cash       True              1            65
# 9          9   West    Credit Card       True              1            21
# 10         9  South         Online      False              2            24
# 11         2   West    Credit Card       True              2            69
# 12         4   West         Online      False              4            44
# 13         8  North         Online       True              6            19
# 14         3   West           Cash       True              5            26
# 15         5   West         Online       True              5            28
# 16         1  North           Cash      False              5            24
# 17         7  North           Cash      False              6            25
# 18         8   East           Cash       True              1            68
# 19         3  North         Online      False              1            54
# 20         3   West         Online      False              6            55
# 21         9  North           Cash      False              5            57
# 22         2   West         Online       True              6            18
# 23         3   West    Credit Card      False              3            24
# 24         5  North    Credit Card      False              2            68
# 25         2   East           Cash      False              5            47
# 26         9  South           Cash      False              6            32
# 27         2   East           Cash       True              5            47
# 28         7   West    Credit Card      False              3            57
# 29         5  North    Credit Card       True              1            45
# 30         9  South           Cash       True              6            53
# 31         7   West    Credit Card       True              1            51
# 32         4   East    Credit Card       True              4            60
# 33         4   East           Cash      False              2            59
# 34         3  South           Cash      False              2            59
# 35         9  South           Cash      False              6            32
# 36         8  North         Online       True              6            19
# 37         5  North    Credit Card      False              2            68
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     2.2      Returned  Negative          12.35
# 1   Female            Books     4.8      Returned  Negative           8.02
# 2     Male      Electronics     1.6  Not Returned  Positive           7.95
# 3     Male         Clothing     3.6      Returned   Neutral          13.20
# 4    Other             Food     3.3      Returned  Positive          16.14
# 5   Female         Clothing     4.9  Not Returned  Positive          14.32
# 6    Other             Food     2.7  Not Returned  Positive           6.70
# 7   Female             Food     3.0      Returned  Positive            NaN
# 8     Male         Clothing     4.4      Returned   Neutral          14.38
# 9    Other         Clothing     2.6  Not Returned  Positive            NaN
# 10   Other            Books     2.2  Not Returned  Positive            NaN
# 11   Other      Electronics     1.6      Returned   Neutral           8.98
# 12   Other      Electronics     4.5      Returned   Neutral           8.92
# 13    Male         Clothing     3.9      Returned   Neutral            NaN
# 14   Other            Books     3.8      Returned   Neutral          18.13
# 15    Male      Electronics     2.7      Returned  Positive          10.48
# 16    Male            Books     4.3      Returned  Positive          14.85
# 17   Other            Books     2.9  Not Returned   Neutral          12.77
# 18    Male         Clothing     4.2  Not Returned   Neutral            NaN
# 19   Other             Food     3.7  Not Returned   Neutral          15.84
# 20    Male            Books     1.6  Not Returned  Positive          13.93
# 21   Other      Electronics     4.5  Not Returned   Neutral          11.57
# 22   Other             Food     4.7      Returned  Positive          14.25
# 23    Male         Clothing     1.7      Returned  Positive          14.28
# 24   Other            Books     3.7      Returned  Positive          16.35
# 25   Other         Clothing     4.8  Not Returned  Positive            NaN
# 26   Other             Food     2.5      Returned   Neutral           7.41
# 27   Other         Clothing     4.7      Returned  Positive          13.23
# 28   Other             Food     2.4  Not Returned  Negative            NaN
# 29  Female         Clothing     1.1      Returned  Negative          13.06
# 30   Other         Clothing     3.0      Returned  Negative          11.26
# 31   Other      Electronics     4.3  Not Returned   Neutral          11.23
# 32    Male             Food     2.2      Returned  Negative          13.93
# 33   Other             Food     2.7      Returned   Neutral          10.63
# 34    Male         Clothing     2.9  Not Returned  Positive           6.34
# 35   Other             Food     2.5      Returned   Neutral           7.41
# 36    Male         Clothing     3.9      Returned   Neutral            NaN
# 37   Other            Books     3.7      Returned  Positive          16.35
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              NaN          1
# 1       SAVE10              4.2          2
# 2     FREESHIP              1.6          3
# 3     FREESHIP              2.1          4
# 4       SAVE10              2.8          5
# 5       SAVE10              4.1          6
# 6          nan              NaN          7
# 7     FREESHIP              1.3          8
# 8       SAVE10              2.2          9
# 9     FREESHIP              3.7         10
# 10    WELCOME5              3.7         11
# 11         nan              4.5         12
# 12         nan              2.9         13
# 13      SAVE10              NaN         14
# 14    WELCOME5              NaN         15
# 15         nan              3.0         16
# 16         nan              3.2         17
# 17         nan              NaN         18
# 18         nan              3.5         19
# 19      SAVE10              4.9         20
# 20         nan              1.5         21
# 21         nan              2.0         22
# 22         nan              3.6         23
# 23    FREESHIP              NaN         24
# 24    FREESHIP              4.1         25
# 25         nan              2.2         26
# 26         nan              2.2         27
# 27    WELCOME5              3.9         28
# 28      SAVE10              NaN         29
# 29         nan              2.9         30
# 30    FREESHIP              1.2         31
# 31      SAVE10              3.2         32
# 32         nan              NaN         33
# 33         nan              NaN         34
# 34      SAVE10              1.9         35
# 35         nan              2.2         36
# 36      SAVE10              NaN         37
# 37    FREESHIP              4.1         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 10:**
# </div>

# %%
# 10. Ensuring No Missing Values in a Critical Column
# Write a Pandas program that ensures no missing values in a critical column.

def check_missing_values(column_name, dataframe):
    missing_values = dataframe[column_name].isnull().sum()
    if missing_values > 0:
        print("Column {:>30} has {} missing values.".format(column_name, missing_values))
        display(dataframe[dataframe[column_name].isnull()])
    else:
        print("Column {:>30} has no missing values.".format(column_name))

# Apply to all columns
for col in df.columns:
    check_missing_values(col, df)
# Out:
# Column                           date has no missing values.
# Column                    customer_id has no missing values.
# Column                     product_id has no missing values.
# Column                       quantity has no missing values.
# Column                          price has no missing values.
# Column                       discount has no missing values.
# Column                        revenue has no missing values.
# Column                       store_id has no missing values.
# Column                         region has no missing values.
# Column                 payment_method has no missing values.
# Column                      is_member has no missing values.
# Column                  delivery_days has no missing values.
# Column                   customer_age has no missing values.
# Column                         gender has no missing values.
# Column               product_category has no missing values.
# Column                         rating has no missing values.
# Column                  return_status has no missing values.
# Column                       feedback has no missing values.
# Column                  shipping_cost has 11 missing values.
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 7  2023-01-08         1045         142         7  51.31      0.20  287.3360
# 9  2023-01-10         1824         135         8  82.97      0.22  517.7328
# 10 2023-01-11         1066         105         9  65.79      0.28  426.3192
# 13 2023-01-14         1762         194         9  67.21      0.26  447.6186
# 18 2023-01-19         1913         111         3  84.68      0.25  190.5300
# 25 2023-01-26         1948         159         3  58.95      0.16  148.5540
# 28 2023-01-29         1203         161         6  77.45      0.22  362.4660
# 36 2023-01-14         1762         194         9  67.21      0.26  447.6186
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 7          9  North         Online       True              3            24
# 9          9   West    Credit Card       True              1            21
# 10         9  South         Online      False              2            24
# 13         8  North         Online       True              6            19
# 18         8   East           Cash       True              1            68
# 25         2   East           Cash      False              5            47
# 28         7   West    Credit Card      False              3            57
# 36         8  North         Online       True              6            19
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 7   Female             Food     3.0      Returned  Positive            NaN
# 9    Other         Clothing     2.6  Not Returned  Positive            NaN
# 10   Other            Books     2.2  Not Returned  Positive            NaN
# 13    Male         Clothing     3.9      Returned   Neutral            NaN
# 18    Male         Clothing     4.2  Not Returned   Neutral            NaN
# 25   Other         Clothing     4.8  Not Returned  Positive            NaN
# 28   Other             Food     2.4  Not Returned  Negative            NaN
# 36    Male         Clothing     3.9      Returned   Neutral            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 7     FREESHIP              1.3          8
# 9     FREESHIP              3.7         10
# 10    WELCOME5              3.7         11
# 13      SAVE10              NaN         14
# 18         nan              3.5         19
# 25         nan              2.2         26
# 28      SAVE10              NaN         29
# 36      SAVE10              NaN         37
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                    coupon_code has 3 missing values.
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                delivery_rating has 13 missing values.
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1904         153         8  9999.99      0.05  329.4600
# 6  2023-01-07         1108         131         9    18.80      0.13  147.2040
# 13 2023-01-14         1762         194         9    67.21      0.26  447.6186
# 14 2023-01-15         1884         143         1    67.33      0.08   61.9436
# 17 2023-01-18         1985         150         1    64.17      0.08   59.0364
# 23 2023-01-24         1314         144         3    30.00      0.03   87.3000
# 28 2023-01-29         1203         161         6    77.45      0.22  362.4660
# 32 2023-02-02         1416         189         4    32.56      0.14  112.0064
# 33 2023-02-03         1062         150         8    91.62      0.16  615.6864
# 36 2023-01-14         1762         194         9    67.21      0.26  447.6186
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6  North           Cash       True              3            66
# 6          3   West           Cash       True              2            19
# 13         8  North         Online       True              6            19
# 14         3   West           Cash       True              5            26
# 17         7  North           Cash      False              6            25
# 23         3   West    Credit Card      False              3            24
# 28         7   West    Credit Card      False              3            57
# 32         4   East    Credit Card       True              4            60
# 33         4   East           Cash      False              2            59
# 36         8  North         Online       True              6            19
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     2.2      Returned  Negative          12.35
# 6    Other             Food     2.7  Not Returned  Positive           6.70
# 13    Male         Clothing     3.9      Returned   Neutral            NaN
# 14   Other            Books     3.8      Returned   Neutral          18.13
# 17   Other            Books     2.9  Not Returned   Neutral          12.77
# 23    Male         Clothing     1.7      Returned  Positive          14.28
# 28   Other             Food     2.4  Not Returned  Negative            NaN
# 32    Male             Food     2.2      Returned  Negative          13.93
# 33   Other             Food     2.7      Returned   Neutral          10.63
# 36    Male         Clothing     3.9      Returned   Neutral            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              NaN          1
# 6          nan              NaN          7
# 13      SAVE10              NaN         14
# 14    WELCOME5              NaN         15
# 17         nan              NaN         18
# 23    FREESHIP              NaN         24
# 28      SAVE10              NaN         29
# 32         nan              NaN         33
# 33         nan              NaN         34
# 36      SAVE10              NaN         37
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6   East         Online       True              1            64
# 1          8  South    Credit Card      False              2            22
# 2          1   East           Cash      False              6            48
# 3          2   East    Credit Card       True              4            63
# 4          2  South         Online       True              1            61
# 5          3   West           Cash      False              2            35
# 6          5   West    Credit Card      False              1            58
# 7          7   West         Online      False              6            22
# 8          4   West         Online      False              2            22
# 9          6  South         Online       True              3            53
# 10         3  North    Credit Card       True              1            30
# 11         1  North           Cash       True              4            48
# 12         7   West         Online       True              4            45
# 13         1   West           Cash      False              5            37
# 14         8   West         Online      False              5            65
# 15         3   West           Cash       True              5            54
# 16         4  South    Credit Card       True              5            57
# 17         9  North         Online       True              4            39
# 18         8  South           Cash       True              6            18
# 19         4   East         Online       True              6            24
# 20         3  North    Credit Card       True              3            20
# 21         1  South           Cash       True              3            27
# 22         3   West         Online       True              6            28
# 23         9  South         Online       True              3            32
# 24         9  South         Online      False              1            39
# 25         8   East    Credit Card      False              1            59
# 26         8  North           Cash       True              5            59
# 27         8  North    Credit Card       True              4            56
# 28         5   East    Credit Card      False              2            60
# 29         8   West         Online      False              2            57
# 30         2   West         Online       True              3            45
# 31         8   East           Cash       True              2            42
# 32         5  South           Cash      False              2            43
# 33         2  South    Credit Card      False              6            29
# 34         6   West         Online       True              1            50
# 35         8  North           Cash       True              5            59
# 36         1   West           Cash      False              5            37
# 37         9  South         Online      False              1            39
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other             Food     4.4  Not Returned  Positive          12.34
# 1    Other            Books     4.9      Returned   Neutral          13.02
# 2    Other         Clothing     2.5  Not Returned  Positive            NaN
# 3    Other      Electronics     2.8      Returned  Negative          16.18
# 4    Other      Electronics     4.7      Returned   Neutral          19.33
# 5     Male         Clothing     3.8  Not Returned  Positive            NaN
# 6     Male      Electronics     2.8  Not Returned  Negative           5.07
# 7     Male            Books     1.4      Returned  Positive           5.94
# 8   Female             Food     3.3  Not Returned  Positive            NaN
# 9   Female             Food     4.5      Returned   Neutral           5.70
# 10    Male         Clothing     4.6      Returned  Positive          15.21
# 11    Male      Electronics     1.6  Not Returned  Positive          14.57
# 12    Male         Clothing     4.5      Returned  Negative          12.04
# 13   Other      Electronics     4.3      Returned  Negative          16.71
# 14   Other      Electronics     2.8  Not Returned  Negative          11.19
# 15   Other      Electronics     2.4  Not Returned  Positive            NaN
# 16  Female      Electronics     2.1  Not Returned  Positive           6.63
# 17    Male      Electronics     3.5  Not Returned  Negative          18.42
# 18   Other            Books     3.1  Not Returned  Positive           6.95
# 19   Other      Electronics     1.5  Not Returned  Negative           7.62
# 20  Female             Food     4.8      Returned  Positive          14.93
# 21  Female      Electronics     3.2      Returned  Negative          18.23
# 22  Female      Electronics     1.4  Not Returned   Neutral            NaN
# 23   Other         Clothing     4.4  Not Returned  Negative          11.97
# 24  Female         Clothing     1.7  Not Returned  Negative            NaN
# 25  Female         Clothing     2.0  Not Returned  Positive           8.84
# 26   Other      Electronics     2.1      Returned  Positive          15.84
# 27  Female      Electronics     3.8  Not Returned  Negative          11.98
# 28  Female         Clothing     4.5  Not Returned  Negative          10.21
# 29    Male             Food     2.3      Returned  Positive           6.24
# 30  Female             Food     2.6  Not Returned  Negative           6.97
# 31   Other             Food     1.0      Returned  Negative          16.63
# 32  Female            Books     2.6      Returned  Positive            NaN
# 33    Male             Food     2.9  Not Returned   Neutral           7.20
# 34   Other             Food     4.0      Returned   Neutral          14.26
# 35   Other      Electronics     2.1      Returned  Positive          15.84
# 36   Other      Electronics     4.3      Returned  Negative          16.71
# 37  Female         Clothing     1.7  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0       SAVE10              4.3          1
# 1          nan              NaN          2
# 2     FREESHIP              4.6          3
# 3          nan              2.6          4
# 4          nan              3.7          5
# 5       SAVE10              4.0          6
# 6          nan              1.7          7
# 7       SAVE10              NaN          8
# 8     FREESHIP              NaN          9
# 9     FREESHIP              3.9         10
# 10         nan              NaN         11
# 11    WELCOME5              4.5         12
# 12    FREESHIP              NaN         13
# 13      SAVE10              NaN         14
# 14      SAVE10              2.5         15
# 15         nan              1.2         16
# 16    WELCOME5              3.5         17
# 17    FREESHIP              1.8         18
# 18    FREESHIP              NaN         19
# 19    FREESHIP              1.4         20
# 20    FREESHIP              NaN         21
# 21         nan              3.0         22
# 22         nan              2.1         23
# 23    FREESHIP              3.4         24
# 24         nan              2.2         25
# 25    FREESHIP              4.6         26
# 26         nan              4.9         27
# 27         nan              4.1         28
# 28    WELCOME5              1.1         29
# 29    WELCOME5              1.6         30
# 30         nan              1.7         31
# 31    FREESHIP              2.4         32
# 32         nan              4.0         33
# 33    FREESHIP              NaN         34
# 34      SAVE10              NaN         35
# 35         nan              4.9         36
# 36      SAVE10              NaN         37
# 37         nan              2.2         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 11:**
# </div>

# %%
# 11. Validating String Length in a DataFrame Column
# Write a Pandas program that validates string length in a DataFrame column.

def validate_string_length(dataframe, column_name, min_length: int=0, max_length: int=100):
    if not pd.api.types.is_string_dtype(dataframe[column_name]):
        print("Column {:>30} is not a string type and will be skipped.".format(column_name))
        return
    else:
        invalid_length = dataframe[(dataframe[column_name].str.len() < min_length) | (dataframe[column_name].str.len() > max_length)]
    if not invalid_length.empty:
        print("Column {:>30} INVALID LENGTH DETECTED.\n####### INVALID LENGTH #######".format(column_name))
        display(invalid_length)
    else:
        print("Column {:>30} has no invalid length detected.".format(column_name))

# Apply to all columns
for col in df.columns:
    validate_string_length(df, col, min_length=0, max_length=4)
# Out:
# Column                           date is not a string type and will be skipped.
# Column                    customer_id is not a string type and will be skipped.
# Column                     product_id is not a string type and will be skipped.
# Column                       quantity is not a string type and will be skipped.
# Column                          price is not a string type and will be skipped.
# Column                       discount is not a string type and will be skipped.
# Column                        revenue is not a string type and will be skipped.
# Column                       store_id is not a string type and will be skipped.
# Column                         region INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 1  2023-01-02         1673         103         1  26.95      0.09   24.5245
# 4  2023-01-05         1593         110         2  64.33      0.13  111.9342
# 9  2023-01-10         1675         120         2  37.97      0.27   55.4362
# 10 2023-01-11         1189         166         5  34.79      0.18  142.6390
# 11 2023-01-12         1411         186         4  59.32      0.02  232.5344
# 16 2023-01-17         1722         195         6  71.98      0.05  410.2860
# 17 2023-01-18         1223         147         8  75.17      0.15  511.1560
# 18 2023-01-19         1492         111         8  40.90      0.07  304.2960
# 20 2023-01-21         1621         198         2  61.55      0.29   87.4010
# 21 2023-01-22         1205         186         8  92.63      0.26  548.3696
# 23 2023-01-24         1335         190         6  63.31      0.23  292.4922
# 24 2023-01-25         1898         126         9  76.31      0.17  570.0357
# 26 2023-01-27         1331         163         2  50.17      0.04   96.3264
# 27 2023-01-28         1902         141         4  81.61      0.05  310.1180
# 32 2023-02-02         1990         106         4  32.75      0.17  108.7300
# 33 2023-02-03         1753         168         3  52.14      0.28  112.6224
# 35 2023-01-27         1331         163         2  50.17      0.04   96.3264
# 37 2023-01-25         1898         126         9  76.31      0.17  570.0357
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 1          8  South    Credit Card      False              2            22
# 4          2  South         Online       True              1            61
# 9          6  South         Online       True              3            53
# 10         3  North    Credit Card       True              1            30
# 11         1  North           Cash       True              4            48
# 16         4  South    Credit Card       True              5            57
# 17         9  North         Online       True              4            39
# 18         8  South           Cash       True              6            18
# 20         3  North    Credit Card       True              3            20
# 21         1  South           Cash       True              3            27
# 23         9  South         Online       True              3            32
# 24         9  South         Online      False              1            39
# 26         8  North           Cash       True              5            59
# 27         8  North    Credit Card       True              4            56
# 32         5  South           Cash      False              2            43
# 33         2  South    Credit Card      False              6            29
# 35         8  North           Cash       True              5            59
# 37         9  South         Online      False              1            39
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 1    Other            Books     4.9      Returned   Neutral          13.02
# 4    Other      Electronics     4.7      Returned   Neutral          19.33
# 9   Female             Food     4.5      Returned   Neutral           5.70
# 10    Male         Clothing     4.6      Returned  Positive          15.21
# 11    Male      Electronics     1.6  Not Returned  Positive          14.57
# 16  Female      Electronics     2.1  Not Returned  Positive           6.63
# 17    Male      Electronics     3.5  Not Returned  Negative          18.42
# 18   Other            Books     3.1  Not Returned  Positive           6.95
# 20  Female             Food     4.8      Returned  Positive          14.93
# 21  Female      Electronics     3.2      Returned  Negative          18.23
# 23   Other         Clothing     4.4  Not Returned  Negative          11.97
# 24  Female         Clothing     1.7  Not Returned  Negative            NaN
# 26   Other      Electronics     2.1      Returned  Positive          15.84
# 27  Female      Electronics     3.8  Not Returned  Negative          11.98
# 32  Female            Books     2.6      Returned  Positive            NaN
# 33    Male             Food     2.9  Not Returned   Neutral           7.20
# 35   Other      Electronics     2.1      Returned  Positive          15.84
# 37  Female         Clothing     1.7  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
#
#    coupon_code  delivery_rating  unique_id
# 1          nan              NaN          2
# 4          nan              3.7          5
# 9     FREESHIP              3.9         10
# 10         nan              NaN         11
# 11    WELCOME5              4.5         12
# 16    WELCOME5              3.5         17
# 17    FREESHIP              1.8         18
# 18    FREESHIP              NaN         19
# 20    FREESHIP              NaN         21
# 21         nan              3.0         22
# 23    FREESHIP              3.4         24
# 24         nan              2.2         25
# 26         nan              4.9         27
# 27         nan              4.1         28
# 32         nan              4.0         33
# 33    FREESHIP              NaN         34
# 35         nan              4.9         36
# 37         nan              2.2         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# Column                 payment_method INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         
# 19   Other      Electronics     1.5  Not Returned  Negative           7.62
# 20  Female             Food     4.8      Returned  Positive          14.93
# 22  Female      Electronics     1.4  Not Returned   Neutral            NaN
# 23   Other         Clothing     4.4  Not Returned  Negative          11.97
# 24  Female         Clothing     1.7  Not Returned  Negative            NaN
# 25  Female         Clothing     2.0  Not Returned  Positive           8.84
# 27  Female      Electronics     3.8  Not Returned  Negative          11.98
# 28  Female         Clothing     4.5  Not Returned  Negative          10.21
# 29    Male             Food     2.3      Returned  Positive           6.24
# 30  Female             Food     2.6  Not Returned  Negative           6.97
# 33    Male             Food     2.9  Not Returned   Neutral           7.20
# 34   Other             Food     4.0      Returned   Neutral          14.26
# 37  Female         Clothing     1.7  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0       SAVE10              4.3          1
# 1          nan              NaN          2
# 3          nan              2.6          4
# 4          nan              3.7          5
# 6          nan              1.7          7
# 7       SAVE10              NaN          8
# 8     FREESHIP              NaN          9
# 9     FREESHIP              3.9         10
# 10         nan              NaN         11
# 12    FREESHIP              NaN         13
# 14      SAVE10              2.5         15
# 16    WELCOME5              3.5         17
# 17    FREESHIP              1.8         18
# 19    FREESHIP              1.4         20
# 20    FREESHIP              NaN         21
# 22         nan              2.1         23
# 23    FREESHIP              3.4         24
# 24         nan              2.2         25
# 25    FREESHIP              4.6         26
# 27         nan              4.1         28
# 28    WELCOME5              1.1         29
# 29    WELCOME5              1.6         30
# 30         nan              1.7         31
# 33    FREESHIP              NaN         34
# 34      SAVE10              NaN         35
# 37         nan              2.2         38
# 38         NaN              NaN         39
# 40         NaN              NaN         41
# Column                      is_member is not a string type and will be skipped.
# Column                  delivery_days is not a string type and will be skipped.
# Column                   customer_age is not a string type and will be skipped.
# Column                         gender INVALID LENGTH DETECTED.
# ####### INVALID LENGTH #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1424         105         3  9999.99      0.10  269.9730
# 1  2023-01-02         1673         103         1    26.95      0.09   24.5245
# 2  2023-01-03         1455         133         5    46.31      0.17  192.1865
# 3  2023-01-04         1793         140         3  8888.88      0.17   71.3634
# 4  2023-01-05         1593         110         2    64.33      0.13  111.9342
# 8  2023-01-09         1663         163         2    71.83      0.19  116.3646
# 9  2023-01-10         1675         120         2    37.97      0.27   55.4362
# 13 2023-01-14         1406         188         7    24.14      0.25  126.7350
# 14 2023-01-15         1563         167         1    56.05      0.27   40.9165
# 15 2023-01-16         1663         114         6    97.36      0.24  443.9616
# 16 2023-01-17         1722         195         6    71.98      0.05  410.2860
# 18 2023-01-19         1492         111         8    40.90      0.07  304.2960
# 19 2023-01-20         1701         192         8    14.66      0.09  106.7248
# 20 2023-01-21         1621         198         2    61.55      0.29   87.4010
# 21 2023-01-22         1205         186         8    92.63      0.26  548.3696
# 22 2023-01-23         1024         113         1    49.76      0.16   41.7984
# 23 2023-01-24         1335         190         6    63.31      0.23  292.4922
# 24 2023-01-25         1898         126         9    76.31      0.17  570.0357
# 25 2023-01-26         1644         177         2    62.81      0.11  111.8018
# 26 2023-01-27         1331         163         2    50.17      0.04   96.3264
# 27 2023-01-28         1902         141         4    81.61      0.05  310.1180
# 28 2023-01-29         1031         142         6    85.98      0.21  407.5452
# 30 2023-01-31         1577         144         7    75.76      0.18  434.8624
# 31 2023-02-01         1211         131         4    87.69      0.24  266.5776
# 32 2023-02-02         1990         106         4    32.75      0.17  108.7300
# 34 2023-02-04         1090         112         8    65.00      0.07  483.6000
# 35 2023-01-27         1331         163         2    50.17      0.04   96.3264
# 36 2023-01-14         1406         188         7    24.14      0.25  126.7350
# 37 2023-01-25         1898         126         9    76.31      0.17  570.0357
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6   East         Online       True              1            64
# 1          8  South    Credit Card      False              2            22
# 2          1   East           Cash      False              6            48
# 3          2   East    Credit Card       True              4            63
# 4          2  South         Online       True              1            61
# 8          4   West         Online      False              2            22
# 9          6  South         Online       True              3            53
# 13         1   West           Cash      False              5            37
# 14         8   West         Online      False              5            65
# 15         3   West           Cash       True              5            54
# 16         4  South    Credit Card       True              5            57
# 18         8  South           Cash       True              6            18
# 19         4   East         Online       True              6            24
# 20         3  North    Credit Card       True              3            20
# 21         1  South           Cash       True              3            27
# 22         3   West         Online       True              6            28
# 23         9  South         Online       True              3            32
# 24         9  South         Online      False              1            39
# 25         8   East    Credit Card      False              1            59
# 26         8  North           Cash       True              5            59
# 27         8  North    Credit Card       True              4            56
# 28         5   East    Credit Card      False              2            60
# 30         2   West         Online       True              3            45
# 31         8   East           Cash       True              2            42
# 32         5  South           Cash      False              2            43
# 34         6   West         Online       True              1            50
# 35         8  North           Cash       True              5            59
# 36         1   West           Cash      False              5            37
# 37         9  South         Online      False              1            39
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other             Food     4.4  Not Returned  Positive          12.34
# 1    Other            Books     4.9      Returned   Neutral          13.02
# 2    Other         Clothing     2.5  Not Returned  Positive            NaN
# 3    Other      Electronics     2.8      Returned  Negative          16.18
# 4    Other      Electronics     4.7      Returned   Neutral          19.33
# 8   Female             Food     3.3  Not Returned  Positive            NaN
# 9   Female             Food     4.5      Returned   Neutral           5.70
# 13   Other      Electronics     4.3      Returned  Negative          16.71
# 14   Other      Electronics     2.8  Not Returned  Negative          11.19
# 15   Other      Electronics     2.4  Not Returned  Positive            NaN
# 16  Female      Electronics     2.1  Not Returned  Positive           6.63
# 18   Other            Books     3.1  Not Returned  Positive           6.95
# 19   Other      Electronics     1.5  Not Returned  Negative           7.62
# 20  Female             Food     4.8      Returned  Positive          14.93
# 21  Female      Electronics     3.2      Returned  Negative          18.23
# 22  Female      Electronics     1.4  Not Returned   Neutral            NaN
# 23   Other         Clothing     4.4  Not Returned  Negative          11.97
# 24  Female         Clothing     1.7  Not Returned  Negative            NaN
# 25  Female         Clothing     2.0  Not Returned  Positive           8.84
# 26   Other      Electronics     2.1      Returned  Positive          15.84
# 27  Female      Electronics     3.8  Not Returned  Negative          11.98
# 28  Female         Clothing     4.5  Not Returned  Negative          10.21
# 30  Female             Food     2.6  Not Returned  Negative           6.97
# 31   Other             Food     1.0      Returned  Negative          16.63
# 32  Female            Books     2.6      Returned  Positive            NaN
# 34   Other             Food     4.0      Returned   Neutral          14.26
# 35   Other      Electronics     2.1      Returned  Positive          15.84
# 36   Other      Electronics     4.3      Returned  Negative          16.71
# 37  Female         Clothing     1.7  Not Returned  Negative            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 1          8  South    Credit Card      False              2            22
# 2          1   East           Cash      False              6            48
# 3          2   East    Credit Card       True              4            63
# 4          2  South         Online       True              1            61
# 5          3   West           Cash      False              2            35
# 6          5   West    Credit Card      False              1            58
# 7          7   West         Online      False              6            22
# 10         3  North    Credit Card       True              1            30
# 11         1  North           Cash       True              4            48
# 12         7   West         Online       True              4            45
# 13         1   West           Cash      False              5            37
# 14         8   West         Online      False              5            65
# 15         3   West           Cash       True              5            54
# 16         4  South    Credit Card       True              5            57
# 17         9  North         Online       True              4            39
# 18         8  South           Cash       True              6            18
# 19         4   East         Online       True              6            24
# 21         1  South           Cash       True              3            27
# 22         3   West         Online       True              6            28
# 23         9  South         Online       True              3            32
# 24         9  South         Online      False              1            39
# 25         8   East    Credit Card      False              1            59
# 26         8  North           Cash       True              5            59
# 27         8  North    Credit Card       True              4            56
# 28         5   East    Credit Card      False              2            60
# 32         5  South           Cash      False              2            43
# 35         8  North           Cash       True              5            59
# 36         1   West           Cash      False              5            37
# 37         9  South         Online      False              1            39
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 1    Other            Books     4.9      Returned   Neutral          13.02
# 2    Other         Clothing     2.5  Not Returned  Positive            NaN
# 3    Other      Electronics     2.8      Returned  Negative          16.18
# 4    Other      Electronics     4.7      Returned   Neutral          19.33
# 5     Male         Clothing     3.8  Not Returned  Positive            NaN
# 6     Male      Electronics     2.8  Not Returned  Negative           5.07
# 7     Male            Books     1.4      Returned  Positive           5.94
# 10    Male         Clothing     4.6      Returned  Positive          15.21
# 11    Male      Electronics     1.6  Not Returned  Positive          14.57
# 12    Male         Clothing     4.5      Returned  Negative          12.04
# 13   Other      Electronics     4.3      Returned  Negative          16.71
# 14   Other      Electronics     2.8  Not Returned  Negative          11.19
# 15   Other      Electronics     2.4  Not Returned  Positive            NaN
# 16  Female      Electronics     2.1  Not Returned  Positive           6.63
# 17    Male      Electronics     3.5  Not Returned  Negative          18.42
# 18   Other            Books     3.1  Not Returned  Positive           6.95
# 19   Other      Electronics     1.5  Not Returned  Negative           7.62
# 21  Female      Electronics     3.2      Returned  Negative          18.23
# 22  Female      Electronics     1.4  Not Returned   Neutral            NaN
# 23   Other         Clothing     4.4  Not Returned  Negative          11.97
# 24  Female         Clothing     1.7  Not Returned  Negative            NaN
# 25  Female         Clothing     2.0  Not Returned  Positive           8.84
# 26   Other      Electronics     2.1      Returned  Positive          15.84
# 27  Female      Electronics     3.8  Not Returned  Negative          11.98
# 28  Female         Clothing     4.5  Not Returned  Negative          10.21
# 32  Female            Books     2.6      Returned  Positive            NaN
# 35   Other      Electronics     2.1      Returned  Positive          15.84
# 36   Other      Electronics     4.3      Returned  Negative          16.71
# 37  Female         Clothing     1.7  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 1          nan              NaN          2
# 2     FREESHIP              4.6          3
# 3          nan              2.6          4
# 4          nan              3.7          5
# 5       SAVE10              4.0          6
# 6          nan              1.7          7
# 7       SAVE10              NaN          8
# 10         nan              NaN         11
# 11    WELCOME5              4.5         12
# 12    FREESHIP              NaN         13
# 13      SAVE10              NaN         14
# 14      SAVE10              2.5         15
# 15         nan              1.2         16
# 16    WELCOME5              3.5         17
# 17    FREESHIP              1.8         18
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6   East         Online       True              1            64
# 1          8  South    Credit Card      False              2            22
# 2          1   East           Cash      False              6            48
# 3          2   East    Credit Card       True              4            63
# 4          2  South         Online       True              1            61
# 5          3   West           Cash      False              2            35
# 6          5   West    Credit Card      False              1            58
# 7          7   West         Online      False              6            22
# 8          4   West         Online      False              2            22
# 9          6  South         Online       True              3            53
# 10         3  North    Credit Card       True              1            30
# 11         1  North           Cash       True              4            48
# 12         7   West         Online       True              4            45
# 13         1   West           Cash      False              5            37
# 14         8   West         Online      False              5            65
# 15         3   West           Cash       True              5            54
# 16         4  South    Credit Card       True              5            57
# 17         9  North         Online       True              4            39
# 18         8  South           Cash       True              6            18
# 19         4   East         Online       True              6            24
# 20         3  North    Credit Card       True              3            20
# 21         1  South           Cash       True              3            27
# 22         3   West         Online       True              6            28
# 23         9  South         Online       True              3            32
# 24         9  South         Online      False              1            39
# 25         8   East    Credit Card      False              1            59
# 26         8  North           Cash       True              5            59
# 27         8  North    Credit Card       True              4            56
# 28         5   East    Credit Card      False              2            60
# 29         8   West         Online      False              2            57
# 30         2   West         Online       True              3            45
# 31         8   East           Cash       True              2            42
# 32         5  South           Cash      False              2            43
# 33         2  South    Credit Card      False              6            29
# 34         6   West         Online       True              1            50
# 35         8  North           Cash       True              5            59
# 36         1   West           Cash      False              5            37
# 37         9  South         Online      False              1            39
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other             Food     4.4  Not Returned  Positive          12.34
# 1    Other            Books     4.9      Returned   Neutral          13.02
# 2    Other         Clothing     2.5  Not Returned  Positive            NaN
# 3    Other      Electronics     2.8      Returned  Negative          16.18
# 4    Other      Electronics     4.7      Returned   Neutral          19.33
# 5     Male         Clothing     3.8  Not Returned  Positive            NaN
# 6     Male      Electronics     2.8  Not Returned  Negative           5.07
# 7     Male            Books     1.4      Returned  Positive           5.94
# 8   Female             Food     3.3  Not Returned  Positive            NaN
# 9   Female             Food     4.5      Returned   Neutral           5.70
# 10    Male         Clothing     4.6      Returned  Positive          15.21
# 11    Male      Electronics     1.6  Not Returned  Positive          14.57
# 12    Male         Clothing     4.5      Returned  Negative          12.04
# 13   Other      Electronics     4.3      Returned  Negative          16.71
# 14   Other      Electronics     2.8  Not Returned  Negative          11.19
# 15   Other      Electronics     2.4  Not Returned  Positive            NaN
# 16  Female      Electronics     2.1  Not Returned  Positive           6.63
# 17    Male      Electronics     3.5  Not Returned  Negative          18.42
# 18   Other            Books     3.1  Not Returned  Positive           6.95
# 19   Other      Electronics     1.5  Not Returned  Negative           7.62
# 20  Female             Food     4.8      Returned  Positive          14.93
# 21  Female      Electronics     3.2      Returned  Negative          18.23
# 22  Female      Electronics     1.4  Not Returned   Neutral            NaN
# 23   Other         Clothing     4.4  Not Returned  Negative          11.97
# 24  Female         Clothing     1.7  Not Returned  Negative            NaN
# 25  Female         Clothing     2.0  Not Returned  Positive           8.84
# 26   Other      Electronics     2.1      Returned  Positive          15.84
# 27  Female      Electronics     3.8  Not Returned  Negative          11.98
# 28  Female         Clothing     4.5  Not Returned  Negative          10.21
# 29    Male             Food     2.3      Returned  Positive           6.24
# 30  Female             Food     2.6  Not Returned  Negative           6.97
# 31   Other             Food     1.0      Returned  Negative          16.63
# 32  Female            Books     2.6      Returned  Positive            NaN
# 33    Male             Food     2.9  Not Returned   Neutral           7.20
# 34   Other             Food     4.0      Returned   Neutral          14.26
# 35   Other      Electronics     2.1      Returned  Positive          15.84
# 36   Other      Electronics     4.3      Returned  Negative          16.71
# 37  Female         Clothing     1.7  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 
# 26 2023-01-27         1331         163         2    50.17      0.04   96.3264
# 27 2023-01-28         1902         141         4    81.61      0.05  310.1180
# 28 2023-01-29         1031         142         6    85.98      0.21  407.5452
# 29 2023-01-30         1017         118         9    47.67      0.13  373.2561
# 30 2023-01-31         1577         144         7    75.76      0.18  434.8624
# 31 2023-02-01         1211         131         4    87.69      0.24  266.5776
# 32 2023-02-02         1990         106         4    32.75      0.17  108.7300
# 33 2023-02-03         1753         168         3    52.14      0.28  112.6224
# 34 2023-02-04         1090         112         8    65.00      0.07  483.6000
# 35 2023-01-27         1331         163         2    50.17      0.04   96.3264
# 36 2023-01-14         1406         188         7    24.14      0.25  126.7350
# 37 2023-01-25         1898         126         9    76.31      0.17  570.0357
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6   East         Online       True              1            64
# 1          8  South    Credit Card      False              2            22
# 2          1   East           Cash      False              6            48
# 3          2   East    Credit Card       True              4            63
# 4          2  South         Online       True              1            61
# 5          3   West           Cash      False              2            35
# 6          5   West    Credit Card      False              1            58
# 7          7   West         Online      False              6            22
# 8          4   West         Online      False              2            22
# 9          6  South         Online       True              3            53
# 10         3  North    Credit Card       True              1            30
# 11         1  North           Cash       True              4            48
# 12         7   West         Online       True              4            45
# 13         1   West           Cash      False              5            37
# 14         8   West         Online      False              5            65
# 15         3   West           Cash       True              5            54
# 16         4  South    Credit Card       True              5            57
# 17         9  North         Online       True              4            39
# 18         8  South           Cash       True              6            18
# 19         4   East         Online       True              6            24
# 20         3  North    Credit Card       True              3            20
# 21         1  South           Cash       True              3            27
# 22         3   West         Online       True              6            28
# 23         9  South         Online       True              3            32
# 24         9  South         Online      False              1            39
# 25         8   East    Credit Card      False              1            59
# 26         8  North           Cash       True              5            59
# 27         8  North    Credit Card       True              4            56
# 28         5   East    Credit Card      False              2            60
# 29         8   West         Online      False              2            57
# 30         2   West         Online       True              3            45
# 31         8   East           Cash       True              2            42
# 32         5  South           Cash      False              2            43
# 33         2  South    Credit Card      False              6            29
# 34         6   West         Online       True              1            50
# 35         8  North           Cash       True              5            59
# 36         1   West           Cash      False              5            37
# 37         9  South         Online      False              1            39
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other             Food     4.4  Not Returned  Positive          12.34
# 1    Other            Books     4.9      Returned   Neutral          13.02
# 2    Other         Clothing     2.5  Not Returned  Positive            NaN
# 3    Other      Electronics     2.8      Returned  Negative          16.18
# 4    Other      Electronics     4.7      Returned   Neutral          19.33
# 5     Male         Clothing     3.8  Not Returned  Positive            NaN
# 6     Male      Electronics     2.8  Not Returned  Negative           5.07
# 7     Male            Books     1.4      Returned  Positive           5.94
# 8   Female             Food     3.3  Not Returned  Positive            NaN
# 9   Female             Food     4.5      Returned   Neutral           5.70
# 10    Male         Clothing     4.6      Returned  Positive          15.21
# 11    Male      Electronics     1.6  Not Returned  Positive          14.57
# 12    Male         Clothing     4.5      Returned  Negative          12.04
# 13   Other      Electronics     4.3      Returned  Negative          16.71
# 14   Other      Electronics     2.8  Not Returned  Negative          11.19
# 15   Other      Electronics     2.4  Not Returned  Positive            NaN
# 16  Female      Electronics     2.1  Not Returned  Positive           6.63
# 17    Male      Electronics     3.5  Not Returned  Negative          18.42
# 18   Other            Books     3.1  Not Returned  Positive           6.95
# 19   Other      Electronics     1.5  Not Returned  Negative           7.62
# 20  Female             Food     4.8      Returned  Positive          14.93
# 21  Female      Electronics     3.2      Returned  Negative          18.23
# 22  Female      Electronics     1.4  Not Returned   Neutral            NaN
# 23   Other         Clothing     4.4  Not Returned  Negative          11.97
# 24  Female         Clothing     1.7  Not Returned  Negative            NaN
# 25  Female         Clothing     2.0  Not Returned  Positive           8.84
# 26   Other      Electronics     2.1      Returned  Positive          15.84
# 27  Female      Electronics     3.8  Not Returned  Negative          11.98
# 28  Female         Clothing     4.5  Not Returned  Negative          10.21
# 29    Male             Food     2.3      Returned  Positive           6.24
# 30  Female             Food     2.6  Not Returned  Negative           6.97
# 31   Other             Food     1.0      Returned  Negative          16.63
# 32  Female            Books     2.6      Returned  Positive            NaN
# 33    Male             Food     2.9  Not Returned   Neutral           7.20
# 34   Other             Food     4.0      Returned   Neutral          14.26
# 35   Other      Electronics     2.1      Returned  Positive          15.84
# 36   Other      Electronics     4.3      Returned  Negative          16.71
# 37  Female         Clothing     1.7  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0       SAVE10              4.3          1
# 1          nan              NaN          2
# 2     FREESHIP              4.6          3
# 3          nan              2.6          4
# 4          nan              3.7          5
# 5       SAVE10              4.0          6
# 6          nan              1.7          7
# 7       SAVE10              NaN          8
# 8     FREESHIP              NaN          9
# 9     FREESHIP              3.9         10
# 10         nan              NaN         11
# 11    WELCOME5              4.5         12
# 12    FREESHIP              NaN         13
# 13      SAVE10              NaN         14
# 14      SAVE10              2.5         15
# 15         nan              1.2         16
# 16    WELCOME5              3.5         17
# 17    FREESHIP              1.8         18
# 18    FREESHIP              NaN         19
# 19    FREESHIP              1.4         20
# 20    FREESHIP              NaN         21
# 21         nan              3.0         22
# 22         nan              2.1         23
# 23    FREESHIP              3.4         24
# 24         nan              2.2         25
# 25    FREESHIP              4.6         26
# 26         nan              4.9         27
# 27         nan              4.1         28
# 28    WELCOME5              1.1         29
# 29    WELCOME5              1.6         30
# 30         nan              1.7         31
# 31    FREESHIP              2.4         32
# 32         nan              4.0         33
# 33    FREESHIP              NaN         34
# 34      SAVE10              NaN         35
# 35         nan              4.9         36
# 36      SAVE10              NaN         37
# 37         nan              2.2         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                  shipping_cost is not a string type and will be skipped.
# Column                    coupon_code is not a string type and will be skipped.
# Column                delivery_rating is not a string type and will be skipped.
# Column                      unique_id is not a string type and will be skipped.

# %% [markdown]
# <div class="alert alert-warning">
#
# **12. Verifying Numeric Range in a DataFrame Column**
#
# **Write a Pandas program to verify numeric range in a DataFrame column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         
# 25         5  North         Online      False              2            63
# 26         7   West    Credit Card      False              6            29
# 27         2   East    Credit Card      False              5            23
# 28         9   West           Cash       True              4            41
# 29         7   West           Cash      False              5            38
# 30         7   East    Credit Card      False              1            47
# 31         5  North           Cash       True              4            40
# 32         1   East           Cash      False              6            55
# 33         7   East         Online       True              6            46
# 34         4  South           Cash      False              4            49
# 35         7   West    Credit Card      False              6            29
# 36         9   West         Online      False              6            41
# 37         7   West           Cash      False              6            44
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other            Books     1.7  Not Returned  Negative            NaN
# 1   Female      Electronics     4.0  Not Returned  Negative            NaN
# 2   Female            Books     3.5      Returned   Neutral          13.17
# 3     Male            Books     1.2  Not Returned  Negative          14.10
# 4    Other             Food     4.1      Returned  Positive          13.83
# 5    Other      Electronics     2.5  Not Returned  Negative          18.77
# 6     Male      Electronics     4.4  Not Returned  Negative           5.50
# 7     Male         Clothing     2.8      Returned  Positive           8.64
# 8     Male      Electronics     3.0  Not Returned  Positive          17.67
# 9     Male            Books     1.2      Returned  Positive            NaN
# 10    Male         Clothing     1.9      Returned  Negative          16.18
# 11   Other            Books     4.6  Not Returned  Positive           8.78
# 12  Female      Electronics     1.1  Not Returned  Positive          14.69
# 13   Other             Food     1.5      Returned  Positive          15.08
# 14    Male             Food     2.6  Not Returned  Positive          12.90
# 15  Female            Books     1.2  Not Returned  Negative           9.79
# 16  Female         Clothing     3.1      Returned   Neutral            NaN
# 17    Male            Books     1.2      Returned  Negative          12.66
# 18  Female             Food     3.2  Not Returned  Positive          10.91
# 19   Other            Books     4.3      Returned  Negative            NaN
# 20    Male            Books     3.6      Returned  Positive            NaN
# 21    Male            Books     3.8  Not Returned   Neutral          18.26
# 22  Female      Electronics     1.5      Returned  Negative          15.89
# 23   Other            Books     5.0      Returned  Positive            NaN
# 24   Other             Food     2.7      Returned  Positive            NaN
# 25    Male             Food     2.0  Not Returned   Neutral           5.48
# 26   Other             Food     2.8      Returned  Negative           8.95
# 27   Other         Clothing     2.5      Returned  Positive           5.80
# 28    Male      Electronics     2.4  Not Returned  Positive          18.54
# 29    Male      Electronics     3.6  Not Returned  Positive          17.67
# 30  Female      Electronics     3.2      Returned  Negative          18.38
# 31  Female         Clothing     4.6  Not Returned  Negative           9.30
# 32    Male            Books     4.3  Not Returned  Positive           6.01
# 33   Other             Food     3.1      Returned  Negative            NaN
# 34    Male         Clothing     1.3      Returned   Neutral            NaN
# 35   Other             Food     2.8      Returned  Negative           8.95
# 36   Other             Food     1.5      Returned  Positive          15.08
# 37   Other             Food     2.7      Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0       SAVE10              1.7          1
# 1     FREESHIP              3.0          2
# 2          nan              3.7          3
# 3          nan              3.5          4
# 4       SAVE10              NaN          5
# 5     WELCOME5              4.8          6
# 6     WELCOME5              NaN          7
# 7     WELCOME5              4.1          8
# 8          nan              NaN          9
# 9          nan              3.4         10
# 10    FREESHIP              4.4         11
# 11    WELCOME5              4.3         12
# 12         nan              5.0         13
# 13    FREESHIP              3.3         14
# 14    WELCOME5              2.9         15
# 15    WELCOME5              3.7         16
# 16         nan              3.1         17
# 17    WELCOME5              2.6         18
# 18      SAVE10              4.4         19
# 19      SAVE10              NaN         20
# 20    WELCOME5              NaN         21
# 21      SAVE10              2.9         22
# 22         nan              NaN         23
# 23      SAVE10              4.1         24
# 24         nan              3.4         25
# 25         nan              NaN         26
# 26      SAVE10              4.1         27
# 27    WELCOME5              NaN         28
# 28         nan              3.2         29
# 29    FREESHIP              4.8         30
# 30         nan              3.6         31
# 31         nan              NaN         32
# 32         nan              1.4         33
# 33         nan              NaN         34
# 34    FREESHIP              NaN         35
# 35      SAVE10              4.1         36
# 36    FREESHIP              3.3         37
# 37         nan              3.4         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 12:**
# </div>

# %%
# 12. Verifying Numeric Range in a DataFrame Column
# Write a Pandas program to verify numeric range in a DataFrame column.

def verify_numeric_range(dataframe, column_name, min_value, max_value):
    if not pd.api.types.is_numeric_dtype(dataframe[column_name]):
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        out_of_range = dataframe[(dataframe[column_name] < min_value) | (dataframe[column_name] > max_value)]
    if not out_of_range.empty:
        print("Column {:>30} OUT OF RANGE DETECTED.\n####### OUT OF RANGE #######".format(column_name))
        display(out_of_range)
    else:
        print("Column {:>30} has no out of range values detected.".format(column_name))

# Apply to price column only
verify_numeric_range(df, 'price', min_value=0, max_value=100)
# Out:
# Column                          price OUT OF RANGE DETECTED.
# ####### OUT OF RANGE #######
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1553         147         1  9999.99      0.19   25.2882
# 3  2023-01-04         1784         119         7  8888.88      0.05  184.4045
# 5  2023-01-06         1793         122         9  7777.77      0.06  514.7910
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          2  North           Cash      False              3            37
# 3          2  South           Cash      False              4            47
# 5          4  North           Cash       True              2            64
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other            Books     1.7  Not Returned  Negative            NaN
# 3     Male            Books     1.2  Not Returned  Negative          14.10
# 5    Other      Electronics     2.5  Not Returned  Negative          18.77
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0       SAVE10              1.7          1
# 3          nan              3.5          4
# 5     WELCOME5              4.8          6
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-warning">
#
# **13. Validating the Format of Email Addresses**
#
# **Write a Pandas program that validates the format of email addresses.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# add emails
df['email'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, 'customer' + df['customer_id'].astype(str) + '@example.com')
df.loc[0, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[10, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[20, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df['email'] = df['email'].fillna('onemore-invalid_email')


# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male      Electronics     2.1  Not Returned  Positive           7.49
# 1   Female            Books     3.0      Returned   Neutral          19.74
# 2     Male      Electronics     4.5  Not Returned   Neutral          15.31
# 3   Female             Food     4.5      Returned  Positive            NaN
# 4   Female            Books     2.4      Returned  Positive          18.20
# 5     Male            Books     2.3      Returned  Negative          11.85
# 6    Other      Electronics     2.4      Returned  Positive            NaN
# 7    Other             Food     2.7      Returned  Positive            NaN
# 8    Other            Books     2.1      Returned   Neutral          14.14
# 9   Female         Clothing     4.0      Returned   Neutral          14.19
# 10   Other            Books     2.1      Returned   Neutral           7.45
# 11   Other             Food     3.6  Not Returned  Positive           5.54
# 12    Male             Food     4.4  Not Returned   Neutral            NaN
# 13    Male         Clothing     3.8      Returned  Positive          19.40
# 14    Male      Electronics     3.6      Returned   Neutral          10.00
# 15  Female             Food     4.6      Returned   Neutral          16.06
# 16    Male            Books     2.9      Returned   Neutral          13.85
# 17    Male             Food     1.4  Not Returned  Negative          16.78
# 18    Male         Clothing     1.9      Returned  Positive           7.40
# 19  Female            Books     1.2      Returned   Neutral          12.18
# 20   Other             Food     4.0      Returned  Negative          14.98
# 21  Female         Clothing     4.9      Returned  Negative            NaN
# 22    Male         Clothing     2.8      Returned  Negative           7.37
# 23  Female            Books     1.0  Not Returned  Negative            NaN
# 24   Other         Clothing     4.0      Returned   Neutral            NaN
# 25  Female         Clothing     2.5      Returned   Neutral           8.45
# 26   Other      Electronics     4.3  Not Returned   Neutral            NaN
# 27   Other         Clothing     2.2      Returned  Positive          13.15
# 28    Male             Food     1.2      Returned   Neutral          13.80
# 29    Male            Books     4.2  Not Returned  Negative            NaN
# 30  Female             Food     4.9      Returned  Negative           8.20
# 31   Other            Books     2.5      Returned  Positive          13.84
# 32   Other         Clothing     3.2  Not Returned  Negative          12.35
# 33  Female      Electronics     4.5  Not Returned   Neutral          12.49
# 34    Male      Electronics     2.0      Returned   Neutral          10.11
# 35   Other      Electronics     4.3  Not Returned   Neutral            NaN
# 36    Male         Clothing     3.8      Returned  Positive          19.40
# 37   Other         Clothing     4.0      Returned   Neutral            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id                     email
# 0     FREESHIP              NaN          1      invalid-email-format
# 1       SAVE10              NaN          2  customer1024@example.com
# 2       SAVE10              3.2          3  customer1660@example.com
# 3     FREESHIP              4.8          4  customer1013@example.com
# 4     WELCOME5              2.2          5  customer1308@example.com
# 5       SAVE10              5.0          6  customer1621@example.com
# 6       SAVE10              NaN          7  customer1136@example.com
# 7          nan              2.0          8  customer1791@example.com
# 8       SAVE10              3.2          9  customer1418@example.com
# 9     FREESHIP              2.8         10  customer1950@example.com
# 10    WELCOME5              4.1         11      invalid-email-format
# 11         nan              4.5         12  customer1827@example.com
# 12         nan              2.7         13  customer1323@example.com
# 13    WELCOME5              3.7         14  customer1793@example.com
# 14    FREESHIP              2.4         15     onemore-invalid_email
# 15      SAVE10              2.1         16  customer1452@example.com
# 16    WELCOME5              3.7         17  customer1275@example.com
# 17    FREESHIP              1.8         18  customer1081@example.com
# 18         nan              1.6         19     onemore-invalid_email
# 19         nan              1.6         20  customer1560@example.com
# 20      SAVE10              NaN         21      invalid-email-format
# 21      SAVE10              2.6         22  customer1701@example.com
# 22      SAVE10              3.8         23  customer1646@example.com
# 23    FREESHIP              1.1         24  customer1067@example.com
# 24      SAVE10              NaN         25  customer1966@example.com
# 25    WELCOME5              5.0         26  customer1250@example.com
# 26    WELCOME5              NaN         27  customer1626@example.com
# 27         nan              2.7         28     onemore-invalid_email
# 28      SAVE10              5.0         29  customer1151@example.com
# 29    FREESHIP              4.7         30  customer1291@example.com
# 30    FREESHIP              1.9         31  customer1608@example.com
# 31    FREESHIP              3.3         32  customer1392@example.com
# 32      SAVE10              2.0         33     onemore-invalid_email
# 33         nan              4.9         34     onemore-invalid_email
# 34    FREESHIP              4.8         35  customer1037@example.com
# 35    WELCOME5              NaN         36  customer1626@example.com
# 36    WELCOME5              3.7         37     onemore-invalid_email
# 37      SAVE10              NaN         38  customer1966@example.com
# 38         NaN              NaN         39  customer1500@example.com
# 39         NaN              NaN         40  customer1501@example.com
# 40         NaN              NaN         41  customer1502@example.com

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 13:**
# </div>

# %%
# 13. Validating the Format of Email Addresses
# Write a Pandas program that validates the format of email addresses.

# Validate email format using a regular expression
valid_emails = df['email'].str.contains(r'^[\w\.-]+@[\w\.-]+\.\w+$')

# Output the result
df[~valid_emails].loc[:, ['email']]
# Out:
#                     email
# 0    invalid-email-format
# 10   invalid-email-format
# 14  onemore-invalid_email
# 18  onemore-invalid_email
# 20   invalid-email-format
# 27  onemore-invalid_email
# 32  onemore-invalid_email
# 33  onemore-invalid_email
# 36  onemore-invalid_email

# %% [markdown]
# <div class="alert alert-warning">
#
# **14. Checking Consistent Date Order in a Column**
#
# **Write a Pandas program to check consistent date order in a column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# add emails
df['email'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, 'customer' + df['customer_id'].astype(str) + '@example.com')
df.loc[0, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[10, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[20, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df['email'] = df['email'].fillna('onemore-invalid_email')


# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1970         116         3  9999.99      0.17  149.0514
# 1  2023-01-02         1760         123         7    55.26      0.10  348.1380
# 2  2023-01-03         1397         165         4    89.00      0.03  345.3200
# 3  2023-01-04         1151         138         5  8888.88      0.18  120.2530
# 4  2023-01-05         1905         155         2    18.94      0.04   36.3648
# 5  2023-01-06         1480         163         3  7777.77      0.23  141.7185
# 6  2023-01-07         1455         143         5    21.25      0.29   75.4375
# 7  2023-01-08         1333         139         5    50.26      0.08  231.1960
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0     Male             Food     1.7  Not Returned  Positive          19.39
# 1     Male         Clothing     2.0      Returned   Neutral          18.30
# 2     Male             Food     4.6      Returned  Positive          12.90
# 3     Male             Food     3.4      Returned  Positive           7.76
# 4    Other             Food     4.8  Not Returned  Negative          16.89
# 5     Male         Clothing     2.7  Not Returned  Positive            NaN
# 6    Other             Food     1.0      Returned  Positive          12.07
# 7   Female            Books     3.3      Returned   Neutral            NaN
# 8   Female         Clothing     3.3      Returned  Positive           6.01
# 9    Other      Electronics     4.0  Not Returned   Neutral          18.30
# 10   Other      Electronics     3.6  Not Returned  Negative          16.85
# 11    Male             Food     1.9  Not Returned   Neutral          19.56
# 12   Other      Electronics     4.0      Returned  Negative           7.49
# 13    Male      Electronics     1.5      Returned  Negative            NaN
# 14  Female         Clothing     3.5      Returned   Neutral          17.55
# 15   Other             Food     4.2  Not Returned   Neutral          17.48
# 16   Other         Clothing     1.2  Not Returned  Positive          19.26
# 17  Female            Books     4.8      Returned   Neutral          18.97
# 18    Male            Books     4.2  Not Returned   Neutral          15.33
# 19   Other         Clothing     3.4      Returned  Negative          10.66
# 20   Other         Clothing     3.9      Returned  Positive            NaN
# 21    Male             Food     3.3      Returned   Neutral           7.01
# 22    Male         Clothing     4.5  Not Returned  Positive          18.75
# 23  Female            Books     2.0      Returned  Positive          10.42
# 24   Other            Books     1.7  Not Returned  Negative          17.51
# 25    Male         Clothing     4.3  Not Returned  Negative          19.18
# 26  Female            Books     3.2      Returned  Negative            NaN
# 27  Female      Electronics     3.8      Returned  Positive           5.83
# 28   Other             Food     3.4  Not Returned   Neutral          12.37
# 29  Female            Books     3.6      Returned  Positive          14.11
# 30   Other            Books     1.5  Not Returned  Positive           6.70
# 31    Male            Books     4.1      Returned  Negative          15.24
# 32   Other      Electronics     2.5      Returned   Neutral            NaN
# 33   Other            Books     4.8      Returned  Negative          15.29
# 34    Male            Books     4.9  Not Returned   Neutral            NaN
# 35  Female            Books     3.2      Returned  Negative            NaN
# 36    Male      Electronics     1.5      Returned  Negative            NaN
# 37   Other            Books     1.7  Not Returned  Negative          17.51
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id                     email
# 0     FREESHIP              4.7          1      invalid-email-format
# 1     FREESHIP              3.7          2  customer1760@example.com
# 2       SAVE10              2.9          3  customer1397@example.com
# 3       SAVE10              1.7          4  customer1151@example.com
# 4     FREESHIP              4.5          5  customer1905@example.com
# 5     WELCOME5              3.5          6     onemore-invalid_email
# 6     FREESHIP              4.4          7     onemore-invalid_email
# 7          nan              2.9          8     onemore-invalid_email
# 8          nan              3.1          9  customer1477@example.com
# 9     WELCOME5              NaN         10  customer1480@example.com
# 10    FREESHIP              2.9         11      invalid-email-format
# 11         nan              3.7         12  customer1771@example.com
# 12         nan              1.3         13  customer1463@example.com
# 13    FREESHIP              3.8         14  customer1929@example.com
# 14    FREESHIP              1.8         15     onemore-invalid_email
# 15    FREESHIP              4.4         16     onemore-invalid_email
# 16      SAVE10              2.0         17  customer1296@example.com
# 17         nan              4.3         18  customer1421@example.com
# 18      SAVE10              4.0         19  customer1959@example.com
# 19      SAVE10              2.7         20  customer1070@example.com
# 20    FREESHIP              3.3         21      invalid-email-format
# 21      SAVE10              NaN         22  customer1422@example.com
# 22    FREESHIP              2.7         23  customer1619@example.com
# 23    WELCOME5              2.4         24  customer1235@example.com
# 24         nan              1.2         25  customer1823@example.com
# 25    WELCOME5              1.5         26  customer1839@example.com
# 26         nan              NaN         27  customer1965@example.com
# 27      SAVE10              3.6         28  customer1195@example.com
# 28      SAVE10              NaN         29  customer1321@example.com
# 29    WELCOME5              4.3         30  customer1964@example.com
# 30    WELCOME5              2.0         31  customer1749@example.com
# 31         nan              3.8         32     onemore-invalid_email
# 32    WELCOME5              3.6         33  customer1972@example.com
# 33    WELCOME5              NaN         34  customer1780@example.com
# 34      SAVE10              4.5         35  customer1061@example.com
# 35         nan              NaN         36  customer1965@example.com
# 36    FREESHIP              3.8         37  customer1929@example.com
# 37         nan              1.2         38  customer1823@example.com
# 38         NaN              NaN         39  customer1500@example.com
# 39         NaN              NaN         40     onemore-invalid_email
# 40         NaN              NaN         41  customer1502@example.com

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 14:**
# </div>

# %%
# 14. Checking Consistent Date Order in a Column
# Write a Pandas program to check consistent date order in a column.

# Check if dates are in consistent order
is_consistent = df['date'].is_monotonic_increasing

# Output the result
is_consistent

print(f"Dates in chronological order: {is_consistent}")
# Out:
# Dates in chronological order: False

# %% [markdown]
# <div class="alert alert-warning">
#
# **15. Ensuring No Negative Values in a DataFrame Column**
#
# **Write a Pandas program that ensures no negative values in a DataFrame column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# add emails
df['email'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, 'customer' + df['customer_id'].astype(str) + '@example.com')
df.loc[0, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[10, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df.loc[20, 'email'] = 'invalid-email-format'  # Introduce an invalid email for testing
df['email'] = df['email'].fillna('onemore-invalid_email')

# add some prices negative
df.loc[30, 'price'] = -10.00
df.loc[31, 'price'] = -5.00
df.loc[32, 'price'] = -15.00

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1123         180         3  9999.99      0.16  215.2836
# 1  2023-01-02         1179         147         7    60.39      0.06  397.3662
# 2  2023-01-03         1878         134         9    65.28      0.21  464.1408
# 3  2023-01-04         1541         143         7  8888.88      0.19  564.3918
# 4  2023-01-05         1640         146         8    52.38      0.26  310.0896
# 5  2023-01-06         1278         121         8  7777.77      0.01  706.5432
# 6  2023-01-07         1532         194         6    48.20      0.20  231.3600
# 7  2023-01-08         1196         197         8    19.41      0.04  149.0688
# 8  2023-01-09         1118         140         3    52.97      0.28  114.4152
# 9  2023-01-10         1064         114         5    13.71      0.18   56.2110
# 10 2023-01-11         1524         197         5    45.97      0.03  222.9545
# 11 2023-01-12         1549         136         9    87.10      0.17  650.6370
# 12 2023-01-13         1393         140         1    98.24      0.05   93.3280
# 13 2023-01-14         1188         172         7    45.77      0.24  243.4964
# 14 2023-01-15         1842         166         5    23.41      0.29   83.1055
# 15 2023-01-16         1509         188         1    92.05      0.17   76.4015
# 16 2023-01-17         1898         199         1    21.36      0.24   16.2336
# 17 2023-01-18         1422         196         2    27.40      0.10   49.3200
# 18 2023-01-19         1319         196         9    77.55      0.10  628.1550
# 19 2023-01-20         1020         122         4    79.22      0.12  278.8544
# 20 2023-01-21         1140         105         7    70.81      0.08  456.0164
# 21 2023-01-22         1552         108         5    49.87      0.01  246.8565
# 22 2023-01-23         1446         101         2    54.75      0.04  105.1200
# 23 2023-01-24         1994         146         7    74.99      0.10  472.4370
# 24 2023-01-25         1239         158         6    89.49      0.19  434.9214
# 25 2023-01-26         1516         100         7    15.79      0.30   77.3710
# 26 2023-01-27         1712         172         4    78.46      0.17  260.4872
# 27 2023-01-28         1528         108         6    72.37      0.26  321.3228
# 28 2023-01-29         1330         118         7    62.56      0.04  420.4032
# 29 2023-01-30         1430         120         1    27.28      0.04   26.1888
# 30 2023-01-31         1807         101         8   -10.00      0.00  210.4000
# 31 2023-02-01         1106         191         4    -5.00      0.28   79.0560
# 32 2023-02-02         1565         172         9   -15.00      0.18  128.4120
# 33 2023-02-03         1142         179         7    43.78      0.19  248.2326
# 34 2023-02-04         1754         103         1    13.50      0.06   12.6900
# 35 2023-01-27         1712         172         4    78.46      0.17  260.4872
# 36 2023-01-14         1188         172         7    45.77      0.24  243.4964
# 37 2023-01-25         1239         158         6    89.49      0.19  434.9214
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East           Cash       True              4            64
# 1          6   East    Credit Card       True              3            69
# 2          2  North         Online      False              6            64
# 3          7  North    Credit Card       True              6            55
# 4          6   West         Online       True              1            24
# 5          4  North         Online      False              1            31
# 6          5   East    Credit Card      False              1            18
# 7          1   East           Cash      False              3            31
# 8          6   East         Online      False              6            40
# 9          5   West           Cash      False              5            48
# 10         1  North           Cash      False              3            48
# 11         4  South           Cash       True              4            56
# 12         2  South           Cash      False              2            39
# 13         7   East         Online      False              1            21
# 14         2   West         Online       True              2            36
# 15         5   East    Credit Card      False              5            67
# 16         2  North           Cash      False              3            26
# 17         8  North         Online       True              6            26
# 18         9   East           Cash       True              3            52
# 19         5   East           Cash      False              3            20
# 20         5  North         Online       True              2            69
# 21         3   East    Credit Card       True              3            20
# 22         5   West         Online       True              2            48
# 23         7  South         Online       True              5            39
# 24         1  North           Cash      False              2            50
# 25         1   West    Credit Card       True              6            22
# 26         5  South         Online       True              1            64
# 27         3  South    Credit Card      False              2            52
# 28         6   West           Cash      False              1            43
# 29         2  North           Cash      False              2            59
# 30         3  South    Credit Card       True              2            51
# 31         5  South    Credit Card       True              2            19
# 32         6  North         Online      False              1            20
# 33         3   West           Cash      False              4            46
# 34         3   West           Cash       True              1            19
# 35         5  South         Online       True              1            64
# 36         7   East         Online      False              1            21
# 37         1  North           Cash      False              2            50
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other      Electronics     4.1      Returned  Negative            NaN
# 1    Other             Food     2.6  Not Returned  Positive           9.40
# 2     Male            Books     4.9  Not Returned   Neutral            NaN
# 3    Other         Clothing     2.9      Returned  Positive            NaN
# 4     Male      Electronics     1.6  Not Returned  Negative          18.39
# 5    Other            Books     3.0      Returned   Neutral          14.81
# 6     Male             Food     2.3      Returned   Neutral          10.37
# 7    Other             Food     3.6  Not Returned  Negative          18.62
# 8    Other         Clothing     2.4  Not Returned  Positive            NaN
# 9   Female      Electronics     4.6  Not Returned  Negative            NaN
# 10   Other             Food     1.2      Returned  Positive           9.54
# 11    Male      Electronics     1.3      Returned   Neutral           7.58
# 12   Other             Food     4.7      Returned   Neutral          10.62
# 13  Female            Books     1.9      Returned  Negative            NaN
# 14   Other            Books     2.5      Returned  Negative           9.71
# 15    Male      Electronics     3.4  Not Returned  Negative          15.76
# 16  Female             Food     4.6      Returned  Negative           7.35
# 17   Other             Food     3.6      Returned   Neutral          12.05
# 18  Female      Electronics     4.7      Returned   Neutral           5.50
# 19   Other         Clothing     1.7  Not Returned   Neutral           7.87
# 20   Other             Food     3.2      Returned   Neutral          15.65
# 21   Other         Clothing     1.5      Returned  Positive            NaN
# 22    Male             Food     2.4      Returned   Neutral          16.71
# 23   Other         Clothing     5.0  Not Returned  Negative          10.01
# 24   Other         Clothing     1.1  Not Returned  Negative          14.66
# 25   Other            Books     3.7  Not Returned  Positive           6.44
# 26   Other             Food     3.0      Returned   Neutral           6.95
# 27  Female             Food     1.1      Returned  Positive            NaN
# 28    Male         Clothing     2.9      Returned  Negative          15.79
# 29  Female             Food     2.7      Returned  Negative          18.34
# 30    Male         Clothing     3.0      Returned   Neutral            NaN
# 31  Female      Electronics     3.8      Returned  Positive           6.35
# 32    Male             Food     2.2  Not Returned  Positive           7.93
# 33  Female         Clothing     3.5      Returned   Neutral          15.12
# 34   Other         Clothing     3.2  Not Returned  Negative           9.14
# 35   Other             Food     3.0      Returned   Neutral           6.95
# 36  Female            Books     1.9      Returned  Negative            NaN
# 37   Other         Clothing     1.1  Not Returned  Negative          14.66
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id                     email
# 0       SAVE10              3.5          1      invalid-email-format
# 1          nan              4.5          2  customer1179@example.com
# 2       SAVE10              4.6          3  customer1878@example.com
# 3     FREESHIP              4.5          4     onemore-invalid_email
# 4          nan              1.5          5  customer1640@example.com
# 5     WELCOME5              1.2          6  customer1278@example.com
# 6       SAVE10              4.2          7     onemore-invalid_email
# 7          nan              NaN          8  customer1196@example.com
# 8     FREESHIP              1.7          9  customer1118@example.com
# 9       SAVE10              1.7         10     onemore-invalid_email
# 10         nan              NaN         11      invalid-email-format
# 11    FREESHIP              NaN         12  customer1549@example.com
# 12    FREESHIP              NaN         13  customer1393@example.com
# 13      SAVE10              2.9         14  customer1188@example.com
# 14    FREESHIP              4.1         15  customer1842@example.com
# 15         nan              2.1         16  customer1509@example.com
# 16      SAVE10              NaN         17     onemore-invalid_email
# 17    FREESHIP              1.4         18  customer1422@example.com
# 18         nan              2.7         19  customer1319@example.com
# 19      SAVE10              1.9         20  customer1020@example.com
# 20      SAVE10              1.2         21      invalid-email-format
# 21         nan              4.1         22  customer1552@example.com
# 22    WELCOME5              2.5         23  customer1446@example.com
# 23    WELCOME5              1.3         24  customer1994@example.com
# 24         nan              NaN         25     onemore-invalid_email
# 25         nan              2.3         26  customer1516@example.com
# 26         nan              NaN         27  customer1712@example.com
# 27    FREESHIP              2.0         28  customer1528@example.com
# 28    WELCOME5              4.9         29  customer1330@example.com
# 29    WELCOME5              2.2         30  customer1430@example.com
# 30      SAVE10              2.3         31  customer1807@example.com
# 31      SAVE10              4.7         32  customer1106@example.com
# 32    WELCOME5              3.1         33  customer1565@example.com
# 33    FREESHIP              4.4         34     onemore-invalid_email
# 34    FREESHIP              3.7         35     onemore-invalid_email
# 35         nan              NaN         36  customer1712@example.com
# 36      SAVE10              2.9         37  customer1188@example.com
# 37         nan              NaN         38     onemore-invalid_email
# 38         NaN              NaN         39  customer1500@example.com
# 39         NaN              NaN         40  customer1501@example.com
# 40         NaN              NaN         41  customer1502@example.com

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 15:**
# </div>

# %%
# 15. Ensuring No Negative Values in a DataFrame Column
# Write a Pandas program that ensures no negative values in a DataFrame column.



# Check for any negative values in the 'price' column
no_negatives = (df['price'] >= 0).all()

# Output the result
print(f"Are there any negative values? {not no_negatives}")


def find_negative_values(dataframe, column):
    # Check for any negative values in the specified column
    negative = dataframe[column] < 0
    return negative

# Find negative values in the 'price' column
negative_prices = find_negative_values(df, 'price')
print("Rows with negative prices:")
display(df[negative_prices])

# Replace negative values in the 'price' column with 0
df['price'] = df['price'].clip(lower=0)
df
# Out:
# Are there any negative values? True
# Rows with negative prices:
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 30 2023-01-31         1807         101         8  -10.0      0.00  210.400
# 31 2023-02-01         1106         191         4   -5.0      0.28   79.056
# 32 2023-02-02         1565         172         9  -15.0      0.18  128.412
# 38 2023-02-05         1500         150         2  -20.0      0.10    0.000
# 39 2023-02-06         1501         151         3  -15.0      0.20    0.000
# 40 2023-02-07         1502         152         1  -30.0      0.15    0.000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
#
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East           Cash       True              4            64
# 1          6   East    Credit Card       True              3            69
# 2          2  North         Online      False              6            64
# 3          7  North    Credit Card       True              6            55
# 4          6   West         Online       True              1            24
# 5          4  North         Online      False              1            31
# 6          5   East    Credit Card      False              1            18
# 7          1   East           Cash      False              3            31
# 8          6   East         Online      False              6            40
# 9          5   West           Cash      False              5            48
# 10         1  North           Cash      False              3            48
# 11         4  South           Cash       True              4            56
# 12         2  South           Cash      False              2            39
# 13         7   East         Online      False              1            21
# 14         2   West         Online       True              2            36
# 15         5   East    Credit Card      False              5            67
# 16         2  North           Cash      False              3            26
# 17         8  North         Online       True              6            26
# 18         9   East           Cash       True              3            52
# 19         5   East           Cash      False              3            20
# 20         5  North         Online       True              2            69
# 21         3   East    Credit Card       True              3            20
# 22         5   West         Online       True              2            48
# 23         7  South         Online       True              5            39
# 24         1  North           Cash      False              2            50
# 25         1   West    Credit Card       True              6            22
# 26         5  South         Online       True              1            64
# 27         3  South    Credit Card      False              2            52
# 28         6   West           Cash      False              1            43
# 29         2  North           Cash      False              2            59
# 30         3  South    Credit Card       True              2            51
# 31         5  South    Credit Card       True              2            19
# 32         6  North         Online      False              1            20
# 33         3   West           Cash      False              4            46
# 34         3   West           Cash       True              1            19
# 35         5  South         Online       True              1            64
# 36         7   East         Online      False              1            21
# 37         1  North           Cash      False              2            50
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other      Electronics     4.1      Returned  Negative            NaN
# 1    Other             Food     2.6  Not Returned  Positive           9.40
# 2     Male            Books     4.9  Not Returned   Neutral            NaN
# 3    Other         Clothing     2.9      Returned  Positive            NaN
# 4     Male      Electronics     1.6  Not Returned  Negative          18.39
# 5    Other            Books     3.0      Returned   Neutral          14.81
# 6     Male             Food     2.3      Returned   Neutral          10.37
# 7    Other             Food     3.6  Not Returned  Negative          18.62
# 8    Other         Clothing     2.4  Not Returned  Positive            NaN
# 9   Female      Electronics     4.6  Not Returned  Negative            NaN
# 10   Other             Food     1.2      Returned  Positive           9.54
# 11    Male      Electronics     1.3      Returned   Neutral           7.58
# 12   Other             Food     4.7      Returned   Neutral          10.62
# 13  Female            Books     1.9      Returned  Negative            NaN
# 14   Other            Books     2.5      Returned  Negative           9.71
# 15    Male      Electronics     3.4  Not Returned  Negative          15.76
# 16  Female             Food     4.6      Returned  Negative           7.35
# 17   Other             Food     3.6      Returned   Neutral          12.05
# 18  Female      Electronics     4.7      Returned   Neutral           5.50
# 19   Other         Clothing     1.7  Not Returned   Neutral           7.87
# 20   Other             Food     3.2      Returned   Neutral          15.65
# 21   Other         Clothing     1.5      Returned  Positive            NaN
# 22    Male             Food     2.4      Returned   Neutral          16.71
# 23   Other         Clothing     5.0  Not Returned  Negative          10.01
# 24   Other         Clothing     1.1  Not Returned  Negative          14.66
# 25   Other            Books     3.7  Not Returned  Positive           6.44
# 26   Other             Food     3.0      Returned   Neutral           6.95
# 27  Female             Food     1.1      Returned  Positive            NaN
# 28    Male         Clothing     2.9      Returned  Negative          15.79
# 29  Female             Food     2.7      Returned  Negative          18.34
# 30    Male         Clothing     3.0      Returned   Neutral            NaN
# 31  Female      Electronics     3.8      Returned  Positive           6.35
# 32    Male             Food     2.2  Not Returned  Positive           7.93
# 33  Female         Clothing     3.5      Returned   Neutral          15.12
# 34   Other         Clothing     3.2  Not Returned  Negative           9.14
# 35   Other             Food     3.0      Returned   Neutral           6.95
# 36  Female            Books     1.9      Returned  Negative            NaN
# 37   Other         Clothing     1.1  Not Returned  Negative          14.66
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id                     email
# 0       SAVE10              3.5          1      invalid-email-format
# 1          nan              4.5          2  customer1179@example.com
# 2       SAVE10              4.6          3  customer1878@example.com
# 3     FREESHIP              4.5          4     onemore-invalid_email
# 4          nan              1.5          5  customer1640@example.com
# 5     WELCOME5              1.2          6  customer1278@example.com
# 6       SAVE10              4.2          7     onemore-invalid_email
# 7          nan              NaN          8  customer1196@example.com
# 8     FREESHIP              1.7          9  customer1118@example.com
# 9       SAVE10              1.7         10     onemore-invalid_email
# 10         nan              NaN         11      invalid-email-format
# 11    FREESHIP              NaN         12  customer1549@example.com
# 12    FREESHIP              NaN         13  customer1393@example.com
# 13      SAVE10              2.9         14  customer1188@example.com
# 14    FREESHIP              4.1         15  customer1842@example.com
# 15         nan              2.1         16  customer1509@example.com
# 16      SAVE10              NaN         17     onemore-invalid_email
# 17    FREESHIP              1.4         18  customer1422@example.com
# 18         nan              2.7         19  customer1319@example.com
# 19      SAVE10              1.9         20  customer1020@example.com
# 20      SAVE10              1.2         21      invalid-email-format
# 21         nan              4.1         22  customer1552@example.com
# 22    WELCOME5              2.5         23  customer1446@example.com
# 23    WELCOME5              1.3         24  customer1994@example.com
# 24         nan              NaN         25     onemore-invalid_email
# 25         nan              2.3         26  customer1516@example.com
# 26         nan              NaN         27  customer1712@example.com
# 27    FREESHIP              2.0         28  customer1528@example.com
# 28    WELCOME5              4.9         29  customer1330@example.com
# 29    WELCOME5              2.2         30  customer1430@example.com
# 30      SAVE10              2.3         31  customer1807@example.com
# 31      SAVE10              4.7         32  customer1106@example.com
# 32    WELCOME5              3.1         33  customer1565@example.com
# 33    FREESHIP              4.4         34     onemore-invalid_email
# 34    FREESHIP              3.7         35     onemore-invalid_email
# 35         nan              NaN         36  customer1712@example.com
# 36      SAVE10              2.9         37  customer1188@example.com
# 37         nan              NaN         38     onemore-invalid_email
# 38         NaN              NaN         39  customer1500@example.com
# 39         NaN              NaN         40  customer1501@example.com
# 40         NaN              NaN         41  customer1502@example.com
