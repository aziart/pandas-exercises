# %% [markdown]
# [Pandas Data Validation](https://www.w3resource.com/python-exercises/pandas/pandas-data-validation.php)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <div class="alert alert-warning">
#
# **1. Checking Missing Values in a DataFrame**
#
# **Write a Pandas program to check for missing values in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1234         194         6  41.09      0.29  175.0434
# 1  2023-01-02         1236         117         3  32.59      0.06   91.9038
# 2  2023-01-03         1035         103         5  87.29      0.27  318.6085
# 3  2023-01-04         1090         111         2  51.45      0.04   98.7840
# 4  2023-01-05         1660         123         5  75.64      0.29  268.5220
# 5  2023-01-06         1407         169         3  57.80      0.15  147.3900
# 6  2023-01-07         1267         188         7  93.16      0.21  515.1748
# 7  2023-01-08         1230         129         2  14.86      0.15   25.2620
# 8  2023-01-09         1142         176         5  40.82      0.24  155.1160
# 9  2023-01-10         1704         123         4  21.92      0.29   62.2528
# 10 2023-01-11         1059         100         7  74.70      0.11  465.3810
# 11 2023-01-12         1993         151         7  38.55      0.06  253.6590
# 12 2023-01-13         1259         196         7  58.82      0.08  378.8008
# 13 2023-01-14         1440         128         3  95.26      0.23  220.0506
# 14 2023-01-15         1945         133         5  82.57      0.06  388.0790
# 15 2023-01-16         1337         124         2  38.50      0.28   55.4400
# 16 2023-01-17         1076         168         8  92.36      0.20  591.1040
# 17 2023-01-18         1193         113         3  64.85      0.19  157.5855
# 18 2023-01-19         1884         119         6  82.47      0.21  390.9078
# 19 2023-01-20         1760         119         7  13.39      0.04   89.9808
# 20 2023-01-21         1572         192         4  22.70      0.20   72.6400
# 21 2023-01-22         1183         190         5  53.92      0.26  199.5040
# 22 2023-01-23         1332         110         7  72.01      0.11  448.6223
# 23 2023-01-24         1980         140         9  44.68      0.15  341.8020
# 24 2023-01-25         1285         187         3  38.06      0.12  100.4784
# 25 2023-01-26         1115         160         1  58.86      0.12   51.7968
# 26 2023-01-27         1797         113         6  45.45      0.27  199.0710
# 27 2023-01-28         1017         148         6  34.41      0.12  181.6848
# 28 2023-01-29         1481         101         6  13.41      0.25   60.3450
# 29 2023-01-30         1215         177         8  86.87      0.19  562.9176
# 30 2023-01-31         1315         119         7  86.79      0.08  558.9276
# 31 2023-02-01         1537         170         3  92.85      0.13  242.3385
# 32 2023-02-02         1484         165         8  30.45      0.26  180.2640
# 33 2023-02-03         1784         169         9  53.80      0.09  440.6220
# 34 2023-02-04         1896         190         4  92.98      0.17  308.6936
#
#     store_id region payment_method  ...  delivery_days  customer_age  gender  \
# 0          8   East           Cash  ...              4            30  Female
# 1          6   West           Cash  ...              3            48   Other
# 2          9  South           Cash  ...              4            30    Male
# 3          2   West           Cash  ...              2            53   Other
# 4          8  South           Cash  ...              6            36   Other
# 5          5  South    Credit Card  ...              2            25  Female
# 6          8  North           Cash  ...              6            61    Male
# 7          7  North           Cash  ...              5            39  Female
# 8          5  North         Online  ...              1            39   Other
# 9          3   West         Online  ...              6            41   Other
# 10         8   West    Credit Card  ...              2            21  Female
# 11         4  South    Credit Card  ...              2            49  Female
# 12         8  North    Credit Card  ...              6            67    Male
# 13         4  North           Cash  ...              6            49  Female
# 14         7   East    Credit Card  ...              3            62   Other
# 15         8   East    Credit Card  ...              5            38   Other
# 16         3   West           Cash  ...              1            69    Male
# 17         3  North    Credit Card  ...              1            30  Female
# 18         1  North           Cash  ...              2            57  Female
# 19         6   West           Cash  ...              5            22  Female
# 20         6  North           Cash  ...              4            58  Female
# 21         4   East           Cash  ...              6            49  Female
# 22         9  North         Online  ...              4            52   Other
# 23         1   West           Cash  ...              6            46   Other
# 24         6  North    Credit Card  ...              2            45  Female
# 25         1  South         Online  ...              2            54    Male
# 26         1   East           Cash  ...              4            53  Female
# 27         8   East    Credit Card  ...              1            57   Other
# 28         7  North           Cash  ...              3            57    Male
# 29         4   East    Credit Card  ...              4            60   Other
# 30         2   West           Cash  ...              3            29   Other
# 31         7  South           Cash  ...              3            44  Female
# 32         3  North    Credit Card  ...              1            19   Other
# 33         8  North           Cash  ...              5            34    Male
# 34         6  North    Credit Card  ...              4            49    Male
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0             Books    2.9       Returned  Positive          6.02
# 1          Clothing    4.5   Not Returned  Positive         12.71
# 2              Food    2.6   Not Returned  Negative          9.36
# 3          Clothing    1.3       Returned  Negative         18.52
# 4              Food    3.7   Not Returned   Neutral          7.23
# 5             Books    2.2   Not Returned  Negative         19.10
# 6             Books    3.3   Not Returned   Neutral           NaN
# 7              Food    4.1   Not Returned  Positive          8.51
# 8       Electronics    1.9       Returned  Negative         13.54
# 9             Books    1.4       Returned  Positive          6.61
# 10      Electronics    4.8       Returned  Negative         18.61
# 11         Clothing    3.9   Not Returned   Neutral          5.71
# 12             Food    2.7   Not Returned   Neutral         17.00
# 13             Food    4.6       Returned  Positive         17.09
# 14      Electronics    1.4   Not Returned  Positive         15.47
# 15      Electronics    1.7   Not Returned  Negative         15.89
# 16         Clothing    4.7       Returned  Negative          7.77
# 17             Food    3.0       Returned   Neutral         19.52
# 18         Clothing    1.2   Not Returned  Negative         17.33
# 19      Electronics    4.7   Not Returned  Negative           NaN
# 20      Electronics    5.0   Not Returned  Negative          9.09
# 21            Books    3.7       Returned  Negative          8.24
# 22         Clothing    1.3   Not Returned   Neutral         16.53
# 23             Food    1.9   Not Returned  Negative         16.43
# 24      Electronics    2.5       Returned   Neutral          9.82
# 25      Electronics    2.6       Returned  Positive           NaN
# 26      Electronics    4.2       Returned   Neutral         14.02
# 27             Food    3.4   Not Returned  Negative         12.34
# 28             Food    1.7   Not Returned  Positive         16.36
# 29            Books    1.7   Not Returned  Positive         11.52
# 30             Food    1.5       Returned  Negative         14.86
# 31      Electronics    4.7   Not Returned  Negative         10.48
# 32            Books    4.5   Not Returned   Neutral          6.87
# 33      Electronics    3.7       Returned  Negative          8.40
# 34            Books    3.5   Not Returned  Positive         14.75
#
#     coupon_code delivery_rating
# 0        SAVE10             1.0
# 1      WELCOME5             2.7
# 2           nan             3.0
# 3      WELCOME5             3.4
# 4        SAVE10             2.3
# 5           nan             NaN
# 6        SAVE10             2.5
# 7           nan             3.5
# 8           nan             NaN
# 9      WELCOME5             NaN
# 10     WELCOME5             2.6
# 11     FREESHIP             2.7
# 12     FREESHIP             3.0
# 13          nan             1.7
# 14       SAVE10             NaN
# 15       SAVE10             4.4
# 16     FREESHIP             3.7
# 17     FREESHIP             3.7
# 18       SAVE10             3.6
# 19          nan             2.2
# 20          nan             4.7
# 21       SAVE10             2.2
# 22       SAVE10             2.7
# 23     FREESHIP             3.8
# 24       SAVE10             3.4
# 25          nan             3.3
# 26          nan             4.8
# 27          nan             2.9
# 28     WELCOME5             3.9
# 29       SAVE10             NaN
# 30     FREESHIP             4.0
# 31     WELCOME5             1.1
# 32       SAVE10             4.5
# 33     WELCOME5             1.8
# 34       SAVE10             NaN
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
# 13         9  South         Online  ...              5            69    Male
# 14         9   East           Cash  ...              5            68    Male
# 15         7   East           Cash  ...              4            32   Other
# 16         4  North           Cash  ...              2            33    Male
# 17         6  North    Credit Card  ...              3            69  Female
# 18         9   West         Online  ...              2            61    Male
# 19         2   East         Online  ...              1            56   Other
# 20         4  North         Online  ...              2            20    Male
# 21         7  North         Online  ...              2            27    Male
# 22         3   East           Cash  ...              2            31   Other
# 23         7   West         Online  ...              4            21  Female
# 24         8  North    Credit Card  ...              1            33    Male
# 25         8   East         Online  ...              1            33   Other
# 26         7  South         Online  ...              4            18   Other
# 27         3   East    Credit Card  ...              2            50    Male
# 28         1   East         Online  ...              1            42    Male
# 29         9   East           Cash  ...              2            37  Female
# 30         9   West         Online  ...              1            42  Female
# 31         5  South    Credit Card  ...              5            19    Male
# 32         9   West         Online  ...              3            28   Other
# 33         8   East         Online  ...              3            54   Other
# 34         9   West           Cash  ...              2            62  Female
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0             Books    4.4       Returned  Positive         18.09
# 1       Electronics    4.5   Not Returned   Neutral         18.52
# 2              Food    4.5       Returned  Negative          5.08
# 3          Clothing    3.8   Not Returned  Positive         15.95
# 4              Food    1.9   Not Returned   Neutral         16.16
# 5          Clothing    4.9       Returned   Neutral          5.71
# 6       Electronics    3.1       Returned   Neutral         15.18
# 7             Books    5.0       Returned  Negative           NaN
# 8              Food    2.9       Returned   Neutral          7.18
# 9       Electronics    1.2   Not Returned  Positive         16.09
# 10      Electronics    1.5       Returned  Positive         13.52
# 11            Books    1.2   Not Returned   Neutral          5.05
# 12            Books    4.7       Returned   Neutral         17.24
# 13            Books    4.7       Returned  Negative          8.75
# 14            Books    4.1   Not Returned  Positive         12.81
# 15            Books    2.2   Not Returned   Neutral           NaN
# 16             Food    4.3   Not Returned   Neutral         17.06
# 17            Books    2.4       Returned  Negative         15.40
# 18         Clothing    4.5   Not Returned  Positive          5.53
# 19         Clothing    3.3       Returned  Positive         10.87
# 20             Food    1.5       Returned   Neutral          8.37
# 21      Electronics    3.0       Returned  Negative         15.11
# 22            Books    3.1       Returned  Negative         19.75
# 23      Electronics    4.9   Not Returned  Positive         17.18
# 24      Electronics    1.0       Returned   Neutral          5.17
# 25         Clothing    1.7   Not Returned  Positive           NaN
# 26      Electronics    1.9   Not Returned  Negative           NaN
# 27             Food    3.5       Returned  Positive         12.78
# 28             Food    4.6   Not Returned  Negative           NaN
# 29             Food    3.1       Returned   Neutral           NaN
# 30      Electronics    4.7   Not Returned  Positive           NaN
# 31      Electronics    3.5   Not Returned  Positive         19.67
# 32         Clothing    3.2       Returned  Positive         10.95
# 33            Books    1.8   Not Returned  Positive          8.79
# 34      Electronics    4.5       Returned  Positive         10.82
#
#     coupon_code delivery_rating
# 0      FREESHIP             NaN
# 1           nan             1.5
# 2        SAVE10             1.6
# 3      WELCOME5             3.3
# 4           nan             1.8
# 5           nan             NaN
# 6      FREESHIP             4.2
# 7        SAVE10             NaN
# 8        SAVE10             NaN
# 9      WELCOME5             1.9
# 10     FREESHIP             4.3
# 11     FREESHIP             3.9
# 12     FREESHIP             NaN
# 13       SAVE10             1.1
# 14     FREESHIP             4.0
# 15     WELCOME5             4.4
# 16     WELCOME5             5.0
# 17     FREESHIP             2.0
# 18     WELCOME5             4.9
# 19     FREESHIP             1.3
# 20          nan             2.6
# 21     WELCOME5             2.5
# 22          nan             NaN
# 23       SAVE10             4.5
# 24          nan             3.5
# 25          nan             1.7
# 26     WELCOME5             1.2
# 27          nan             NaN
# 28     WELCOME5             NaN
# 29       SAVE10             4.5
# 30     FREESHIP             2.7
# 31     FREESHIP             2.2
# 32     FREESHIP             1.8
# 33     WELCOME5             NaN
# 34     WELCOME5             NaN
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 02:**
# </div>

# %%
# 2. Ensuring Consistent Data Types of All Columns
# Write a Pandas program to check and ensure that the data types of all columns are consistent.

# Check data types
data_types = df.dtypes
data_types
# Out:
# date                datetime64[ns]
# customer_id                  int64
# product_id                   int64
# quantity                     int64
# price                      float64
# discount                   float64
# revenue                    float64
# store_id                     int64
# region                      object
# payment_method              object
# is_member                     bool
# delivery_days                int64
# customer_age                 int64
# gender                      object
# product_category            object
# rating                     float64
# return_status               object
# feedback                    object
# shipping_cost              float64
# coupon_code                 object
# delivery_rating            float64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning">
#
# **3. Validating the Data Type of a Specific Column**
#
# **Write a Pandas program to validate the data type of a specific column in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1165         108         7  64.09      0.01  444.1437
# 1  2023-01-02         1736         178         2  77.24      0.09  140.5768
# 2  2023-01-03         1759         190         4  34.30      0.27  100.1560
# 3  2023-01-04         1883         195         9  56.13      0.10  454.6530
# 4  2023-01-05         1817         104         8  60.82      0.28  350.3232
# 5  2023-01-06         1381         118         8  28.24      0.02  221.4016
# 6  2023-01-07         1246         106         2  40.59      0.19   65.7558
# 7  2023-01-08         1380         133         8  83.09      0.11  591.6008
# 8  2023-01-09         1181         164         2  78.37      0.25  117.5550
# 9  2023-01-10         1386         178         8  27.52      0.14  189.3376
# 10 2023-01-11         1711         124         7  37.31      0.20  208.9360
# 11 2023-01-12         1484         102         7  21.07      0.14  126.8414
# 12 2023-01-13         1447         143         4  15.54      0.06   58.4304
# 13 2023-01-14         1326         109         5  18.08      0.12   79.5520
# 14 2023-01-15         1104         112         9  19.77      0.23  137.0061
# 15 2023-01-16         1377         115         5  85.40      0.29  303.1700
# 16 2023-01-17         1598         121         7  40.65      0.06  267.4770
# 17 2023-01-18         1584         132         1  21.91      0.20   17.5280
# 18 2023-01-19         1217         199         7  53.30      0.03  361.9070
# 19 2023-01-20         1268         187         1  88.22      0.04   84.6912
# 20 2023-01-21         1727         188         9  89.64      0.27  588.9348
# 21 2023-01-22         1313         116         3  29.21      0.15   74.4855
# 22 2023-01-23         1065         153         4  99.02      0.28  285.1776
# 23 2023-01-24         1099         142         9  15.56      0.25  105.0300
# 24 2023-01-25         1906         145         6  28.91      0.07  161.3178
# 25 2023-01-26         1186         116         1  11.81      0.25    8.8575
# 26 2023-01-27         1639         138         9  45.65      0.07  382.0905
# 27 2023-01-28         1020         107         4  28.56      0.02  111.9552
# 28 2023-01-29         1519         131         5  33.43      0.27  122.0195
# 29 2023-01-30         1238         142         4  34.82      0.25  104.4600
# 30 2023-01-31         1680         124         1  81.39      0.09   74.0649
# 31 2023-02-01         1711         113         8  32.11      0.02  251.7424
# 32 2023-02-02         1530         137         9  48.45      0.05  414.2475
# 33 2023-02-03         1107         195         8  72.97      0.10  525.3840
# 34 2023-02-04         1935         123         5  78.57      0.08  361.4220
#
#     store_id region payment_method  ...  delivery_days  customer_age  gender  \
# 0          9  North         Online  ...              2            67   Other
# 1          9   East           Cash  ...              1            65  Female
# 2          2   East    Credit Card  ...              3            23  Female
# 3          8   West           Cash  ...              1            69  Female
# 4          6   West         Online  ...              6            58   Other
# 5          8   West         Online  ...              2            69  Female
# 6          3   West         Online  ...              1            29    Male
# 7          8  North    Credit Card  ...              3            63   Other
# 8          5   West    Credit Card  ...              1            61   Other
# 9          2   West           Cash  ...              1            61    Male
# 10         8   East         Online  ...              3            27   Other
# 11         8  North         Online  ...              6            25   Other
# 12         3   East    Credit Card  ...              2            41    Male
# 13         3   East           Cash  ...              3            37  Female
# 14         9  South    Credit Card  ...              2            19   Other
# 15         2   East           Cash  ...              2            35    Male
# 16         6   East         Online  ...              1            57    Male
# 17         1   East         Online  ...              2            42    Male
# 18         9   West           Cash  ...              6            67    Male
# 19         2  North    Credit Card  ...              2            19  Female
# 20         6   East           Cash  ...              4            55  Female
# 21         3  North    Credit Card  ...              4            29   Other
# 22         8   West    Credit Card  ...              5            42    Male
# 23         5  South           Cash  ...              4            38   Other
# 24         5  North         Online  ...              6            41    Male
# 25         7  South    Credit Card  ...              5            18    Male
# 26         1   East           Cash  ...              1            50   Other
# 27         3  North           Cash  ...              2            33    Male
# 28         1   East    Credit Card  ...              6            30    Male
# 29         8   East         Online  ...              5            40   Other
# 30         9  South           Cash  ...              6            44    Male
# 31         5  North         Online  ...              2            48  Female
# 32         5  South    Credit Card  ...              6            24  Female
# 33         4  South    Credit Card  ...              5            62  Female
# 34         7  South         Online  ...              4            18  Female
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0       Electronics    4.5   Not Returned   Neutral         11.54
# 1             Books    1.1       Returned   Neutral         14.08
# 2       Electronics    1.5   Not Returned  Positive         13.63
# 3       Electronics    3.7   Not Returned  Positive         15.32
# 4             Books    2.2   Not Returned  Negative         13.80
# 5          Clothing    2.5       Returned  Negative         11.85
# 6       Electronics    1.8   Not Returned   Neutral           NaN
# 7             Books    3.6       Returned  Positive           NaN
# 8              Food    3.2       Returned  Positive         13.64
# 9       Electronics    2.4       Returned  Negative         16.18
# 10             Food    4.0   Not Returned  Positive           NaN
# 11      Electronics    2.0   Not Returned  Positive         11.66
# 12             Food    1.6       Returned  Positive         19.37
# 13            Books    5.0   Not Returned  Negative         16.14
# 14      Electronics    5.0   Not Returned  Negative          5.15
# 15             Food    2.1   Not Returned   Neutral           NaN
# 16      Electronics    3.2   Not Returned   Neutral          5.28
# 17         Clothing    1.2       Returned   Neutral         16.67
# 18             Food    1.3       Returned  Negative         15.21
# 19         Clothing    2.3       Returned  Positive         14.02
# 20             Food    2.0   Not Returned   Neutral         12.12
# 21             Food    1.9   Not Returned  Positive         13.60
# 22            Books    2.9       Returned  Negative           NaN
# 23             Food    2.8   Not Returned   Neutral         17.75
# 24            Books    4.5       Returned  Negative         15.64
# 25         Clothing    1.7       Returned   Neutral         16.19
# 26         Clothing    4.2       Returned  Negative         10.44
# 27             Food    3.7   Not Returned   Neutral          9.22
# 28      Electronics    3.1   Not Returned  Positive           NaN
# 29         Clothing    4.7   Not Returned   Neutral         13.79
# 30             Food    1.5       Returned  Positive           NaN
# 31         Clothing    2.2       Returned   Neutral         15.83
# 32         Clothing    3.2   Not Returned  Negative          5.53
# 33             Food    3.7   Not Returned   Neutral           NaN
# 34         Clothing    4.6   Not Returned  Positive         12.04
#
#     coupon_code delivery_rating
# 0      WELCOME5             2.1
# 1           nan             NaN
# 2      FREESHIP             4.6
# 3      WELCOME5             NaN
# 4           nan             1.9
# 5      FREESHIP             4.8
# 6        SAVE10             3.2
# 7           nan             NaN
# 8           nan             1.8
# 9      FREESHIP             2.6
# 10          nan             NaN
# 11          nan             NaN
# 12          nan             NaN
# 13          nan             2.5
# 14     WELCOME5             NaN
# 15       SAVE10             2.8
# 16          nan             NaN
# 17       SAVE10             3.0
# 18       SAVE10             3.8
# 19          nan             3.1
# 20     FREESHIP             NaN
# 21     FREESHIP             1.4
# 22       SAVE10             4.3
# 23     WELCOME5             3.7
# 24          nan             3.4
# 25          nan             NaN
# 26          nan             4.6
# 27          nan             2.3
# 28          nan             2.9
# 29          nan             3.6
# 30       SAVE10             1.3
# 31       SAVE10             3.6
# 32     FREESHIP             NaN
# 33     WELCOME5             4.2
# 34          nan             1.7
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 03:**
# </div>

# %%
# 3. Validating the Data Type of a Specific Column
# Write a Pandas program to validate the data type of a specific column in a DataFrame.

# Check if 'price' column is of type float
is_of_type = 'float64'
is_price_float = df['price'].dtype == is_of_type
is_price_float

# Validate the data type of 'price' column
if is_price_float:
    print("The 'price' column is of type {}.".format(df['price'].dtype))
else:
    print("The 'price' column is not of type {}, it is {}.".format(is_of_type, df['price'].dtype))
# Out:
# The 'price' column is of type float64.

# %% [markdown]
# <div class="alert alert-warning">
#
# **4. Checking Duplicate Rows in a DataFrame**
#
# **Write a Pandas program to check duplicate rows in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1596         164         3  80.56      0.07  224.7624
# 1  2023-01-02         1047         176         9  85.03      0.10  688.7430
# 2  2023-01-03         1001         119         8  74.93      0.30  419.6080
# 3  2023-01-04         1669         147         5  54.39      0.16  228.4380
# 4  2023-01-05         1658         124         7  27.26      0.29  135.4822
# 5  2023-01-06         1733         189         3  60.21      0.29  128.2473
# 6  2023-01-07         1873         117         5  60.45      0.26  223.6650
# 7  2023-01-08         1202         135         7  54.59      0.24  290.4188
# 8  2023-01-09         1716         145         1  18.31      0.03   17.7607
# 9  2023-01-10         1279         120         2  83.92      0.08  154.4128
# 10 2023-01-11         1306         154         1  65.41      0.04   62.7936
# 11 2023-01-12         1507         114         9  59.47      0.22  417.4794
# 12 2023-01-13         1843         175         9  20.47      0.19  149.2263
# 13 2023-01-14         1142         116         8  95.33      0.12  671.1232
# 14 2023-01-15         1946         191         6  75.68      0.19  367.8048
# 15 2023-01-16         1070         141         9  77.23      0.20  556.0560
# 16 2023-01-17         1973         167         4  29.32      0.20   93.8240
# 17 2023-01-18         1197         153         8  50.23      0.17  333.5272
# 18 2023-01-19         1672         143         3  85.81      0.01  254.8557
# 19 2023-01-20         1295         152         6  14.60      0.26   64.8240
# 20 2023-01-21         1022         120         6  91.27      0.07  509.2866
# 21 2023-01-22         1477         124         4  43.75      0.15  148.7500
# 22 2023-01-23         1869         124         9  32.09      0.12  254.1528
# 12            Books    3.2   Not Returned  Negative         16.23
# 13             Food    2.8   Not Returned  Negative          5.40
# 14         Clothing    2.7       Returned  Negative          6.31
# 15            Books    1.3   Not Returned   Neutral          5.65
# 16            Books    2.7   Not Returned   Neutral          5.07
# 17             Food    2.4   Not Returned  Positive         10.04
# 18         Clothing    4.5   Not Returned  Negative           NaN
# 19             Food    3.7       Returned   Neutral           NaN
# 20         Clothing    2.4   Not Returned   Neutral         13.59
# 21         Clothing    4.3   Not Returned  Positive         12.53
# 22            Books    2.5   Not Returned   Neutral         18.68
# 23             Food    1.2   Not Returned  Positive          8.04
# 24      Electronics    1.7       Returned  Negative         13.80
# 25            Books    2.3   Not Returned  Positive         18.26
# 26             Food    2.4   Not Returned  Negative          8.97
# 27             Food    2.2       Returned  Negative         15.50
# 28             Food    2.3       Returned  Positive         10.54
# 29            Books    2.2   Not Returned  Negative         17.13
# 30         Clothing    1.1   Not Returned  Negative          8.27
# 31         Clothing    3.1   Not Returned  Negative         11.93
# 32      Electronics    2.4   Not Returned  Positive          7.78
# 33         Clothing    1.4   Not Returned   Neutral         12.61
# 34      Electronics    3.0   Not Returned  Negative         18.30
# 35             Food    2.4   Not Returned  Negative          8.97
# 36             Food    2.8   Not Returned  Negative          5.40
# 37      Electronics    1.7       Returned  Negative         13.80
#
#     coupon_code delivery_rating
# 0        SAVE10             2.1
# 1        SAVE10             4.9
# 2      WELCOME5             1.4
# 3      WELCOME5             3.7
# 4        SAVE10             3.2
# 5           nan             NaN
# 6        SAVE10             3.8
# 7      FREESHIP             3.7
# 8           nan             3.3
# 9        SAVE10             4.8
# 10     FREESHIP             4.4
# 11     FREESHIP             NaN
# 12     WELCOME5             NaN
# 13     FREESHIP             NaN
# 14          nan             NaN
# 15     WELCOME5             1.9
# 16     WELCOME5             2.5
# 17       SAVE10             2.1
# 18          nan             4.1
# 19          nan             1.2
# 20          nan             3.7
# 21     FREESHIP             3.5
# 22          nan             3.4
# 23          nan             4.7
# 24     FREESHIP             4.9
# 25          nan             2.0
# 26       SAVE10             4.9
# 27     FREESHIP             3.0
# 28          nan             4.9
# 29          nan             4.1
# 30     FREESHIP             NaN
# 31          nan             4.2
# 32          nan             2.9
# 33     WELCOME5             2.5
# 34     WELCOME5             3.5
# 35       SAVE10             4.9
# 36     FREESHIP             NaN
# 37     FREESHIP             4.9
#
# [38 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
# 4. Checking Duplicate Rows in a DataFrame
# Write a Pandas program to check duplicate rows in a DataFrame.

# Check for duplicate rows
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 35 2023-01-27         1634         194         4  40.83      0.07  151.8876
# 36 2023-01-14         1142         116         8  95.33      0.12  671.1232
# 37 2023-01-25         1320         186         3  31.19      0.03   90.7629
#
#     store_id region payment_method  ...  delivery_days  customer_age  gender  \
# 35         2  North         Online  ...              5            63  Female
# 36         9  South    Credit Card  ...              2            22  Female
# 37         6   West           Cash  ...              1            67    Male
#
#    product_category rating  return_status  feedback shipping_cost  \
# 35             Food    2.4   Not Returned  Negative          8.97
# 36             Food    2.8   Not Returned  Negative          5.40
# 37      Electronics    1.7       Returned  Negative         13.80
#
#     coupon_code delivery_rating
# 35       SAVE10             4.9
# 36     FREESHIP             NaN
# 37     FREESHIP             4.9
#
# [3 rows x 21 columns]
