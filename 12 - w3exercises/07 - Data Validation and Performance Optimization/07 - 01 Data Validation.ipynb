# 21         8  South         Online       True              5            41
# 22         7  South    Credit Card       True              2            57
# 23         8   West    Credit Card      False              2            69
# 24         9   West           Cash       True              5            64
# 25         8   East         Online       True              6            26
# 26         5   West           Cash      False              3            19
# 27         3  North         Online       True              3            19
# 28         8   East           Cash       True              6            34
# 29         7   East    Credit Card       True              6            19
# 30         9  North    Credit Card       True              1            68
# 31         1   West         Online      False              5            65
# 32         7  North         Online      False              6            37
# 33         7  North           Cash      False              2            69
# 34         1  North    Credit Card      False              1            28
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other      Electronics     2.8  Not Returned  Negative            NaN
# 1    Other             Food     3.2      Returned  Positive          17.02
# 2   Female            Books     3.1  Not Returned  Negative           7.14
# 3     Male            Books     1.5      Returned   Neutral          10.93
# 4    Other            Books     5.0      Returned   Neutral            NaN
# 5    Other            Books     3.7      Returned  Positive            NaN
# 6     Male      Electronics     1.2      Returned  Positive           6.42
# 7    Other            Books     2.3      Returned  Positive           5.29
# 8   Female            Books     4.3  Not Returned   Neutral            NaN
# 9    Other             Food     1.1  Not Returned  Negative          13.60
# 10   Other            Books     3.1      Returned  Positive          14.19
# 11    Male      Electronics     3.0  Not Returned  Negative           7.03
# 12    Male            Books     4.3      Returned  Negative          11.97
# 13  Female         Clothing     3.4  Not Returned  Positive           7.17
# 14    Male             Food     2.5      Returned   Neutral            NaN
# 15   Other            Books     4.1      Returned  Negative           7.84
# 16   Other             Food     1.3      Returned  Negative            NaN
# 17   Other         Clothing     1.6  Not Returned  Positive          16.67
# 18   Other         Clothing     1.1      Returned  Positive          12.92
# 19  Female             Food     4.0  Not Returned  Negative           9.20
# 20    Male            Books     1.9      Returned  Negative          17.67
# 21    Male         Clothing     3.1      Returned  Negative            NaN
# 22  Female      Electronics     2.8      Returned  Negative          16.01
# 23    Male            Books     1.8  Not Returned   Neutral           5.76
# 24  Female      Electronics     3.3      Returned  Negative          15.63
# 25    Male         Clothing     2.4      Returned  Negative          11.60
# 26    Male         Clothing     3.7      Returned  Negative          10.22
# 27    Male         Clothing     3.6  Not Returned  Positive            NaN
# 28   Other      Electronics     3.7  Not Returned   Neutral           8.75
# 29    Male            Books     2.9      Returned  Positive          19.99
# 30  Female            Books     3.0  Not Returned   Neutral          15.55
# 31   Other            Books     3.1  Not Returned   Neutral          14.03
# 32   Other      Electronics     2.3      Returned  Positive          15.23
# 33  Female      Electronics     4.5      Returned   Neutral            NaN
# 34    Male      Electronics     4.0      Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0          nan              NaN
# 1     FREESHIP              3.4
# 2          nan              2.5
# 3     WELCOME5              1.5
# 4       SAVE10              NaN
# 5          nan              NaN
# 6     FREESHIP              NaN
# 7          nan              4.9
# 8     WELCOME5              2.6
# 9       SAVE10              NaN
# 10      SAVE10              NaN
# 11      SAVE10              2.7
# 12         nan              1.2
# 13         nan              3.4
# 14    FREESHIP              1.7
# 15         nan              3.4
# 16    FREESHIP              NaN
# 17         nan              1.4
# 18    WELCOME5              1.4
# 19    WELCOME5              2.6
# 20         nan              3.6
# 21         nan              3.2
# 22    FREESHIP              3.0
# 23      SAVE10              1.4
# 24      SAVE10              NaN
# 25         nan              NaN
# 26      SAVE10              3.2
# 27    FREESHIP              NaN
# 28         nan              4.5
# 29    WELCOME5              1.5
# 30      SAVE10              4.6
# 31      SAVE10              4.0
# 32         nan              NaN
# 33    FREESHIP              NaN
# 34    FREESHIP              2.8

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
# 11         1   East           Cash       True              2            47
# 12         1   East    Credit Card      False              2            38
# 13         8  South           Cash       True              2            30
# 14         6  North    Credit Card      False              1            59
# 15         1   East         Online      False              1            42
# 16         4   West    Credit Card       True              3            65
# 17         6  North           Cash       True              2            27
# 18         5   East         Online      False              5            47
# 19         5  South           Cash       True              5            48
# 20         1  South         Online       True              4            25
# 21         2   East           Cash       True              5            27
# 22         9   East    Credit Card       True              6            44
# 23         6  South           Cash      False              1            64
# 24         6   West         Online      False              2            27
# 25         5   East           Cash       True              5            33
# 26         7  North    Credit Card       True              2            39
# 27         5  North    Credit Card       True              5            57
# 28         5  South    Credit Card       True              2            60
# 29         4  South         Online      False              4            65
# 30         7  North         Online      False              5            21
# 31         7  South    Credit Card      False              3            42
# 32         1  North           Cash       True              4            49
# 33         2  South         Online       True              6            53
# 34         6   East         Online      False              2            47
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female         Clothing     2.6      Returned   Neutral           5.92
# 1   Female             Food     3.1  Not Returned   Neutral           8.50
# 2    Other      Electronics     3.2      Returned  Positive          13.82
# 3     Male            Books     1.5  Not Returned  Negative            NaN
# 4    Other             Food     2.9      Returned   Neutral          16.75
# 5   Female             Food     3.5      Returned  Negative          13.47
# 6   Female         Clothing     2.5      Returned  Negative          15.79
# 7    Other         Clothing     3.8  Not Returned  Negative          12.99
# 8   Female      Electronics     3.2      Returned  Negative           9.10
# 9   Female      Electronics     4.0      Returned  Negative            NaN
# 10   Other      Electronics     4.1  Not Returned   Neutral          16.57
# 11   Other         Clothing     3.2      Returned  Negative          14.02
# 12  Female         Clothing     3.4      Returned  Negative            NaN
# 13    Male      Electronics     3.3      Returned   Neutral          13.62
# 14  Female      Electronics     4.5  Not Returned  Positive          16.76
# 15    Male      Electronics     2.2  Not Returned  Negative            NaN
# 16    Male      Electronics     1.9  Not Returned  Negative           7.46
# 17   Other      Electronics     1.2  Not Returned   Neutral          11.78
# 18   Other      Electronics     3.3  Not Returned   Neutral           8.13
# 19  Female             Food     2.1  Not Returned   Neutral          19.85
# 20   Other         Clothing     1.8  Not Returned  Negative           9.78
# 21    Male             Food     4.9  Not Returned   Neutral           9.48
# 22  Female             Food     2.2      Returned   Neutral          18.58
# 23   Other      Electronics     4.6  Not Returned  Positive          14.95
# 24  Female             Food     1.7      Returned  Negative            NaN
# 25    Male             Food     4.3  Not Returned  Positive            NaN
# 26    Male            Books     2.6      Returned   Neutral          15.29
# 27   Other         Clothing     2.5  Not Returned  Negative          19.10
# 28  Female         Clothing     3.9  Not Returned   Neutral            NaN
# 29   Other             Food     3.8      Returned   Neutral            NaN
# 30    Male            Books     4.6  Not Returned   Neutral           8.68
# 31  Female             Food     4.2      Returned  Negative          14.81
# 32    Male      Electronics     2.1      Returned  Positive            NaN
# 33   Other             Food     1.2      Returned   Neutral          10.72
# 34    Male         Clothing     1.9  Not Returned   Neutral            NaN
#
#    coupon_code  delivery_rating
# 0     FREESHIP              4.1
# 1     WELCOME5              2.0
# 2          nan              NaN
# 3     FREESHIP              NaN
# 4          nan              NaN
# 5          nan              NaN
# 6       SAVE10              NaN
# 7       SAVE10              5.0
# 8          nan              3.1
# 9     FREESHIP              NaN
# 10         nan              2.8
# 11         nan              4.6
# 12      SAVE10              NaN
# 13         nan              NaN
# 14    FREESHIP              NaN
# 15         nan              3.9
# 16    FREESHIP              NaN
# 17         nan              4.2
# 18         nan              3.2
# 19    WELCOME5              1.7
# 20      SAVE10              1.5
# 21         nan              3.7
# 22         nan              4.3
# 23      SAVE10              3.9
# 24    WELCOME5              4.8
# 25         nan              NaN
# 26    FREESHIP              2.5
# 27    FREESHIP              NaN
# 28         nan              NaN
# 29      SAVE10              NaN
# 30         nan              2.1
# 31         nan              NaN
# 32    WELCOME5              4.1
# 33    WELCOME5              4.5
# 34         nan              1.7

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 02:**
# </div>

# %%
# 2. Ensuring Consistent Data Types of All Columns
# Write a Pandas program to check and ensure that the data types of all columns are consistent.

# Check data types
data_types = df.dtypes
data_types
# Out:
# date                datetime64[ns]
# customer_id                  int64
# product_id                   int64
# quantity                     int64
# price                      float64
# discount                   float64
# revenue                    float64
# store_id                     int64
# region                      object
# payment_method              object
# is_member                     bool
# delivery_days                int64
# customer_age                 int64
# gender                      object
# product_category            object
# rating                     float64
# return_status               object
# feedback                    object
# shipping_cost              float64
# coupon_code                 object
# delivery_rating            float64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning">
#
# **3. Validating the Data Type of a Specific Column**
#
# **Write a Pandas program to validate the data type of a specific column in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1440         197         6  87.42      0.04  503.5392
# 1  2023-01-02         1677         140         2  47.33      0.27   69.1018
# 2  2023-01-03         1704         150         7  85.58      0.20  479.2480
# 3  2023-01-04         1546         120         5  49.04      0.11  218.2280
# 4  2023-01-05         1270         128         5  14.04      0.23   54.0540
# 5  2023-01-06         1806         187         9  22.47      0.22  157.7394
# 6  2023-01-07         1527         102         9  67.47      0.18  497.9286
# 7  2023-01-08         1352         112         8  68.50      0.18  449.3600
# 8  2023-01-09         1030         129         3  99.58      0.11  265.8786
# 9  2023-01-10         1565         171         2  50.64      0.22   78.9984
# 10 2023-01-11         1402         149         1  71.43      0.12   62.8584
# 11 2023-01-12         1936         183         5  62.87      0.13  273.4845
# 12 2023-01-13         1724         178         8  16.27      0.18  106.7312
# 13 2023-01-14         1918         149         7  49.00      0.02  336.1400
# 14 2023-01-15         1873         137         9  67.92      0.25  458.4600
# 15 2023-01-16         1067         120         6  65.35      0.22  305.8380
# 16 2023-01-17         1440         174         6  59.83      0.29  254.8758
# 17 2023-01-18         1213         180         7  45.95      0.00  321.6500
# 18 2023-01-19         1284         164         2  51.83      0.30   72.5620
# 19 2023-01-20         1700         131         8  61.29      0.02  480.5136
# 20 2023-01-21         1392         182         6  55.84      0.18  274.7328
# 21 2023-01-22         1939         176         1  75.49      0.11   67.1861
# 22 2023-01-23         1878         145         8  16.92      0.06  127.2384
# 23 2023-01-24         1567         163         5  96.62      0.15  410.6350
# 24 2023-01-25         1511         127         1  94.89      0.09   86.3499
# 25 2023-01-26         1199         138         6  27.18      0.13  141.8796
# 26 2023-01-27         1129         164         6  23.73      0.22  111.0564
# 27 2023-01-28         1089         130         9  95.91      0.01  854.5581
# 28 2023-01-29         1737         183         4  38.60      0.10  138.9600
# 29 2023-01-30         1362         107         2  42.56      0.08   78.3104
# 30 2023-01-31         1010         163         1  54.53      0.27   39.8069
# 31 2023-02-01         1077         141         3  99.53      0.26  220.9566
# 32 2023-02-02         1493         180         6  66.08      0.07  368.7264
# 33 2023-02-03         1722         161         1  71.85      0.06   67.5390
# 34 2023-02-04         1367         199         5  42.55      0.27  155.3075
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          8   West           Cash      False              2            35
# 1          7   East           Cash       True              5            52
# 2          7   West    Credit Card       True              3            63
# 3          6  South    Credit Card      False              4            37
# 4          5   West           Cash      False              1            57
# 5          8   East           Cash      False              1            49
# 6          5  South         Online      False              1            44
# 7          1   East         Online      False              6            34
# 8          4   East         Online       True              2            49
# 9          1   West    Credit Card      False              5            29
# 10         7  South    Credit Card      False              1            30
# 11         4  South    Credit Card      False              5            65
# 12         7   West         Online      False              1            27
# 13         1  North           Cash       True              3            37
# 14         5   West    Credit Card      False              3            24
# 15         1  South         Online       True              3            32
# 16         3  South         Online       True              5            48
# 17         1   West           Cash      False              6            52
# 18         3   East           Cash       True              6            66
# 19         2   West           Cash      False              5            53
# 20         8   East           Cash       True              2            43
# 21         9  South         Online       True              2            65
# 22         1  North    Credit Card      False              1            44
# 23         2  North           Cash      False              4            68
# 24         5   West    Credit Card       True              2            50
# 25         2   East         Online       True              6            66
# 26         8  South           Cash       True              4            29
# 27         8  South         Online      False              1            49
# 28         4   West    Credit Card      False              5            24
# 29         5   West           Cash       True              5            59
# 30         6  North    Credit Card      False              3            52
# 31         3  South           Cash       True              2            21
# 32         2  South    Credit Card       True              5            35
# 33         8  South    Credit Card       True              6            64
# 34         6   East         Online      False              6            20
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     3.9  Not Returned  Negative            NaN
# 1   Female      Electronics     4.8      Returned   Neutral          15.40
# 2   Female             Food     2.6  Not Returned  Negative          17.84
# 3   Female             Food     2.0  Not Returned  Positive            NaN
# 4    Other             Food     1.5      Returned  Positive            NaN
# 5     Male      Electronics     1.3  Not Returned  Positive            NaN
# 6   Female         Clothing     3.3      Returned  Positive          19.53
# 7     Male             Food     2.6  Not Returned   Neutral          18.21
# 8   Female            Books     4.6      Returned  Positive          18.27
# 9     Male      Electronics     2.5  Not Returned  Positive           9.30
# 10    Male             Food     1.5  Not Returned  Negative          13.24
# 11    Male         Clothing     3.0  Not Returned  Positive           7.57
# 12  Female      Electronics     4.9  Not Returned  Negative          12.97
# 13    Male         Clothing     3.1      Returned   Neutral          11.91
# 14    Male             Food     1.7      Returned  Positive          18.55
# 15   Other             Food     2.2      Returned  Negative          13.29
# 16   Other             Food     1.0  Not Returned  Positive            NaN
# 17   Other      Electronics     3.3  Not Returned   Neutral          18.55
# 18    Male         Clothing     1.2  Not Returned  Positive           7.04
# 19   Other             Food     1.9  Not Returned   Neutral           5.91
# 20  Female      Electronics     3.6      Returned  Positive           6.43
# 21  Female             Food     1.1  Not Returned  Negative            NaN
# 22   Other             Food     3.8  Not Returned   Neutral           5.91
# 23    Male            Books     2.9      Returned  Positive          10.47
# 24  Female             Food     2.9  Not Returned  Negative          13.12
# 25  Female      Electronics     4.8      Returned   Neutral            NaN
# 26   Other         Clothing     1.2  Not Returned   Neutral          15.87
# 27    Male             Food     2.5  Not Returned  Negative           9.28
# 28  Female         Clothing     3.1  Not Returned  Negative           6.80
# 29    Male      Electronics     3.6  Not Returned   Neutral           5.49
# 30  Female         Clothing     1.3      Returned  Negative          16.02
# 31    Male      Electronics     2.9      Returned  Positive          19.67
# 32  Female            Books     3.7      Returned  Positive          14.19
# 33  Female         Clothing     2.4  Not Returned   Neutral           9.88
# 34  Female         Clothing     3.2  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0       SAVE10              2.3
# 1          nan              NaN
# 2          nan              2.9
# 3          nan              1.3
# 4     FREESHIP              3.9
# 5     WELCOME5              NaN
# 6          nan              4.1
# 7     FREESHIP              4.6
# 8     FREESHIP              NaN
# 9     WELCOME5              NaN
# 10      SAVE10              3.7
# 11    FREESHIP              4.0
# 12         nan              NaN
# 13         nan              2.5
# 14    FREESHIP              2.7
# 15         nan              1.1
# 16    WELCOME5              3.1
# 17    WELCOME5              4.5
# 18      SAVE10              2.6
# 19         nan              3.8
# 20    WELCOME5              3.1
# 21    FREESHIP              1.9
# 22         nan              3.2
# 23         nan              1.9
# 24         nan              1.0
# 25         nan              4.4
# 26    WELCOME5              1.5
# 27    WELCOME5              4.5
# 28    WELCOME5              3.5
# 29         nan              NaN
# 30      SAVE10              1.4
# 31      SAVE10              NaN
# 32    WELCOME5              NaN
# 33      SAVE10              3.7
# 34         nan              4.5

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 03:**
# </div>

# %%
# 3. Validating the Data Type of a Specific Column
# Write a Pandas program to validate the data type of a specific column in a DataFrame.

# Check if 'price' column is of type float
is_of_type = 'float64'
is_price_float = df['price'].dtype == is_of_type
is_price_float

# Validate the data type of 'price' column
if is_price_float:
    print("The 'price' column is of type {}.".format(df['price'].dtype))
else:
    print("The 'price' column is not of type {}, it is {}.".format(is_of_type, df['price'].dtype))
# Out:
# The 'price' column is of type float64.

# %% [markdown]
# <div class="alert alert-warning">
#
# **4. Checking Duplicate Rows in a DataFrame**
#
# **Write a Pandas program to check duplicate rows in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1482         110         1  48.76      0.03   47.2972
# 1  2023-01-02         1586         192         6  47.19      0.06  266.1516
# 2  2023-01-03         1717         185         9  21.36      0.14  165.3264
# 3  2023-01-04         1116         110         2  88.25      0.20  141.2000
# 4  2023-01-05         1900         122         1  67.99      0.01   67.3101
# 5  2023-01-06         1563         154         4  62.78      0.12  220.9856
# 6  2023-01-07         1224         127         1  38.45      0.26   28.4530
# 7  2023-01-08         1042         151         3  45.61      0.25  102.6225
# 8  2023-01-09         1251         103         1  79.77      0.26   59.0298
# 9  2023-01-10         1336         136         2  87.43      0.11  155.6254
# 10 2023-01-11         1216         131         9  89.59      0.13  701.4897
# 11 2023-01-12         1803         137         2  80.24      0.27  117.1504
# 12 2023-01-13         1922         158         1  69.72      0.27   50.8956
# 13 2023-01-14         1321         155         1  30.75      0.10   27.6750
# 14 2023-01-15         1716         170         5  68.44      0.15  290.8700
# 15 2023-01-16         1820         193         2  20.66      0.19   33.4692
# 16 2023-01-17         1828         134         1  13.75      0.06   12.9250
# 17 2023-01-18         1490         177         5  72.04      0.02  352.9960
# 18 2023-01-19         1552         101         5  69.74      0.07  324.2910
# 19 2023-01-20         1583         169         2  23.45      0.16   39.3960
# 20 2023-01-21         1971         124         9  43.57      0.17  325.4679
# 21 2023-01-22         1696         157         4  71.47      0.03  277.3036
# 22 2023-01-23         1447         168         6  75.96      0.30  319.0320
# 23 2023-01-24         1360         163         2  76.28      0.21  120.5224
# 24 2023-01-25         1947         104         2  17.13      0.14   29.4636
# 25 2023-01-26         1484         185         4  55.25      0.27  161.3300
# 26 2023-01-27         1464         176         3  47.40      0.07  132.2460
# 27 2023-01-28         1122         131         3  41.50      0.28   89.6400
# 28 2023-01-29         1980         107         9  72.88      0.13  570.6504
# 29 2023-01-30         1366         143         9  30.57      0.04  264.1248
# 30 2023-01-31         1878         147         9  36.21      0.14  280.2654
# 31 2023-02-01         1366         138         4  88.29      0.20  282.5280
# 32 2023-02-02         1008         111         7  80.70      0.11  502.7610
# 33 2023-02-03         1267         176         4  56.98      0.12  200.5696
# 34 2023-02-04         1943         159         1  97.54      0.14   83.8844
# 35 2023-01-27         1464         176         3  47.40      0.07  132.2460
# 36 2023-01-14         1321         155         1  30.75      0.10   27.6750
# 37 2023-01-25         1947         104         2  17.13      0.14   29.4636
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          6   East           Cash       True              1            24
# 1          9   East           Cash       True              5            64
# 2          7  North         Online      False              6            27
# 3          3  North           Cash      False              1            26
# 4          2  South           Cash      False              6            30
# 5          8   East    Credit Card      False              3            45
# 6          7   East           Cash      False              1            35
# 7          1   East           Cash      False              2            46
# 8          5   West           Cash      False              3            43
# 9          9   East           Cash      False              2            21
# 10         9  North           Cash       True              1            23
# 11         7   West         Online       True              5            48
# 12         4   West         Online       True              6            53
# 13         3  South         Online      False              2            50
# 14         1   West           Cash       True              5            20
# 15         4   West           Cash       True              4            19
# 16         7   East    Credit Card      False              5            25
# 17         2  North           Cash       True              1            66
# 18         3  South    Credit Card       True              1            41
# 19         6  South    Credit Card       True              6            28
# 20         8   East           Cash       True              2            68
# 21         7  South           Cash       True              2            42
# 22         4  North    Credit Card      False              5            67
# 23         7  North    Credit Card      False              4            66
# 24         8   West    Credit Card       True              1            51
# 25         9   West    Credit Card      False              3            21
# 26         5   East           Cash      False              6            52
# 27         1   West           Cash       True              4            22
# 28         6  North    Credit Card       True              3            18
# 29         5   West         Online       True              6            62
# 30         7   West    Credit Card       True              4            45
# 31         5  North    Credit Card      False              4            28
# 32         3  South         Online      False              5            41
# 33         5   East         Online      False              3            31
# 34         1   East           Cash       True              4            41
# 35         5   East           Cash      False              6            52
# 36         3  South         Online      False              2            50
# 37         8   West    Credit Card       True              1            51
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other            Books     2.3  Not Returned  Positive           9.75
# 1    Other      Electronics     3.2  Not Returned  Negative          17.69
# 2    Other         Clothing     2.2  Not Returned  Negative          12.11
# 3    Other            Books     3.1      Returned  Negative          17.88
# 4     Male             Food     1.3      Returned  Positive          13.93
# 5   Female            Books     1.6  Not Returned  Negative          13.08
# 6    Other            Books     2.5      Returned   Neutral           9.03
# 7    Other             Food     1.2      Returned  Positive           6.50
# 8   Female            Books     2.1      Returned  Positive          18.59
# 9     Male             Food     4.6      Returned  Negative            NaN
# 10  Female             Food     2.2  Not Returned   Neutral            NaN
# 11  Female         Clothing     3.6      Returned  Negative          12.54
# 12  Female      Electronics     3.9  Not Returned  Negative          10.90
# 13   Other      Electronics     4.4  Not Returned   Neutral          19.64
# 14  Female             Food     2.6      Returned   Neutral            NaN
# 15   Other             Food     3.8      Returned  Negative          16.81
# 16  Female         Clothing     5.0      Returned  Negative          12.04
# 17   Other             Food     3.9  Not Returned  Positive          17.62
# 18    Male         Clothing     4.6      Returned  Negative           7.21
# 19   Other         Clothing     4.4  Not Returned   Neutral            NaN
# 20    Male             Food     1.4      Returned  Positive          11.97
# 21  Female         Clothing     3.0      Returned  Positive          19.29
# 22  Female            Books     4.7  Not Returned  Negative           5.01
# 23   Other         Clothing     3.7  Not Returned  Positive          14.38
# 24   Other         Clothing     4.2  Not Returned  Positive          12.32
# 25  Female             Food     1.7  Not Returned   Neutral            NaN
# 26   Other         Clothing     1.8      Returned  Positive           8.95
# 27    Male             Food     3.2      Returned   Neutral          11.40
# 28   Other            Books     1.6  Not Returned  Positive          11.35
# 29    Male            Books     4.5  Not Returned  Positive          18.85
# 30   Other             Food     1.8      Returned   Neutral            NaN
# 31    Male         Clothing     1.0      Returned  Positive           7.37
# 32   Other             Food     1.6      Returned   Neutral            NaN
# 33   Other             Food     3.8      Returned  Negative          15.86
# 34  Female      Electronics     1.8      Returned  Positive          19.09
# 35   Other         Clothing     1.8      Returned  Positive           8.95
# 36   Other      Electronics     4.4  Not Returned   Neutral          19.64
# 37   Other         Clothing     4.2  Not Returned  Positive          12.32
#
#    coupon_code  delivery_rating
# 0          nan              4.0
# 1          nan              4.2
# 2       SAVE10              4.9
# 3     WELCOME5              3.4
# 4          nan              3.3
# 5     WELCOME5              NaN
# 6          nan              NaN
# 7          nan              1.1
# 8          nan              1.3
# 9          nan              1.2
# 10    FREESHIP              NaN
# 11    WELCOME5              2.4
# 12    WELCOME5              NaN
# 13         nan              NaN
# 14    WELCOME5              3.4
# 15      SAVE10              3.9
# 16      SAVE10              NaN
# 17         nan              NaN
# 18         nan              3.6
# 19         nan              NaN
# 20    FREESHIP              NaN
# 21         nan              NaN
# 22         nan              1.5
# 23         nan              3.5
# 24         nan              NaN
# 25    FREESHIP              1.7
# 26      SAVE10              4.7
# 27      SAVE10              3.6
# 28         nan              1.5
# 29    FREESHIP              NaN
# 30    FREESHIP              3.6
# 31         nan              4.0
# 32         nan              NaN
# 33    WELCOME5              NaN
# 34         nan              3.1
# 35      SAVE10              4.7
# 36         nan              NaN
# 37         nan              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
# 4. Checking Duplicate Rows in a DataFrame
# Write a Pandas program to check duplicate rows in a DataFrame.

# Check for duplicate rows
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 35 2023-01-27         1464         176         3  47.40      0.07  132.2460
# 36 2023-01-14         1321         155         1  30.75      0.10   27.6750
# 37 2023-01-25         1947         104         2  17.13      0.14   29.4636
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
#
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          1   West         Online       True              3            22
# 1          7  South           Cash       True              4            54
# 2          8  South         Online       True              6            39
# 3          2  North    Credit Card       True              2            35
# 4          6  North           Cash       True              2            43
# 5          7   East           Cash      False              4            42
# 6          9   West         Online      False              2            26
# 7          6   West           Cash       True              4            22
# 8          3   West           Cash      False              2            64
# 9          2   West           Cash      False              6            26
# 10         2  South    Credit Card       True              1            58
# 11         1   East    Credit Card       True              6            37
# 12         1   West           Cash       True              5            36
# 13         7   East           Cash       True              1            40
# 14         3   West    Credit Card       True              3            35
# 15         6   East         Online      False              4            63
# 16         6  North           Cash      False              3            31
# 17         1   East           Cash       True              3            61
# 18         9  North           Cash       True              2            27
# 19         4   West           Cash       True              1            42
# 20         2   East           Cash       True              1            62
# 21         3  South    Credit Card      False              5            39
# 22         3   East           Cash      False              2            27
# 23         6   East         Online       True              2            27
# 24         8   West         Online       True              4            33
# 25         5  North           Cash       True              5            48
# 26         7  North    Credit Card       True              1            32
# 27         9   West           Cash       True              6            38
# 28         4   East         Online      False              3            24
# 29         2   West         Online       True              4            54
# 30         6   West    Credit Card       True              2            50
# 31         4   East         Online      False              4            52
# 32         9  South    Credit Card      False              2            26
# 33         3   West           Cash       True              5            29
# 34         2   East           Cash      False              1            67
# 35         7  North    Credit Card       True              1            32
# 36         7   East           Cash       True              1            40
# 37         8   West         Online       True              4            33
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other      Electronics     2.0  Not Returned  Negative          17.27
# 1   Female         Clothing     2.9  Not Returned  Positive          15.03
# 2   Female            Books     4.5      Returned   Neutral           8.27
# 3     Male            Books     1.9      Returned   Neutral          13.59
# 4    Other            Books     4.2  Not Returned  Negative            NaN
# 5    Other      Electronics     1.3      Returned   Neutral            NaN
# 6     Male            Books     4.9  Not Returned  Negative           9.46
# 7    Other             Food     3.2  Not Returned  Positive          17.02
# 8   Female             Food     3.4      Returned   Neutral           7.76
# 9    Other         Clothing     1.1      Returned   Neutral            NaN
# 10    Male            Books     3.8      Returned  Negative           6.51
# 11    Male             Food     2.9  Not Returned  Positive          14.02
# 12  Female      Electronics     1.9      Returned  Negative          13.70
# 13  Female      Electronics     3.6      Returned  Positive            NaN
# 14    Male            Books     4.0  Not Returned   Neutral          11.29
# 15  Female             Food     4.4      Returned  Negative          18.95
# 16  Female         Clothing     3.2      Returned   Neutral          17.70
# 17  Female             Food     2.0      Returned   Neutral            NaN
# 18   Other             Food     4.8  Not Returned  Negative          17.61
# 19   Other             Food     2.4  Not Returned  Negative            NaN
# 20  Female         Clothing     2.7  Not Returned  Positive          16.59
# 21  Female             Food     4.7      Returned  Negative          11.77
# 22   Other            Books     1.1      Returned   Neutral           8.42
# 23    Male      Electronics     4.6      Returned  Positive           5.15
# 24    Male            Books     2.6  Not Returned  Positive          14.53
# 25   Other      Electronics     4.6      Returned   Neutral           9.82
# 26    Male            Books     1.8      Returned  Negative            NaN
# 27    Male      Electronics     2.7      Returned  Negative          19.68
# 28  Female            Books     4.5  Not Returned  Positive          12.88
# 29    Male             Food     4.4  Not Returned  Positive          19.06
# 30   Other             Food     4.7  Not Returned  Negative            NaN
# 31    Male      Electronics     3.3      Returned  Positive          17.67
# 32    Male         Clothing     3.8  Not Returned  Positive          11.70
# 33    Male      Electronics     1.2      Returned  Negative          14.00
# 34   Other      Electronics     3.7      Returned  Positive           7.37
# 35    Male            Books     1.8      Returned  Negative            NaN
# 36  Female      Electronics     3.6      Returned  Positive            NaN
# 37    Male            Books     2.6  Not Returned  Positive          14.53
#
#    coupon_code  delivery_rating
# 0     FREESHIP              NaN
# 1     WELCOME5              2.4
# 2          nan              1.7
# 3     FREESHIP              4.2
# 4     FREESHIP              2.4
# 5     FREESHIP              NaN
# 6          nan              3.5
# 7          nan              2.1
# 8       SAVE10              4.9
# 9          nan              NaN
# 10         nan              NaN
# 11         nan              3.1
# 12      SAVE10              4.1
# 13    FREESHIP              3.4
# 14         nan              NaN
# 15         nan              NaN
# 16    FREESHIP              4.3
# 17    WELCOME5              1.1
# 18    FREESHIP              3.4
# 19      SAVE10              3.6
# 20    FREESHIP              4.6
# 21    FREESHIP              1.5
# 22         nan              NaN
# 23    FREESHIP              NaN
# 24    FREESHIP              2.5
# 25    WELCOME5              3.6
# 26      SAVE10              2.3
# 27      SAVE10              4.6
# 28         nan              2.4
# 29         nan              1.1
# 30         nan              NaN
# 31    WELCOME5              4.4
# 32         nan              3.5
# 33         nan              3.3
# 34    FREESHIP              1.4
# 35      SAVE10              2.3
# 36    FREESHIP              3.4
# 37    FREESHIP              2.5

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
# 5. Removing Duplicate Rows from a DataFrame
# Write a Pandas program to remove duplicate rows from a DataFrame.

print("Shape of DataFrame before removing duplicates:\n", df.shape)
# Remove duplicate rows
df = df.drop_duplicates()
print("Shape of DataFrame after removing duplicates:\n", df.shape)
# Out:
# Shape of DataFrame before removing duplicates:
#  (38, 21)
# Shape of DataFrame after removing duplicates:
#  (35, 21)

# %% [markdown]
# <div class="alert alert-warning">
#
# **6. Validating Data Based on Custom Conditions**
#
# **Write a Pandas program to validate data based on custom conditions.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1819         173         6  64.90      0.19  315.4140
# 1  2023-01-02         1977         116         1  52.17      0.27   38.0841
# 2  2023-01-03         1763         168         8  12.34      0.03   95.7584
# 3  2023-01-04         1888         141         2  47.76      0.20   76.4160
# 4  2023-01-05         1632         176         6  51.66      0.06  291.3624
# 5  2023-01-06         1110         176         5  55.07      0.07  256.0755
# 6  2023-01-07         1207         189         1  41.10      0.01   40.6890
# 7  2023-01-08         1284         116         4  28.12      0.05  106.8560
# 8  2023-01-09         1429         143         8  12.06      0.08   88.7616
# 9  2023-01-10         1029         142         1  18.46      0.15   15.6910
# 10 2023-01-11         1963         130         1  29.12      0.15   24.7520
# 11 2023-01-12         1061         127         1  28.93      0.18   23.7226
# 12 2023-01-13         1040         186         8  38.37      0.22  239.4288
# 13 2023-01-14         1207         187         2  23.75      0.18   38.9500
# 14 2023-01-15         1155         178         1  21.35      0.03   20.7095
# 15 2023-01-16         1974         146         4  49.94      0.14  171.7936
# 16 2023-01-17         1196         153         8  58.37      0.10  420.2640
# 17 2023-01-18         1156         138         2  40.30      0.23   62.0620
# 18 2023-01-19         1429         123         3  10.88      0.25   24.4800
# 19 2023-01-20         1143         105         2  11.18      0.26   16.5464
# 20 2023-01-21         1700         146         4  67.92      0.30  190.1760
# 21 2023-01-22         1252         168         8  57.95      0.13  403.3320
# 22 2023-01-23         1952         171         8  13.68      0.08  100.6848
# 23 2023-01-24         1370         124         5  52.81      0.02  258.7690
# 24 2023-01-25         1112         151         4  85.32      0.16  286.6752
# 25 2023-01-26         1509         154         7  30.55      0.11  190.3265
# 26 2023-01-27         1540         101         7  69.83      0.28  351.9432
# 27 2023-01-28         1606         174         4  60.90      0.18  199.7520
# 28 2023-01-29         1459         176         8  11.60      0.01   91.8720
# 29 2023-01-30         1881         147         1  58.20      0.12   51.2160
# 30 2023-01-31         1881         168         1  41.54      0.25   31.1550
# 31 2023-02-01         1582         133         9  69.11      0.03  603.3303
# 32 2023-02-02         1159         103         2  30.12      0.05   57.2280
# 33 2023-02-03         1329         158         5  96.03      0.26  355.3110
# 34 2023-02-04         1062         182         6  57.97      0.10  313.0380
# 35 2023-01-27         1540         101         7  69.83      0.28  351.9432
# 36 2023-01-14         1207         187         2  23.75      0.18   38.9500
# 37 2023-01-25         1112         151         4  85.32      0.16  286.6752
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          7   East         Online      False              5            43
# 1          7   East           Cash      False              5            64
# 2          1   East           Cash      False              1            27
# 3          1   West           Cash       True              3            69
# 4          5  South         Online      False              2            41
# 5          1   West           Cash      False              6            54
# 6          1  North    Credit Card       True              5            52
# 7          4  South         Online       True              5            49
# 8          3   West    Credit Card      False              2            61
# 9          9   East           Cash       True              4            52
# 10         6   West    Credit Card       True              1            35
# 11         7   West         Online       True              5            32
# 12         3  South         Online      False              6            59
# 13         6  South    Credit Card       True              6            24
# 14         1  North         Online      False              4            34
# 15         4   East         Online       True              3            54
# 16         3  North           Cash      False              6            66
# 17         2  South           Cash       True              5            31
# 18         5  North    Credit Card       True              1            21
# 19         3  South    Credit Card       True              4            36
# 20         9   West    Credit Card       True              4            67
# 21         8   East           Cash       True              3            56
# 22         7   West         Online       True              3            64
# 23         5  South    Credit Card      False              6            23
# 24         5   East    Credit Card      False              2            19
# 25         9  North         Online       True              6            49
# 26         5   West           Cash       True              4            49
# 27         7   East    Credit Card      False              2            57
# 28         8   East    Credit Card      False              1            40
# 29         3   West    Credit Card      False              5            31
# 30         8  North           Cash      False              1            27
# 31         7  North    Credit Card      False              3            67
# 32         9   East           Cash      False              4            27
# 33         5   West           Cash      False              3            57
# 34         2   West    Credit Card       True              5            57
# 35         5   West           Cash       True              4            49
# 36         6  South    Credit Card       True              6            24
# 37         5   East    Credit Card      False              2            19
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female             Food     1.1  Not Returned  Positive           7.32
# 1   Female         Clothing     1.1  Not Returned   Neutral          18.00
# 2   Female      Electronics     3.0  Not Returned  Negative          19.15
# 3     Male         Clothing     3.0      Returned  Negative          10.47
# 4    Other         Clothing     2.2  Not Returned  Positive            NaN
# 5    Other            Books     4.4  Not Returned   Neutral           9.02
# 6     Male      Electronics     3.6  Not Returned   Neutral           5.79
# 7   Female            Books     4.0      Returned  Negative          12.32
# 8    Other      Electronics     4.7      Returned  Positive          19.83
# 9   Female      Electronics     1.9  Not Returned  Positive          11.18
# 10    Male            Books     3.4      Returned  Positive          12.24
# 11  Female            Books     1.5  Not Returned  Positive          13.19
# 12  Female             Food     4.0      Returned  Negative          17.00
# 13  Female             Food     4.1      Returned   Neutral          13.63
# 14   Other         Clothing     4.2  Not Returned  Positive            NaN
# 15  Female      Electronics     2.1  Not Returned   Neutral           6.48
# 16   Other            Books     4.8      Returned   Neutral           5.12
# 17   Other         Clothing     3.2      Returned  Negative            NaN
# 18   Other             Food     3.0  Not Returned  Negative          18.05
# 19  Female         Clothing     4.8  Not Returned  Negative          16.09
# 20   Other         Clothing     1.0  Not Returned  Positive           9.70
# 21   Other             Food     3.0      Returned  Positive           9.29
# 22  Female      Electronics     2.5  Not Returned  Negative           7.18
# 23  Female         Clothing     3.9  Not Returned  Negative           9.51
# 24  Female      Electronics     1.4  Not Returned  Negative          17.16
# 25   Other            Books     1.4  Not Returned  Negative          18.16
# 26    Male         Clothing     4.3  Not Returned  Negative            NaN
# 27    Male            Books     3.4      Returned   Neutral          14.10
# 28    Male            Books     1.3      Returned  Negative          18.41
# 29   Other             Food     1.7      Returned   Neutral            NaN
# 30   Other      Electronics     4.3      Returned  Negative            NaN
# 31   Other         Clothing     5.0      Returned   Neutral           5.89
# 32  Female         Clothing     4.8  Not Returned  Positive           8.30
# 33   Other         Clothing     3.0  Not Returned   Neutral          10.53
# 34   Other            Books     2.6      Returned  Negative          18.67
# 35    Male         Clothing     4.3  Not Returned  Negative            NaN
# 36  Female             Food     4.1      Returned   Neutral          13.63
# 37  Female      Electronics     1.4  Not Returned  Negative          17.16
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0       SAVE10              4.7
# 1          nan              2.0
# 2          nan              NaN
# 3     WELCOME5              NaN
# 4     FREESHIP              3.4
# 5          nan              3.7
# 6     FREESHIP              2.6
# 7     FREESHIP              NaN
# 8          nan              3.9
# 9       SAVE10              NaN
# 10    FREESHIP              3.5
# 11    WELCOME5              NaN
# 12      SAVE10              NaN
# 13      SAVE10              2.0
# 14      SAVE10              NaN
# 15      SAVE10              4.5
# 16    FREESHIP              4.7
# 17    FREESHIP              1.5
# 18    FREESHIP              4.4
# 19         nan              4.4
# 20    FREESHIP              1.0
# 21         nan              4.2
# 22    FREESHIP              2.8
# 23         nan              4.1
# 24         nan              4.8
# 25      SAVE10              2.4
# 26         nan              NaN
# 27    WELCOME5              NaN
# 28    WELCOME5              4.4
# 29         nan              3.5
# 30         nan              2.2
# 31      SAVE10              1.3
# 32         nan              NaN
# 33    WELCOME5              3.6
# 34      SAVE10              NaN
# 35         nan              NaN
# 36      SAVE10              2.0
# 37         nan              4.8
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 06:**
# </div>

# %%
# 6. Validating Data Based on Custom Conditions
# Write a Pandas program to validate data based on custom conditions.

# Check if 'price' is greater than 0
valid_price = df['price'] > 0
if valid_price.all():
    print("All prices are valid.")
else:
    print("Some prices are invalid:")
    display(df[~valid_price])
# Out:
# Some prices are invalid:
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN
