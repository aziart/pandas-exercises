# 20         2  South    Credit Card       True              5            30
# 21         7   West           Cash      False              6            53
# 22         1   East         Online      False              3            25
# 23         7  South           Cash       True              1            44
# 24         5   West           Cash       True              4            51
# 25         6  North           Cash       True              4            32
# 26         3  North    Credit Card       True              2            64
# 27         4   West    Credit Card       True              1            36
# 28         8  North           Cash      False              4            22
# 29         1  South           Cash       True              4            34
# 30         3   West           Cash       True              5            51
# 31         6   West           Cash      False              5            55
# 32         9   East         Online      False              2            51
# 33         4  South           Cash       True              5            58
# 34         7  South    Credit Card      False              3            51
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female         Clothing     3.4  Not Returned   Neutral           8.29
# 1    Other             Food     2.8  Not Returned  Positive          18.87
# 2     Male             Food     2.4  Not Returned  Negative            NaN
# 3     Male      Electronics     2.6  Not Returned   Neutral          18.04
# 4     Male             Food     2.5  Not Returned   Neutral          15.79
# 5   Female         Clothing     3.1  Not Returned  Positive          12.56
# 6    Other            Books     1.6      Returned   Neutral          19.37
# 7    Other         Clothing     2.9  Not Returned   Neutral          13.63
# 8     Male         Clothing     1.4  Not Returned  Positive          10.29
# 9   Female         Clothing     1.9  Not Returned  Negative          16.28
# 10  Female         Clothing     3.7      Returned  Negative           6.85
# 11    Male             Food     4.8      Returned  Negative          15.99
# 12    Male            Books     2.2      Returned  Positive            NaN
# 13  Female         Clothing     3.0      Returned  Negative           9.42
# 14   Other             Food     4.0  Not Returned  Positive            NaN
# 15    Male             Food     3.8  Not Returned  Negative          19.98
# 16  Female             Food     3.2      Returned  Positive          15.15
# 17    Male         Clothing     2.5      Returned  Positive          16.47
# 18   Other            Books     4.4      Returned  Positive          18.74
# 19   Other      Electronics     1.8  Not Returned  Positive           8.28
# 20   Other      Electronics     3.7  Not Returned  Positive           5.82
# 21   Other             Food     3.1      Returned  Positive          19.49
# 22  Female            Books     2.9  Not Returned  Negative            NaN
# 23    Male             Food     2.0  Not Returned   Neutral           5.46
# 24    Male            Books     1.0      Returned  Negative            NaN
# 25  Female         Clothing     1.7      Returned  Positive          11.94
# 26  Female         Clothing     2.3      Returned  Negative          11.78
# 27  Female            Books     4.5  Not Returned   Neutral          11.94
# 28    Male      Electronics     1.0      Returned  Negative          16.47
# 29  Female      Electronics     3.1      Returned  Positive          12.27
# 30  Female             Food     2.2      Returned  Positive          14.07
# 31  Female         Clothing     2.3  Not Returned  Negative            NaN
# 32  Female            Books     3.8      Returned   Neutral          13.35
# 33    Male             Food     3.1  Not Returned  Positive            NaN
# 34  Female            Books     2.3      Returned  Positive          14.09
#
#    coupon_code  delivery_rating
# 0       SAVE10              NaN
# 1          nan              2.9
# 2       SAVE10              1.1
# 3     FREESHIP              3.3
# 4     FREESHIP              NaN
# 5     FREESHIP              3.4
# 6     FREESHIP              3.7
# 7     FREESHIP              1.4
# 8     WELCOME5              1.1
# 9       SAVE10              1.0
# 10    WELCOME5              4.1
# 11         nan              4.1
# 12      SAVE10              2.6
# 13    FREESHIP              3.1
# 14    WELCOME5              NaN
# 15      SAVE10              NaN
# 16    WELCOME5              1.8
# 17         nan              NaN
# 18    FREESHIP              4.1
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          3  South           Cash      False              1            66
# 1          9  South           Cash      False              1            38
# 2          9  North    Credit Card       True              3            41
# 3          4  South    Credit Card      False              3            36
# 4          1   East    Credit Card       True              6            51
# 5          2  South         Online       True              4            53
# 6          8   West           Cash       True              1            38
# 7          9  North           Cash      False              4            47
# 8          3  South         Online       True              4            68
# 9          5  North           Cash       True              1            69
# 10         3  North         Online       True              4            38
# 11         4  North         Online       True              4            34
# 12         4   West           Cash       True              3            50
# 13         6   East         Online       True              4            46
# 14         7  North    Credit Card      False              1            64
# 15         4   East    Credit Card      False              1            41
# 16         2  North           Cash       True              5            51
# 17         8   West    Credit Card      False              6            49
# 18         5  North    Credit Card       True              2            22
# 19         4   East           Cash      False              5            21
# 20         1  South         Online       True              2            46
# 21         1  North    Credit Card      False              3            51
# 22         1   East         Online       True              3            54
# 23         2   East         Online       True              6            54
# 24         7   East    Credit Card       True              6            45
# 25         6  South           Cash       True              3            30
# 26         4   West           Cash      False              1            20
# 27         1   West    Credit Card      False              5            53
# 28         2   East         Online       True              3            36
# 29         9  South    Credit Card       True              6            29
# 30         7  South         Online       True              3            65
# 31         2   East         Online       True              3            54
# 32         1   East         Online       True              4            46
# 33         1   West           Cash       True              4            26
# 34         4  North         Online       True              4            37
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other            Books     1.5  Not Returned   Neutral           7.39
# 1    Other             Food     1.5  Not Returned  Negative          11.72
# 2     Male            Books     5.0      Returned  Negative           8.64
# 3     Male             Food     5.0  Not Returned  Negative            NaN
# 4    Other         Clothing     2.3      Returned  Positive          18.69
# 5    Other         Clothing     2.1  Not Returned  Positive           7.13
# 6   Female         Clothing     1.3  Not Returned   Neutral            NaN
# 7     Male      Electronics     4.8  Not Returned  Negative           6.20
# 8     Male            Books     3.6  Not Returned  Positive           9.56
# 9   Female            Books     1.7  Not Returned  Negative           8.82
# 10   Other         Clothing     4.2  Not Returned  Negative            NaN
# 11   Other      Electronics     4.4      Returned  Negative           7.10
# 12   Other      Electronics     4.8  Not Returned  Negative          11.24
# 13    Male            Books     2.9      Returned   Neutral          11.70
# 14   Other            Books     3.9      Returned  Positive          15.51
# 15    Male      Electronics     2.6  Not Returned  Negative          19.46
# 16   Other            Books     2.7  Not Returned   Neutral          15.72
# 17    Male             Food     1.5      Returned  Positive          16.39
# 18   Other         Clothing     4.5      Returned  Negative          14.92
# 19   Other             Food     4.1  Not Returned  Negative          16.39
# 20  Female             Food     2.8      Returned  Positive          11.76
# 21  Female         Clothing     3.4      Returned  Negative           9.43
# 22  Female            Books     4.9      Returned   Neutral           7.42
# 23    Male      Electronics     3.8  Not Returned  Negative          13.63
# 24  Female      Electronics     2.7      Returned  Positive          16.11
# 25  Female      Electronics     1.8      Returned   Neutral          19.90
# 26   Other         Clothing     4.1  Not Returned  Positive           8.41
# 27  Female            Books     3.7  Not Returned  Negative          10.01
# 28   Other            Books     4.9  Not Returned  Negative          15.07
# 29   Other             Food     2.1      Returned   Neutral           7.33
# 30   Other            Books     4.9      Returned  Positive          13.79
# 31   Other      Electronics     2.8  Not Returned  Positive           5.66
# 32    Male             Food     1.2  Not Returned  Positive            NaN
# 33    Male             Food     4.2  Not Returned   Neutral          19.81
# 34   Other      Electronics     1.6      Returned  Negative          18.03
#
#    coupon_code  delivery_rating
# 0     FREESHIP              NaN
# 1       SAVE10              4.5
# 2       SAVE10              NaN
# 3       SAVE10              NaN
# 4       SAVE10              4.7
# 5       SAVE10              2.5
# 6          nan              2.0
# 7     FREESHIP              4.5
# 8     WELCOME5              4.4
# 9          nan              1.5
# 10    WELCOME5              4.1
# 11    FREESHIP              4.2
# 12         nan              1.2
# 13         nan              1.3
# 14    WELCOME5              NaN
# 15    WELCOME5              3.6
# 16    FREESHIP              2.1
# 17      SAVE10              2.2
# 18         nan              4.6
# 19    WELCOME5              4.3
# 20         nan              2.8
# 21         nan              NaN
# 22      SAVE10              2.4
# 23         nan              NaN
# 24      SAVE10              2.8
# 25         nan              2.9
# 26      SAVE10              1.4
# 27    FREESHIP              NaN
# 28    WELCOME5              NaN
# 29      SAVE10              NaN
# 30         nan              NaN
# 31         nan              NaN
# 32    WELCOME5              4.7
# 33    WELCOME5              3.0
# 34      SAVE10              5.0

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 02:**
# </div>

# %%
# 2. Ensuring Consistent Data Types of All Columns
# Write a Pandas program to check and ensure that the data types of all columns are consistent.

# Check data types
data_types = df.dtypes
data_types
# Out:
# date                datetime64[ns]
# customer_id                  int64
# product_id                   int64
# quantity                     int64
# price                      float64
# discount                   float64
# revenue                    float64
# store_id                     int64
# region                      object
# payment_method              object
# is_member                     bool
# delivery_days                int64
# customer_age                 int64
# gender                      object
# product_category            object
# rating                     float64
# return_status               object
# feedback                    object
# shipping_cost              float64
# coupon_code                 object
# delivery_rating            float64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning">
#
# **3. Validating the Data Type of a Specific Column**
#
# **Write a Pandas program to validate the data type of a specific column in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1423         105         9  92.88      0.13  727.2504
# 1  2023-01-02         1930         134         5  65.43      0.02  320.6070
# 2  2023-01-03         1874         169         8  14.34      0.06  107.8368
# 3  2023-01-04         1498         106         7  95.08      0.18  545.7592
# 4  2023-01-05         1536         186         3  10.62      0.20   25.4880
# 5  2023-01-06         1551         175         3  62.11      0.23  143.4741
# 6  2023-01-07         1816         103         8  79.47      0.01  629.4024
# 7  2023-01-08         1921         161         8  56.20      0.08  413.6320
# 8  2023-01-09         1148         116         8  73.09      0.06  549.6368
# 9  2023-01-10         1644         123         1  44.92      0.03   43.5724
# 10 2023-01-11         1096         110         7  24.34      0.13  148.2306
# 11 2023-01-12         1524         120         2  24.15      0.21   38.1570
# 12 2023-01-13         1031         133         3  90.79      0.01  269.6463
# 13 2023-01-14         1118         144         1  69.67      0.02   68.2766
# 14 2023-01-15         1136         160         8  23.54      0.22  146.8896
# 15 2023-01-16         1526         106         3  76.69      0.29  163.3497
# 16 2023-01-17         1912         128         7  43.25      0.30  211.9250
# 17 2023-01-18         1709         150         8  70.71      0.02  554.3664
# 18 2023-01-19         1358         194         6  41.27      0.29  175.8102
# 19 2023-01-20         1209         156         2  67.45      0.05  128.1550
# 20 2023-01-21         1141         112         8  55.92      0.25  335.5200
# 21 2023-01-22         1406         111         1  33.05      0.10   29.7450
# 22 2023-01-23         1410         111         3  34.44      0.08   95.0544
# 23 2023-01-24         1161         178         7  40.22      0.24  213.9704
# 24 2023-01-25         1639         176         3  18.50      0.15   47.1750
# 25 2023-01-26         1794         114         4  21.91      0.04   84.1344
# 26 2023-01-27         1052         110         2  39.68      0.12   69.8368
# 27 2023-01-28         1731         160         2  51.95      0.30   72.7300
# 28 2023-01-29         1032         116         8  59.87      0.19  387.9576
# 29 2023-01-30         1165         133         5  68.37      0.22  266.6430
# 30 2023-01-31         1694         151         7  76.75      0.17  445.9175
# 31 2023-02-01         1515         140         2  15.15      0.01   29.9970
# 32 2023-02-02         1636         161         2  99.52      0.25  149.2800
# 33 2023-02-03         1341         130         3  52.30      0.05  149.0550
# 34 2023-02-04         1344         140         1  17.00      0.05   16.1500
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          4  South    Credit Card       True              2            36
# 1          3  North           Cash       True              6            36
# 2          8  South           Cash      False              1            39
# 3          1   West         Online       True              6            25
# 4          7   East         Online      False              4            57
# 5          3   East    Credit Card       True              2            56
# 6          2   West         Online       True              3            53
# 7          2  North           Cash       True              2            48
# 8          4  South           Cash      False              6            29
# 9          8   West           Cash       True              2            48
# 10         2   East         Online       True              4            26
# 11         2  North         Online      False              2            48
# 12         1   West    Credit Card       True              3            57
# 13         9   East    Credit Card       True              2            18
# 14         7  North           Cash       True              4            59
# 15         8   West    Credit Card      False              2            40
# 16         7  North           Cash       True              5            57
# 17         5  South    Credit Card      False              2            31
# 18         9  North           Cash       True              2            45
# 19         8  North    Credit Card      False              3            19
# 20         8  North           Cash      False              4            56
# 21         1   East    Credit Card       True              5            67
# 22         2  South         Online      False              6            65
# 23         6   West    Credit Card      False              3            26
# 24         9  South         Online       True              2            49
# 25         9  North           Cash       True              3            45
# 26         5   East         Online      False              1            57
# 27         8  North           Cash       True              1            41
# 28         3   East           Cash      False              2            18
# 29         8   West         Online      False              4            53
# 30         2  North           Cash      False              3            21
# 31         2  South         Online       True              1            60
# 32         8  South    Credit Card       True              1            57
# 33         4   East    Credit Card       True              4            41
# 34         2   East           Cash       True              5            52
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female         Clothing     4.7  Not Returned  Positive          18.96
# 1    Other             Food     4.1      Returned  Positive          12.50
# 2   Female            Books     4.6      Returned  Negative           8.09
# 3    Other      Electronics     2.4      Returned   Neutral          19.16
# 4    Other      Electronics     4.7  Not Returned  Positive          16.09
# 5    Other            Books     4.9  Not Returned  Negative           7.69
# 6   Female      Electronics     3.3  Not Returned  Positive           6.18
# 7    Other            Books     4.0  Not Returned   Neutral            NaN
# 8    Other      Electronics     1.6      Returned  Positive           8.81
# 9     Male             Food     4.1      Returned  Negative            NaN
# 10    Male         Clothing     3.8      Returned  Positive            NaN
# 11    Male      Electronics     1.3      Returned   Neutral           5.81
# 12    Male            Books     2.5      Returned   Neutral          19.78
# 13  Female             Food     2.7      Returned  Positive          17.78
# 14  Female            Books     1.2  Not Returned   Neutral           5.94
# 15  Female      Electronics     3.0      Returned  Positive           8.73
# 16    Male             Food     1.1  Not Returned  Negative          12.72
# 17   Other             Food     2.2      Returned   Neutral            NaN
# 18   Other         Clothing     3.9  Not Returned  Positive           6.13
# 19  Female      Electronics     3.7      Returned  Positive            NaN
# 20    Male         Clothing     3.1      Returned   Neutral            NaN
# 21   Other            Books     4.2  Not Returned   Neutral          12.09
# 22  Female      Electronics     2.4      Returned   Neutral           9.47
# 23  Female      Electronics     4.8      Returned   Neutral            NaN
# 24  Female             Food     2.4  Not Returned  Negative           5.05
# 25    Male            Books     2.0  Not Returned   Neutral          19.92
# 26    Male         Clothing     4.3  Not Returned   Neutral          10.54
# 27   Other            Books     3.3  Not Returned  Negative            NaN
# 28    Male            Books     1.7      Returned   Neutral          13.26
# 29    Male            Books     3.8      Returned  Positive          11.44
# 30    Male      Electronics     1.9      Returned   Neutral          15.83
# 31    Male         Clothing     1.6      Returned   Neutral          10.26
# 32    Male      Electronics     2.5      Returned   Neutral          17.03
# 33  Female      Electronics     4.4      Returned  Negative            NaN
# 34  Female            Books     3.2  Not Returned   Neutral          16.28
#
#    coupon_code  delivery_rating
# 0          nan              3.6
# 1          nan              1.3
# 2     WELCOME5              NaN
# 3       SAVE10              2.8
# 4       SAVE10              3.3
# 5          nan              1.7
# 6     WELCOME5              NaN
# 7     WELCOME5              NaN
# 8     FREESHIP              3.1
# 9          nan              2.4
# 10      SAVE10              1.8
# 11      SAVE10              2.8
# 12         nan              1.5
# 13    WELCOME5              4.1
# 14         nan              NaN
# 15         nan              4.0
# 16         nan              1.6
# 17      SAVE10              NaN
# 18      SAVE10              NaN
# 19         nan              NaN
# 20      SAVE10              1.5
# 21      SAVE10              2.5
# 22      SAVE10              3.8
# 23    WELCOME5              3.3
# 24      SAVE10              4.5
# 25         nan              NaN
# 26         nan              1.3
# 27         nan              NaN
# 28      SAVE10              1.3
# 29    WELCOME5              1.1
# 30         nan              4.2
# 31    WELCOME5              4.7
# 32    WELCOME5              1.4
# 33    WELCOME5              NaN
# 34    WELCOME5              1.4

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 03:**
# </div>

# %%
# 3. Validating the Data Type of a Specific Column
# Write a Pandas program to validate the data type of a specific column in a DataFrame.

# Check if 'price' column is of type float
is_of_type = 'float64'
is_price_float = df['price'].dtype == is_of_type
is_price_float

# Validate the data type of 'price' column
if is_price_float:
    print("The 'price' column is of type {}.".format(df['price'].dtype))
else:
    print("The 'price' column is not of type {}, it is {}.".format(is_of_type, df['price'].dtype))
# Out:
# The 'price' column is of type float64.

# %% [markdown]
# <div class="alert alert-warning">
#
# **4. Checking Duplicate Rows in a DataFrame**
#
# **Write a Pandas program to check duplicate rows in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1397         139         1  12.50      0.16   10.5000
# 1  2023-01-02         1303         127         3  98.02      0.26  217.6044
# 2  2023-01-03         1974         114         5  73.82      0.22  287.8980
# 3  2023-01-04         1175         147         9  88.48      0.03  772.4304
# 4  2023-01-05         1567         184         9  16.22      0.21  115.3242
# 5  2023-01-06         1132         159         7  50.19      0.07  326.7369
# 6  2023-01-07         1428         182         5  88.40      0.01  437.5800
# 7  2023-01-08         1473         155         2  23.24      0.26   34.3952
# 8  2023-01-09         1355         162         5  21.31      0.16   89.5020
# 9  2023-01-10         1649         147         2  36.87      0.20   58.9920
# 10 2023-01-11         1666         161         2  25.82      0.28   37.1808
# 11 2023-01-12         1063         117         2  36.66      0.04   70.3872
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     1.4  Not Returned  Positive            NaN
# 1   Female             Food     4.8  Not Returned  Positive           9.78
# 2   Female      Electronics     2.2  Not Returned  Positive          10.95
# 3    Other            Books     1.4      Returned  Negative           5.09
# 4     Male             Food     3.8  Not Returned  Negative           9.48
# 5   Female      Electronics     3.8  Not Returned   Neutral          14.33
# 6    Other         Clothing     3.6      Returned  Negative          15.00
# 7     Male            Books     4.0      Returned  Positive          19.33
# 8    Other      Electronics     1.0  Not Returned   Neutral          14.13
# 9    Other            Books     3.8  Not Returned  Negative            NaN
# 10   Other         Clothing     3.5      Returned  Negative          17.50
# 11  Female      Electronics     1.2      Returned   Neutral           8.99
# 12    Male            Books     4.0      Returned  Positive           6.26
# 13  Female             Food     1.8      Returned  Positive            NaN
# 14  Female             Food     2.6  Not Returned  Positive          18.96
# 15    Male      Electronics     3.8  Not Returned   Neutral          18.98
# 16   Other      Electronics     3.6  Not Returned  Positive           7.26
# 17  Female            Books     4.0      Returned  Positive          18.97
# 18   Other         Clothing     1.1      Returned   Neutral          18.44
# 19  Female         Clothing     1.8      Returned   Neutral          12.48
# 20    Male            Books     1.8  Not Returned   Neutral            NaN
# 21   Other         Clothing     3.8      Returned   Neutral           9.99
# 22   Other      Electronics     2.2  Not Returned  Positive          15.35
# 23  Female      Electronics     4.9      Returned   Neutral           9.06
# 24  Female             Food     1.9  Not Returned  Negative          12.16
# 25  Female      Electronics     4.4      Returned   Neutral            NaN
# 26  Female      Electronics     2.1  Not Returned  Positive           6.00
# 27   Other         Clothing     4.3      Returned  Positive           5.97
# 28    Male      Electronics     3.1      Returned   Neutral          15.05
# 29  Female      Electronics     4.4  Not Returned   Neutral            NaN
# 30   Other            Books     2.1  Not Returned   Neutral          10.40
# 31  Female            Books     3.3  Not Returned  Negative           9.98
# 32  Female         Clothing     2.1      Returned  Positive          10.40
# 33    Male             Food     5.0  Not Returned  Negative           7.93
# 34    Male            Books     1.1      Returned  Negative          14.91
# 35  Female      Electronics     2.1  Not Returned  Positive           6.00
# 36  Female             Food     1.8      Returned  Positive            NaN
# 37  Female             Food     1.9  Not Returned  Negative          12.16
#
#    coupon_code  delivery_rating
# 0       SAVE10              3.0
# 1     FREESHIP              3.9
# 2          nan              NaN
# 3       SAVE10              1.3
# 4          nan              3.5
# 5     WELCOME5              NaN
# 6          nan              NaN
# 7     FREESHIP              3.2
# 8     WELCOME5              1.2
# 9     WELCOME5              NaN
# 10      SAVE10              3.5
# 11    WELCOME5              NaN
# 12         nan              4.1
# 13      SAVE10              NaN
# 14    WELCOME5              4.9
# 15    WELCOME5              2.0
# 16         nan              4.5
# 17    FREESHIP              2.6
# 18    WELCOME5              2.4
# 19         nan              3.4
# 20         nan              NaN
# 21         nan              4.4
# 22    WELCOME5              2.3
# 23      SAVE10              NaN
# 24      SAVE10              2.0
# 25    FREESHIP              2.9
# 26         nan              NaN
# 27      SAVE10              3.8
# 28    FREESHIP              NaN
# 29         nan              NaN
# 30         nan              4.4
# 31         nan              2.8
# 32    WELCOME5              NaN
# 33      SAVE10              2.4
# 34         nan              NaN
# 35         nan              NaN
# 36      SAVE10              NaN
# 37      SAVE10              2.0

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          8   West    Credit Card      False              3            62
# 1          3  North    Credit Card      False              3            18
# 2          2  North         Online       True              5            35
# 3          5  North         Online       True              1            59
# 4          3  South           Cash      False              2            30
# 5          5   West           Cash      False              3            63
# 6          1   East         Online      False              1            52
# 7          7   West    Credit Card       True              3            25
# 8          2  South         Online      False              6            28
# 9          9  North    Credit Card       True              4            30
# 10         3   West           Cash      False              2            29
# 11         5   East    Credit Card      False              1            39
# 12         2  South         Online      False              4            48
# 13         4   East           Cash      False              1            26
# 14         2  North           Cash      False              4            61
# 15         1  South    Credit Card      False              6            31
# 16         1   East           Cash       True              6            24
# 17         9  North    Credit Card       True              3            33
# 18         4  South         Online      False              6            21
# 19         1   West         Online      False              6            41
# 20         2   East           Cash       True              5            60
# 21         5  South           Cash      False              4            51
# 22         5   West           Cash       True              2            27
# 23         7  North    Credit Card      False              6            21
# 24         4  North           Cash      False              1            35
# 25         7  North           Cash       True              3            54
# 26         4   East    Credit Card       True              1            46
# 27         6  North    Credit Card       True              3            38
# 28         2  South           Cash       True              4            25
# 29         2   West           Cash       True              2            45
# 30         1  South    Credit Card       True              3            35
# 31         8  South    Credit Card       True              2            65
# 32         3  South           Cash      False              3            37
# 33         2   East    Credit Card       True              2            25
# 34         4   West         Online       True              6            44
# 35         4   East    Credit Card       True              1            46
# 36         4   East           Cash      False              1            26
# 37         4  North           Cash      False              1            35
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female         Clothing     4.8  Not Returned   Neutral            NaN
# 1     Male             Food     3.4  Not Returned   Neutral          16.14
# 2   Female             Food     1.1  Not Returned  Positive            NaN
# 3    Other         Clothing     1.5  Not Returned  Negative            NaN
# 4     Male             Food     1.5  Not Returned  Negative           9.78
# 5   Female             Food     4.2  Not Returned  Negative          13.82
# 6    Other         Clothing     1.5  Not Returned  Negative          14.56
# 7     Male            Books     3.9  Not Returned  Positive          10.62
# 8     Male             Food     3.6      Returned   Neutral           5.94
# 9   Female      Electronics     1.6      Returned  Positive          10.45
# 10    Male      Electronics     3.4      Returned   Neutral            NaN
# 11    Male             Food     3.9      Returned  Negative           7.64
# 12    Male      Electronics     4.4  Not Returned  Positive          19.65
# 13   Other             Food     2.9      Returned   Neutral           5.80
# 14  Female            Books     1.4      Returned   Neutral           5.69
# 15    Male         Clothing     4.0      Returned   Neutral           9.22
# 16   Other      Electronics     2.3      Returned  Positive          18.16
# 17  Female             Food     3.6      Returned  Negative          15.86
# 18    Male         Clothing     1.9  Not Returned  Positive          10.88
# 19   Other             Food     4.1  Not Returned  Negative          15.08
# 20    Male            Books     3.3      Returned  Negative            NaN
# 21  Female      Electronics     2.2  Not Returned  Positive           9.07
# 22    Male         Clothing     1.2  Not Returned  Positive          16.02
# 23    Male            Books     2.9      Returned   Neutral          10.55
# 24  Female             Food     3.2      Returned   Neutral          18.72
# 25  Female         Clothing     2.0  Not Returned  Negative          11.06
# 26  Female      Electronics     2.8      Returned  Positive          19.84
# 27   Other         Clothing     3.3  Not Returned   Neutral          14.25
# 28    Male             Food     2.6      Returned  Negative           8.36
# 29   Other         Clothing     3.4  Not Returned  Positive          10.38
# 30    Male            Books     4.8      Returned  Positive           5.41
# 31  Female      Electronics     1.7      Returned   Neutral           7.63
# 32    Male      Electronics     2.8  Not Returned  Negative          19.26
# 33  Female            Books     1.5  Not Returned   Neutral            NaN
# 34   Other      Electronics     4.4      Returned   Neutral           6.46
# 35  Female      Electronics     2.8      Returned  Positive          19.84
# 36   Other             Food     2.9      Returned   Neutral           5.80
# 37  Female             Food     3.2      Returned   Neutral          18.72
#
#    coupon_code  delivery_rating
# 0     WELCOME5              1.2
# 1          nan              NaN
# 2     WELCOME5              1.6
# 3          nan              2.6
# 4          nan              3.8
# 5     WELCOME5              2.5
# 6     FREESHIP              4.6
# 7     WELCOME5              NaN
# 8     FREESHIP              3.7
# 9          nan              1.2
# 10    FREESHIP              2.5
# 11         nan              4.4
# 12         nan              NaN
# 13         nan              4.9
# 14    WELCOME5              1.7
# 15      SAVE10              3.5
# 16      SAVE10              4.6
# 17    WELCOME5              3.0
# 18      SAVE10              NaN
# 19    WELCOME5              3.7
# 20    WELCOME5              3.0
# 21         nan              NaN
# 22         nan              3.2
# 23      SAVE10              NaN
# 24    FREESHIP              3.8
# 25    WELCOME5              1.9
# 26    FREESHIP              1.7
# 27    FREESHIP              1.9
# 28    FREESHIP              NaN
# 29         nan              1.0
# 30         nan              3.4
# 31    FREESHIP              2.0
# 32    WELCOME5              NaN
# 33    FREESHIP              2.7
# 34    FREESHIP              NaN
# 35    FREESHIP              1.7
# 36         nan              4.9
# 37    FREESHIP              3.8

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
# 5. Removing Duplicate Rows from a DataFrame
# Write a Pandas program to remove duplicate rows from a DataFrame.

print("Shape of DataFrame before removing duplicates:\n", df.shape)
# Remove duplicate rows
df = df.drop_duplicates()
print("Shape of DataFrame after removing duplicates:\n", df.shape)
# Out:
# Shape of DataFrame before removing duplicates:
#  (38, 21)
# Shape of DataFrame after removing duplicates:
#  (35, 21)

# %% [markdown]
# <div class="alert alert-warning">
#
# **6. Validating Data Based on Custom Conditions**
#
# **Write a Pandas program to validate data based on custom conditions.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1788         198         6  67.64      0.26  300.3216
# 1  2023-01-02         1643         156         2  93.52      0.20  149.6320
# 2  2023-01-03         1178         198         8  83.42      0.16  560.5824
# 3  2023-01-04         1535         130         9  84.61      0.19  616.8069
# 4  2023-01-05         1515         185         5  93.51      0.02  458.1990
# 5  2023-01-06         1474         129         1  56.15      0.24   42.6740
# 6  2023-01-07         1951         192         4  11.77      0.10   42.3720
# 7  2023-01-08         1966         151         1  41.08      0.22   32.0424
# 8  2023-01-09         1119         137         9  76.79      0.18  566.7102
# 9  2023-01-10         1941         183         4  93.48      0.13  325.3104
# 10 2023-01-11         1625         156         9  42.86      0.20  308.5920
# 11 2023-01-12         1364         167         4  23.02      0.19   74.5848
# 12 2023-01-13         1375         154         2  85.12      0.19  137.8944
# 13 2023-01-14         1816         111         9  85.11      0.27  559.1727
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     3.9      Returned  Positive          17.42
# 1    Other      Electronics     1.7  Not Returned  Positive           8.47
# 2   Female            Books     1.4      Returned  Negative          16.60
# 3   Female            Books     2.3  Not Returned   Neutral           5.33
# 4     Male            Books     2.1      Returned  Negative          12.45
# 5     Male            Books     4.8      Returned  Positive            NaN
# 6   Female      Electronics     2.6  Not Returned  Positive          17.60
# 7   Female            Books     2.2  Not Returned   Neutral           9.32
# 8   Female            Books     2.2      Returned  Negative          19.82
# 9     Male         Clothing     4.3      Returned   Neutral          12.19
# 10  Female             Food     1.0  Not Returned  Negative            NaN
# 11   Other      Electronics     4.3      Returned   Neutral          15.87
# 12    Male      Electronics     1.1      Returned   Neutral          16.80
# 13    Male      Electronics     5.0      Returned   Neutral            NaN
# 14   Other            Books     4.8  Not Returned  Negative            NaN
# 15   Other      Electronics     3.7      Returned  Negative          12.87
# 16  Female             Food     3.6      Returned  Negative          15.40
# 17    Male             Food     4.8  Not Returned  Negative          18.25
# 18  Female         Clothing     1.9      Returned   Neutral          14.07
# 19  Female             Food     4.8  Not Returned  Negative           7.92
# 20   Other            Books     1.8      Returned  Negative          15.17
# 21   Other      Electronics     1.9  Not Returned  Negative          10.77
# 22  Female         Clothing     2.0  Not Returned  Negative          14.92
# 23  Female         Clothing     3.9  Not Returned  Negative          11.44
# 24   Other            Books     2.7      Returned  Positive          10.10
# 25    Male         Clothing     2.5  Not Returned  Negative          11.50
# 26   Other         Clothing     3.6      Returned  Positive          12.99
# 27  Female      Electronics     3.4  Not Returned   Neutral            NaN
# 28  Female             Food     3.9  Not Returned  Negative          14.51
# 29    Male         Clothing     1.4  Not Returned  Positive           9.52
# 30   Other      Electronics     4.0  Not Returned  Positive          11.37
# 31   Other             Food     2.6      Returned  Negative          19.54
# 32  Female             Food     3.7  Not Returned   Neutral          17.12
# 33  Female         Clothing     4.2      Returned  Positive          18.76
# 34    Male             Food     4.9  Not Returned  Negative          15.76
# 35   Other         Clothing     3.6      Returned  Positive          12.99
# 36    Male      Electronics     5.0      Returned   Neutral            NaN
# 37   Other            Books     2.7      Returned  Positive          10.10
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 0     FREESHIP              4.2
# 1       SAVE10              3.1
# 2     FREESHIP              2.1
# 3     FREESHIP              1.6
# 4          nan              NaN
# 5     FREESHIP              3.9
# 6     FREESHIP              2.3
# 7       SAVE10              NaN
# 8          nan              1.0
# 9     FREESHIP              3.4
# 10    FREESHIP              4.5
# 11      SAVE10              2.8
# 12    FREESHIP              2.0
# 13         nan              NaN
# 14      SAVE10              NaN
# 15         nan              3.0
# 16    WELCOME5              2.4
# 17    FREESHIP              2.7
# 18      SAVE10              2.7
# 19         nan              NaN
# 20    FREESHIP              NaN
# 21    WELCOME5              3.5
# 22         nan              NaN
# 23         nan              2.2
# 24    FREESHIP              NaN
# 25         nan              NaN
# 26    FREESHIP              4.2
# 27    WELCOME5              4.2
# 28         nan              2.5
# 29         nan              NaN
# 30    WELCOME5              NaN
# 31         nan              4.0
# 32         nan              NaN
# 33    WELCOME5              4.4
# 34    FREESHIP              4.1
# 35    FREESHIP              4.2
# 36         nan              NaN
# 37    FREESHIP              NaN
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 06:**
# </div>

# %%
# 6. Validating Data Based on Custom Conditions
# Write a Pandas program to validate data based on custom conditions.

# Check if 'price' is greater than 0
valid_price = df['price'] > 0
if valid_price.all():
    print("All prices are valid.")
else:
    print("Some prices are invalid:")
    display(df[~valid_price])
# Out:
# Some prices are invalid:
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating
# 38         NaN              NaN
# 39         NaN              NaN
# 40         NaN              NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **7. Checking That a Specific Column Contains Only Unique Values**
#
# **Write a Pandas program to check that a specific column contains only unique values.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1252         105         2  54.65      0.24   83.0680
# 1  2023-01-02         1754         165         3  63.11      0.16  159.0372
# 2  2023-01-03         1602         169         4  26.94      0.17   89.4408
# 3  2023-01-04         1483         133         5  89.76      0.15  381.4800
# 4  2023-01-05         1519         102         1  69.28      0.18   56.8096
# 5  2023-01-06         1947         114         4  71.38      0.23  219.8504
# 6  2023-01-07         1371         150         3  70.00      0.03  203.7000
# 7  2023-01-08         1051         100         7  56.60      0.00  396.2000
# 8  2023-01-09         1798         161         6  90.35      0.26  401.1540
# 9  2023-01-10         1707         154         6  28.00      0.29  119.2800
# 10 2023-01-11         1929         129         3  33.02      0.13   86.1822
# 11 2023-01-12         1364         189         4  81.97      0.29  232.7948
# 12 2023-01-13         1739         144         9  63.93      0.05  546.6015
# 13 2023-01-14         1923         150         4  54.83      0.13  190.8084
# 14 2023-01-15         1993         178         2  59.00      0.27   86.1400
# 15 2023-01-16         1206         193         5  42.30      0.11  188.2350
# 16 2023-01-17         1087         159         4  51.59      0.29  146.5156
# 17 2023-01-18         1008         122         3  16.96      0.12   44.7744
# 18 2023-01-19         1200         137         5  17.68      0.20   70.7200
# 19 2023-01-20         1784         150         9  62.40      0.01  555.9840
# 20 2023-01-21         1494         187         8  91.79      0.02  719.6336
# 21 2023-01-22         1348         100         3  19.55      0.18   48.0930
# 22 2023-01-23         1199         106         6  56.96      0.13  297.3312
# 23 2023-01-24         1934         106         5  33.62      0.08  154.6520
# 24 2023-01-25         1666         197         8  95.12      0.21  601.1584
# 25 2023-01-26         1304         122         1  27.12      0.01   26.8488
# 26 2023-01-27         1790         154         5  66.89      0.10  301.0050
# 27 2023-01-28         1254         179         6  62.44      0.18  307.2048
# 28 2023-01-29         1218         109         8  22.05      0.26  130.5360
# 29 2023-01-30         1780         158         5  52.67      0.19  213.3135
# 30 2023-01-31         1056         103         8  50.18      0.11  357.2816
# 31 2023-02-01         1649         189         2  17.77      0.05   33.7630
# 32 2023-02-02         1946         165         5  85.12      0.21  336.2240
# 33 2023-02-03         1898         110         7  86.92      0.19  492.8364
# 34 2023-02-04         1774         197         5  85.54      0.18  350.7140
# 35 2023-01-27         1790         154         5  66.89      0.10  301.0050
# 36 2023-01-14         1923         150         4  54.83      0.13  190.8084
# 37 2023-01-25         1666         197         8  95.12      0.21  601.1584
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          5   East           Cash      False              4            52
# 1          1  North           Cash       True              1            43
# 2          9   East           Cash       True              2            29
# 3          8  North         Online       True              3            68
# 4          1  North    Credit Card       True              5            25
# 5          7  North         Online      False              6            39
# 6          2  South    Credit Card      False              2            68
# 7          6  North    Credit Card      False              1            38
# 8          2   West           Cash      False              1            52
# 9          5   West    Credit Card       True              3            66
# 10         1  South           Cash      False              1            69
# 11         3   East    Credit Card      False              1            58
# 12         5  South         Online       True              2            22
# 13         2   West    Credit Card       True              4            23
# 14         2  North           Cash       True              4            51
# 15         2   West         Online       True              6            45
# 16         2   East           Cash      False              1            69
# 17         6   East         Online       True              4            43
# 18         6   West           Cash       True              3            19
# 19         5   East    Credit Card      False              4            18
# 20         9  North    Credit Card      False              4            40
# 21         7  South         Online       True              5            34
# 22         5   West         Online      False              6            30
# 23         2   East         Online       True              2            29
# 24         3   East    Credit Card      False              3            27
# 25         9   West           Cash      False              2            26
# 26         4  North           Cash       True              2            52
# 27         2   East         Online      False              3            62
# 28         5  North         Online       True              4            19
# 29         7   West         Online       True              4            62
# 30         5  South         Online       True              6            19
# 31         5   East           Cash      False              4            55
# 32         1  South         Online       True              6            59
# 33         2   West    Credit Card       True              3            57
# 34         2   East    Credit Card      False              2            59
# 35         4  North           Cash       True              2            52
# 36         2   West    Credit Card       True              4            23
# 37         3   East    Credit Card      False              3            27
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female      Electronics     4.7      Returned   Neutral          15.96
# 1     Male             Food     4.3  Not Returned  Negative          14.79
# 2     Male      Electronics     3.2  Not Returned   Neutral           8.72
# 3     Male         Clothing     2.4  Not Returned  Positive          16.15
# 4   Female            Books     2.0      Returned  Positive          16.21
# 5    Other      Electronics     1.4      Returned  Negative          17.43
# 6     Male            Books     2.3  Not Returned  Positive          17.56
# 7    Other             Food     1.8      Returned  Negative            NaN
# 8   Female            Books     2.7  Not Returned  Positive           9.91
# 9   Female         Clothing     4.4      Returned  Positive            NaN
# 10    Male            Books     4.2      Returned  Negative           5.83
# 11   Other      Electronics     2.3      Returned  Positive           6.53
# 12  Female            Books     3.7  Not Returned  Positive          17.69
# 13   Other         Clothing     1.4      Returned   Neutral            NaN
# 14    Male            Books     2.9      Returned  Negative            NaN
# 15    Male         Clothing     4.6      Returned   Neutral          11.75
# 16   Other         Clothing     4.0      Returned  Positive          19.04
# 17   Other            Books     2.7      Returned   Neutral          11.82
# 18  Female         Clothing     4.8  Not Returned  Positive          19.16
# 19  Female      Electronics     2.2  Not Returned  Positive          11.20
# 20   Other         Clothing     3.3  Not Returned   Neutral          17.80
# 21  Female      Electronics     5.0      Returned  Negative          12.98
# 22   Other             Food     1.5  Not Returned   Neutral            NaN
# 23    Male             Food     3.0  Not Returned   Neutral          19.21
# 24  Female         Clothing     1.8  Not Returned   Neutral          14.75
# 25    Male      Electronics     4.1  Not Returned  Negative           6.62
# 26   Other            Books     3.2      Returned   Neutral            NaN
# 27    Male      Electronics     2.2      Returned   Neutral            NaN
# 28    Male            Books     2.7      Returned  Positive          14.02
# 29    Male             Food     3.2      Returned  Negative          15.49
# 30    Male         Clothing     4.6  Not Returned   Neutral            NaN
# 31   Other         Clothing     3.1      Returned  Negative           8.72
# 32  Female             Food     3.4      Returned   Neutral          19.25
# 33  Female         Clothing     4.5  Not Returned   Neutral          13.98
# 34    Male      Electronics     2.9  Not Returned  Positive          17.38
# 35   Other            Books     3.2      Returned   Neutral            NaN
# 36   Other         Clothing     1.4      Returned   Neutral            NaN
# 37  Female         Clothing     1.8  Not Returned   Neutral          14.75
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0          nan              2.3          1
# 1          nan              NaN          2
# 2     WELCOME5              3.9          3
# 3       SAVE10              2.1          4
# 4          nan              NaN          5
# 5     WELCOME5              1.6          6
# 6       SAVE10              NaN          7
# 7       SAVE10              4.9          8
# 8       SAVE10              1.0          9
# 9          nan              1.7         10
# 10      SAVE10              4.0         11
# 11    WELCOME5              NaN         12
# 12    WELCOME5              3.6         13
# 13         nan              1.0         14
# 14    FREESHIP              NaN         15
# 15         nan              1.3         16
# 16    WELCOME5              NaN         17
# 17    FREESHIP              NaN         18
# 18         nan              2.1         19
# 19    FREESHIP              NaN         20
# 20         nan              NaN         21
# 21         nan              4.5         22
# 22         nan              4.8         23
# 23      SAVE10              NaN         24
# 24    WELCOME5              NaN         25
# 25         nan              2.7         26
# 26    WELCOME5              NaN         27
# 27      SAVE10              NaN         28
# 28      SAVE10              2.9         29
# 29    WELCOME5              3.3         30
# 30         nan              NaN         31
# 31         nan              NaN         32
# 32      SAVE10              3.9         33
# 33         nan              3.9         34
# 34         nan              4.8         35
# 35    WELCOME5              NaN         36
# 36         nan              1.0         37
# 37    WELCOME5              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 07:**
# </div>

# %%
pd.Series.is_unique?
# Out:
# Type:        property
# String form: <property object at 0x116f60220>
# Docstring:
# Return boolean if values in the object are unique.
#
# Returns
# -------
# bool
#
# Examples
# --------
# >>> s = pd.Series([1, 2, 3])
# >>> s.is_unique
# True
#
# >>> s = pd.Series([1, 2, 3, 1])
# >>> s.is_unique
# False

# %%
# 7. Checking That a Specific Column Contains Only Unique Values
# Write a Pandas program to check that a specific column contains only unique values.


def is_unique(column_name, dataframe):
    if dataframe[column_name].is_unique:
        print("The column {:<20} contains only unique values.".format(column_name))
    else:
        print("The column {:<20} has more than one unique value - has duplicates.".format(column_name))

for col in df.columns:
    is_unique(col, df)
# Out:
# The column date                 has more than one unique value - has duplicates.
# The column customer_id          has more than one unique value - has duplicates.
# The column product_id           has more than one unique value - has duplicates.
# The column quantity             has more than one unique value - has duplicates.
# The column price                has more than one unique value - has duplicates.
# The column discount             has more than one unique value - has duplicates.
# The column revenue              has more than one unique value - has duplicates.
# The column store_id             has more than one unique value - has duplicates.
# The column region               has more than one unique value - has duplicates.
# The column payment_method       has more than one unique value - has duplicates.
# The column is_member            has more than one unique value - has duplicates.
# The column delivery_days        has more than one unique value - has duplicates.
# The column customer_age         has more than one unique value - has duplicates.
# The column gender               has more than one unique value - has duplicates.
# The column product_category     has more than one unique value - has duplicates.
# The column rating               has more than one unique value - has duplicates.
# The column return_status        has more than one unique value - has duplicates.
# The column feedback             has more than one unique value - has duplicates.
# The column shipping_cost        has more than one unique value - has duplicates.
# The column coupon_code          has more than one unique value - has duplicates.
# The column delivery_rating      has more than one unique value - has duplicates.
# The column unique_id            contains only unique values.

# %% [markdown]
# <div class="alert alert-warning">
#
# **8. Detecting Outliers in a DataFrame**
#
# **Write a Pandas program to detect outliers in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

# add column with unique value
df['unique_id'] = pd.Series(range(1, len(df) + 1))

# add outliers
df.loc[[0,3,5], ['price']] = [9999.99, 8888.88, 7777.77]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1267         150         2  9999.99      0.20   45.3600
# 1  2023-01-02         1593         185         4    19.19      0.29   54.4996
# 2  2023-01-03         1044         154         3    20.10      0.08   55.4760
# 3  2023-01-04         1010         113         5  8888.88      0.03  156.8005
# 4  2023-01-05         1734         107         5    90.50      0.28  325.8000
# 5  2023-01-06         1296         140         1  7777.77      0.05   44.6215
# 6  2023-01-07         1869         157         9    20.12      0.25  135.8100
# 7  2023-01-08         1241         135         6    84.37      0.29  359.4162
# 8  2023-01-09         1310         183         1    60.21      0.15   51.1785
# 9  2023-01-10         1759         177         1    62.53      0.15   53.1505
# 10 2023-01-11         1587         165         6    81.86      0.03  476.4252
# 11 2023-01-12         1551         139         3    77.23      0.05  220.1055
# 12 2023-01-13         1280         182         4    53.08      0.06  199.5808
# 13 2023-01-14         1934         178         4    78.80      0.08  289.9840
# 14 2023-01-15         1798         190         7    98.73      0.06  649.6434
# 15 2023-01-16         1284         174         5    91.10      0.00  455.5000
# 16 2023-01-17         1148         197         8    89.86      0.15  611.0480
# 17 2023-01-18         1204         130         6    56.31      0.19  273.6666
# 18 2023-01-19         1816         173         4    61.74      0.25  185.2200
# 19 2023-01-20         1865         138         8    54.39      0.20  348.0960
# 20 2023-01-21         1071         164         9    91.64      0.24  626.8176
# 21 2023-01-22         1137         189         8    80.11      0.28  461.4336
# 22 2023-01-23         1923         135         7    85.02      0.20  476.1120
# 23 2023-01-24         1969         125         4    20.24      0.26   59.9104
# 24 2023-01-25         1078         125         4    79.31      0.28  228.4128
# 25 2023-01-26         1152         111         3    39.10      0.02  114.9540
# 26 2023-01-27         1124         192         3    14.90      0.08   41.1240
# 27 2023-01-28         1743         144         8    89.21      0.04  685.1328
# 28 2023-01-29         1856         163         6    57.15      0.13  298.3230
# 29 2023-01-30         1082         157         3    32.35      0.18   79.5810
# 30 2023-01-31         1505         131         8    80.16      0.18  525.8496
# 31 2023-02-01         1677         100         2    77.45      0.15  131.6650
# 32 2023-02-02         1119         164         6    28.73      0.27  125.8374
# 33 2023-02-03         1928         138         1    49.98      0.05   47.4810
# 34 2023-02-04         1856         103         4    38.24      0.28  110.1312
# 35 2023-01-27         1124         192         3    14.90      0.08   41.1240
# 36 2023-01-14         1934         178         4    78.80      0.08  289.9840
# 37 2023-01-25         1078         125         4    79.31      0.28  228.4128
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          1  North           Cash       True              5            30
# 1          3   West           Cash      False              2            53
# 2          5  North           Cash      False              2            29
# 3          6  South    Credit Card      False              1            25
# 4          3   West           Cash       True              5            19
# 5          2  South         Online      False              5            21
# 6          3  North         Online      False              1            53
# 7          3  North    Credit Card       True              4            34
# 8          5   East         Online       True              4            56
# 9          4   East           Cash      False              2            24
# 10         3   East           Cash      False              3            23
# 11         5   West         Online       True              1            19
# 12         2   East         Online       True              2            51
# 13         9  South         Online      False              3            60
# 14         7   West         Online      False              6            58
# 15         6  North           Cash       True              3            30
# 16         1   East         Online       True              3            33
# 17         2   West           Cash      False              5            33
# 18         6  North         Online       True              6            41
# 19         6  South    Credit Card       True              5            41
# 20         4  North           Cash      False              4            58
# 21         3   West           Cash       True              1            56
# 22         2   West    Credit Card       True              5            35
# 23         3  North           Cash       True              3            54
# 24         6   East           Cash       True              4            40
# 25         1  South    Credit Card      False              1            46
# 26         1   East         Online       True              3            22
# 27         3   West           Cash       True              5            35
# 28         3   West    Credit Card      False              5            33
# 29         4   East           Cash      False              6            68
# 30         3  South         Online       True              2            45
# 31         4   East           Cash       True              1            44
# 32         6   East         Online      False              1            33
# 33         8   West         Online       True              2            58
# 34         9  South    Credit Card      False              1            65
# 35         1   East         Online       True              3            22
# 36         9  South         Online      False              3            60
# 37         6   East           Cash       True              4            40
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0    Other         Clothing     2.1      Returned  Positive          16.86
# 1     Male            Books     2.5  Not Returned  Negative          13.02
# 2   Female         Clothing     3.3  Not Returned   Neutral          14.96
# 3    Other      Electronics     2.8      Returned   Neutral           7.75
# 4     Male            Books     2.9      Returned  Negative            NaN
# 5     Male             Food     4.5  Not Returned   Neutral            NaN
# 6     Male             Food     1.4      Returned   Neutral          11.95
# 7   Female         Clothing     1.8      Returned  Negative          15.98
# 8   Female      Electronics     1.3      Returned  Positive           7.35
# 9     Male         Clothing     4.6      Returned  Negative          11.69
# 10  Female            Books     4.1  Not Returned  Positive          13.13
# 11   Other             Food     4.8      Returned  Negative          10.72
# 12   Other             Food     1.3      Returned  Negative            NaN
# 13   Other            Books     3.2  Not Returned  Positive            NaN
# 14   Other             Food     2.0  Not Returned  Positive          18.41
# 15   Other      Electronics     4.5  Not Returned   Neutral          14.36
# 16  Female            Books     3.1  Not Returned  Positive          11.90
# 17  Female      Electronics     4.6  Not Returned  Negative          11.88
# 18   Other            Books     3.8      Returned  Positive            NaN
# 19    Male         Clothing     3.8  Not Returned  Negative            NaN
# 20   Other      Electronics     3.5      Returned  Positive          18.15
# 21    Male         Clothing     4.0  Not Returned  Positive           7.38
# 22   Other            Books     3.1      Returned   Neutral          12.21
# 23    Male            Books     4.3  Not Returned  Negative            NaN
# 24    Male      Electronics     4.6  Not Returned  Positive           9.72
# 25  Female         Clothing     3.1      Returned  Positive           6.44
# 26   Other         Clothing     2.7  Not Returned  Negative           7.80
# 27  Female             Food     1.1      Returned   Neutral            NaN
# 28  Female         Clothing     4.3      Returned  Negative           5.17
# 29  Female            Books     1.7  Not Returned  Positive          16.55
# 30   Other         Clothing     3.0  Not Returned  Positive          18.10
# 31   Other      Electronics     3.3  Not Returned   Neutral          10.64
# 32   Other         Clothing     4.8      Returned  Positive           5.22
# 33    Male      Electronics     2.2  Not Returned  Positive            NaN
# 34  Female      Electronics     1.2      Returned   Neutral          10.96
# 35   Other         Clothing     2.7  Not Returned  Negative           7.80
# 36   Other            Books     3.2  Not Returned  Positive            NaN
# 37    Male      Electronics     4.6  Not Returned  Positive           9.72
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     FREESHIP              1.0          1
# 1       SAVE10              2.7          2
# 2       SAVE10              1.1          3
# 3     WELCOME5              4.9          4
# 4     WELCOME5              1.4          5
# 5     WELCOME5              4.1          6
# 6     FREESHIP              2.2          7
# 7     FREESHIP              2.4          8
# 8     WELCOME5              2.4          9
# 9     WELCOME5              NaN         10
# 10         nan              3.3         11
# 11      SAVE10              2.8         12
# 12         nan              NaN         13
# 13      SAVE10              NaN         14
# 14    WELCOME5              2.5         15
# 15      SAVE10              4.3         16
# 16         nan              4.2         17
# 17         nan              4.4         18
# 18         nan              2.7         19
# 19         nan              4.4         20
# 20    WELCOME5              1.9         21
# 21         nan              4.1         22
# 22    WELCOME5              NaN         23
# 23         nan              2.9         24
# 24    FREESHIP              2.3         25
# 25         nan              4.2         26
# 26    FREESHIP              1.6         27
# 27    WELCOME5              NaN         28
# 28         nan              NaN         29
# 29      SAVE10              1.8         30
# 30      SAVE10              NaN         31
# 31         nan              4.9         32
# 32         nan              NaN         33
# 33    FREESHIP              2.0         34
# 34    FREESHIP              3.2         35
# 35    FREESHIP              1.6         36
# 36      SAVE10              NaN         37
# 37    FREESHIP              2.3         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 08:**
# </div>

# %%
# 8. Detecting Outliers in a DataFrame
# Write a Pandas program to detect outliers in a DataFrame.

def detect_outliers(column_name, dataframe):
    if dataframe[column_name].dtype not in [np.float64, np.int64]:
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        Q1 = dataframe[column_name].quantile(0.25)
        Q3 = dataframe[column_name].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = dataframe[(dataframe[column_name] < lower_bound) | (dataframe[column_name] > upper_bound)]
    if not outliers.empty:
        print("Column {:>30} OUTLIERS DETECTED.\n####### OUTLIERS #######".format(column_name))
        display(outliers)
    else:
        print("Column {:>30} has no outliers detected.".format(column_name))

for col in df.columns:
    detect_outliers(col, df)
# Out:
# Column                           date is not numeric and will be skipped.
# Column                    customer_id has no outliers detected.
# Column                     product_id has no outliers detected.
# Column                       quantity has no outliers detected.
# Column                          price OUTLIERS DETECTED.
# ####### OUTLIERS #######
#         date  customer_id  product_id  quantity    price  discount   revenue  \
# 0 2023-01-01         1267         150         2  9999.99      0.20   45.3600
# 3 2023-01-04         1010         113         5  8888.88      0.03  156.8005
# 5 2023-01-06         1296         140         1  7777.77      0.05   44.6215
#
#    store_id region payment_method  is_member  delivery_days  customer_age  \
# 0         1  North           Cash       True              5            30
# 3         6  South    Credit Card      False              1            25
# 5         2  South         Online      False              5            21
#
#   gender product_category  rating return_status  feedback  shipping_cost  \
# 0  Other         Clothing     2.1      Returned  Positive          16.86
# 3  Other      Electronics     2.8      Returned   Neutral           7.75
# 5   Male             Food     4.5  Not Returned   Neutral            NaN
#
#   coupon_code  delivery_rating  unique_id
# 0    FREESHIP              1.0          1
# 3    WELCOME5              4.9          4
# 5    WELCOME5              4.1          6
# Column                       discount has no outliers detected.
# Column                        revenue has no outliers detected.
# Column                       store_id has no outliers detected.
# Column                         region is not numeric and will be skipped.
# Column                 payment_method is not numeric and will be skipped.
# Column                      is_member is not numeric and will be skipped.
# Column                  delivery_days has no outliers detected.
# Column                   customer_age has no outliers detected.
# Column                         gender is not numeric and will be skipped.
# Column               product_category is not numeric and will be skipped.
# Column                         rating has no outliers detected.
# Column                  return_status is not numeric and will be skipped.
# Column                       feedback is not numeric and will be skipped.
# Column                  shipping_cost has no outliers detected.
# Column                    coupon_code is not numeric and will be skipped.
# Column                delivery_rating has no outliers detected.
# Column                      unique_id has no outliers detected.

# %%
# finding outliers using the 3-σ rule

def detect_outliers_3sigma(column_name, dataframe):
    if dataframe[column_name].dtype not in [np.float64, np.int64]:
        print("Column {:>30} is not numeric and will be skipped.".format(column_name))
        return
    else:
        mean = dataframe[column_name].mean()
        std = dataframe[column_name].std()
        lower_bound = mean - 3 * std
        upper_bound = mean + 3 * std
        outliers = dataframe[(dataframe[column_name] < lower_bound) | (dataframe[column_name] > upper_bound)]
    
    if not outliers.empty:
        print("Column {:>30} OUTLIERS DETECTED (3σ rule).\n####### OUTLIERS #######".format(column_name))
        display(outliers)
    else:
        print("Column {:>30} has no outliers detected.".format(column_name))

# Apply to all columns
for col in df.columns:
    detect_outliers_3sigma(col, df)
# Out:
# Column                           date is not numeric and will be skipped.
# Column                    customer_id has no outliers detected.
# Column                     product_id has no outliers detected.
# Column                       quantity has no outliers detected.
# Column                          price OUTLIERS DETECTED (3σ rule).
# ####### OUTLIERS #######
#         date  customer_id  product_id  quantity    price  discount   revenue  \
# 0 2023-01-01         1267         150         2  9999.99      0.20   45.3600
# 3 2023-01-04         1010         113         5  8888.88      0.03  156.8005
# 5 2023-01-06         1296         140         1  7777.77      0.05   44.6215
#
#    store_id region payment_method  is_member  delivery_days  customer_age  \
# 0         1  North           Cash       True              5            30
# 3         6  South    Credit Card      False              1            25
# 5         2  South         Online      False              5            21
#
#   gender product_category  rating return_status  feedback  shipping_cost  \
# 0  Other         Clothing     2.1      Returned  Positive          16.86
# 3  Other      Electronics     2.8      Returned   Neutral           7.75
# 5   Male             Food     4.5  Not Returned   Neutral            NaN
#
#   coupon_code  delivery_rating  unique_id
# 0    FREESHIP              1.0          1
# 3    WELCOME5              4.9          4
# 5    WELCOME5              4.1          6
# Column                       discount has no outliers detected.
# Column                        revenue has no outliers detected.
# Column                       store_id has no outliers detected.
# Column                         region is not numeric and will be skipped.
# Column                 payment_method is not numeric and will be skipped.
# Column                      is_member is not numeric and will be skipped.
# Column                  delivery_days has no outliers detected.
# Column                   customer_age has no outliers detected.
# Column                         gender is not numeric and will be skipped.
# Column               product_category is not numeric and will be skipped.
# Column                         rating has no outliers detected.
# Column                  return_status is not numeric and will be skipped.
# Column                       feedback is not numeric and will be skipped.
# Column                  shipping_cost has no outliers detected.
# Column                    coupon_code is not numeric and will be skipped.
# Column                delivery_rating has no outliers detected.
# Column                      unique_id has no outliers detected.

# %% [markdown]
# <div class="alert alert-warning">
#
# **9. Validating Date Formats in a DataFrame**
#
# **Write a Pandas program to validate date formats in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          2  South         Online      False              2            30
# 1          9  South    Credit Card       True              4            57
# 2          4   West           Cash      False              5            19
# 3          1  South    Credit Card       True              2            20
# 4          1  South           Cash      False              6            51
# 5          9   West         Online      False              2            59
# 6          3  North    Credit Card       True              2            33
# 7          4   East           Cash      False              5            55
# 8          2  South           Cash      False              6            48
# 9          1   West           Cash       True              6            45
# 10         8   East           Cash       True              5            69
# 11         7  North    Credit Card      False              3            22
# 12         9   East    Credit Card      False              3            40
# 13         8   East    Credit Card       True              3            53
# 14         3   West         Online      False              1            38
# 15         4  South           Cash      False              1            45
# 16         8   East    Credit Card      False              1            65
# 17         6  North    Credit Card       True              6            21
# 18         2  South         Online       True              2            27
# 19         2   West    Credit Card       True              2            44
# 20         2  North           Cash       True              1            55
# 21         1   East           Cash       True              2            41
# 22         6   West    Credit Card      False              4            39
# 23         9   West           Cash      False              5            57
# 24         2  North    Credit Card       True              1            23
# 25         5  South           Cash       True              4            36
# 26         5  North           Cash       True              5            41
# 27         9  North         Online      False              1            63
# 28         9   East         Online      False              3            19
# 29         4  North           Cash       True              4            28
# 30         6   East    Credit Card       True              2            68
# 31         7  North    Credit Card       True              6            34
# 32         5   East    Credit Card       True              6            42
# 33         8   East    Credit Card       True              5            67
# 34         8  South           Cash       True              1            56
# 35         5  North           Cash       True              5            41
# 36         8   East    Credit Card       True              3            53
# 37         2  North    Credit Card       True              1            23
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     1.4  Not Returned  Negative          11.24
# 1    Other             Food     3.8      Returned   Neutral          19.75
# 2     Male         Clothing     3.3  Not Returned  Negative           7.62
# 3     Male         Clothing     4.8  Not Returned   Neutral           5.09
# 4    Other         Clothing     1.4      Returned   Neutral            NaN
# 5     Male             Food     1.0      Returned  Positive           5.37
# 6     Male            Books     2.5  Not Returned  Positive          12.71
# 7     Male             Food     2.7      Returned  Positive            NaN
# 8   Female      Electronics     2.3  Not Returned   Neutral           6.27
# 9     Male         Clothing     3.0      Returned  Positive            NaN
# 10    Male      Electronics     3.3  Not Returned  Negative          17.64
# 11    Male         Clothing     4.3      Returned  Positive            NaN
# 12  Female      Electronics     2.1  Not Returned   Neutral           7.61
# 13  Female      Electronics     1.7  Not Returned  Negative            NaN
# 14  Female         Clothing     4.2  Not Returned  Negative           8.08
# 15   Other         Clothing     2.3  Not Returned  Negative          18.01
# 16    Male         Clothing     4.1      Returned   Neutral            NaN
# 17    Male            Books     1.9  Not Returned  Negative            NaN
# 18  Female            Books     2.5      Returned  Negative            NaN
# 19   Other         Clothing     1.1  Not Returned   Neutral           7.16
# 20  Female             Food     2.7  Not Returned  Negative            NaN
# 21    Male         Clothing     4.8  Not Returned   Neutral            NaN
# 22  Female            Books     1.1      Returned  Positive          19.24
# 23    Male             Food     4.9  Not Returned   Neutral           8.12
# 24  Female         Clothing     3.6      Returned  Positive            NaN
# 25  Female             Food     1.4      Returned   Neutral          12.67
# 26   Other         Clothing     1.2  Not Returned   Neutral          10.70
# 27    Male             Food     4.2  Not Returned   Neutral          12.76
# 28   Other      Electronics     1.2  Not Returned  Positive          10.22
# 29    Male      Electronics     4.0  Not Returned   Neutral          16.26
# 30  Female             Food     4.5  Not Returned  Positive            NaN
# 31    Male             Food     1.9  Not Returned  Negative          11.77
# 32   Other             Food     4.9      Returned  Negative           6.62
# 33    Male             Food     2.0  Not Returned  Negative          19.32
# 34   Other            Books     4.9      Returned   Neutral            NaN
# 35   Other         Clothing     1.2  Not Returned   Neutral          10.70
# 36  Female      Electronics     1.7  Not Returned  Negative            NaN
# 37  Female         Clothing     3.6      Returned  Positive            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0       SAVE10              NaN          1
# 1       SAVE10              NaN          2
# 2       SAVE10              4.2          3
# 3     FREESHIP              4.3          4
# 4     WELCOME5              1.8          5
# 5     FREESHIP              3.3          6
# 6     WELCOME5              4.5          7
# 7     FREESHIP              4.4          8
# 8       SAVE10              3.9          9
# 9     FREESHIP              NaN         10
# 10    WELCOME5              4.0         11
# 11    WELCOME5              2.5         12
# 12      SAVE10              NaN         13
# 13      SAVE10              1.4         14
# 14         nan              NaN         15
# 15    WELCOME5              NaN         16
# 16         nan              NaN         17
# 17         nan              2.0         18
# 18    WELCOME5              3.7         19
# 19    WELCOME5              NaN         20
# 20         nan              NaN         21
# 21         nan              4.1         22
# 22    WELCOME5              3.1         23
# 23         nan              1.5         24
# 24         nan              4.3         25
# 25    FREESHIP              NaN         26
# 26    FREESHIP              1.8         27
# 27    FREESHIP              1.0         28
# 28    WELCOME5              1.9         29
# 29    WELCOME5              NaN         30
# 30    FREESHIP              NaN         31
# 31    WELCOME5              2.2         32
# 32         nan              3.6         33
# 33    FREESHIP              NaN         34
# 34    WELCOME5              3.6         35
# 35    FREESHIP              1.8         36
# 36      SAVE10              1.4         37
# 37         nan              4.3         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 09:**
# </div>

# %%
# 9. Validating Date Formats in a DataFrame
# Write a Pandas program to validate date formats in a DataFrame.

def validate_date_formats(date_column, dataframe):
    if not pd.api.types.is_datetime64_any_dtype(dataframe[date_column]):
        print("Column {:>30} is not a datetime type and will be skipped.".format(date_column))
        return
    else:
        invalid_dates = dataframe[~dataframe[date_column].dt.strftime('%Y-%m-%d').str.match(r'^\d{4}-\d{2}-\d{2}$')]
    if not invalid_dates.empty:
        print("Column {:>30} INVALID DATES DETECTED.\n####### INVALID DATES #######".format(date_column))
        display(invalid_dates)
    else:
        print("Column {:>30} has no invalid dates detected.".format(date_column))

# Apply to all columns
for col in df.columns:
    validate_date_formats(col, df)
# Out:
# Column                           date has no invalid dates detected.
# Column                    customer_id is not a datetime type and will be skipped.
# Column                     product_id is not a datetime type and will be skipped.
# Column                       quantity is not a datetime type and will be skipped.
# Column                          price is not a datetime type and will be skipped.
# Column                       discount is not a datetime type and will be skipped.
# Column                        revenue is not a datetime type and will be skipped.
# Column                       store_id is not a datetime type and will be skipped.
# Column                         region is not a datetime type and will be skipped.
# Column                 payment_method is not a datetime type and will be skipped.
# Column                      is_member is not a datetime type and will be skipped.
# Column                  delivery_days is not a datetime type and will be skipped.
# Column                   customer_age is not a datetime type and will be skipped.
# Column                         gender is not a datetime type and will be skipped.
# Column               product_category is not a datetime type and will be skipped.
# Column                         rating is not a datetime type and will be skipped.
# Column                  return_status is not a datetime type and will be skipped.
# Column                       feedback is not a datetime type and will be skipped.
# Column                  shipping_cost is not a datetime type and will be skipped.
# Column                    coupon_code is not a datetime type and will be skipped.
# Column                delivery_rating is not a datetime type and will be skipped.
# Column                      unique_id is not a datetime type and will be skipped.

# %% [markdown]
# <div class="alert alert-warning">
#
# **10. Ensuring No Missing Values in a Critical Column**
#
# **Write a Pandas program that ensures no missing values in a critical column.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Add 3 duplicate rows
df = pd.concat([df, df.sample(n=3, random_state=42)], ignore_index=True)

# Add 3 more rows with negative price
df = pd.concat([df, pd.DataFrame({
    'date': pd.date_range(start='2023-02-05', periods=3, freq='D'),
    'customer_id': [1500, 1501, 1502],
    'product_id': [150, 151, 152],
    'quantity': [2, 3, 1],
    'price': [-20.00, -15.00, -30.00],  # Negative prices
    'discount': [0.1, 0.2, 0.15],
    'revenue': [0, 0, 0],  # Placeholder; will be recalculated
    'store_id': [5, 6, 7],
    'region': ['North', 'South', 'East'],
    'payment_method': ['Credit Card', 'Cash', 'Online'],
    'is_member': [True, False, True],
    'delivery_days': [3, 4, 2],
    'customer_age': [25, 34, 45],
    'gender': ['Male', 'Female', 'Other'],
    'product_category': ['Electronics', 'Clothing', 'Books'],
    'rating': [4.5, 3.0, 5.0],
    'return_status': ['Not Returned', 'Returned', 'Not Returned'],
    'feedback': ['Positive', 'Neutral', 'Negative'],
})], ignore_index=True)

30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          8   East           Cash      False              4            61
# 1          7   East         Online       True              1            43
# 2          6   West         Online      False              2            22
# 3          2  South    Credit Card      False              4            39
# 4          8   East           Cash       True              2            22
# 5          4  North         Online      False              1            34
# 6          6   West    Credit Card      False              1            20
# 7          9   West    Credit Card       True              1            68
# 8          1  South    Credit Card      False              3            28
# 9          4  South           Cash       True              1            61
# 10         8   West         Online       True              2            42
# 11         1  North           Cash      False              6            44
# 12         1  North         Online      False              1            22
# 13         8   East         Online      False              1            62
# 14         1  North         Online       True              2            43
# 15         4   West           Cash      False              5            34
# 16         5   East         Online      False              6            24
# 17         1  South    Credit Card      False              1            19
# 18         3   East    Credit Card       True              2            39
# 19         8  North           Cash      False              4            61
# 20         5   West         Online       True              5            66
# 21         7   East           Cash       True              5            47
# 22         6   East         Online      False              2            37
# 23         1  North         Online       True              5            23
# 24         4   East         Online       True              1            31
# 25         9   West    Credit Card       True              1            20
# 26         8   West           Cash      False              2            43
# 27         6   East           Cash       True              3            34
# 28         3   West         Online       True              4            45
# 29         7   West         Online      False              1            19
# 30         5   West         Online      False              1            29
# 31         9  North           Cash       True              2            59
# 32         7   East           Cash       True              2            33
# 33         9   West         Online       True              2            32
# 34         1   East           Cash      False              5            67
# 35         8   West           Cash      False              2            43
# 36         8   East         Online      False              1            62
# 37         4   East         Online       True              1            31
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     2.4      Returned  Positive            NaN
# 1    Other             Food     3.9      Returned   Neutral          10.50
# 2    Other            Books     3.0      Returned   Neutral           6.68
# 3     Male             Food     2.7  Not Returned  Negative           9.82
# 4     Male             Food     2.4      Returned   Neutral            NaN
# 5   Female            Books     1.3      Returned   Neutral            NaN
# 6     Male      Electronics     4.1  Not Returned  Positive          18.04
# 7    Other            Books     2.1  Not Returned  Positive            NaN
# 8     Male         Clothing     4.1  Not Returned   Neutral          12.14
# 9     Male            Books     3.7  Not Returned  Positive          13.99
# 10   Other      Electronics     1.2  Not Returned  Negative          11.17
# 11  Female             Food     4.1  Not Returned  Positive          11.79
# 12   Other         Clothing     1.7  Not Returned   Neutral          15.79
# 13  Female         Clothing     3.7      Returned  Negative          15.76
# 14  Female         Clothing     3.1      Returned   Neutral           5.74
# 15    Male      Electronics     4.4  Not Returned  Positive           9.52
# 16    Male            Books     1.7  Not Returned   Neutral          15.16
# 17   Other      Electronics     3.7      Returned  Negative            NaN
# 18   Other             Food     2.7  Not Returned  Negative           9.12
# 19    Male            Books     1.4  Not Returned  Positive           7.90
# 20   Other      Electronics     1.5  Not Returned  Negative           5.92
# 21  Female             Food     2.6      Returned  Negative            NaN
# 22    Male         Clothing     4.2  Not Returned  Negative          13.28
# 23    Male         Clothing     3.0      Returned   Neutral          19.31
# 24   Other      Electronics     3.5      Returned  Negative           5.19
# 25    Male            Books     4.6      Returned   Neutral           9.94
# 26  Female            Books     4.8      Returned   Neutral           9.62
# 27   Other      Electronics     3.2      Returned   Neutral            NaN
# 28   Other         Clothing     5.0  Not Returned  Negative            NaN
# 29    Male            Books     2.8      Returned   Neutral          14.40
# 30  Female             Food     2.8  Not Returned  Positive           8.00
# 31  Female         Clothing     2.6  Not Returned   Neutral          12.14
# 32   Other            Books     4.8  Not Returned  Negative            NaN
# 33    Male      Electronics     2.4  Not Returned  Positive          19.42
# 34    Male         Clothing     3.8      Returned   Neutral          18.32
# 35  Female            Books     4.8      Returned   Neutral           9.62
# 36  Female         Clothing     3.7      Returned  Negative          15.76
# 37   Other      Electronics     3.5      Returned  Negative           5.19
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              4.9          1
# 1     WELCOME5              2.0          2
# 2          nan              NaN          3
# 3     WELCOME5              1.7          4
# 4     FREESHIP              2.5          5
# 5          nan              1.4          6
# 6          nan              1.2          7
# 7       SAVE10              1.9          8
# 8     WELCOME5              2.5          9
# 9     FREESHIP              1.9         10
# 10    FREESHIP              2.1         11
# 11    WELCOME5              1.1         12
# 12    FREESHIP              5.0         13
# 13         nan              4.8         14
# 14         nan              2.8         15
# 15    FREESHIP              2.2         16
# 16    FREESHIP              1.3         17
# 17         nan              4.1         18
# 18    FREESHIP              NaN         19
# 19         nan              1.5         20
# 20      SAVE10              NaN         21
# 21    FREESHIP              1.0         22
# 22    FREESHIP              3.3         23
# 23      SAVE10              3.1         24
# 24      SAVE10              NaN         25
# 25      SAVE10              NaN         26
# 26         nan              1.2         27
# 27    WELCOME5              2.8         28
# 28    FREESHIP              4.7         29
# 29         nan              2.1         30
# 30    WELCOME5              4.4         31
# 31         nan              3.4         32
# 32         nan              NaN         33
# 33         nan              NaN         34
# 34      SAVE10              3.6         35
# 35         nan              1.2         36
# 36         nan              4.8         37
# 37      SAVE10              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 10:**
# </div>

# %%
# 10. Ensuring No Missing Values in a Critical Column
# Write a Pandas program that ensures no missing values in a critical column.

def check_missing_values(column_name, dataframe):
    missing_values = dataframe[column_name].isnull().sum()
    if missing_values > 0:
        print("Column {:>30} has {} missing values.".format(column_name, missing_values))
        display(dataframe[dataframe[column_name].isnull()])
    else:
        print("Column {:>30} has no missing values.".format(column_name))

# Apply to all columns
for col in df.columns:
    check_missing_values(col, df)
# Out:
# Column                           date has no missing values.
# Column                    customer_id has no missing values.
# Column                     product_id has no missing values.
# Column                       quantity has no missing values.
# Column                          price has no missing values.
# Column                       discount has no missing values.
# Column                        revenue has no missing values.
# Column                       store_id has no missing values.
# Column                         region has no missing values.
# Column                 payment_method has no missing values.
# Column                      is_member has no missing values.
# Column                  delivery_days has no missing values.
# Column                   customer_age has no missing values.
# Column                         gender has no missing values.
# Column               product_category has no missing values.
# Column                         rating has no missing values.
# Column                  return_status has no missing values.
# Column                       feedback has no missing values.
# Column                  shipping_cost has 12 missing values.
#          date  customer_id  product_id  quantity    price  discount   revenue  \
# 0  2023-01-01         1220         137         1  9999.99      0.05   42.2085
# 4  2023-01-05         1618         147         7    76.50      0.22  417.6900
# 5  2023-01-06         1618         164         3  7777.77      0.29   97.5540
# 7  2023-01-08         1599         154         8    87.87      0.22  548.3088
# 17 2023-01-18         1077         129         2    64.36      0.09  117.1352
# 21 2023-01-22         1821         181         7    32.68      0.21  180.7204
# 27 2023-01-28         1743         163         5    36.97      0.10  166.3650
# 28 2023-01-29         1500         104         5    13.30      0.27   48.5450
# 32 2023-02-02         1084         103         5    85.20      0.29  302.4600
# 38 2023-02-05         1500         150         2   -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3   -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1   -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 0          8   East           Cash      False              4            61
# 4          8   East           Cash       True              2            22
# 5          4  North         Online      False              1            34
# 7          9   West    Credit Card       True              1            68
# 17         1  South    Credit Card      False              1            19
# 21         7   East           Cash       True              5            47
# 27         6   East           Cash       True              3            34
# 28         3   West         Online       True              4            45
# 32         7   East           Cash       True              2            33
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 0   Female            Books     2.4      Returned  Positive            NaN
# 4     Male             Food     2.4      Returned   Neutral            NaN
# 5   Female            Books     1.3      Returned   Neutral            NaN
# 7    Other            Books     2.1  Not Returned  Positive            NaN
# 17   Other      Electronics     3.7      Returned  Negative            NaN
# 21  Female             Food     2.6      Returned  Negative            NaN
# 27   Other      Electronics     3.2      Returned   Neutral            NaN
# 28   Other         Clothing     5.0  Not Returned  Negative            NaN
# 32   Other            Books     4.8  Not Returned  Negative            NaN
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 0     WELCOME5              4.9          1
# 4     FREESHIP              2.5          5
# 5          nan              1.4          6
# 7       SAVE10              1.9          8
# 17         nan              4.1         18
# 21    FREESHIP              1.0         22
# 27    WELCOME5              2.8         28
# 28    FREESHIP              4.7         29
# 32         nan              NaN         33
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                    coupon_code has 3 missing values.
#          date  customer_id  product_id  quantity  price  discount  revenue  \
# 38 2023-02-05         1500         150         2  -20.0      0.10      0.0
# 39 2023-02-06         1501         151         3  -15.0      0.20      0.0
# 40 2023-02-07         1502         152         1  -30.0      0.15      0.0
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                delivery_rating has 11 missing values.
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 2  2023-01-03         1013         186         4  15.32      0.03   59.4416
# 18 2023-01-19         1058         173         5  52.52      0.26  194.3240
# 20 2023-01-21         1604         156         9  40.20      0.14  311.1480
# 24 2023-01-25         1560         129         3  17.27      0.03   50.2557
# 25 2023-01-26         1307         101         2  86.18      0.22  134.4408
# 32 2023-02-02         1084         103         5  85.20      0.29  302.4600
# 33 2023-02-03         1164         161         5  43.56      0.30  152.4600
# 37 2023-01-25         1560         129         3  17.27      0.03   50.2557
# 38 2023-02-05         1500         150         2 -20.00      0.10    0.0000
# 39 2023-02-06         1501         151         3 -15.00      0.20    0.0000
# 40 2023-02-07         1502         152         1 -30.00      0.15    0.0000
#
#     store_id region payment_method  is_member  delivery_days  customer_age  \
# 2          6   West         Online      False              2            22
# 18         3   East    Credit Card       True              2            39
# 20         5   West         Online       True              5            66
# 24         4   East         Online       True              1            31
# 25         9   West    Credit Card       True              1            20
# 32         7   East           Cash       True              2            33
# 33         9   West         Online       True              2            32
# 37         4   East         Online       True              1            31
# 38         5  North    Credit Card       True              3            25
# 39         6  South           Cash      False              4            34
# 40         7   East         Online       True              2            45
#
#     gender product_category  rating return_status  feedback  shipping_cost  \
# 2    Other            Books     3.0      Returned   Neutral           6.68
# 18   Other             Food     2.7  Not Returned  Negative           9.12
# 20   Other      Electronics     1.5  Not Returned  Negative           5.92
# 24   Other      Electronics     3.5      Returned  Negative           5.19
# 25    Male            Books     4.6      Returned   Neutral           9.94
# 32   Other            Books     4.8  Not Returned  Negative            NaN
# 33    Male      Electronics     2.4  Not Returned  Positive          19.42
# 37   Other      Electronics     3.5      Returned  Negative           5.19
# 38    Male      Electronics     4.5  Not Returned  Positive            NaN
# 39  Female         Clothing     3.0      Returned   Neutral            NaN
# 40   Other            Books     5.0  Not Returned  Negative            NaN
#
#    coupon_code  delivery_rating  unique_id
# 2          nan              NaN          3
# 18    FREESHIP              NaN         19
# 20      SAVE10              NaN         21
# 24      SAVE10              NaN         25
# 25      SAVE10              NaN         26
# 32         nan              NaN         33
# 33         nan              NaN         34
# 37      SAVE10              NaN         38
# 38         NaN              NaN         39
# 39         NaN              NaN         40
# 40         NaN              NaN         41
# Column                      unique_id has no missing values.
