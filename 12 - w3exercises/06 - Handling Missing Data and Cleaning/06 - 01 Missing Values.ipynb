# 15         3   East           Cash  ...              5            23    Male
# 16         1  North           Cash  ...              4            19    Male
# 17         3  North    Credit Card  ...              4            36  Female
# 18         5   East         Online  ...              4            56   Other
# 19         9  North    Credit Card  ...              6            65   Other
# 20         5  South    Credit Card  ...              2            52    Male
# 21         6   West    Credit Card  ...              3            44    Male
# 22         8   West    Credit Card  ...              6            58   Other
# 23         3  North    Credit Card  ...              1            47   Other
# 24         5   East    Credit Card  ...              1            36    Male
# 25         6  North         Online  ...              6            28  Female
# 26         6  North         Online  ...              5            66    Male
# 27         1   East         Online  ...              2            30   Other
# 28         5   West           Cash  ...              5            41  Female
# 29         9  South           Cash  ...              4            25    Male
# 30         7  South    Credit Card  ...              6            51   Other
# 31         3   West    Credit Card  ...              2            34   Other
# 32         7  South         Online  ...              1            33   Other
# 33         3   East    Credit Card  ...              3            21   Other
# 34         6   East         Online  ...              5            23   Other
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0          Clothing    3.3       Returned  Positive           NaN
# 1       Electronics    4.3   Not Returned  Positive         17.87
# 2          Clothing    3.2       Returned   Neutral         12.65
# 3              Food    2.7       Returned  Positive          7.99
# 4              Food    5.0   Not Returned  Negative         10.00
# 5             Books    4.9       Returned  Negative         14.94
# 6       Electronics    5.0   Not Returned  Negative         17.44
# 7          Clothing    3.0   Not Returned   Neutral         14.39
# 8             Books    1.8   Not Returned   Neutral         13.36
# 9              Food    3.7   Not Returned  Negative         18.92
# 10         Clothing    3.7       Returned  Negative         18.58
# 11             Food    2.2   Not Returned   Neutral         12.17
# 12             Food    3.8   Not Returned  Positive          8.28
# 13         Clothing    2.0       Returned  Negative         14.76
# 14      Electronics    1.9   Not Returned   Neutral          6.61
# 15      Electronics    3.4       Returned  Positive         16.96
# 16      Electronics    2.0       Returned  Negative          5.40
# 17             Food    2.6   Not Returned  Negative         17.29
# 18      Electronics    1.6       Returned   Neutral          9.31
# 19             Food    4.7       Returned  Negative         18.54
# 20            Books    3.4       Returned   Neutral           NaN
# 21            Books    1.5       Returned  Positive         13.56
# 22      Electronics    2.3       Returned   Neutral         17.51
# 23            Books    3.9       Returned  Negative         14.80
# 24             Food    3.9       Returned  Positive           NaN
# 25         Clothing    1.1       Returned  Negative         11.11
# 26      Electronics    3.4   Not Returned   Neutral           NaN
# 27         Clothing    1.3       Returned  Negative         13.53
# 28      Electronics    3.0       Returned  Negative           NaN
# 29             Food    4.7   Not Returned   Neutral           NaN
# 30      Electronics    2.3       Returned  Positive         15.36
# 31             Food    3.3       Returned  Positive         19.56
# 32         Clothing    2.9   Not Returned  Negative         11.82
# 33      Electronics    2.6   Not Returned   Neutral           NaN
# 34             Food    2.8   Not Returned  Negative         12.40
#
#     coupon_code delivery_rating
# 0        SAVE10             4.7
# 1           nan             3.2
# 2           nan             4.1
# 3        SAVE10             3.6
# 4        SAVE10             NaN
# 5           nan             4.4
# 6        SAVE10             3.5
# 7           nan             3.4
# 8           nan             4.3
# 9           nan             2.5
# 10          nan             NaN
# 11          nan             1.7
# 12       SAVE10             NaN
# 13          nan             NaN
# 14       SAVE10             NaN
# 15          nan             NaN
# 16     WELCOME5             1.7
# 17          nan             4.3
# 18       SAVE10             NaN
# 19     WELCOME5             1.2
# 20          nan             2.2
# 21     FREESHIP             3.4
# 22     WELCOME5             1.1
# 23     FREESHIP             3.1
# 24          nan             3.2
# 25          nan             2.8
# 26     WELCOME5             NaN
# 27          nan             1.4
# 28     FREESHIP             3.7
# 29          nan             NaN
# 30          nan             NaN
# 31       SAVE10             1.2
# 32          nan             4.3
# 33       SAVE10             1.8
# 34     FREESHIP             NaN
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
print(type(df.isna()))
df.isna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      date  customer_id  product_id  quantity  price  discount  revenue  \
# 0   False        False       False     False  False     False    False
# 1   False        False       False     False  False     False    False
# 2   False        False       False     False  False     False    False
# 3   False        False       False     False  False     False    False
# 4   False        False       False     False  False     False    False
# 5   False        False       False     False  False     False    False
# 6   False        False       False     False  False     False    False
# 7   False        False       False     False  False     False    False
# 8   False        False       False     False  False     False    False
# 9   False        False       False     False  False     False    False
# 10  False        False       False     False  False     False    False
# 11  False        False       False     False  False     False    False
# 12  False        False       False     False  False     False    False
# 13  False        False       False     False  False     False    False
# 14  False        False       False     False  False     False    False
# 15  False        False       False     False  False     False    False
# 16  False        False       False     False  False     False    False
# 17  False        False       False     False  False     False    False
# 18  False        False       False     False  False     False    False
# 19  False        False       False     False  False     False    False
# 20  False        False       False     False  False     False    False
# 21  False        False       False     False  False     False    False
# 22  False        False       False     False  False     False    False
# 23  False        False       False     False  False     False    False
# 24  False        False       False     False  False     False    False
# 25  False        False       False     False  False     False    False
# 26  False        False       False     False  False     False    False
# 27  False        False       False     False  False     False    False
# 28  False        False       False     False  False     False    False
# 29  False        False       False     False  False     False    False
# 30  False        False       False     False  False     False    False
# 31  False        False       False     False  False     False    False
# 32  False        False       False     False  False     False    False
# 33  False        False       False     False  False     False    False
# 34  False        False       False     False  False     False    False
#
#     store_id  region  payment_method  ...  delivery_days  customer_age  \
# 0      False   False           False  ...          False         False
# 1      False   False           False  ...          False         False
# 2      False   False           False  ...          False         False
# 3      False   False           False  ...          False         False
# 4      False   False           False  ...          False         False
# 5      False   False           False  ...          False         False
# 6      False   False           False  ...          False         False
# 7      False   False           False  ...          False         False
# 8      False   False           False  ...          False         False
# 9      False   False           False  ...          False         False
# 10     False   False           False  ...          False         False
# 11     False   False           False  ...          False         False
# 12     False   False           False  ...          False         False
# 13     False   False           False  ...          False         False
# 14     False   False           False  ...          False         False
# 15     False   False           False  ...          False         False
# 16     False   False           False  ...          False         False
# 17     False   False           False  ...          False         False
# 18     False   False           False  ...          False         False
# 19     False   False           False  ...          False         False
# 20     False   False           False  ...          False         False
# 21     False   False           False  ...          False         False
# 22     False   False           False  ...          False         False
# 23     False   False           False  ...          False         False
# 24     False   False           False  ...          False         False
# 25     False   False           False  ...          False         False
# 26     False   False           False  ...          False         False
# 27     False   False           False  ...          False         False
# 28     False   False           False  ...          False         False
# 29     False   False           False  ...          False         False
# 30     False   False           False  ...          False         False
# 31     False   False           False  ...          False         False
# 32     False   False           False  ...          False         False
# 33     False   False           False  ...          False         False
# 34     False   False           False  ...          False         False
#
#     gender  product_category  rating  return_status  feedback  shipping_cost  \
# 0    False             False   False          False     False           True
# 1    False             False   False          False     False          False
# 2    False             False   False          False     False          False
# 3    False             False   False          False     False          False
# 4    False             False   False          False     False          False
# 5    False             False   False          False     False          False
# 6    False             False   False          False     False          False
# 7    False             False   False          False     False          False
# 8    False             False   False          False     False          False
# 9    False             False   False          False     False          False
# 10   False             False   False          False     False          False
# 11   False             False   False          False     False          False
# 12   False             False   False          False     False          False
# 13   False             False   False          False     False          False
# 14   False             False   False          False     False          False
# 15   False             False   False          False     False          False
# 16   False             False   False          False     False          False
# 17   False             False   False          False     False          False
# 18   False             False   False          False     False          False
# 19   False             False   False          False     False          False
# 20   False             False   False          False     False           True
# 21   False             False   False          False     False          False
# 22   False             False   False          False     False          False
# 23   False             False   False          False     False          False
# 24   False             False   False          False     False           True
# 25   False             False   False          False     False          False
# 26   False             False   False          False     False           True
# 27   False             False   False          False     False          False
# 28   False             False   False          False     False           True
# 29   False             False   False          False     False           True
# 30   False             False   False          False     False          False
# 31   False             False   False          False     False          False
# 32   False             False   False          False     False          False
# 33   False             False   False          False     False           True
# 34   False             False   False          False     False          False
#
#     coupon_code  delivery_rating
# 0         False            False
# 1         False            False
# 2         False            False
# 3         False            False
# 4         False             True
# 5         False            False
# 6         False            False
# 7         False            False
# 8         False            False
# 9         False            False
# 10        False             True
# 11        False            False
# 12        False             True
# 13        False             True
# 14        False             True
# 15        False             True
# 16        False            False
# 17        False            False
# 18        False             True
# 19        False            False
# 20        False            False
# 21        False            False
# 22        False            False
# 23        False            False
# 24        False            False
# 25        False            False
# 26        False             True
# 27        False            False
# 28        False            False
# 29        False             True
# 30        False             True
# 31        False            False
# 32        False            False
# 33        False            False
# 34        False             True
#
# [35 rows x 21 columns]

# %%
print(df.isna().any())  
df.isna().sum()
# Out:
# date                False
# customer_id         False
# product_id          False
# quantity            False
# price               False
# discount            False
# revenue             False
# store_id            False
# region              False
# payment_method      False
# is_member           False
# delivery_days       False
# customer_age        False
# gender              False
# product_category    False
# rating              False
# return_status       False
# feedback            False
# shipping_cost        True
# coupon_code         False
# delivery_rating      True
# dtype: bool
# date                 0
# customer_id          0
# product_id           0
# quantity             0
# price                0
# discount             0
# revenue              0
# store_id             0
# region               0
# payment_method       0
# is_member            0
# delivery_days        0
# customer_age         0
# gender               0
# product_category     0
# rating               0
# return_status        0
# feedback             0
# shipping_cost        7
# coupon_code          0
# delivery_rating     11
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **2. Identify Columns with Missing Values**
#
# **Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1312         112         2  13.52      0.17   22.4432
# 1  2023-01-02         1045         119         2  59.47      0.11  105.8566
# 2  2023-01-03         1118         128         5  17.98      0.03   87.2030
# 3  2023-01-04         1688         188         8  61.03      0.18  400.3568
# 4  2023-01-05         1792         111         8  68.47      0.22  427.2528
# 5  2023-01-06         1031         160         7  78.43      0.05  521.5595
# 6  2023-01-07         1950         101         3  25.18      0.27   55.1442
Other
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0             Books    1.2   Not Returned  Positive           NaN
# 1             Books    1.0   Not Returned  Negative           NaN
# 2              Food    3.7       Returned   Neutral         17.10
# 3              Food    1.9   Not Returned  Negative          7.70
# 4       Electronics    2.6       Returned  Negative          8.55
# 5          Clothing    1.7       Returned  Negative         15.23
# 6       Electronics    2.3       Returned  Negative          8.99
# 7              Food    3.1   Not Returned   Neutral         15.21
# 8              Food    2.7   Not Returned  Negative          6.33
# 9       Electronics    4.9       Returned  Positive          5.54
# 10         Clothing    2.3   Not Returned  Negative          5.29
# 11      Electronics    3.6   Not Returned  Negative           NaN
# 12            Books    4.3       Returned  Negative         13.37
# 13      Electronics    1.1       Returned  Negative         10.53
# 14             Food    1.7   Not Returned   Neutral           NaN
# 15             Food    3.6   Not Returned   Neutral         17.70
# 16         Clothing    3.4   Not Returned  Negative          9.27
# 17      Electronics    2.1       Returned  Negative          6.52
# 18            Books    2.6       Returned  Positive         18.08
# 19             Food    1.7   Not Returned   Neutral           NaN
# 20             Food    2.0   Not Returned  Negative          5.44
# 21             Food    3.2   Not Returned  Positive           NaN
# 22      Electronics    2.3       Returned  Negative         11.31
# 23         Clothing    2.8       Returned   Neutral         17.49
# 24             Food    3.7       Returned   Neutral         11.60
# 25      Electronics    1.8       Returned   Neutral         16.53
# 26            Books    1.7       Returned  Negative           NaN
# 27             Food    2.0       Returned  Positive         14.23
# 28         Clothing    2.2   Not Returned   Neutral         17.91
# 29             Food    1.5   Not Returned  Negative         13.55
# 30            Books    2.9       Returned   Neutral         18.45
# 31             Food    4.8       Returned  Positive           NaN
# 32            Books    3.4   Not Returned  Positive           NaN
# 33            Books    4.3   Not Returned  Positive          5.09
# 34             Food    4.4   Not Returned   Neutral         18.31
#
#     coupon_code delivery_rating
# 0      FREESHIP             1.9
# 1        SAVE10             2.8
# 2        SAVE10             NaN
# 3      WELCOME5             NaN
# 4        SAVE10             3.8
# 5      WELCOME5             2.4
# 6      FREESHIP             NaN
# 7           nan             1.2
# 8           nan             4.7
# 9      WELCOME5             4.5
# 10          nan             4.7
# 11       SAVE10             NaN
# 12     FREESHIP             2.3
# 13       SAVE10             1.5
# 14          nan             3.6
# 15          nan             4.6
# 16          nan             4.7
# 17     FREESHIP             NaN
# 18       SAVE10             2.4
# 19          nan             2.8
# 20     FREESHIP             NaN
# 21     WELCOME5             NaN
# 22       SAVE10             3.9
# 23     WELCOME5             3.0
# 24     FREESHIP             NaN
# 25     WELCOME5             3.5
# 26          nan             4.0
# 27       SAVE10             3.4
# 28          nan             2.7
# 29          nan             4.4
# 30          nan             3.5
# 31          nan             1.7
# 32       SAVE10             NaN
# 33          nan             4.1
# 34       SAVE10             4.1
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution
# 18         3  North         Online  ...              1            28  Female
# 19         9  South    Credit Card  ...              5            55  Female
# 20         2  South           Cash  ...              3            63   Other
# 21         6  South    Credit Card  ...              1            45  Female
# 22         2  South         Online  ...              2            43  Female
# 23         7  South         Online  ...              1            52  Female
# 24         5   East         Online  ...              1            69  Female
# 25         3  North    Credit Card  ...              4            50    Male
# 26         6  South           Cash  ...              6            53    Male
# 27         5   East           Cash  ...              4            26   Other
# 28         2   West         Online  ...              4            58  Female
# 29         6   West           Cash  ...              2            40    Male
# 30         3  South         Online  ...              4            37    Male
# 31         9   East           Cash  ...              5            68    Male
# 32         6  South         Online  ...              4            30   Other
# 33         3  South           Cash  ...              1            32   Other
# 34         9  North           Cash  ...              4            63    Male
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0       Electronics    2.7   Not Returned   Neutral           NaN
# 1       Electronics    2.6       Returned  Negative          8.65
# 2             Books    2.9       Returned  Negative          9.32
# 3       Electronics    2.9   Not Returned  Positive         13.58
# 4       Electronics    4.4       Returned  Positive         15.28
# 5             Books    4.3       Returned  Negative         10.27
# 6              Food    1.3   Not Returned  Positive         14.06
# 7       Electronics    4.4   Not Returned  Negative          5.20
# 8             Books    1.1       Returned  Negative           NaN
# 9       Electronics    1.5   Not Returned   Neutral         19.56
# 10         Clothing    1.0       Returned  Positive           NaN
# 11      Electronics    4.7   Not Returned  Positive         15.44
# 12         Clothing    2.0   Not Returned  Negative          8.48
# 13      Electronics    2.1   Not Returned  Positive          5.14
# 14            Books    4.2   Not Returned   Neutral           NaN
# 15            Books    4.6   Not Returned  Positive         13.30
# 16      Electronics    2.2       Returned   Neutral         15.78
# 17             Food    2.3       Returned   Neutral           NaN
# 18         Clothing    4.4   Not Returned  Positive         15.81
# 19         Clothing    2.3   Not Returned  Negative         13.12
# 20             Food    2.6   Not Returned  Positive         14.66
# 21            Books    3.4       Returned  Positive          5.81
# 22      Electronics    2.0   Not Returned   Neutral         12.90
# 23         Clothing    2.1       Returned   Neutral         15.09
# 24         Clothing    4.7   Not Returned   Neutral          8.67
# 25      Electronics    4.6   Not Returned  Positive         17.39
# 26            Books    1.3       Returned   Neutral         18.69
# 27             Food    3.1       Returned  Negative         19.93
# 28            Books    1.3       Returned  Negative           NaN
# 29         Clothing    5.0       Returned  Positive         17.79
# 30         Clothing    3.4       Returned   Neutral           NaN
# 31            Books    2.7   Not Returned  Negative         13.19
# 32      Electronics    2.5       Returned   Neutral          6.16
# 33            Books    1.7       Returned  Positive          7.99
# 34      Electronics    1.5       Returned  Positive          6.77
#
#     coupon_code delivery_rating
# 0      FREESHIP             4.4
# 1           nan             NaN
# 2        SAVE10             1.6
# 3           nan             NaN
# 4           nan             3.1
# 5           nan             1.3
# 6           nan             4.3
# 7      WELCOME5             NaN
# 8           nan             4.5
# 9           nan             4.2
# 10          nan             3.0
# 11          nan             3.6
# 12     WELCOME5             2.1
# 13       SAVE10             2.5
# 14          nan             2.4
# 15          nan             4.6
# 16          nan             1.1
# 17          nan             NaN
# 18       SAVE10             NaN
# 19       SAVE10             NaN
# 20          nan             2.8
# 21          nan             NaN
# 22       SAVE10             NaN
# 23          nan             4.2
# 24          nan             1.7
# 25          nan             NaN
# 26          nan             2.8
# 27     FREESHIP             NaN
# 28          nan             1.8
# 29     FREESHIP             2.2
# 30       SAVE10             1.7
# 31       SAVE10             3.1
# 32       SAVE10             1.2
# 33     WELCOME5             2.1
# 34          nan             4.3
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution
# 1          4   East           Cash  ...    Male              Food     3.2
# 2          5   West           Cash  ...    Male       Electronics     2.1
# 3          3   East         Online  ...    Male             Books     3.1
# 4          8  South           Cash  ...   Other       Electronics     2.2
# 5          2  North    Credit Card  ...   Other             Books     1.6
# 6          5  North           Cash  ...   Other       Electronics     1.1
# 7          8  North         Online  ...    Male          Clothing     2.2
# 8          3  North         Online  ...    Male             Books     2.9
# 9          1   West    Credit Card  ...    Male             Books     4.1
# 10         2  North         Online  ...    Male       Electronics     4.9
# 11         8   West    Credit Card  ...  Female             Books     3.2
# 12         7   West           Cash  ...    Male       Electronics     3.3
# 13         4   East         Online  ...   Other             Books     3.7
# 14         8  North           Cash  ...  Female              Food     3.4
# 15         7  South         Online  ...    Male          Clothing     4.8
# 16         1  North         Online  ...  Female             Books     1.6
# 17         5  South    Credit Card  ...  Female          Clothing     2.7
# 18         4  North         Online  ...    Male             Books     2.7
# 19         8  North    Credit Card  ...    Male       Electronics     2.3
# 20         9  South         Online  ...   Other          Clothing     2.1
# 21         9  South    Credit Card  ...   Other              Food     3.5
# 22         4  North         Online  ...  Female       Electronics     3.4
# 23         5  South           Cash  ...  Female              Food     1.4
# 24         2   East         Online  ...   Other              Food     1.6
# 25         5  North           Cash  ...   Other       Electronics     2.8
# 26         4   West    Credit Card  ...   Other          Clothing     4.7
# 27         8  South           Cash  ...   Other          Clothing     1.4
# 28         5   West           Cash  ...    Male              Food     4.5
# 29         8   West           Cash  ...   Other             Books     1.9
# 30         5   West         Online  ...  Female          Clothing     2.4
# 31         1   West    Credit Card  ...    Male       Electronics     2.0
# 32         1  North         Online  ...    Male              Food     1.3
# 33         6   West    Credit Card  ...  Female              Food     4.3
# 34         5  North         Online  ...    Male       Electronics     2.4
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0       Returned   Neutral           8.19    WELCOME5             3.7
# 1       Returned  Negative          18.57    WELCOME5             3.9
# 2   Not Returned  Negative          19.77         nan             NaN
# 3   Not Returned  Positive          10.19      SAVE10             1.2
# 4   Not Returned  Positive          13.44    WELCOME5             2.9
# 5       Returned   Neutral          16.02      SAVE10             2.3
# 6       Returned   Neutral           5.55    WELCOME5             NaN
# 7   Not Returned   Neutral           6.11         nan             3.7
# 8       Returned   Neutral          11.82         nan             1.5
# 9       Returned  Positive          11.69      SAVE10             1.8
# 10  Not Returned  Positive          14.57      SAVE10             2.4
# 11  Not Returned  Negative           7.11         nan             3.7
# 12  Not Returned   Neutral          19.96         nan             NaN
# 13      Returned   Neutral          10.76         nan             NaN
# 14      Returned  Positive          19.91         nan             4.0
# 15  Not Returned  Positive          11.87      SAVE10             4.1
# 16  Not Returned  Negative           7.43         nan             1.9
# 17      Returned  Positive          10.36      SAVE10             4.4
# 18      Returned   Neutral          16.92    FREESHIP             4.9
# 19      Returned  Negative           9.01         nan             NaN
# 20  Not Returned   Neutral          18.97         nan             NaN
# 21  Not Returned   Neutral          19.43    FREESHIP             NaN
# 22  Not Returned   Neutral          17.05         nan             2.1
# 23      Returned  Positive           8.43      SAVE10             2.6
# 24  Not Returned  Positive          13.00      SAVE10             NaN
# 25  Not Returned  Positive          10.35    FREESHIP             1.3
# 26      Returned   Neutral          12.38         nan             4.3
# 27      Returned  Negative            NaN      SAVE10             4.3
# 28  Not Returned  Positive          11.87    FREESHIP             NaN
# 29      Returned   Neutral          16.88    FREESHIP             1.7
# 30  Not Returned  Positive          10.21      SAVE10             1.1
# 31  Not Returned  Positive          14.61         nan             3.1
# 32      Returned  Negative           7.02    FREESHIP             NaN
# 33      Returned   Neutral          15.33    WELCOME5             NaN
# 34      Returned   Neutral          10.56    FREESHIP             3.8
#
#                  customer_note customer_values
# 0                      unknown         value_5
# 1                      unknown         unknown
# 2                      no_data         value_3
# 3                      unknown         unknown
# 4                      unknown         value_2
# 5                      unknown         value_5
# 6          First-time customer         unknown
# 7               Frequent buyer         value_4
# 8          Used loyalty points         value_1
# 9                      unknown         value_3
# 10              Frequent buyer         value_3
# 11              Frequent buyer         value_2
# 12         Requested gift wrap         unknown
# 13         First-time customer         value_3
# 14         Used loyalty points         unknown
# 15         Used loyalty points         unknown
# 16                     no_data         no_data
# 17              Frequent buyer         no_data
# 18         Used loyalty points         no_data
# 19         Requested gift wrap         value_5
# 20         Requested gift wrap         value_1
# 21                     no_data         unknown
# 22                     unknown         no_data
# 23         First-time customer         unknown
# 24         Requested gift wrap         no_data
# 25              Frequent buyer         value_1
# 26         First-time customer         value_3
# 27                     unknown         unknown
# 28                     no_data         unknown
# 29         First-time customer         unknown
# 30                     unknown         value_2
# 31                     unknown         unknown
# 32  Preferred morning delivery         value_2
# 33              Frequent buyer         no_data
# 34  Preferred morning delivery         value_2
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
df.replace({
    'customer_note': {
        'no_data': np.nan,
        'unknown': np.nan
    },
    'customer_values': {
        'no_data': np.nan,
        'unknown': np.nan
    }
}, inplace=True)

display(df.isna().any())
display(df.isna().sum())
# Out:
# date                False
# customer_id         False
# product_id          False
# quantity            False
# price               False
# discount            False
# revenue             False
# store_id            False
# region              False
# payment_method      False
# is_member           False
# delivery_days       False
# customer_age        False
# gender              False
# product_category    False
# rating              False
# return_status       False
# feedback            False
# shipping_cost        True
# coupon_code         False
# delivery_rating      True
# customer_note        True
# customer_values      True
# dtype: bool
# date                 0
# customer_id          0
# product_id           0
# quantity             0
# price                0
# discount             0
# revenue              0
# store_id             0
# region               0
# payment_method       0
# is_member            0
# delivery_days        0
# customer_age         0
# gender               0
# product_category     0
# rating               0
# return_status        0
# feedback             0
# shipping_cost        1
# coupon_code          0
# delivery_rating     11
# customer_note       14
# customer_values     18
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **5. Drop Rows with Any Missing Value**
#
# **Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         
# 22         9   West    Credit Card  ...   Other              Food     2.7
# 23         9  South         Online  ...  Female          Clothing     3.0
# 24         7   East           Cash  ...   Other          Clothing     4.0
# 25         7  South           Cash  ...  Female             Books     3.1
# 26         8  South    Credit Card  ...   Other             Books     4.5
# 27         7   West           Cash  ...  Female       Electronics     3.4
# 28         9   East    Credit Card  ...    Male             Books     2.6
# 29         8  North           Cash  ...    Male       Electronics     1.2
# 30         9  South           Cash  ...   Other             Books     3.1
# 31         8  North    Credit Card  ...   Other          Clothing     2.5
# 32         8  North    Credit Card  ...  Female              Food     2.4
# 33         4  North           Cash  ...  Female              Food     3.5
# 34         6  North         Online  ...   Other              Food     4.4
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0   Not Returned  Negative          11.98         nan             NaN
# 1       Returned  Positive            NaN    WELCOME5             4.1
# 2   Not Returned  Positive           9.77         nan             3.8
# 3       Returned  Negative          13.84         nan             4.2
# 4       Returned  Negative          18.36    FREESHIP             2.1
# 5       Returned   Neutral          18.73         nan             1.6
# 6       Returned   Neutral            NaN         nan             3.8
# 7       Returned  Negative          16.71      SAVE10             1.1
# 8   Not Returned  Negative           5.16         nan             2.7
# 9       Returned  Negative            NaN      SAVE10             4.9
# 10      Returned   Neutral           8.76      SAVE10             1.4
# 11      Returned   Neutral            NaN      SAVE10             NaN
# 12  Not Returned  Negative           5.92         nan             1.6
# 13      Returned  Positive           5.97      SAVE10             2.8
# 14  Not Returned  Negative            NaN      SAVE10             3.1
# 15  Not Returned  Positive          16.03    WELCOME5             2.5
# 16  Not Returned  Negative           8.92    FREESHIP             2.6
# 17      Returned  Positive            NaN         nan             1.0
# 18      Returned  Positive          13.08    FREESHIP             NaN
# 19  Not Returned  Positive          17.43         nan             2.5
# 20      Returned  Positive           8.40    WELCOME5             NaN
# 21  Not Returned  Negative           7.73         nan             4.2
# 22  Not Returned   Neutral           9.98         nan             1.9
# 23  Not Returned  Positive          17.96         nan             NaN
# 24      Returned  Positive          15.74      SAVE10             NaN
# 25      Returned  Positive           8.37    WELCOME5             NaN
# 26      Returned   Neutral           9.72    FREESHIP             4.0
# 27      Returned   Neutral            NaN         nan             NaN
# 28      Returned  Negative          12.70      SAVE10             4.9
# 29  Not Returned   Neutral          13.75      SAVE10             4.5
# 30  Not Returned  Positive           6.60         nan             NaN
# 31  Not Returned  Negative          11.06         nan             NaN
# 32  Not Returned  Positive          13.11         nan             3.5
# 33  Not Returned  Positive          16.53      SAVE10             2.8
# 34  Not Returned  Positive            NaN      SAVE10             1.6
#
#                  customer_note customer_values
# 0                      unknown         value_5
# 1                      unknown         value_3
# 2   Preferred morning delivery         unknown
# 3                      unknown         value_5
# 4                      no_data         value_4
# 5          First-time customer         no_data
# 6                      no_data         no_data
# 7                      unknown         value_2
# 8          Used loyalty points         no_data
# 9          First-time customer         value_5
# 10         First-time customer         unknown
# 11                     no_data         value_1
# 12         First-time customer         no_data
# 13                     unknown         unknown
# 14                     no_data         unknown
# 15         Requested gift wrap         value_1
# 16  Preferred morning delivery         value_5
# 17                     unknown         value_5
# 18         First-time customer         unknown
# 19                     no_data         unknown
# 20                     no_data         value_4
# 21                     no_data         value_2
# 22                     no_data         value_4
# 23                     no_data         no_data
# 24         First-time customer         value_5
# 25              Frequent buyer         value_3
# 26                     unknown         value_5
# 27         Requested gift wrap         no_data
# 28  Preferred morning delivery         value_4
# 29         Requested gift wrap         value_4
# 30                     unknown         value_4
# 31                     unknown         no_data
# 32                     no_data         no_data
# 33                     no_data         value_1
# 34                     unknown         value_4
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
dropped_df = df.dropna(how='any')
display(dropped_df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 2  2023-01-03         1048         184         4  27.99      0.06  105.2424
# 3  2023-01-04         1144         185         5  71.27      0.10  320.7150
# 4  2023-01-05         1144         106         5  27.20      0.27   99.2800
# 5  2023-01-06         1185         135         6  52.41      0.15  267.2910
# 7  2023-01-08         1683         142         5  36.93      0.22  144.0270
# 8  2023-01-09         1123         191         1  68.43      0.25   51.3225
# 10 2023-01-11         1806         173         7  72.80      0.22  397.4880
# 12 2023-01-13         1781         157         5  12.12      0.16   50.9040
# 13 2023-01-14         1627         123         1  34.87      0.19   28.2447
# 15 2023-01-16         1018         130         3  68.82      0.10  185.8140
# 16 2023-01-17         1593         194         8  70.66      0.12  497.4464
# 19 2023-01-20         1683         188         4  94.88      0.26  280.8448
# 21 2023-01-22         1519         194         5  24.23      0.09  110.2465
# 22 2023-01-23         1207         104         5  48.47      0.00  242.3500
# 26 2023-01-27         1837         128         6  70.58      0.21  334.5492
# 28 2023-01-29         1277         150         6  83.28      0.26  369.7632
# 29 2023-01-30         1339         121         4  70.63      0.16  237.3168
# 32 2023-02-02         1055         116         8  77.67      0.29  441.1656
# 33 2023-02-03         1487         160         6  45.12      0.28  194.9184
#
#     store_id region payment_method  ...  gender  product_category  rating  \
# 2          4   East           Cash  ...    Male       Electronics     4.3
# 3          3   West         Online  ...    Male       Electronics     3.0
# 4          9  North    Credit Card  ...   Other          Clothing     1.1
# 5          5  North         Online  ...   Other              Food     2.9
# 7          6  North           Cash  ...   Other          Clothing     2.2
# 8          3  North           Cash  ...    Male       Electronics     3.6
# 10         1  South           Cash  ...   Other              Food     1.4
# 12         7   East    Credit Card  ...  Female          Clothing     3.4
# 13         3  North         Online  ...  Female              Food     1.6
# 15         2  North         Online  ...    Male             Books     4.2
# 16         1  South           Cash  ...   Other              Food     1.6
# 19         9   East           Cash  ...  Female       Electronics     3.3
# 21         6   East           Cash  ...    Male          Clothing     4.1
# 22         9   West    Credit Card  ...   Other              Food     2.7
# 26         8  South    Credit Card  ...   Other             Books     4.5
# 28         9   East    Credit Card  ...    Male             Books     2.6
# 29         8  North           Cash  ...    Male       Electronics     1.2
# 32         8  North    Credit Card  ...  Female              Food     2.4
# 33         4  North           Cash  ...  Female              Food     3.5
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 2   Not Returned  Positive           9.77         nan             3.8
# 3       Returned  Negative          13.84         nan             4.2
# 4       Returned  Negative          18.36    FREESHIP             2.1
# 5       Returned   Neutral          18.73         nan             1.6
# 7       Returned  Negative          16.71      SAVE10             1.1
# 8   Not Returned  Negative           5.16         nan             2.7
# 10      Returned   Neutral           8.76      SAVE10             1.4
# 12  Not Returned  Negative           5.92         nan             1.6
# 13      Returned  Positive           5.97      SAVE10             2.8
# 15  Not Returned  Positive          16.03    WELCOME5             2.5
# 16  Not Returned  Negative           8.92    FREESHIP             2.6
# 19  Not Returned  Positive          17.43         nan             2.5
# 21  Not Returned  Negative           7.73         nan             4.2
# 22  Not Returned   Neutral           9.98         nan             1.9
# 26      Returned   Neutral           9.72    FREESHIP             4.0
# 28      Returned  Negative          12.70      SAVE10             4.9
# 29  Not Returned   Neutral          13.75      SAVE10             4.5
# 32  Not Returned  Positive          13.11         nan             3.5
# 33  Not Returned  Positive          16.53      SAVE10             2.8
#
#                  customer_note customer_values
# 2   Preferred morning delivery         unknown
# 3                      unknown         value_5
# 4                      no_data         value_4
# 5          First-time customer         no_data
# 7                      unknown         value_2
# 8          Used loyalty points         no_data
# 10         First-time customer         unknown
# 12         First-time customer         no_data
# 13                     unknown         unknown
# 15         Requested gift wrap         value_1
# 16  Preferred morning delivery         value_5
# 19                     no_data         unknown
# 21                     no_data         value_2
# 22                     no_data         value_4
# 26                     unknown         value_5
# 28  Preferred morning delivery         value_4
# 29         Requested gift wrap         value_4
# 32                     no_data         no_data
# 33                     no_data         value_1
#
# [19 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **6. Drop Columns with Any Missing Value**
#
# **Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1935         128         1  37.14      0.02   36.3972
# 1  2023-01-02         1501         129         2  44.16      0.27   64.4736
# 2  2023-01-03         1308         192         8  37.17      0.19  240.8616
# 3  2023-01-04         1419         140         7  70.09      0.18  402.3166
# 4  2023-01-05         1694         146         9  30.70      0.01  273.5370
# 5  2023-01-06         1965         199         1  70.77      0.12   62.2776
# 6  2023-01-07         1932         113         8  97.45      0.16  654.8640
# 7  2023-01-08         1904         195         4  42.89      0.20  137.2480
# 8  2023-01-09         1654         109         4  89.89      0.15  305.6260
# 9  2023-01-10         1401         180         8  80.72      0.25  484.3200
# 10 2023-01-11         1743         157         6  91.25      0.11  487.2750
# 11 2023-01-12         1963         179         2  30.43      0.25   45.6450
# 12 2023-01-13         1844         178         9  78.98      0.25  533.1150
# 13 2023-01-14         1004         199         4  33.74      0.13  117.4152
# 14 2023-01-15         1180         106         4  12.12      0.21   38.2992
# 15 2023-01-16         1416         191         7  52.01      0.14  313.1002
# 16 2023-01-17         1841         195         9  41.43      0.28  268.4664
# 17 2023-01-18         1229         138         9  27.54      0.21  195.8094
# 18 2023-01-19         1114         188         7  31.15      0.25  163.5375
# 19 2023-01-20         1167         118         2  64.88      0.12  114.1888
# 20 2023-01-21         1885         117         5  77.08      0.25  289.0500
# 21 2023-01-22         1347         128         7  59.57      0.20  333.5920
# 22 2023-01-23         1508         181         2  78.56      0.19  127.2672
# 23 2023-01-24         1705         117         9  79.74      0.11  638.7174
# 24 2023-01-25         1014         112         1  89.35      0.28   64.3320
# 25 2023-01-26         1713         140         7  41.93      0.08  270.0292
# 26 2023-01-27         1693         146         7  48.48      0.04  325.7856
# 27 2023-01-28         1014         171         3  77.32      0.02  227.3208
# 28 2023-01-29         1779         177         4  30.54      0.11  108.7224
# 29 2023-01-30         1223         146         5  11.32      0.27   41.3180
# 30 2023-01-31         1780         131         6  63.67      0.14  328.5372
# 31 2023-02-01         1365         121         2  44.92      0.21   70.9736
# 32 2023-02-02         1453         166         6  71.45      0.17  355.8210
# 33 2023-02-03         1708         128         7  82.15      0.07  534.7965
# 34 2023-02-04         1699         132         2  75.13      0.00  150.2600
#
#     store_id region payment_method  ...  gender  product_category  rating  \
# 0          7  North         Online  ...  Female             Books     2.3
# 1          8  South           Cash  ...   Other             Books     1.9
# 2          6  South           Cash  ...  Female       Electronics     1.4
# 3          1  North    Credit Card  ...  Female          Clothing     4.1
# 4          5   West    Credit Card  ...   Other              Food     3.4
# 5          4  South    Credit Card  ...  Female       Electronics     1.4
# 6          5   East         Online  ...  Female          Clothing     5.0
# 7          5   East           Cash  ...   Other             Books     2.8
# 8          8   East    Credit Card  ...  Female          Clothing     4.5
# 9          9  North           Cash  ...  Female       Electronics     4.7
# 10         2  North           Cash  ...   Other          Clothing     1.4
# 11         5  South         Online  ...   Other          Clothing     4.9
# 12         1   East         Online  ...  Female             Books     3.4
# 13         9   East         Online  ...  Female              Food     3.9
# 14         1   East         Online  ...    Male          Clothing     2.3
# 15         8   West           Cash  ...  Female       Electronics     4.3
# 16         6  North         Online  ...   Other             Books     2.2
# 17         6  South         Online  ...  Female              Food     2.7
# 18         9   West           Cash  ...  Female          Clothing     3.7
# 19         9   West         Online  ...  Female       Electronics     3.3
# 20         8  North           Cash  ...    Male             Books     1.1
# 21         3   East         Online  ...   Other       Electronics     4.5
# 22         3   East    Credit Card  ...   Other              Food     4.6
# 23         2  South           Cash  ...    Male          Clothing     2.4
# 24         4  South         Online  ...  Female              Food     4.5
# 25         9   East    Credit Card  ...  Female       Electronics     2.1
# 26         7   West           Cash  ...  Female          Clothing     4.8
# 27         1  North           Cash  ...  Female             Books     4.7
# 28         5   West    Credit Card  ...  Female              Food     3.7
# 29         8   East         Online  ...    Male             Books     4.1
# 30         7   West    Credit Card  ...   Other          Clothing     4.8
# 31         9   East           Cash  ...    Male          Clothing     4.2
# 32         6  South         Online  ...    Male       Electronics     1.4
# 33         7   West         Online  ...  Female              Food     3.4
# 34         1   East    Credit Card  ...   Other              Food     2.6
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0   Not Returned  Positive            NaN         nan             NaN
# 1       Returned  Positive            NaN    WELCOME5             4.0
# 2   Not Returned  Negative           5.01         nan             3.0
# 3   Not Returned  Negative           6.21         nan             4.1
# 4   Not Returned  Negative            NaN    FREESHIP             2.3
# 5   Not Returned   Neutral            NaN      SAVE10             2.1
# 6       Returned  Negative          15.96         nan             1.6
# 7   Not Returned   Neutral            NaN    FREESHIP             1.3
# 8       Returned  Negative          15.66         nan             1.2
# 9   Not Returned  Negative          16.80    FREESHIP             1.6
# 10  Not Returned  Positive           8.83    FREESHIP             2.5
# 11  Not Returned  Positive           7.57         nan             NaN
# 12      Returned  Positive            NaN    WELCOME5             4.9
# 13      Returned  Positive           9.04         nan             4.3
# 14      Returned  Positive          10.69         nan             3.5
# 15  Not Returned  Positive          10.55         nan             NaN
# 16  Not Returned   Neutral           9.73         nan             2.8
# 17  Not Returned  Negative          15.28    FREESHIP             4.8
# 18  Not Returned  Positive          15.06    WELCOME5             1.8
# 19      Returned   Neutral          19.94      SAVE10             NaN
# 20      Returned  Positive            NaN         nan             4.1
# 21  Not Returned  Positive           8.11         nan             3.0
# 22  Not Returned  Negative           6.53    WELCOME5             1.7
# 23  Not Returned  Negative          14.43    FREESHIP             3.4
# 24  Not Returned  Positive            NaN      SAVE10             NaN
# 25  Not Returned  Positive          16.92    FREESHIP             NaN
# 26  Not Returned  Negative            NaN    FREESHIP             1.3
# 27  Not Returned   Neutral          11.27    FREESHIP             3.1
# 28  Not Returned   Neutral            NaN    FREESHIP             3.4
# 29  Not Returned  Positive           7.59         nan             1.7
# 30      Returned  Negative            NaN    WELCOME5             2.9
# 31      Returned   Neutral            NaN      SAVE10             NaN
# 32  Not Returned   Neutral           5.43    FREESHIP             NaN
# 33  Not Returned  Positive           5.84    FREESHIP             NaN
# 34  Not Returned  Positive          13.06    WELCOME5             1.6
#
#                  customer_note customer_values
# 0                      no_data         no_data
# 1                      no_data         value_5
# 2                      no_data         value_2
# 3   Preferred morning delivery         unknown
# 4                      unknown         value_2
# 5                      no_data         unknown
# 6                      unknown         value_1
# 7                      no_data         no_data
# 8                      unknown         no_data
# 9          Requested gift wrap         unknown
# 10         Requested gift wrap         value_3
# 11  Preferred morning delivery         value_5
# 12         First-time customer         no_data
# 13                     unknown         value_1
# 14         Requested gift wrap         value_4
# 15              Frequent buyer         unknown
# 16                     no_data         no_data
# 17         First-time customer         no_data
# 18  Preferred morning delivery         value_5
# 19                     unknown         no_data
# 20         Used loyalty points         unknown
# 21              Frequent buyer         value_1
# 22                     no_data         value_3
# 23         Requested gift wrap         value_2
# 24         First-time customer         value_4
# 25                     no_data         value_5
# 26                     no_data         unknown
# 27                     unknown         value_5
# 28  Preferred morning delivery         no_data
# 29                     unknown         unknown
# 30         Used loyalty points         value_3
# 31         Requested gift wrap         no_data
# 32         Used loyalty points         value_2
# 33                     no_data         no_data
# 34                     no_data         value_1
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 06:**
# </div>

# %%
# Drop columns with any missing value
dropped_df = df.dropna(axis=1, how='any')
display(dropped_df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1935         128         1  37.14      0.02   36.3972
# 1  2023-01-02         1501         129         2  44.16      0.27   64.4736
# 2  2023-01-03         1308         192         8  37.17      0.19  240.8616
# 3  2023-01-04         1419         140         7  70.09      0.18  402.3166
# 4  2023-01-05         1694         146         9  30.70      0.01  273.5370
# 5  2023-01-06         1965         199         1  70.77      0.12   62.2776
# 6  2023-01-07         1932         113         8  97.45      0.16  654.8640
# 7  2023-01-08         1904         195         4  42.89      0.20  137.2480
# 31         9   East           Cash  ...              4            32    Male
# 32         6  South         Online  ...              6            36    Male
# 33         7   West         Online  ...              2            36  Female
# 34         1   East    Credit Card  ...              4            54   Other
#
#    product_category rating  return_status  feedback coupon_code  \
# 0             Books    2.3   Not Returned  Positive         nan
# 1             Books    1.9       Returned  Positive    WELCOME5
# 2       Electronics    1.4   Not Returned  Negative         nan
# 3          Clothing    4.1   Not Returned  Negative         nan
# 4              Food    3.4   Not Returned  Negative    FREESHIP
# 5       Electronics    1.4   Not Returned   Neutral      SAVE10
# 6          Clothing    5.0       Returned  Negative         nan
# 7             Books    2.8   Not Returned   Neutral    FREESHIP
# 8          Clothing    4.5       Returned  Negative         nan
# 9       Electronics    4.7   Not Returned  Negative    FREESHIP
# 10         Clothing    1.4   Not Returned  Positive    FREESHIP
# 11         Clothing    4.9   Not Returned  Positive         nan
# 12            Books    3.4       Returned  Positive    WELCOME5
# 13             Food    3.9       Returned  Positive         nan
# 14         Clothing    2.3       Returned  Positive         nan
# 15      Electronics    4.3   Not Returned  Positive         nan
# 16            Books    2.2   Not Returned   Neutral         nan
# 17             Food    2.7   Not Returned  Negative    FREESHIP
# 18         Clothing    3.7   Not Returned  Positive    WELCOME5
# 19      Electronics    3.3       Returned   Neutral      SAVE10
# 20            Books    1.1       Returned  Positive         nan
# 21      Electronics    4.5   Not Returned  Positive         nan
# 22             Food    4.6   Not Returned  Negative    WELCOME5
# 23         Clothing    2.4   Not Returned  Negative    FREESHIP
# 24             Food    4.5   Not Returned  Positive      SAVE10
# 25      Electronics    2.1   Not Returned  Positive    FREESHIP
# 26         Clothing    4.8   Not Returned  Negative    FREESHIP
# 27            Books    4.7   Not Returned   Neutral    FREESHIP
# 28             Food    3.7   Not Returned   Neutral    FREESHIP
# 29            Books    4.1   Not Returned  Positive         nan
# 30         Clothing    4.8       Returned  Negative    WELCOME5
# 31         Clothing    4.2       Returned   Neutral      SAVE10
# 32      Electronics    1.4   Not Returned   Neutral    FREESHIP
# 33             Food    3.4   Not Returned  Positive    FREESHIP
# 34             Food    2.6   Not Returned  Positive    WELCOME5
#
#                  customer_note customer_values
# 0                      no_data         no_data
# 1                      no_data         value_5
# 2                      no_data         value_2
# 3   Preferred morning delivery         unknown
# 4                      unknown         value_2
# 5                      no_data         unknown
# 6                      unknown         value_1
# 7                      no_data         no_data
# 8                      unknown         no_data
# 9          Requested gift wrap         unknown
# 10         Requested gift wrap         value_3
# 11  Preferred morning delivery         value_5
# 12         First-time customer         no_data
# 13                     unknown         value_1
# 14         Requested gift wrap         value_4
# 15              Frequent buyer         unknown
# 16                     no_data         no_data
# 17         First-time customer         no_data
# 18  Preferred morning delivery         value_5
# 19                     unknown         no_data
# 20         Used loyalty points         unknown
# 21              Frequent buyer         value_1
# 22                     no_data         value_3
# 23         Requested gift wrap         value_2
# 24         First-time customer         value_4
# 25                     no_data         value_5
# 26                     no_data         unknown
# 27                     unknown         value_5
# 28  Preferred morning delivery         no_data
# 29                     unknown         unknown
# 30         Used loyalty points         value_3
# 31         Requested gift wrap         no_data
# 32         Used loyalty points         value_2
# 33                     no_data         no_data
# 34                     no_data         value_1
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
#
# 35        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        1.0  North           Cash  ...            Books     2.2
# 1        4.0  South    Credit Card  ...             Food     4.8
# 2        5.0   West         Online  ...             Food     2.1
# 3        9.0   West    Credit Card  ...      Electronics     4.1
# 4        4.0  North         Online  ...             Food     2.2
# 5        5.0   West         Online  ...            Books     3.5
# 6        8.0  South    Credit Card  ...            Books     1.4
# 7        4.0  South    Credit Card  ...         Clothing     3.0
# 8        9.0   West         Online  ...      Electronics     4.6
# 9        3.0  North    Credit Card  ...            Books     1.3
# 10       5.0   East    Credit Card  ...             Food     3.4
# 11       1.0   East           Cash  ...            Books     3.6
# 12       7.0   West           Cash  ...      Electronics     4.4
# 13       9.0   West    Credit Card  ...         Clothing     4.8
# 14       9.0   West           Cash  ...            Books     2.9
# 15       4.0   East           Cash  ...            Books     3.9
# 16       9.0  North           Cash  ...      Electronics     4.2
# 17       7.0   West           Cash  ...             Food     1.8
# 18       4.0  South         Online  ...            Books     4.8
# 19       7.0   West         Online  ...      Electronics     2.0
# 20       9.0  South    Credit Card  ...         Clothing     2.1
# 21       9.0  South           Cash  ...      Electronics     4.4
# 22       7.0  North         Online  ...      Electronics     2.3
# 23       7.0   West           Cash  ...         Clothing     2.6
# 24       6.0  South         Online  ...             Food     1.3
# 25       9.0   West           Cash  ...             Food     2.1
# 26       7.0  North           Cash  ...            Books     3.3
# 27       4.0  North    Credit Card  ...             Food     4.8
# 28       9.0   West         Online  ...      Electronics     1.8
# 29       2.0  South           Cash  ...            Books     3.4
# 30       6.0  North    Credit Card  ...      Electronics     2.5
# 31       1.0  North    Credit Card  ...      Electronics     2.2
# 32       2.0   East         Online  ...            Books     4.7
# 33       7.0   West           Cash  ...         Clothing     4.1
# 34       6.0  North    Credit Card  ...         Clothing     4.2
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned  Negative         17.67     FREESHIP             1.7
# 1        Returned   Neutral          6.24          nan             NaN
# 2        Returned  Positive         15.86       SAVE10             NaN
# 3    Not Returned  Positive         19.03     WELCOME5             NaN
# 4        Returned  Positive          8.30       SAVE10             NaN
# 5    Not Returned  Positive         11.23     FREESHIP             4.0
# 6        Returned  Negative         14.99     WELCOME5             NaN
# 7        Returned  Positive         19.47          nan             4.6
# 8    Not Returned   Neutral          6.30     WELCOME5             NaN
# 9    Not Returned   Neutral           NaN          nan             NaN
# 10       Returned  Positive         10.32     WELCOME5             3.3
# 11   Not Returned  Negative         18.62     WELCOME5             1.4
# 12       Returned  Positive         18.90          nan             3.6
# 13   Not Returned  Positive          6.36          nan             NaN
# 14       Returned  Negative           NaN          nan             4.2
# 15   Not Returned  Negative         12.01          nan             1.8
# 16       Returned  Positive          8.96     WELCOME5             2.0
# 17       Returned  Positive         13.68     WELCOME5             3.2
# 18   Not Returned  Negative         12.25     WELCOME5             NaN
# 19   Not Returned  Negative          9.33     WELCOME5             NaN
# 20   Not Returned  Positive         18.00     WELCOME5             NaN
# 21   Not Returned  Positive         11.10       SAVE10             2.0
# 22       Returned   Neutral         17.79          nan             2.0
# 23   Not Returned  Positive         14.96          nan             NaN
# 24   Not Returned  Negative          7.82       SAVE10             2.7
# 25   Not Returned  Positive         15.86          nan             NaN
# 26   Not Returned  Positive         19.32       SAVE10             NaN
# 27   Not Returned  Negative           NaN       SAVE10             3.7
# 28   Not Returned  Positive         12.95     WELCOME5             NaN
# 29   Not Returned   Neutral         19.88          nan             3.8
# 30       Returned   Neutral          8.21     FREESHIP             3.3
# 31       Returned  Negative         11.82          nan             1.3
# 32   Not Returned   Neutral         18.25     FREESHIP             2.9
# 33   Not Returned  Negative         15.67       SAVE10             1.1
# 34   Not Returned  Negative          6.67     FREESHIP             2.0
# 35            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0          Used loyalty points          value_4            NaN
# 1   Preferred morning delivery          value_1            NaN
# 2               Frequent buyer          value_5            NaN
# 3                      unknown          no_data            NaN
# 4                      unknown          unknown            NaN
# 5               Frequent buyer          value_2            NaN
# 6                      no_data          value_3            NaN
# 7                      unknown          unknown            NaN
# 8                      no_data          unknown            NaN
# 9   Preferred morning delivery          value_3            NaN
# 10  Preferred morning delivery          no_data            NaN
# 11         First-time customer          value_4            NaN
# 12  Preferred morning delivery          value_5            NaN
# 13                     unknown          unknown            NaN
# 14         Requested gift wrap          no_data            NaN
# 15         Used loyalty points          no_data            NaN
# 16  Preferred morning delivery          unknown            NaN
# 17                     unknown          value_1            NaN
# 18                     no_data          value_2            NaN
# 19         Used loyalty points          value_2            NaN
# 20                     unknown          value_5            NaN
# 21                     no_data          unknown            NaN
# 22         First-time customer          value_1            NaN
# 23                     unknown          value_1            NaN
# 24                     unknown          value_1            NaN
# 25                     unknown          value_1            NaN
# 26         Requested gift wrap          unknown            NaN
# 27                     unknown          no_data            NaN
# 28         First-time customer          no_data            NaN
# 29         First-time customer          value_2            NaN
# 30                     no_data          unknown            NaN
# 31         Requested gift wrap          value_5            NaN
# 32         Used loyalty points          value_5            NaN
# 33                     unknown          value_5            NaN
# 34                     no_data          value_4            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 07:**
# </div>

# %%
# Write a Pandas program to drop the rows where all elements are missing in a given DataFrame
df_dropped = df.dropna(how='all')

# Display the DataFrame after dropping rows
display(df_dropped)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01       1076.0       129.0       4.0  58.96      0.01  233.4816
# 1  2023-01-02       1398.0       141.0       7.0  53.28      0.11  331.9344
# 2  2023-01-03       1426.0       146.0       7.0  87.98      0.20  492.6880
# 3  2023-01-04       1431.0       183.0       7.0  65.82      0.25  345.5550
# 4  2023-01-05       1169.0       160.0       1.0  16.52      0.14   14.2072
# 5  2023-01-06       1543.0       110.0       6.0  31.23      0.26  138.6612
# 6  2023-01-07       1461.0       159.0       4.0  39.37      0.26  116.5352
# 7  2023-01-08       1555.0       188.0       5.0  46.71      0.27  170.4915
# 8  2023-01-09       1379.0       130.0       8.0  83.96      0.28  483.6096
# 9  2023-01-10       1465.0       141.0       6.0  15.08      0.06   85.0512
# 10 2023-01-11       1449.0       118.0       9.0  30.64      0.13  239.9112
# 11 2023-01-12       1001.0       122.0       4.0  67.61      0.28  194.7168
# 12 2023-01-13       1648.0       123.0       2.0  15.58      0.09   28.3556
# 13 2023-01-14       1505.0       185.0       7.0  13.00      0.02   89.1800
# 14 2023-01-15       1240.0       169.0       3.0  61.15      0.14  157.7670
# 15 2023-01-16       1319.0       109.0       5.0  57.36      0.18  235.1760
# 16 2023-01-17       1204.0       159.0       1.0  39.87      0.15   33.8895
# 17 2023-01-18       1650.0       150.0       1.0  65.90      0.09   59.9690
# 18 2023-01-19       1660.0       112.0       4.0  85.50      0.13  297.5400
# 19 2023-01-20       1092.0       134.0       5.0  23.79      0.27   86.8335
# 20 2023-01-21       1719.0       190.0       3.0  81.63      0.20  195.9120
# 21 2023-01-22       1179.0       137.0       5.0  78.71      0.01  389.6145
# 22 2023-01-23       1464.0       108.0       8.0  93.14      0.19  603.5472
# 23 2023-01-24       1473.0       137.0       8.0  96.49      0.17  640.6936
# 24 2023-01-25       1568.0       109.0       9.0  87.20      0.16  659.2320
# 25 2023-01-26       1428.0       148.0       9.0  36.24      0.13  283.7592
# 26 2023-01-27       1168.0       172.0       6.0  57.89      0.23  267.4518
# 27 2023-01-28       1651.0       101.0       9.0  86.04      0.03  751.1292
# 28 2023-01-29       1012.0       163.0       4.0  68.14      0.00  272.5600
# 29 2023-01-30       1330.0       110.0       7.0  92.75      0.25  486.9375
# 30 2023-01-31       1270.0       102.0       2.0  87.14      0.23  134.1956
# 31 2023-02-01       1550.0       190.0       1.0  59.54      0.01   58.9446
# 32 2023-02-02       1098.0       173.0       9.0  40.77      0.10  330.2370
# 33 2023-02-03       1007.0       165.0       9.0  78.46      0.19  571.9734
# 34 2023-02-04       1408.0       118.0       8.0  21.80      0.10  156.9600
#
#     store_id region payment_method  ... product_category  rating  \
# 0        1.0  North           Cash  ...            Books     2.2
# 1        4.0  South    Credit Card  ...             Food     4.8
# 2        5.0   West         Online  ...             Food     2.1
# 3        9.0   West    Credit Card  ...      Electronics     4.1
# 4        4.0  North         Online  ...             Food     2.2
# 5        5.0   West         Online  ...            Books     3.5
# 6        8.0  South    Credit Card  ...            Books     1.4
# 7        4.0  South    Credit Card  ...         Clothing     3.0
# 8        9.0   West         Online  ...      Electronics     4.6
# 9        3.0  North    Credit Card  ...            Books     1.3
# 10       5.0   East    Credit Card  ...             Food     3.4
# 11       1.0   East           Cash  ...            Books     3.6
# 12       7.0   West           Cash  ...      Electronics     4.4
# 13       9.0   West    Credit Card  ...         Clothing     4.8
# 14       9.0   West           Cash  ...            Books     2.9
# 15       4.0   East           Cash  ...            Books     3.9
# 16       9.0  North           Cash  ...      Electronics     4.2
# 17       7.0   West           Cash  ...             Food     1.8
# 18       4.0  South         Online  ...            Books     4.8
# 19       7.0   West         Online  ...      Electronics     2.0
# 20       9.0  South    Credit Card  ...         Clothing     2.1
# 21       9.0  South           Cash  ...      Electronics     4.4
# 22       7.0  North         Online  ...      Electronics     2.3
# 23       7.0   West           Cash  ...         Clothing     2.6
# 24       6.0  South         Online  ...             Food     1.3
# 25       9.0   West           Cash  ...             Food     2.1
# 26       7.0  North           Cash  ...            Books     3.3
# 27       4.0  North    Credit Card  ...             Food     4.8
# 28       9.0   West         Online  ...      Electronics     1.8
# 29       2.0  South           Cash  ...            Books     3.4
# 30       6.0  North    Credit Card  ...      Electronics     2.5
# 31       1.0  North    Credit Card  ...      Electronics     2.2
# 32       2.0   East         Online  ...            Books     4.7
# 33       7.0   West           Cash  ...         Clothing     4.1
# 34       6.0  North    Credit Card  ...         Clothing     4.2
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned  Negative         17.67     FREESHIP             1.7
# 1        Returned   Neutral          6.24          nan             NaN
# 2        Returned  Positive         15.86       SAVE10             NaN
# 3    Not Returned  Positive         19.03     WELCOME5             NaN
# 4        Returned  Positive          8.30       SAVE10             NaN
# 5    Not Returned  Positive         11.23     FREESHIP             4.0
# 6        Returned  Negative         14.99     WELCOME5             NaN
# 7        Returned  Positive         19.47          nan             4.6
# 8    Not Returned   Neutral          6.30     WELCOME5             NaN
# 9    Not Returned   Neutral           NaN          nan             NaN
# 10       Returned  Positive         10.32     WELCOME5             3.3
# 11   Not Returned  Negative         18.62     WELCOME5             1.4
# 12       Returned  Positive         18.90          nan             3.6
# 13   Not Returned  Positive          6.36          nan             NaN
# 14       Returned  Negative           NaN          nan             4.2
# 15   Not Returned  Negative         12.01          nan             1.8
# 16       Returned  Positive          8.96     WELCOME5             2.0
# 17       Returned  Positive         13.68     WELCOME5             3.2
# 18   Not Returned  Negative         12.25     WELCOME5             NaN
# 19   Not Returned  Negative          9.33     WELCOME5             NaN
# 20   Not Returned  Positive         18.00     WELCOME5             NaN
# 21   Not Returned  Positive         11.10       SAVE10             2.0
# 22       Returned   Neutral         17.79          nan             2.0
# 23   Not Returned  Positive         14.96          nan             NaN
# 24   Not Returned  Negative          7.82       SAVE10             2.7
# 25   Not Returned  Positive         15.86          nan             NaN
# 26   Not Returned  Positive         19.32       SAVE10             NaN
# 27   Not Returned  Negative           NaN       SAVE10             3.7
# 28   Not Returned  Positive         12.95     WELCOME5             NaN
# 29   Not Returned   Neutral         19.88          nan             3.8
# 30       Returned   Neutral          8.21     FREESHIP             3.3
# 31       Returned  Negative         11.82          nan             1.3
# 32   Not Returned   Neutral         18.25     FREESHIP             2.9
# 33   Not Returned  Negative         15.67       SAVE10             1.1
# 34   Not Returned  Negative          6.67     FREESHIP             2.0
#
#                  customer_note  customer_values all_nan_column
# 0          Used loyalty points          value_4            NaN
# 1   Preferred morning delivery          value_1            NaN
# 2               Frequent buyer          value_5            NaN
# 3                      unknown          no_data            NaN
# 4                      unknown          unknown            NaN
# 5               Frequent buyer          value_2            NaN
# 6                      no_data          value_3            NaN
# 7                      unknown          unknown            NaN
# 8                      no_data          unknown            NaN
# 9   Preferred morning delivery          value_3            NaN
# 10  Preferred morning delivery          no_data            NaN
# 11         First-time customer          value_4            NaN
# 12  Preferred morning delivery          value_5            NaN
# 13                     unknown          unknown            NaN
# 14         Requested gift wrap          no_data            NaN
# 15         Used loyalty points          no_data            NaN
# 16  Preferred morning delivery          unknown            NaN
# 17                     unknown          value_1            NaN
# 18                     no_data          value_2            NaN
# 19         Used loyalty points          value_2            NaN
# 20                     unknown          value_5            NaN
# 21                     no_data          unknown            NaN
# 22         First-time customer          value_1            NaN
# 23                     unknown          value_1            NaN
# 24                     unknown          value_1            NaN
# 25                     unknown          value_1            NaN
# 26         Requested gift wrap          unknown            NaN
# 27                     unknown          no_data            NaN
# 28         First-time customer          no_data            NaN
# 29         First-time customer          value_2            NaN
# 30                     no_data          unknown            NaN
# 31         Requested gift wrap          value_5            NaN
# 32         Used loyalty points          value_5            NaN
# 33                     unknown          value_5            NaN
# 34                     no_data          value_4            NaN
#
# [35 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
#
# 35        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        8.0   East           Cash  ...      Electronics     3.1
# 1        5.0   West         Online  ...             Food     1.9
# 2        5.0  South    Credit Card  ...            Books     3.9
# 3        7.0  North         Online  ...            Books     2.1
# 4        4.0  North         Online  ...            Books     1.1
# 5        3.0   West           Cash  ...            Books     3.3
# 6        3.0  South    Credit Card  ...      Electronics     4.4
# 7        3.0  South    Credit Card  ...      Electronics     1.0
# 8        6.0   West    Credit Card  ...            Books     1.3
# 9        9.0   West           Cash  ...             Food     1.1
# 10       7.0  South         Online  ...      Electronics     3.5
# 11       6.0   East         Online  ...            Books     4.6
# 12       6.0   East           Cash  ...         Clothing     4.3
# 13       5.0   East           Cash  ...      Electronics     3.3
# 14       2.0  North    Credit Card  ...      Electronics     4.5
# 15       6.0   West         Online  ...            Books     3.4
# 16       2.0   West         Online  ...         Clothing     2.7
# 17       1.0  North    Credit Card  ...         Clothing     1.5
# 18       4.0  South    Credit Card  ...      Electronics     4.1
# 19       1.0  South    Credit Card  ...      Electronics     4.8
# 20       8.0   West           Cash  ...         Clothing     4.2
# 21       1.0  South           Cash  ...            Books     1.6
# 22       4.0  South         Online  ...      Electronics     4.5
# 23       5.0   East    Credit Card  ...            Books     4.1
# 24       6.0  North           Cash  ...      Electronics     3.2
# 25       7.0  South    Credit Card  ...      Electronics     2.3
# 26       7.0  South    Credit Card  ...            Books     3.8
# 27       6.0   West         Online  ...             Food     3.4
# 28       2.0   West           Cash  ...         Clothing     4.8
# 29       6.0  South         Online  ...            Books     3.1
# 30       8.0   West         Online  ...            Books     3.2
# 31       8.0  South           Cash  ...            Books     2.7
# 32       5.0  North         Online  ...             Food     2.1
# 33       9.0  North         Online  ...            Books     3.3
# 34       5.0   West    Credit Card  ...      Electronics     1.3
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned  Negative         15.36          nan             NaN
# 1        Returned   Neutral         10.38          nan             1.4
# 2    Not Returned  Negative         12.81     FREESHIP             3.2
# 3        Returned  Negative         18.80     WELCOME5             NaN
# 4    Not Returned  Positive           NaN     WELCOME5             2.2
# 5        Returned  Positive         12.44     WELCOME5             4.6
# 6        Returned   Neutral          7.89       SAVE10             1.2
# 7    Not Returned  Negative           NaN          nan             2.2
# 8        Returned   Neutral           NaN          nan             4.2
# 9        Returned  Positive         16.01     WELCOME5             4.0
# 10       Returned   Neutral           NaN     WELCOME5             1.2
# 11   Not Returned   Neutral           NaN     FREESHIP             2.7
# 12       Returned  Negative         11.31          nan             4.8
# 13   Not Returned  Positive          8.82          nan             1.9
# 14   Not Returned  Negative         12.43     FREESHIP             NaN
# 15       Returned   Neutral          9.23     FREESHIP             4.3
# 16   Not Returned   Neutral         18.64          nan             NaN
# 17   Not Returned   Neutral         10.65          nan             1.7
# 18   Not Returned  Positive           NaN     WELCOME5             NaN
# 19   Not Returned   Neutral           NaN       SAVE10             NaN
# 20       Returned   Neutral         19.67          nan             1.2
# 21       Returned   Neutral         10.26     WELCOME5             2.1
# 22       Returned   Neutral         16.97          nan             NaN
# 23       Returned   Neutral         11.29       SAVE10             NaN
# 24   Not Returned   Neutral         13.01          nan             NaN
# 25       Returned  Negative         13.73     FREESHIP             NaN
# 26       Returned   Neutral         18.64     WELCOME5             NaN
# 27       Returned   Neutral         12.15     FREESHIP             NaN
# 28   Not Returned   Neutral          5.30     WELCOME5             NaN
# 29   Not Returned   Neutral          7.23     FREESHIP             2.2
# 30   Not Returned  Positive           NaN          nan             2.3
# 31   Not Returned  Negative         18.92          nan             3.8
# 32       Returned  Positive         11.29          nan             2.0
# 33       Returned  Positive          8.13     WELCOME5             1.5
# 34   Not Returned  Positive         19.14     FREESHIP             1.4
# 35            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0                      no_data          value_3            NaN
# 1          Requested gift wrap          value_2            NaN
# 2                      no_data          unknown            NaN
# 3                      no_data          value_1            NaN
# 4               Frequent buyer          value_5            NaN
# 5                      unknown          no_data            NaN
# 6               Frequent buyer          unknown            NaN
# 7          Used loyalty points          no_data            NaN
# 8               Frequent buyer          no_data            NaN
# 9          First-time customer          value_3            NaN
# 10         Requested gift wrap          value_4            NaN
# 11                     unknown          no_data            NaN
# 12                     no_data          no_data            NaN
# 13                     unknown          unknown            NaN
# 14                     no_data          no_data            NaN
# 15         Requested gift wrap          value_3            NaN
# 16         First-time customer          value_5            NaN
# 17                     no_data          unknown            NaN
# 18                     unknown          value_3            NaN
# 19                     unknown          unknown            NaN
# 20                     no_data          no_data            NaN
# 21                     unknown          no_data            NaN
# 22              Frequent buyer          value_3            NaN
# 23                     unknown          no_data            NaN
# 24                     no_data          unknown            NaN
# 25                     unknown          no_data            NaN
# 26  Preferred morning delivery          value_2            NaN
# 27                     no_data          value_5            NaN
# 28                     unknown          value_4            NaN
# 29                     no_data          value_2            NaN
# 30         First-time customer          unknown            NaN
# 31                     no_data          value_3            NaN
# 32                     unknown          value_3            NaN
# 33         Used loyalty points          no_data            NaN
# 34              Frequent buyer          unknown            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 08:**
# </div>

# %%
pd.DataFrame.sum?
# Out:
# Signature:
# pd.DataFrame.sum(
#     self,
#     axis: 'Axis | None' = 0,
#     skipna: 'bool' = True,
#     numeric_only: 'bool' = False,
#     min_count: 'int' = 0,
#     **kwargs,
# )
# Docstring:
# Return the sum of the values over the requested axis.
#
# This is equivalent to the method ``numpy.sum``.
#
# Parameters
# ----------
# axis : {index (0), columns (1)}
#     Axis for the function to be applied on.
#     For `Series` this parameter is unused and defaults to 0.
#
#     .. warning::
#
#         The behavior of DataFrame.sum with ``axis=None`` is deprecated,
#         in a future version this will reduce over both axes and return a scalar
#         To retain the old behavior, pass axis=0 (or do not pass axis).
#
#     .. versionadded:: 2.0.0
#
# skipna : bool, default True
#     Exclude NA/null values when computing the result.
# numeric_only : bool, default False
#     Include only float, int, boolean columns. Not implemented for Series.
#
# min_count : int, default 0
#     The required number of valid values to perform the operation. If fewer than
#     ``min_count`` non-NA values are present the result will be NA.
# **kwargs
#     Additional keyword arguments to be passed to the function.
#
# Returns
# -------
# Series or scalar
#
# See Also
# --------
# Series.sum : Return the sum.
# Series.min : Return the minimum.
# Series.max : Return the maximum.
# Series.idxmin : Return the index of the minimum.
# Series.idxmax : Return the index of the maximum.
# DataFrame.sum : Return the sum over the requested axis.
# DataFrame.min : Return the minimum over the requested axis.
# DataFrame.max : Return the maximum over the requested axis.
# DataFrame.idxmin : Return the index of the minimum over the requested axis.
# DataFrame.idxmax : Return the index of the maximum over the requested axis.
#
# Examples
# --------
# >>> idx = pd.MultiIndex.from_arrays([
# ...     ['warm', 'warm', 'cold', 'cold'],
# ...     ['dog', 'falcon', 'fish', 'spider']],
# ...     names=['blooded', 'animal'])
# >>> s = pd.Series([4, 2, 0, 8], name='legs', index=idx)
# >>> s
# blooded  animal
# warm     dog       4
#          falcon    2
# cold     fish      0
#          spider    8
# Name: legs, dtype: int64
#
# >>> s.sum()
# 14
#
# By default, the sum of an empty or all-NA Series is ``0``.
#
# >>> pd.Series([], dtype="float64").sum()  # min_count=0 is the default
# 0.0
#
# This can be controlled with the ``min_count`` parameter. For example, if
# you'd like the sum of an empty series to be NaN, pass ``min_count=1``.
#
# >>> pd.Series([], dtype="float64").sum(min_count=1)
# nan
#
# Thanks to the ``skipna`` parameter, ``min_count`` handles all-NA and
# empty series identically.
#
# >>> pd.Series([np.nan]).sum()
# 0.0
#
# >>> pd.Series([np.nan]).sum(min_count=1)
# nan
# File:      ~/dev/pandas-exercises/.venv/lib/python3.12/site-packages/pandas/core/frame.py
# Type:      function

# %%
df.isnull().sum(axis=0)
# Out:
# date                 1
# customer_id          1
# product_id           1
# quantity             1
# price                1
# discount             1
# revenue              1
# store_id             1
# region               1
# payment_method       1
# is_member            1
# delivery_days        1
# customer_age         1
# gender               1
# product_category     1
# rating               1
# return_status        1
# feedback             1
# shipping_cost        9
# coupon_code          1
# delivery_rating     14
# customer_note        1
# customer_values      1
# all_nan_column      36
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0      2
# 1      1
# 2      1
# 3      2
# 4      2
# 5      1
# 6      1
# 7      2
# 8      2
# 9      1
# 10     2
# 11     2
# 12     1
# 13     1
# 14     2
# 15     1
# 16     2
# 17     1
# 18     3
# 19     3
# 20     1
# 21     1
# 22     2
# 23     2
# 24     2
# 25     2
# 26     2
# 27     2
# 28     2
# 29     1
# 30     2
# 31     1
# 32     1
# 33     1
# 34     1
# 35    24
# dtype: int64

# %%
df_kept = df[df.isnull().sum(axis=1) >= 2]

# Display the DataFrame after keeping rows
display(df_kept.reset_index(drop=True))
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01       1691.0       116.0       7.0  89.61      0.02  614.7246
# 1  2023-01-04       1707.0       199.0       4.0  64.34      0.12  226.4768
# 2  2023-01-05       1812.0       117.0       1.0  85.98      0.18   70.5036
# 3  2023-01-08       1370.0       197.0       9.0  74.19      0.22  520.8138
# 4  2023-01-09       1251.0       102.0       4.0  84.38      0.18  276.7664
# 5  2023-01-11       1233.0       111.0       9.0  98.16      0.21  697.9176
# 6  2023-01-12       1211.0       110.0       2.0  67.73      0.17  112.4318
# 7  2023-01-15       1034.0       160.0       7.0  63.45      0.05  421.9425
# 8  2023-01-17       1905.0       111.0       8.0  65.28      0.02  511.7952
# 9  2023-01-19       1123.0       109.0       6.0  56.13      0.14  289.6308
# 10 2023-01-20       1388.0       181.0       1.0  29.98      0.29   21.2858
# 11 2023-01-23       1564.0       163.0       6.0  43.79      0.03  254.8578
# 12 2023-01-24       1770.0       102.0       4.0  20.85      0.17   69.2220
# 13 2023-01-25       1741.0       155.0       3.0  86.23      0.14  222.4734
# 14 2023-01-26       1504.0       164.0       3.0  85.86      0.26  190.6092
# 15 2023-01-27       1313.0       164.0       1.0  53.18      0.08   48.9256
# 16 2023-01-28       1629.0       176.0       2.0  91.70      0.30  128.3800
# 17 2023-01-29       1923.0       103.0       7.0  21.86      0.04  146.8992
# 18 2023-01-31       1083.0       105.0       5.0  39.69      0.14  170.6670
# 19        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        8.0   East           Cash  ...      Electronics     3.1
# 1        7.0  North         Online  ...            Books     2.1
# 2        4.0  North         Online  ...            Books     1.1
# 3        3.0  South    Credit Card  ...      Electronics     1.0
# 4        6.0   West    Credit Card  ...            Books     1.3
# 5        7.0  South         Online  ...      Electronics     3.5
# 6        6.0   East         Online  ...            Books     4.6
# 7        2.0  North    Credit Card  ...      Electronics     4.5
# 8        2.0   West         Online  ...         Clothing     2.7
# 9        4.0  South    Credit Card  ...      Electronics     4.1
# 10       1.0  South    Credit Card  ...      Electronics     4.8
# 11       4.0  South         Online  ...      Electronics     4.5
# 12       5.0   East    Credit Card  ...            Books     4.1
# 13       6.0  North           Cash  ...      Electronics     3.2
# 14       7.0  South    Credit Card  ...      Electronics     2.3
# 15       7.0  South    Credit Card  ...            Books     3.8
# 16       6.0   West         Online  ...             Food     3.4
# 17       2.0   West           Cash  ...         Clothing     4.8
# 18       8.0   West         Online  ...            Books     3.2
# 19       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned  Negative         15.36          nan             NaN
# 1        Returned  Negative         18.80     WELCOME5             NaN
# 2    Not Returned  Positive           NaN     WELCOME5             2.2
# 3    Not Returned  Negative           NaN          nan             2.2
# 4        Returned   Neutral           NaN          nan             4.2
# 5        Returned   Neutral           NaN     WELCOME5             1.2
# 6    Not Returned   Neutral           NaN     FREESHIP             2.7
# 7    Not Returned  Negative         12.43     FREESHIP             NaN
# 8    Not Returned   Neutral         18.64          nan             NaN
# 9    Not Returned  Positive           NaN     WELCOME5             NaN
# 10   Not Returned   Neutral           NaN       SAVE10             NaN
# 11       Returned   Neutral         16.97          nan             NaN
# 12       Returned   Neutral         11.29       SAVE10             NaN
# 13   Not Returned   Neutral         13.01          nan             NaN
# 14       Returned  Negative         13.73     FREESHIP             NaN
# 15       Returned   Neutral         18.64     WELCOME5             NaN
# 16       Returned   Neutral         12.15     FREESHIP             NaN
# 17   Not Returned   Neutral          5.30     WELCOME5             NaN
# 18   Not Returned  Positive           NaN          nan             2.3
# 19            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0                      no_data          value_3            NaN
# 1                      no_data          value_1            NaN
# 2               Frequent buyer          value_5            NaN
# 3          Used loyalty points          no_data            NaN
# 4               Frequent buyer          no_data            NaN
# 5          Requested gift wrap          value_4            NaN
# 6                      unknown          no_data            NaN
# 7                      no_data          no_data            NaN
# 8          First-time customer          value_5            NaN
# 9                      unknown          value_3            NaN
# 10                     unknown          unknown            NaN
# 11              Frequent buyer          value_3            NaN
# 12                     unknown          no_data            NaN
# 13                     no_data          unknown            NaN
# 14                     unknown          no_data            NaN
# 15  Preferred morning delivery          value_2            NaN
# 16                     no_data          value_5            NaN
# 17                     unknown          value_4            NaN
# 18         First-time customer          unknown            NaN
# 19                         NaN              NaN            NaN
#
# [20 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
#
# 35        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        6.0  North           Cash  ...         Clothing     4.4
# 1        6.0  South         Online  ...         Clothing     4.0
# 2        8.0   West           Cash  ...         Clothing     2.3
# 3        9.0   East    Credit Card  ...             Food     2.5
# 4        6.0   East           Cash  ...             Food     1.3
# 5        6.0   West    Credit Card  ...            Books     4.9
# 6        9.0  South         Online  ...             Food     1.7
# 7        1.0  South    Credit Card  ...         Clothing     2.7
# 8        5.0  South         Online  ...             Food     1.5
# 9        8.0   East    Credit Card  ...      Electronics     1.7
# 10       3.0   West    Credit Card  ...      Electronics     1.2
# 11       3.0   East         Online  ...            Books     2.5
# 12       6.0   West         Online  ...         Clothing     3.9
# 13       5.0   East         Online  ...             Food     1.5
# 14       2.0  North    Credit Card  ...      Electronics     3.6
# 15       2.0  South         Online  ...             Food     4.8
# 16       5.0   East         Online  ...             Food     3.0
# 17       5.0  North         Online  ...            Books     1.2
# 18       6.0  North         Online  ...             Food     1.8
# 19       3.0   East           Cash  ...             Food     2.8
# 20       2.0   East           Cash  ...             Food     1.1
# 21       4.0  North    Credit Card  ...             Food     3.2
# 22       1.0   West           Cash  ...         Clothing     3.9
# 23       4.0  South    Credit Card  ...      Electronics     2.1
# 24       1.0   West         Online  ...      Electronics     1.1
# 25       1.0  South    Credit Card  ...            Books     2.3
# 26       6.0   East    Credit Card  ...            Books     3.4
# 27       3.0   East         Online  ...      Electronics     1.0
# 28       3.0   West         Online  ...            Books     1.8
# 29       6.0   West           Cash  ...      Electronics     4.4
# 30       7.0   East    Credit Card  ...         Clothing     4.9
# 31       2.0   East    Credit Card  ...      Electronics     2.7
# 32       4.0   East         Online  ...         Clothing     3.8
# 33       4.0  North           Cash  ...      Electronics     2.9
# 34       9.0   East    Credit Card  ...         Clothing     2.3
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned  Negative         16.31     FREESHIP             NaN
# 1        Returned  Positive         15.08     WELCOME5             NaN
# 2        Returned  Positive          9.14       SAVE10             2.4
# 3        Returned   Neutral           NaN       SAVE10             NaN
# 4    Not Returned  Negative         12.60     FREESHIP             2.8
# 5    Not Returned   Neutral          8.93          nan             2.7
# 6    Not Returned  Positive          6.48          nan             2.2
# 7    Not Returned  Negative          5.37       SAVE10             2.2
# 8    Not Returned  Negative         18.33          nan             4.8
# 9    Not Returned  Positive         10.16     FREESHIP             3.0
# 10       Returned   Neutral          6.87          nan             3.2
# 11       Returned   Neutral         17.62       SAVE10             4.4
# 12   Not Returned   Neutral         18.92     FREESHIP             2.5
# 13       Returned  Positive          6.97     FREESHIP             4.0
# 14   Not Returned   Neutral         18.05          nan             4.4
# 15   Not Returned  Positive          5.19          nan             NaN
# 16       Returned   Neutral          5.96          nan             NaN
# 17       Returned   Neutral         19.45          nan             3.0
# 18   Not Returned  Positive         10.31     FREESHIP             NaN
# 19   Not Returned  Positive          9.70          nan             3.6
# 20       Returned   Neutral         17.88       SAVE10             4.9
# 21       Returned  Positive         10.55     WELCOME5             NaN
# 22   Not Returned   Neutral         13.94          nan             5.0
# 23   Not Returned  Positive         10.27       SAVE10             2.5
# 24   Not Returned  Negative           NaN          nan             3.2
# 25       Returned   Neutral          5.04       SAVE10             3.1
# 26       Returned   Neutral         19.07       SAVE10             2.9
# 27   Not Returned  Negative         19.79          nan             2.8
# 28       Returned  Positive         16.00          nan             1.1
# 29   Not Returned   Neutral         19.20       SAVE10             1.8
# 30       Returned  Negative         11.25          nan             NaN
# 31       Returned  Negative         13.29     FREESHIP             4.0
# 32       Returned   Neutral           NaN          nan             4.0
# 33       Returned  Negative         12.54          nan             1.6
# 34       Returned  Positive           NaN          nan             1.5
# 35            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0                      unknown          value_3            NaN
# 1          First-time customer          no_data            NaN
# 2                      unknown          value_5            NaN
# 3          First-time customer          no_data            NaN
# 4               Frequent buyer          value_4            NaN
# 5                      unknown          no_data            NaN
# 6               Frequent buyer          value_1            NaN
# 7               Frequent buyer          no_data            NaN
# 8                      no_data          value_3            NaN
# 9                      unknown          value_1            NaN
# 10         First-time customer          value_4            NaN
# 11  Preferred morning delivery          no_data            NaN
# 12              Frequent buyer          unknown            NaN
# 13                     unknown          no_data            NaN
# 14         First-time customer          no_data            NaN
# 15                     unknown          value_5            NaN
# 16                     unknown          unknown            NaN
# 17              Frequent buyer          unknown            NaN
# 18         Used loyalty points          value_5            NaN
# 19                     unknown          no_data            NaN
# 20                     no_data          value_4            NaN
# 21         Used loyalty points          unknown            NaN
# 22         Used loyalty points          value_4            NaN
# 23                     no_data          no_data            NaN
# 24              Frequent buyer          no_data            NaN
# 25         Used loyalty points          no_data            NaN
# 26                     no_data          no_data            NaN
# 27         Requested gift wrap          value_2            NaN
# 28                     no_data          value_5            NaN
# 29         Requested gift wrap          value_2            NaN
# 30                     unknown          value_2            NaN
# 31                     no_data          value_1            NaN
# 32              Frequent buyer          unknown            NaN
# 33                     unknown          value_3            NaN
# 34         First-time customer          value_2            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 09:**
# </div>

# %%
# Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values
dropped_df = df.dropna(subset=['shipping_cost', 'coupon_code', 'delivery_rating'])
dropped_df
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 2  2023-01-03       1798.0       163.0       8.0  41.39      0.08  304.6304
# 4  2023-01-05       1434.0       157.0       7.0  45.37      0.06  298.5346
# 5  2023-01-06       1571.0       196.0       6.0  93.04      0.13  485.6688
# 6  2023-01-07       1180.0       135.0       8.0  59.00      0.06  443.6800
# 7  2023-01-08       1593.0       151.0       5.0  94.03      0.03  456.0455
# 8  2023-01-09       1197.0       184.0       3.0  78.24      0.09  213.5952
# 9  2023-01-10       1062.0       131.0       1.0  59.88      0.07   55.6884
# 10 2023-01-11       1493.0       120.0       1.0  74.17      0.25   55.6275
# 11 2023-01-12       1257.0       181.0       2.0  63.32      0.29   89.9144
# 12 2023-01-13       1349.0       167.0       4.0  25.55      0.20   81.7600
# 13 2023-01-14       1212.0       112.0       6.0  95.48      0.05  544.2360
# 14 2023-01-15       1620.0       147.0       1.0  30.46      0.26   22.5404
# 17 2023-01-18       1699.0       188.0       6.0  97.87      0.29  416.9262
# 19 2023-01-20       1808.0       127.0       9.0  80.99      0.22  568.5498
# 20 2023-01-21       1897.0       156.0       1.0  66.87      0.14   57.5082
# 22 2023-01-23       1305.0       150.0       7.0  32.45      0.01  224.8785
# 23 2023-01-24       1568.0       117.0       7.0  53.98      0.23  290.9522
# 25 2023-01-26       1405.0       143.0       3.0  90.02      0.13  234.9522
# 26 2023-01-27       1655.0       121.0       8.0  62.80      0.27  366.7520
# 27 2023-01-28       1131.0       176.0       9.0  63.75      0.03  556.5375
# 28 2023-01-29       1088.0       176.0       6.0  27.49      0.29  117.1074
# 29 2023-01-30       1013.0       141.0       5.0  92.89      0.10  418.0050
# 31 2023-02-01       1822.0       166.0       3.0  93.93      0.23  216.9783
# 33 2023-02-03       1346.0       148.0       6.0  11.12      0.14   57.3792
#
#     store_id region payment_method  ... product_category  rating  \
# 2        8.0   West           Cash  ...         Clothing     2.3
# 4        6.0   East           Cash  ...             Food     1.3
# 5        6.0   West    Credit Card  ...            Books     4.9
# 6        9.0  South         Online  ...             Food     1.7
# 7        1.0  South    Credit Card  ...         Clothing     2.7
# 8        5.0  South         Online  ...             Food     1.5
# 9        8.0   East    Credit Card  ...      Electronics     1.7
# 10       3.0   West    Credit Card  ...      Electronics     1.2
# 11       3.0   East         Online  ...            Books     2.5
# 12       6.0   West         Online  ...         Clothing     3.9
# 13       5.0   East         Online  ...             Food     1.5
# 14       2.0  North    Credit Card  ...      Electronics     3.6
# 17       5.0  North         Online  ...            Books     1.2
# 19       3.0   East           Cash  ...             Food     2.8
# 20       2.0   East           Cash  ...             Food     1.1
# 22       1.0   West           Cash  ...         Clothing     3.9
# 23       4.0  South    Credit Card  ...      Electronics     2.1
# 25       1.0  South    Credit Card  ...            Books     2.3
# 26       6.0   East    Credit Card  ...            Books     3.4
# 27       3.0   East         Online  ...      Electronics     1.0
# 28       3.0   West         Online  ...            Books     1.8
# 29       6.0   West           Cash  ...      Electronics     4.4
# 31       2.0   East    Credit Card  ...      Electronics     2.7
# 33       4.0  North           Cash  ...      Electronics     2.9
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 2        Returned  Positive          9.14       SAVE10             2.4
# 4    Not Returned  Negative         12.60     FREESHIP             2.8
# 5    Not Returned   Neutral          8.93          nan             2.7
# 6    Not Returned  Positive          6.48          nan             2.2
# 7    Not Returned  Negative          5.37       SAVE10             2.2
# 8    Not Returned  Negative         18.33          nan             4.8
# 9    Not Returned  Positive         10.16     FREESHIP             3.0
# 10       Returned   Neutral          6.87          nan             3.2
# 11       Returned   Neutral         17.62       SAVE10             4.4
# 12   Not Returned   Neutral         18.92     FREESHIP             2.5
# 13       Returned  Positive          6.97     FREESHIP             4.0
# 14   Not Returned   Neutral         18.05          nan             4.4
# 17       Returned   Neutral         19.45          nan             3.0
# 19   Not Returned  Positive          9.70          nan             3.6
# 20       Returned   Neutral         17.88       SAVE10             4.9
# 22   Not Returned   Neutral         13.94          nan             5.0
# 23   Not Returned  Positive         10.27       SAVE10             2.5
# 25       Returned   Neutral          5.04       SAVE10             3.1
# 26       Returned   Neutral         19.07       SAVE10             2.9
# 27   Not Returned  Negative         19.79          nan             2.8
# 28       Returned  Positive         16.00          nan             1.1
# 29   Not Returned   Neutral         19.20       SAVE10             1.8
# 31       Returned  Negative         13.29     FREESHIP             4.0
# 33       Returned  Negative         12.54          nan             1.6
#
#                  customer_note  customer_values all_nan_column
# 2                      unknown          value_5            NaN
# 4               Frequent buyer          value_4            NaN
# 5                      unknown          no_data            NaN
# 6               Frequent buyer          value_1            NaN
# 7               Frequent buyer          no_data            NaN
# 8                      no_data          value_3            NaN
# 9                      unknown          value_1            NaN
# 10         First-time customer          value_4            NaN
# 11  Preferred morning delivery          no_data            NaN
# 12              Frequent buyer          unknown            NaN
# 13                     unknown          no_data            NaN
# 14         First-time customer          no_data            NaN
# 17              Frequent buyer          unknown            NaN
# 19                     unknown          no_data            NaN
# 20                     no_data          value_4            NaN
# 22         Used loyalty points          value_4            NaN
# 23                     no_data          no_data            NaN
# 25         Used loyalty points          no_data            NaN
# 26                     no_data          no_data            NaN
# 27         Requested gift wrap          value_2            NaN
# 28                     no_data          value_5            NaN
# 29         Requested gift wrap          value_2            NaN
# 31                     no_data          value_1            NaN
# 33                     unknown          value_3            NaN
#
# [24 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **10. Keep Only Valid Entries**
#
# **Write a Pandas program to keep the valid entries of a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Append a row of NaNs
df = pd.concat([df, pd.DataFrame([[np.nan] * df.shape[1]], columns=df.columns)], ignore_index=True)

# Add a new all-NaN column
df['all_nan_column'] = np.nan

# Display the updated DataFrame
display(df)
# Out:
# /var/folders/fb/453r9d2j24g8x8tc93n2k6600000gn/T/ipykernel_96118/4116745759.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([[np.nan] * df.shape[1]], columns=df.columns)], ignore_index=True)
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01       1739.0       177.0       3.0  46.52      0.03  135.3732
# 1  2023-01-02       1294.0       130.0       1.0  38.22      0.13   33.2514
# 2  2023-01-03       1433.0       105.0       3.0  33.43      0.15   85.2465
# 3  2023-01-04       1539.0       180.0       1.0  18.85      0.18   15.4570
# 4  2023-01-05       1117.0       119.0       5.0  52.96      0.16  222.4320
# 5  2023-01-06       1165.0       124.0       2.0  84.18      0.27  122.9028
# 6  2023-01-07       1181.0       128.0       5.0  23.18      0.27   84.6070
# 7  2023-01-08       1577.0       152.0       5.0  50.24      0.22  195.9360
# 8  2023-01-09       1590.0       122.0       2.0  76.43      0.01  151.3314
# 9  2023-01-10       1234.0       167.0       7.0  58.47      0.03  397.0113
# 10 2023-01-11       1588.0       193.0       5.0  28.73      0.22  112.0470
# 11 2023-01-12       1090.0       182.0       2.0  24.10      0.07   44.8260
# 12 2023-01-13       1716.0       127.0       6.0  34.22      0.09  186.8412
# 13 2023-01-14       1055.0       196.0       4.0  77.73      0.16  261.1728
# 14 2023-01-15       1286.0       108.0       7.0  83.17      0.06  547.2586
# 15 2023-01-16       1438.0       120.0       8.0  68.38      0.10  492.3360
# 16 2023-01-17       1236.0       106.0       1.0  73.89      0.27   53.9397
# 17 2023-01-18       1374.0       193.0       3.0  34.88      0.24   79.5264
# 18 2023-01-19       1412.0       181.0       9.0  80.29      0.06  679.2534
# 19 2023-01-20       1185.0       152.0       6.0  47.06      0.17  234.3588
# 20 2023-01-21       1395.0       173.0       8.0  94.57      0.00  756.5600
# 21 2023-01-22       1032.0       110.0       4.0  89.36      0.05  339.5680
# 22 2023-01-23       1112.0       132.0       6.0  80.68      0.23  372.7416
# 23 2023-01-24       1481.0       121.0       1.0  90.23      0.26   66.7702
# 24 2023-01-25       1560.0       163.0       1.0  58.89      0.17   48.8787
# 25 2023-01-26       1198.0       163.0       8.0  67.66      0.24  411.3728
# 26 2023-01-27       1928.0       127.0       6.0  23.38      0.11  124.8492
# 27 2023-01-28       1513.0       157.0       9.0  80.52      0.16  608.7312
# 28 2023-01-29       1697.0       107.0       5.0  96.35      0.20  385.4000
# 29 2023-01-30       1800.0       178.0       3.0  84.06      0.02  247.1364
# 30 2023-01-31       1574.0       156.0       9.0  53.32      0.00  479.8800
# 31 2023-02-01       1855.0       135.0       2.0  51.35      0.19   83.1870
# 32 2023-02-02       1025.0       191.0       9.0  15.29      0.18  112.8402
# 33 2023-02-03       1757.0       170.0       4.0  63.25      0.18  207.4600
# 34 2023-02-04       1738.0       187.0       7.0  56.35      0.20  315.5600
# 35        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        4.0  North           Cash  ...             Food     4.4
# 1        6.0  South         Online  ...             Food     3.1
# 2        7.0  South         Online  ...             Food     1.9
# 3        8.0   East           Cash  ...      Electronics     3.4
# 4        1.0   East           Cash  ...      Electronics     2.9
# 5        3.0   West    Credit Card  ...            Books     1.2
# 6        8.0   West           Cash  ...             Food     1.4
# 7        6.0  South    Credit Card  ...         Clothing     2.5
# 8        8.0   East           Cash  ...      Electronics     3.3
# 9        9.0   West         Online  ...             Food     2.4
# 10       1.0   East         Online  ...             Food     4.2
# 11       5.0  North           Cash  ...      Electronics     4.3
# 12       2.0  South           Cash  ...            Books     4.9
# 13       2.0   West         Online  ...             Food     3.4
# 14       2.0  South         Online  ...         Clothing     1.5
# 15       5.0   West         Online  ...            Books     2.3
# 16       4.0   West    Credit Card  ...         Clothing     3.8
# 17       8.0   West         Online  ...      Electronics     1.8
# 18       6.0   West         Online  ...         Clothing     4.5
# 19       9.0  South    Credit Card  ...            Books     2.0
# 20       4.0  North         Online  ...             Food     2.3
# 21       2.0   West         Online  ...             Food     2.5
# 22       1.0  South    Credit Card  ...             Food     3.7
# 23       9.0  North    Credit Card  ...         Clothing     5.0
# 24       8.0   West           Cash  ...      Electronics     5.0
# 25       4.0  South         Online  ...         Clothing     2.8
# 26       3.0  South    Credit Card  ...      Electronics     1.6
# 27       2.0   East    Credit Card  ...            Books     2.4
# 28       9.0  South         Online  ...            Books     4.5
# 29       4.0  North    Credit Card  ...            Books     4.5
# 30       2.0  North    Credit Card  ...      Electronics     1.4
# 31       6.0  South           Cash  ...         Clothing     3.2
# 32       7.0  South         Online  ...         Clothing     2.9
# 33       8.0  South           Cash  ...             Food     2.4
# 34       2.0  South         Online  ...         Clothing     4.3
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned   Neutral         14.07          nan             NaN
# 1    Not Returned  Negative           NaN     FREESHIP             2.3
# 2        Returned   Neutral          8.20          nan             NaN
# 3        Returned   Neutral         18.87     WELCOME5             2.3
# 4    Not Returned  Positive          8.53          nan             2.4
# 5        Returned  Negative         19.89     FREESHIP             NaN
# 6        Returned  Positive          6.30          nan             4.2
# 7    Not Returned   Neutral           NaN          nan             2.9
# 8        Returned   Neutral         11.20          nan             1.2
# 9        Returned  Positive         18.77       SAVE10             3.8
# 10       Returned  Positive         13.00       SAVE10             NaN
# 11   Not Returned  Positive         11.04     FREESHIP             NaN
# 12   Not Returned  Positive         17.87          nan             4.4
# 13   Not Returned  Positive           NaN     WELCOME5             4.5
# 14   Not Returned   Neutral           NaN          nan             2.2
# 15   Not Returned  Positive         18.72     WELCOME5             NaN
# 16       Returned  Positive           NaN       SAVE10             4.4
# 17   Not Returned  Positive           NaN     FREESHIP             1.5
# 18   Not Returned   Neutral         10.92          nan             NaN
# 19   Not Returned  Positive          9.39     FREESHIP             NaN
# 20   Not Returned   Neutral           NaN     FREESHIP             NaN
# 21       Returned   Neutral          9.40          nan             3.4
# 22       Returned  Positive         10.84     FREESHIP             NaN
# 23   Not Returned  Positive         15.46     FREESHIP             4.1
# 24       Returned   Neutral         16.38          nan             4.7
# 25   Not Returned   Neutral         14.72          nan             NaN
# 26       Returned  Negative          5.45     WELCOME5             4.4
# 27       Returned  Positive         19.88          nan             2.5
# 28       Returned   Neutral           NaN          nan             NaN
# 29   Not Returned   Neutral         13.03       SAVE10             3.2
# 30   Not Returned   Neutral           NaN       SAVE10             NaN
# 31   Not Returned  Positive          8.79          nan             2.8
# 32   Not Returned  Negative         16.70          nan             1.4
# 33       Returned  Positive         11.48       SAVE10             3.1
# 34       Returned  Negative          8.19       SAVE10             2.5
# 35            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0                      no_data          no_data            NaN
# 1                      no_data          value_1            NaN
# 2                      unknown          value_1            NaN
# 3                      no_data          value_1            NaN
# 4                      no_data          unknown            NaN
# 5                      no_data          unknown            NaN
# 6                      unknown          value_3            NaN
# 7                      no_data          no_data            NaN
# 8          First-time customer          unknown            NaN
# 9                      unknown          value_4            NaN
# 10         Used loyalty points          value_5            NaN
# 11                     no_data          value_5            NaN
# 12         First-time customer          no_data            NaN
# 13              Frequent buyer          value_1            NaN
# 14         First-time customer          no_data            NaN
# 15              Frequent buyer          no_data            NaN
# 16         First-time customer          unknown            NaN
# 17                     unknown          no_data            NaN
# 18                     no_data          value_3            NaN
# 19         First-time customer          value_4            NaN
# 20  Preferred morning delivery          value_5            NaN
# 21         Requested gift wrap          unknown            NaN
# 22                     no_data          unknown            NaN
# 23                     unknown          unknown            NaN
# 24         Requested gift wrap          value_4            NaN
# 25                     no_data          value_3            NaN
# 26         Used loyalty points          value_1            NaN
# 27         Used loyalty points          no_data            NaN
# 28                     unknown          value_4            NaN
# 29         Used loyalty points          unknown            NaN
# 30         Requested gift wrap          no_data            NaN
# 31         Requested gift wrap          value_5            NaN
# 32                     unknown          no_data            NaN
# 33                     no_data          no_data            NaN
# 34                     no_data          value_5            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 10:**
# </div>

# %%
# Write a Pandas program to keep the valid entries of a given DataFrame
valid_entries_df = df.dropna(subset=['customer_id', 'product_id', 'quantity', 'price', 'revenue', 'delivery_rating'])
display(valid_entries_df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 1  2023-01-02       1294.0       130.0       1.0  38.22      0.13   33.2514
# 3  2023-01-04       1539.0       180.0       1.0  18.85      0.18   15.4570
# 4  2023-01-05       1117.0       119.0       5.0  52.96      0.16  222.4320
# 6  2023-01-07       1181.0       128.0       5.0  23.18      0.27   84.6070
# 7  2023-01-08       1577.0       152.0       5.0  50.24      0.22  195.9360
# 8  2023-01-09       1590.0       122.0       2.0  76.43      0.01  151.3314
# 9  2023-01-10       1234.0       167.0       7.0  58.47      0.03  397.0113
# 12 2023-01-13       1716.0       127.0       6.0  34.22      0.09  186.8412
# 13 2023-01-14       1055.0       196.0       4.0  77.73      0.16  261.1728
# 14 2023-01-15       1286.0       108.0       7.0  83.17      0.06  547.2586
# 16 2023-01-17       1236.0       106.0       1.0  73.89      0.27   53.9397
# 17 2023-01-18       1374.0       193.0       3.0  34.88      0.24   79.5264
# 21 2023-01-22       1032.0       110.0       4.0  89.36      0.05  339.5680
# 23 2023-01-24       1481.0       121.0       1.0  90.23      0.26   66.7702
# 24 2023-01-25       1560.0       163.0       1.0  58.89      0.17   48.8787
# 26 2023-01-27       1928.0       127.0       6.0  23.38      0.11  124.8492
# 27 2023-01-28       1513.0       157.0       9.0  80.52      0.16  608.7312
# 29 2023-01-30       1800.0       178.0       3.0  84.06      0.02  247.1364
# 31 2023-02-01       1855.0       135.0       2.0  51.35      0.19   83.1870
# 32 2023-02-02       1025.0       191.0       9.0  15.29      0.18  112.8402
# 33 2023-02-03       1757.0       170.0       4.0  63.25      0.18  207.4600
# 34 2023-02-04       1738.0       187.0       7.0  56.35      0.20  315.5600
#
#     store_id region payment_method  ... product_category  rating  \
# 1        6.0  South         Online  ...             Food     3.1
# 3        8.0   East           Cash  ...      Electronics     3.4
# 4        1.0   East           Cash  ...      Electronics     2.9
# 6        8.0   West           Cash  ...             Food     1.4
# 7        6.0  South    Credit Card  ...         Clothing     2.5
# 8        8.0   East           Cash  ...      Electronics     3.3
# 9        9.0   West         Online  ...             Food     2.4
# 12       2.0  South           Cash  ...            Books     4.9
# 13       2.0   West         Online  ...             Food     3.4
# 14       2.0  South         Online  ...         Clothing     1.5
# 16       4.0   West    Credit Card  ...         Clothing     3.8
# 17       8.0   West         Online  ...      Electronics     1.8
# 21       2.0   West         Online  ...             Food     2.5
# 23       9.0  North    Credit Card  ...         Clothing     5.0
# 24       8.0   West           Cash  ...      Electronics     5.0
# 26       3.0  South    Credit Card  ...      Electronics     1.6
# 27       2.0   East    Credit Card  ...            Books     2.4
# 29       4.0  North    Credit Card  ...            Books     4.5
# 31       6.0  South           Cash  ...         Clothing     3.2
# 32       7.0  South         Online  ...         Clothing     2.9
# 33       8.0  South           Cash  ...             Food     2.4
# 34       2.0  South         Online  ...         Clothing     4.3
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 1    Not Returned  Negative           NaN     FREESHIP             2.3
# 3        Returned   Neutral         18.87     WELCOME5             2.3
# 4    Not Returned  Positive          8.53          nan             2.4
# 6        Returned  Positive          6.30          nan             4.2
# 7    Not Returned   Neutral           NaN          nan             2.9
# 8        Returned   Neutral         11.20          nan             1.2
# 9        Returned  Positive         18.77       SAVE10             3.8
# 12   Not Returned  Positive         17.87          nan             4.4
# 13   Not Returned  Positive           NaN     WELCOME5             4.5
# 14   Not Returned   Neutral           NaN          nan             2.2
# 16       Returned  Positive           NaN       SAVE10             4.4
# 17   Not Returned  Positive           NaN     FREESHIP             1.5
# 21       Returned   Neutral          9.40          nan             3.4
# 23   Not Returned  Positive         15.46     FREESHIP             4.1
# 24       Returned   Neutral         16.38          nan             4.7
# 26       Returned  Negative          5.45     WELCOME5             4.4
# 27       Returned  Positive         19.88          nan             2.5
# 29   Not Returned   Neutral         13.03       SAVE10             3.2
# 31   Not Returned  Positive          8.79          nan             2.8
# 32   Not Returned  Negative         16.70          nan             1.4
# 33       Returned  Positive         11.48       SAVE10             3.1
# 34       Returned  Negative          8.19       SAVE10             2.5
#
#           customer_note  customer_values all_nan_column
# 1               no_data          value_1            NaN
# 3               no_data          value_1            NaN
# 4               no_data          unknown            NaN
# 6               unknown          value_3            NaN
# 7               no_data          no_data            NaN
# 8   First-time customer          unknown            NaN
# 9               unknown          value_4            NaN
# 12  First-time customer          no_data            NaN
# 13       Frequent buyer          value_1            NaN
# 14  First-time customer          no_data            NaN
# 16  First-time customer          unknown            NaN
# 17              unknown          no_data            NaN
# 21  Requested gift wrap          unknown            NaN
# 23              unknown          unknown            NaN
# 24  Requested gift wrap          value_4            NaN
# 26  Used loyalty points          value_1            NaN
# 27  Used loyalty points          no_data            NaN
# 29  Used loyalty points          unknown            NaN
# 31  Requested gift wrap          value_5            NaN
# 32              unknown          no_data            NaN
# 33              no_data          no_data            NaN
# 34              no_data          value_5            NaN
#
# [22 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **11. Total Number of Missing Values in DataFrame**
#
# **Write a Pandas program to calculate the total number of missing values in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Append a row of NaNs
df = pd.concat([df, pd.DataFrame([[np.nan] * df.shape[1]], columns=df.columns)], ignore_index=True)

# Add a new all-NaN column
df['all_nan_column'] = np.nan

# Display the updated DataFrame
display(df)
# Out:
# /var/folders/fb/453r9d2j24g8x8tc93n2k6600000gn/T/ipykernel_96118/4116745759.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([[np.nan] * df.shape[1]], columns=df.columns)], ignore_index=True)
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01       1559.0       157.0       8.0  32.31      0.26  191.2752
# 1  2023-01-02       1390.0       199.0       5.0  52.73      0.07  245.1945
# 2  2023-01-03       1447.0       186.0       1.0  44.03      0.11   39.1867
# 3  2023-01-04       1699.0       111.0       6.0  55.66      0.02  327.2808
# 4  2023-01-05       1214.0       138.0       6.0  39.03      0.29  166.2678
# 5  2023-01-06       1954.0       161.0       7.0  15.29      0.17   88.8349
# 6  2023-01-07       1305.0       137.0       1.0  33.83      0.28   24.3576
# 7  2023-01-08       1743.0       171.0       8.0  98.48      0.03  764.2048
# 8  2023-01-09       1329.0       119.0       8.0  17.22      0.13  119.8512
# 9  2023-01-10       1908.0       120.0       3.0  18.68      0.18   45.9528
# 10 2023-01-11       1849.0       195.0       9.0  58.93      0.16  445.5108
# 11 2023-01-12       1170.0       113.0       4.0  65.53      0.21  207.0748
# 12 2023-01-13       1253.0       105.0       7.0  24.57      0.17  142.7517
# 13 2023-01-14       1697.0       159.0       5.0  34.78      0.11  154.7710
# 14 2023-01-15       1657.0       164.0       5.0  48.69      0.05  231.2775
# 15 2023-01-16       1567.0       197.0       7.0  53.30      0.12  328.3280
# 16 2023-01-17       1735.0       172.0       7.0  65.57      0.04  440.6304
# 17 2023-01-18       1052.0       131.0       6.0  62.38      0.04  359.3088
# 18 2023-01-19       1237.0       177.0       4.0  19.46      0.27   56.8232
# 19 2023-01-20       1215.0       150.0       9.0  25.24      0.19  183.9996
# 20 2023-01-21       1176.0       188.0       9.0  10.81      0.04   93.3984
# 21 2023-01-22       1446.0       159.0       7.0  84.14      0.07  547.7514
# 22 2023-01-23       1335.0       188.0       4.0  30.22      0.01  119.6712
# 23 2023-01-24       1447.0       168.0       4.0  80.95      0.12  284.9440
# 24 2023-01-25       1480.0       197.0       5.0  19.78      0.01   97.9110
# 25 2023-01-26       1588.0       189.0       4.0  45.60      0.08  167.8080
# 26 2023-01-27       1439.0       129.0       9.0  85.97      0.14  665.4078
# 27 2023-01-28       1996.0       156.0       1.0  98.09      0.30   68.6630
# 28 2023-01-29       1790.0       164.0       3.0  58.65      0.03  170.6715
# 29 2023-01-30       1296.0       179.0       3.0  59.77      0.30  125.5170
# 30 2023-01-31       1730.0       129.0       8.0  94.40      0.06  709.8880
# 31 2023-02-01       1917.0       147.0       1.0  87.83      0.22   68.5074
# 32 2023-02-02       1587.0       123.0       9.0  24.69      0.17  184.4343
# 33 2023-02-03       1939.0       100.0       3.0  87.00      0.09  237.5100
# 34 2023-02-04       1065.0       144.0       8.0  94.10      0.15  639.8800
# 35        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        1.0   West           Cash  ...             Food     2.2
# 1        2.0  South    Credit Card  ...         Clothing     2.9
# 2        8.0   West    Credit Card  ...      Electronics     3.4
# 3        3.0  North    Credit Card  ...             Food     2.0
# 4        8.0  North           Cash  ...            Books     2.0
# 5        8.0   East           Cash  ...         Clothing     3.3
# 6        6.0   East    Credit Card  ...      Electronics     4.1
# 7        8.0  North    Credit Card  ...      Electronics     3.5
# 8        8.0   East    Credit Card  ...         Clothing     1.6
# 9        3.0   East         Online  ...      Electronics     1.5
# 10       8.0   West           Cash  ...      Electronics     2.4
# 11       8.0   West         Online  ...         Clothing     1.1
# 12       4.0   West           Cash  ...            Books     5.0
# 13       5.0   West    Credit Card  ...      Electronics     1.4
# 14       5.0  North           Cash  ...            Books     4.0
# 15       5.0   East         Online  ...             Food     4.7
# 16       6.0  South         Online  ...            Books     2.8
# 17       6.0  South    Credit Card  ...             Food     1.4
# 18       7.0  North         Online  ...         Clothing     4.9
# 19       9.0  South         Online  ...            Books     3.3
# 20       2.0  North    Credit Card  ...         Clothing     1.2
# 21       4.0   East    Credit Card  ...      Electronics     3.1
# 22       9.0   West    Credit Card  ...         Clothing     4.7
# 23       4.0   East    Credit Card  ...            Books     1.7
# 24       7.0   West         Online  ...         Clothing     1.3
# 25       9.0  South           Cash  ...             Food     1.8
# 26       7.0  North           Cash  ...             Food     1.7
# 27       6.0   West         Online  ...         Clothing     4.5
# 28       4.0  South    Credit Card  ...             Food     3.5
# 29       6.0   West           Cash  ...            Books     3.3
# 30       4.0   West           Cash  ...         Clothing     2.9
# 31       1.0  South         Online  ...             Food     1.7
# 32       7.0  South    Credit Card  ...         Clothing     4.9
# 33       8.0   West           Cash  ...            Books     4.5
# 34       4.0   East    Credit Card  ...      Electronics     1.5
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned  Negative         14.40     WELCOME5             3.8
# 1        Returned  Positive         11.36          nan             NaN
# 2        Returned  Positive          8.21          nan             NaN
# 3    Not Returned  Negative         10.82          nan             3.1
# 4        Returned  Positive           NaN     FREESHIP             5.0
# 5        Returned  Positive         16.49     WELCOME5             4.6
# 6        Returned  Positive          7.85       SAVE10             NaN
# 7    Not Returned  Positive         16.84       SAVE10             3.7
# 8    Not Returned  Positive          8.27          nan             NaN
# 9        Returned  Negative          8.86     WELCOME5             2.8
# 10   Not Returned   Neutral         18.43          nan             4.9
# 11   Not Returned   Neutral          6.52       SAVE10             NaN
# 12       Returned  Positive           NaN          nan             4.1
# 13       Returned   Neutral          9.09       SAVE10             2.2
# 14       Returned  Positive           NaN       SAVE10             2.1
# 15       Returned  Negative           NaN       SAVE10             2.3
# 16   Not Returned  Positive           NaN       SAVE10             NaN
# 17       Returned  Negative          7.23       SAVE10             NaN
# 18       Returned   Neutral         15.59     WELCOME5             1.6
# 19   Not Returned  Positive           NaN          nan             NaN
# 20   Not Returned  Negative           NaN     FREESHIP             5.0
# 21       Returned   Neutral           NaN     WELCOME5             2.4
# 22       Returned  Negative          9.86     FREESHIP             3.9
# 23       Returned  Negative         10.57          nan             3.3
# 24   Not Returned   Neutral           NaN     FREESHIP             NaN
# 25       Returned  Negative           NaN          nan             4.9
# 26       Returned   Neutral         12.92     WELCOME5             1.4
# 27       Returned   Neutral          8.08     FREESHIP             1.1
# 28   Not Returned  Negative         16.04     FREESHIP             NaN
# 29   Not Returned  Negative         18.25          nan             NaN
# 30       Returned  Negative          6.86       SAVE10             1.8
# 31       Returned  Positive          7.51     FREESHIP             NaN
# 32       Returned   Neutral         11.98          nan             NaN
# 33       Returned  Positive         17.36          nan             3.7
# 34       Returned   Neutral         12.16     WELCOME5             1.2
# 35            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0               Frequent buyer          value_2            NaN
# 1                      no_data          unknown            NaN
# 2               Frequent buyer          no_data            NaN
# 3          First-time customer          value_5            NaN
# 4               Frequent buyer          value_2            NaN
# 5          Requested gift wrap          value_3            NaN
# 6                      no_data          no_data            NaN
# 7                      no_data          unknown            NaN
# 8                      unknown          unknown            NaN
# 9          Used loyalty points          unknown            NaN
# 10                     no_data          no_data            NaN
# 11                     unknown          value_2            NaN
# 12                     no_data          value_2            NaN
# 13         Used loyalty points          unknown            NaN
# 14              Frequent buyer          no_data            NaN
# 15         First-time customer          value_4            NaN
# 16                     unknown          value_1            NaN
# 17                     no_data          value_5            NaN
# 18              Frequent buyer          value_2            NaN
# 19                     unknown          value_2            NaN
# 20                     no_data          no_data            NaN
# 21                     unknown          value_2            NaN
# 22                     unknown          value_2            NaN
# 23         Requested gift wrap          no_data            NaN
# 24         Requested gift wrap          unknown            NaN
# 25                     no_data          no_data            NaN
# 26                     no_data          value_4            NaN
# 27                     no_data          value_4            NaN
# 28                     unknown          value_2            NaN
# 29                     unknown          no_data            NaN
# 30         Used loyalty points          unknown            NaN
# 31         Used loyalty points          value_5            NaN
# 32                     no_data          value_4            NaN
# 33         First-time customer          value_3            NaN
# 34  Preferred morning delivery          no_data            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 11:**
# </div>

# %%
print(df.isna().sum().sum())
# Out:
# 82

# %% [markdown]
# <div class="alert alert-warning">
#
# **12. Replace NaNs with a Constant in Specified Columns**
#
# **Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Append a row of NaNs
df = pd.concat([df, pd.DataFrame([[np.nan] * df.shape[1]], columns=df.columns)], ignore_index=True)

# Add a new all-NaN column
df['all_nan_column'] = np.nan

# Display the updated DataFrame
display(df)
# Out:
# /var/folders/fb/453r9d2j24g8x8tc93n2k6600000gn/T/ipykernel_96118/4116745759.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([[np.nan] * df.shape[1]], columns=df.columns)], ignore_index=True)
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01       
# 15       2.0  South           Cash  ...         Clothing     4.3
# 16       1.0   West           Cash  ...      Electronics     3.7
# 17       6.0   West         Online  ...      Electronics     2.6
# 18       4.0   West    Credit Card  ...            Books     3.2
# 19       5.0   East         Online  ...         Clothing     1.7
# 20       2.0  North    Credit Card  ...            Books     1.9
# 21       6.0   East    Credit Card  ...         Clothing     3.5
# 22       2.0   East         Online  ...         Clothing     4.8
# 23       4.0   West    Credit Card  ...         Clothing     2.2
# 24       2.0  South    Credit Card  ...         Clothing     1.7
# 25       6.0  North    Credit Card  ...            Books     4.9
# 26       9.0   West         Online  ...         Clothing     4.9
# 27       6.0  North           Cash  ...             Food     3.9
# 28       8.0   West         Online  ...      Electronics     1.6
# 29       9.0  North           Cash  ...         Clothing     1.7
# 30       4.0  South           Cash  ...         Clothing     3.4
# 31       2.0   West           Cash  ...         Clothing     2.1
# 32       2.0  North         Online  ...            Books     3.1
# 33       4.0   East    Credit Card  ...            Books     1.7
# 34       3.0  South    Credit Card  ...      Electronics     3.5
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0    Not Returned  Positive         10.34          nan             NaN
# 1        Returned   Neutral           NaN     FREESHIP             3.1
# 2        Returned  Positive           NaN     FREESHIP             1.4
# 3    Not Returned   Neutral         10.08       SAVE10             NaN
# 4        Returned   Neutral         16.66     FREESHIP             1.8
# 5    Not Returned  Negative          5.54       SAVE10             NaN
# 6    Not Returned  Negative          8.68          nan             NaN
# 7        Returned  Negative         11.74     FREESHIP             2.1
# 8        Returned   Neutral         11.83       SAVE10             1.2
# 9        Returned   Neutral         11.98          nan             1.7
# 10       Returned   Neutral         19.65          nan             3.7
# 11   Not Returned  Negative         14.82          nan             NaN
# 12       Returned  Negative         15.22          nan             NaN
# 13   Not Returned  Negative           NaN          nan             1.3
# 14   Not Returned  Positive         12.44       SAVE10             4.1
# 15       Returned  Negative         13.92     WELCOME5             4.8
# 16       Returned  Positive         13.23     FREESHIP             2.8
# 17       Returned  Negative         18.61          nan             1.4
# 18   Not Returned   Neutral         14.32          nan             2.7
# 19       Returned  Negative         16.51       SAVE10             3.9
# 20   Not Returned  Negative         14.07     FREESHIP             2.4
# 21   Not Returned  Positive         15.25     FREESHIP             1.4
# 22   Not Returned  Positive         13.30     FREESHIP             1.0
# 23   Not Returned  Positive          9.80     FREESHIP             1.4
# 24   Not Returned   Neutral          7.57          nan             3.9
# 25       Returned  Negative           NaN          nan             2.0
# 26   Not Returned   Neutral         11.24          nan             1.5
# 27   Not Returned   Neutral          5.45       SAVE10             4.7
# 28   Not Returned   Neutral          8.06     WELCOME5             3.3
# 29   Not Returned  Negative         14.38          nan             NaN
# 30       Returned  Negative         16.20          nan             4.1
# 31       Returned  Negative         11.87          nan             1.2
# 32   Not Returned  Negative          9.55          nan             3.1
# 33       Returned   Neutral         15.51       SAVE10             1.6
# 34   Not Returned  Negative           NaN       SAVE10             3.3
# 35            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0                      unknown          value_2            NaN
# 1                      no_data          value_3            NaN
# 2                      unknown          value_2            NaN
# 3               Frequent buyer          value_5            NaN
# 4                      no_data          value_2            NaN
# 5                      unknown          value_3            NaN
# 6                      unknown          unknown            NaN
# 7                      unknown          value_2            NaN
# 8                      no_data          unknown            NaN
# 9                      no_data          value_4            NaN
# 10                     unknown          no_data            NaN
# 11                     no_data          value_1            NaN
# 12                     unknown          unknown            NaN
# 13         Used loyalty points          value_3            NaN
# 14         Used loyalty points          value_4            NaN
# 15         Requested gift wrap          value_3            NaN
# 16                     no_data          value_1            NaN
# 17                     unknown          value_4            NaN
# 18                     unknown          value_2            NaN
# 19                     unknown          value_3            NaN
# 20              Frequent buyer          unknown            NaN
# 21                     no_data          no_data            NaN
# 22         Requested gift wrap          no_data            NaN
# 23              Frequent buyer          value_4            NaN
# 24                     no_data          value_4            NaN
# 25                     no_data          value_4            NaN
# 26                     unknown          unknown            NaN
# 27         Used loyalty points          value_3            NaN
# 28         Used loyalty points          value_5            NaN
# 29                     no_data          no_data            NaN
# 30                     no_data          value_5            NaN
# 31         Requested gift wrap          unknown            NaN
# 32                     no_data          unknown            NaN
# 33  Preferred morning delivery          unknown            NaN
# 34                     unknown          no_data            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 12:**
# </div>

# %%
# Write a Pandas program to fill the missing values in specific columns of a given DataFrame
df_filled = df.fillna({'shipping_cost': 0, 'coupon_code': 'NO_COUPON', 'delivery_rating': 0})
df_filled

# or we can use the `fillna` method directly on the DataFrame
df['shipping_cost'].fillna(0, inplace=True)

# or we can use the `fillna` method directly on the DataFrame with multiple columns
df.fillna(
    {
        'shipping_cost': 0
        , 'coupon_code': 'NO_COUPON'
        , 'delivery_rating': 0
    }
    , inplace=True
)

df
# Out:
# /var/folders/fb/453r9d2j24g8x8tc93n2k6600000gn/T/ipykernel_96118/3401518830.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['shipping_cost'].fillna(0, inplace=True)
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01       1920.0       192.0       3.0  78.09      0.08  215.5284
# 1  2023-01-02       1311.0       119.0       2.0  72.18      0.17  119.8188
# 2  2023-01-03       1258.0       158.0       4.0  37.56      0.15  127.7040
# 3  2023-01-04       1867.0       134.0       3.0  99.05      0.02  291.2070
# 4  2023-01-05       1847.0       115.0       2.0  49.36      0.25   74.0400
# 5  2023-01-06       1386.0       159.0       4.0  76.97      0.08  283.2496
# 6  2023-01-07       1368.0       102.0       8.0  20.55      0.28  118.3680
# 7  2023-01-08       1701.0       160.0       9.0  75.04      0.08  621.3312
# 8  2023-01-09       1264.0       164.0       6.0  45.81      0.20  219.8880
# 9  2023-01-10       1120.0       141.0       5.0  12.90      0.20   51.6000
# 10 2023-01-11       1426.0       176.0       5.0  40.48      0.11  180.1360
# 11 2023-01-12       1115.0       176.0       7.0  49.55      0.27  253.2005
# 12 2023-01-13       1709.0       190.0       4.0  42.33      0.01  167.6268
# 13 2023-01-14       1935.0       119.0       3.0  14.47      0.24   32.9916
# 14 2023-01-15       1526.0       119.0       4.0  73.70      0.23  226.9960
# 15 2023-01-16       1163.0       168.0       1.0  19.23      0.26   14.2302
# 16 2023-01-17       1085.0       104.0       3.0  66.90      0.01  198.6930
# 17 2023-01-18       1868.0       129.0       5.0  68.06      0.10  306.2700
# 18 2023-01-19       1911.0       133.0       8.0  73.56      0.28  423.7056
# 19 2023-01-20       1416.0       122.0       3.0  37.09      0.29   79.0017
# 20 2023-01-21       1603.0       177.0       4.0  60.69      0.19  196.6356
# 21 2023-01-22       1396.0       158.0       5.0  44.91      0.11  199.8495
# 22 2023-01-23       1117.0       104.0       6.0  55.29      0.14  285.2964
# 23 2023-01-24       1893.0       161.0       9.0  76.58      0.19  558.2682
# 24 2023-01-25       1163.0       140.0       9.0  54.80      0.15  419.2200
# 25 2023-01-26       1042.0       141.0       2.0  38.02      0.01   75.2796
# 26 2023-01-27       1153.0       164.0       3.0  49.48      0.11  132.1116
# 27 2023-01-28       1088.0       103.0       1.0  80.27      0.26   59.3998
# 28 2023-01-29       1310.0       126.0       4.0  85.08      0.10  306.2880
# 29 2023-01-30       1496.0       150.0       1.0  40.77      0.12   35.8776
# 30 2023-01-31       1229.0       147.0       7.0  46.46      0.04  312.2112
# 31 2023-02-01       1009.0       199.0       6.0  50.52      0.23  233.4024
# 32 2023-02-02       1283.0       126.0       2.0  40.70      0.20   65.1200
# 33 2023-02-03       1663.0       163.0       6.0  65.43      0.12  345.4704
# 34 2023-02-04       1172.0       132.0       5.0  42.84      0.22  167.0760
# 35        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        6.0  North           Cash  ...      Electronics     1.5
# 1        4.0  South         Online  ...             Food     1.6
# 2        1.0   West         Online  ...         Clothing     1.1
# 3        9.0  South         Online  ...            Books     2.5
# 4        3.0  South         Online  ...      Electronics     1.3
# 5        4.0   East    Credit Card  ...             Food     3.5
# 6        9.0   East         Online  ...             Food     3.6
# 7        6.0   East         Online  ...             Food     4.1
# 8        9.0  South           Cash  ...             Food     1.6
# 9        8.0  North           Cash  ...         Clothing     1.9
# 10       6.0  South           Cash  ...            Books     1.5
# 11       6.0   East           Cash  ...             Food     3.1
# 12       7.0   West    Credit Card  ...      Electronics     1.7
# 13       6.0  North    Credit Card  ...         Clothing     1.2
# 14       5.0  South         Online  ...      Electronics     1.5
# 15       2.0  South           Cash  ...         Clothing     4.3
# 16       1.0   West           Cash  ...      Electronics     3.7
# 17       6.0   West         Online  ...      Electronics     2.6
# 18       4.0   West    Credit Card  ...            Books     3.2
# 19       5.0   East         Online  ...         Clothing     1.7
# 20       2.0  North    Credit Card  ...            Books     1.9
# 21       6.0   East    Credit Card  ...         Clothing     3.5
# 22       2.0   East         Online  ...         Clothing     4.8
# 23       4.0   West    Credit Card  ...         Clothing     2.2
# 24       2.0  South    Credit Card  ...         Clothing     1.7
# 25       6.0  North    Credit Card  ...            Books     4.9
# 26       9.0   West         Online  ...         Clothing     4.9
# 27       6.0  North           Cash  ...             Food     3.9
# 28       8.0   West         Online  ...      Electronics     1.6
# 29       9.0  North           Cash  ...         Clothing     1.7
# 30       4.0  South           Cash  ...         Clothing     3.4
# 31       2.0   West           Cash  ...         Clothing     2.1
# 32       2.0  North         Online  ...            Books     3.1
# 33       4.0   East    Credit Card  ...            Books     1.7
# 34       3.0  South    Credit Card  ...      Electronics     3.5
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0    Not Returned  Positive         10.34          nan             0.0
# 1        Returned   Neutral          0.00     FREESHIP             3.1
# 2        Returned  Positive          0.00     FREESHIP             1.4
# 3    Not Returned   Neutral         10.08       SAVE10             0.0
# 4        Returned   Neutral         16.66     FREESHIP             1.8
# 5    Not Returned  Negative          5.54       SAVE10             0.0
# 6    Not Returned  Negative          8.68          nan             0.0
# 7        Returned  Negative         11.74     FREESHIP             2.1
# 8        Returned   Neutral         11.83       SAVE10             1.2
# 9        Returned   Neutral         11.98          nan             1.7
# 10       Returned   Neutral         19.65          nan             3.7
# 11   Not Returned  Negative         14.82          nan             0.0
# 12       Returned  Negative         15.22          nan             0.0
# 13   Not Returned  Negative          0.00          nan             1.3
# 14   Not Returned  Positive         12.44       SAVE10             4.1
# 15       Returned  Negative         13.92     WELCOME5             4.8
# 16       Returned  Positive         13.23     FREESHIP             2.8
# 17       Returned  Negative         18.61          nan             1.4
# 18   Not Returned   Neutral         14.32          nan             2.7
# 19       Returned  Negative         16.51       SAVE10             3.9
# 20   Not Returned  Negative         14.07     FREESHIP             2.4
# 21   Not Returned  Positive         15.25     FREESHIP             1.4
# 22   Not Returned  Positive         13.30     FREESHIP             1.0
# 23   Not Returned  Positive          9.80     FREESHIP             1.4
# 24   Not Returned   Neutral          7.57          nan             3.9
# 25       Returned  Negative          0.00          nan             2.0
# 26   Not Returned   Neutral         11.24          nan             1.5
# 27   Not Returned   Neutral          5.45       SAVE10             4.7
# 28   Not Returned   Neutral          8.06     WELCOME5             3.3
# 29   Not Returned  Negative         14.38          nan             0.0
# 30       Returned  Negative         16.20          nan             4.1
# 31       Returned  Negative         11.87          nan             1.2
# 32   Not Returned  Negative          9.55          nan             3.1
# 33       Returned   Neutral         15.51       SAVE10             1.6
# 34   Not Returned  Negative          0.00       SAVE10             3.3
# 35            NaN       NaN          0.00    NO_COUPON             0.0
#
#                  customer_note  customer_values all_nan_column
# 0                      unknown          value_2            NaN
# 1                      no_data          value_3            NaN
# 2                      unknown          value_2            NaN
# 3               Frequent buyer          value_5            NaN
# 4                      no_data          value_2            NaN
# 5                      unknown          value_3            NaN
# 6                      unknown          unknown            NaN
# 7                      unknown          value_2            NaN
# 8                      no_data          unknown            NaN
# 9                      no_data          value_4            NaN
# 10                     unknown          no_data            NaN
# 11                     no_data          value_1            NaN
# 12                     unknown          unknown            NaN
# 13         Used loyalty points          value_3            NaN
# 14         Used loyalty points          value_4            NaN
# 15         Requested gift wrap          value_3            NaN
# 16                     no_data          value_1            NaN
# 17                     unknown          value_4            NaN
# 18                     unknown          value_2            NaN
# 19                     unknown          value_3            NaN
# 20              Frequent buyer          unknown            NaN
# 21                     no_data          no_data            NaN
# 22         Requested gift wrap          no_data            NaN
# 23              Frequent buyer          value_4            NaN
# 24                     no_data          value_4            NaN
# 25                     no_data          value_4            NaN
# 26                     unknown          unknown            NaN
# 27         Used loyalty points          value_3            NaN
# 28         Used loyalty points          value_5            NaN
# 29                     no_data          no_data            NaN
# 30                     no_data          value_5            NaN
# 31         Requested gift wrap          unknown            NaN
# 32                     no_data          unknown            NaN
# 33  Preferred morning delivery          unknown            NaN
# 34                     unknown          no_data            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]
