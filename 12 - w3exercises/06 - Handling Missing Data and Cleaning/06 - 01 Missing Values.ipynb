# 15         5  South           Cash  ...              2            18    Male
# 16         2  North           Cash  ...              1            66  Female
# 17         6   East           Cash  ...              6            28  Female
# 18         3  South         Online  ...              5            67    Male
# 19         4  South         Online  ...              3            20    Male
# 20         7  South    Credit Card  ...              3            49   Other
# 21         9  South         Online  ...              3            56    Male
# 22         9   West         Online  ...              5            35    Male
# 23         7   West           Cash  ...              4            20    Male
# 24         4  South           Cash  ...              4            55   Other
# 25         6   West    Credit Card  ...              3            34    Male
# 26         3  South         Online  ...              6            44    Male
# 27         8  North    Credit Card  ...              1            21  Female
# 28         5   East    Credit Card  ...              4            36    Male
# 29         6   East    Credit Card  ...              1            30   Other
# 30         9   West         Online  ...              2            40   Other
# 31         4  South    Credit Card  ...              4            56   Other
# 32         4   East    Credit Card  ...              3            28   Other
# 33         9   West         Online  ...              1            21   Other
# 34         3  North         Online  ...              4            59  Female
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0       Electronics    2.9       Returned   Neutral         15.27
# 1       Electronics    2.3       Returned   Neutral         11.63
# 2       Electronics    3.8       Returned  Positive         13.51
# 3       Electronics    3.2   Not Returned  Negative         14.55
# 4             Books    2.3   Not Returned  Negative         16.70
# 5             Books    3.3       Returned  Negative         16.79
# 6             Books    3.4       Returned   Neutral         12.47
# 7       Electronics    4.0       Returned   Neutral           NaN
# 8              Food    2.1       Returned  Positive         18.20
# 9          Clothing    3.0       Returned   Neutral         17.33
# 10            Books    2.9   Not Returned   Neutral          7.09
# 11            Books    4.3   Not Returned  Negative         17.92
# 12            Books    4.4   Not Returned  Negative          6.99
# 13            Books    1.2       Returned  Negative         13.55
# 14            Books    4.5   Not Returned  Positive          7.95
# 15         Clothing    2.3   Not Returned  Positive         17.95
# 16         Clothing    2.8       Returned  Positive           NaN
# 17         Clothing    1.0   Not Returned  Positive          5.94
# 18      Electronics    1.4       Returned  Positive         18.25
# 19             Food    4.8       Returned  Negative         16.54
# 20            Books    1.5   Not Returned  Negative           NaN
# 21         Clothing    3.6   Not Returned   Neutral         11.12
# 22         Clothing    1.8   Not Returned  Negative         16.29
# 23         Clothing    2.7   Not Returned  Negative         12.58
# 24         Clothing    3.9   Not Returned  Positive         12.70
# 25            Books    4.9   Not Returned   Neutral         14.19
# 26             Food    4.1   Not Returned  Negative         19.27
# 27            Books    4.1   Not Returned  Negative         11.26
# 28         Clothing    1.5   Not Returned  Positive         18.41
# 29         Clothing    4.8   Not Returned  Positive          6.81
# 30            Books    4.1   Not Returned  Negative           NaN
# 31         Clothing    3.0       Returned  Negative         17.03
# 32      Electronics    4.7   Not Returned  Negative          7.79
# 33         Clothing    1.5   Not Returned  Positive           NaN
# 34             Food    4.2   Not Returned  Positive          9.56
#
#     coupon_code delivery_rating
# 0        SAVE10             2.1
# 1           nan             2.2
# 2      FREESHIP             NaN
# 3        SAVE10             1.3
# 4      FREESHIP             NaN
# 5           nan             NaN
# 6           nan             1.2
# 7           nan             1.6
# 8      FREESHIP             4.8
# 9        SAVE10             NaN
# 10          nan             NaN
# 11       SAVE10             5.0
# 12       SAVE10             4.7
# 13     FREESHIP             2.2
# 14       SAVE10             NaN
# 15     FREESHIP             NaN
# 16     WELCOME5             2.6
# 17       SAVE10             5.0
# 18     WELCOME5             NaN
# 19       SAVE10             2.4
# 20     FREESHIP             NaN
# 21          nan             NaN
# 22     WELCOME5             3.3
# 23     FREESHIP             3.9
# 24       SAVE10             1.8
# 25     WELCOME5             2.3
# 26     WELCOME5             2.7
# 27       SAVE10             3.6
# 28     FREESHIP             1.4
# 29       SAVE10             4.2
# 30          nan             NaN
# 31          nan             2.0
# 32          nan             3.8
# 33          nan             4.9
# 34          nan             2.1
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
print(type(df.isna()))
df.isna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      date  customer_id  product_id  quantity  price  discount  revenue  \
# 0   False        False       False     False  False     False    False
# 1   False        False       False     False  False     False    False
# 2   False        False       False     False  False     False    False
# 3   False        False       False     False  False     False    False
# 4   False        False       False     False  False     False    False
# 5   False        False       False     False  False     False    False
# 6   False        False       False     False  False     False    False
# 7   False        False       False     False  False     False    False
# 8   False        False       False     False  False     False    False
# 9   False        False       False     False  False     False    False
# 10  False        False       False     False  False     False    False
# 11  False        False       False     False  False     False    False
# 12  False        False       False     False  False     False    False
# 13  False        False       False     False  False     False    False
# 14  False        False       False     False  False     False    False
# 15  False        False       False     False  False     False    False
# 16  False        False       False     False  False     False    False
# 17  False        False       False     False  False     False    False
# 18  False        False       False     False  False     False    False
# 19  False        False       False     False  False     False    False
# 20  False        False       False     False  False     False    False
# 21  False        False       False     False  False     False    False
# 22  False        False       False     False  False     False    False
# 23  False        False       False     False  False     False    False
# 24  False        False       False     False  False     False    False
# 25  False        False       False     False  False     False    False
# 26  False        False       False     False  False     False    False
# 27  False        False       False     False  False     False    False
# 28  False        False       False     False  False     False    False
# 29  False        False       False     False  False     False    False
# 30  False        False       False     False  False     False    False
# 31  False        False       False     False  False     False    False
# 32  False        False       False     False  False     False    False
# 33  False        False       False     False  False     False    False
# 34  False        False       False     False  False     False    False
#
#     store_id  region  payment_method  ...  delivery_days  customer_age  \
# 0      False   False           False  ...          False         False
# 1      False   False           False  ...          False         False
# 2      False   False           False  ...          False         False
# 3      False   False           False  ...          False         False
# 4      False   False           False  ...          False         False
# 5      False   False           False  ...          False         False
# 6      False   False           False  ...          False         False
# 7      False   False           False  ...          False         False
# 8      False   False           False  ...          False         False
# 9      False   False           False  ...          False         False
# 10     False   False           False  ...          False         False
# 11     False   False           False  ...          False         False
# 12     False   False           False  ...          False         False
# 13     False   False           False  ...          False         False
# 14     False   False           False  ...          False         False
# 15     False   False           False  ...          False         False
# 16     False   False           False  ...          False         False
# 17     False   False           False  ...          False         False
# 18     False   False           False  ...          False         False
# 19     False   False           False  ...          False         False
# 20     False   False           False  ...          False         False
# 21     False   False           False  ...          False         False
# 22     False   False           False  ...          False         False
# 23     False   False           False  ...          False         False
# 24     False   False           False  ...          False         False
# 25     False   False           False  ...          False         False
# 26     False   False           False  ...          False         False
# 27     False   False           False  ...          False         False
# 28     False   False           False  ...          False         False
# 29     False   False           False  ...          False         False
# 30     False   False           False  ...          False         False
# 31     False   False           False  ...          False         False
# 32     False   False           False  ...          False         False
# 33     False   False           False  ...          False         False
# 34     False   False           False  ...          False         False
#
#     gender  product_category  rating  return_status  feedback  shipping_cost  \
# 0    False             False   False          False     False          False
# 1    False             False   False          False     False          False
# 2    False             False   False          False     False          False
# 3    False             False   False          False     False          False
# 4    False             False   False          False     False          False
# 5    False             False   False          False     False          False
# 6    False             False   False          False     False          False
# 7    False             False   False          False     False           True
# 8    False             False   False          False     False          False
# 9    False             False   False          False     False          False
# 10   False             False   False          False     False          False
# 11   False             False   False          False     False          False
# 12   False             False   False          False     False          False
# 13   False             False   False          False     False          False
# 14   False             False   False          False     False          False
# 15   False             False   False          False     False          False
# 16   False             False   False          False     False           True
# 17   False             False   False          False     False          False
# 18   False             False   False          False     False          False
# 19   False             False   False          False     False          False
# 20   False             False   False          False     False           True
# 21   False             False   False          False     False          False
# 22   False             False   False          False     False          False
# 23   False             False   False          False     False          False
# 24   False             False   False          False     False          False
# 25   False             False   False          False     False          False
# 26   False             False   False          False     False          False
# 27   False             False   False          False     False          False
# 28   False             False   False          False     False          False
# 29   False             False   False          False     False          False
# 30   False             False   False          False     False           True
# 31   False             False   False          False     False          False
# 32   False             False   False          False     False          False
# 33   False             False   False          False     False           True
# 34   False             False   False          False     False          False
#
#     coupon_code  delivery_rating
# 0         False            False
# 1         False            False
# 2         False             True
# 3         False            False
# 4         False             True
# 5         False             True
# 6         False            False
# 7         False            False
# 8         False            False
# 9         False             True
# 10        False             True
# 11        False            False
# 12        False            False
# 13        False            False
# 14        False             True
# 15        False             True
# 16        False            False
# 17        False            False
# 18        False             True
# 19        False            False
# 20        False             True
# 21        False             True
# 22        False            False
# 23        False            False
# 24        False            False
# 25        False            False
# 26        False            False
# 27        False            False
# 28        False            False
# 29        False            False
# 30        False             True
# 31        False            False
# 32        False            False
# 33        False            False
# 34        False            False
#
# [35 rows x 21 columns]

# %%
print(df.isna().any())  
df.isna().sum()
# Out:
# date                False
# customer_id         False
# product_id          False
# quantity            False
# price               False
# discount            False
# revenue             False
# store_id            False
# region              False
# payment_method      False
# is_member           False
# delivery_days       False
# customer_age        False
# gender              False
# product_category    False
# rating              False
# return_status       False
# feedback            False
# shipping_cost        True
# coupon_code         False
# delivery_rating      True
# dtype: bool
# date                 0
# customer_id          0
# product_id           0
# quantity             0
# price                0
# discount             0
# revenue              0
# store_id             0
# region               0
# payment_method       0
# is_member            0
# delivery_days        0
# customer_age         0
# gender               0
# product_category     0
# rating               0
# return_status        0
# feedback             0
# shipping_cost        5
# coupon_code          0
# delivery_rating     11
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **2. Identify Columns with Missing Values**
#
# **Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         
Other
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0          Clothing    2.6       Returned  Negative         13.31
# 1       Electronics    4.2   Not Returned  Positive           NaN
# 2          Clothing    4.9   Not Returned  Positive          7.71
# 3              Food    1.6       Returned  Negative           NaN
# 4       Electronics    4.3       Returned   Neutral         14.05
# 5             Books    2.3       Returned  Positive         14.90
# 6              Food    3.2   Not Returned  Positive         10.35
# 7             Books    1.3       Returned  Positive         18.55
# 8       Electronics    1.6   Not Returned  Negative           NaN
# 9             Books    2.5       Returned  Negative           NaN
# 10      Electronics    2.1       Returned  Positive          5.07
# 11             Food    2.8       Returned   Neutral         17.22
# 12            Books    1.9       Returned   Neutral         19.34
# 13      Electronics    4.3       Returned   Neutral         17.11
# 14             Food    1.0       Returned   Neutral           NaN
# 15            Books    3.3   Not Returned   Neutral         11.87
# 16            Books    2.0   Not Returned  Negative         13.27
# 17             Food    2.6   Not Returned  Positive         14.84
# 18            Books    3.5   Not Returned  Positive         15.33
# 19            Books    3.0       Returned  Positive           NaN
# 20         Clothing    1.5   Not Returned  Positive         14.68
# 21      Electronics    3.2   Not Returned  Positive         13.52
# 22         Clothing    4.6   Not Returned  Negative          6.96
# 23         Clothing    1.6       Returned  Positive         19.04
# 24            Books    4.4   Not Returned  Positive           NaN
# 25         Clothing    2.5   Not Returned  Negative           NaN
# 26      Electronics    4.9       Returned   Neutral         11.28
# 27      Electronics    2.0   Not Returned   Neutral         14.84
# 28            Books    1.6       Returned  Negative          7.34
# 29         Clothing    3.8       Returned   Neutral          5.98
# 30      Electronics    1.2   Not Returned  Positive           NaN
# 31             Food    1.6       Returned   Neutral         15.32
# 32         Clothing    1.9   Not Returned  Positive         10.06
# 33      Electronics    3.8       Returned  Negative          7.96
# 34      Electronics    4.4   Not Returned  Negative           NaN
#
#     coupon_code delivery_rating
# 0        SAVE10             1.4
# 1      WELCOME5             2.1
# 2      WELCOME5             4.7
# 3      FREESHIP             5.0
# 4           nan             NaN
# 5        SAVE10             1.7
# 6      WELCOME5             4.7
# 7           nan             4.5
# 8      FREESHIP             NaN
# 9           nan             NaN
# 10     WELCOME5             4.7
# 11       SAVE10             3.5
# 12     WELCOME5             3.9
# 13       SAVE10             3.7
# 14       SAVE10             4.9
# 15     FREESHIP             3.9
# 16          nan             4.4
# 17          nan             2.8
# 18          nan             NaN
# 19       SAVE10             NaN
# 20          nan             3.3
# 21          nan             2.6
# 22          nan             NaN
# 23          nan             4.7
# 24     FREESHIP             4.4
# 25       SAVE10             3.3
# 26          nan             2.6
# 27     FREESHIP             4.3
# 28     FREESHIP             1.6
# 29          nan             NaN
# 30     WELCOME5             2.4
# 31          nan             NaN
# 32     WELCOME5             3.3
# 33       SAVE10             4.5
# 34     WELCOME5             4.9
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution
# 16         4  South    Credit Card  ...              2            46  Female
# 17         8   West    Credit Card  ...              2            29    Male
# 18         6   East    Credit Card  ...              5            58  Female
# 19         5   West           Cash  ...              3            43  Female
# 20         5  North         Online  ...              2            19   Other
# 21         9  North    Credit Card  ...              2            19    Male
# 22         7   West         Online  ...              4            32    Male
# 23         8   West         Online  ...              3            39    Male
# 24         1   West    Credit Card  ...              1            26   Other
# 25         5   East           Cash  ...              4            26    Male
# 26         8  North    Credit Card  ...              5            48   Other
# 27         4   West           Cash  ...              6            32    Male
# 28         3  North         Online  ...              6            67    Male
# 29         6  South           Cash  ...              1            21  Female
# 30         8  North         Online  ...              1            27  Female
# 31         5   East           Cash  ...              6            59   Other
# 32         2   West           Cash  ...              3            59  Female
# 33         6   West    Credit Card  ...              2            32   Other
# 34         5   East         Online  ...              6            64  Female
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0          Clothing    2.3   Not Returned  Negative         12.58
# 1       Electronics    3.3       Returned  Positive         13.84
# 2       Electronics    1.4   Not Returned   Neutral         17.37
# 3             Books    4.4       Returned  Positive           NaN
# 4          Clothing    1.3   Not Returned  Positive          6.30
# 5             Books    2.0       Returned   Neutral          9.63
# 6              Food    1.5       Returned   Neutral          8.01
# 7          Clothing    3.0       Returned  Negative           NaN
# 8              Food    2.9   Not Returned  Negative         12.24
# 9             Books    1.1       Returned   Neutral           NaN
# 10             Food    3.0   Not Returned   Neutral         19.73
# 11            Books    3.7   Not Returned   Neutral           NaN
# 12            Books    2.2       Returned  Positive           NaN
# 13            Books    3.7   Not Returned   Neutral           NaN
# 14            Books    3.4       Returned   Neutral           NaN
# 15         Clothing    2.4       Returned   Neutral          8.07
# 16         Clothing    3.6       Returned  Negative           NaN
# 17         Clothing    1.7   Not Returned   Neutral           NaN
# 18            Books    1.5       Returned   Neutral         11.16
# 19            Books    3.0       Returned  Positive          7.42
# 20         Clothing    4.9   Not Returned  Negative         13.51
# 21            Books    3.0       Returned  Positive         16.78
# 22             Food    3.8       Returned  Negative         11.49
# 23         Clothing    4.3       Returned  Negative          8.15
# 24      Electronics    2.5       Returned  Positive          5.56
# 25             Food    1.1   Not Returned   Neutral           NaN
# 26         Clothing    1.1       Returned   Neutral         15.12
# 27      Electronics    2.6   Not Returned  Negative          5.28
# 28            Books    2.1       Returned  Negative         14.76
# 29      Electronics    3.7       Returned   Neutral           NaN
# 30      Electronics    1.7   Not Returned  Positive          8.83
# 31            Books    3.8   Not Returned   Neutral          6.76
# 32         Clothing    5.0   Not Returned  Negative          8.15
# 33            Books    2.0       Returned  Negative         14.38
# 34            Books    2.0   Not Returned  Positive          7.61
#
#     coupon_code delivery_rating
# 0      WELCOME5             NaN
# 1           nan             3.0
# 2      FREESHIP             1.8
# 3           nan             NaN
# 4           nan             3.4
# 5           nan             4.2
# 6           nan             1.9
# 7           nan             4.6
# 8           nan             3.4
# 9           nan             NaN
# 10       SAVE10             NaN
# 11          nan             1.2
# 12       SAVE10             2.7
# 13       SAVE10             1.1
# 14     WELCOME5             3.9
# 15     FREESHIP             NaN
# 16          nan             NaN
# 17          nan             4.4
# 18          nan             4.4
# 19          nan             NaN
# 20          nan             NaN
# 21     FREESHIP             1.3
# 22       SAVE10             NaN
# 23     FREESHIP             2.4
# 24     FREESHIP             3.4
# 25          nan             3.4
# 26          nan             NaN
# 27       SAVE10             1.2
# 28       SAVE10             2.0
# 29          nan             1.3
# 30       SAVE10             1.2
# 31          nan             4.8
# 32     FREESHIP             NaN
# 33          nan             4.9
# 34     FREESHIP             2.4
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 03:**
# </div>

# %%
df.isna().sum()
# Out:
# date                 0
# customer_id          0
# product_id           0
# quantity             0
# price                0
# discount             0
# revenue              0
# store_id             0
# region               0
# payment_method       0
# is_member            0
# delivery_days        0
# customer_age         0
# gender               0
# product_category     0
# rating               0
# return_status        0
# feedback             0
# shipping_cost       11
# coupon_code          0
# delivery_rating     11
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **4. Replace Non-Valuable Missing Values**
#
# **Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1346         181         8  89.80      0.09  653.7440
# 1  2023-01-02         1609         151         7  99.56      0.13  606.3204
# 2  2023-01-03         1840         148         1  43.11      0.08   39.6612
# 3  2023-01-04         1053         167         3  30.08      0.13   78.5088
# 4  2023-01-05         1971         131         7  80.81      0.20  452.5360
# 5  2023-01-06         1279         117         6  71.80      0.13  374.7960
# 6  2023-01-07         1570         182         2  46.81      0.20   74.8960
# 7  2023-01-08         1602         148         6  84.31      0.00  505.8600
# 8  2023-01-09         1047         181         6  20.76      0.09  113.3496
# 9  2023-01-10         1708         150         9  97.86      0.29  625.3254
# 10 2023-01-11         1810         194         5  44.82      0.18  183.7620
# 11 2023-01-12         1071         170         8  59.62      0.01  472.1904
# 12 2023-01-13         1316         199         2  52.72      0.19   85.4064
# 13 2023-01-14         1362         182         9  80.52      0.11  644.9652
# 14 2023-01-15         1224         120         9  61.52      0.25  415.2600
# 15 2023-01-16         1985         184         8  47.87      0.17  317.8568
# 16 2023-01-17         1232         180         5  85.77      0.14  368.8110
# 17 2023-01-18         1412         161         4  80.12      0.11  285.2272
# 18 2023-01-19         1585         102         6  55.11      0.28  238.0752
# 19 2023-01-20         1280         159         8  25.27      0.13  175.8792
# 20 2023-01-21         1309         197         7  41.05      0.22  224.1330
# 21 2023-01-22         1402         168         8  65.12      0.09  474.0736
# 22 2023-01-23         1264         130         1  30.86      0.10   27.7740
# 23 2023-01-24         1969         130         6  56.85      0.10  306.9900
# 24 2023-01-25         1435         147         6  63.22      0.11  337.5948
# 25 2023-01-26         1594         155         5  35.07      0.14  150.8010
# 26 2023-01-27         1464         180         3  78.07      0.11  208.4469
# 27 2023-01-28         1189         174         9  38.37      0.25  258.9975
# 28 2023-01-29         1743         177         7  46.83      0.11  291.7509
# 29 2023-01-30         1875         113         3  62.24      0.15  158.7120
# 30 2023-01-31         1114         133         2  59.71      0.09  108.6722
# 31 2023-02-01         1384         150         3  97.76      0.00  293.2800
# 32 2023-02-02         1511         174         1  83.63      0.21   66.0677
# 33 2023-02-03         1922         139         5  80.79      0.09  367.5945
# 34 2023-02-04         1161         131         3  20.36      0.20   48.8640
#
#     store_id region payment_method  ...  gender  product_category  rating  \
# 0          5  South    Credit Card  ...    Male          Clothing     1.0
# 1          4   West           Cash  ...   Other             Books     4.1
# 2          9  South           Cash  ...   Other          Clothing     3.5
# 3          7   West           Cash  ...    Male              Food     4.0
# 4          9   West           Cash  ...    Male          Clothing     4.2
# 5          5  North    Credit Card  ...  Female              Food     4.5
# 6          7   West         Online  ...    Male       Electronics     4.3
# 7          1   West         Online  ...   Other          Clothing     4.4
# 8          1   East         Online  ...   Other              Food     1.5
# 9          2  North    Credit Card  ...    Male             Books     4.6
# 10         1   East    Credit Card  ...   Other       Electronics     4.6
# 11         5  South    Credit Card  ...  Female          Clothing     2.5
# 12         9   West    Credit Card  ...  Female          Clothing     4.4
# 13         3  North    Credit Card  ...  Female             Books     2.6
# 14         3  North         Online  ...    Male              Food     3.8
# 15         3  North         Online  ...  Female             Books     2.3
# 16         4   East           Cash  ...    Male          Clothing     4.3
# 17         3   West    Credit Card  ...  Female          Clothing     3.5
# 18         1   East         Online  ...  Female             Books     2.8
# 19         2  North         Online  ...    Male          Clothing     3.2
# 20         6  North    Credit Card  ...    Male             Books     2.2
# 21         2   East         Online  ...    Male       Electronics     4.0
# 22         5  North           Cash  ...   Other          Clothing     2.3
# 23         7   East         Online  ...  Female             Books     3.2
# 24         7  North         Online  ...  Female              Food     4.0
# 25         9  North         Online  ...  Female          Clothing     1.7
# 26         9   West    Credit Card  ...   Other       Electronics     5.0
# 27         3  North           Cash  ...    Male       Electronics     2.0
# 28         1  South           Cash  ...  Female       Electronics     4.6
# 29         1  North    Credit Card  ...   Other       Electronics     1.9
# 30         4  North         Online  ...    Male             Books     2.4
# 31         6  South    Credit Card  ...    Male              Food     1.4
# 32         6   East           Cash  ...  Female              Food     1.5
# 33         3  North    Credit Card  ...    Male             Books     2.4
# 34         4   West    Credit Card  ...    Male       Electronics     4.5
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0       Returned  Negative            NaN      SAVE10             3.5
# 1       Returned  Positive          15.74      SAVE10             3.1
# 2       Returned  Positive          19.39         nan             NaN
# 3       Returned  Positive          15.53    WELCOME5             3.0
# 4   Not Returned   Neutral          12.26         nan             1.6
# 5       Returned   Neutral          17.06    FREESHIP             NaN
# 6       Returned  Positive            NaN    WELCOME5             2.8
# 7       Returned  Positive          14.82         nan             NaN
# 8       Returned   Neutral            NaN    WELCOME5             3.3
# 9       Returned  Positive            NaN    WELCOME5             4.2
# 10      Returned  Negative            NaN    WELCOME5             2.1
# 11  Not Returned  Negative          15.24    FREESHIP             4.4
# 12      Returned  Negative          11.44    WELCOME5             2.9
# 13      Returned  Negative            NaN         nan             2.2
# 14  Not Returned   Neutral            NaN      SAVE10             4.0
# 15  Not Returned   Neutral           8.34         nan             NaN
# 16  Not Returned  Negative            NaN      SAVE10             2.6
# 17      Returned  Positive           7.56         nan             4.2
# 18  Not Returned  Negative            NaN         nan             1.5
# 19  Not Returned   Neutral          16.77         nan             2.9
# 20      Returned  Negative          15.00      SAVE10             2.9
# 21  Not Returned  Negative          11.49      SAVE10             NaN
# 22      Returned  Negative          19.51         nan             4.8
# 23      Returned   Neutral           6.58      SAVE10             1.0
# 24  Not Returned  Positive            NaN      SAVE10             NaN
# 25  Not Returned  Positive          10.86      SAVE10             2.4
# 26      Returned  Positive            NaN      SAVE10             NaN
# 27      Returned  Positive          11.14      SAVE10             1.0
# 28      Returned   Neutral          18.13      SAVE10             3.8
# 29  Not Returned  Negative          16.75      SAVE10             3.9
# 30      Returned  Positive          19.61         nan             3.1
# 31  Not Returned   Neutral          14.44    FREESHIP             1.6
# 32  Not Returned  Positive          18.31      SAVE10             NaN
# 33  Not Returned  Positive           5.17    WELCOME5             4.4
# 34  Not Returned  Positive            NaN      SAVE10             2.6
#
#                  customer_note customer_values
# 0          First-time customer         value_3
# 1          Requested gift wrap         no_data
# 2          Requested gift wrap         value_5
# 3   Preferred morning delivery         unknown
# 4          First-time customer         unknown
# 5          Requested gift wrap         unknown
# 6                      no_data         value_4
# 7                      unknown         unknown
# 8               Frequent buyer         unknown
# 9          Requested gift wrap         unknown
# 10         Requested gift wrap         unknown
# 11         Used loyalty points         unknown
# 12                     unknown         unknown
# 13                     no_data         value_5
# 14                     no_data         no_data
# 15         Used loyalty points         no_data
# 16         First-time customer         no_data
# 17                     unknown         unknown
# 18         Requested gift wrap         value_2
# 19                     unknown         value_4
# 20                     unknown         no_data
# 21                     no_data         no_data
# 22                     no_data         value_5
# 23                     no_data         value_1
# 24                     no_data         no_data
# 25         First-time customer         no_data
# 26                     no_data         no_data
# 27                     unknown         unknown
# 28                     no_data         value_5
# 29                     unknown         no_data
# 30         First-time customer         value_5
# 31                     unknown         value_4
# 32                     unknown         value_1
# 33              Frequent buyer         value_5
# 34                     no_data         value_1
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
df.replace({
    'customer_note': {
        'no_data': np.nan,
        'unknown': np.nan
    },
    'customer_values': {
        'no_data': np.nan,
        'unknown': np.nan
    }
}, inplace=True)

display(df.isna().any())
display(df.isna().sum())
# Out:
# date                False
# customer_id         False
# product_id          False
# quantity            False
# price               False
# discount            False
# revenue             False
# store_id            False
# region              False
# payment_method      False
# is_member           False
# delivery_days       False
# customer_age        False
# gender              False
# product_category    False
# rating              False
# return_status       False
# feedback            False
# shipping_cost        True
# coupon_code         False
# delivery_rating      True
# customer_note        True
# customer_values      True
# dtype: bool
# date                 0
# customer_id          0
# product_id           0
# quantity             0
# price                0
# discount             0
# revenue              0
# store_id             0
# region               0
# payment_method       0
# is_member            0
# delivery_days        0
# customer_age         0
# gender               0
# product_category     0
# rating               0
# return_status        0
# feedback             0
# shipping_cost       12
# coupon_code          0
# delivery_rating      8
# customer_note       19
# customer_values     21
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **5. Drop Rows with Any Missing Value**
#
# **Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         
# 20         8   East         Online  ...  Female              Food     4.6
# 21         3   West         Online  ...    Male          Clothing     3.6
# 22         8  North         Online  ...   Other          Clothing     3.7
# 23         5  North         Online  ...    Male              Food     2.4
# 24         5   East    Credit Card  ...   Other       Electronics     4.8
# 25         1  South           Cash  ...  Female       Electronics     1.0
# 26         7   West         Online  ...   Other       Electronics     2.0
# 27         7   East    Credit Card  ...    Male             Books     1.2
# 28         3  North           Cash  ...    Male          Clothing     3.0
# 29         7  South           Cash  ...  Female              Food     2.2
# 30         1  South         Online  ...  Female          Clothing     4.3
# 31         4  North           Cash  ...    Male       Electronics     2.9
# 32         5  South         Online  ...   Other          Clothing     2.8
# 33         8  South    Credit Card  ...   Other          Clothing     1.4
# 34         8  South           Cash  ...    Male       Electronics     3.9
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0       Returned  Positive          10.14         nan             1.5
# 1   Not Returned  Positive          18.39         nan             NaN
# 2       Returned  Negative          16.52    WELCOME5             3.2
# 3   Not Returned  Positive          10.01    FREESHIP             NaN
# 4       Returned  Positive          17.20    FREESHIP             2.8
# 5       Returned   Neutral          15.38    WELCOME5             NaN
# 6   Not Returned  Positive          14.36    FREESHIP             NaN
# 7       Returned  Negative          12.74    FREESHIP             3.7
# 8       Returned  Negative          11.65         nan             3.9
# 9       Returned  Positive            NaN    FREESHIP             4.1
# 10      Returned  Negative            NaN      SAVE10             3.2
# 11      Returned   Neutral          18.41    FREESHIP             4.0
# 12  Not Returned  Positive          13.97    FREESHIP             5.0
# 13  Not Returned  Negative            NaN         nan             4.3
# 14      Returned  Negative          17.74         nan             3.7
# 15      Returned  Negative          15.93    WELCOME5             NaN
# 16  Not Returned  Positive            NaN    WELCOME5             4.8
# 17      Returned  Positive          12.01         nan             3.8
# 18  Not Returned  Negative            NaN    WELCOME5             1.8
# 19      Returned   Neutral            NaN         nan             4.0
# 20  Not Returned  Positive          10.93    WELCOME5             2.5
# 21      Returned  Negative           9.33         nan             1.6
# 22      Returned  Negative          13.22    WELCOME5             NaN
# 23      Returned   Neutral           8.70         nan             2.7
# 24  Not Returned  Negative           7.99      SAVE10             1.0
# 25      Returned   Neutral          15.08    WELCOME5             NaN
# 26      Returned  Negative           9.62         nan             2.6
# 27  Not Returned  Positive          11.52    WELCOME5             2.7
# 28  Not Returned  Positive          19.86         nan             3.2
# 29      Returned  Positive           9.59         nan             2.8
# 30  Not Returned   Neutral           5.76    WELCOME5             4.5
# 31      Returned  Negative           9.61    WELCOME5             5.0
# 32      Returned  Negative          18.88    WELCOME5             1.6
# 33      Returned  Positive           9.53         nan             1.1
# 34      Returned  Negative          10.33         nan             1.5
#
#                  customer_note customer_values
# 0                      unknown         no_data
# 1                      unknown         value_5
# 2          First-time customer         value_4
# 3          Requested gift wrap         value_1
# 4          First-time customer         value_5
# 5                      no_data         value_4
# 6                      no_data         value_3
# 7                      unknown         no_data
# 8          Requested gift wrap         value_3
# 9               Frequent buyer         value_2
# 10                     no_data         value_2
# 11         Used loyalty points         value_4
# 12              Frequent buyer         unknown
# 13  Preferred morning delivery         value_1
# 14  Preferred morning delivery         no_data
# 15                     no_data         no_data
# 16                     unknown         no_data
# 17  Preferred morning delivery         no_data
# 18         First-time customer         no_data
# 19                     no_data         no_data
# 20                     no_data         no_data
# 21         Used loyalty points         no_data
# 22                     no_data         value_5
# 23                     no_data         value_3
# 24  Preferred morning delivery         unknown
# 25                     no_data         unknown
# 26                     no_data         unknown
# 27                     no_data         no_data
# 28                     unknown         value_1
# 29                     unknown         no_data
# 30         Used loyalty points         value_4
# 31                     no_data         no_data
# 32  Preferred morning delivery         no_data
# 33                     unknown         value_1
# 34              Frequent buyer         no_data
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
dropped_df = df.dropna(how='any')
display(dropped_df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1402         176         4  22.59      0.28   65.0592
# 2  2023-01-03         1832         162         1  67.49      0.04   64.7904
# 4  2023-01-05         1349         117         8  79.13      0.18  519.0928
# 7  2023-01-08         1458         192         7  65.01      0.06  427.7658
# 8  2023-01-09         1888         124         4  54.20      0.05  205.9600
# 11 2023-01-12         1278         132         9  37.76      0.17  282.0672
# 12 2023-01-13         1840         178         1  81.12      0.16   68.1408
# 14 2023-01-15         1539         140         1  11.45      0.10   10.3050
# 17 2023-01-18         1954         178         6  43.80      0.20  210.2400
# 20 2023-01-21         1497         107         8  76.99      0.15  523.5320
# 21 2023-01-22         1105         147         7  82.69      0.07  538.3119
# 23 2023-01-24         1201         104         7  89.84      0.17  521.9704
# 24 2023-01-25         1476         190         9  43.09      0.09  352.9071
# 26 2023-01-27         1983         197         3  39.75      0.06  112.0950
# 27 2023-01-28         1993         177         6  46.62      0.15  237.7620
# 28 2023-01-29         1468         181         5  52.71      0.13  229.2885
# 29 2023-01-30         1846         151         9  93.96      0.15  718.7940
# 30 2023-01-31         1584         163         8  78.67      0.09  572.7176
# 31 2023-02-01         1473         107         6  82.93      0.14  427.9188
# 32 2023-02-02         1494         163         7  47.21      0.05  313.9465
# 33 2023-02-03         1942         165         9  66.34      0.16  501.5304
# 34 2023-02-04         1794         125         4  61.74      0.11  219.7944
#
#     store_id region payment_method  ...  gender  product_category  rating  \
# 0          1  South         Online  ...  Female       Electronics     3.1
# 2          4  South           Cash  ...    Male              Food     1.6
# 4          2  North    Credit Card  ...   Other       Electronics     1.0
# 7          1  North    Credit Card  ...    Male       Electronics     4.6
# 8          5  North    Credit Card  ...    Male       Electronics     4.6
# 11         7   West           Cash  ...   Other             Books     1.3
# 12         5   West         Online  ...    Male             Books     4.2
# 14         2   West    Credit Card  ...  Female       Electronics     1.7
# 17         4   West         Online  ...  Female             Books     3.5
# 20         8   East         Online  ...  Female              Food     4.6
# 21         3   West         Online  ...    Male          Clothing     3.6
# 23         5  North         Online  ...    Male              Food     2.4
# 24         5   East    Credit Card  ...   Other       Electronics     4.8
# 26         7   West         Online  ...   Other       Electronics     2.0
# 27         7   East    Credit Card  ...    Male             Books     1.2
# 28         3  North           Cash  ...    Male          Clothing     3.0
# 29         7  South           Cash  ...  Female              Food     2.2
# 30         1  South         Online  ...  Female          Clothing     4.3
# 31         4  North           Cash  ...    Male       Electronics     2.9
# 32         5  South         Online  ...   Other          Clothing     2.8
# 33         8  South    Credit Card  ...   Other          Clothing     1.4
# 34         8  South           Cash  ...    Male       Electronics     3.9
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0       Returned  Positive          10.14         nan             1.5
# 2       Returned  Negative          16.52    WELCOME5             3.2
# 4       Returned  Positive          17.20    FREESHIP             2.8
# 7       Returned  Negative          12.74    FREESHIP             3.7
# 8       Returned  Negative          11.65         nan             3.9
# 11      Returned   Neutral          18.41    FREESHIP             4.0
# 12  Not Returned  Positive          13.97    FREESHIP             5.0
# 14      Returned  Negative          17.74         nan             3.7
# 17      Returned  Positive          12.01         nan             3.8
# 20  Not Returned  Positive          10.93    WELCOME5             2.5
# 21      Returned  Negative           9.33         nan             1.6
# 23      Returned   Neutral           8.70         nan             2.7
# 24  Not Returned  Negative           7.99      SAVE10             1.0
# 26      Returned  Negative           9.62         nan             2.6
# 27  Not Returned  Positive          11.52    WELCOME5             2.7
# 28  Not Returned  Positive          19.86         nan             3.2
# 29      Returned  Positive           9.59         nan             2.8
# 30  Not Returned   Neutral           5.76    WELCOME5             4.5
# 31      Returned  Negative           9.61    WELCOME5             5.0
# 32      Returned  Negative          18.88    WELCOME5             1.6
# 33      Returned  Positive           9.53         nan             1.1
# 34      Returned  Negative          10.33         nan             1.5
#
#                  customer_note customer_values
# 0                      unknown         no_data
# 2          First-time customer         value_4
# 4          First-time customer         value_5
# 7                      unknown         no_data
# 8          Requested gift wrap         value_3
# 11         Used loyalty points         value_4
# 12              Frequent buyer         unknown
# 14  Preferred morning delivery         no_data
# 17  Preferred morning delivery         no_data
# 20                     no_data         no_data
# 21         Used loyalty points         no_data
# 23                     no_data         value_3
# 24  Preferred morning delivery         unknown
# 26                     no_data         unknown
# 27                     no_data         no_data
# 28                     unknown         value_1
# 29                     unknown         no_data
# 30         Used loyalty points         value_4
# 31                     no_data         no_data
# 32  Preferred morning delivery         no_data
# 33                     unknown         value_1
# 34              Frequent buyer         no_data
#
# [22 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **6. Drop Columns with Any Missing Value**
#
# **Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1281         137         3  89.80      0.27  196.6620
# 1  2023-01-02         1475         143         2  84.63      0.16  142.1784
# 2  2023-01-03         1917         188         4  10.01      0.15   34.0340
# 3  2023-01-04         1169         139         6  48.34      0.18  237.8328
# 4  2023-01-05         1226         140         1  29.77      0.17   24.7091
# 5  2023-01-06         1150         139         7  26.62      0.27  136.0282
# 6  2023-01-07         1177         104         9  71.01      0.12  562.3992
# 7  2023-01-08         1342         186         5  97.85      0.12  430.5400
# 8  2023-01-09         1944         191         8  28.54      0.18  187.2224
# 9  2023-01-10         1056         179         7  61.47      0.17  357.1407
# 10 2023-01-11         1699         192         2  26.38      0.21   41.6804
# 11 2023-01-12         1366         155         2  18.34      0.28   26.4096
# 12 2023-01-13         1494         198         5  64.88      0.02  317.9120
# 32         5   East    Credit Card  ...   Other             Books     1.3
# 33         2  North           Cash  ...    Male              Food     4.5
# 34         8  South         Online  ...   Other       Electronics     3.4
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0   Not Returned   Neutral          19.27    FREESHIP             1.3
# 1       Returned  Negative            NaN         nan             2.2
# 2       Returned  Negative          15.06    WELCOME5             NaN
# 3   Not Returned  Negative          11.77         nan             3.3
# 4       Returned  Positive          14.15         nan             2.9
# 5       Returned   Neutral            NaN    FREESHIP             3.4
# 6       Returned   Neutral          15.72    WELCOME5             3.8
# 7       Returned  Negative          17.36         nan             NaN
# 8       Returned  Negative            NaN      SAVE10             4.9
# 9   Not Returned  Positive            NaN      SAVE10             1.7
# 10  Not Returned  Positive          17.81    WELCOME5             3.4
# 11  Not Returned  Negative          10.18         nan             NaN
# 12  Not Returned  Positive           9.67         nan             5.0
# 13      Returned   Neutral          15.60    FREESHIP             3.9
# 14      Returned  Negative            NaN    FREESHIP             NaN
# 15      Returned   Neutral          18.84    WELCOME5             NaN
# 16  Not Returned   Neutral          10.57         nan             NaN
# 17      Returned  Negative           6.61      SAVE10             1.2
# 18      Returned  Positive           5.12    FREESHIP             1.4
# 19  Not Returned  Positive          12.17    WELCOME5             4.3
# 20      Returned  Positive            NaN    FREESHIP             1.7
# 21  Not Returned   Neutral            NaN         nan             2.1
# 22  Not Returned   Neutral            NaN         nan             1.8
# 23      Returned  Positive            NaN         nan             4.8
# 24  Not Returned  Positive           5.82         nan             NaN
# 25  Not Returned  Positive            NaN    WELCOME5             1.0
# 26  Not Returned  Negative            NaN         nan             NaN
# 27  Not Returned  Negative            NaN         nan             NaN
# 28  Not Returned   Neutral           9.47    WELCOME5             4.0
# 29  Not Returned   Neutral           8.04    WELCOME5             2.3
# 30  Not Returned   Neutral            NaN      SAVE10             3.3
# 31  Not Returned  Positive          16.97      SAVE10             2.1
# 32  Not Returned   Neutral          13.54    WELCOME5             NaN
# 33  Not Returned  Positive           8.26    FREESHIP             2.2
# 34      Returned   Neutral          14.41      SAVE10             1.7
#
#                  customer_note customer_values
# 0          First-time customer         no_data
# 1                      unknown         unknown
# 2   Preferred morning delivery         unknown
# 3   Preferred morning delivery         value_1
# 4                      unknown         unknown
# 5                      no_data         no_data
# 6               Frequent buyer         value_5
# 7                      unknown         value_4
# 8          Requested gift wrap         unknown
# 9               Frequent buyer         unknown
# 10                     no_data         value_2
# 11  Preferred morning delivery         unknown
# 12         Requested gift wrap         no_data
# 13         Requested gift wrap         unknown
# 14         First-time customer         no_data
# 15                     unknown         no_data
# 16              Frequent buyer         value_1
# 17                     unknown         value_4
# 18                     no_data         value_3
# 19                     no_data         no_data
# 20         First-time customer         value_1
# 21                     no_data         value_2
# 22                     unknown         unknown
# 23                     unknown         value_4
# 24                     no_data         value_3
# 25                     unknown         no_data
# 26              Frequent buyer         value_2
# 27                     unknown         value_1
# 28         First-time customer         unknown
# 29                     unknown         value_5
# 30                     unknown         value_2
# 31                     unknown         unknown
# 32         Requested gift wrap         value_5
# 33                     unknown         value_4
# 34         Used loyalty points         value_2
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution
# 15         6  South    Credit Card  ...              3            29  Female
# 16         5   East           Cash  ...              4            30  Female
# 17         2   West         Online  ...              2            49    Male
# 18         7  South         Online  ...              6            47    Male
# 19         3  South    Credit Card  ...              4            41   Other
# 20         3   West    Credit Card  ...              1            48  Female
# 21         1   West           Cash  ...              3            33   Other
# 22         3  South           Cash  ...              1            63    Male
# 23         3  North           Cash  ...              5            25    Male
# 24         1  North         Online  ...              4            33    Male
# 25         8  South           Cash  ...              2            37    Male
# 26         9   West         Online  ...              4            61  Female
# 27         2  South    Credit Card  ...              3            56   Other
# 28         2  North         Online  ...              2            37  Female
# 29         4  North    Credit Card  ...              6            67    Male
# 30         1  South         Online  ...              6            65  Female
# 31         9  South           Cash  ...              6            45    Male
# 32         5   East    Credit Card  ...              1            45   Other
# 33         2  North           Cash  ...              4            28    Male
# 34         8  South         Online  ...              6            60   Other
#
#    product_category rating  return_status  feedback coupon_code  \
# 0              Food    1.1   Not Returned   Neutral    FREESHIP
# 1              Food    1.1       Returned  Negative         nan
# 2          Clothing    2.3       Returned  Negative    WELCOME5
# 3             Books    2.7   Not Returned  Negative         nan
# 4          Clothing    1.5       Returned  Positive         nan
# 5             Books    1.1       Returned   Neutral    FREESHIP
# 6       Electronics    5.0       Returned   Neutral    WELCOME5
# 7             Books    4.6       Returned  Negative         nan
# 8              Food    2.4       Returned  Negative      SAVE10
# 9              Food    4.3   Not Returned  Positive      SAVE10
# 10         Clothing    1.5   Not Returned  Positive    WELCOME5
# 11      Electronics    2.9   Not Returned  Negative         nan
# 12      Electronics    4.2   Not Returned  Positive         nan
# 13      Electronics    2.7       Returned   Neutral    FREESHIP
# 14            Books    1.3       Returned  Negative    FREESHIP
# 15             Food    2.2       Returned   Neutral    WELCOME5
# 16            Books    4.9   Not Returned   Neutral         nan
# 17             Food    3.6       Returned  Negative      SAVE10
# 18             Food    3.2       Returned  Positive    FREESHIP
# 19         Clothing    2.8   Not Returned  Positive    WELCOME5
# 20             Food    2.8       Returned  Positive    FREESHIP
# 21         Clothing    2.6   Not Returned   Neutral         nan
# 22            Books    1.8   Not Returned   Neutral         nan
# 23            Books    3.3       Returned  Positive         nan
# 24            Books    1.1   Not Returned  Positive         nan
# 25      Electronics    3.7   Not Returned  Positive    WELCOME5
# 26            Books    4.0   Not Returned  Negative         nan
# 27            Books    3.1   Not Returned  Negative         nan
# 28         Clothing    1.7   Not Returned   Neutral    WELCOME5
# 29      Electronics    4.4   Not Returned   Neutral    WELCOME5
# 30             Food    1.5   Not Returned   Neutral      SAVE10
# 31            Books    1.0   Not Returned  Positive      SAVE10
# 32            Books    1.3   Not Returned   Neutral    WELCOME5
# 33             Food    4.5   Not Returned  Positive    FREESHIP
# 34      Electronics    3.4       Returned   Neutral      SAVE10
#
#                  customer_note customer_values
# 0          First-time customer         no_data
# 1                      unknown         unknown
# 2   Preferred morning delivery         unknown
# 3   Preferred morning delivery         value_1
# 4                      unknown         unknown
# 5                      no_data         no_data
# 6               Frequent buyer         value_5
# 7                      unknown         value_4
# 8          Requested gift wrap         unknown
# 35        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        4.0  North           Cash  ...            Books     3.7
# 1        3.0  North    Credit Card  ...             Food     2.0
# 2        8.0  South         Online  ...            Books     5.0
# 3        6.0   West    Credit Card  ...            Books     3.6
# 4        9.0   West           Cash  ...      Electronics     2.3
# 5        2.0   West           Cash  ...      Electronics     4.4
# 6        5.0   East           Cash  ...             Food     4.6
# 7        5.0   West         Online  ...         Clothing     1.4
# 8        6.0  South           Cash  ...      Electronics     2.3
# 9        9.0   West         Online  ...             Food     4.4
# 10       1.0   East         Online  ...            Books     2.5
# 11       6.0   West         Online  ...      Electronics     3.3
# 12       8.0   West    Credit Card  ...         Clothing     1.7
# 13       1.0  North    Credit Card  ...             Food     2.6
# 14       3.0  South         Online  ...            Books     4.8
# 15       8.0   East           Cash  ...      Electronics     4.6
# 16       8.0   East         Online  ...             Food     1.7
# 17       2.0   East    Credit Card  ...         Clothing     3.3
# 18       5.0   West           Cash  ...             Food     2.4
# 19       9.0   West           Cash  ...         Clothing     1.9
# 20       5.0   East           Cash  ...             Food     2.6
# 21       4.0   East         Online  ...             Food     1.1
# 22       1.0   East         Online  ...      Electronics     3.7
# 23       4.0  North         Online  ...         Clothing     4.0
# 24       6.0  North    Credit Card  ...             Food     5.0
# 25       8.0  South         Online  ...      Electronics     3.2
# 26       6.0   East    Credit Card  ...      Electronics     4.2
# 27       3.0  North           Cash  ...      Electronics     2.1
# 28       1.0   East    Credit Card  ...         Clothing     2.7
# 29       5.0   West           Cash  ...         Clothing     3.8
# 30       2.0  South           Cash  ...            Books     3.1
# 31       6.0   East    Credit Card  ...      Electronics     1.2
# 32       8.0  South    Credit Card  ...            Books     4.7
# 33       7.0  South    Credit Card  ...         Clothing     2.6
# 34       1.0  South         Online  ...            Books     1.1
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned   Neutral           NaN     FREESHIP             2.4
# 1    Not Returned   Neutral          8.82       SAVE10             NaN
# 2        Returned   Neutral         11.50       SAVE10             NaN
# 3        Returned  Positive          8.88     WELCOME5             1.6
# 4        Returned  Negative          8.90     WELCOME5             1.5
# 5    Not Returned  Negative         19.87     WELCOME5             3.4
# 6    Not Returned   Neutral         15.62     WELCOME5             NaN
# 7        Returned  Negative         17.77          nan             NaN
# 8        Returned  Negative          9.45          nan             2.2
# 9    Not Returned   Neutral         18.59          nan             NaN
# 10       Returned  Positive         16.76          nan             1.6
# 11   Not Returned  Positive         13.07          nan             3.0
# 12       Returned  Negative         18.86          nan             3.7
# 13   Not Returned  Negative           NaN     FREESHIP             1.2
# 14   Not Returned   Neutral         13.82          nan             4.0
# 15       Returned   Neutral         10.59       SAVE10             3.5
# 16       Returned   Neutral          9.59     WELCOME5             1.3
# 17       Returned  Positive         11.93     WELCOME5             4.7
# 18       Returned   Neutral         13.54     WELCOME5             2.3
# 19   Not Returned  Negative         16.55          nan             NaN
# 20   Not Returned  Negative           NaN          nan             4.6
# 21       Returned  Positive         10.50     FREESHIP             NaN
# 22   Not Returned  Positive         14.72          nan             NaN
# 23       Returned  Positive         15.25     WELCOME5             1.5
# 24   Not Returned  Positive         12.29          nan             5.0
# 25   Not Returned  Negative          6.71          nan             3.9
# 26       Returned   Neutral         15.24     FREESHIP             1.2
# 27       Returned   Neutral           NaN     FREESHIP             NaN
# 28   Not Returned  Positive          7.48       SAVE10             2.7
# 29       Returned  Positive          6.11     WELCOME5             4.7
# 30   Not Returned  Positive         16.74     FREESHIP             4.8
# 31       Returned  Negative          6.71          nan             2.7
# 32       Returned  Negative          7.00     FREESHIP             1.0
# 33       Returned  Positive           NaN          nan             NaN
# 34       Returned  Positive           NaN     FREESHIP             1.1
# 35            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0                      no_data          no_data            NaN
# 1                      unknown          value_4            NaN
# 2   Preferred morning delivery          unknown            NaN
# 3                      no_data          value_5            NaN
# 4          Used loyalty points          no_data            NaN
# 5                      unknown          value_2            NaN
# 6          First-time customer          no_data            NaN
# 7               Frequent buyer          value_2            NaN
# 8                      no_data          no_data            NaN
# 9                      no_data          unknown            NaN
# 10                     no_data          value_5            NaN
# 11                     unknown          value_4            NaN
# 12         Used loyalty points          unknown            NaN
# 13  Preferred morning delivery          unknown            NaN
# 14              Frequent buyer          unknown            NaN
# 15         Used loyalty points          unknown            NaN
# 16              Frequent buyer          no_data            NaN
# 17                     unknown          unknown            NaN
# 18         First-time customer          unknown            NaN
# 19                     unknown          unknown            NaN
# 20                     no_data          value_4            NaN
# 21         Used loyalty points          value_5            NaN
# 22                     no_data          value_1            NaN
# 23                     unknown          value_2            NaN
# 24                     unknown          value_3            NaN
# 25         Used loyalty points          no_data            NaN
# 26                     unknown          value_2            NaN
# 27              Frequent buyer          value_2            NaN
# 28                     unknown          unknown            NaN
# 29                     unknown          unknown            NaN
# 30                     no_data          no_data            NaN
# 31         Used loyalty points          no_data            NaN
# 32  Preferred morning delivery          no_data            NaN
# 33              Frequent buyer          value_3            NaN
# 34         Requested gift wrap          value_5            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 07:**
# </div>

# %%
# Write a Pandas program to drop the rows where all elements are missing in a given DataFrame
df_dropped = df.dropna(how='all')

# Display the DataFrame after dropping rows
display(df_dropped)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01       1381.0       165.0       3.0  30.74      0.06   86.6868
# 1  2023-01-02       1250.0       110.0       8.0  80.23      0.24  487.7984
# 2  2023-01-03       1500.0       189.0       8.0  73.13      0.12  514.8352
# 3  2023-01-04       1404.0       131.0       5.0  25.69      0.09  116.8895
# 4  2023-01-05       1479.0       197.0       8.0  11.98      0.26   70.9216
# 5  2023-01-06       1661.0       199.0       7.0  74.95      0.02  514.1570
# 6  2023-01-07       1217.0       119.0       8.0  30.56      0.10  220.0320
# 7  2023-01-08       1383.0       112.0       4.0  54.84      0.20  175.4880
# 8  2023-01-09       1299.0       101.0       7.0  61.41      0.03  416.9739
# 9  2023-01-10       1622.0       112.0       5.0  29.93      0.13  130.1955
# 23       4.0  North         Online  ...         Clothing     4.0
# 24       6.0  North    Credit Card  ...             Food     5.0
# 25       8.0  South         Online  ...      Electronics     3.2
# 26       6.0   East    Credit Card  ...      Electronics     4.2
# 27       3.0  North           Cash  ...      Electronics     2.1
# 28       1.0   East    Credit Card  ...         Clothing     2.7
# 29       5.0   West           Cash  ...         Clothing     3.8
# 30       2.0  South           Cash  ...            Books     3.1
# 31       6.0   East    Credit Card  ...      Electronics     1.2
# 32       8.0  South    Credit Card  ...            Books     4.7
# 33       7.0  South    Credit Card  ...         Clothing     2.6
# 34       1.0  South         Online  ...            Books     1.1
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned   Neutral           NaN     FREESHIP             2.4
# 1    Not Returned   Neutral          8.82       SAVE10             NaN
# 2        Returned   Neutral         11.50       SAVE10             NaN
# 3        Returned  Positive          8.88     WELCOME5             1.6
# 4        Returned  Negative          8.90     WELCOME5             1.5
# 5    Not Returned  Negative         19.87     WELCOME5             3.4
# 6    Not Returned   Neutral         15.62     WELCOME5             NaN
# 7        Returned  Negative         17.77          nan             NaN
# 8        Returned  Negative          9.45          nan             2.2
# 9    Not Returned   Neutral         18.59          nan             NaN
# 10       Returned  Positive         16.76          nan             1.6
# 11   Not Returned  Positive         13.07          nan             3.0
# 12       Returned  Negative         18.86          nan             3.7
# 13   Not Returned  Negative           NaN     FREESHIP             1.2
# 14   Not Returned   Neutral         13.82          nan             4.0
# 15       Returned   Neutral         10.59       SAVE10             3.5
# 16       Returned   Neutral          9.59     WELCOME5             1.3
# 17       Returned  Positive         11.93     WELCOME5             4.7
# 18       Returned   Neutral         13.54     WELCOME5             2.3
# 19   Not Returned  Negative         16.55          nan             NaN
# 20   Not Returned  Negative           NaN          nan             4.6
# 21       Returned  Positive         10.50     FREESHIP             NaN
# 22   Not Returned  Positive         14.72          nan             NaN
# 23       Returned  Positive         15.25     WELCOME5             1.5
# 24   Not Returned  Positive         12.29          nan             5.0
# 25   Not Returned  Negative          6.71          nan             3.9
# 26       Returned   Neutral         15.24     FREESHIP             1.2
# 27       Returned   Neutral           NaN     FREESHIP             NaN
# 28   Not Returned  Positive          7.48       SAVE10             2.7
# 29       Returned  Positive          6.11     WELCOME5             4.7
# 30   Not Returned  Positive         16.74     FREESHIP             4.8
# 31       Returned  Negative          6.71          nan             2.7
# 32       Returned  Negative          7.00     FREESHIP             1.0
# 33       Returned  Positive           NaN          nan             NaN
# 34       Returned  Positive           NaN     FREESHIP             1.1
#
#                  customer_note  customer_values all_nan_column
# 0                      no_data          no_data            NaN
# 1                      unknown          value_4            NaN
# 2   Preferred morning delivery          unknown            NaN
# 3                      no_data          value_5            NaN
# 4          Used loyalty points          no_data            NaN
# 5                      unknown          value_2            NaN
# 6          First-time customer          no_data            NaN
# 7               Frequent buyer          value_2            NaN
# 8                      no_data          no_data            NaN
# 9                      no_data          unknown            NaN
# 10                     no_data          value_5            NaN
# 11                     unknown          value_4            NaN
# 12         Used loyalty points          unknown            NaN
# 13  Preferred morning delivery          unknown            NaN
# 14              Frequent buyer          unknown            NaN
# 15         Used loyalty points          unknown            NaN
# 16              Frequent buyer          no_data            NaN
# 17                     unknown          unknown            NaN
# 18         First-time customer          unknown            NaN
# 19                     unknown          unknown            NaN
# 20                     no_data          value_4            NaN
# 21         Used loyalty points          value_5            NaN
# 22                     no_data          value_1            NaN
# 23                     unknown          value_2            NaN
# 24                     unknown          value_3            NaN
# 25         Used loyalty points          no_data            NaN
# 26                     unknown          value_2            NaN
# 27              Frequent buyer          value_2            NaN
# 28                     unknown          unknown            NaN
# 29                     unknown          unknown            NaN
# 30                     no_data          no_data            NaN
# 31         Used loyalty points          no_data            NaN
# 32  Preferred morning delivery          no_data            NaN
# 33              Frequent buyer          value_3            NaN
# 34         Requested gift wrap          value_5            NaN
#
# [35 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **8. Keep Rows with at Least 2 NaN Values**
#
# **Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Append a row of NaNs
df = pd.concat([df, pd.DataFrame([[np.nan] * df.shape[1]], columns=df.columns)], ignore_index=True)

# Add a new all-NaN column
df['all_nan_column'] = np.nan

# Display the updated DataFrame
display(df)
# Out:
# /var/folders/fb/453r9d2j24g8x8tc93n2k6600000gn/T/ipykernel_83461/4116745759.py:85: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([[np.nan] * df.shape[1]], columns=df.columns)], ignore_index=True)
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01       1616.0       198.0       6.0  78.48      0.28  339.0336
# 1  2023-01-02       1421.0       170.0       7.0  11.85      0.07   77.1435
# 2  2023-01-03       1475.0       107.0       9.0  99.93      0.22  701.5086
# 3  2023-01-04       1644.0       128.0       2.0  47.67      0.04   91.5264
# 4  2023-01-05       1035.0       122.0       1.0  32.69      0.28   23.5368
# 5  2023-01-06       1556.0       154.0       4.0  48.65      0.27  142.0580
# 6  2023-01-07       1418.0       126.0       7.0  52.71      0.05  350.5215
# 7  2023-01-08       1157.0       155.0       3.0  94.70      0.04  272.7360
# 8  2023-01-09       1832.0       145.0       8.0  99.85      0.01  790.8120
# 9  2023-01-10       1560.0       110.0       7.0  30.49      0.24  162.2068
# 10 2023-01-11       1276.0       177.0       7.0  75.48      0.27  385.7028
# 11 2023-01-12       1242.0       177.0       3.0  99.56      0.14  256.8648
# 12 2023-01-13       1894.0       157.0       4.0  69.17      0.25  207.5100
# 13 2023-01-14       1028.0       100.0       5.0  36.58      0.21  144.4910
# 14 2023-01-15       1877.0       109.0       2.0  52.03      0.26   77.0044
# 15 2023-01-16       1190.0       161.0       1.0  40.23      0.05   38.2185
# 16 2023-01-17       1873.0       196.0       7.0  53.61      0.05  356.5065
# 17 2023-01-18       1828.0       157.0       8.0  58.79      0.19  380.9592
# 18 2023-01-19       1146.0       183.0       2.0  18.35      0.13   31.9290
# 19 2023-01-20       1017.0       141.0       7.0  35.73      0.11  222.5979
# 20 2023-01-21       1449.0       144.0       6.0  14.70      0.04   84.6720
# 21 2023-01-22       1275.0       181.0       9.0  92.39      0.03  806.5647
# 22 2023-01-23       1692.0       161.0       4.0  52.19      0.05  198.3220
# 23 2023-01-24       1357.0       125.0       8.0  53.20      0.02  417.0880
# 24 2023-01-25       1237.0       146.0       6.0  43.28      0.22  202.5504
# 25 2023-01-26       1865.0       128.0       5.0  76.50      0.07  355.7250
# 26 2023-01-27       1095.0       120.0       1.0  53.49      0.00   53.4900
# 27 2023-01-28       1930.0       165.0       3.0  78.22      0.06  220.5804
# 28 2023-01-29       1830.0       191.0       9.0  11.30      0.13   88.4790
# 29 2023-01-30       1972.0       123.0       7.0  85.59      0.26  443.3562
# 30 2023-01-31       1376.0       149.0       6.0  44.48      0.09  242.8608
# 31 2023-02-01       1380.0       119.0       8.0  70.07      0.15  476.4760
# 32 2023-02-02       1403.0       169.0       9.0  72.75      0.22  510.7050
# 33 2023-02-03       1283.0       169.0       9.0  11.48      0.24   78.5232
# 34 2023-02-04       1012.0       103.0       4.0  20.60      0.21   65.0960
# 35        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        7.0  North           Cash  ...      Electronics     2.9
# 1        4.0   West           Cash  ...            Books     1.3
# 2        4.0  North         Online  ...             Food     4.3
# 3        6.0   East    Credit Card  ...      Electronics     1.2
# 4        8.0  South    Credit Card  ...      Electronics     2.8
# 5        2.0   East           Cash  ...             Food     1.2
# 6        7.0  North           Cash  ...             Food     4.6
# 7        4.0   East         Online  ...             Food     3.0
# 8        1.0   West           Cash  ...         Clothing     2.4
# 9        8.0   West         Online  ...         Clothing     4.2
# 10       2.0   East    Credit Card  ...      Electronics     3.4
# 11       5.0  South         Online  ...         Clothing     3.9
# 12       9.0   East           Cash  ...      Electronics     4.3
# 13       9.0   West           Cash  ...             Food     4.3
# 14       9.0  South    Credit Card  ...            Books     3.4
# 15       2.0  North           Cash  ...             Food     2.1
# 16       3.0   West           Cash  ...            Books     3.4
# 17       5.0  South    Credit Card  ...      Electronics     1.5
# 18       1.0  South    Credit Card  ...      Electronics     3.5
# 19       2.0  North    Credit Card  ...         Clothing     4.1
# 20       1.0  South           Cash  ...             Food     3.4
# 21       7.0   East    Credit Card  ...      Electronics     4.8
# 22       5.0  South         Online  ...      Electronics     2.1
# 23       6.0  North           Cash  ...            Books     2.0
# 24       2.0  North         Online  ...      Electronics     3.2
# 25       7.0  South         Online  ...            Books     3.8
# 26       2.0   West         Online  ...         Clothing     1.8
# 27       1.0   West           Cash  ...             Food     2.5
# 28       4.0  South    Credit Card  ...            Books     3.9
# 29       2.0   West           Cash  ...         Clothing     1.8
# 30       1.0  North         Online  ...             Food     2.5
# 31       8.0   East           Cash  ...             Food     2.6
# 32       1.0   East    Credit Card  ...            Books     2.2
# 33       1.0   West           Cash  ...      Electronics     4.1
# 34       8.0   West         Online  ...            Books     4.2
# 35       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0        Returned   Neutral         18.20          nan             2.9
# 1    Not Returned   Neutral          6.87     FREESHIP             NaN
# 2    Not Returned   Neutral         13.06     WELCOME5             3.8
# 3        Returned   Neutral          9.06          nan             2.4
# 4    Not Returned   Neutral          7.24     FREESHIP             NaN
# 5    Not Returned  Negative         11.77     FREESHIP             4.7
# 6    Not Returned  Negative           NaN       SAVE10             NaN
# 7        Returned  Negative          8.50     FREESHIP             4.6
# 8        Returned  Negative          5.93     FREESHIP             4.2
# 9    Not Returned  Positive         15.52       SAVE10             NaN
# 10       Returned  Negative          8.83     WELCOME5             NaN
# 11       Returned  Positive         11.23       SAVE10             4.9
# 12       Returned  Negative         19.06          nan             NaN
# 13       Returned  Negative          5.43     FREESHIP             NaN
# 14   Not Returned  Positive          9.59     WELCOME5             3.0
# 15       Returned  Negative          5.41     FREESHIP             2.4
# 16       Returned  Positive           NaN     WELCOME5             NaN
# 17       Returned   Neutral           NaN     WELCOME5             4.8
# 18       Returned   Neutral           NaN     FREESHIP             2.3
# 19   Not Returned   Neutral          5.15     WELCOME5             3.3
# 20   Not Returned  Negative         16.71          nan             2.5
# 21   Not Returned  Negative           NaN          nan             1.3
# 22   Not Returned   Neutral         11.76     FREESHIP             NaN
# 23       Returned  Positive         11.45       SAVE10             NaN
# 24       Returned   Neutral         19.15     FREESHIP             4.9
# 25   Not Returned   Neutral         18.53     FREESHIP             4.5
# 26       Returned  Negative           NaN     WELCOME5             NaN
# 27       Returned   Neutral           NaN     FREESHIP             1.7
# 28       Returned   Neutral         12.65          nan             3.7
# 29       Returned  Positive          5.89          nan             1.4
# 30       Returned  Negative          9.23       SAVE10             1.2
# 31   Not Returned  Negative         19.21          nan             1.4
# 32   Not Returned   Neutral         18.76          nan             1.6
# 33       Returned   Neutral         14.90     FREESHIP             2.5
# 34   Not Returned  Positive         18.14       SAVE10             2.4
# 35            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0          Requested gift wrap          no_data            NaN
# 1                      no_data          unknown            NaN
# 2          Used loyalty points          value_5            NaN
# 3                      no_data          value_4            NaN
# 4   Preferred morning delivery          value_5            NaN
# 5          Requested gift wrap          no_data            NaN
# 6                      unknown          unknown            NaN
# 7                      no_data          no_data            NaN
# 8                      unknown          value_4            NaN
# 9   Preferred morning delivery          no_data            NaN
# 10                     unknown          no_data            NaN
# 11              Frequent buyer          value_3            NaN
# 12                     no_data          unknown            NaN
# 13         Used loyalty points          value_3            NaN
# 14         Used loyalty points          value_2            NaN
# 15  Preferred morning delivery          value_2            NaN
# 16                     unknown          value_5            NaN
# 17                     unknown          value_4            NaN
# 18         Used loyalty points          value_3            NaN
# 19         First-time customer          no_data            NaN
# 20                     unknown          value_3            NaN
# 21         Used loyalty points          value_5            NaN
# 22                     unknown          unknown            NaN
# 23              Frequent buyer          no_data            NaN
# 24         Used loyalty points          value_1            NaN
# 25                     unknown          no_data            NaN
# 26         First-time customer          value_2            NaN
# 27                     unknown          value_5            NaN
# 28         First-time customer          unknown            NaN
# 29              Frequent buyer          unknown            NaN
# 30                     no_data          value_1            NaN
# 31              Frequent buyer          value_1            NaN
# 32  Preferred morning delivery          no_data            NaN
# 33                     no_data          value_5            NaN
# 34                     no_data          value_2            NaN
# 35                         NaN              NaN            NaN
#
# [36 rows x 24 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 08:**
# </div>

# %%
pd.DataFrame.sum?
# Out:
# Signature:
# pd.DataFrame.sum(
#     self,
#     axis: 'Axis | None' = 0,
#     skipna: 'bool' = True,
#     numeric_only: 'bool' = False,
#     min_count: 'int' = 0,
#     **kwargs,
# )
# Docstring:
# Return the sum of the values over the requested axis.
#
# This is equivalent to the method ``numpy.sum``.
#
# Parameters
# ----------
# axis : {index (0), columns (1)}
#     Axis for the function to be applied on.
#     For `Series` this parameter is unused and defaults to 0.
#
#     .. warning::
#
#         The behavior of DataFrame.sum with ``axis=None`` is deprecated,
#         in a future version this will reduce over both axes and return a scalar
#         To retain the old behavior, pass axis=0 (or do not pass axis).
#
#     .. versionadded:: 2.0.0
#
# skipna : bool, default True
#     Exclude NA/null values when computing the result.
# numeric_only : bool, default False
#     Include only float, int, boolean columns. Not implemented for Series.
#
# min_count : int, default 0
#     The required number of valid values to perform the operation. If fewer than
#     ``min_count`` non-NA values are present the result will be NA.
# **kwargs
#     Additional keyword arguments to be passed to the function.
#
# Returns
# -------
# Series or scalar
#
# See Also
# --------
# Series.sum : Return the sum.
# Series.min : Return the minimum.
# Series.max : Return the maximum.
# Series.idxmin : Return the index of the minimum.
# Series.idxmax : Return the index of the maximum.
# DataFrame.sum : Return the sum over the requested axis.
# DataFrame.min : Return the minimum over the requested axis.
# DataFrame.max : Return the maximum over the requested axis.
# DataFrame.idxmin : Return the index of the minimum over the requested axis.
# DataFrame.idxmax : Return the index of the maximum over the requested axis.
#
# Examples
# --------
# >>> idx = pd.MultiIndex.from_arrays([
# ...     ['warm', 'warm', 'cold', 'cold'],
# ...     ['dog', 'falcon', 'fish', 'spider']],
# ...     names=['blooded', 'animal'])
# >>> s = pd.Series([4, 2, 0, 8], name='legs', index=idx)
# >>> s
# blooded  animal
# warm     dog       4
#          falcon    2
# cold     fish      0
#          spider    8
# Name: legs, dtype: int64
#
# >>> s.sum()
# 14
#
# By default, the sum of an empty or all-NA Series is ``0``.
#
# >>> pd.Series([], dtype="float64").sum()  # min_count=0 is the default
# 0.0
#
# This can be controlled with the ``min_count`` parameter. For example, if
# you'd like the sum of an empty series to be NaN, pass ``min_count=1``.
#
# >>> pd.Series([], dtype="float64").sum(min_count=1)
# nan
#
# Thanks to the ``skipna`` parameter, ``min_count`` handles all-NA and
# empty series identically.
#
# >>> pd.Series([np.nan]).sum()
# 0.0
#
# >>> pd.Series([np.nan]).sum(min_count=1)
# nan
# File:      ~/dev/pandas-exercises/.venv/lib/python3.12/site-packages/pandas/core/frame.py
# Type:      function

# %%
df.isnull().sum(axis=0)
# Out:
# date                 1
# customer_id          1
# product_id           1
# quantity             1
# price                1
# discount             1
# revenue              1
# store_id             1
# region               1
# payment_method       1
# is_member            1
# delivery_days        1
# customer_age         1
# gender               1
# product_category     1
# rating               1
# return_status        1
# feedback             1
# shipping_cost        8
# coupon_code          1
# delivery_rating     12
# customer_note        1
# customer_values      1
# all_nan_column      36
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      2
# 5      1
# 6      3
# 7      1
# 8      1
# 9      2
# 10     2
# 11     1
# 12     2
# 13     2
# 14     1
# 15     1
# 16     3
# 17     2
# 18     2
# 19     1
# 20     1
# 21     2
# 22     2
# 23     2
# 24     1
# 25     1
# 26     3
# 27     2
# 28     1
# 29     1
# 30     1
# 31     1
# 32     1
# 33     1
# 34     1
# 35    24
# dtype: int64

# %%
df_kept = df[df.isnull().sum(axis=1) >= 2]

# Display the DataFrame after keeping rows
display(df_kept.reset_index(drop=True))
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-02       1421.0       170.0       7.0  11.85      0.07   77.1435
# 1  2023-01-05       1035.0       122.0       1.0  32.69      0.28   23.5368
# 2  2023-01-07       1418.0       126.0       7.0  52.71      0.05  350.5215
# 3  2023-01-10       1560.0       110.0       7.0  30.49      0.24  162.2068
# 4  2023-01-11       1276.0       177.0       7.0  75.48      0.27  385.7028
# 5  2023-01-13       1894.0       157.0       4.0  69.17      0.25  207.5100
# 6  2023-01-14       1028.0       100.0       5.0  36.58      0.21  144.4910
# 7  2023-01-17       1873.0       196.0       7.0  53.61      0.05  356.5065
# 8  2023-01-18       1828.0       157.0       8.0  58.79      0.19  380.9592
# 9  2023-01-19       1146.0       183.0       2.0  18.35      0.13   31.9290
# 10 2023-01-22       1275.0       181.0       9.0  92.39      0.03  806.5647
# 11 2023-01-23       1692.0       161.0       4.0  52.19      0.05  198.3220
# 12 2023-01-24       1357.0       125.0       8.0  53.20      0.02  417.0880
# 13 2023-01-27       1095.0       120.0       1.0  53.49      0.00   53.4900
# 14 2023-01-28       1930.0       165.0       3.0  78.22      0.06  220.5804
# 15        NaT          NaN         NaN       NaN    NaN       NaN       NaN
#
#     store_id region payment_method  ... product_category  rating  \
# 0        4.0   West           Cash  ...            Books     1.3
# 1        8.0  South    Credit Card  ...      Electronics     2.8
# 2        7.0  North           Cash  ...             Food     4.6
# 3        8.0   West         Online  ...         Clothing     4.2
# 4        2.0   East    Credit Card  ...      Electronics     3.4
# 5        9.0   East           Cash  ...      Electronics     4.3
# 6        9.0   West           Cash  ...             Food     4.3
# 7        3.0   West           Cash  ...            Books     3.4
# 8        5.0  South    Credit Card  ...      Electronics     1.5
# 9        1.0  South    Credit Card  ...      Electronics     3.5
# 10       7.0   East    Credit Card  ...      Electronics     4.8
# 11       5.0  South         Online  ...      Electronics     2.1
# 12       6.0  North           Cash  ...            Books     2.0
# 13       2.0   West         Online  ...         Clothing     1.8
# 14       1.0   West           Cash  ...             Food     2.5
# 15       NaN    NaN            NaN  ...              NaN     NaN
#
#     return_status  feedback shipping_cost  coupon_code delivery_rating  \
# 0    Not Returned   Neutral          6.87     FREESHIP             NaN
# 1    Not Returned   Neutral          7.24     FREESHIP             NaN
# 2    Not Returned  Negative           NaN       SAVE10             NaN
# 3    Not Returned  Positive         15.52       SAVE10             NaN
# 4        Returned  Negative          8.83     WELCOME5             NaN
# 5        Returned  Negative         19.06          nan             NaN
# 6        Returned  Negative          5.43     FREESHIP             NaN
# 7        Returned  Positive           NaN     WELCOME5             NaN
# 8        Returned   Neutral           NaN     WELCOME5             4.8
# 9        Returned   Neutral           NaN     FREESHIP             2.3
# 10   Not Returned  Negative           NaN          nan             1.3
# 11   Not Returned   Neutral         11.76     FREESHIP             NaN
# 12       Returned  Positive         11.45       SAVE10             NaN
# 13       Returned  Negative           NaN     WELCOME5             NaN
# 14       Returned   Neutral           NaN     FREESHIP             1.7
# 15            NaN       NaN           NaN          NaN             NaN
#
#                  customer_note  customer_values all_nan_column
# 0                      no_data          unknown            NaN
# 1   Preferred morning delivery          value_5            NaN
# 2                      unknown          unknown            NaN
# 3   Preferred morning delivery          no_data            NaN
# 4                      unknown          no_data            NaN
# 5                      no_data          unknown            NaN
# 6          Used loyalty points          value_3            NaN
# 7                      unknown          value_5            NaN
# 8                      unknown          value_4            NaN
# 9          Used loyalty points          value_3            NaN
# 10         Used loyalty points          value_5            NaN
# 11                     unknown          unknown            NaN
# 12              Frequent buyer          no_data            NaN
# 13         First-time customer          value_2            NaN
# 14                     unknown          value_5            NaN
# 15                         NaN              NaN            NaN
#
# [16 rows x 24 columns]
