# 17         1  North         Online  ...              3            39    Male
# 18         8  South         Online  ...              3            45   Other
# 19         1   West           Cash  ...              6            29  Female
# 20         8   West         Online  ...              3            19  Female
# 21         9  South         Online  ...              4            42    Male
# 22         2   West         Online  ...              1            47   Other
# 23         8  South         Online  ...              4            31    Male
# 24         7  North         Online  ...              6            62    Male
# 25         4   East           Cash  ...              1            47    Male
# 26         4  South           Cash  ...              4            29   Other
# 27         2  North           Cash  ...              2            63  Female
# 28         8   West    Credit Card  ...              5            54  Female
# 29         6   East    Credit Card  ...              4            27   Other
# 30         1   West         Online  ...              3            38    Male
# 31         7   East         Online  ...              6            41   Other
# 32         8  North           Cash  ...              5            56   Other
# 33         4   East         Online  ...              1            49    Male
# 34         7  North    Credit Card  ...              3            39    Male
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0             Books    2.9   Not Returned  Positive         15.74
# 1       Electronics    1.8       Returned   Neutral         17.60
# 2             Books    3.2   Not Returned  Positive          5.87
# 3              Food    1.3   Not Returned   Neutral         13.57
# 4       Electronics    2.9       Returned  Negative           NaN
# 5       Electronics    3.5       Returned  Negative           NaN
# 6             Books    3.7       Returned  Positive           NaN
# 7             Books    2.5   Not Returned  Positive         10.21
# 8          Clothing    1.8       Returned  Positive         16.61
# 9          Clothing    2.8   Not Returned  Negative         18.45
# 10      Electronics    2.0       Returned  Positive           NaN
# 11            Books    4.3       Returned  Negative         17.86
# 12      Electronics    3.5       Returned  Positive         13.36
# 13         Clothing    4.0   Not Returned   Neutral          7.53
# 14             Food    2.5   Not Returned   Neutral         10.06
# 15      Electronics    1.6       Returned  Positive           NaN
# 16            Books    3.5       Returned  Positive         10.24
# 17         Clothing    1.7   Not Returned  Positive          5.17
# 18         Clothing    4.0   Not Returned   Neutral          9.95
# 19         Clothing    1.7   Not Returned  Positive         15.43
# 20      Electronics    3.0   Not Returned   Neutral         14.25
# 21            Books    4.1       Returned  Positive           NaN
# 22             Food    2.4   Not Returned  Negative         11.98
# 23            Books    2.1       Returned   Neutral         15.55
# 24             Food    2.6   Not Returned  Negative          8.44
# 25            Books    2.2       Returned   Neutral         11.07
# 26         Clothing    1.7       Returned  Negative          6.97
# 27            Books    2.0   Not Returned  Negative         16.31
# 28            Books    5.0   Not Returned  Negative         14.97
# 29            Books    3.3   Not Returned   Neutral         15.81
# 30             Food    4.2       Returned   Neutral           NaN
# 31         Clothing    2.8       Returned  Positive           NaN
# 32      Electronics    2.7       Returned   Neutral           NaN
# 33             Food    1.5       Returned  Negative         16.54
# 34            Books    4.8       Returned  Negative           NaN
#
#     coupon_code delivery_rating
# 0        SAVE10             2.1
# 1      WELCOME5             1.6
# 2        SAVE10             3.4
# 3      WELCOME5             2.1
# 4           nan             3.3
# 5           nan             5.0
# 6      FREESHIP             2.5
# 7           nan             NaN
# 8           nan             1.7
# 9           nan             2.9
# 10     FREESHIP             4.8
# 11     WELCOME5             2.3
# 12          nan             2.1
# 13     FREESHIP             NaN
# 14     WELCOME5             NaN
# 15          nan             3.5
# 16     WELCOME5             1.8
# 17     FREESHIP             NaN
# 18     FREESHIP             4.8
# 19     WELCOME5             3.2
# 20       SAVE10             NaN
# 21     WELCOME5             NaN
# 22     FREESHIP             3.7
# 23       SAVE10             4.7
# 24          nan             3.9
# 25          nan             4.8
# 26     FREESHIP             1.9
# 27     FREESHIP             1.3
# 28     FREESHIP             NaN
# 29          nan             NaN
# 30     FREESHIP             4.3
# 31     FREESHIP             2.6
# 32     FREESHIP             4.0
# 33     FREESHIP             3.7
# 34          nan             1.3
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
print(type(df.isna()))
df.isna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      date  customer_id  product_id  quantity  price  discount  revenue  \
# 0   False        False       False     False  False     False    False
# 1   False        False       False     False  False     False    False
# 2   False        False       False     False  False     False    False
# 3   False        False       False     False  False     False    False
# 4   False        False       False     False  False     False    False
# 5   False        False       False     False  False     False    False
# 6   False        False       False     False  False     False    False
# 7   False        False       False     False  False     False    False
# 8   False        False       False     False  False     False    False
# 9   False        False       False     False  False     False    False
# 10  False        False       False     False  False     False    False
# 11  False        False       False     False  False     False    False
# 12  False        False       False     False  False     False    False
# 13  False        False       False     False  False     False    False
# 14  False        False       False     False  False     False    False
# 15  False        False       False     False  False     False    False
# 16  False        False       False     False  False     False    False
# 17  False        False       False     False  False     False    False
# 18  False        False       False     False  False     False    False
# 19  False        False       False     False  False     False    False
# 20  False        False       False     False  False     False    False
# 21  False        False       False     False  False     False    False
# 22  False        False       False     False  False     False    False
# 23  False        False       False     False  False     False    False
# 24  False        False       False     False  False     False    False
# 25  False        False       False     False  False     False    False
# 26  False        False       False     False  False     False    False
# 27  False        False       False     False  False     False    False
# 28  False        False       False     False  False     False    False
# 29  False        False       False     False  False     False    False
# 30  False        False       False     False  False     False    False
# 31  False        False       False     False  False     False    False
# 32  False        False       False     False  False     False    False
# 33  False        False       False     False  False     False    False
# 34  False        False       False     False  False     False    False
#
#     store_id  region  payment_method  ...  delivery_days  customer_age  \
# 0      False   False           False  ...          False         False
# 1      False   False           False  ...          False         False
# 2      False   False           False  ...          False         False
# 3      False   False           False  ...          False         False
# 4      False   False           False  ...          False         False
# 5      False   False           False  ...          False         False
# 6      False   False           False  ...          False         False
# 7      False   False           False  ...          False         False
# 8      False   False           False  ...          False         False
# 9      False   False           False  ...          False         False
# 10     False   False           False  ...          False         False
# 11     False   False           False  ...          False         False
# 12     False   False           False  ...          False         False
# 13     False   False           False  ...          False         False
# 14     False   False           False  ...          False         False
# 15     False   False           False  ...          False         False
# 16     False   False           False  ...          False         False
# 17     False   False           False  ...          False         False
# 18     False   False           False  ...          False         False
# 19     False   False           False  ...          False         False
# 20     False   False           False  ...          False         False
# 21     False   False           False  ...          False         False
# 22     False   False           False  ...          False         False
# 23     False   False           False  ...          False         False
# 24     False   False           False  ...          False         False
# 25     False   False           False  ...          False         False
# 26     False   False           False  ...          False         False
# 27     False   False           False  ...          False         False
# 28     False   False           False  ...          False         False
# 29     False   False           False  ...          False         False
# 30     False   False           False  ...          False         False
# 31     False   False           False  ...          False         False
# 32     False   False           False  ...          False         False
# 33     False   False           False  ...          False         False
# 34     False   False           False  ...          False         False
#
#     gender  product_category  rating  return_status  feedback  shipping_cost  \
# 0    False             False   False          False     False          False
# 1    False             False   False          False     False          False
# 2    False             False   False          False     False          False
# 3    False             False   False          False     False          False
# 4    False             False   False          False     False           True
# 5    False             False   False          False     False           True
# 6    False             False   False          False     False           True
# 7    False             False   False          False     False          False
# 8    False             False   False          False     False          False
# 9    False             False   False          False     False          False
# 10   False             False   False          False     False           True
# 11   False             False   False          False     False          False
# 12   False             False   False          False     False          False
# 13   False             False   False          False     False          False
# 14   False             False   False          False     False          False
# 15   False             False   False          False     False           True
# 16   False             False   False          False     False          False
# 17   False             False   False          False     False          False
# 18   False             False   False          False     False          False
# 19   False             False   False          False     False          False
# 20   False             False   False          False     False          False
# 21   False             False   False          False     False           True
# 22   False             False   False          False     False          False
# 23   False             False   False          False     False          False
# 24   False             False   False          False     False          False
# 25   False             False   False          False     False          False
# 26   False             False   False          False     False          False
# 27   False             False   False          False     False          False
# 28   False             False   False          False     False          False
# 29   False             False   False          False     False          False
# 30   False             False   False          False     False           True
# 31   False             False   False          False     False           True
# 32   False             False   False          False     False           True
# 33   False             False   False          False     False          False
# 34   False             False   False          False     False           True
#
#     coupon_code  delivery_rating
# 0         False            False
# 1         False            False
# 2         False            False
# 3         False            False
# 4         False            False
# 5         False            False
# 6         False            False
# 7         False             True
# 8         False            False
# 9         False            False
# 10        False            False
# 11        False            False
# 12        False            False
# 13        False             True
# 14        False             True
# 15        False            False
# 16        False            False
# 17        False             True
# 18        False            False
# 19        False            False
# 20        False             True
# 21        False             True
# 22        False            False
# 23        False            False
# 24        False            False
# 25        False            False
# 26        False            False
# 27        False            False
# 28        False             True
# 29        False             True
# 30        False            False
# 31        False            False
# 32        False            False
# 33        False            False
# 34        False            False
#
# [35 rows x 21 columns]

# %%
print(df.isna().any())  
df.isna().sum()
# Out:
# date                False
# customer_id         False
# product_id          False
# quantity            False
# price               False
# discount            False
# revenue             False
# store_id            False
# region              False
# payment_method      False
# is_member           False
# delivery_days       False
# customer_age        False
# gender              False
# product_category    False
# rating              False
# return_status       False
# feedback            False
# shipping_cost        True
# coupon_code         False
# delivery_rating      True
# dtype: bool
# date                 0
# customer_id          0
# product_id           0
# quantity             0
# price                0
# discount             0
# revenue              0
# store_id             0
# region               0
# payment_method       0
# is_member            0
# delivery_days        0
# customer_age         0
# gender               0
# product_category     0
# rating               0
# return_status        0
# feedback             0
# shipping_cost       10
# coupon_code          0
# delivery_rating      8
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **2. Identify Columns with Missing Values**
#
# **Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1395         152         2  87.75      0.28  126.3600
# 1  2023-01-02         1009         121         3  62.05      0.19  150.7815
# 2  2023-01-03         1415         182         3  55.18      0.06  155.6076
# 3  2023-01-04         1999         198         9  77.35      0.19  563.8815
# 4  2023-01-05         1839         124         9  51.63      0.25  348.5025
# 5  2023-01-06         1162         109         3  96.70      0.05  275.5950
# 6  2023-01-07         1853         173         4  35.82      0.19  116.0568
# 7  2023-01-08         1185         137         1  32.04      0.02   31.3992
# 8  2023-01-09         1103         132         9  19.64      0.03  171.4572
# 9  2023-01-10         1788         166         1  15.39      0.10   13.8510
Other
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0          Clothing    1.1   Not Returned   Neutral           NaN
# 1       Electronics    4.4       Returned   Neutral          7.01
# 2          Clothing    1.7   Not Returned   Neutral         18.53
# 3              Food    4.6   Not Returned  Positive         16.08
# 4       Electronics    4.6       Returned   Neutral          6.03
# 5              Food    2.6       Returned  Positive         14.41
# 6             Books    1.3   Not Returned  Positive          5.10
# 7          Clothing    1.0       Returned  Negative         11.23
# 8              Food    3.3   Not Returned  Positive         16.12
# 9          Clothing    3.0       Returned  Negative          9.94
# 10            Books    4.9       Returned  Negative          6.48
# 11         Clothing    3.5       Returned  Negative         16.28
# 12             Food    4.6       Returned   Neutral          7.27
# 13      Electronics    2.6       Returned  Positive         15.50
# 14      Electronics    3.5   Not Returned   Neutral          7.28
# 15            Books    1.2   Not Returned  Positive          5.09
# 16      Electronics    3.1       Returned  Negative         16.09
# 17      Electronics    4.7       Returned  Positive         12.51
# 18             Food    1.3       Returned   Neutral         10.57
# 19             Food    3.2   Not Returned  Negative         19.20
# 20      Electronics    3.9       Returned   Neutral          6.87
# 21         Clothing    4.6       Returned   Neutral         11.24
# 22            Books    1.6       Returned  Positive         15.45
# 23      Electronics    2.7   Not Returned  Negative           NaN
# 24      Electronics    3.9       Returned  Negative          5.53
# 25            Books    1.6   Not Returned   Neutral          5.37
# 26      Electronics    4.4       Returned  Negative         19.92
# 27            Books    1.7   Not Returned   Neutral           NaN
# 28         Clothing    1.1       Returned  Negative         16.74
# 29      Electronics    1.4   Not Returned   Neutral         18.18
# 30         Clothing    1.5   Not Returned  Positive           NaN
# 31             Food    1.8       Returned  Positive          6.20
# 32         Clothing    2.6       Returned  Positive         16.56
# 33             Food    3.1       Returned   Neutral          9.82
# 34         Clothing    1.8       Returned  Positive         19.43
#
#     coupon_code delivery_rating
# 0      WELCOME5             2.4
# 1      FREESHIP             NaN
# 2      FREESHIP             NaN
# 3           nan             NaN
# 4      WELCOME5             NaN
# 5        SAVE10             NaN
# 6           nan             2.4
# 7           nan             1.7
# 8      WELCOME5             4.4
# 9      WELCOME5             NaN
# 10          nan             4.2
# 11          nan             1.5
# 12     FREESHIP             1.2
# 13          nan             2.6
# 14          nan             3.2
# 15       SAVE10             NaN
# 16       SAVE10             NaN
# 17     FREESHIP             4.1
# 18          nan             1.2
# 19          nan             NaN
# 20     FREESHIP             NaN
# 21       SAVE10             3.5
# 22          nan             3.1
# 23          nan             NaN
# 24     FREESHIP             4.6
# 25          nan             NaN
# 26     FREESHIP             2.3
# 27       SAVE10             1.2
# 28     FREESHIP             NaN
# 29          nan             3.6
# 30     FREESHIP             NaN
# 31     FREESHIP             4.1
# 32          nan             1.1
# 33          nan             1.4
# 34     FREESHIP             2.6
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 02:**
# </div>

# %%
df.isna().any()
cols_have_na = df.isna().any()[lambda x: x].index.tolist()

# %% [markdown]
# <div class="alert alert-warning">
#
# **3. Count Missing Values in Each Column**
#
# **Write a Pandas program to count the number of missing values in each column of a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         
# 25         1   West           Cash  ...              4            63  Female
# 26         9   East         Online  ...              2            61    Male
# 27         2  South           Cash  ...              4            36    Male
# 28         8  North         Online  ...              2            37    Male
# 29         2  North    Credit Card  ...              4            27    Male
# 30         2  South           Cash  ...              2            37    Male
# 31         7  North           Cash  ...              3            59   Other
# 32         3  North    Credit Card  ...              6            65   Other
# 33         2  North    Credit Card  ...              1            55    Male
# 34         5  South           Cash  ...              3            52    Male
#
#    product_category rating  return_status  feedback shipping_cost  \
# 0       Electronics    1.8       Returned  Negative         14.36
# 1          Clothing    1.1       Returned  Negative          8.54
# 2       Electronics    1.4       Returned  Negative         16.18
# 3          Clothing    1.9   Not Returned  Positive           NaN
# 4              Food    2.8   Not Returned  Positive         10.33
# 5       Electronics    1.7   Not Returned  Negative         16.92
# 6          Clothing    1.6       Returned  Negative         11.08
# 7          Clothing    1.1       Returned  Positive          8.19
# 8             Books    1.4       Returned   Neutral          6.22
# 9          Clothing    1.5   Not Returned  Negative         13.85
# 10      Electronics    1.7   Not Returned  Positive         17.19
# 11            Books    1.4   Not Returned  Negative         11.61
# 12         Clothing    4.2   Not Returned  Negative         10.66
# 13            Books    3.8   Not Returned  Negative         13.86
# 14             Food    2.6       Returned   Neutral          5.66
# 15         Clothing    1.4       Returned   Neutral         14.97
# 16         Clothing    1.1   Not Returned  Positive         10.48
# 17         Clothing    1.0       Returned  Negative         15.89
# 18            Books    1.9       Returned  Positive         12.05
# 19         Clothing    1.3   Not Returned  Positive         14.60
# 20             Food    2.4       Returned   Neutral          9.53
# 21             Food    3.4       Returned   Neutral          5.01
# 22         Clothing    3.6   Not Returned  Negative         17.90
# 23             Food    4.0   Not Returned   Neutral         14.26
# 24      Electronics    4.3       Returned  Positive         11.26
# 25         Clothing    3.0   Not Returned  Negative         19.14
# 26            Books    3.7       Returned   Neutral         14.07
# 27         Clothing    1.7       Returned  Positive         14.53
# 28             Food    1.6   Not Returned   Neutral          5.07
# 29         Clothing    1.9   Not Returned  Positive         16.34
# 30         Clothing    1.2       Returned   Neutral         12.60
# 31         Clothing    3.9   Not Returned  Positive          9.37
# 32             Food    4.6   Not Returned  Positive         16.18
# 33      Electronics    2.1   Not Returned  Positive         19.70
# 34            Books    4.6   Not Returned  Positive           NaN
#
#     coupon_code delivery_rating
# 0      WELCOME5             1.9
# 1           nan             NaN
# 2      FREESHIP             3.8
# 3      WELCOME5             NaN
# 4           nan             4.8
# 5           nan             2.1
# 6           nan             2.5
# 7           nan             2.9
# 8      WELCOME5             1.9
# 9           nan             2.6
# 10          nan             1.3
# 11       SAVE10             NaN
# 12     FREESHIP             1.2
# 13     FREESHIP             NaN
# 14       SAVE10             2.0
# 15       SAVE10             4.5
# 16       SAVE10             NaN
# 17          nan             1.2
# 18       SAVE10             NaN
# 19     WELCOME5             4.1
# 20     WELCOME5             1.2
# 21          nan             4.5
# 22          nan             4.4
# 23     WELCOME5             NaN
# 24     FREESHIP             4.7
# 25     FREESHIP             NaN
# 26          nan             4.6
# 27     WELCOME5             NaN
# 28     WELCOME5             4.5
# 29     FREESHIP             4.0
# 30          nan             1.8
# 31          nan             1.2
# 32       SAVE10             NaN
# 33       SAVE10             4.7
# 34     FREESHIP             NaN
#
# [35 rows x 21 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution
# 7          4  South           Cash  ...   Other             Books     1.5
# 8          4  South         Online  ...   Other          Clothing     2.2
# 9          1   West           Cash  ...  Female          Clothing     4.4
# 10         1   East    Credit Card  ...    Male       Electronics     3.5
# 11         3  South           Cash  ...    Male              Food     2.1
# 12         8   West    Credit Card  ...   Other              Food     4.2
# 13         5   West    Credit Card  ...    Male          Clothing     5.0
# 14         2   East         Online  ...    Male          Clothing     4.7
# 15         8   East           Cash  ...  Female          Clothing     4.8
# 16         9   East         Online  ...    Male              Food     3.4
# 17         7   West         Online  ...  Female          Clothing     3.2
# 18         5   West    Credit Card  ...    Male              Food     2.3
# 19         9   West         Online  ...    Male       Electronics     3.7
# 20         6  North         Online  ...    Male       Electronics     3.0
# 21         8   West    Credit Card  ...    Male       Electronics     4.3
# 22         5   East         Online  ...  Female       Electronics     4.0
# 23         8   West    Credit Card  ...  Female             Books     1.4
# 24         7   East         Online  ...    Male              Food     3.5
# 25         9  North           Cash  ...  Female       Electronics     4.0
# 26         5  South           Cash  ...    Male              Food     1.3
# 27         9  South         Online  ...  Female              Food     4.0
# 28         7  South           Cash  ...  Female             Books     3.7
# 29         8  North    Credit Card  ...   Other          Clothing     2.8
# 30         2   West         Online  ...  Female              Food     4.2
# 31         6   East         Online  ...  Female              Food     2.6
# 32         8  South         Online  ...    Male       Electronics     2.1
# 33         2  North         Online  ...   Other          Clothing     4.1
# 34         4   East           Cash  ...    Male              Food     3.1
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0   Not Returned  Negative          15.78         nan             2.9
# 1       Returned   Neutral          10.14         nan             5.0
# 2       Returned  Positive          11.02    FREESHIP             2.4
# 3   Not Returned  Positive          17.01         nan             NaN
# 4   Not Returned  Positive           6.73         nan             NaN
# 5   Not Returned  Negative           8.56    WELCOME5             NaN
# 6   Not Returned   Neutral          14.92         nan             4.2
# 7   Not Returned  Negative          11.35         nan             NaN
# 8       Returned  Positive            NaN    WELCOME5             4.1
# 9   Not Returned   Neutral          11.11      SAVE10             4.9
# 10  Not Returned   Neutral          11.99      SAVE10             2.4
# 11      Returned  Negative          19.07    FREESHIP             4.9
# 12      Returned   Neutral          14.54         nan             3.6
# 13  Not Returned  Positive           8.90    WELCOME5             4.9
# 14      Returned  Negative          14.62         nan             2.1
# 15  Not Returned  Positive            NaN         nan             3.0
# 16      Returned  Positive          14.05         nan             3.6
# 17  Not Returned  Positive           8.81    WELCOME5             NaN
# 18      Returned  Positive          16.52         nan             NaN
# 19      Returned  Negative          13.06         nan             3.0
# 20  Not Returned   Neutral          17.69      SAVE10             2.0
# 21  Not Returned  Negative            NaN         nan             2.5
# 22  Not Returned  Negative          18.65         nan             1.0
# 23  Not Returned  Negative          17.67         nan             1.6
# 24  Not Returned  Negative          13.26    WELCOME5             3.4
# 25  Not Returned  Negative            NaN    FREESHIP             3.1
# 26  Not Returned  Positive           5.43    WELCOME5             2.8
# 27      Returned   Neutral           5.92         nan             NaN
# 28      Returned  Positive           9.53    WELCOME5             NaN
# 29  Not Returned   Neutral           5.57      SAVE10             2.5
# 30      Returned  Positive           5.06    WELCOME5             2.7
# 31  Not Returned  Positive           7.91         nan             NaN
# 32      Returned  Positive          19.67         nan             1.5
# 33  Not Returned  Positive          13.35    FREESHIP             3.6
# 34      Returned  Positive          10.09         nan             1.7
#
#                  customer_note customer_values
# 0                      unknown         value_1
# 1                      unknown         value_3
# 2                      no_data         value_5
# 3                      unknown         value_5
# 4                      no_data         unknown
# 5                      no_data         unknown
# 6                      no_data         unknown
# 7                      unknown         unknown
# 8                      unknown         unknown
# 9   Preferred morning delivery         no_data
# 10         Used loyalty points         unknown
# 11  Preferred morning delivery         no_data
# 12         First-time customer         value_1
# 13                     no_data         no_data
# 14         First-time customer         value_2
# 15              Frequent buyer         unknown
# 16         Used loyalty points         unknown
# 17                     unknown         no_data
# 18                     unknown         unknown
# 19                     no_data         value_5
# 20                     unknown         no_data
# 21  Preferred morning delivery         no_data
# 22              Frequent buyer         no_data
# 23                     unknown         value_1
# 24                     unknown         unknown
# 25         First-time customer         unknown
# 26                     unknown         no_data
# 27              Frequent buyer         no_data
# 28         Used loyalty points         unknown
# 29              Frequent buyer         no_data
# 30         First-time customer         unknown
# 31                     unknown         value_4
# 32         Requested gift wrap         no_data
# 33                     unknown         no_data
# 34                     unknown         unknown
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
df.replace({
    'customer_note': {
        'no_data': np.nan,
        'unknown': np.nan
    },
    'customer_values': {
        'no_data': np.nan,
        'unknown': np.nan
    }
}, inplace=True)

display(df.isna().any())
display(df.isna().sum())
# Out:
# date                False
# customer_id         False
# product_id          False
# quantity            False
# price               False
# discount            False
# revenue             False
# store_id            False
# region              False
# payment_method      False
# is_member           False
# delivery_days       False
# customer_age        False
# gender              False
# product_category    False
# rating              False
# return_status       False
# feedback            False
# shipping_cost        True
# coupon_code         False
# delivery_rating      True
# customer_note        True
# customer_values      True
# dtype: bool
# date                 0
# customer_id          0
# product_id           0
# quantity             0
# price                0
# discount             0
# revenue              0
# store_id             0
# region               0
# payment_method       0
# is_member            0
# delivery_days        0
# customer_age         0
# gender               0
# product_category     0
# rating               0
# return_status        0
# feedback             0
# shipping_cost        4
# coupon_code          0
# delivery_rating      9
# customer_note       20
# customer_values     26
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **5. Drop Rows with Any Missing Value**
#
# **Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1686         192         9  63.66      0.08  527.1048
# 1  2023-01-02         1385         104         6  34.30      0.10  185.2200
# 2  2023-01-03         1252         115         3  21.02      0.20   50.4480
# 3  2023-01-04         1247         171         9  10.40      0.02   91.7280
# 4  2023-01-05         1212         157         7  92.68      0.25  486.5700
# 5  2023-01-06         1745         186         8  39.16      0.07  291.3504
# 6  2023-01-07         1240         130         1  81.85      0.00   81.8500
# 7  2023-01-08         1027         118         9  18.17      0.18  134.0946
# 8  2023-01-09         1984         115         1  28.34      0.19   22.9554
# 9  2023-01-10         1003         157         7  34.83      0.05  231.6195
# 10 2023-01-11         1082         188         3  34.03      0.16   85.7556
# 11 2023-01-12         1207         100         7  12.33      0.13   75.0897
# 12 2023-01-13         1225         146         8  41.23      0.21  260.5736
# 33         3   East    Credit Card  ...  Female             Books     3.4
# 34         4   West    Credit Card  ...  Female       Electronics     5.0
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0       Returned  Positive            NaN    WELCOME5             4.2
# 1   Not Returned  Positive            NaN    WELCOME5             3.3
# 2       Returned  Positive           6.51         nan             1.6
# 3   Not Returned  Positive            NaN         nan             1.3
# 4   Not Returned  Negative           7.07      SAVE10             3.4
# 5   Not Returned   Neutral          11.79      SAVE10             2.6
# 6   Not Returned   Neutral          14.57         nan             NaN
# 7       Returned  Negative            NaN         nan             3.3
# 8   Not Returned  Positive          11.33    WELCOME5             1.6
# 9   Not Returned  Positive          14.07    FREESHIP             4.0
# 10      Returned  Positive          19.76      SAVE10             2.6
# 11  Not Returned   Neutral          10.11         nan             4.2
# 12  Not Returned  Negative           9.69      SAVE10             4.8
# 13      Returned   Neutral           9.40    WELCOME5             1.0
# 14      Returned  Positive           7.37         nan             4.5
# 15  Not Returned   Neutral          12.32    WELCOME5             2.4
# 16  Not Returned  Negative          15.10    FREESHIP             4.1
# 17  Not Returned   Neutral            NaN    FREESHIP             NaN
# 18  Not Returned  Negative          16.16    WELCOME5             4.4
# 19  Not Returned   Neutral          16.83      SAVE10             4.8
# 20  Not Returned   Neutral            NaN    WELCOME5             4.2
# 21      Returned  Positive          15.88         nan             NaN
# 22  Not Returned   Neutral          15.42    WELCOME5             NaN
# 23      Returned  Positive           6.56    WELCOME5             2.5
# 24      Returned  Positive          18.12         nan             3.9
# 25  Not Returned   Neutral          17.95         nan             3.9
# 26  Not Returned  Positive          18.57      SAVE10             2.2
# 27  Not Returned   Neutral            NaN    FREESHIP             1.4
# 28  Not Returned   Neutral           8.86    WELCOME5             2.6
# 29      Returned  Negative           7.82    WELCOME5             2.1
# 30  Not Returned   Neutral          13.06         nan             NaN
# 31  Not Returned  Positive            NaN      SAVE10             4.5
# 32      Returned   Neutral          14.33      SAVE10             3.9
# 33      Returned   Neutral          10.63    WELCOME5             3.5
# 34  Not Returned   Neutral          10.55    FREESHIP             3.4
#
#                  customer_note customer_values
# 0               Frequent buyer         value_1
# 1                      unknown         unknown
# 2                      no_data         value_5
# 3                      unknown         value_1
# 4               Frequent buyer         value_3
# 5               Frequent buyer         value_5
# 6               Frequent buyer         no_data
# 7          First-time customer         unknown
# 8          Requested gift wrap         no_data
# 9          First-time customer         unknown
# 10         Requested gift wrap         unknown
# 11  Preferred morning delivery         value_3
# 12                     unknown         value_1
# 13         First-time customer         value_5
# 14         First-time customer         value_4
# 15              Frequent buyer         value_4
# 16                     unknown         value_1
# 17                     no_data         value_2
# 18              Frequent buyer         value_3
# 19                     unknown         no_data
# 20                     unknown         value_2
# 21                     no_data         no_data
# 22                     no_data         value_1
# 23                     no_data         value_4
# 24                     no_data         unknown
# 25                     unknown         value_3
# 26         First-time customer         value_3
# 27                     no_data         value_2
# 28                     no_data         value_5
# 29                     unknown         value_2
# 30                     unknown         value_1
# 31         First-time customer         unknown
# 32         First-time customer         no_data
# 33         First-time customer         value_2
# 34                     no_data         value_4
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
dropped_df = df.dropna(how='any')
display(dropped_df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 2  2023-01-03         1252         115         3  21.02      0.20   50.4480
# 4  2023-01-05         1212         157         7  92.68      0.25  486.5700
# 5  2023-01-06         1745         186         8  39.16      0.07  291.3504
# 8  2023-01-09         1984         115         1  28.34      0.19   22.9554
# 9  2023-01-10         1003         157         7  34.83      0.05  231.6195
# 10 2023-01-11         1082         188         3  34.03      0.16   85.7556
# 11 2023-01-12         1207         100         7  12.33      0.13   75.0897
# 12 2023-01-13         1225         146         8  41.23      0.21  260.5736
# 13 2023-01-14         1680         119         4  52.82      0.27  154.2344
# 14 2023-01-15         1409         194         6  42.29      0.10  228.3660
# 15 2023-01-16         1634         100         7  72.68      0.23  391.7452
# 16 2023-01-17         1398         161         9  83.33      0.15  637.4745
# 18 2023-01-19         1025         140         5  27.84      0.09  126.6720
# 19 2023-01-20         1903         137         4  60.09      0.15  204.3060
# 23 2023-01-24         1298         109         7  26.59      0.07  173.1009
# 24 2023-01-25         1866         125         2  13.21      0.11   23.5138
# 25 2023-01-26         1434         122         5  39.52      0.11  175.8640
# 26 2023-01-27         1102         185         6  28.83      0.16  145.3032
# 28 2023-01-29         1086         140         4  30.88      0.09  112.4032
# 29 2023-01-30         1055         182         6  32.30      0.02  189.9240
# 32 2023-02-02         1460         104         2  49.44      0.18   81.0816
# 33 2023-02-03         1803         189         7  42.43      0.14  255.4286
# 34 2023-02-04         1740         123         8  88.40      0.10  636.4800
#
#     store_id region payment_method  ...  gender  product_category  rating  \
# 2          9  South           Cash  ...   Other             Books     2.8
# 4          5  South    Credit Card  ...   Other          Clothing     4.1
# 5          2  South    Credit Card  ...    Male             Books     4.1
# 8          1   East           Cash  ...    Male              Food     1.7
# 9          1   East           Cash  ...    Male          Clothing     3.5
# 10         9   East         Online  ...   Other              Food     3.0
# 11         9   East         Online  ...   Other              Food     4.6
# 12         8   West           Cash  ...  Female          Clothing     2.7
# 13         5  South           Cash  ...  Female          Clothing     1.1
# 14         1   East         Online  ...    Male          Clothing     4.6
# 15         9   West         Online  ...    Male             Books     3.2
# 16         8  South           Cash  ...    Male          Clothing     2.6
# 18         9   West    Credit Card  ...    Male              Food     1.1
# 19         3   West    Credit Card  ...   Other              Food     4.0
# 23         5  North    Credit Card  ...  Female             Books     3.6
# 24         4  North         Online  ...    Male             Books     4.7
# 25         3  South    Credit Card  ...    Male              Food     3.5
# 26         8   East           Cash  ...  Female              Food     3.1
# 28         5  South           Cash  ...    Male          Clothing     4.3
# 29         2  South    Credit Card  ...    Male             Books     3.8
# 32         2  South           Cash  ...    Male       Electronics     2.9
# 33         3   East    Credit Card  ...  Female             Books     3.4
# 34         4   West    Credit Card  ...  Female       Electronics     5.0
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 2       Returned  Positive           6.51         nan             1.6
# 4   Not Returned  Negative           7.07      SAVE10             3.4
# 5   Not Returned   Neutral          11.79      SAVE10             2.6
# 8   Not Returned  Positive          11.33    WELCOME5             1.6
# 9   Not Returned  Positive          14.07    FREESHIP             4.0
# 10      Returned  Positive          19.76      SAVE10             2.6
# 11  Not Returned   Neutral          10.11         nan             4.2
# 12  Not Returned  Negative           9.69      SAVE10             4.8
# 13      Returned   Neutral           9.40    WELCOME5             1.0
# 14      Returned  Positive           7.37         nan             4.5
# 15  Not Returned   Neutral          12.32    WELCOME5             2.4
# 16  Not Returned  Negative          15.10    FREESHIP             4.1
# 18  Not Returned  Negative          16.16    WELCOME5             4.4
# 19  Not Returned   Neutral          16.83      SAVE10             4.8
# 23      Returned  Positive           6.56    WELCOME5             2.5
# 24      Returned  Positive          18.12         nan             3.9
# 25  Not Returned   Neutral          17.95         nan             3.9
# 26  Not Returned  Positive          18.57      SAVE10             2.2
# 28  Not Returned   Neutral           8.86    WELCOME5             2.6
# 29      Returned  Negative           7.82    WELCOME5             2.1
# 32      Returned   Neutral          14.33      SAVE10             3.9
# 33      Returned   Neutral          10.63    WELCOME5             3.5
# 34  Not Returned   Neutral          10.55    FREESHIP             3.4
#
#                  customer_note customer_values
# 2                      no_data         value_5
# 4               Frequent buyer         value_3
# 5               Frequent buyer         value_5
# 8          Requested gift wrap         no_data
# 9          First-time customer         unknown
# 10         Requested gift wrap         unknown
# 11  Preferred morning delivery         value_3
# 12                     unknown         value_1
# 13         First-time customer         value_5
# 14         First-time customer         value_4
# 15              Frequent buyer         value_4
# 16                     unknown         value_1
# 18              Frequent buyer         value_3
# 19                     unknown         no_data
# 23                     no_data         value_4
# 24                     no_data         unknown
# 25                     unknown         value_3
# 26         First-time customer         value_3
# 28                     no_data         value_5
# 29                     unknown         value_2
# 32         First-time customer         no_data
# 33         First-time customer         value_2
# 34                     no_data         value_4
#
# [23 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **6. Drop Columns with Any Missing Value**
#
# **Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.**
#
# </div>

# %%
# Create date range
date_range = pd.date_range(start='2023-01-01', periods=35, freq='D')

# Create a dictionary of data
data = {
    'date': date_range,
    'customer_id': np.random.randint(1000, 2000, size=35),
    'product_id': np.random.randint(100, 200, size=35),
    'quantity': np.random.randint(1, 10, size=35),
    'price': np.round(np.random.uniform(10.0, 100.0, size=35), 2),
    'discount': np.round(np.random.uniform(0, 0.3, size=35), 2),
    'revenue': lambda df: df['quantity'] * df['price'] * (1 - df['discount']),
    'store_id': np.random.randint(1, 10, size=35),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=35),
    'payment_method': np.random.choice(['Credit Card', 'Cash', 'Online'], size=35),
    'is_member': np.random.choice([True, False], size=35),
    'delivery_days': np.random.randint(1, 7, size=35),
    'customer_age': np.random.randint(18, 70, size=35),
    'gender': np.random.choice(['Male', 'Female', 'Other'], size=35),
    'product_category': np.random.choice(['Electronics', 'Clothing', 'Books', 'Food'], size=35),
    'rating': np.round(np.random.uniform(1.0, 5.0, size=35), 1),
    'return_status': np.random.choice(['Returned', 'Not Returned'], size=35),
    'feedback': np.random.choice(['Positive', 'Neutral', 'Negative'], size=35),
}

# Create DataFrame
df = pd.DataFrame(data)

# Compute revenue using the lambda function above
df['revenue'] = df['quantity'] * df['price'] * (1 - df['discount'])

# Add 'shipping_cost' with some missing values
df['shipping_cost'] = np.where(np.random.rand(len(df)) < 0.2, np.nan, np.round(np.random.uniform(5.0, 20.0, size=len(df)), 2))

# Add 'coupon_code' with some missing values
coupon_options = ['SAVE10', 'WELCOME5', 'FREESHIP', np.nan]
df['coupon_code'] = np.random.choice(coupon_options, size=len(df), p=[0.2, 0.2, 0.2, 0.4])

# Add 'delivery_rating' with some missing values
df['delivery_rating'] = np.where(np.random.rand(len(df)) < 0.3, np.nan, np.round(np.random.uniform(1.0, 5.0, size=len(df)), 1))

# Define informative and non-informative options
informative_notes = [
    "Requested gift wrap",
    "Preferred morning delivery",
    "Frequent buyer",
    "First-time customer",
    "Used loyalty points"
]

non_informative_notes = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_note():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_notes)
    else:
        return np.random.choice(informative_notes)

# Apply function to create the column
df['customer_note'] = [random_customer_note() for _ in range(len(df))]


# Define informative and non-informative options again for the second column
informative_values = [
    "value_1",
    "value_2",
    "value_3",
    "value_4",
    "value_5"
]

non_informative_values = ["no_data", "unknown"]

# Function to randomly pick one informative or one non-informative note
def random_customer_values():
    if np.random.rand() < 0.5:
        return np.random.choice(non_informative_values)
    else:
        return np.random.choice(informative_values)

df['customer_values'] = [random_customer_values() for _ in range(len(df))]

# Display the updated DataFrame
display(df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1711         194         6  67.69      0.16  341.1576
# 1  2023-01-02         1556         152         3  31.21      0.28   67.4136
# 2  2023-01-03         1422         166         4  84.81      0.07  315.4932
# 3  2023-01-04         1998         152         8  46.69      0.06  351.1088
# 4  2023-01-05         1540         127         4  46.58      0.25  139.7400
# 5  2023-01-06         1947         126         4  81.67      0.07  303.8124
# 6  2023-01-07         1036         135         9  67.24      0.22  472.0248
# 7  2023-01-08         1945         118         2  11.39      0.26   16.8572
# 8  2023-01-09         1431         174         9  70.77      0.14  547.7598
# 9  2023-01-10         1526         178         1  58.30      0.00   58.3000
# 10 2023-01-11         1569         136         6  73.39      0.20  352.2720
# 11 2023-01-12         1027         161         7  67.95      0.23  366.2505
# 12 2023-01-13         1843         122         8  98.63      0.06  741.6976
# 13 2023-01-14         1755         152         5  32.99      0.21  130.3105
# 14 2023-01-15         1592         125         8  54.41      0.16  365.6352
# 15 2023-01-16         1606         167         2  46.41      0.20   74.2560
# 16 2023-01-17         1219         107         8  52.97      0.10  381.3840
# 17 2023-01-18         1512         129         4  45.34      0.19  146.9016
# 18 2023-01-19         1790         170         8  11.87      0.25   71.2200
# 19 2023-01-20         1838         161         9  42.92      0.21  305.1612
# 20 2023-01-21         1577         160         9  31.39      0.26  209.0574
# 21 2023-01-22         1068         106         1  28.17      0.18   23.0994
# 22 2023-01-23         1873         171         3  52.19      0.23  120.5589
# 23 2023-01-24         1226         186         9  37.52      0.11  300.5352
# 24 2023-01-25         1432         153         8  72.64      0.02  569.4976
# 25 2023-01-26         1442         157         3  41.76      0.11  111.4992
# 26 2023-01-27         1274         179         2  88.33      0.16  148.3944
# 27 2023-01-28         1624         162         5  73.57      0.08  338.4220
# 28 2023-01-29         1518         103         5  37.31      0.13  162.2985
# 29 2023-01-30         1555         132         1  85.36      0.30   59.7520
# 30 2023-01-31         1010         137         5  74.67      0.21  294.9465
# 31 2023-02-01         1211         126         4  25.71      0.21   81.2436
# 32 2023-02-02         1238         153         3  23.27      0.00   69.8100
# 33 2023-02-03         1159         173         3  26.03      0.17   64.8147
# 34 2023-02-04         1433         118         3  91.14      0.13  237.8754
#
#     store_id region payment_method  ...  gender  product_category  rating  \
# 0          7   West           Cash  ...   Other              Food     2.9
# 1          3   West    Credit Card  ...    Male       Electronics     3.0
# 2          5  South           Cash  ...  Female             Books     2.0
# 3          4  North         Online  ...   Other       Electronics     3.3
# 4          6  South    Credit Card  ...  Female          Clothing     4.2
# 5          9  North           Cash  ...  Female             Books     4.7
# 6          8   West           Cash  ...  Female             Books     4.6
# 7          1   West         Online  ...    Male       Electronics     1.8
# 8          4   West    Credit Card  ...  Female              Food     2.4
# 9          1   East           Cash  ...  Female             Books     3.8
# 10         8   East         Online  ...  Female              Food     4.7
# 11         6   East         Online  ...    Male       Electronics     3.0
# 12         6   East           Cash  ...    Male          Clothing     1.8
# 13         9   West    Credit Card  ...    Male          Clothing     1.1
# 14         9   East    Credit Card  ...    Male          Clothing     3.1
# 15         3   East           Cash  ...   Other              Food     4.1
# 16         5   East           Cash  ...    Male       Electronics     1.9
# 17         6  South    Credit Card  ...  Female          Clothing     3.2
# 18         1   West           Cash  ...  Female              Food     4.5
# 19         9  North    Credit Card  ...   Other              Food     1.3
# 20         4   East           Cash  ...  Female          Clothing     3.4
# 21         8  North           Cash  ...    Male              Food     2.8
# 22         5   West    Credit Card  ...  Female              Food     3.4
# 23         2  North         Online  ...   Other             Books     1.3
# 24         6  South           Cash  ...    Male          Clothing     4.6
# 25         9  North           Cash  ...   Other              Food     3.0
# 26         5   West    Credit Card  ...   Other              Food     3.0
# 27         7  North         Online  ...   Other          Clothing     3.4
# 28         3  North    Credit Card  ...  Female             Books     2.9
# 29         1   East    Credit Card  ...   Other          Clothing     1.6
# 30         7   East         Online  ...    Male             Books     2.1
# 31         6  North         Online  ...    Male              Food     1.6
# 32         7   East           Cash  ...    Male             Books     4.5
# 33         1  North    Credit Card  ...    Male       Electronics     4.0
# 34         4   West    Credit Card  ...   Other       Electronics     1.2
#
#    return_status  feedback  shipping_cost coupon_code delivery_rating  \
# 0       Returned   Neutral           6.86      SAVE10             NaN
# 1       Returned  Negative          15.04         nan             3.6
# 2       Returned  Negative          16.59         nan             3.7
# 3       Returned   Neutral          10.40    WELCOME5             3.5
# 4       Returned   Neutral          15.90    WELCOME5             1.0
# 5       Returned  Negative           7.21         nan             NaN
# 6       Returned   Neutral            NaN    FREESHIP             2.2
# 7   Not Returned   Neutral            NaN         nan             NaN
# 8   Not Returned  Positive           9.50         nan             NaN
# 9   Not Returned   Neutral          10.24         nan             2.4
# 10      Returned  Negative           5.39         nan             2.7
# 11      Returned  Positive           5.09         nan             NaN
# 12  Not Returned  Positive          11.21         nan             2.2
# 13  Not Returned   Neutral           7.58         nan             4.4
# 14  Not Returned   Neutral            NaN         nan             2.5
# 15      Returned  Positive          11.80    FREESHIP             3.6
# 16  Not Returned  Negative          15.10    FREESHIP             2.4
# 17      Returned  Positive          16.72         nan             NaN
# 18      Returned  Negative           5.47      SAVE10             1.4
# 19  Not Returned  Negative          19.39      SAVE10             NaN
# 20  Not Returned   Neutral          13.95         nan             4.9
# 21  Not Returned  Positive            NaN    FREESHIP             NaN
# 22      Returned   Neutral           8.55         nan             4.9
# 23      Returned  Negative           6.94      SAVE10             4.4
# 24  Not Returned  Positive          19.21         nan             NaN
# 25  Not Returned   Neutral           9.54         nan             NaN
# 26  Not Returned   Neutral            NaN    WELCOME5             4.3
# 27      Returned  Positive           6.91      SAVE10             NaN
# 28  Not Returned  Positive          14.35         nan             2.0
# 29      Returned  Negative           7.87    WELCOME5             1.3
# 30  Not Returned   Neutral          11.36         nan             3.1
# 31      Returned   Neutral           7.57         nan             3.4
# 32      Returned  Negative          19.01         nan             4.3
# 33      Returned   Neutral          19.66         nan             NaN
# 34  Not Returned  Negative          17.13    WELCOME5             2.7
#
#                  customer_note customer_values
# 0          Requested gift wrap         no_data
# 1          Requested gift wrap         no_data
# 2               Frequent buyer         unknown
# 3                      unknown         value_3
# 4   Preferred morning delivery         value_3
# 5          Requested gift wrap         value_3
# 6   Preferred morning delivery         value_2
# 7                      unknown         no_data
# 8                      no_data         unknown
# 9   Preferred morning delivery         value_2
# 10                     no_data         value_4
# 11              Frequent buyer         unknown
# 12                     unknown         value_5
# 13                     unknown         value_3
# 14              Frequent buyer         value_1
# 15         Requested gift wrap         unknown
# 16                     unknown         unknown
# 17                     unknown         unknown
# 18                     unknown         value_4
# 19                     no_data         value_3
# 20  Preferred morning delivery         value_2
# 21         Requested gift wrap         unknown
# 22                     unknown         value_4
# 23         First-time customer         no_data
# 24                     no_data         value_1
# 25                     no_data         value_5
# 26                     unknown         no_data
# 27                     unknown         unknown
# 28  Preferred morning delivery         no_data
# 29                     no_data         unknown
# 30         Used loyalty points         value_1
# 31                     unknown         no_data
# 32         First-time customer         value_5
# 33              Frequent buyer         unknown
# 34                     unknown         value_1
#
# [35 rows x 23 columns]

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 06:**
# </div>

# %%
# Drop columns with any missing value
dropped_df = df.dropna(axis=1, how='any')
display(dropped_df)
# Out:
#          date  customer_id  product_id  quantity  price  discount   revenue  \
# 0  2023-01-01         1711         194         6  67.69      0.16  341.1576
# 1  2023-01-02         1556         152         3  31.21      0.28   67.4136
# 2  2023-01-03         1422         166         4  84.81      0.07  315.4932
# 3  2023-01-04         1998         152         8  46.69      0.06  351.1088
# 4  2023-01-05         1540         127         4  46.58      0.25  139.7400
# 5  2023-01-06         1947         126         4  81.67      0.07  303.8124
# 6  2023-01-07         1036         135         9  67.24      0.22  472.0248
# 31         6  North         Online  ...              1            26    Male
# 32         7   East           Cash  ...              6            36    Male
# 33         1  North    Credit Card  ...              5            34    Male
# 34         4   West    Credit Card  ...              5            32   Other
#
#    product_category rating  return_status  feedback coupon_code  \
# 0              Food    2.9       Returned   Neutral      SAVE10
# 1       Electronics    3.0       Returned  Negative         nan
# 2             Books    2.0       Returned  Negative         nan
# 3       Electronics    3.3       Returned   Neutral    WELCOME5
# 4          Clothing    4.2       Returned   Neutral    WELCOME5
# 5             Books    4.7       Returned  Negative         nan
# 6             Books    4.6       Returned   Neutral    FREESHIP
# 7       Electronics    1.8   Not Returned   Neutral         nan
# 8              Food    2.4   Not Returned  Positive         nan
# 9             Books    3.8   Not Returned   Neutral         nan
# 10             Food    4.7       Returned  Negative         nan
# 11      Electronics    3.0       Returned  Positive         nan
# 12         Clothing    1.8   Not Returned  Positive         nan
# 13         Clothing    1.1   Not Returned   Neutral         nan
# 14         Clothing    3.1   Not Returned   Neutral         nan
# 15             Food    4.1       Returned  Positive    FREESHIP
# 16      Electronics    1.9   Not Returned  Negative    FREESHIP
# 17         Clothing    3.2       Returned  Positive         nan
# 18             Food    4.5       Returned  Negative      SAVE10
# 19             Food    1.3   Not Returned  Negative      SAVE10
# 20         Clothing    3.4   Not Returned   Neutral         nan
# 21             Food    2.8   Not Returned  Positive    FREESHIP
# 22             Food    3.4       Returned   Neutral         nan
# 23            Books    1.3       Returned  Negative      SAVE10
# 24         Clothing    4.6   Not Returned  Positive         nan
# 25             Food    3.0   Not Returned   Neutral         nan
# 26             Food    3.0   Not Returned   Neutral    WELCOME5
# 27         Clothing    3.4       Returned  Positive      SAVE10
# 28            Books    2.9   Not Returned  Positive         nan
# 29         Clothing    1.6       Returned  Negative    WELCOME5
# 30            Books    2.1   Not Returned   Neutral         nan
# 31             Food    1.6       Returned   Neutral         nan
# 32            Books    4.5       Returned  Negative         nan
# 33      Electronics    4.0       Returned   Neutral         nan
# 34      Electronics    1.2   Not Returned  Negative    WELCOME5
#
#                  customer_note customer_values
# 0          Requested gift wrap         no_data
# 1          Requested gift wrap         no_data
# 2               Frequent buyer         unknown
# 3                      unknown         value_3
# 4   Preferred morning delivery         value_3
# 5          Requested gift wrap         value_3
# 6   Preferred morning delivery         value_2
# 7                      unknown         no_data
# 8                      no_data         unknown
# 9   Preferred morning delivery         value_2
# 10                     no_data         value_4
# 11              Frequent buyer         unknown
# 12                     unknown         value_5
# 13                     unknown         value_3
# 14              Frequent buyer         value_1
# 15         Requested gift wrap         unknown
# 16                     unknown         unknown
# 17                     unknown         unknown
# 18                     unknown         value_4
# 19                     no_data         value_3
# 20  Preferred morning delivery         value_2
# 21         Requested gift wrap         unknown
# 22                     unknown         value_4
# 23         First-time customer         no_data
# 24                     no_data         value_1
# 25                     no_data         value_5
# 26                     unknown         no_data
# 27                     unknown         unknown
# 28  Preferred morning delivery         no_data
# 29                     no_data         unknown
# 30         Used loyalty points         value_1
# 31                     unknown         no_data
# 32         First-time customer         value_5
# 33              Frequent buyer         unknown
# 34                     unknown         value_1
#
# [35 rows x 21 columns]
