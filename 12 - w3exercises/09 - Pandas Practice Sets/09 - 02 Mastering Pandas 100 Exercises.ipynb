# %% [markdown]
# [Mastering Pandas: 100 Exercises with solutions for Python data analysis](https://www.w3resource.com/python-exercises/pandas/pandas_100_exercises_with_solutions.php)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 1:**
#
# **Create a DataFrame from a dictionary of lists.**
#
# </div>

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#  'Age': [24, 27, 22, 32],
#  'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']}

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 01:**
# </div>

# %%
# Exercise 1:
# Create a DataFrame from a dictionary of lists.

df = pd.DataFrame(data)
df
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 2:**
#
# **Select the first 3 rows of a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 02:**
# </div>

# %%
# Exercise 2:
# Select the first 3 rows of a DataFrame.

df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0    man        True  NaN  Southampton    no  False          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN
# 2  woman       False  NaN  Southampton   yes   True          NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 3:**
#
# **Select the 'age' column from a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 03:**
# </div>

# %%
# Exercise 3:
# Select the 'age' column from a DataFrame.

display(df['age'])
display(df.loc[:, 'age'])
display(df.loc[:, ['age']])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 4:**
#
# **Filter rows based on a column condition.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 04:**
# </div>

# %%
# Exercise 4:
# Filter rows based on a column condition.

filt = df['age'] > 30
df_filtered = df[filt]
print(df_filtered.shape)
display(df_filtered.head(20))
# Out:
# (305, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 20         0       2    male  35.0      0      0  26.0000        S  Second
# 21         1       2    male  34.0      0      0  13.0000        S  Second
# 25         1       3  female  38.0      1      5  31.3875        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 5:**
#
# **Add a new column to an existing DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 05:**
# </div>

# %%
# Exercise 5:
# Add a new column to an existing DataFrame.

def adding_new_column(row):
    if row['who'] == 'man':
        return 1
    elif row['who'] == 'woman':
        return 2
    else:
        return 0

df['encoded_gender'] = df.apply(adding_new_column, axis=1)

#make sure all genders encoded
df.groupby(by=['who', 'encoded_gender']).agg(
    count = ('who','count')
    , sum_fare = ('fare','sum')
)
# Out:
#                       count    sum_fare
# who   encoded_gender
# child 0                  83   2721.2210
# man   1                 537  13352.0656
# woman 2                 271  12620.6627

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 6:**
#
# **Remove a column from a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 06:**
# </div>

# %%
# choosing column to drop
column2drop = df.isnull().sum()[df.isnull().sum().values == df.isnull().sum().max()].index.values[0]

# dropping the column
df.drop(
    columns=column2drop
    , axis=1
    , inplace=True
)

df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 7:**
#
# **Sort a DataFrame by a column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 07:**
# </div>

# %%
# Exercise 7:
# Sort a DataFrame by a column.

# sorting by one column
df.sort_values(
    by=['who']
    , ascending=[False]
    , inplace=True
)
print("DataFrame sorted by one column:\n")
display(df)

# sorting by one column
df.sort_values(
    by=['who', 'class', 'age']
    , ascending=[False, True, False]
    , inplace=True
)

print("DataFrame sorted by three columns:\n")
display(df)
# Out:
# DataFrame sorted by one column:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 255         1       3  female  29.0      0      2  15.2458        C   Third
# 591         1       1  female  52.0      1      0  78.2667        C   First
# 710         1       1  female  24.0      0      0  49.5042        C   First
# 402         0       3  female  21.0      1      0   9.8250        S   Third
# 593         0       3  female   NaN      0      2   7.7500        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 731         0       3    male  11.0      0      0  18.7875        C   Third
# 205         0       3  female   2.0      0      1  10.4625        S   Third
# 720         1       2  female   6.0      0      1  33.0000        S  Second
# 237         1       2  female   8.0      0      2  26.2500        S  Second
# 445         1       1    male   4.0      0      2  81.8583        S   First
#
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 8:**
#
# **Group a DataFrame by a column and calculate the mean of each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 08:**
# </div>

# %%
# Exercise 8:
# Group a DataFrame by a column and calculate the mean of each group.

# simple way
df.groupby(by=['who'])[['survived']].mean()
# Out:
#        survived
# who
# child  0.590361
# man    0.163873
# woman  0.756458

# %%
# more complicated one
def calculate_several_metrics(group):
    return pd.Series(
        {
            'mean_survived': group['survived'].mean()
            , 'max_age': group['age'].max()
            , 'min_fare': group['fare'].min()
            , 'std_age': group['age'].std()
            , 'average_age_of_survivors': group.loc[group['survived'] == 1, 'age'].mean()
        }
    )

df.groupby(by=['who']).apply(
    calculate_several_metrics
    , include_groups=False
)
# Out:
#        mean_survived  max_age  min_fare    std_age  average_age_of_survivors
# who
# child       0.590361     15.0     7.225   4.729063                  5.778980
# man         0.163873     80.0     0.000  12.906908                 34.069444
# woman       0.756458     63.0     6.750  11.495441                 32.446746

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 9:**
#
# **Replace missing values in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 09:**
# </div>

# %%
# Exercise 9:
# Replace missing values in a DataFrame.

df['Unnamed: 15'] = df['Unnamed: 15'].fillna(0)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 10:**
#
# **Convert a column to datetime.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)

# create a date column
df['date'] = '2023-01-01'
print(df.dtypes)
df.head(20)
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# Unnamed: 15    float64
# date            object
# dtype: object
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 10:**
# </div>

# %%
# Exercise 10:
# Convert a column to datetime.

df['date'] = pd.to_datetime(df['date'])
print(df.dtypes)
df.head(20)
# Out:
# survived                int64
# pclass                  int64
# sex                    object
# age                   float64
# sibsp                   int64
# parch                   int64
# fare                  float64
# embarked               object
# class                  object
# who                    object
# adult_male               bool
# deck                   object
# embark_town            object
# alive                  object
# alone                    bool
# Unnamed: 15           float64
# date           datetime64[ns]
# dtype: object
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 11:**
#
# **Create a DataFrame with specific column names.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 11:**
# </div>

# %%
# Exercise 11:
# Create a DataFrame with specific column names.

new_column_names = []
for col in df.columns:
    new_column_names.append(f'col_{col.capitalize()}')
df.columns = new_column_names
df.head(20)
# Out:
#     col_Survived  col_Pclass col_Sex  col_Age  col_Sibsp  col_Parch  col_Fare  \
# 0              0           3    male     22.0          1          0    7.2500
# 1              1           1  female     38.0          1          0   71.2833
# 2              1           3  female     26.0          0          0    7.9250
# 3              1           1  female     35.0          1          0   53.1000
# 4              0           3    male     35.0          0          0    8.0500
# 5              0           3    male      NaN          0          0    8.4583
# 6              0           1    male     54.0          0          0   51.8625
# 7              0           3    male      2.0          3          1   21.0750
# 8              1           3  female     27.0          0          2   11.1333
# 9              1           2  female     14.0          1          0   30.0708
# 10             1           3  female      4.0          1          1   16.7000
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 12:**
#
# **Calculate the sum of values in each column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 12:**
# </div>

# %%
# Exercise 12:
# Calculate the sum of values in each column.

df.select_dtypes(include=np.number).sum()
# Out:
# survived         342.0000
# pclass          2057.0000
# age            21205.1700
# sibsp            466.0000
# parch            340.0000
# fare           28693.9493
# Unnamed: 15        0.0000
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 13:**
#
# **Calculate the mean of values in each row.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 13:**
# </div>

# %%
# Exercise 13:
# Calculate the mean of values in each row.

df.select_dtypes(include=[np.number]).mean()
# Out:
# survived        0.383838
# pclass          2.308642
# age            29.699118
# sibsp           0.523008
# parch           0.381594
# fare           32.204208
# Unnamed: 15          NaN
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 14:**
#
# **Concatenate two DataFrames.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 14:**
# </div>

# %%
# Exercise 14:
# Concatenate two DataFrames.

concatenated_df = pd.concat([df,df], axis=0) # up and down
display(concatenated_df)

concatenated_df = pd.concat([df,df], axis=1) # left and right
display(concatenated_df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 15:**
#
# **Merge two DataFrames on a key.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 15:**
# </div>

# %%
# Exercise 15:
# Merge two DataFrames on a key.

merged_df = pd.merge(df, df, on=df.index)
merged_df
# Out:
#      key_0  survived_x  pclass_x   sex_x  age_x  sibsp_x  parch_x   fare_x  \
# 0        0           0         3    male   22.0        1        0   7.2500
# 1        1           1         1  female   38.0        1        0  71.2833
# 2        2           1         3  female   26.0        0        0   7.9250
# 3        3           1         1  female   35.0        1        0  53.1000
# 4        4           0         3    male   35.0        0        0   8.0500
# ..     ...         ...       ...     ...    ...      ...      ...      ...
# 886    886           0         2    male   27.0        0        0  13.0000
# 887    887           1         1  female   19.0        0        0  30.0000
# 888    888           0         3  female    NaN        1        2  23.4500
# 889    889           1         1    male   26.0        0        0  30.0000
# 890    890           0         3    male   32.0        0        0   7.7500
#
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 16:**
#
# **Create a pivot table from a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 16:**
# </div>

# %%
pd.pivot_table?
# Out:
# Signature:
# pd.pivot_table(
#     data: 'DataFrame',
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc: 'AggFuncType' = 'mean',
#     fill_value=None,
#     margins: 'bool' = False,
#     dropna: 'bool' = True,
#     margins_name: 'Hashable' = 'All',
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     sort: 'bool' = True,
# ) -> 'DataFrame'
# Docstring:
# Create a spreadsheet-style pivot table as a DataFrame.
#
# The levels in the pivot table will be stored in MultiIndex objects
# (hierarchical indexes) on the index and columns of the result DataFrame.
#
# Parameters
# ----------
# data : DataFrame
# values : list-like or scalar, optional
#     Column or columns to aggregate.
# index : column, Grouper, array, or list of the previous
#     Keys to group by on the pivot table index. If a list is passed,
#     it can contain any of the other types (except list). If an array is
#     passed, it must be the same length as the data and will be used in
# ...

# %%
# Exercise 16:
# Create a pivot table from a DataFrame.

result = pd.pivot_table(
    data=df
    , index='pclass'
    , columns='embarked'
    , values=['fare', 'age']
    , aggfunc=['mean', 'sum']
)

result

new_columns = []
for i in result.columns:
    a = i[0]+'_'+i[1]+'_'+i[2]
    new_columns.append(a)

result.columns = new_columns
result
# Out:
#         mean_age_C  mean_age_Q  mean_age_S  mean_fare_C  mean_fare_Q  \
# pclass
# 1        38.027027     38.5000   38.152037   104.718529    90.000000
# 2        22.766667     43.5000   30.386731    25.358335    12.350000
# 3        20.741951     25.9375   25.696552    11.214083    11.183393
#
#         mean_fare_S  sum_age_C  sum_age_Q  sum_age_S  sum_fare_C  sum_fare_Q  \
# pclass
# 1         70.364862    2814.00       77.0    4120.42   8901.0750    180.0000
# 2         20.327439     341.50       87.0    4740.33    431.0917     37.0500
# 3         14.644083     850.42      622.5    7452.00    740.1295    805.2043
#
#         sum_fare_S
# pclass
# 1        8936.3375
# 2        3333.7000
# 3        5169.3613

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 17:**
#
# **Reshape a DataFrame from long to wide format.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 17:**
# </div>

# %%
# Exercise 17:
# Reshape a DataFrame from long to wide format.

pd.pivot_table(
    data=df.head(30).iloc[:,:3]
    , index='sex'
    , columns='survived'
    , values='pclass'
    , aggfunc='sum'
)
# Out:
# survived   0   1
# sex
# female     9  28
# male      31   5

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 18:**
#
# **Calculate the correlation between columns in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 18:**
# </div>

# %%
# Exercise 18:
# Calculate the correlation between columns in a DataFrame.

df.select_dtypes(include=[np.number]).corr()
# Out:
#              survived    pclass       age     sibsp     parch      fare  \
# survived     1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass      -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age         -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp       -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch        0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare         0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# Unnamed: 15       NaN       NaN       NaN       NaN       NaN       NaN
#
#              Unnamed: 15
# survived             NaN
# pclass               NaN
# age                  NaN
# sibsp                NaN
# parch                NaN
# fare                 NaN
# Unnamed: 15          NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 19:**
#
# **Iterate over rows in a DataFrame using iterrows().**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 19:**
# </div>

# %%
# Exercise 19:
# Iterate over rows in a DataFrame using iterrows().
cnt = 0
for index, row in df.iterrows():
    print(index, row['age'], row['fare'])
    cnt+=1
    if cnt>20:
        break
# Out:
# 0 22.0 7.25
# 1 38.0 71.2833
# 2 26.0 7.925
# 3 35.0 53.1
# 4 35.0 8.05
# 5 nan 8.4583
# 6 54.0 51.8625
# 7 2.0 21.075
# 8 27.0 11.1333
# 9 14.0 30.0708
# 10 4.0 16.7
# 11 58.0 26.55
# 12 20.0 8.05
# 13 39.0 31.275
# 14 14.0 7.8542
# 15 55.0 16.0
# 16 2.0 29.125
# 17 nan 13.0
# 18 31.0 18.0
# 19 nan 7.225
# 20 35.0 26.0

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 20:**
#
# **Apply a function to each element in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 20:**
# </div>

# %%
# Exercise 20:
# Apply a function to each element in a DataFrame.

display(df.head(20))
lf = lambda col: col.map(lambda x: (x**2) * 2)
# Apply a function to each element using the map method
df = df.select_dtypes(include=[np.number]).apply(lf)
display(df.head(20))
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 21:**
#
# **Create a DataFrame from a list of dictionaries.**
#
# </div>

# %%
# path = '../data/'
# file_name = 'titanic.csv'
# df = pd.read_csv(path + file_name)
# print(df.shape)
# df.head(20)


mdict = {
    'col_1': [1,2,3,4,5,6]
    , 'col_2': [10,20,30,40,50,60]
}

mdict
# Out:
# {'col_1': [1, 2, 3, 4, 5, 6], 'col_2': [10, 20, 30, 40, 50, 60]}

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 21:**
# </div>

# %%
# Exercise 21:
# Create a DataFrame from a list of dictionaries.

df = pd.DataFrame(mdict)
df
# Out:
#    col_1  col_2
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50
# 5      6     60

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 22:**
#
# **Rename columns in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 22:**
# </div>

# %%
pd.DataFrame.rename?
# Out:
# Signature:
# pd.DataFrame.rename(
#     self,
#     mapper: 'Renamer | None' = None,
#     *,
#     index: 'Renamer | None' = None,
#     columns: 'Renamer | None' = None,
#     axis: 'Axis | None' = None,
#     copy: 'bool | None' = None,
#     inplace: 'bool' = False,
#     level: 'Level | None' = None,
#     errors: 'IgnoreRaise' = 'ignore',
# ) -> 'DataFrame | None'
# Docstring:
# Rename columns or index labels.
#
# Function / dict values must be unique (1-to-1). Labels not contained in
# a dict / Series will be left as-is. Extra labels listed don't throw an
# error.
#
# See the :ref:`user guide <basics.rename>` for more.
#
# Parameters
# ----------
# mapper : dict-like or function
#     Dict-like or function transformations to apply to
#     that axis' values. Use either ``mapper`` and ``axis`` to
#     specify the axis to target with ``mapper``, or ``index`` and
#     ``columns``.
# index : dict-like or function
#     Alternative to specifying axis (``mapper, axis=0``
# ...

# %%
# Exercise 22:
# Rename columns in a DataFrame.


print("DataFrame before renaming columns:")
display(df.head(20))

rename_names = {}
for i in df.columns:
    rename_names[i] = i.upper()
print('Rename columns dictionary:')
display(rename_names)


df.rename(
    columns=rename_names
    , inplace=True
)
print("DataFrame after renamin columns:")
display(df.head(20))
# Out:
# DataFrame before renaming columns:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
df = pd.read_csv(path + file_name)
print("DataFrame before renaming columns:")
display(df.head(20))


cols_upper = [i.upper() for i in df.columns]
cols_upper

for i, j in zip(df.columns, cols_upper):
    print(i, '->', j)
    df.rename(
        columns={i:j}
        , inplace=True
    )
print("DataFrame after renaming columns:")
df.head(20)
# Out:
# DataFrame before renaming columns:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 23:**
#
# **Filter rows by multiple conditions.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 23:**
# </div>

# %%
# Exercise 23:
# Filter rows by multiple conditions.


f1 = (df['sex']=='female')
f2 = (df['fare']>=10)

# filter + groupby + apply custom functions

def calculate_values(group):
    return pd.Series(
        {
            'age_sum': group['age'].sum()
            , 'alone_true': group.loc[group['alone']==True, 'alone'].sum()
            , 'alone_perc': group.loc[group['alone']==True, 'alone'].count() / group['alone'].count()
        }
    )

df[f1 & f2].groupby(by=['pclass']).apply(
    calculate_values
    , include_groups=False
)
# Out:
#         age_sum  alone_true  alone_perc
# pclass
# 1        2942.0        34.0    0.361702
# 2        2125.5        32.0    0.421053
# 3        1237.0         4.0    0.050000

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 24:**
#
# **Calculate the cumulative sum of a column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 24:**
# </div>

# %%
# Exercise 24:
# Calculate the cumulative sum of a column.


df['fareCumulativeSum'] = df['fare'].cumsum()
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 25:**
#
# **Drop rows with missing values.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 25:**
# </div>

# %%
# Exercise 25:
# Drop rows with missing values.

# df = df.drop("Unnamed: 15", axis=1)
print("DataFrame before dropna():")
display(df.head(20))

df.dropna(inplace=True)

print("DataFrame after dropna():")
display(df.head(20))
# Out:
# DataFrame before dropna():
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 26:**
#
# **Replace values in a DataFrame based on a condition.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 26:**
# </div>

# %%
# Exercise 26:
# Replace values in a DataFrame based on a condition.

condition = df['age']>18
df.loc[condition, ['fare']] = df['fare'] / 10
df
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0   0.72500        S   Third
# 1           1       1  female  38.0      1      0   7.12833        C   First
# 2           1       3  female  26.0      0      0   0.79250        S   Third
# 3           1       1  female  35.0      1      0   5.31000        S   First
# 4           0       3    male  35.0      0      0   0.80500        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 886         0       2    male  27.0      0      0   1.30000        S  Second
# 887         1       1  female  19.0      0      0   3.00000        S   First
# 888         0       3  female   NaN      1      2  23.45000        S   Third
# 889         1       1    male  26.0      0      0   3.00000        C   First
# 890         0       3    male  32.0      0      0   0.77500        Q   Third
#
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 27:**
#
# **Create a DataFrame with a MultiIndex.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 27:**
# </div>

# %%
# Exercise 27:
# Create a DataFrame with a MultiIndex.
arrays = [
    ['bar', 'bar', 'baz', 'baz'],
    ['one', 'two', 'one', 'two']
]
index = pd.MultiIndex.from_arrays(arrays, names=('first', 'second'))
df = pd.DataFrame({'A': [1, 2, 3, 4]}, index=index)
df
# Out:
#               A
# first second
# bar   one     1
#       two     2
# baz   one     3
#       two     4

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 28:**
#
# **Calculate the rolling mean of a column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 28:**
# </div>

# %%
# Exercise 28:
# Calculate the rolling mean of a column.

print("rolling mean:")
display(df.loc[:,['fare']].rolling(window=3).mean())


print("groupby + rolling mean:")
display(df.groupby(by=['embark_town'])[['fare']].rolling(window=3).mean())
# Out:
# rolling mean:
#           fare
# 0          NaN
# 1          NaN
# 2    28.819433
# 3    44.102767
# 4    23.025000
# ..         ...
# 886  16.391667
# 887  24.041667
# 888  22.150000
# 889  27.816667
# 890  20.400000
#
# [891 rows x 1 columns]
# groupby + rolling mean:
#                       fare
# embark_town
# Cherbourg   1          NaN
#             9          NaN
#             19   36.193033
#             26   14.840267
#             30   14.056933
# ...                    ...
# Southampton 883   9.637500
#             884   9.355567
#             886  10.183333
#             887  16.683333
#             888  22.150000
#
# [889 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 29:**
#
# **Create a DataFrame from a list of tuples.**
#
# </div>

# %%
data = [
    (1,2)
    , (3,4)
    , (3,4)
    , (3,4)
    , (3,4)
]
print("Data:\n", data)

col_names = ['column_1', 'column_2']
print("Column names:\n", col_names)
# Out:
# Data:
#  [(1, 2), (3, 4), (3, 4), (3, 4), (3, 4)]
# Column names:
#  ['column_1', 'column_2']

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 29:**
# </div>

# %%
# Exercise 29:
# Create a DataFrame from a list of tuples.

df = pd.DataFrame(
    data=data
    , columns=col_names
)

df
# Out:
#    column_1  column_2
# 0         1         2
# 1         3         4
# 2         3         4
# 3         3         4
# 4         3         4

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 30:**
#
# **Add a row to a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 30:**
# </div>

# %%
# Exercise 30:
# Add a row to a DataFrame.

row_data = [1, 1, 'male', 100, 1, 1, 100, 'S', 'First', 'man', True, 'C', 'Southampton', 'yes', True, np.nan]

# change specific row
df.iloc[0,:] = row_data
print('After changing first row')
display(df.head(5))
# Out:
# After changing first row
#    survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 0         1       1    male  100.0      1      1  100.0000        S  First
# 1         1       1  female   38.0      1      0   71.2833        C  First
# 2         1       3  female   26.0      0      0    7.9250        S  Third
# 3         1       1  female   35.0      1      0   53.1000        S  First
# 4         0       3    male   35.0      0      0    8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0    man        True    C  Southampton   yes   True          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN
# 2  woman       False  NaN  Southampton   yes   True          NaN
# 3  woman       False    C  Southampton   yes  False          NaN
# 4    man        True  NaN  Southampton    no   True          NaN

# %%
pd.concat?
# Out:
# Signature:
# pd.concat(
#     objs: 'Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame]',
#     *,
#     axis: 'Axis' = 0,
#     join: 'str' = 'outer',
#     ignore_index: 'bool' = False,
#     keys: 'Iterable[Hashable] | None' = None,
#     levels=None,
#     names: 'list[HashableT] | None' = None,
#     verify_integrity: 'bool' = False,
#     sort: 'bool' = False,
#     copy: 'bool | None' = None,
# ) -> 'DataFrame | Series'
# Docstring:
# Concatenate pandas objects along a particular axis.
#
# Allows optional set logic along the other axes.
#
# Can also add a layer of hierarchical indexing on the concatenation axis,
# which may be useful if the labels are the same (or overlapping) on
# the passed axis number.
#
# Parameters
# ----------
# objs : a sequence or mapping of Series or DataFrame objects
#     If a mapping is passed, the sorted keys will be used as the `keys`
#     argument, unless it is passed, in which case the values will be
# ...

# %%
# concatenating
full_columns_list = [i for i in df.columns]
df_row = pd.DataFrame(
    data=[row_data]
    , columns=full_columns_list
)

print('Will be adding:')
display(df_row)

df_concatenated = pd.concat(
    objs=[df_row, df]
    , ignore_index=False
)

print("Result:")
df_concatenated.head(20)
# Out:
# Will be adding:
#    survived  pclass   sex  age  sibsp  parch  fare embarked  class  who  \
# 0         1       1  male  100      1      1   100        S  First  man
#
#    adult_male deck  embark_town alive  alone  Unnamed: 15
# 0        True    C  Southampton   yes   True          NaN
# Result:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0          1       1    male  100.0      1      1  100.0000        S   First
# 0          1       1    male  100.0      1      1  100.0000        S   First
# 1          1       1  female   38.0      1      0   71.2833        C   First
# 2          1       3  female   26.0      0      0    7.9250        S   Third
# 3          1       1  female   35.0      1      0   53.1000        S   First
# 4          0       3    male   35.0      0      0    8.0500        S   Third
# 5          0       3    male    NaN      0      0    8.4583        Q   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 31:**
#
# **Create a DataFrame with random values.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 31:**
# </div>

# %%
# Exercise 31:
# Create a DataFrame with random values.

data = np.random.rand(30, 6)
df = pd.DataFrame(data, columns=['a', 'b', 'c', 'd', 'e', 'f'])
df
# Out:
#            a         b         c         d         e         f
# 0   0.703452  0.908592  0.270255  0.728114  0.079812  0.105244
# 1   0.309291  0.265185  0.037955  0.897583  0.455794  0.829272
# 2   0.161356  0.536627  0.779217  0.947935  0.067804  0.365497
# 3   0.670900  0.390366  0.376642  0.067633  0.000734  0.236353
# 4   0.027016  0.299560  0.169097  0.876125  0.037540  0.552750
# 5   0.875129  0.510466  0.118003  0.796989  0.135687  0.699179
# 6   0.166777  0.202851  0.371216  0.096899  0.367557  0.303243
# 7   0.166706  0.813640  0.582025  0.551123  0.942715  0.369390
# 8   0.447537  0.980779  0.217927  0.195406  0.702032  0.231327
# 9   0.356365  0.544389  0.982227  0.426758  0.845746  0.242105
# 10  0.045022  0.877541  0.455321  0.585961  0.729812  0.269785
# 11  0.199298  0.019202  0.107131  0.176602  0.288160  0.711286
# 12  0.454869  0.434325  0.965930  0.515913  0.297413  0.316050
# 13  0.179703  0.596091  0.524896  0.064542  0.056856  0.624070
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 32:**
#
# **Calculate the rank of values in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 32:**
# </div>

# %%
# Exercise 32:
# Calculate the rank of values in a DataFrame.

df['ageRank'] = df['age'].rank()
df.sort_values(by=['age'], ascending=True).head(30)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 827         1       2    male  1.00      0      2   37.0042        C  Second
# 381         1       3  female  1.00      0      2   15.7417        C   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 33:**
#
# **Change the data type of a column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 33:**
# </div>

# %%
# Exercise 33:
# Change the data type of a column.

df['alone'] = df['alone'].astype('int')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 34:**
#
# **Filter rows based on string matching.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 34:**
# </div>

# %%
# Exercise 34:
# Filter rows based on string matching.

df_filtered = df[df['embark_town'].str.contains('outh', na=False)]
df_filtered
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 35:**
#
# **Create a DataFrame with specified row and column labels.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 35:**
# </div>

# %%
# Exercise 35:
# Create a DataFrame with specified row and column labels.

data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
df = pd.DataFrame(
    data=data
    , index=['row1', 'row2', 'row3']
    , columns=['col1', 'col2', 'col3']
)
display(df)
# Out:
#       col1  col2  col3
# row1     1     2     3
# row2     4     5     6
# row3     7     8     9

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 36:**
#
# **Transpose a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 36:**
# </div>

# %%
# Exercise 36:
# Transpose a DataFrame.

df.T
# Out:
#                      0          1            2            3            4    \
# survived               0          1            1            1            0
# pclass                 3          1            3            1            3
# sex                 male     female       female       female         male
# age                 22.0       38.0         26.0         35.0         35.0
# sibsp                  1          1            0            1            0
# parch                  0          0            0            0            0
# fare                7.25    71.2833        7.925         53.1         8.05
# embarked               S          C            S            S            S
# class              Third      First        Third        First        Third
# who                  man      woman        woman        woman          man
# adult_male          True      False        False        False         True
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 37:**
#
# **Set a column as the index of a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 37:**
# </div>

# %%
# Exercise 37:
# Set a column as the index of a DataFrame.

# setting one column as index
# df.set_index('survived', inplace=True)

# setting 2 or more columns as index
df.set_index(['pclass', 'survived'], inplace=True)

df.head(20)
# Out:
#                     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass survived
# 3      0           male  22.0      1      0   7.2500        S   Third    man
# 1      1         female  38.0      1      0  71.2833        C   First  woman
# 3      1         female  26.0      0      0   7.9250        S   Third  woman
# 1      1         female  35.0      1      0  53.1000        S   First  woman
# 3      0           male  35.0      0      0   8.0500        S   Third    man
#        0           male   NaN      0      0   8.4583        Q   Third    man
# 1      0           male  54.0      0      0  51.8625        S   First    man
# 3      0           male   2.0      3      1  21.0750        S   Third  child
#        1         female  27.0      0      2  11.1333        S   Third  woman
# 2      1         female  14.0      1      0  30.0708        C  Second  child
# 3      1         female   4.0      1      1  16.7000        S   Third  child
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 38:**
#
# **Reset the index of a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 38:**
# </div>

# %%
# setting 2 or more columns as index
df.set_index(['pclass', 'survived'], inplace=True)

print("DataFrame with set indices:")
display(df.head(7))

df.reset_index(inplace=True)
print("DataFrame after index-reset:")
df.head(7)
# Out:
# DataFrame with set indices:
#                     sex   age  sibsp  parch     fare embarked  class    who  \
# pclass survived
# 3      0           male  22.0      1      0   7.2500        S  Third    man
# 1      1         female  38.0      1      0  71.2833        C  First  woman
# 3      1         female  26.0      0      0   7.9250        S  Third  woman
# 1      1         female  35.0      1      0  53.1000        S  First  woman
# 3      0           male  35.0      0      0   8.0500        S  Third    man
#        0           male   NaN      0      0   8.4583        Q  Third    man
# 1      0           male  54.0      0      0  51.8625        S  First    man
#
#                  adult_male deck  embark_town alive  alone  Unnamed: 15
# pclass survived
# 3      0               True  NaN  Southampton    no  False          NaN
# 1      1              False    C    Cherbourg   yes  False          NaN
# 3      1              False  NaN  Southampton   yes   True          NaN
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 39:**
#
# **Add a prefix or suffix to column names.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 39:**
# </div>

# %%
# Exercise 39:
# Add a prefix or suffix to column names.


print("Adding prefix to Series")
display(df['survived'].add_prefix("prefix_").head(5))
print("Adding prefix to 1-column DataFrame")
display(df[['survived']].add_prefix("prefix_").head(5))
print("Adding prefix to several-columns DataFrame")
display(df.iloc[:, 3:5+1].add_prefix("prefix_").head(5))
print("Adding prefix to whole DataFrame")
display(df.add_prefix("prefix_").head(5))
# Out:
# Adding prefix to Series
# prefix_0    0
# prefix_1    1
# prefix_2    1
# prefix_3    1
# prefix_4    0
# Name: survived, dtype: int64
# Adding prefix to 1-column DataFrame
#    prefix_survived
# 0                0
# 1                1
# 2                1
# 3                1
# 4                0
# Adding prefix to several-columns DataFrame
#    prefix_age  prefix_sibsp  prefix_parch
# 0        22.0             1             0
# 1        38.0             1             0
# 2        26.0             0             0
# 3        35.0             1             0
# 4        35.0             0             0
# Adding prefix to whole DataFrame
#    prefix_survived  prefix_pclass prefix_sex  prefix_age  prefix_sibsp  \
# 0                0              3       male        22.0             1
# 1                1              1     female        38.0             1
# 2                1              3     female        26.0             0
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 40:**
#
# **Filter rows based on datetime index.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
# add datetime column with different dates random
df['date'] = pd.date_range(start='2023-01-01', periods=len(df), freq='D')
print(df.shape)
df.head(20)
# Out:
# (891, 17)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 40:**
# </div>

# %%
# Exercise 40:
# Filter rows based on datetime index.

df[df['date']<'2023-01-21']
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 41:**
#
# **Create a DataFrame with duplicate rows and remove duplicates.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
# add datetime column with different dates random
df['date'] = pd.date_range(start='2023-01-01', periods=len(df), freq='D')
# add some duplicates

df = pd.concat(objs=[df.head(10),df], axis=0)
df.reset_index(inplace=True, drop=True)
print(df.shape)
df.head(20)
# Out:
# (901, 17)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         0       3    male  22.0      1      0   7.2500        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 41:**
# </div>

# %%
# Exercise 41:
# Create a DataFrame with duplicate rows and remove duplicates.

mask_dupes = df.duplicated()

print("Duplicated rows are:")
display(df[mask_dupes])

print("Dropping duplicated rows:")
df.drop_duplicates(inplace=True)

mask_dupes = df.duplicated()

print("Checking for duplicated rows are:")
display(df[mask_dupes])
# Out:
# Duplicated rows are:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 10         0       3    male  22.0      1      0   7.2500        S   Third
# 11         1       1  female  38.0      1      0  71.2833        C   First
# 12         1       3  female  26.0      0      0   7.9250        S   Third
# 13         1       1  female  35.0      1      0  53.1000        S   First
# 14         0       3    male  35.0      0      0   8.0500        S   Third
# 15         0       3    male   NaN      0      0   8.4583        Q   Third
# 16         0       1    male  54.0      0      0  51.8625        S   First
# 17         0       3    male   2.0      3      1  21.0750        S   Third
# 18         1       3  female  27.0      0      2  11.1333        S   Third
# 19         1       2  female  14.0      1      0  30.0708        C  Second
#
#       who  adult_male deck  embark_town alive  alone  Unnamed: 15       date
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 42:**
#
# **Create a DataFrame with hierarchical index.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 42:**
# </div>

# %%
# Exercise 42:
# Create a DataFrame with hierarchical index.

df.set_index(
    keys=['survived','pclass']
    , inplace=True
)
df.head(20)
# Out:
#                     sex   age  sibsp  parch     fare embarked   class    who  \
# survived pclass
# 0        3         male  22.0      1      0   7.2500        S   Third    man
# 1        1       female  38.0      1      0  71.2833        C   First  woman
#          3       female  26.0      0      0   7.9250        S   Third  woman
#          1       female  35.0      1      0  53.1000        S   First  woman
# 0        3         male  35.0      0      0   8.0500        S   Third    man
#          3         male   NaN      0      0   8.4583        Q   Third    man
#          1         male  54.0      0      0  51.8625        S   First    man
#          3         male   2.0      3      1  21.0750        S   Third  child
# 1        3       female  27.0      0      2  11.1333        S   Third  woman
#          2       female  14.0      1      0  30.0708        C  Second  child
#          3       female   4.0      1      1  16.7000        S   Third  child
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 43:**
#
# **Calculate the difference between consecutive rows in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 43:**
# </div>

# %%
# Exercise 43:
# Calculate the difference between consecutive rows in a DataFrame.
display(df.select_dtypes(include=[np.number]).diff())

# Calculate the difference between consecutive rows in a DataFrame in fare column
df['fareDiff'] = df['fare'].diff()

display(df)

# Calculate the difference between consecutive rows in a DataFrame in fare column and grouped by pclass
df['fareDiffGrouped'] = df.groupby(by=['pclass'])['fare'].diff()
display(df.sort_values(by=['pclass']))
# Out:
#      survived  pclass   age  sibsp  parch     fare  Unnamed: 15
# 0         NaN     NaN   NaN    NaN    NaN      NaN          NaN
# 1         1.0    -2.0  16.0    0.0    0.0  64.0333          NaN
# 2         0.0     2.0 -12.0   -1.0    0.0 -63.3583          NaN
# 3         0.0    -2.0   9.0    1.0    0.0  45.1750          NaN
# 4        -1.0     2.0   0.0   -1.0    0.0 -45.0500          NaN
# ..        ...     ...   ...    ...    ...      ...          ...
# 886       0.0    -1.0 -12.0    0.0   -5.0 -16.1250          NaN
# 887       1.0    -1.0  -8.0    0.0    0.0  17.0000          NaN
# 888      -1.0     2.0   NaN    1.0    2.0  -6.5500          NaN
# 889       1.0    -2.0   NaN   -1.0   -2.0   6.5500          NaN
# 890      -1.0     2.0   6.0    0.0    0.0 -22.2500          NaN
#
# [891 rows x 7 columns]
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 44:**
#
# **Create a DataFrame with hierarchical columns.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 44:**
# </div>

# %%
# Exercise 44:
# Create a DataFrame with hierarchical columns.
arrays = [
    ['fare', 'fare', 'age', 'age'],
    ['mean', 'sum', 'mean', 'sum']
]
columns = pd.MultiIndex.from_arrays(arrays, names=('first', 'second'))
data = [
    [10.5, 100.0, 25.0, 250.0],
    [20.0, 200.0, 30.0, 300.0],
    [15.0, 150.0, 22.0, 220.0]
]
df = pd.DataFrame(data, index=['class1', 'class2', 'class3'], columns=columns)
df.head(20)
# Out:
# first   fare          age
# second  mean    sum  mean    sum
# class1  10.5  100.0  25.0  250.0
# class2  20.0  200.0  30.0  300.0
# class3  15.0  150.0  22.0  220.0

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 45:**
#
# **Filter rows based on the length of strings in a column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 45:**
# </div>

# %%
# Exercise 45:
# Filter rows based on the length of strings in a column.
# will use embark_town


filt = df['embark_town'].str.len() > 10
df_filtered = df[filt]

print(df_filtered.shape)
df_filtered.head(20)
# Out:
# (644, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 46:**
#
# **Calculate the percentage change between rows in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 46:**
# </div>

# %%
# Exercise 46:
# Calculate the percentage change between rows in a DataFrame.

df['percentage_change'] = df['fare'].pct_change()
display(df.head(20))
df['percentage_change'] = df.sort_values(by=['fare'], ascending=True)['fare'].pct_change()
df.sort_values(by=['fare'], ascending=True, inplace=True)
df.head(40)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 47:**
#
# **Create a DataFrame from a dictionary of Series.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 47:**
# </div>

# %%
# Exercise 47:
# Create a DataFrame from a dictionary of Series.


data = {
    'col_1': pd.Series([1, 2, 3])
    , 'col_2': pd.Series([4, 5, 6])
    , 'col_3': pd.Series(['a', 'b', 'c'])
}
print("Data:\n", data)


df = pd.DataFrame(data)
display(df)
# Out:
# Data:
#  {'col_1': 0    1
# 1    2
# 2    3
# dtype: int64, 'col_2': 0    4
# 1    5
# 2    6
# dtype: int64, 'col_3': 0    a
# 1    b
# 2    c
# dtype: object}
#    col_1  col_2 col_3
# 0      1      4     a
# 1      2      5     b
# 2      3      6     c

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 48:**
#
# **Filter rows based on whether a column value is in a list.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 48:**
# </div>

# %%
# Exercise 48:
# Filter rows based on whether a column value is in a list.

df[df['sibsp'].isin([1])].head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# 13         0       3    male  39.0      1      5   31.2750        S   Third
# 18         0       3  female  31.0      1      0   18.0000        S   Third
# 25         1       3  female  38.0      1      5   31.3875        S   Third
# 31         1       1  female   NaN      1      0  146.5208        C   First
# 34         0       1    male  28.0      1      0   82.1708        C   First
# 35         0       1    male  42.0      1      0   52.0000        S   First
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 49:**
#
# **Calculate the z-score of values in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 49:**
# </div>

# %%
# Exercise 49:
# Calculate the z-score of values in a DataFrame.

def calculate_zscore(row, col):
    mean = df[col].mean()
    std = df[col].std()
    zscore = (row[col] - mean) / std
    return zscore

df['fare_zscore'] = df.apply(lambda row: calculate_zscore(row, 'fare'), axis=1)
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 50:**
#
# **Create a DataFrame with random integers and calculate descriptive statistics.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 50:**
# </div>

# %%
# calculate descriptive statistics.

print("Descriptive stats on titanic dataset:")
display(df.select_dtypes(include=[np.number]).describe(percentiles=np.linspace(0,1,11)))
display(df.select_dtypes(include=['O']).describe())
# Out:
# Descriptive stats on titanic dataset:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 0%       0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 10%      0.000000    1.000000   14.000000    0.000000    0.000000    7.550000
# 20%      0.000000    1.000000   19.000000    0.000000    0.000000    7.854200
# 30%      0.000000    2.000000   22.000000    0.000000    0.000000    8.050000
# 40%      0.000000    2.000000   25.000000    0.000000    0.000000   10.500000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# ...

# %%
# Exercise 50:
# Create a DataFrame with random integers and calculate descriptive statistics.

data = np.random.randint(0, 100, size=(10, 5))
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random integers:")
display(df)
print("Descriptive statistics:")
display(df.describe())
# Out:
# DataFrame with random integers:
#     A   B   C   D   E
# 0  47  48  58  71  79
# 1  79  70  55  78  53
# 2  59  31  41  51  25
# 3  72   0  27  43  62
# 4  50  56   6  78  57
# 5  37  18  85  28  89
# 6   5   3  12  35  88
# 7  32  86  74  76  18
# 8   9  85   1   1  47
# 9  89   4  54  43  63
# Descriptive statistics:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   47.900000  40.100000  41.300000  50.400000  58.100000
# std    28.069161  33.649996  28.944583  25.587323  23.988192
# min     5.000000   0.000000   1.000000   1.000000  18.000000
# 25%    33.250000   7.500000  15.750000  37.000000  48.500000
# 50%    48.500000  39.500000  47.500000  47.000000  59.500000
# 75%    68.750000  66.500000  57.250000  74.750000  75.000000
# max    89.000000  86.000000  85.000000  78.000000  89.000000

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 51:**
#
# **Calculate the rank of values in each column of a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 51:**
# </div>

# %%
# Exercise 51:
# Calculate the rank of values in each column of a DataFrame.

df['rank_fare'] = df['fare'].rank()
df['rank_age'] = df['age'].rank()

df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 52:**
#
# **Filter rows based on multiple string conditions.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 52:**
# </div>

# %%
# Exercise 52:
# Filter rows based on multiple string conditions.

filt = (df['embark_town'].str.contains('outh', na=False)) & (df['sex'] == 'female')
df_filtered = df[filt]
print(df_filtered.shape)
df_filtered.head(20)
# Out:
# (203, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 24         0       3  female   8.0      3      1  21.0750        S   Third
# 25         1       3  female  38.0      1      5  31.3875        S   Third
# 38         0       3  female  18.0      2      0  18.0000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 53:**
#
# **Create a DataFrame with random values and calculate the skewness.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 53:**
# </div>

# %%
pd.DataFrame.skew?
# Out:
# Signature:
# pd.DataFrame.skew(
#     self,
#     axis: 'Axis | None' = 0,
#     skipna: 'bool' = True,
#     numeric_only: 'bool' = False,
#     **kwargs,
# )
# Docstring:
# Return unbiased skew over requested axis.
#
# Normalized by N-1.
#
# Parameters
# ----------
# axis : {index (0), columns (1)}
#     Axis for the function to be applied on.
#     For `Series` this parameter is unused and defaults to 0.
#
#     For DataFrames, specifying ``axis=None`` will apply the aggregation
#     across both axes.
#
#     .. versionadded:: 2.0.0
#
# skipna : bool, default True
#     Exclude NA/null values when computing the result.
# numeric_only : bool, default False
#     Include only float, int, boolean columns. Not implemented for Series.
#
# **kwargs
#     Additional keyword arguments to be passed to the function.
#
# Returns
# -------
# Series or scalar
#
#             Examples
#             --------
#             >>> s = pd.Series([1, 2, 3])
#             >>> s.skew()
# ...

# %%
# Exercise 53:
# Create a DataFrame with random values and calculate the skewness.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Skewness of each column:")
display(df.skew())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.952479  0.950038  0.489310  0.245825  0.035840
# 1  0.077455  0.831373  0.788187  0.249605  0.055144
# 2  0.697763  0.661251  0.202562  0.166475  0.469499
# 3  0.657803  0.077897  0.473026  0.569075  0.372439
# 4  0.242806  0.348644  0.615152  0.865713  0.000335
# 5  0.230443  0.690848  0.647037  0.396305  0.319486
# 6  0.367230  0.543002  0.369047  0.924438  0.000596
# 7  0.282824  0.999482  0.442011  0.574074  0.443376
# 8  0.412075  0.519798  0.709678  0.995978  0.206595
# 9  0.616483  0.380066  0.596700  0.914968  0.872354
# Skewness of each column:
# A   -0.071046
# B   -0.237768
# C    0.159877
# D    0.026198
# E    0.203256
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 54:**
#
# **Create a DataFrame and calculate the kurtosis.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 54:**
# </div>

# %%
pd.DataFrame.kurtosis?
# Out:
# Signature:
# pd.DataFrame.kurtosis(
#     self,
#     axis: 'Axis | None' = 0,
#     skipna: 'bool' = True,
#     numeric_only: 'bool' = False,
#     **kwargs,
# )
# Docstring:
# Return unbiased kurtosis over requested axis.
#
# Kurtosis obtained using Fisher's definition of
# kurtosis (kurtosis of normal == 0.0). Normalized by N-1.
#
# Parameters
# ----------
# axis : {index (0), columns (1)}
#     Axis for the function to be applied on.
#     For `Series` this parameter is unused and defaults to 0.
#
#     For DataFrames, specifying ``axis=None`` will apply the aggregation
#     across both axes.
#
#     .. versionadded:: 2.0.0
#
# skipna : bool, default True
#     Exclude NA/null values when computing the result.
# numeric_only : bool, default False
#     Include only float, int, boolean columns. Not implemented for Series.
#
# **kwargs
#     Additional keyword arguments to be passed to the function.
#
# Returns
# -------
# Series or scalar
#
#             Examples
# ...

# %%
pd.DataFrame.kurt?
# Out:
# Signature:
# pd.DataFrame.kurt(
#     self,
#     axis: 'Axis | None' = 0,
#     skipna: 'bool' = True,
#     numeric_only: 'bool' = False,
#     **kwargs,
# )
# Docstring:
# Return unbiased kurtosis over requested axis.
#
# Kurtosis obtained using Fisher's definition of
# kurtosis (kurtosis of normal == 0.0). Normalized by N-1.
#
# Parameters
# ----------
# axis : {index (0), columns (1)}
#     Axis for the function to be applied on.
#     For `Series` this parameter is unused and defaults to 0.
#
#     For DataFrames, specifying ``axis=None`` will apply the aggregation
#     across both axes.
#
#     .. versionadded:: 2.0.0
#
# skipna : bool, default True
#     Exclude NA/null values when computing the result.
# numeric_only : bool, default False
#     Include only float, int, boolean columns. Not implemented for Series.
#
# **kwargs
#     Additional keyword arguments to be passed to the function.
#
# Returns
# -------
# Series or scalar
#
#             Examples
# ...

# %%
# Exercise 54:
# Create a DataFrame and calculate the kurtosis.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Kurtosis of each column:")
display(df.kurt())
display(df.kurtosis())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.987159  0.502657  0.700584  0.831367  0.198517
# 1  0.450972  0.178723  0.135676  0.612348  0.568564
# 2  0.917179  0.717343  0.690530  0.233884  0.873044
# 3  0.756013  0.271468  0.892017  0.610478  0.836015
# 4  0.573115  0.549997  0.677905  0.547589  0.913462
# 5  0.199415  0.273431  0.659477  0.084847  0.129453
# 6  0.625232  0.824915  0.765154  0.307510  0.034575
# 7  0.763331  0.599244  0.612568  0.646383  0.909313
# 8  0.756503  0.728595  0.710377  0.737943  0.481226
# 9  0.941411  0.878841  0.737744  0.666787  0.797182
# Kurtosis of each column:
# A   -1.201551
# B   -1.224345
# C   -1.207865
# D   -1.110488
# E   -1.096195
# dtype: float64
# A   -1.201551
# B   -1.224345
# C   -1.207865
# D   -1.110488
# E   -1.096195
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 55:**
#
# **Calculate the cumulative product of a column in a DataFrame.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 55:**
# </div>

# %%
# Exercise 55:
# Calculate the cumulative product of a column in a DataFrame.

df['cumulative_product_fare'] = df['fare'].cumprod()
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 56:**
#
# **Create a DataFrame and calculate the rolling standard deviation.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 56:**
# </div>

# %%
# Exercise 56:
# Create a DataFrame and calculate the rolling standard deviation.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Rolling standard deviation with window size 5:")
display(df.rolling(window=5).std())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.516455  0.261059  0.354466  0.190181  0.771160
# 1  0.795498  0.349788  0.145411  0.671366  0.904020
# 2  0.155675  0.995770  0.776246  0.694080  0.904222
# 3  0.105443  0.123210  0.189724  0.318030  0.900468
# 4  0.143464  0.419765  0.081528  0.054631  0.735342
# 5  0.310312  0.877063  0.236129  0.215971  0.903744
# 6  0.961831  0.709874  0.719796  0.198734  0.217465
# 7  0.429162  0.456093  0.504836  0.086727  0.088641
# 8  0.112298  0.975246  0.781765  0.607001  0.769825
# 9  0.668091  0.514961  0.007260  0.579740  0.092188
# Rolling standard deviation with window size 5:
#            A         B         C         D         E
# 0        NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN       NaN
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 57:**
#
# **Create a DataFrame and calculate the expanding mean.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 57:**
# </div>

# %%
# Exercise 57:
# Create a DataFrame and calculate the expanding mean.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Expanding mean:")
display(df.expanding().mean())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.033421  0.684499  0.110742  0.564731  0.619240
# 1  0.841096  0.124546  0.645118  0.782663  0.092737
# 2  0.141865  0.724811  0.744446  0.205672  0.847658
# 3  0.743106  0.238685  0.366440  0.093168  0.612712
# 4  0.558527  0.505652  0.352971  0.065979  0.570451
# 5  0.978781  0.810594  0.350946  0.173852  0.213592
# 6  0.859283  0.658923  0.799292  0.005409  0.491576
# 7  0.771004  0.149457  0.961103  0.122513  0.953047
# 8  0.412136  0.471570  0.508495  0.605719  0.544823
# 9  0.126606  0.790451  0.004843  0.119810  0.370688
# Expanding mean:
#            A         B         C         D         E
# 0   0.033421  0.684499  0.110742  0.564731  0.619240
# 1   0.437258  0.404522  0.377930  0.673697  0.355989
# 2   0.338794  0.511285  0.500102  0.517689  0.519879
# 3   0.439872  0.443135  0.466686  0.411559  0.543087
# 4   0.463603  0.455638  0.443943  0.342443  0.548560
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 58:**
#
# **Create a DataFrame with random values and calculate the covariance matrix.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 58:**
# </div>

# %%
# Exercise 58:
# Create a DataFrame with random values and calculate the covariance matrix.
fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Covariance matrix:")
display(df.cov())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.217830  0.802879  0.845457  0.541465  0.867846
# 1  0.322647  0.177342  0.552191  0.422898  0.805245
# 2  0.542285  0.438495  0.067168  0.526958  0.912754
# 3  0.559439  0.370498  0.755458  0.854159  0.350280
# 4  0.316137  0.859276  0.784815  0.570911  0.317419
# 5  0.113731  0.301852  0.399169  0.846466  0.317513
# 6  0.735479  0.643211  0.440594  0.174784  0.905282
# 7  0.075721  0.399019  0.747301  0.274373  0.896022
# 8  0.871254  0.186092  0.719685  0.931332  0.384129
# 9  0.680415  0.588946  0.144274  0.554161  0.995017
# Covariance matrix:
#           A         B         C         D         E
# A  0.092796  0.005195  0.003450  0.002120 -0.006047
# B  0.005195  0.089501  0.025875 -0.011011  0.007837
# C  0.003450  0.025875  0.083105  0.001018 -0.000846
# D  0.002120 -0.011011  0.001018  0.076244  0.000232
# E -0.006047  0.007837 -0.000846  0.000232  0.077674

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 59:**
#
# **Create a DataFrame with random values and calculate the correlation matrix.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 59:**
# </div>

# %%
# Exercise 59:
# Create a DataFrame with random values and calculate the correlation matrix.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Correlation matrix:")
display(df.corr())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.972491  0.618928  0.262063  0.066394  0.893802
# 1  0.415754  0.829490  0.886327  0.026206  0.626124
# 2  0.436252  0.952328  0.196910  0.008230  0.655088
# 3  0.880171  0.946798  0.763805  0.366128  0.871724
# 4  0.706231  0.598546  0.924792  0.563525  0.460175
# 5  0.176176  0.304924  0.045286  0.571386  0.623382
# 6  0.922394  0.095353  0.295011  0.070689  0.272237
# 7  0.428838  0.777695  0.516124  0.137354  0.216523
# 8  0.122572  0.780621  0.420547  0.269182  0.544283
# 9  0.470854  0.223755  0.685879  0.597075  0.008696
# Correlation matrix:
#           A         B         C         D         E
# A  1.000000 -0.105867  0.147542 -0.132453  0.116572
# B -0.105867  1.000000  0.072639 -0.031980 -0.042412
# C  0.147542  0.072639  1.000000  0.074772  0.202099
# D -0.132453 -0.031980  0.074772  1.000000  0.171685
# E  0.116572 -0.042412  0.202099  0.171685  1.000000

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 60:**
#
# **Create a DataFrame and calculate the rolling correlation between two columns.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 60:**
# </div>

# %%
# Exercise 60:
# Create a DataFrame and calculate the rolling correlation between two columns.

fdata = np.random.rand(100, 2)
df = pd.DataFrame(fdata, columns=['A', 'B'])
print("DataFrame with random values:")
display(df.head(10))
print("Rolling correlation with window size 5:")
display(df['A'].rolling(window=5).corr(df['B']))
# Out:
# DataFrame with random values:
#           A         B
# 0  0.698621  0.118018
# 1  0.596311  0.151048
# 2  0.341199  0.664659
# 3  0.110835  0.518670
# 4  0.568975  0.026238
# 5  0.675622  0.971797
# 6  0.672326  0.004962
# 7  0.032413  0.977073
# 8  0.876138  0.070433
# 9  0.849967  0.862477
# Rolling correlation with window size 5:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4    -0.808831
#         ...
# 95   -0.677057
# 96   -0.963858
# 97   -0.839543
# 98   -0.749364
# 99   -0.224484
# Length: 100, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 61:**
#
# **Create a DataFrame and calculate the expanding variance.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 61:**
# </div>

# %%
# Exercise 61:
# Create a DataFrame and calculate the expanding variance.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Expanding variance:")
display(df.expanding().var())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.552023  0.835285  0.064632  0.674568  0.761987
# 1  0.877285  0.276823  0.740345  0.430329  0.577372
# 2  0.944440  0.966922  0.051489  0.894479  0.479453
# 3  0.235897  0.711780  0.454660  0.781314  0.646203
# 4  0.578795  0.755460  0.981658  0.297082  0.269171
# 5  0.450026  0.337330  0.257193  0.383360  0.870029
# 6  0.055902  0.534306  0.300458  0.478507  0.877148
# 7  0.331465  0.658880  0.690095  0.510861  0.221589
# 8  0.154737  0.311677  0.988818  0.483741  0.030565
# 9  0.701257  0.149174  0.240348  0.708147  0.856752
# Expanding variance:
#            A         B         C         D         E
# 0        NaN       NaN       NaN       NaN       NaN
# 1   0.052898  0.155940  0.228294  0.029826  0.017041
# 2   0.044049  0.134241  0.155214  0.053908  0.020583
# 3   0.106470  0.089582  0.110631  0.039237  0.014120
# 4   0.080937  0.067854  0.168484  0.061123  0.034684
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 62:**
#
# **Create a DataFrame with datetime index and resample by month.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 62:**
# </div>

# %%
# Exercise 62:
# Create a DataFrame with datetime index and resample by month.

date_rng = pd.date_range(start='2023-01-01', end='2023-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.rand(len(date_rng))
df.set_index('date', inplace=True)
print("DataFrame with datetime index:")
display(df.head(10))
print("Resampled by month:")
display(df.resample('ME').mean())
# Out:
# DataFrame with datetime index:
#                 data
# date
# 2023-01-01  0.880807
# 2023-01-02  0.494530
# 2023-01-03  0.667953
# 2023-01-04  0.945935
# 2023-01-05  0.119617
# 2023-01-06  0.282640
# 2023-01-07  0.737045
# 2023-01-08  0.930304
# 2023-01-09  0.477237
# 2023-01-10  0.755115
# Resampled by month:
#                 data
# date
# 2023-01-31  0.489644
# 2023-02-28  0.491056
# 2023-03-31  0.504538
# 2023-04-30  0.524805
# 2023-05-31  0.476263
# 2023-06-30  0.597951
# 2023-07-31  0.520256
# 2023-08-31  0.518550
# 2023-09-30  0.411316
# 2023-10-31  0.518840
# 2023-11-30  0.529659
# 2023-12-31  0.460370

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 63:**
#
# **Create a DataFrame and calculate the exponential moving average.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 63:**
# </div>

# %%
# Exercise 63:
# Create a DataFrame and calculate the exponential moving average.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Exponential moving average with span 10:")
display(df.ewm(span=10, adjust=False).mean())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.001267  0.810226  0.612099  0.184717  0.778047
# 1  0.687924  0.578870  0.589464  0.847583  0.077642
# 2  0.958755  0.939618  0.297872  0.091179  0.941152
# 3  0.748147  0.988800  0.698537  0.595694  0.102042
# 4  0.889250  0.740827  0.511536  0.945384  0.090836
# 5  0.158915  0.746936  0.693467  0.526191  0.935602
# 6  0.020506  0.735985  0.481491  0.625877  0.929923
# 7  0.516506  0.332902  0.692480  0.352142  0.746855
# 8  0.880423  0.271347  0.708383  0.288355  0.499012
# 9  0.108656  0.557750  0.524822  0.107477  0.358483
# Exponential moving average with span 10:
#            A         B         C         D         E
# 0   0.001267  0.810226  0.612099  0.184717  0.778047
# 1   0.126114  0.768161  0.607983  0.305238  0.650700
# 2   0.277503  0.799335  0.551599  0.266318  0.703510
# 3   0.363075  0.833783  0.578315  0.326205  0.594152
# 4   0.458743  0.816882  0.566174  0.438783  0.502640
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 64:**
#
# **Create a DataFrame with random integers and calculate the mode.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 64:**
# </div>

# %%
# Exercise 64:
# Create a DataFrame with random integers and calculate the mode.

fdata = np.random.randint(0, 10, size=(100, 5))
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random integers:")
display(df.head(10))
print("Mode of each column:")
display(df.mode())
# Out:
# DataFrame with random integers:
#    A  B  C  D  E
# 0  6  1  0  7  3
# 1  6  3  5  9  8
# 2  4  1  2  3  5
# 3  1  5  8  1  9
# 4  9  3  3  9  7
# 5  1  3  5  6  7
# 6  5  7  8  1  8
# 7  2  8  3  1  1
# 8  6  8  1  3  7
# 9  3  0  8  2  4
# Mode of each column:
#      A  B    C    D    E
# 0  8.0  6  4.0  0.0  8.0
# 1  NaN  7  NaN  NaN  NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 65:**
#
# **Create a DataFrame and calculate the z-score of each column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 65:**
# </div>

# %%
# Exercise 65:
# Create a DataFrame and calculate the z-score of each column.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Z-score of each column:")
zscore_df = (df - df.mean()) / df.std()
display(zscore_df.head(10))
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.447654  0.752007  0.418171  0.547557  0.948810
# 1  0.221804  0.925469  0.656836  0.452766  0.343402
# 2  0.104391  0.308814  0.511730  0.245382  0.037619
# 3  0.851449  0.630916  0.229430  0.830664  0.010194
# 4  0.099794  0.734108  0.834877  0.411196  0.644694
# 5  0.400159  0.024812  0.004159  0.052904  0.517259
# 6  0.293016  0.048479  0.894102  0.225290  0.042111
# 7  0.476229  0.727874  0.428439  0.566119  0.681115
# 8  0.760553  0.567245  0.088746  0.558894  0.588608
# 9  0.275593  0.344391  0.405058  0.089386  0.128778
# Z-score of each column:
#           A         B         C         D         E
# 0 -0.212700  0.987612 -0.144824  0.308128  1.369697
# 1 -1.026725  1.573333  0.674768 -0.029038 -0.544680
# 2 -1.449911 -0.508900  0.176463 -0.766686 -1.511603
# 3  1.242684  0.578731 -0.792974  1.315118 -1.598323
# 4 -1.466483  0.927173  1.286175 -0.176897  0.408045
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 66:**
#
# **Create a DataFrame with random values and calculate the median.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 66:**
# </div>

# %%
# Exercise 66:
# Create a DataFrame with random values and calculate the median.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Median of each column:")
display(df.median())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.304498  0.686994  0.822698  0.688480  0.418837
# 1  0.962874  0.148778  0.577131  0.675580  0.752985
# 2  0.586503  0.093190  0.710769  0.781894  0.981406
# 3  0.483388  0.799173  0.172574  0.770441  0.417619
# 4  0.233953  0.243405  0.682288  0.674308  0.788990
# 5  0.461229  0.436266  0.777933  0.893347  0.330479
# 6  0.239307  0.166976  0.422576  0.515371  0.424301
# 7  0.842175  0.956905  0.574148  0.973558  0.639958
# 8  0.181869  0.400731  0.593572  0.154927  0.219609
# 9  0.130772  0.323107  0.516552  0.495885  0.193555
# Median of each column:
# A    0.481756
# B    0.501420
# C    0.546436
# D    0.598805
# E    0.499487
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 67:**
#
# **Create a DataFrame and apply a custom function to each column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 67:**
# </div>

# %%
# Exercise 67:
# Create a DataFrame and apply a custom function to each column.

# will use titanic dataset and create a custom function to calculate range (max-min)
def calculate_range(col):
    return col.max() - col.min()
range_df = df.select_dtypes(include=[np.number]).apply(calculate_range)
print("Range of each numeric column:")
display(range_df)
# Out:
# Range of each numeric column:
# survived         1.0000
# pclass           2.0000
# age             79.5800
# sibsp            8.0000
# parch            6.0000
# fare           512.3292
# Unnamed: 15         NaN
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 68:**
#
# **Create a DataFrame with hierarchical index and calculate the mean for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 68:**
# </div>

# %%
# Exercise 68:
# Create a DataFrame with hierarchical index and calculate the mean for each group.

df.set_index(
    keys=['pclass','survived']
    , inplace=True
)
mean_df = df.select_dtypes(include=[np.number]).groupby(level=['pclass','survived']).mean()
print("Mean for each group in hierarchical index:")
display(mean_df)
# Out:
# Mean for each group in hierarchical index:
#                        age     sibsp     parch       fare  Unnamed: 15
# pclass survived
# 1      0         43.695312  0.287500  0.300000  64.684007          NaN
#        1         35.368197  0.492647  0.389706  95.608029          NaN
# 2      0         33.544444  0.319588  0.144330  19.412328          NaN
#        1         25.901566  0.494253  0.643678  22.055700          NaN
# 3      0         26.555556  0.672043  0.384409  13.669364          NaN
#        1         20.646118  0.436975  0.420168  13.694887          NaN

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 69:**
#
# **Create a DataFrame and calculate the percentage of missing values in each column.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 69:**
# </div>

# %%
# Exercise 69:
# Create a DataFrame and calculate the percentage of missing values in each column.

missing_percentage = df.isnull().mean() * 100
print("Percentage of missing values in each column:")
display(missing_percentage)
# Out:
# Percentage of missing values in each column:
# survived         0.000000
# pclass           0.000000
# sex              0.000000
# age             19.865320
# sibsp            0.000000
# parch            0.000000
# fare             0.000000
# embarked         0.224467
# class            0.000000
# who              0.000000
# adult_male       0.000000
# deck            77.216611
# embark_town      0.224467
# alive            0.000000
# alone            0.000000
# Unnamed: 15    100.000000
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 70:**
#
# **Create a DataFrame and apply a custom function to each row.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 70:**
# </div>

# %%
# Exercise 70:
# Create a DataFrame and apply a custom function to each row.

df['age_plus_fare'] = df.apply(lambda row: row['age'] + row['fare'], axis=1)
print("DataFrame with age plus fare column:")
display(df.head(20))
# Out:
# DataFrame with age plus fare column:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 71:**
#
# **Create a DataFrame with random values and calculate the quantiles.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 71:**
# </div>

# %%
# Exercise 71:
# Create a DataFrame with random values and calculate the quantiles.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Quantiles of each column:")
display(df.quantile([0.25, 0.5, 0.75]))
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.852094  0.055364  0.878974  0.216035  0.569812
# 1  0.122862  0.723927  0.132922  0.299859  0.101650
# 2  0.822574  0.912135  0.968771  0.224261  0.508737
# 3  0.462248  0.604241  0.805844  0.301603  0.641361
# 4  0.695974  0.732245  0.787562  0.868093  0.611277
# 5  0.702678  0.693583  0.939965  0.921725  0.821730
# 6  0.958678  0.383882  0.982124  0.120600  0.799028
# 7  0.773992  0.857614  0.442536  0.481453  0.188367
# 8  0.196850  0.156702  0.784339  0.162155  0.672301
# 9  0.109579  0.257307  0.197191  0.570330  0.418126
# Quantiles of each column:
#              A         B         C         D         E
# 0.25  0.261572  0.271488  0.262157  0.235889  0.424925
# 0.50  0.491104  0.570306  0.465465  0.520057  0.588765
# 0.75  0.772552  0.748239  0.811002  0.729083  0.774119

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 72:**
#
# **Create a DataFrame and calculate the interquartile range (IQR).**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 72:**
# </div>

# %%
# Exercise 72:
# Create a DataFrame and calculate the interquartile range (IQR).

def calculate_iqr(col):
    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1
    return IQR

iqr_df = df.select_dtypes(include=[np.number]).apply(calculate_iqr)
print("Interquartile range (IQR) of each numeric column:")
display(iqr_df)
# Out:
# Interquartile range (IQR) of each numeric column:
# survived        1.0000
# pclass          1.0000
# age            17.8750
# sibsp           1.0000
# parch           0.0000
# fare           23.0896
# Unnamed: 15        NaN
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 73:**
#
# **Create a DataFrame with datetime index and calculate the rolling mean.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 73:**
# </div>

# %%
# Exercise 73:
# Create a DataFrame with datetime index and calculate the rolling mean.

date_rng = pd.date_range(start='2023-01-01', end='2023-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.rand(len(date_rng))
df.set_index('date', inplace=True)
print("DataFrame with datetime index:")
display(df.head(10))
print("Rolling mean with window size 7:")
display(df.rolling(window=7).mean())
# Out:
# DataFrame with datetime index:
#                 data
# date
# 2023-01-01  0.527572
# 2023-01-02  0.297069
# 2023-01-03  0.057511
# 2023-01-04  0.789729
# 2023-01-05  0.061645
# 2023-01-06  0.998117
# 2023-01-07  0.047692
# 2023-01-08  0.570955
# 2023-01-09  0.894619
# 2023-01-10  0.570334
# Rolling mean with window size 7:
#                 data
# date
# 2023-01-01       NaN
# 2023-01-02       NaN
# 2023-01-03       NaN
# 2023-01-04       NaN
# 2023-01-05       NaN
# ...              ...
# 2023-12-27  0.669365
# 2023-12-28  0.720436
# 2023-12-29  0.782066
# 2023-12-30  0.652954
# 2023-12-31  0.655601
#
# [365 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 74:**
#
# **Create a DataFrame and calculate the cumulative maximum.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 74:**
# </div>

# %%
# Exercise 74:
# Create a DataFrame and calculate the cumulative maximum.

df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1]
})
print("DataFrame:")
display(df)
print("Cumulative maximum of each column:")
display(df.cummax())
# Out:
# DataFrame:
#    A  B
# 0  1  5
# 1  2  4
# 2  3  3
# 3  4  2
# 4  5  1
# Cumulative maximum of each column:
#    A  B
# 0  1  5
# 1  2  5
# 2  3  5
# 3  4  5
# 4  5  5

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 75:**
#
# **Create a DataFrame and calculate the cumulative minimum.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 75:**
# </div>

# %%
# Exercise 75:
# Create a DataFrame and calculate the cumulative minimum.

df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1]
})
print("DataFrame:")
display(df)
print("Cumulative minimum of each column:")
display(df.cummin())
# Out:
# DataFrame:
#    A  B
# 0  1  5
# 1  2  4
# 2  3  3
# 3  4  2
# 4  5  1
# Cumulative minimum of each column:
#    A  B
# 0  1  5
# 1  1  4
# 2  1  3
# 3  1  2
# 4  1  1

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 76:**
#
# **Create a DataFrame with random values and calculate the cumulative variance.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 76:**
# </div>

# %%
# Exercise 76:
# Create a DataFrame with random values and calculate the cumulative variance.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Cumulative variance of each column:")

display(df.expanding().var())
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.976226  0.716880  0.211989  0.282810  0.780497
# 1  0.120331  0.240468  0.856332  0.907027  0.556360
# 2  0.742386  0.918358  0.863251  0.027593  0.192637
# 3  0.857466  0.030114  0.700840  0.113813  0.374751
# 4  0.722218  0.769335  0.702817  0.858244  0.361137
# 5  0.841170  0.026850  0.280994  0.973400  0.070628
# 6  0.675445  0.217110  0.208346  0.862709  0.333433
# 7  0.538434  0.115270  0.891759  0.515804  0.308570
# 8  0.811072  0.779886  0.716075  0.306485  0.903929
# 9  0.406664  0.355256  0.029091  0.243074  0.423005
# Cumulative variance of each column:
#            A         B         C         D         E
# 0        NaN       NaN       NaN       NaN       NaN
# 1   0.366278  0.113484  0.207589  0.194824  0.025119
# 2   0.195698  0.121183  0.139895  0.204698  0.088019
# 3   0.145409  0.169331  0.094075  0.157781  0.063241
# 4   0.109520  0.144154  0.070956  0.173552  0.050072
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 77:**
#
# **Create a DataFrame and apply a custom function to each element.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 77:**
# </div>

# %%
# Exercise 77:
# Create a DataFrame and apply a custom function to each element.

def custom_function(x):
    return x * 2 if isinstance(x, (int, float)) else x

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

print("Original DataFrame:")
display(df)

print("DataFrame after applying custom function:")
display(df.applymap(custom_function))
# Out:
# Original DataFrame:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# DataFrame after applying custom function:
# /var/folders/fb/453r9d2j24g8x8tc93n2k6600000gn/T/ipykernel_34775/4104873565.py:16: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   display(df.applymap(custom_function))
#    A   B
# 0  2   8
# 1  4  10
# 2  6  12

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 78:**
#
# **Create a DataFrame with random values and calculate the z-score for each element.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 78:**
# </div>

# %%
# Exercise 78:
# Create a DataFrame with random values and calculate the z-score for each element.

fdata = np.random.rand(100, 5)
df = pd.DataFrame(fdata, columns=['A', 'B', 'C', 'D', 'E'])
print("DataFrame with random values:")
display(df.head(10))
print("Z-score for each element:")
zscore_df = df.applymap(lambda x: (x - df.values.mean()) / df.values.std())
display(zscore_df.head(10))
# Out:
# DataFrame with random values:
#           A         B         C         D         E
# 0  0.196124  0.436890  0.098408  0.317052  0.025031
# 1  0.854536  0.215991  0.561643  0.643933  0.627390
# 2  0.766014  0.772830  0.621708  0.910046  0.614573
# 3  0.930554  0.388176  0.695667  0.583154  0.818142
# 4  0.242369  0.425750  0.702474  0.283180  0.337952
# 5  0.542219  0.104087  0.788508  0.620697  0.612799
# 6  0.349921  0.168854  0.519623  0.031591  0.675551
# 7  0.243754  0.850833  0.605711  0.479207  0.421954
# 8  0.779053  0.712564  0.867084  0.280064  0.858456
# 9  0.427602  0.048357  0.546371  0.023903  0.583912
# Z-score for each element:
# /var/folders/fb/453r9d2j24g8x8tc93n2k6600000gn/T/ipykernel_34775/3270515785.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   zscore_df = df.applymap(lambda x: (x - df.values.mean()) / df.values.std())
#           A         B         C         D         E
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 79:**
#
# **Create a DataFrame and calculate the cumulative sum for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 79:**
# </div>

# %%
# Exercise 79:
# Create a DataFrame and calculate the cumulative sum for each group.

df['cumulative_sum_grouped'] = df.groupby(by=['pclass'])['fare'].cumsum()
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 80:**
#
# **Create a DataFrame with random values and calculate the rank for each element.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 80:**
# </div>

# %%
# Exercise 80:
# Create a DataFrame with random values and calculate the rank for each element.

# will calculate rank for each element in the existing DataFrame
rank_df = df.rank()
display(rank_df.head(10))
# Out:
#    survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0     275.0   646.0  603.0  218.0  713.0  339.5   77.0     567.5  646.0
# 1     720.5   108.5  157.5  532.0  713.0  339.5  789.0      84.5  108.5
# 2     720.5   646.0  157.5  310.5  304.5  339.5  232.5     567.5  646.0
# 3     720.5   108.5  157.5  488.5  713.0  339.5  748.0     567.5  108.5
# 4     275.0   646.0  603.0  488.5  304.5  339.5  264.0     567.5  646.0
# 5     275.0   646.0  603.0    NaN  304.5  339.5  293.0     207.0  646.0
# 6     275.0   108.5  603.0  668.5  304.5  339.5  734.5     567.5  108.5
# 7     275.0   646.0  603.0   19.5  853.5  737.5  532.5     567.5  646.0
# 8     720.5   646.0  157.5  328.5  304.5  836.5  366.0     567.5  646.0
# 9     720.5   308.5  157.5   74.5  713.0  339.5  658.5      84.5  308.5
#
#      who  adult_male   deck  embark_town  alive  alone  Unnamed: 15
# 0  352.0       623.0    NaN        567.5  275.0  177.5          NaN
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 81:**
#
# **Create a DataFrame and calculate the cumulative product for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 81:**
# </div>

# %%
# Exercise 81:
# Create a DataFrame and calculate the cumulative product for each group.

df['cumulative_product_grouped'] = df.groupby(by=['survived'])['pclass'].cumprod()
df.reset_index(drop=False).head(20).sort_values(by=['survived', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 7       7         0       3    male   2.0      3      1  21.0750        S
# 12     12         0       3    male  20.0      0      0   8.0500        S
# 13     13         0       3    male  39.0      1      5  31.2750        S
# 14     14         0       3  female  14.0      0      0   7.8542        S
# 16     16         0       3    male   2.0      4      1  29.1250        Q
# 18     18         0       3  female  31.0      1      0  18.0000        S
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 2       2         1       3  female  26.0      0      0   7.9250        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 82:**
#
# **Create a DataFrame with random values and calculate the expanding sum.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 82:**
# </div>

# %%
# Exercise 82:
# Create a DataFrame with random values and calculate the expanding sum.
# will use existing titanic dataset numeric columns

expanding_sum_df = df.select_dtypes(include=[np.number]).expanding().sum()
print("Expanding sum of each numeric column:")
display(expanding_sum_df.head(20))
# Out:
# Expanding sum of each numeric column:
#     survived  pclass    age  sibsp  parch      fare  Unnamed: 15
# 0        0.0     3.0   22.0    1.0    0.0    7.2500          NaN
# 1        1.0     4.0   60.0    2.0    0.0   78.5333          NaN
# 2        2.0     7.0   86.0    2.0    0.0   86.4583          NaN
# 3        3.0     8.0  121.0    3.0    0.0  139.5583          NaN
# 4        3.0    11.0  156.0    3.0    0.0  147.6083          NaN
# 5        3.0    14.0  156.0    3.0    0.0  156.0666          NaN
# 6        3.0    15.0  210.0    3.0    0.0  207.9291          NaN
# 7        3.0    18.0  212.0    6.0    1.0  229.0041          NaN
# 8        4.0    21.0  239.0    6.0    3.0  240.1374          NaN
# 9        5.0    23.0  253.0    7.0    3.0  270.2082          NaN
# 10       6.0    26.0  257.0    8.0    4.0  286.9082          NaN
# 11       7.0    27.0  315.0    8.0    4.0  313.4582          NaN
# 12       7.0    30.0  335.0    8.0    4.0  321.5082          NaN
# ...

# %%
df.expanding?
# Out:
# Signature:
# df.expanding(
#     min_periods: 'int' = 1,
#     axis: 'Axis | lib.NoDefault' = <no_default>,
#     method: "Literal['single', 'table']" = 'single',
# ) -> 'Expanding'
# Docstring:
# Provide expanding window calculations.
#
# Parameters
# ----------
# min_periods : int, default 1
#     Minimum number of observations in window required to have a value;
#     otherwise, result is ``np.nan``.
#
# axis : int or str, default 0
#     If ``0`` or ``'index'``, roll across the rows.
#
#     If ``1`` or ``'columns'``, roll across the columns.
#
#     For `Series` this parameter is unused and defaults to 0.
#
# method : str {'single', 'table'}, default 'single'
#     Execute the rolling operation per single column or row (``'single'``)
#     or over the entire object (``'table'``).
#
#     This argument is only implemented when specifying ``engine='numba'``
#     in the method call.
#
#     .. versionadded:: 1.3.0
#
# Returns
# -------
# pandas.api.typing.Expanding
#
# See Also
# ...

# %%
df.groupby(by=['pclass'])[['fare']].expanding().sum()
# Out:
#                  fare
# pclass
# 1      1      71.2833
#        3     124.3833
#        6     176.2458
#        11    202.7958
#        23    238.2958
# ...               ...
# 3      882  6647.3201
#        884  6654.3701
#        885  6683.4951
#        888  6706.9451
#        890  6714.6951
#
# [891 rows x 1 columns]

# %%
df[df['pclass']==3].groupby(by=['pclass'])[['fare']].expanding().sum().reset_index(drop=False).head(20).sort_values(by=['pclass', 'level_1'])
# Out:
#     pclass  level_1      fare
# 0        3        0    7.2500
# 1        3        2   15.1750
# 2        3        4   23.2250
# 3        3        5   31.6833
# 4        3        7   52.7583
# 5        3        8   63.8916
# 6        3       10   80.5916
# 7        3       12   88.6416
# 8        3       13  119.9166
# 9        3       14  127.7708
# 10       3       16  156.8958
# 11       3       18  174.8958
# 12       3       19  182.1208
# 13       3       22  190.1500
# 14       3       24  211.2250
# 15       3       25  242.6125
# 16       3       26  249.8375
# 17       3       28  257.7167
# 18       3       29  265.6125
# 19       3       32  273.3625

# %%
df.groupby(by=['pclass'])[['fare']].expanding().sum().reset_index(drop=False).head(20).sort_values(by=['pclass', 'level_1'])
# Out:
#     pclass  level_1       fare
# 0        1        1    71.2833
# 1        1        3   124.3833
# 2        1        6   176.2458
# 3        1       11   202.7958
# 4        1       23   238.2958
# 5        1       27   501.2958
# 6        1       30   529.0166
# 7        1       31   675.5374
# 8        1       34   757.7082
# 9        1       35   809.7082
# 10       1       52   886.4374
# 11       1       54   948.4166
# 12       1       55   983.9166
# 13       1       61  1063.9166
# 14       1       62  1147.3916
# 15       1       64  1175.1124
# 16       1       83  1222.2124
# 17       1       88  1485.2124
# 18       1       92  1546.3874
# 19       1       96  1581.0416

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 83:**
#
# **Create a DataFrame and calculate the expanding minimum for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 83:**
# </div>

# %%
# Exercise 83:
# Create a DataFrame and calculate the expanding minimum for each group.

df['expanding_min_grouped'] = df.groupby(by=['embark_town'])['age'].expanding().min().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['embark_town', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 19     19         1       3  female   NaN      0      0   7.2250        C
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 16     16         0       3    male   2.0      4      1  29.1250        Q
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 7       7         0       3    male   2.0      3      1  21.0750        S
# 8       8         1       3  female  27.0      0      2  11.1333        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 84:**
#
# **Create a DataFrame with random values and calculate the expanding maximum for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 84:**
# </div>

# %%
# Exercise 84:
# Create a DataFrame with random values and calculate the expanding maximum for each group.

df['expanding_max_grouped'] = df.groupby(by=['embark_town'])['fare'].expanding().max().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['embark_town', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 19     19         1       3  female   NaN      0      0   7.2250        C
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 16     16         0       3    male   2.0      4      1  29.1250        Q
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 7       7         0       3    male   2.0      3      1  21.0750        S
# 8       8         1       3  female  27.0      0      2  11.1333        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 85:**
#
# **Create a DataFrame and calculate the expanding variance for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 85:**
# </div>

# %%
# Exercise 85:
# Create a DataFrame and calculate the expanding variance for each group.

df['expanding_var_grouped'] = df.groupby(by=['embark_town'])['age'].expanding().var().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['embark_town', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 19     19         1       3  female   NaN      0      0   7.2250        C
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 16     16         0       3    male   2.0      4      1  29.1250        Q
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 7       7         0       3    male   2.0      3      1  21.0750        S
# 8       8         1       3  female  27.0      0      2  11.1333        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 86:**
#
# **Create a DataFrame with random values and calculate the expanding standard deviation.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 86:**
# </div>

# %%
# Exercise 86:
# Create a DataFrame with random values and calculate the expanding standard deviation.

df['expanding_std_grouped'] = df.groupby(by=['embark_town'])['age'].expanding().std().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['embark_town', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 19     19         1       3  female   NaN      0      0   7.2250        C
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 16     16         0       3    male   2.0      4      1  29.1250        Q
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 7       7         0       3    male   2.0      3      1  21.0750        S
# 8       8         1       3  female  27.0      0      2  11.1333        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 87:**
#
# **Create a DataFrame and calculate the expanding covariance.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 87:**
# </div>

# %%
# Exercise 87:
# Create a DataFrame and calculate the expanding covariance.
df['expanding_cov_grouped'] = df.groupby(by=['pclass'])['fare'].expanding().cov().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 88:**
#
# **Create a DataFrame with random values and calculate the expanding correlation.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 88:**
# </div>

# %%
# Exercise 88:
# Create a DataFrame with random values and calculate the expanding correlation.

df['expanding_corr_grouped'] = df.groupby(by=['pclass'])['fare'].expanding().corr().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 89:**
#
# **Create a DataFrame and calculate the expanding median.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 89:**
# </div>

# %%
# Exercise 89:
# Create a DataFrame and calculate the expanding median.

df['expanding_median_grouped'] = df.groupby(by=['embark_town'])['fare'].expanding().median().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['embark_town', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 19     19         1       3  female   NaN      0      0   7.2250        C
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 16     16         0       3    male   2.0      4      1  29.1250        Q
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 7       7         0       3    male   2.0      3      1  21.0750        S
# 8       8         1       3  female  27.0      0      2  11.1333        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 90:**
#
# **Create a DataFrame with datetime index and calculate the expanding mean for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 90:**
# </div>

# %%
# Exercise 90:
# Create a DataFrame with datetime index and calculate the expanding mean for each group.

date_rng = pd.date_range(start='2023-01-01', end='2023-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.rand(len(date_rng))
df['group'] = np.random.choice(['A', 'B', 'C'], size=len(date_rng))
df.set_index('date', inplace=True)
print("DataFrame with datetime index:")
display(df.head(10))
print("Expanding mean for each group:")
# expanding_mean_grouped = df.groupby(by=['group'])['data'].expanding().mean().reset_index(drop=True)
# df['expanding_mean_grouped'] = expanding_mean_grouped
# display(df.head(20))

# fix using transform
expanding_mean_grouped = df.groupby('group')['data'].transform(lambda x: x.expanding().mean())
df['expanding_mean_grouped'] = expanding_mean_grouped
display(df.head(20))
# Out:
# DataFrame with datetime index:
#                 data group
# date
# 2023-01-01  0.175495     A
# 2023-01-02  0.551956     C
# 2023-01-03  0.133026     B
# 2023-01-04  0.663577     C
# 2023-01-05  0.258708     A
# 2023-01-06  0.413909     B
# 2023-01-07  0.860290     C
# 2023-01-08  0.521611     C
# 2023-01-09  0.289731     C
# 2023-01-10  0.967193     B
# Expanding mean for each group:
#                 data group  expanding_mean_grouped
# date
# 2023-01-01  0.175495     A                0.175495
# 2023-01-02  0.551956     C                0.551956
# 2023-01-03  0.133026     B                0.133026
# 2023-01-04  0.663577     C                0.607767
# 2023-01-05  0.258708     A                0.217101
# 2023-01-06  0.413909     B                0.273467
# 2023-01-07  0.860290     C                0.691941
# 2023-01-08  0.521611     C                0.649359
# 2023-01-09  0.289731     C                0.577433
# 2023-01-10  0.967193     B                0.504709
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 91:**
#
# **Create a DataFrame with random values and calculate the rolling sum for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 91:**
# </div>

# %%
# Exercise 91:
# Create a DataFrame with random values and calculate the rolling sum for each group.

df['rolling_sum_grouped'] = df.groupby(by=['pclass'])['fare'].rolling(window=3).sum().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 92:**
#
# **Create a DataFrame and calculate the rolling mean for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 92:**
# </div>

# %%
# Exercise 92:
# Create a DataFrame and calculate the rolling mean for each group.

df['rolling_mean_grouped'] = df.groupby(by=['pclass'])['fare'].rolling(window=3).mean().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 93:**
#
# **Create a DataFrame with random values and calculate the rolling standard deviation for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 93:**
# </div>

# %%
# Exercise 93:
# Create a DataFrame with random values and calculate the rolling standard deviation for each group.

df['rolling_std_grouped'] = df.groupby(by=['pclass'])['fare'].rolling(window=3).std().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 94:**
#
# **Create a DataFrame and calculate the rolling variance for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 94:**
# </div>

# %%
# Exercise 94:
# Create a DataFrame and calculate the rolling variance for each group.

df['rolling_var_grouped'] = df.groupby(by=['pclass'])['fare'].rolling(window=3).var().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 95:**
#
# **Create a DataFrame with random values and calculate the rolling correlation for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 95:**
# </div>

# %%
# Exercise 95:
# Create a DataFrame with random values and calculate the rolling correlation for each group.
df['rolling_corr_grouped'] = df.groupby(by=['pclass'])['fare'].rolling(window=3).corr().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 96:**
#
# **Create a DataFrame and calculate the rolling covariance for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 96:**
# </div>

# %%
# Exercise 96:
# Create a DataFrame and calculate the rolling covariance for each group.

df['rolling_cov_grouped'] = df.groupby(by=['pclass'])['fare'].rolling(window=3).cov().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 97:**
#
# **Create a DataFrame with random values and calculate the rolling skewness for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 97:**
# </div>

# %%
# Exercise 97:
# Create a DataFrame with random values and calculate the rolling skewness for each group.

df['rolling_skew_grouped'] = df.groupby(by=['pclass'])['fare'].rolling(window=3).skew().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...

# %% [markdown]
# <div class="alert alert-warning">
#
# **Exercise 98:**
#
# **Create a DataFrame and calculate the rolling kurtosis for each group.**
#
# </div>

# %%
path = '../data/'
file_name = 'titanic.csv'
df = pd.read_csv(path + file_name)
print(df.shape)
df.head(20)
# Out:
# (891, 16)
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Solution 98:**
# </div>

# %%
# Exercise 98:
# Create a DataFrame and calculate the rolling kurtosis for each group.

df['rolling_kurt_grouped'] = df.groupby(by=['pclass'])['fare'].rolling(window=3).kurt().reset_index(drop=True)
df.reset_index(drop=False).head(20).sort_values(by=['pclass', 'index'])
# Out:
#     index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 1       1         1       1  female  38.0      1      0  71.2833        C
# 3       3         1       1  female  35.0      1      0  53.1000        S
# 6       6         0       1    male  54.0      0      0  51.8625        S
# 11     11         1       1  female  58.0      0      0  26.5500        S
# 9       9         1       2  female  14.0      1      0  30.0708        C
# 15     15         1       2  female  55.0      0      0  16.0000        S
# 17     17         1       2    male   NaN      0      0  13.0000        S
# 0       0         0       3    male  22.0      1      0   7.2500        S
# 2       2         1       3  female  26.0      0      0   7.9250        S
# 4       4         0       3    male  35.0      0      0   8.0500        S
# 5       5         0       3    male   NaN      0      0   8.4583        Q
# 7       7         0       3    male   2.0      3      1  21.0750        S
# ...
