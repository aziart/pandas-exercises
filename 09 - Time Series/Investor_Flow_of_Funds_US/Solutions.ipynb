# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
pd.set_option("display.float_format", "{:,.2f}".format)
pd.set_option("display.max_columns", None)
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %%
path = "../../data/investor_flow.csv"
df = pd.read_csv(path)
df.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity    Hybrid  \
# 0  2011-10-05         -4002        -4,499.00           497 -1,354.00
# 1  2011-10-12         -7397        -5,842.00         -1555    512.00
# 2  2011-10-19         -3292        -3,466.00           174  1,399.00
# 3  2011-10-26         -3696        -2,998.00          -698  2,631.00
# 4  2011-12-07         -7956        -5,761.00         -2196  1,089.00
#
#    Total Bond  Taxable Bond  Municipal Bond      Total
# 0       -5828     -6,258.00             430 -11,184.00
# 1        3954      3,927.00              28  -2,931.00
# 2        5652      5,102.00             550   3,759.00
# 3        4910      4,070.00             841   3,846.00
# 4        3523      2,068.00            1456  -3,343.00

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
called = df.copy()
called['Date'] = pd.to_datetime(called['Date'])
called.head()
# Out:
#         Date  Total Equity  Domestic Equity  World Equity    Hybrid  \
# 0 2011-10-05         -4002        -4,499.00           497 -1,354.00
# 1 2011-10-12         -7397        -5,842.00         -1555    512.00
# 2 2011-10-19         -3292        -3,466.00           174  1,399.00
# 3 2011-10-26         -3696        -2,998.00          -698  2,631.00
# 4 2011-12-07         -7956        -5,761.00         -2196  1,089.00
#
#    Total Bond  Taxable Bond  Municipal Bond      Total
# 0       -5828     -6,258.00             430 -11,184.00
# 1        3954      3,927.00              28  -2,931.00
# 2        5652      5,102.00             550   3,759.00
# 3        4910      4,070.00             841   3,846.00
# 4        3523      2,068.00            1456  -3,343.00

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
called.sort_values(by=['Date']
                   , ascending=True)['Date'].diff().value_counts().index[0]
# Out:
# Timedelta('7 days 00:00:00')

# %% [markdown]
# <font color="red">Answer:</font> Weekly

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
called.set_index("Date"
                 , inplace=True)
called.head()
# Out:
#             Total Equity  Domestic Equity  World Equity    Hybrid  Total Bond  \
# Date
# 2011-10-05         -4002        -4,499.00           497 -1,354.00       -5828
# 2011-10-12         -7397        -5,842.00         -1555    512.00        3954
# 2011-10-19         -3292        -3,466.00           174  1,399.00        5652
# 2011-10-26         -3696        -2,998.00          -698  2,631.00        4910
# 2011-12-07         -7956        -5,761.00         -2196  1,089.00        3523
#
#             Taxable Bond  Municipal Bond      Total
# Date
# 2011-10-05     -6,258.00             430 -11,184.00
# 2011-10-12      3,927.00              28  -2,931.00
# 2011-10-19      5,102.00             550   3,759.00
# 2011-10-26      4,070.00             841   3,846.00
# 2011-12-07      2,068.00            1456  -3,343.00

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
called.reset_index().dtypes
# Out:
# Date               datetime64[ns]
# Total Equity                int64
# Domestic Equity           float64
# World Equity                int64
# Hybrid                    float64
# Total Bond                  int64
# Taxable Bond              float64
# Municipal Bond              int64
# Total                     float64
# dtype: object

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
called.index = pd.to_datetime(called.index)
type(called.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

#