# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import numpy as np
import pandas as pd
pd.set_option("display.float_format", "{:.2f}".format)
pd.set_option("display.max_columns", None)

import warnings
warnings.filterwarnings("ignore")

# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns


# print the graphs in the notebook
# %matplotlib inline

# set seaborn style to white
sns.set_style("white")

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %%
path = "../../data/"
fname = "tips.csv"
df = pd.read_csv(path+fname)
df
# Out:
#      Unnamed: 0  total_bill  tip     sex smoker   day    time  size
# 0             0       16.99 1.01  Female     No   Sun  Dinner     2
# 1             1       10.34 1.66    Male     No   Sun  Dinner     3
# 2             2       21.01 3.50    Male     No   Sun  Dinner     3
# 3             3       23.68 3.31    Male     No   Sun  Dinner     2
# 4             4       24.59 3.61  Female     No   Sun  Dinner     4
# ..          ...         ...  ...     ...    ...   ...     ...   ...
# 239         239       29.03 5.92    Male     No   Sat  Dinner     3
# 240         240       27.18 2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67 2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82 1.75    Male     No   Sat  Dinner     2
# 243         243       18.78 3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = df.copy()
tips
# Out:
#      Unnamed: 0  total_bill  tip     sex smoker   day    time  size
# 0             0       16.99 1.01  Female     No   Sun  Dinner     2
# 1             1       10.34 1.66    Male     No   Sun  Dinner     3
# 2             2       21.01 3.50    Male     No   Sun  Dinner     3
# 3             3       23.68 3.31    Male     No   Sun  Dinner     2
# 4             4       24.59 3.61  Female     No   Sun  Dinner     4
# ..          ...         ...  ...     ...    ...   ...     ...   ...
# 239         239       29.03 5.92    Male     No   Sat  Dinner     3
# 240         240       27.18 2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67 2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82 1.75    Male     No   Sat  Dinner     2
# 243         243       18.78 3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips = tips.drop(columns=['Unnamed: 0']
             , axis=1)
tips
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 0         16.99 1.01  Female     No   Sun  Dinner     2
# 1         10.34 1.66    Male     No   Sun  Dinner     3
# 2         21.01 3.50    Male     No   Sun  Dinner     3
# 3         23.68 3.31    Male     No   Sun  Dinner     2
# 4         24.59 3.61  Female     No   Sun  Dinner     4
# ..          ...  ...     ...    ...   ...     ...   ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2
# 242       17.82 1.75    Male     No   Sat  Dinner     2
# 243       18.78 3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
total_bill_start = -10
total_bill_end = 65
total_bill_interval = 10

buckets = np.arange(total_bill_start
                  , total_bill_end
                  , total_bill_interval)
buckets
total_bill_group = pd.cut(tips['total_bill'], buckets)
tips.insert(loc = len(tips.columns)
            , column="total_bill_group"
            , value=total_bill_group
            , allow_duplicates=True)
tips
# online_rt.groupby(UnitPrice_grouped)['SalesVolume'].sum()
# Out:
#      total_bill  tip     sex smoker   day    time  size total_bill_group
# 0         16.99 1.01  Female     No   Sun  Dinner     2         (10, 20]
# 1         10.34 1.66    Male     No   Sun  Dinner     3         (10, 20]
# 2         21.01 3.50    Male     No   Sun  Dinner     3         (20, 30]
# 3         23.68 3.31    Male     No   Sun  Dinner     2         (20, 30]
# 4         24.59 3.61  Female     No   Sun  Dinner     4         (20, 30]
# ..          ...  ...     ...    ...   ...     ...   ...              ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3         (20, 30]
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2         (20, 30]
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2         (20, 30]
# 242       17.82 1.75    Male     No   Sat  Dinner     2         (10, 20]
# 243       18.78 3.00  Female     No  Thur  Dinner     2         (10, 20]
#
# [244 rows x 8 columns]

# %%
sns.histplot(
    data=tips
    , x="total_bill"
    , bins=buckets
    , kde=True
);
plt.show();

sns.histplot(
    data=tips
    , x="total_bill"
    , kde=True
);

# %%
sns.displot(
    data=tips
    , x='total_bill'
    , kind='hist'
)
sns.displot(
    data=tips
    , x='total_bill'
    , kind='kde'
)

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
tips
# Out:
#      total_bill  tip     sex smoker   day    time  size total_bill_group
# 0         16.99 1.01  Female     No   Sun  Dinner     2         (10, 20]
# 1         10.34 1.66    Male     No   Sun  Dinner     3         (10, 20]
# 2         21.01 3.50    Male     No   Sun  Dinner     3         (20, 30]
# 3         23.68 3.31    Male     No   Sun  Dinner     2         (20, 30]
# 4         24.59 3.61  Female     No   Sun  Dinner     4         (20, 30]
# ..          ...  ...     ...    ...   ...     ...   ...              ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3         (20, 30]
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2         (20, 30]
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2         (20, 30]
# 242       17.82 1.75    Male     No   Sat  Dinner     2         (10, 20]
# 243       18.78 3.00  Female     No  Thur  Dinner     2         (10, 20]
#
# [244 rows x 8 columns]

# %%
# Scatter plot + distribution

sns.jointplot(
    data=tips
    , x='total_bill'
    , y='tip'
    , hue="time"
    # , height=10
    , legend=True
    , ratio=4
    , kind="scatter"
);

# %%
sns.jointplot(
    data=tips
    , x='total_bill'
    , y='tip'
    , kind='scatter'
    , legend=False
)

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
tips
# Out:
#      total_bill  tip     sex smoker   day    time  size total_bill_group
# 0         16.99 1.01  Female     No   Sun  Dinner     2         (10, 20]
# 1         10.34 1.66    Male     No   Sun  Dinner     3         (10, 20]
# 2         21.01 3.50    Male     No   Sun  Dinner     3         (20, 30]
# 3         23.68 3.31    Male     No   Sun  Dinner     2         (20, 30]
# 4         24.59 3.61  Female     No   Sun  Dinner     4         (20, 30]
# ..          ...  ...     ...    ...   ...     ...   ...              ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3         (20, 30]
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2         (20, 30]
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2         (20, 30]
# 242       17.82 1.75    Male     No   Sat  Dinner     2         (10, 20]
# 243       18.78 3.00  Female     No  Thur  Dinner     2         (10, 20]
#
# [244 rows x 8 columns]

# %%
g = sns.pairplot(
    data=tips
    , vars=['total_bill', 'tip', 'size']
)
plt.show();

# %%
g = sns.pairplot(
    data=tips
    , vars=['total_bill', 'tip', 'size']
    , corner=True
)
plt.show();

# %%
g = sns.pairplot(
    data=tips
    , vars=['total_bill', 'tip', 'size']
    , hue='time'
    , corner=True
    , size=2
)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
tips
# Out:
#      total_bill  tip     sex smoker   day    time  size total_bill_group
# 0         16.99 1.01  Female     No   Sun  Dinner     2         (10, 20]
# 1         10.34 1.66    Male     No   Sun  Dinner     3         (10, 20]
# 2         21.01 3.50    Male     No   Sun  Dinner     3         (20, 30]
# 3         23.68 3.31    Male     No   Sun  Dinner     2         (20, 30]
# 4         24.59 3.61  Female     No   Sun  Dinner     4         (20, 30]
# ..          ...  ...     ...    ...   ...     ...   ...              ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3         (20, 30]
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2         (20, 30]
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2         (20, 30]
# 242       17.82 1.75    Male     No   Sat  Dinner     2         (10, 20]
# 243       18.78 3.00  Female     No  Thur  Dinner     2         (10, 20]
#
# [244 rows x 8 columns]

# %%
g = sns.catplot(
    data=tips
    , x='day'
    , y='total_bill'
    , hue='day'
    , aspect=1.5
    , alpha=0.5
    , legend=True
)
g.set_xticklabels(rotation=45, horizontalalignment='right')

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
g = sns.catplot(
    data=tips
    , x='tip'
    , y='day'
    , hue='sex'
    , aspect=1.5
    , alpha=0.5
    , legend=True
)
g.set_xticklabels(rotation=45, horizontalalignment='right')

# %%
sns.stripplot(x = "day", y = "tip", hue = "sex", data = tips, jitter = True);
plt.show();
sns.stripplot(x = "tip", y = "day", hue = "sex", data = tips, jitter = True);
plt.show();

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.catplot(
    data=tips,
    x="day",
    y="total_bill",
    hue="time",
    aspect=1.5,
    kind="box",
).set_xticklabels(rotation=45, horizontalalignment="right");
plt.show();

# %%
sns.catplot(
    data=tips,
    x="day",
    y="total_bill",
    hue="time",
    aspect=1.5,
    kind="boxen",
).set_xticklabels(rotation=45, horizontalalignment="right");
plt.show();

# %%
sns.catplot(
    data=tips,
    x="day",
    y="total_bill",
    hue="time",
    aspect=1.5,
    kind="violin",
).set_xticklabels(rotation=45, horizontalalignment="right");
plt.show();

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
g = sns.displot(
    data=tips
    , x='tip'
    , col='time'
    # , hue='time'
    , legend=True
    , alpha=.5
    , kind='hist' # or kde
    , aspect=2
    , col_wrap=2
    , kde=True
    , color="grey"
);

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
tips
# Out:
#      total_bill  tip     sex smoker   day    time  size total_bill_group
# 0         16.99 1.01  Female     No   Sun  Dinner     2         (10, 20]
# 1         10.34 1.66    Male     No   Sun  Dinner     3         (10, 20]
# 2         21.01 3.50    Male     No   Sun  Dinner     3         (20, 30]
# 3         23.68 3.31    Male     No   Sun  Dinner     2         (20, 30]
# 4         24.59 3.61  Female     No   Sun  Dinner     4         (20, 30]
# ..          ...  ...     ...    ...   ...     ...   ...              ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3         (20, 30]
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2         (20, 30]
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2         (20, 30]
# 242       17.82 1.75    Male     No   Sat  Dinner     2         (10, 20]
# 243       18.78 3.00  Female     No  Thur  Dinner     2         (10, 20]
#
# [244 rows x 8 columns]

# %%
g = sns.relplot(
    data=tips
    , x='total_bill'
    , y='tip'
    , col='sex'
    , hue='smoker'
    , kind='scatter'
    , col_wrap=2
    , aspect=1.2
)

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
